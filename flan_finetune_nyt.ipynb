# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset
from transformers import DataCollatorForSeq2Seq
import torch
import evaluate
import numpy as np
import ast
import jsonlines
import json
import re
import glob
import numpy as np
from tqdm import tqdm

# %%
torch.cuda.empty_cache()

model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-large", 
                                              cache_dir="/scratch/wadhwa.s/cache", 
                                              device_map="auto")
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-large", 
                                          cache_dir="/scratch/wadhwa.s/cache")

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

# %%
rouge = evaluate.load("rouge")

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    result = rouge.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    return {k: round(v, 4) for k, v in result.items()}

# %%
path = "/home/wadhwa.s/gpt3/nyt_explanations/"
df = pd.read_csv(path + "nyt_explanations_training.csv")
df.head()
# Out:
#                                                input  \
# 0  TEXT: When Weah returned to Liberia this sprin...
# 1  TEXT: Senate Republicans intend to be as coope...
# 2  TEXT: Libya , where young men in Darfur used t...
# 3  TEXT: They crossed five international boundari...
# 4  TEXT: Ending with a rock 'n' rock fiesta in En...
#
#                                       gold_relations  \
# 0  [['Florida', '/location/location/contains', 'F...
# 1  [['Mitch McConnell', '/people/person/place_liv...
# 2  [['Darfur', '/location/administrative_division...
# 3  [['Africa', '/location/location/contains', 'Ni...
# 4  [['Mexico', '/location/location/contains', 'En...
#
#                                         explanations
# 0  Explanation: Fort Lauderdale is a location in ...
# 1  Explanation: Mitch McConnell is a person who l...
# 2  Explanation: Darfur is a place located in the ...
# 3  Explanation: Nigeria, Chad, Accra, Benin and T...
# 4  Explanation: Ensenada is a location located in...

# %%
nyt_data = load_dataset("csv", data_files=path+"nyt_explanations_training.csv")
nyt_data = nyt_data["train"]
# Out:
# Using custom data configuration default-915147562b964706
# Found cached dataset csv (/home/wadhwa.s/.cache/huggingface/datasets/csv/default-915147562b964706/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
# 100%|██████████| 1/1 [00:00<00:00, 538.84it/s]

# %%
prefix = "List all relations between entities of the types [LOCATION, PERSON, ORGANIZATION] in the following TEXT and provide reasonable explanation:\n\n"
print (prefix + nyt_data[0]["input"] + "\nRelations: ")
# Out:
# List all relations between entities of the types [LOCATION, PERSON, ORGANIZATION] in the following TEXT and provide reasonable explanation:
#
# TEXT: When Weah returned to Liberia this spring after a long sojourn in Florida -- his American wife and children live in Fort Lauderdale -- his arrival shut down the capital for the day .
# Relations:

# %%
nyt = nyt_data.train_test_split(test_size=0.1)
nyt
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'gold_relations', 'explanations'],
#         num_rows: 22438
#     })
#     test: Dataset({
#         features: ['input', 'gold_relations', 'explanations'],
#         num_rows: 2494
#     })
# })

# %%
target = [prefix + example + "\nRelations: " for example in nyt["train"]["input"]]
print (target[0])
# Out:
# List all relations between entities of the types [LOCATION, PERSON, ORGANIZATION] in the following TEXT and provide reasonable explanation:
#
# TEXT: The lack of security that led to some of the election problems continued to be an issue in Iraq , as one American soldier was killed and another was wounded just after noon on Wednesday in an insurgent attack on a convoy near Baghdad , the United States military said .
# Relations:

# %%
def preprocess_function(examples):
    inputs = [prefix + example + "\nRelations: " for example in examples["input"]]
    model_inputs = tokenizer(inputs, max_length=512, truncation=True)
    targets = [gold_relations + "\n" + explanation for gold_relations, explanation in zip(examples["gold_relations"], examples["explanations"])]
    labels = tokenizer(text_target=targets, max_length=256, truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_nyt = nyt.map(preprocess_function, batched=True)
# Out:
# 100%|██████████| 23/23 [00:09<00:00,  2.55ba/s]
# 100%|██████████| 3/3 [00:00<00:00,  3.11ba/s]

# %%
tokenized_nyt
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'gold_relations', 'explanations', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 22438
#     })
#     test: Dataset({
#         features: ['input', 'gold_relations', 'explanations', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 2494
#     })
# })

# %%
torch.cuda.empty_cache()

training_args = Seq2SeqTrainingArguments(
    output_dir="/scratch/wadhwa.s/cache/nyt_explanations",
    evaluation_strategy="steps",
    logging_strategy="steps",
    learning_rate=3e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    logging_steps=1000,
    eval_delay=1000,
    save_total_limit=7,
    weight_decay=0.01,
    num_train_epochs=10,
    predict_with_generate=True,
    # gradient_accumulation_steps=4,
    # fp16=True,
    # push_to_hub=True,
)
# Out:
# using `logging_steps` to initialize `eval_steps` to 1000
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_nyt["train"],
    eval_dataset=tokenized_nyt["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 22438
#   Num Epochs = 10
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 56100
#   Number of trainable parameters = 783150080
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# wandb: Currently logged in as: sw7. Use `wandb login --relogin` to force relogin
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/wadhwa.s/gpt3/wandb/run-20230103_144634-zh6hm2t7</code>
# Syncing run <strong><a href="https://wandb.ai/sw7/huggingface/runs/zh6hm2t7" target="_blank">/scratch/wadhwa.s/cache/nyt_explanations</a></strong> to <a href="https://wandb.ai/sw7/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='21001' max='56100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [21001/56100 5:46:59 < 9:39:59, 1.01 it/s, Epoch 3.74/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.249000</td>
#       <td>0.140235</td>
#       <td>0.306200</td>
#       <td>0.248600</td>
#       <td>0.305200</td>
#       <td>0.305100</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.155500</td>
#       <td>0.121165</td>
#       <td>0.315900</td>
#       <td>0.260100</td>
#       <td>0.315100</td>
#       <td>0.315100</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.139300</td>
#       <td>0.112603</td>
#       <td>0.319800</td>
#       <td>0.264600</td>
#       <td>0.319500</td>
#       <td>0.319300</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.134400</td>
#       <td>0.109109</td>
#       <td>0.315800</td>
#       <td>0.260900</td>
#       <td>0.315300</td>
#       <td>0.315200</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.123800</td>
#       <td>0.105850</td>
#       <td>0.321900</td>
#       <td>0.266900</td>
#       <td>0.321600</td>
#       <td>0.321700</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.116100</td>
#       <td>0.103039</td>
#       <td>0.323000</td>
#       <td>0.267700</td>
#       <td>0.322500</td>
#       <td>0.322400</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.106800</td>
#       <td>0.100134</td>
#       <td>0.321600</td>
#       <td>0.266500</td>
#       <td>0.321200</td>
#       <td>0.321300</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.108400</td>
#       <td>0.098545</td>
#       <td>0.323500</td>
#       <td>0.268700</td>
#       <td>0.323000</td>
#       <td>0.322900</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.101500</td>
#       <td>0.097185</td>
#       <td>0.323900</td>
#       <td>0.269200</td>
#       <td>0.323500</td>
#       <td>0.323600</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.102600</td>
#       <td>0.094230</td>
#       <td>0.325300</td>
#       <td>0.270100</td>
#       <td>0.324900</td>
#       <td>0.324800</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.101900</td>
#       <td>0.092658</td>
#       <td>0.326100</td>
#       <td>0.271500</td>
#       <td>0.325800</td>
#       <td>0.325800</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.092800</td>
#       <td>0.092562</td>
#       <td>0.326200</td>
#       <td>0.271600</td>
#       <td>0.326000</td>
#       <td>0.325900</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.087900</td>
#       <td>0.092655</td>
#       <td>0.326700</td>
#       <td>0.272200</td>
#       <td>0.326400</td>
#       <td>0.326400</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.088500</td>
#       <td>0.091816</td>
#       <td>0.326900</td>
#       <td>0.272700</td>
#       <td>0.326600</td>
#       <td>0.326500</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.088000</td>
#       <td>0.091526</td>
#       <td>0.324900</td>
#       <td>0.270200</td>
#       <td>0.324500</td>
#       <td>0.324500</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.087900</td>
#       <td>0.090041</td>
#       <td>0.326700</td>
#       <td>0.272300</td>
#       <td>0.326500</td>
#       <td>0.326400</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.084700</td>
#       <td>0.089943</td>
#       <td>0.325000</td>
#       <td>0.270700</td>
#       <td>0.324700</td>
#       <td>0.324600</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.079300</td>
#       <td>0.091871</td>
#       <td>0.327600</td>
#       <td>0.273000</td>
#       <td>0.327300</td>
#       <td>0.327300</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.076700</td>
#       <td>0.090645</td>
#       <td>0.328500</td>
#       <td>0.274200</td>
#       <td>0.328300</td>
#       <td>0.328200</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.078400</td>
#       <td>0.090437</td>
#       <td>0.326800</td>
#       <td>0.272000</td>
#       <td>0.326400</td>
#       <td>0.326400</td>
#       <td>19.000000</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='120' max='624' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/624 01:39 < 07:00, 1.20 it/s]
#     </div>
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-500/spiece.model
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1000/spiece.model
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1500/spiece.model
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2000/spiece.model
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2500/spiece.model
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3000/spiece.model
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3500/spiece.model
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-5500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-7500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-8500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-9500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-10500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-11500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-12500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-13500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-18000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-18000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-18000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-18000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-14500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-18500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-18500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-18500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-18500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-19000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-19000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-19000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-19000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-15500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-19500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-19500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-19500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-19500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-19500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-19500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-20000
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-20000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-20000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-20000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-16500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-20500
# Configuration saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-20500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-20500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-20500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-20500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/nyt_explanations/checkpoint-20500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: gold_relations, explanations, input. If gold_relations, explanations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2494
#   Batch size = 4
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_4613/4032920361.py:1 in <cell line: 1>                                            │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_4613/4032920361.py'                         │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/trainer.py:1501 in      │
# │ train                                                                                            │
# │                                                                                                  │
# │   1498 │   │   inner_training_loop = find_executable_batch_size(                                 │
# │   1499 │   │   │   self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size  │
# │   1500 │   │   )                                                                                 │
# │ ❱ 1501 │   │   return inner_training_loop(                                                       │
# │   1502 │   │   │   args=args,                                                                    │
# │   1503 │   │   │   resume_from_checkpoint=resume_from_checkpoint,                                │
# │   1504 │   │   │   trial=trial,                                                                  │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/trainer.py:1826 in      │
# │ _inner_training_loop                                                                             │
# │                                                                                                  │
# │   1823 │   │   │   │   │   self.state.epoch = epoch + (step + 1) / steps_in_epoch                │
# │   1824 │   │   │   │   │   self.control = self.callback_handler.on_step_end(args, self.state, s  │
# │   1825 │   │   │   │   │                                                                         │
# │ ❱ 1826 │   │   │   │   │   self._maybe_log_save_evaluate(tr_loss, model, trial, epoch, ignore_k  │
# │   1827 │   │   │   │   else:                                                                     │
# │   1828 │   │   │   │   │   self.control = self.callback_handler.on_substep_end(args, self.state  │
# │   1829                                                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/trainer.py:2089 in      │
# │ _maybe_log_save_evaluate                                                                         │
# │                                                                                                  │
# │   2086 │   │   │   │   │   │   metric_key_prefix=f"eval_{eval_dataset_name}",                    │
# │   2087 │   │   │   │   │   )                                                                     │
# │   2088 │   │   │   else:                                                                         │
# │ ❱ 2089 │   │   │   │   metrics = self.evaluate(ignore_keys=ignore_keys_for_eval)                 │
# │   2090 │   │   │   self._report_to_hp_search(trial, self.state.global_step, metrics)             │
# │   2091 │   │                                                                                     │
# │   2092 │   │   if self.control.should_save:                                                      │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/trainer_seq2seq.py:78   │
# │ in evaluate                                                                                      │
# │                                                                                                  │
# │    75 │   │   )                                                                                  │
# │    76 │   │   self._gen_kwargs = gen_kwargs                                                      │
# │    77 │   │                                                                                      │
# │ ❱  78 │   │   return super().evaluate(eval_dataset, ignore_keys=ignore_keys, metric_key_prefix   │
# │    79 │                                                                                          │
# │    80 │   def predict(                                                                           │
# ...
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/accelerate/hooks.py:148 in           │
# │ new_forward                                                                                      │
# │                                                                                                  │
# │   145 │   │   │   with torch.no_grad():                                                          │
# │   146 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   147 │   │   else:                                                                              │
# │ ❱ 148 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   149 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   150 │                                                                                          │
# │   151 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.p │
# │ y:1648 in forward                                                                                │
# │                                                                                                  │
# │   1645 │   │   │   │   decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_de  │
# │   1646 │   │                                                                                     │
# │   1647 │   │   # Decode                                                                          │
# │ ❱ 1648 │   │   decoder_outputs = self.decoder(                                                   │
# │   1649 │   │   │   input_ids=decoder_input_ids,                                                  │
# │   1650 │   │   │   attention_mask=decoder_attention_mask,                                        │
# │   1651 │   │   │   inputs_embeds=decoder_inputs_embeds,                                          │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in   │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/accelerate/hooks.py:148 in           │
# │ new_forward                                                                                      │
# │                                                                                                  │
# │   145 │   │   │   with torch.no_grad():                                                          │
# │   146 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   147 │   │   else:                                                                              │
# │ ❱ 148 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   149 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   150 │                                                                                          │
# │   151 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.p │
# │ y:1040 in forward                                                                                │
# │                                                                                                  │
# │   1037 │   │   │   │   │   None,  # past_key_value is always None with gradient checkpointing    │
# │   1038 │   │   │   │   )                                                                         │
# │   1039 │   │   │   else:                                                                         │
# │ ❱ 1040 │   │   │   │   layer_outputs = layer_module(                                             │
# │   1041 │   │   │   │   │   hidden_states,                                                        │
# │   1042 │   │   │   │   │   attention_mask=extended_attention_mask,                               │
# │   1043 │   │   │   │   │   position_bias=position_bias,                                          │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in   │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/accelerate/hooks.py:148 in           │
# │ new_forward                                                                                      │
# │                                                                                                  │
# │   145 │   │   │   with torch.no_grad():                                                          │
# │   146 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   147 │   │   else:                                                                              │
# │ ❱ 148 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   149 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   150 │                                                                                          │
# │   151 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.p │
# │ y:673 in forward                                                                                 │
# │                                                                                                  │
# │    670 │   │   else:                                                                             │
# │    671 │   │   │   self_attn_past_key_value, cross_attn_past_key_value = None, None              │
# │    672 │   │                                                                                     │
# │ ❱  673 │   │   self_attention_outputs = self.layer[0](                                           │
# │    674 │   │   │   hidden_states,                                                                │
# │    675 │   │   │   attention_mask=attention_mask,                                                │
# │    676 │   │   │   position_bias=position_bias,                                                  │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in   │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/accelerate/hooks.py:148 in           │
# │ new_forward                                                                                      │
# │                                                                                                  │
# │   145 │   │   │   with torch.no_grad():                                                          │
# │   146 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   147 │   │   else:                                                                              │
# │ ❱ 148 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   149 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   150 │                                                                                          │
# │   151 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.p │
# │ y:579 in forward                                                                                 │
# │                                                                                                  │
# │    576 │   │   output_attentions=False,                                                          │
# │    577 │   ):                                                                                    │
# │    578 │   │   normed_hidden_states = self.layer_norm(hidden_states)                             │
# │ ❱  579 │   │   attention_output = self.SelfAttention(                                            │
# │    580 │   │   │   normed_hidden_states,                                                         │
# │    581 │   │   │   mask=attention_mask,                                                          │
# │    582 │   │   │   position_bias=position_bias,                                                  │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in   │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/accelerate/hooks.py:148 in           │
# │ new_forward                                                                                      │
# │                                                                                                  │
# │   145 │   │   │   with torch.no_grad():                                                          │
# │   146 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   147 │   │   else:                                                                              │
# │ ❱ 148 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   149 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   150 │                                                                                          │
# │   151 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.p │
# │ y:509 in forward                                                                                 │
# │                                                                                                  │
# │    506 │   │   )                                                                                 │
# │    507 │   │                                                                                     │
# │    508 │   │   # compute scores                                                                  │
# │ ❱  509 │   │   scores = torch.matmul(                                                            │
# │    510 │   │   │   query_states, key_states.transpose(3, 2)                                      │
# │    511 │   │   )  # equivalent of torch.einsum("bnqd,bnkd->bnqk", query_states, key_states), co  │
# │    512                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %% [markdown]
# ## Validation

# %%
prefix = "List all relations between entities of the types [LOCATION, PERSON, ORGANIZATION] in the following TEXT and provide reasonable explanation:\n\n"

# %%
text = []
true_relations = []
num_relations = []

with open("nyt/raw_valid.json") as f:
    for line in f:
        data = ast.literal_eval(line)
        # print (data["sentText"])
        # print ("RELATIONS: ")
        relations = []
        for relation in data["relationMentions"]:
            relations.append([relation["em1Text"], relation["label"], relation["em2Text"]])
        text.append(data["sentText"])
        true_relations.append(relations)
        num_relations.append(len(relations))

# %%
text[0]
# Out:
# 'In Queens , North Shore Towers , near the Nassau border , supplanted a golf course , and housing replaced a gravel quarry in Douglaston .'

# %%
true_relations[0]
# Out:
# [['Douglaston', '/location/neighborhood/neighborhood_of', 'Queens'],
#  ['Queens', '/location/location/contains', 'Douglaston']]

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device
# Out:
# device(type='cuda')

# %%
tuned_model = AutoModelForSeq2SeqLM.from_pretrained("/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17500")
tokenizer = AutoTokenizer.from_pretrained("/scratch/wadhwa.s/cache/nyt_explanations/checkpoint-17500")

# %%
tuned_model = tuned_model.to(device)

# %%
inputs_to_model = []
gold_relations = []
generated_relations = []
full_output = []
nc_flag = []

nc_count = 0
for ix, input in enumerate(tqdm(text)):
    torch.cuda.empty_cache()
    inputs_to_model.append(input)
    gold_relations.append(true_relations[ix])
    input = prefix + input + "\nRelations: "
    inputs = tokenizer(input, return_tensors="pt").input_ids.to(device)
    outputs = tuned_model.generate(inputs, max_new_tokens=256, do_sample=False)
    out = tokenizer.decode(outputs[0], skip_special_tokens=True)
    full_output.append(out)
    try:
        generated = ast.literal_eval(out.split("Explanation:")[0])
        generated_relations.append(generated)
        nc_flag.append(0)
    except:
        nc_count += 1
        nc_flag.append(1)
        generated_relations.append([])
# Out:
# 100%|██████████| 5000/5000 [2:17:21<00:00,  1.65s/it]

# %%
pd.DataFrame({"input": inputs_to_model, "gold_relations": gold_relations, "generated_relations": generated_relations, "full_output": full_output, "nc_flag": nc_flag}).to_csv("nyt/nyt_explanations_output.csv", index=False)

# %%
for i, j, k in zip(inputs_to_model, gold_relations, generated_relations):
    print (i)
    print ("True Relations: ", j)
    print ("Generated Relations: ", k)
    print ("\n----------------------\n")
# Out:
# In Queens , North Shore Towers , near the Nassau border , supplanted a golf course , and housing replaced a gravel quarry in Douglaston .
# True Relations:  [['Douglaston', '/location/neighborhood/neighborhood_of', 'Queens'], ['Queens', '/location/location/contains', 'Douglaston']]
# Generated Relations:  [['Queens', '/location/location/contains', 'Douglaston'], ['Douglaston', '/location/neighborhood/neighborhood_of', 'Queens']]
#
# ----------------------
#
# In his authoritative and tough-minded new book , '' The Assassins ' Gate : America in Iraq , '' the New Yorker writer George Packer reminds us that the decision of the Bush administration to go to war against Iraq and its increasingly embattled handling of the occupation were both predicated upon large , abstract ideas about the role of America in the post-cold war world -- most notably , a belief in pre-emptive and unilateral action , the viability of exporting democracy abroad , the urge to streamline the military and the dream of remaking the Middle East .
# True Relations:  [['Middle East', '/location/location/contains', 'Iraq'], ['Middle East', '/location/location/contains', 'Iraq']]
# Generated Relations:  [['Middle East', '/location/location/contains', 'Iraq'], ['Middle East', '/location/location/contains', 'Iraq']]
#
# ----------------------
#
# Martin , the district attorney for Lehigh County in Pennsylvania , said that after his office 's review of the records , he was satisfied with Mr. Cullen 's denials .
# True Relations:  [['Pennsylvania', '/location/location/contains', 'Lehigh County']]
# Generated Relations:  [['Pennsylvania', '/location/location/contains', 'Lehigh County']]
#
# ----------------------
#
# Mr. Brown has demeaned Mr. Bush as '' a cheerleader , '' declared that Homeland Security Secretary Michael Chertoff did not know '' the first thing about running a disaster , '' and called critics like Representative Gene Taylor , Democrat of Mississippi , '' a little twerp '' and Senator Norm Coleman , Republican of Minnesota , an unprintable vulgarity -LRB- both in Playboy -RRB- .
# True Relations:  [['Gene Taylor', '/people/person/place_lived', 'Mississippi']]
# Generated Relations:  [['Norm Coleman', '/people/person/place_lived', 'Minnesota']]
#
# ----------------------
#
# Pakistan 's president , Pervez Musharraf , and President Hamid Karzai talked by telephone for an hour on Tuesday , a day after the Afghan intelligence service said it had arrested three Pakistanis who were trying to assassinate the American ambassador , Zalmay Khalilzad . ''
# True Relations:  [['Pervez Musharraf', '/people/person/nationality', 'Pakistan']]
# Generated Relations:  [['Pervez Musharraf', '/people/person/nationality', 'Pakistan'], ['Hamid Karzai', '/people/person/nationality', 'Pakistan']]
#
# ----------------------
#
# Martha Whitney Bagnall , the daughter of Whitney S. Bagnall and Roger S. Bagnall of New York , is to be married today in Rhinebeck , N.Y. , to Edward Bing Han , the son of Chou-Yeen Han and Bing-Hou Han of Hopewell Junction , N.Y. Lynn Tomalas , a Universal Life minister , is to officiate at the Wilderstein Preservation , a historic house on the Hudson River .
# True Relations:  [['New York', '/location/location/contains', 'Rhinebeck'], ['New York', '/location/location/contains', 'Hopewell Junction']]
# Generated Relations:  [['New York', '/location/location/contains', 'Hopewell Junction'], ['New York', '/location/location/contains', 'Rhinebeck']]
#
# ----------------------
#
# Russia has been holding up an entry visa to William F. Browder , who controls a $ 4 billion hedge fund in Moscow and is the largest foreign investor in the country 's stock market .
# True Relations:  [['Russia', '/location/location/contains', 'Moscow'], ['Russia', '/location/country/capital', 'Moscow'], ['Russia', '/location/country/administrative_divisions', 'Moscow'], ['Moscow', '/location/administrative_division/country', 'Russia']]
# Generated Relations:  [['Russia', '/location/country/capital', 'Moscow'], ['Russia', '/location/location/contains', 'Moscow']]
#
# ----------------------
#
# It is simple to join emotionally in George Bush 's culture war against the axis of evil , '' editorialized Haaretz , the Israeli newspaper , '' but it must be remembered that , at the end of the day , it is the citizens of Israel and not the Americans who have to continue living in the Middle East .
# True Relations:  [['Middle East', '/location/location/contains', 'Israel']]
# Generated Relations:  [['Middle East', '/location/location/contains', 'Israel']]
#
# ----------------------
#
# For much of the three years since the show first opened at Yale , Peru 's claim on the objects has been played out in behind-the-scenes talks in Lima , Washington and New Haven between Yale and the government of President Alejandro Toledo .
# True Relations:  [['Alejandro Toledo', '/people/person/nationality', 'Peru'], ['Peru', '/location/location/contains', 'Lima'], ['Peru', '/location/country/capital', 'Lima']]
# Generated Relations:  [['Peru', '/location/country/capital', 'Lima'], ['Peru', '/location/location/contains', 'Lima']]
#
# ----------------------
#
# Yale is assuming that it owns the collection , and can negotiate with us which objects it wants to return and which it wants to keep , '' Luis Guillermo Lumbreras , director of Peru 's National Institute of Culture in Lima , said in a telephone interview . ''
# True Relations:  [['Peru', '/location/country/capital', 'Lima'], ['Peru', '/location/location/contains', 'Lima']]
# Generated Relations:  [['Peru', '/location/country/capital', 'Lima'], ['Peru', '/location/location/contains', 'Lima']]
#
# ----------------------
#
# Many people in Turkey have lost hopes in joining Europe and they are looking for other horizons , '' said Onur Oymen , an opposition politician whose party is staunchly secular .
# True Relations:  [['Europe', '/location/location/contains', 'Turkey']]
# Generated Relations:  [['Europe', '/location/location/contains', 'Turkey']]
#
# ----------------------
#
# Should Turkey face eastward , toward its Muslim neighbors , or westward , toward Europe ?
# True Relations:  [['Europe', '/location/location/contains', 'Turkey']]
# Generated Relations:  [['Europe', '/location/location/contains', 'Turkey']]
#
# ----------------------
#
# It was also fictionalized in one of the longest novels ever written , '' Sironia , Texas '' by Madison Cooper , a 1,731-page epic published in two volumes in 1953 .
# True Relations:  [['Madison Cooper', '/people/person/place_lived', 'Texas']]
# Generated Relations:  [['Texas', '/location/location/contains', 'Sironi']]
#
# ----------------------
#
# Some have called for a memorial to the lynched youth to join the many other shrines here in Waco , a city of 113,000 neighboring President Bush 's ranch in Crawford , and home to Baylor University , founded in 1845 , the first institution of higher learning in Texas and the largest Baptist university in the world .
# True Relations:  [['Texas', '/location/location/contains', 'Waco']]
# Generated Relations:  [['Texas', '/location/location/contains', 'Waco'], ['Texas', '/location/location/contains', 'Crawford']]
#
# ----------------------
#
# Israel has been carrying out ground raids in the West Bank and occasional airstrikes in Gaza , saying it is responding to planned or actual Palestinian attacks .
# True Relations:  [['Israel', '/location/location/contains', 'West Bank']]
# Generated Relations:  [['Israel', '/location/location/contains', 'West Bank']]
#
# ----------------------
#
# The Down Time column on Feb. 3 , about the Franklin Institute Science Museum in Philadelphia , misstated Senator John F. Kerry 's gaffe at a popular restaurant during his presidential campaign .
# True Relations:  [['Philadelphia', '/location/location/contains', 'Franklin Institute Science Museum']]
# Generated Relations:  [['John F. Kerry', '/people/person/place_lived', 'Philadelphia'], ['John F. Kerry', '/people/person/place_of_birth', 'Philadelphia']]
#
# ----------------------
#
# WHERE -- Kapalua , Hawaii WHAT -- 2-bedroom house HOW MUCH -- $ 7.95 million This 6,000-square-foot house on Maui has two outdoor showers in private gardens accessible from the houses two full bathrooms .
# True Relations:  [['Hawaii', '/location/location/contains', 'Kapalua']]
# Generated Relations:  [['Hawaii', '/location/location/contains', 'Maui']]
#
# ----------------------
#
# Last month , Dublin , Copenhagen , Munich , Stockholm and Berlin were added to the site bringing the lodging count up to about 600 cheapo places in Europe .
# True Relations:  [['Europe', '/location/location/contains', 'Munich'], ['Europe', '/location/location/contains', 'Berlin']]
# Generated Relations:  [['Europe', '/location/location/contains', 'Munich'], ['Europe', '/location/location/contains', 'Berlin'], ['Europe', '/location/location/contains', 'Stockholm']]
#
# ----------------------
#
# The workers often arrive in convoys , like the 47 repair vehicles from FirstEnergy , a utility holding company in Akron , Ohio , that pulled into the Coliseum parking lot Saturday .
# True Relations:  [['Ohio', '/location/location/contains', 'Akron']]
# Generated Relations:  [['Ohio', '/location/location/contains', 'Akron']]
#
# ----------------------
#
# Randall W. Helmick , the man whose job it is to get the lights back on in New Orleans and many other parts of Louisiana and southern Mississippi , had finally reached his limit .
# True Relations:  [['Louisiana', '/location/location/contains', 'New Orleans']]
# Generated Relations:  [['Louisiana', '/location/location/contains', 'New Orleans']]
#
# ----------------------
#
# Demolition has begun on another purchase in Long Island City , Queens .
# True Relations:  [['Queens', '/location/location/contains', 'Long Island City'], ['Long Island City', '/location/neighborhood/neighborhood_of', 'Queens']]
# Generated Relations:  [['Queens', '/location/location/contains', 'Long Island City'], ['Long Island City', '/location/neighborhood/neighborhood_of', 'Queens']]
#
# ----------------------
#
# But at least 20 cities in Norway have longer nights than Oslo .
# True Relations:  [['Oslo', '/location/administrative_division/country', 'Norway'], ['Norway', '/location/country/capital', 'Oslo'], ['Norway', '/location/country/administrative_divisions', 'Oslo'], ['Norway', '/location/location/contains', 'Oslo']]
# Generated Relations:  [['Norway', '/location/location/contains', 'Oslo'], ['Norway', '/location/country/capital', 'Oslo']]
#
# ----------------------
#
# Attempting to draw a distinction based on the medium used by the blogger or reporter is misguided , said Jack Balkin , a professor at Yale Law School -LRB- also a blogger -RRB- . ''
# True Relations:  [['Jack Balkin', '/business/person/company', 'Yale Law School']]
# Generated Relations:  [['Jack Balkin', '/business/person/company', 'Yale Law School']]
#
# ----------------------
#
# After studying computer science at the University of Pennsylvania in Philadelphia , Mr. Yang took a job as a software engineer at an investment firm downtown .
# True Relations:  [['Philadelphia', '/location/location/contains', 'University of Pennsylvania']]
# Generated Relations:  [['Philadelphia', '/location/location/contains', 'University of Pennsylvania']]
#
# ----------------------
#
# One author of the study , Dr. Pankaj J. Pasricha of the University of Texas Medical Branch at Galveston , said the test for changes in the gastrointestinal tract , an electrogastrogram , was painless and simple to perform .
# True Relations:  [['Galveston', '/location/location/contains', 'University of Texas Medical Branch']]
# Generated Relations:  [['Galveston', '/location/location/contains', 'University of Texas Medical Branch']]
#
# ----------------------
#
# New York City detectives were looking into at least two unsolved cases in Queens , according to law enforcement officials .
# True Relations:  [['New York City', '/location/location/contains', 'Queens']]
# Generated Relations:  [['New York City', '/location/location/contains', 'Queens']]
#
# ----------------------
#
# One ninth-century copy , from the Fulda monastery in Germany , was acquired in 1929 by the New York Academy of Medicine , along with thousands of other culinary books and documents .
# True Relations:  [['Germany', '/location/location/contains', 'Fulda']]
# Generated Relations:  [['Germany', '/location/location/contains', 'Fulda']]
#
# ----------------------
#
# What 's been missing in Washington in the last few months -- to say nothing of capitals in Asia and Europe -- is clear language about what the world is ready to do if Iran and North Korea follow the path of India and Pakistan .
# True Relations:  [['Asia', '/location/location/contains', 'Iran'], ['Asia', '/location/location/contains', 'India'], ['Asia', '/location/location/contains', 'Pakistan'], ['Asia', '/location/location/contains', 'North Korea']]
# Generated Relations:  [['Asia', '/location/location/contains', 'India'], ['Asia', '/location/location/contains', 'North Korea'], ['Asia', '/location/location/contains', 'Pakistan']]
#
# ----------------------
#
# Connecticut Execution Is Cleared to Proceed The United States Supreme Court rejected two last-minute efforts to postpone Connecticut 's execution of a convicted serial killer , clearing the way for the first execution in New England in 45 years .
# True Relations:  [['New England', '/location/location/contains', 'Connecticut']]
# Generated Relations:  [['New England', '/location/location/contains', 'Connecticut']]
#
# ----------------------
#
# The New Jersey Devils gave Newark officials a $ 100 million irrevocable letter of credit yesterday to meet the requirements of the team 's deal with the city to build a $ 310 million arena .
# True Relations:  [['New Jersey Devils', '/sports/sports_team/location', 'Newark'], ['Newark', '/sports/sports_team_location/teams', 'New Jersey Devils']]
# Generated Relations:  [['New Jersey Devils', '/sports/sports_team/location', 'Newark'], ['Newark', '/sports/sports_team_location/teams', 'New Jersey Devils']]
#
# ----------------------
#
# Myles Brand , the National Collegiate Athletic Association president , announced the formation of a Presidential Task Force on the Future of Intercollegiate Athletics .
# True Relations:  [['Myles Brand', '/business/person/company', 'National Collegiate Athletic Association']]
# Generated Relations:  [['Myles Brand', '/business/person/company', 'National Collegiate Athletic Association']]
#
# ----------------------
#
# The remains of the Halat-Fidar bridge in Lebanon , on Aug. 4 , hours after Israeli airstrikes destroyed it and several other bridges along the main highway north of Beirut .
# True Relations:  [['Lebanon', '/location/location/contains', 'Beirut'], ['Lebanon', '/location/country/capital', 'Beirut']]
# Generated Relations:  [['Lebanon', '/location/country/capital', 'Beirut'], ['Lebanon', '/location/location/contains', 'Beirut']]
#
# ----------------------
#
# Her projects included the Paris Theatre , New York ; the Caribe Hilton , San Juan , Puerto Rico ; Bonniers Retail Store , New York ; Earth Sciences Building , MIT , Cambridge , Mass. ; '' Resources for Man '' Pavilion , EXPO 67 , Montreal ; Campus Center , University of Massachusetts , Amherst .
# True Relations:  [['Puerto Rico', '/location/location/contains', 'San Juan'], ['Puerto Rico', '/location/country/capital', 'San Juan']]
# Generated Relations:  [['Puerto Rico', '/location/location/contains', 'San Juan'], ['Puerto Rico', '/location/country/capital', 'San Juan'], ['New York', '/location/location/contains', 'Paris'], ['New York', '/location/location/contains', 'Amherst'], ['Puerto Rico', '/location/country/capital', 'San Juan'], ['New York', '/location/location/contains', 'Amherst'], ['Puerto Rico', '/location/country/capital', 'San Juan']]
#
# ----------------------
#
# Douglas Stinemetz , a lawyer with the Texas firm of Haynes & Boone who often travels between Houston and Moscow , frequently recharges his energy reserves at Moscow 's bowling lanes from 11 p.m. to 4 a.m. '' Bowling does seem to combat jet lag , '' said Mr. Stinemetz . ''
# True Relations:  [['Texas', '/location/location/contains', 'Houston']]
# Generated Relations:  [['Texas', '/location/location/contains', 'Houston']]
#
# ----------------------
#
# Milton Shapiro , an 85-year-old former teacher who raised children in Teaneck , N.J. , moved to Manhattan when he retired in 1996 and lives by himself in an apartment house on the Upper West Side . ''
# True Relations:  [['Upper West Side', '/location/neighborhood/neighborhood_of', 'Manhattan'], ['Manhattan', '/location/location/contains', 'Upper West Side']]
# Generated Relations:  [['Upper West Side', '/location/neighborhood/neighborhood_of', 'Manhattan'], ['Manhattan', '/location/location/contains', 'Upper West Side']]
#
# ----------------------
#
# THE WAY WE LIVE NOW : 1-29-06 James Traub , a contributing writer , is completing a book on the United Nations in the era of Kofi Annan .
# True Relations:  [['Kofi Annan', '/business/person/company', 'United Nations']]
# Generated Relations:  [['Kofi Annan', '/business/person/company', 'United Nations']]
#
# ----------------------
#
# This has been obscured in the state 's overall financial sector by the tripling of securities and brokerage employment in New Jersey , as Wall Street shifted across the Hudson River .
# True Relations:  [['New Jersey', '/location/location/contains', 'Hudson River']]
# Generated Relations:  [['New Jersey', '/location/location/contains', 'Hudson River']]
#
# ----------------------
#
# And the establishment of major new pharmaceutical research facilities in San Diego , California and Cambridge , Mass. -- not in New Jersey -- has recently raised concern .
# True Relations:  [['California', '/location/location/contains', 'San Diego']]
# Generated Relations:  [['California', '/location/location/contains', 'San Diego']]
#
# ----------------------
#
# The vote , 324 to 85 , blocked an effort by Representative Ray LaHood , Republican of Illinois , to veto a report on the matter sent to Congress by President Bush last month .
# True Relations:  [['Illinois', '/location/location/contains', 'Bush']]
# Generated Relations:  [['Ray LaHood', '/people/person/place_lived', 'Illinois']]
#
# ----------------------
#
# NEFF -- Mary V. , formerly of Astoria , Queens on December 22 , 2006 .
# True Relations:  [['Queens', '/location/location/contains', 'Astoria'], ['Astoria', '/location/neighborhood/neighborhood_of', 'Queens']]
# Generated Relations:  [['Queens', '/location/location/contains', 'Astoria'], ['Astoria', '/location/neighborhood/neighborhood_of', 'Queens']]
#
# ----------------------
#
# A6 India Rethinks Attack Evidence Three weeks after the police in India accused Pakistan 's intelligence agency of colluding in serial bombings on the commuter train line in Mumbai , M. K. Narayanan , the Indian national security adviser , said in an interview broadcast on television that the evidence was short of '' clinching . ''
# True Relations:  [['India', '/location/location/contains', 'Mumbai'], ['India', '/location/location/contains', 'Mumbai']]
# Generated Relations:  [['India', '/location/location/contains', 'Mumbai'], ['India', '/location/country/administrative_divisions', 'Mumbai'], ['Mumbai', '/location/administrative_division/country', 'India']]
#
# ----------------------
#
# INTERNATIONAL A3-11 Sudan Fighting Threatens Wider African Conflict A visit to the site of the newest fighting in Sudan revealed a hardening conflict that is increasingly taking place along porous borders among some of the least stable countries in Africa , threatening to ignite a wide conflagration in the heart of the continent .
# True Relations:  [['Africa', '/location/location/contains', 'Sudan'], ['Africa', '/location/location/contains', 'Sudan']]
# Generated Relations:  [['Africa', '/location/location/contains', 'Sudan']]
#
# ----------------------
#
# In an interview , a doctor in Medellin , Colombia , said that while he offered safe , if secret , abortions , many abortionists did not . ''
# True Relations:  [['Colombia', '/location/location/contains', 'Medellín']]
# Generated Relations:  [['Colombia', '/location/location/contains', 'Medelln'], ['Colombia', '/location/country/capital', 'Medelln']]
#
# ----------------------
#
# While Mr. Bush was going to bat for Mr. Burns , Democrats were mounting a new effort against Senator Jon Kyl in Arizona , in a race the party had almost given up on .
# True Relations:  [['Jon Kyl', '/people/person/place_lived', 'Arizona']]
# Generated Relations:  [['Jon Kyl', '/people/person/place_lived', 'Arizona']]
#
# ----------------------
#
# The chief executive of Southwest Airlines , Gary C. Kelly , was not optimistic that major changes would occur at Delta or Northwest . ''
# True Relations:  [['Gary C. Kelly', '/business/person/company', 'Southwest Airlines']]
# Generated Relations:  [['Gary C. Kelly', '/business/person/company', 'Southwest Airlines']]
#
# ----------------------
#
# At one Brooklyn school , St. Finbar in Bath Beach , parents spent the day cold-calling potential corporate sponsors . ''
# True Relations:  [['Bath Beach', '/location/neighborhood/neighborhood_of', 'Brooklyn'], ['Brooklyn', '/location/location/contains', 'Bath Beach']]
# Generated Relations:  [['Bath Beach', '/location/neighborhood/neighborhood_of', 'Brooklyn'], ['Brooklyn', '/location/location/contains', 'Bath Beach']]
#
# ----------------------
#
# In the late 1980 's and early 90 's , breakout stars like Linda Evangelista , Yasmeen Ghauri and Shalom Harlow helped put Canada on the fashion map .
# True Relations:  [['Linda Evangelista', '/people/person/nationality', 'Canada'], ['Shalom Harlow', '/people/person/nationality', 'Canada'], ['Yasmeen Ghauri', '/people/person/nationality', 'Canada']]
# Generated Relations:  [['Shalom Harlow', '/people/person/nationality', 'Canada']]
#
# ----------------------
#
# Or as Heather Marks , the 17-year-old Vogue favorite from Calgary , puts it : '' It could be that Canada is just having a moment like Brazil and Russia did .
# True Relations:  [['Heather Marks', '/people/person/place_of_birth', 'Calgary'], ['Canada', '/location/location/contains', 'Calgary'], ['Heather Marks', '/people/person/nationality', 'Canada']]
# Generated Relations:  [['Canada', '/location/location/contains', 'Calgary']]
#
# ----------------------
#
# In Brussels , European Union leaders had approved a new budget through 2013 on Saturday morning .
# True Relations:  [['European Union', '/location/location/contains', 'Brussels']]
# Generated Relations:  [['European Union', '/location/location/contains', 'Brussels']]
#
# ----------------------
#
# A convicted child molester jailed in California may have sexually assaulted hundreds of young boys in the United States , Brazil and Mexico , the police said Thursday , based on a search of the man 's San Jose home that the police said uncovered a cache of child pornography and detailed journals describing , sometimes in code , the sexual acts performed on children .
# True Relations:  [['California', '/location/location/contains', 'San Jose']]
# Generated Relations:  [['California', '/location/location/contains', 'San Jose']]
#
# ----------------------
#
# Shiites ' Role Deepens ; Envoy Is Threatened Basra , in southern Iraq , far from the insurgency , is being transformed into a Shiite mini-theocracy , forming a flash point because the political parties in Basra also wield significant influence in Baghdad .
# True Relations:  [['Iraq', '/location/country/capital', 'Baghdad'], ['Iraq', '/location/location/contains', 'Basra'], ['Iraq', '/location/location/contains', 'Basra'], ['Iraq', '/location/location/contains', 'Baghdad']]
# Generated Relations:  [['Iraq', '/location/location/contains', 'Basra'], ['Iraq', '/location/country/capital', 'Baghdad'], ['Iraq', '/location/location/contains', 'Baghdad']]
#
# ----------------------
#
# The complaint , filed in State Supreme Court in Manhattan by the New York attorney general and the New York insurance superintendent , details various transactions initiated or overseen by the former chief executive , Maurice R. Greenberg , that were intended to make the underwriting business look stronger than it was .
# True Relations:  [['Maurice R. Greenberg', '/people/person/place_of_birth', 'New York'], ['Maurice R. Greenberg', '/people/person/place_of_birth', 'New York'], ['New York', '/location/location/contains', 'Manhattan'], ['New York', '/location/location/contains', 'Manhattan']]
# Generated Relations:  [['New York', '/location/location/contains', 'Manhattan'], ['New York', '/location/location/contains', 'Manhattan']]
#
# ----------------------
#
# In 1996 , the prime minister of Australia , John Howard , appointed Mr. Bell to lead a task force on small business deregulation .
# True Relations:  [['John Howard', '/people/person/nationality', 'Australia']]
# Generated Relations:  [['John Howard', '/people/person/nationality', 'Australia']]
#
# ----------------------
#
# An executive at the association confirmed in a meeting and conference call among industry officials on Thursday that its clearinghouse had a partnership agreement with Daon , a biometrics company in Dublin , Ireland , according to a transcript of the meeting . ''
# True Relations:  [['Ireland', '/location/country/capital', 'Dublin']]
# Generated Relations:  [['Ireland', '/location/country/capital', 'Dublin']]
#
# ----------------------
#
# Senator Sam Brownback , Republican of Kansas , said he thought the willingness of Senate Democrats to move forward reflected a new attitude within the party . ''
# True Relations:  [['Sam Brownback', '/people/person/place_lived', 'Kansas']]
# Generated Relations:  [['Sam Brownback', '/people/person/place_lived', 'Kansas']]
#
# ----------------------
#
# On Monday , five ethnic Tamil students were killed in Trincomalee in eastern Sri Lanka .
# True Relations:  [['Sri Lanka', '/location/location/contains', 'Trincomalee']]
# Generated Relations:  [['Sri Lanka', '/location/location/contains', 'Trincomalee']]
#
# ----------------------
#
# They collected the names for a letter to the Australian foreign minister , Alexander Downer , demanding that he take action to have Mr. Hicks , 30 , brought back to Australia to stand trial .
# True Relations:  [['Alexander Downer', '/people/person/nationality', 'Australia']]
# Generated Relations:  [['Alexander Downer', '/people/person/nationality', 'Australia']]
#
# ----------------------
#
# There was n't much love lost between Athens and Sparta , the two most important city-states of ancient Greece .
# True Relations:  [['Greece', '/location/country/capital', 'Athens'], ['Greece', '/location/location/contains', 'Sparta'], ['Greece', '/location/location/contains', 'Athens']]
# Generated Relations:  [['Greece', '/location/location/contains', 'Sparta'], ['Greece', '/location/country/capital', 'Athens'], ['Greece', '/location/location/contains', 'Athens']]
#
# ----------------------
#
# Roche , based in Basel , Switzerland , releases earnings figures only twice a year .
# True Relations:  [['Switzerland', '/location/location/contains', 'Basel']]
# Generated Relations:  [['Switzerland', '/location/location/contains', 'Basel']]
#
# ----------------------
#
# I think federalism is a very civilized way of governing , but in Iraq it could lead to separation , '' said Ahmed Sulaiman , 53 , who owns a market in the heavily Sunni Adhamiya neighborhood of Baghdad .
# True Relations:  [['Iraq', '/location/location/contains', 'Baghdad'], ['Iraq', '/location/country/capital', 'Baghdad']]
# Generated Relations:  [['Iraq', '/location/country/capital', 'Baghdad'], ['Iraq', '/location/location/contains', 'Baghdad']]
#
# ----------------------
#
# Me ` Lisa Barber , the fastest American this year , led until Veronica Campbell of Jamaica , the Olympic 200-meter champion , caught her at the tape .
# True Relations:  [['Veronica Campbell', '/people/person/nationality', 'Jamaica']]
# Generated Relations:  [['Veronica Campbell', '/people/person/nationality', 'Jamaica']]
#
# ----------------------
#
# Mr. Basayev has claimed responsibility for the worst terrorist acts in modern Russia , including the downing of two aircraft with bombs and the seizure of a public school in Beslan , both in 2004 .
# True Relations:  [['Russia', '/location/location/contains', 'Beslan']]
# Generated Relations:  [['Russia', '/location/location/contains', 'Beslan']]
#
# ----------------------
#
# which was published in 1968 and examined Israel 's existence in a hostile Middle East .
# True Relations:  [['Middle East', '/location/location/contains', 'Israel']]
# Generated Relations:  [['Middle East', '/location/location/contains', 'Israel']]
#
# ----------------------
#
# The moves by Citigroup and Deutsche Bank are only the latest illustrations of the difficulty of retaining jobs in New York City and rebuilding the business district in Lower Manhattan .
# True Relations:  [['Lower Manhattan', '/location/neighborhood/neighborhood_of', 'New York City'], ['Citigroup', '/business/company/place_founded', 'New York City'], ['New York City', '/location/location/contains', 'Lower Manhattan']]
# Generated Relations:  [['Lower Manhattan', '/location/neighborhood/neighborhood_of', 'New York City'], ['New York City', '/location/location/contains', 'Lower Manhattan']]
#
# ----------------------
#
# On Wednesday , the city councilor , Luis Quintana , sent a letter to Christopher Christie , United States attorney for New Jersey , demanding an inquiry ; yesterday , State Senator Anthony Bucco , a Republican from Morris County , also asked Mr. Christie for an investigation into potential '' financial malfeasance . ''
# True Relations:  [['New Jersey', '/location/location/contains', 'Morris County']]
# Generated Relations:  [['New Jersey', '/location/location/contains', 'Morris County']]
#
# ----------------------
#
# You ca n't go to Italy and tell them how to make leather goods in a new way or how to run their fashion industry , '' said Richard Sachs , who builds bicycles by hand at his shop in Chester , Conn. '' Yet with bikes , the Italians and everyone else in Europe caved in to the American designs . ''
# True Relations:  [['Europe', '/location/location/contains', 'Italy']]
# Generated Relations:  [['Europe', '/location/location/contains', 'Italy']]
#
# ----------------------
#
# The whole debate about disengagement from Gaza exposed the real political trends in Israel today , precisely because having 8,000 Jews living in one-third of the Gaza Strip , surrounded by over 1.3 million Palestinians , had become utterly insane -- disconnected from any strategic , moral , demographic , nationalist or religious logic .
# True Relations:  [['Gaza Strip', '/location/country/capital', 'Gaza']]
# Generated Relations:  [['Gaza Strip', '/location/country/capital', 'Gaza']]
#
# ----------------------
#
# Although China has joined the United States in partnership to press for a resumption of six-party talks to end North Korea 's nuclear weapons program after its recent test , Taiwan remains a potential flash point between Beijing and Washington .
# True Relations:  [['China', '/location/location/contains', 'Beijing'], ['China', '/location/country/capital', 'Beijing'], ['China', '/location/country/administrative_divisions', 'Beijing'], ['China', '/location/country/administrative_divisions', 'Taiwan'], ['Taiwan', '/location/administrative_division/country', 'China'], ['Beijing', '/location/administrative_division/country', 'China']]
# Generated Relations:  [['China', '/location/country/administrative_divisions', 'Taiwan'], ['China', '/location/country/capital', 'Beijing'], ['Taiwan', '/location/administrative_division/country', 'China'], ['China', '/location/country/administrative_divisions', 'Beijing'], ['Beijing', '/location/administrative_division/country', 'China'], ['China', '/location/location/contains', 'Beijing'], ['Taiwan', '/location/administrative_division/country', 'China'], ['China', '/location/country/administrative_divisions', 'Beijing']]
#
# ----------------------
#
# The United States and Europe are pressuring Russia to allow private companies a larger role in Russia 's industry .
# True Relations:  [['Europe', '/location/location/contains', 'Russia'], ['Europe', '/location/location/contains', 'Russia']]
# Generated Relations:  [['Europe', '/location/location/contains', 'Russia'], ['Europe', '/location/location/contains', 'Russia']]
#
# ----------------------
#
# This time , the president chose Father Leon to replace one of those clergymen , the Rev. Franklin Graham , who was filling in for his father , the Rev. Billy Graham , who was ill in 2001 .
# True Relations:  [['Billy Graham', '/people/person/children', 'Franklin Graham']]
# Generated Relations:  [['Billy Graham', '/people/person/children', 'Franklin Graham']]
#
# ----------------------
#
# It is always amazing to see , as this exhibition once more demonstrates , the extent to which Dali absorbed Surrealism 's tenets while still in Spain , reading Freud word for word , devouring special magazines and catalogs from Paris and also studying firsthand the work of the original Surrealist , Hieronymus Bosch , which he saw at the Prado while studying art in Madrid .
# True Relations:  [['Spain', '/location/country/capital', 'Madrid'], ['Spain', '/location/location/contains', 'Madrid']]
# Generated Relations:  [['Spain', '/location/location/contains', 'Madrid'], ['Spain', '/location/country/capital', 'Madrid']]
#
# ----------------------
#
# Second Life , a 3D virtual environment with 40,000 members , was developed by Linden Lab , a San Francisco company , and started in 2003 .
# True Relations:  [['Linden Lab', '/business/company/place_founded', 'San Francisco']]
# Generated Relations:  [['Linden Lab', '/business/company/place_founded', 'San Francisco']]
#
# ----------------------
#
# Cindy Sheehan , whose antiwar protests have made her persona non grata among most Republicans , startled Senator George Allen of Virginia in the makeup room of MSNBC over the summer .
# True Relations:  [['George Allen', '/people/person/place_lived', 'Virginia']]
# Generated Relations:  [['George Allen', '/people/person/place_lived', 'Virginia']]
#
# ----------------------
#
# Gerri and Alan Test from West Chester , Pa. , knew what they wanted even before they closed this month on a three-bedroom , two-and-a-half-bath condo near Rehoboth Beach in Delaware for $ 264,000 .
# True Relations:  [['Delaware', '/location/location/contains', 'Rehoboth Beach']]
# Generated Relations:  [['Delaware', '/location/location/contains', 'Rehoboth Beach']]
#
# ----------------------
#
# Passionately devoted to her family , Janice is survived by her nephew , Nicholas Puner , of Sleepy Hollow , NY , her nieces Lois Valladares of Bethesda , MD , Maggie Duke of Kingston , Ontario , Polly Puner of Brookline , MA .
# True Relations:  [['Ontario', '/location/location/contains', 'Kingston']]
# Generated Relations:  [['Ontario', '/location/location/contains', 'Kingston']]
#
# ----------------------
#
# Long a forlorn hope , the sequencing , or decoding , of Neanderthal DNA suddenly seems possible because of a combination of analytic work on ancient DNA by Svante Paabo , of the Max Planck Institute for Evolutionary Anthropology in Leipzig , Germany , and a new method of DNA sequencing developed by a Connecticut company , 454 Life Sciences .
# True Relations:  [['Germany', '/location/location/contains', 'Leipzig']]
# Generated Relations:  [['Germany', '/location/location/contains', 'Leipzig']]
#
# ----------------------
#
# One might be had for $ 600,000 out in Manorville , but property taxes would be three to four times what the man paid in Pennsylvania , Mr. Caracciolo said , '' and the commute to Garden City would have been miserable . ''
# True Relations:  [['Pennsylvania', '/location/location/contains', 'Manorville']]
# Generated Relations:  [['Pennsylvania', '/location/location/contains', 'Manorville'], ['Pennsylvania', '/location/location/contains', 'Garden City']]
#
# ----------------------
#
# At about the same time , another director , Julian Schnabel , began shooting an adaptation of Jean-Dominique Bauby 's book '' The Diving Bell and the Butterfly '' for Universal Pictures in Lourdes , France .
# True Relations:  [['Jean-Dominique Bauby', '/people/person/nationality', 'France']]
# Generated Relations:  [['France', '/location/location/contains', 'Lourdes']]
#
# ----------------------
#
# The agency has long been concerned about the Arak reactor , which is being built in the desert southwest of Tehran , and has repeatedly asked Iran to abandon the project .
# True Relations:  [['Iran', '/location/location/contains', 'Tehran'], ['Iran', '/location/country/capital', 'Tehran'], ['Iran', '/location/location/contains', 'Arak']]
# Generated Relations:  [['Iran', '/location/location/contains', 'Arak'], ['Iran', '/location/country/capital', 'Tehran'], ['Iran', '/location/location/contains', 'Tehran']]
#
# ----------------------
#
# But Iran 's president , Mahmoud Ahmadinejad , inaugurated the plant in August , saying , '' the Iranian people are determined to take big steps . ''
# True Relations:  [['Mahmoud Ahmadinejad', '/people/person/nationality', 'Iran']]
# Generated Relations:  [['Mahmoud Ahmadinejad', '/people/person/nationality', 'Iran']]
#
# ----------------------
#
# The Americans will clinch a World Cup spot with a victory over Mexico on Sept. 3 in Columbus , Ohio , coupled with anything less than a victory by Costa Rica or Guatemala in their next qualifiers .
# True Relations:  [['Ohio', '/location/location/contains', 'Columbus']]
# Generated Relations:  [['Ohio', '/location/location/contains', 'Columbus']]
#
# ----------------------
#
# The women 's bowling team from Sacred Heart University in Fairfield aims to prove it is the best in the nation at this week 's N.C.A.A. National Collegiate Bowling Championship in Orlando , Fla. .
# True Relations:  [['Fairfield', '/location/location/contains', 'Sacred Heart University']]
# Generated Relations:  [['Fairfield', '/location/location/contains', 'Sacred Heart University']]
#
# ----------------------
#
# Democrats pointed to evidence of what the party 's $ 35 million in spending on turnout programs , nearly matching Republicans , has given them in tight races like the Senate campaign here in Missouri , where Senator Jim Talent , a Republican , won office in 2002 by just 21,000 votes .
# True Relations:  [['Jim Talent', '/people/person/place_lived', 'Missouri']]
# Generated Relations:  [['Jim Talent', '/people/person/place_lived', 'Missouri']]
#
# ----------------------
#
# Our mussels are the best and the fattest because the water is warmer than in Brittany and Normandy , '' France 's other major mussel-growing regions , said Hugo Bordin , a 25-year-old chef at Au Bord ` un Zinc in the Ile de Re town of St. - Martin . ''
# True Relations:  [['France', '/location/location/contains', 'Normandy']]
# Generated Relations:  [['France', '/location/location/contains', 'Normandy'], ['France', '/location/country/administrative_divisions', 'Normandy'], ['Normandy', '/location/administrative_division/country', 'France'], ['France', '/location/country/administrative_divisions', 'Brittany']]
#
# ----------------------
#
# One of the most brutal tyrants of recent history , Saddam Hussein unleashed devastating regional wars and reduced oil-rich Iraq to a claustrophobic police state .
# True Relations:  [['Saddam Hussein', '/people/person/place_of_birth', 'Iraq'], ['Saddam Hussein', '/people/person/nationality', 'Iraq'], ['Saddam Hussein', '/people/deceased_person/place_of_death', 'Iraq']]
# Generated Relations:  [['Saddam Hussein', '/people/person/nationality', 'Iraq'], ['Saddam Hussein', '/people/deceased_person/place_of_death', 'Iraq'], ['Saddam Hussein', '/people/person/place_of_birth', 'Iraq']]
#
# ----------------------
#
# Seven years old when the Germans invaded France in 1940 , Isaac Sztrymfman was the only child of Polish-Jewish emigres who made a home in a Jewish neighborhood in Paris .
# True Relations:  [['France', '/location/country/capital', 'Paris'], ['France', '/location/country/administrative_divisions', 'Paris'], ['France', '/location/location/contains', 'Paris'], ['Paris', '/location/administrative_division/country', 'France']]
# Generated Relations:  [['France', '/location/country/capital', 'Paris'], ['France', '/location/location/contains', 'Paris'], ['Paris', '/location/administrative_division/country', 'France'], ['France', '/location/country/administrative_divisions', 'Paris']]
#
# ----------------------
#
# Mr. Pataki 's hospitalization has forced him to cancel several political trips , including one to New Hampshire last Friday , and one to San Jose this Saturday , where he had planned to make a speech at the California Republican Party 's winter convention .
# True Relations:  [['California', '/location/location/contains', 'San Jose']]
# Generated Relations:  [['California', '/location/location/contains', 'San Jose']]
#
# ----------------------
#
# In the end , the balance of power may well lie with a very few moderate Republicans : Ms. Collins , Arlen Specter of Pennsylvania and Chuck Hagel of Nebraska .
# True Relations:  [['Chuck Hagel', '/people/person/place_lived', 'Nebraska']]
# Generated Relations:  [['Chuck Hagel', '/people/person/place_lived', 'Nebraska']]
#
# ----------------------
#
# At a United counter designated for passengers with paper tickets , Marti Watterman and her husband , Dr. Nelson Bunin , were on their way to Recife , Brazil , through Chicago .
# True Relations:  [['Brazil', '/location/location/contains', 'Recife']]
# Generated Relations:  [['Brazil', '/location/location/contains', 'Recife']]
#
# ----------------------
#
# \*\* 1\/2 -LRB- Rating : Two and a Half Stars -RRB- Shrewsbury , England Complex and intriguing , with flowery and sweet aromas .
# True Relations:  [['England', '/location/location/contains', 'Shrewsbury']]
# Generated Relations:  [['England', '/location/location/contains', 'Shrewsbury']]
#
# ----------------------
#
# It also removes restrictions in earlier drafts on the construction , supplying and operation of an $ 800 million light-water reactor that Russia is building at Bushehr in southern Iran .
# True Relations:  [['Iran', '/location/location/contains', 'Bushehr']]
# Generated Relations:  [['Iran', '/location/location/contains', 'Bushehr']]
#
# ----------------------
#
# He contemplated buying a brownstone in Bedford Stuyvesant , but decided he wanted more amenities and set his sights on new construction condos in Dumbo , Williamsburg , Brooklyn Heights and downtown Brooklyn .
# True Relations:  [['Brooklyn Heights', '/location/neighborhood/neighborhood_of', 'Brooklyn'], ['Brooklyn', '/location/location/contains', 'Brooklyn Heights']]
# Generated Relations:  [['Brooklyn', '/location/location/contains', 'Brooklyn Heights'], ['Brooklyn', '/location/location/contains', 'Brooklyn Heights'], ['Brooklyn Heights', '/location/neighborhood/neighborhood_of', 'Brooklyn']]
#
# ----------------------
#
# In response to bipartisan political uproar , Dubai Ports World , which is controlled by the emir of Dubai , part of the United Arab Emirates , asked the Bush administration on Sunday to conduct the full 45-day review that an interagency panel deemed unnecessary last month .
# True Relations:  [['United Arab Emirates', '/location/location/contains', 'Dubai'], ['Dubai', '/location/administrative_division/country', 'United Arab Emirates'], ['United Arab Emirates', '/location/country/administrative_divisions', 'Dubai']]
# Generated Relations:  [['United Arab Emirates', '/location/location/contains', 'Dubai'], ['Dubai', '/location/administrative_division/country', 'United Arab Emirates'], ['United Arab Emirates', '/location/country/administrative_divisions', 'Dubai']]
#
# ----------------------
#
# The Chinese ambassador to Australia , Fu Ying , last year went to the state of South Australia and visited the Olympic Dam uranium mine , which is owned by BHP Billiton , the world 's largest mining company .
# True Relations:  [['Australia', '/location/country/administrative_divisions', 'South Australia'], ['Australia', '/location/location/contains', 'South Australia'], ['South Australia', '/location/administrative_division/country', 'Australia']]
# Generated Relations:  [['Australia', '/location/location/contains', 'South Australia']]
#
# ----------------------
#
# The United States is expected to get two spots in February 's Olympics in Turin , Italy .
# True Relations:  [['Italy', '/location/location/contains', 'Turin']]
# Generated Relations:  [['Italy', '/location/location/contains', 'Turin']]
#
# ----------------------
#
# Charlie LeDuff 's WORK AND OTHER SINS : Life in New York City and Thereabouts -LRB- Penguin , $ 15 -RRB- is a blunt and touching assortment of articles , written for The Times , that portray a city of faltering dreams , sadness and wit , often expressed in the crowded bars of Brooklyn and Manhattan .
# True Relations:  [['New York City', '/location/location/contains', 'Manhattan'], ['New York City', '/location/location/contains', 'Brooklyn']]
# Generated Relations:  [['New York City', '/location/location/contains', 'Manhattan']]
#
# ----------------------
#
# At St. Stanislaus Kostka Church in Greenpoint , Brooklyn , where Karol Wojtyla visited before he became Pope John Paul II , people lined the church 's steps to hear the 10 a.m. Mass in Polish .
# True Relations:  [['Brooklyn', '/location/location/contains', 'Greenpoint'], ['Greenpoint', '/location/neighborhood/neighborhood_of', 'Brooklyn']]
# Generated Relations:  [['Brooklyn', '/location/location/contains', 'Greenpoint'], ['Greenpoint', '/location/neighborhood/neighborhood_of', 'Brooklyn']]
#
# ----------------------
#
# He is a son of Jean and John C. Friedmann of Princeton , N.J. His mother edits book reviews for Wellesley magazine , the alumnae publication for Wellesley College in Massachusetts .
# True Relations:  [['Massachusetts', '/location/location/contains', 'Wellesley'], ['Wellesley', '/location/location/contains', 'Wellesley College']]
# Generated Relations:  [['Massachusetts', '/location/location/contains', 'Wellesley College']]
#
# ----------------------
#
# LUXURY HOTEL EXPANSION CONTINUES -- The Ritz-Carlton Hotel Company has planted another flag in Indonesia , as major North American luxury hotels keep expanding throughout Asia .
# True Relations:  [['Asia', '/location/location/contains', 'Indonesia']]
# Generated Relations:  [['Asia', '/location/location/contains', 'Indonesia']]
#
# ----------------------
#
# Ebersol said Jack Welch , who was the chairman of General Electric , the parent company of NBC , was so enamored of Madden that he planned to give him a locomotive and parlor car for travel the country during the season .
# True Relations:  [['Jack Welch', '/business/person/company', 'General Electric']]
# Generated Relations:  [['Jack Welch', '/business/person/company', 'General Electric']]
#
# ----------------------
#
# A8 A Focus Shift in Afghanistan President Hamid Karzai of Afghanistan made a plea to international donors at an aid conference in Kabul to shift their focus to helping the country 's struggling private sector .
# True Relations:  [['Afghanistan', '/location/country/capital', 'Kabul'], ['Hamid Karzai', '/people/person/nationality', 'Afghanistan'], ['Afghanistan', '/location/location/contains', 'Kabul'], ['Afghanistan', '/location/country/capital', 'Kabul'], ['Hamid Karzai', '/people/person/nationality', 'Afghanistan'], ['Afghanistan', '/location/location/contains', 'Kabul']]
# Generated Relations:  [['Hamid Karzai', '/people/person/nationality', 'Afghanistan'], ['Afghanistan', '/location/country/capital', 'Kabul'], ['Afghanistan', '/location/location/contains', 'Kabul'], ['Afghanistan', '/location/country/capital', 'Kabul'], ['Hamid Karzai', '/people/person/nationality', 'Afghanistan'], ['Afghanistan', '/location/location/contains', 'Kabul']]
#
# ----------------------
#
# It 's just one piece of the puzzle , '' said William Easterly , a former bank economist who is now an economist at New York University .
# True Relations:  [['William Easterly', '/business/person/company', 'New York University']]
# Generated Relations:  [['William Easterly', '/business/person/company', 'New York University']]
#
# ----------------------
#
# But while other big cities like Chicago , Washington , Seattle and Atlanta have elected female mayors -- women are mayors in 13 of the 100 largest United States cities -- history has not been kind to female mayoral candidates in New York .
# ...
#
# Brooklyn Academy of Music , 30 Lafayette Avenue , at Ashland Place , Fort Greene , Brooklyn , (718)636-4100 ; $ 10 .
# True Relations:  [['Brooklyn', '/location/location/contains', 'Fort Greene'], ['Fort Greene', '/location/neighborhood/neighborhood_of', 'Brooklyn']]
# Generated Relations:  [['Brooklyn', '/location/location/contains', 'Fort Greene'], ['Fort Greene', '/location/neighborhood/neighborhood_of', 'Brooklyn']]
#
# ----------------------
#
# Scholarships From a Critic When Harold C. Schonberg , below , the former chief music critic of The New York Times , died , in 2003 , he established in his will a $ 5 million trust to support piano students at four major music schools : Juilliard , Mannes College of Music and the Manhattan School of Music in New York , and the Curtis Institute of Music in Philadelphia .
# True Relations:  [['Philadelphia', '/location/location/contains', 'Curtis Institute of Music']]
# Generated Relations:  [['New York', '/location/location/contains', 'Manhattan School of Music']]
#
# ----------------------
#
# SPORTSFRIDAY World Bank Chief to Mideast James Wolfensohn , who is retiring as head of the World Bank , has been named by the Bush administration as special coordinator to the Middle East to assist Israel in its planned withdrawal from the Gaza Strip and parts of the West Bank .
# True Relations:  [['James Wolfensohn', '/business/person/company', 'World Bank'], ['Middle East', '/location/location/contains', 'Gaza Strip'], ['Israel', '/location/location/contains', 'West Bank'], ['Middle East', '/location/location/contains', 'Israel']]
# Generated Relations:  [['Israel', '/location/location/contains', 'West Bank'], ['Middle East', '/location/location/contains', 'Gaza Strip'], ['Israel', '/location/location/contains', 'West Bank']]
#
# ----------------------
#
# Center Yao Ming of the Houston Rockets popularized the National Basketball Association in China in 2002 .
# True Relations:  [['Yao Ming', '/people/person/nationality', 'China']]
# Generated Relations:  [['Yao Ming', '/people/person/nationality', 'China']]
#
# ----------------------
#
# This year 's scheduled trips include '' Lord Mayors and Traders : The Jews of Ireland , '' May 1-11 , which visits sites that hold Jewish significance , including synagogues in Dublin and Belfast , a burial ground in Limerick and the Irish Jewish Museum in Dublin .
# True Relations:  [['Ireland', '/location/country/capital', 'Dublin'], ['Ireland', '/location/country/capital', 'Dublin']]
# Generated Relations:  [['Ireland', '/location/country/capital', 'Dublin'], ['Ireland', '/location/location/contains', 'Limerick'], ['Ireland', '/location/country/capital', 'Dublin']]
#
# ----------------------
#
# To engage a broad audience , Mr. Keeve focused on the most dramatic stories : Doo-ri Chung , a Korean immigrant who opened her studio in the basement of her parents ' dry-cleaning shop in New Jersey ; Alexandre Plokhov , the designer at Cloak , who wrestled with a manufacturer to produce his collection on time ; and the precocious team of Jack McCollough and Lazaro Hernandez of Proenza Schouler , who became fashion stars while they were seniors at Parsons School of Design .
# True Relations:  [['Proenza Schouler', '/business/company/founders', 'Jack McCollough'], ['Proenza Schouler', '/business/company/founders', 'Lazaro Hernandez'], ['Jack McCollough', '/business/person/company', 'Proenza Schouler'], ['Lazaro Hernandez', '/business/person/company', 'Proenza Schouler']]
# Generated Relations:  [['Proenza Schouler', '/business/company/founders', 'Jack McCollough'], ['Jack McCollough', '/business/person/company', 'Proenza Schouler']]
#
# ----------------------
#
# She is the daughter of Julie Eastlack Hopson and James W. Hopson of Granville , Ohio .
# True Relations:  [['Ohio', '/location/location/contains', 'Granville']]
# Generated Relations:  [['Ohio', '/location/location/contains', 'Granville']]
#
# ----------------------
#
# The winners were Leo Soanes of Corona , Queens , and Robert Stayman of New Rochelle , N.Y. They finished half a match point ahead of Katherine Kolbert and Andrew Rosenthal of New York .
# True Relations:  [['New York', '/location/location/contains', 'New Rochelle'], ['New York', '/location/location/contains', 'Queens']]
# Generated Relations:  [['New York', '/location/location/contains', 'New Rochelle'], ['New York', '/location/location/contains', 'Queens']]
#
# ----------------------
#
# The site , owned by China 's biggest Internet search engine , asserts that Taiwan 's original inhabitants '' came from mainland China directly or indirectly , '' and not from Malaysia .
# True Relations:  [['China', '/location/country/administrative_divisions', 'Taiwan'], ['Taiwan', '/location/administrative_division/country', 'China'], ['China', '/location/country/administrative_divisions', 'Taiwan'], ['Taiwan', '/location/administrative_division/country', 'China']]
# Generated Relations:  [['Taiwan', '/location/administrative_division/country', 'China'], ['China', '/location/country/administrative_divisions', 'Taiwan'], ['Taiwan', '/location/administrative_division/country', 'China']]
#
# ----------------------
#
# A1 Israel said that if the militant faction Hamas took part in next month 's elections for the Palestinian Parliament , Palestinians in East Jerusalem would not be allowed to cast ballots there .
# True Relations:  [['Israel', '/location/country/capital', 'East Jerusalem']]
# Generated Relations:  [['Israel', '/location/country/capital', 'East Jerusalem']]
#
# ----------------------
#
# C1 Bank Chief to Be Retried A German federal court ruled that the chief executive of Deutsche Bank , Josef Ackermann , should be tried again in a corporate criminal case , casting him back into legal limbo and stirring doubts that he will survive at the bank 's helm .
# True Relations:  [['Josef Ackermann', '/business/person/company', 'Deutsche Bank']]
# Generated Relations:  [['Josef Ackermann', '/business/person/company', 'Deutsche Bank']]
#
# ----------------------
#
# He is the son of Percy E. Sutton , a former Manhattan borough president and an elder statesman of Harlem politics .
# True Relations:  [['Manhattan', '/location/location/contains', 'Harlem'], ['Harlem', '/location/neighborhood/neighborhood_of', 'Manhattan']]
# Generated Relations:  [['Manhattan', '/location/location/contains', 'Harlem'], ['Harlem', '/location/neighborhood/neighborhood_of', 'Manhattan']]
#
# ----------------------
#
# Garry Wills , adjunct professor of history at Northwestern University , is the author , most recently , of '' St. Augustine 's Conversion . ''
# True Relations:  [['Garry Wills', '/business/person/company', 'Northwestern University']]
# Generated Relations:  [['Garry Wills', '/business/person/company', 'Northwestern University']]
#
# ----------------------
#
# But they seized on his boasts about Iran 's programs to press the question of whether the country has a separate set of nuclear facilities , apart from the giant enrichment center at Natanz , that it has not previously revealed .
# True Relations:  [['Iran', '/location/location/contains', 'Natanz']]
# Generated Relations:  [['Iran', '/location/location/contains', 'Natanz']]
#
# ----------------------
#
# Charles B. Darrow , an unemployed salesman , sketched the prototype board game on a tablecloth at his home in the Germantown neighborhood of Philadelphia , using 21 street names from Atlantic City .
# True Relations:  [['Philadelphia', '/location/location/contains', 'Germantown'], ['Germantown', '/location/neighborhood/neighborhood_of', 'Philadelphia']]
# Generated Relations:  [['Philadelphia', '/location/location/contains', 'Germantown'], ['Germantown', '/location/neighborhood/neighborhood_of', 'Philadelphia']]
#
# ----------------------
#
# That situation is the main reason Mr. Kerkorian , whose associates have criticized the pace of the revamping , urged G.M. last month to discuss a possible alliance with Renault of France and Nissan of Japan , both run by Carlos Ghosn .
# True Relations:  [['Carlos Ghosn', '/business/person/company', 'Renault'], ['Carlos Ghosn', '/people/person/nationality', 'France']]
# Generated Relations:  [['Carlos Ghosn', '/business/person/company', 'Renault']]
#
# ----------------------
#
# Days before our interview , the Syrian government announced that it had arrested one man and killed two others who had been planning an attack in Damascus on behalf of an organization called Soldiers of Al Sham , a reference to a '' greater Syria '' that would include Jordan , Lebanon and Palestine .
# True Relations:  [['Syria', '/location/country/capital', 'Damascus'], ['Syria', '/location/location/contains', 'Damascus'], ['Syria', '/location/country/administrative_divisions', 'Damascus'], ['Damascus', '/location/administrative_division/country', 'Syria']]
# Generated Relations:  [['Syria', '/location/country/administrative_divisions', 'Damascus'], ['Syria', '/location/country/capital', 'Damascus'], ['Damascus', '/location/administrative_division/country', 'Syria'], ['Syria', '/location/location/contains', 'Damascus']]
#
# ----------------------
#
# A picturesque town in the Kurram Valley , Parachinar was also Pakistan 's first line of defense against any Afghan incursion .
# True Relations:  [['Kurram Valley', '/location/location/contains', 'Parachinar'], ['Pakistan', '/location/location/contains', 'Parachinar']]
# Generated Relations:  [['Pakistan', '/location/location/contains', 'Parachinar']]
#
# ----------------------
#
# The Grand Duchy of Luxembourg consists of some 1,000 square miles bordered by Germany , Belgium and northeastern France -LRB- barely -RRB- .
# True Relations:  [['Belgium', '/location/country/administrative_divisions', 'Luxembourg'], ['Luxembourg', '/location/administrative_division/country', 'Belgium']]
# Generated Relations:  [['Belgium', '/location/country/administrative_divisions', 'Luxembourg'], ['Luxembourg', '/location/administrative_division/country', 'Belgium'], ['Belgium', '/location/country/administrative_divisions', 'Luxembourg']]
#
# ----------------------
#
# Authors ' Protest at Fair Writers including Nick Hornby , J. M. Coetzee , Mike Leigh , Nadine Gordimer , Will Self and Ian McEwan have called upon the organizer of the London Book Fair to end its association with international arms fairs , the BBC reported .
# True Relations:  [['Nick Hornby', '/people/person/place_lived', 'London'], ['BBC', '/business/company/place_founded', 'London']]
# Generated Relations:  [['BBC', '/business/company/place_founded', 'London']]
#
# ----------------------
#
# Pakistan 's prime minister , Shaukat Aziz , said his country would give the pipeline top priority .
# True Relations:  [['Shaukat Aziz', '/people/person/nationality', 'Pakistan']]
# Generated Relations:  [['Shaukat Aziz', '/people/person/nationality', 'Pakistan']]
#
# ----------------------
#
# If New Delhi ultimately takes up the American offer on fighter jets , it will be the first time India buys a major weapons platform from the United States .
# True Relations:  [['India', '/location/location/contains', 'New Delhi'], ['India', '/location/country/capital', 'New Delhi']]
# Generated Relations:  [['India', '/location/country/capital', 'New Delhi'], ['India', '/location/location/contains', 'New Delhi']]
#
# ----------------------
#
# He nearly succeeded in becoming Africa 's first bike manufacturer , but balked when his negotiating partner , the son of Kenya 's president , demanded a bribe , he said .
# True Relations:  [['Africa', '/location/location/contains', 'Kenya']]
# Generated Relations:  [['Africa', '/location/location/contains', 'Kenya']]
#
# ----------------------
#
# 9 P.M. -LRB- Sundance -RRB- ONE PUNK UNDER GOD Jay Bakker , the pierced and tattooed preacher son of Jim Bakker and Tammy Faye Messner , the founders of the Praise the Lord Club , goes on a soul-searching mission to define his feelings about homosexuality , while visiting his ill mother and reconnecting with his father -LRB- above -RRB- .
# True Relations:  [['Jim Bakker', '/people/person/children', 'Jay Bakker']]
# Generated Relations:  [['Jim Bakker', '/people/person/children', 'Jay Bakker']]
#
# ----------------------
#
# He is survived by his partner and companion of thirty years , Allen Patt of New York , Bay Head , and Santa Fe , and his sisters and brothers-in-law-Betty and Keith Gibson of Rosston , Arkansas , Joann and John Sterrett and Linda Ratliff of Santa Fe , New Mexico .
# True Relations:  [['New Mexico', '/location/location/contains', 'Santa Fe']]
# Generated Relations:  [['New Mexico', '/location/location/contains', 'Santa Fe'], ['Arkansas', '/location/location/contains', 'Rosston'], ['New Mexico', '/location/location/contains', 'Santa Fe']]
#
# ----------------------
#
# On Thursday , Mr. Lieberman , who is now running on the line of his own party , Connecticut for Lieberman , marked the anniversary of saving the Naval Submarine Base in Groton , Conn. , which the Pentagon considered closing last year .
# True Relations:  [['Connecticut', '/location/location/contains', 'Groton']]
# Generated Relations:  [['Connecticut', '/location/location/contains', 'Groton']]
#
# ----------------------
#
# Before leaving Cairo on Wednesday , Ms. Rice met for nearly two hours with Egypt 's intelligence chief , Omar Suleiman , who had traveled to Damascus , Syria , earlier this month to meet with the leaders of Hamas .
# True Relations:  [['Damascus', '/location/administrative_division/country', 'Syria'], ['Syria', '/location/location/contains', 'Damascus'], ['Egypt', '/location/country/capital', 'Cairo'], ['Egypt', '/location/location/contains', 'Cairo'], ['Syria', '/location/country/administrative_divisions', 'Damascus'], ['Syria', '/location/country/capital', 'Damascus']]
# Generated Relations:  [['Syria', '/location/country/administrative_divisions', 'Damascus'], ['Syria', '/location/country/capital', 'Damascus'], ['Damascus', '/location/administrative_division/country', 'Syria'], ['Syria', '/location/location/contains', 'Damascus'], ['Egypt', '/location/country/capital', 'Cairo'], ['Syria', '/location/location/contains', 'Damascus'], ['Egypt', '/location/country/capital', 'Cairo']]
#
# ----------------------
#
# After he joined Kraft Foods in Chicago , Mr. Reuter became a vice president and director for purchasing in 1970 .
# True Relations:  [['Kraft Foods', '/business/company/place_founded', 'Chicago']]
# Generated Relations:  [['Kraft Foods', '/business/company/place_founded', 'Chicago']]
#
# ----------------------
#
# Former owner of the Cleveland Indians , he was tenacious in business and passionate in civic service , and was a strong champion of Cleveland , the city that he loved .
# True Relations:  [['Cleveland', '/sports/sports_team_location/teams', 'Cleveland Indians'], ['Cleveland Indians', '/sports/sports_team/location', 'Cleveland']]
# Generated Relations:  [['Cleveland Indians', '/sports/sports_team/location', 'Cleveland'], ['Cleveland', '/sports/sports_team_location/teams', 'Cleveland Indians']]
#
# ----------------------
#
# It was Richard M. Daley , the current mayor , not his father , Richard J. Daley , who died in 1976 .
# True Relations:  [['Richard J. Daley', '/people/person/children', 'Richard M. Daley']]
# Generated Relations:  [['Richard J. Daley', '/people/person/children', 'Richard M. Daley']]
#
# ----------------------
#
# He is survived by a daughter , Laurie Melissa Keeran of Brewster , MA and her husband Donald Keeran ; a son , the Rev. Theodore A. Gill , Jr. of Geneva , Switzerland and his wife Ruth Ann Shriver Gill ; a granddaughter , Elizabeth Katherine Gill of Durham , NC and her husband Jacob Burt ; and longtime caregiver Ben Mensah of New York City .
# True Relations:  [['Switzerland', '/location/location/contains', 'Geneva']]
# Generated Relations:  [['Switzerland', '/location/location/contains', 'Geneva']]
#
# ----------------------
#
# True to its word , Baylor disconnected her ventilator on Dec. 12 , invoking a law signed in 1999 by George W. Bush , then governor of Texas .
# True Relations:  [['George W. Bush', '/business/person/company', 'Texas']]
# Generated Relations:  [['George W. Bush', '/business/person/company', 'Texas']]
#
# ----------------------

# %%
ix = 22

# %%
sample = prefix + text[ix] + "\nRelations: "
print (sample)
# Out:
# List all relations between entities of the types [LOCATION, PERSON, ORGANIZATION] in the following TEXT and provide reasonable explanation:
#
# Attempting to draw a distinction based on the medium used by the blogger or reporter is misguided , said Jack Balkin , a professor at Yale Law School -LRB- also a blogger -RRB- . ''
# Relations:

# %%
inputs = tokenizer(sample, return_tensors="pt").input_ids.to(device)

# %%
outputs = tuned_model.generate(inputs, max_new_tokens=256, do_sample=False)

# %%
out = tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
r = ast.literal_eval(out.split("Explanation:")[0])
print (type(r[0]))
# Out:
# <class 'list'>

# %%
print (text[ix])
print ("True relations: ", true_relations[ix])
# Out:
# Attempting to draw a distinction based on the medium used by the blogger or reporter is misguided , said Jack Balkin , a professor at Yale Law School -LRB- also a blogger -RRB- . ''
# True relations:  [['Jack Balkin', '/business/person/company', 'Yale Law School']]

# %%
torch.cuda.empty_cache()

# %%
r[0] in true_relations[ix]
# Out:
# True
