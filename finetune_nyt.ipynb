# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset
from transformers import DataCollatorForSeq2Seq
import torch
import evaluate
import re
import numpy as np
from tqdm import tqdm

# %%
torch.cuda.empty_cache()

model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-large", 
                                              cache_dir="/scratch/wadhwa.s/cache", 
                                              device_map="auto")
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-large", 
                                          cache_dir="/scratch/wadhwa.s/cache")

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

# %%
relation_map = {
    "/location/location/contains" : "LOC_CONTAINS",
    "/location/administrative_division/country" : "LOC_COUNTRY",
    "/location/country/capital" : "LOC_CAPITAL",
    "/location/neighborhood/neighborhood_of" : "LOC_NEIGHBORHOOD",
    "/location/country/administrative_divisions" : "LOC_ADMIN_DIVISIONS",

    "/people/person/nationality" : "PEO_NATIONALITY",
    "/people/person/place_lived" : "PEO_PLACE_LIVED",
    "/people/person/place_of_birth" : "PEO_PLACE_OF_BIRTH",
    "/people/deceased_person/place_of_death" : "PEO_PLACE_OF_DEATH",
    "/people/person/children" : "PEO_CHILDREN",
    "/people/person/religion" : "PEO_RELIGION",
    "/people/ethnicity/geographic_distribution" : "PEO_GEORGRAPHIC_DISTRIBUTION",
    "/people/person/ethnicity" : "PEO_ETHNICITY",
    "/people/ethnicity/people" : "PEO_PEOPLE",
    "/people/person/profession" : "PEO_PROFESSION",

    "/business/person/company" : "BUS_COMPANY",
    "/business/company/founders" : "BUS_FOUNDERS",
    "/business/company/place_founded" : "BUS_PLACE_FOUNDED",
    "/business/company_shareholder/major_shareholder_of" : "BUS_MAJOR_SHAREHOLDER",
    "/business/company/major_shareholders" : "BUS_MAJOR_SHAREHOLDERS",
    "/business/company/advisors" : "BUS_ADVISORS",
    "/business/company/industry" : "BUS_INDUSTRY",

    "/sports/sports_team_location/teams" : "SPO_TEAMS",
    "/sports/sports_team/location" : "SPO_LOCATION",
}

# %%
for key, value in relation_map.items():
    print ("<li><strong>",key,"</strong>: ", rel_map_inv[rel_map[value]],"</li>")
# Out:
# <li><strong> /location/location/contains </strong>:  [A, B] Entity A is a location that contains Entity B </li>
# <li><strong> /location/administrative_division/country </strong>:  [A, B] Entity B is a country that contains Entity A </li>
# <li><strong> /location/country/capital </strong>:  [A, B] Entity B is the capital of Entity A </li>
# <li><strong> /location/neighborhood/neighborhood_of </strong>:  [A, B] Entity B is a neighborhood that contains Entity A </li>
# <li><strong> /location/country/administrative_divisions </strong>:  [A, B] Entity B is located in the administrative divisions of Entity A </li>
# <li><strong> /people/person/nationality </strong>:  [A, B] Entity A is a national of Entity B </li>
# <li><strong> /people/person/place_lived </strong>:  [A, B] Entity A has lived in Entity B </li>
# <li><strong> /people/person/place_of_birth </strong>:  [A, B] Entity A was born in Entity B </li>
# <li><strong> /people/deceased_person/place_of_death </strong>:  [A, B] Entity A died in Entity B </li>
# <li><strong> /people/person/children </strong>:  [A, B] Entity B is the child of Entity A </li>
# <li><strong> /people/person/religion </strong>:  [A, B] Entity A is a member Entity B </li>
# <li><strong> /people/ethnicity/geographic_distribution </strong>:  [A, B] Entity A is a member of Entity B's geographic distribution </li>
# <li><strong> /people/person/ethnicity </strong>:  [A, B] Entity A is of ethnicity Entity B </li>
# <li><strong> /people/ethnicity/people </strong>:  [A, B] Entity B is the ethnicity of Entity A </li>
# <li><strong> /people/person/profession </strong>:  [A, B] Entity B is the profession of Entity A </li>
# <li><strong> /business/person/company </strong>:  [A, B] Entity A is a member of company Entity B </li>
# <li><strong> /business/company/founders </strong>:  [A, B] Entity A was founded by Entity B </li>
# <li><strong> /business/company/place_founded </strong>:  [A, B] Entity A was founded in Entity B </li>
# <li><strong> /business/company_shareholder/major_shareholder_of </strong>:  [A, B] Entity B is a major shareholder of Entity A </li>
# <li><strong> /business/company/major_shareholders </strong>:  [A, B] Entity B is a major shareholder of Entity A </li>
# <li><strong> /business/company/advisors </strong>:  [A, B] Entity B advises to Entity A </li>
# <li><strong> /business/company/industry </strong>:  [A, B] Entity A is in the industry Entity B </li>
# <li><strong> /sports/sports_team_location/teams </strong>:  [A, B] Entity B is a team located in Entity A </li>
# <li><strong> /sports/sports_team/location </strong>:  [A, B] Entity B is a location that contains sports team Entity A </li>

# %%
assign = 0
rel_map = {}
for r in list(relation_map.values()):
    rel_map[r] = assign
    assign += 1

print (rel_map)
# Out:
# {'LOC_CONTAINS': 0, 'LOC_COUNTRY': 1, 'LOC_CAPITAL': 2, 'LOC_NEIGHBORHOOD': 3, 'LOC_ADMIN_DIVISIONS': 4, 'PEO_NATIONALITY': 5, 'PEO_PLACE_LIVED': 6, 'PEO_PLACE_OF_BIRTH': 7, 'PEO_PLACE_OF_DEATH': 8, 'PEO_CHILDREN': 9, 'PEO_RELIGION': 10, 'PEO_GEORGRAPHIC_DISTRIBUTION': 11, 'PEO_ETHNICITY': 12, 'PEO_PEOPLE': 13, 'PEO_PROFESSION': 14, 'BUS_COMPANY': 15, 'BUS_FOUNDERS': 16, 'BUS_PLACE_FOUNDED': 17, 'BUS_MAJOR_SHAREHOLDER': 18, 'BUS_MAJOR_SHAREHOLDERS': 19, 'BUS_ADVISORS': 20, 'BUS_INDUSTRY': 21, 'SPO_TEAMS': 22, 'SPO_LOCATION': 23}

# %%
rel_map_inv = {
    0 : "[A, B] Entity A is a location that contains Entity B",
    1 : "[A, B] Entity B is a country that contains Entity A",
    2 : "[A, B] Entity B is the capital of Entity A",
    3 : "[A, B] Entity B is a neighborhood that contains Entity A",
    4 : "[A, B] Entity B is located in the administrative divisions of Entity A",
    
    5 : "[A, B] Entity A is a national of Entity B",
    6 : "[A, B] Entity A has lived in Entity B",
    7 : "[A, B] Entity A was born in Entity B",
    8 : "[A, B] Entity A died in Entity B",
    9 : "[A, B] Entity B is the child of Entity A",
    10 : "[A, B] Entity A is a member Entity B",
    11 : "[A, B] Entity A is a member of Entity B's geographic distribution",
    12 : "[A, B] Entity A is of ethnicity Entity B",
    13 : "[A, B] Entity B is the ethnicity of Entity A",
    14 : "[A, B] Entity B is the profession of Entity A",
    
    15 : "[A, B] Entity A is a member of company Entity B",
    16 : "[A, B] Entity A was founded by Entity B",
    17 : "[A, B] Entity A was founded in Entity B",
    18 : "[A, B] Entity B is a major shareholder of Entity A",
    19 : "[A, B] Entity B is a major shareholder of Entity A",
    20 : "[A, B] Entity B advises to Entity A",
    21 : "[A, B] Entity A is in the industry Entity B",
    
    22 : "[A, B] Entity B is a team located in Entity A",
    23 : "[A, B] Entity B is a location that contains sports team Entity A",

}

# %%
df = pd.read_csv("nyt_fewshot_explanations.csv")
for ix, row in df.iterrows():
    print(row["text"])
    print (row["gold_relations"] + "\n" + row["explanations"])
    print ("\n----------------\n")
# Out:
# Massachusetts ASTON MAGNA Great Barrington ; also at Bard College , Annandale-on-Hudson , N.Y. , July 1-Aug .
# [['Annandale-on-Hudson', 'LOC_CONTAINS', 'Bard College']]
# Explanations: Bard College is located in Annandale-on-Hudson, NY;
#
# ----------------
#
# It will be the final movie credited to Debra Hill , a film producer and native of Haddonfield , who produced '' Halloween '' and was considered a pioneering woman in film .
# [['Debra Hill', 'PEO_PLACE_OF_BIRTH', 'Haddonfield']]
# Explanations: Film producer Debra Hill was a native of (born-in) Haddonfield;
#
# ----------------
#
# Under pressure from Mr. Kerkorian and other disgruntled shareholders , Mr. Wagoner started talks on Friday in Detroit with Carlos Ghosn , the chief executive of Renault and Nissan .
# [['Carlos Ghosn', 'BUS_COMPANY', 'Renault']]
# Explanations: Carlos Ghosn is the chief executive officer of (member-of) Renault;
#
# ----------------
#
# Mr. Ferrer still holds commanding leads over the other two Democrats in the race -- United States Representative Anthony D. Weiner of Brooklyn and Queens , and City Council Speaker Gifford Miller -- and is also ahead of Mayor Michael R. Bloomberg in most polls .
# [['Anthony D. Weiner', 'PEO_PLACE_LIVED', 'Brooklyn'], ['Anthony D. Weiner', 'PEO_PLACE_LIVED', 'Queens']]
# Explanations: Anthony D. Weiner was a representative of Brooklyn; Anthony D. Weiner also represented Queens;
#
# ----------------
#
# Quebec , Canada 's second most populous province , after Ontario , has not decided to go that far .
# [['Ontario', 'LOC_COUNTRY', 'Canada'], ['Canada', 'LOC_CONTAINS', 'Ontario'], ['Canada', 'LOC_ADMIN_DIVISIONS', 'Ontario']]
# Explanations: City of Quebec is located in the country of Canada; Canada contains Ontario; Ontario is located in the administrative divisions of Canada;
#
# ----------------
#
# And Abu Izzadeen , who converted to Islam at 17 and heads another successor group to Al Muhajiroun , called Al Ghurabaa , called suicide bombing '' martyrdom operations . ''
# [['Abu Izzadeen', 'PEO_RELIGION', 'Islam']]
# Explanations: Abu Izzadeen converted to Islam at the age of 17;
#
# ----------------
#
# And yet , despite the success of its exhibitions , the institute remains something of a strange hybrid : located southeast of Notre-Dame , in a striking building designed by Jean Nouvel , it has operated since 1987 as a partnership between France and 22 Arab countries .
# [['Jean Nouvel', 'PEO_NATIONALITY', 'France']]
# Explanations: Jean Nouvel designed the institute in Southeast of Notre Dame, France;
#
# ----------------
#
# They could have done it Sunday , when we were closed , '' said Joseph Bastianich , who owns Del Posto with his mother , Lidia Bastianich , and the chef , Mario Batali .
# [['Lidia Bastianich', 'PEO_CHILDREN', 'Joseph Bastianich']]
# Explanations: Lidia Bastianich is the mother of Joseph Bastianich;
#
# ----------------
#
# A French court sentenced six Algerian-French men to prison terms of up to 10 years on Tuesday for their role in a 2001 plot to attack the United States Embassy in Paris , closing the books on one of France 's most serious terrorist cases .
# [['Paris', 'LOC_COUNTRY', 'France'], ['France', 'LOC_CONTAINS', 'Paris'], ['France', 'LOC_ADMIN_DIVISIONS', 'Paris'], ['France', 'LOC_CAPITAL', 'Paris']]
# Explanations: French court in Paris sentenced men to prison for attacking US Embassy; France contains the city of Paris; US Embassy is located in the city of Paris, which is the capital of Fraince;
#
# ----------------
#
# Anheuser-Busch , which has been the exclusive beer sponsor for the Super Bowl since 1989 , will do so again for the Super Bowls in 2007 and 2010 on CBS and in 2008 and 2011 on Fox Broadcasting , said Anthony T. Ponturo , vice president for global media and sports marketing at Anheuser-Busch in St. Louis .
# [['Anheuser-Busch', 'BUS_PLACE_FOUNDED', 'St. Louis'], ['St. Louis', 'LOC_CONTAINS', 'Anheuser-Busch']]
# Explanations: Anheuser-Busch was founded in St. Louis; St. Louis is located in the city of St. Louis;
#
# ----------------
#
# Somewhat chastened by his retreat in the polls , Mr. Blair acknowledged that Britons had turned against him in part over accusations that he led them into a war in Iraq on dubious legal grounds and on the false premise that Saddam Hussein presented a direct threat because of a supposed arsenal of unconventional weapons that was never found . ''
# [['Saddam Hussein', 'PEO_PLACE_OF_DEATH', 'Iraq'], ['Saddam Hussein', 'PEO_PLACE_OF_BIRTH', 'Iraq'], ['Saddam Hussein', 'PEO_NATIONALITY', 'Iraq']]
# Explanations: Saddam Hussein died in Iraq; Saddam Hussein was from Iraq; Saddam Hussein was the president of Iraq;
#
# ----------------
#
# Rupert Murdoch and John C. Malone , who have wrangled for two years over Mr. Malone 's challenge to Mr. Murdoch 's control of the News Corporation , have made peace .
# [['Rupert Murdoch', 'BUS_COMPANY', 'News Corporation'], ['News Corporation', 'BUS_FOUNDERS', 'Rupert Murdoch']]
# Explanations: Rupert Murdoch controls the News Corporation; News Corporation was founded by Rupert Murdoch;
#
# ----------------
#
# Manhattan , especially the East Village , has long been well stocked with cheap and raucous yakitori places that specialize in skewers and beer .
# [['Manhattan', 'LOC_CONTAINS', 'East Village'], ['East Village', 'LOC_NEIGHBORHOOD', 'Manhattan']]
# Explanations: Manhattan contains East Village; The neighborhood of East Village is located in Manhattan;
#
# ----------------
#
# HEADING OUT -- Sanford I. Weill stepped down as chairman of Citigroup , the worldwide financial supermarket he had meticulously and single-mindedly stitched together through dozens of mergers and acquisitions .
# [['Citigroup', 'BUS_ADVISORS', 'Sanford I. Weill']]
# Explanations: Sanford I. Weill is the chairman of Citigroup;
#
# ----------------
#
# He had decided to use the premiere to publicize the issue ; his plan was to invite the neighborhood 's Russian speakers to sign a petition against piracy , a common practice at the area 's Russian-language video outlets , which sell films and music from Russia and by Russian immigrants in the United States .
# [['Russian', 'PEO_GEORGRAPHIC_DISTRIBUTION', 'Russia']]
# Explanations: Russians reside in the geographical area of Russia;
#
# ----------------
#
# In 1995 , Cleveland successfully lobbied to have the name Cleveland Browns stay in that city after that venerable franchise 's owner , Art Modell , opted to move it to Baltimore .
# [['Cleveland', 'SPO_TEAMS', 'Cleveland Browns'], ['Cleveland Browns', 'SPO_LOCATION', 'Cleveland']]
# Explanations: Cleveland Browns is the sports team of city of Cleveland; Cleveland Browns franchise is located in Cleveland;
#
# ----------------
#
# Mr. Fields , speaking from vacation in France , added , '' That a mogul like Sumner Redstone could make a statement so vicious , so pompous , so petulant as that he did n't want to make a deal with Tom Cruise because of his personal conduct -- it tells you more about Sumner Redstone and Viacom , than about Tom Cruise . ''
# [['Sumner Redstone', 'BUS_MAJOR_SHAREHOLDER', 'Viacom'], ['Sumner Redstone', 'BUS_MAJOR_SHAREHOLDER', 'Viacom'], ['Sumner Redstone', 'BUS_COMPANY', 'Viacom'], ['Viacom', 'BUS_MAJOR_SHAREHOLDERS', 'Sumner Redstone'], ['Sumner Redstone', 'BUS_COMPANY', 'Viacom'], ['Viacom', 'BUS_MAJOR_SHAREHOLDERS', 'Sumner Redstone']]
# Explanations: Summer Redstone is a member of Viacom;
#
# ----------------
#
# It is a room of paintings by Leonard Peltier , a citizen of the Anishinabe and Dakota and Lakota nations who is serving two consecutive life terms in Pennsylvania for the murder of two F.B.I. agents on the Pine Ridge Reservation in South Dakota .
# [['Leonard Peltier', 'PEO_ETHNICITY', 'Lakota'], ['Lakota', 'PEO_PEOPLE', 'Leonard Peltier']]
# Explanations: Explanations: Leonard Peltier is a citizen and member of the Lakota Nation; Lakota is the ethnic group of Leonard Peltier;
#
# ----------------
#
# INSIDE THE N.B.A. Correction : February 9 , 2006 , Thursday A sports article on the Spotlight page on Sunday about Dick Bavetta , a longtime referee in the National Basketball Association , misstated the number he was approaching to set the record for regular-season games worked .
# [['Dick Bavetta', 'PEO_PROFESSION', 'National Basketball Association']]
# Explanations: 'Dick Bavetta works at the National Basketball Association;
#
# ----------------
#
# Now the United States Postal Service may be displaying a similar rebellious streak : tomorrow at the huge Sturgis motorcycle rally in the Black Hills of South Dakota , the Postal Service will issue a set of four stamps that depict classic American bikes .
# [['United States Postal Service', 'BUS_INDUSTRY', 'Postal Service']]
# Explanations: United States Postal Service is in the industry of Postal Service;
#
# ----------------

# %%
nyt_data = load_dataset("csv", data_files="nyt_fewshot_explanations.csv")
nyt = nyt_data["train"]

# nyt_reference = load_dataset("csv", data_files="nyt_fewshot_reference.csv")
# nyt_eval = nyt_reference["train"]
# Out:
# Using custom data configuration default-2c630774495b6253
# Found cached dataset csv (/home/wadhwa.s/.cache/huggingface/datasets/csv/default-2c630774495b6253/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
# 100%|██████████| 1/1 [00:00<00:00, 463.56it/s]

# %%
nyt[10]
# Out:
# {'text': "Somewhat chastened by his retreat in the polls , Mr. Blair acknowledged that Britons had turned against him in part over accusations that he led them into a war in Iraq on dubious legal grounds and on the false premise that Saddam Hussein presented a direct threat because of a supposed arsenal of unconventional weapons that was never found . ''",
#  'true_relations': "[['Saddam Hussein', 8, 'Iraq'], ['Saddam Hussein', 7, 'Iraq'], ['Saddam Hussein', 5, 'Iraq']]",
#  'gold_relations': "[['Saddam Hussein', 'PEO_PLACE_OF_DEATH', 'Iraq'], ['Saddam Hussein', 'PEO_PLACE_OF_BIRTH', 'Iraq'], ['Saddam Hussein', 'PEO_NATIONALITY', 'Iraq']]",
#  'explanations': 'Explanations: Saddam Hussein died in Iraq; Saddam Hussein was from Iraq; Saddam Hussein was the president of Iraq; '}

# %%
prefix = """ Find the following relations in the TEXT below:
    0 : "[A, B] Entity A is a location that contains Entity B",
    1 : "[A, B] Entity B is a country that contains Entity A",
    2 : "[A, B] Entity B is the capital of Entity A",
    3 : "[A, B] Entity B is a neighborhood that contains Entity A",
    4 : "[A, B] Entity B is located in the administrative divisions of Entity A",
    5 : "[A, B] Entity A is a national of Entity B",
    6 : "[A, B] Entity A has lived in Entity B",
    7 : "[A, B] Entity A was born in Entity B",
    8 : "[A, B] Entity A died in Entity B",
    9 : "[A, B] Entity B is the child of Entity A",
    10 : "[A, B] Entity A is a member Entity B",
    11 : "[A, B] Entity A is a member of Entity B's geographic distribution",
    12 : "[A, B] Entity A is of ethnicity Entity B",
    13 : "[A, B] Entity B is the ethnicity of Entity A",
    14 : "[A, B] Entity B is the profession of Entity A",
    15 : "[A, B] Entity A is a member of company Entity B",
    16 : "[A, B] Entity A was founded by Entity B",
    17 : "[A, B] Entity A was founded in Entity B",
    18 : "[A, B] Entity B is a major shareholder of Entity A",
    19 : "[A, B] Entity B is a major shareholder of Entity A",
    20 : "[A, B] Entity B advises to Entity A",
    21 : "[A, B] Entity A is in the industry Entity B",
    22 : "[A, B] Entity B is a team located in Entity A",
    23 : "[A, B] Entity B is a location that contains sports team Entity A",
    
TEXT: """

print(prefix)
# Out:
#  Find the following relations in the TEXT below:
#     0 : "[A, B] Entity A is a location that contains Entity B",
#     1 : "[A, B] Entity B is a country that contains Entity A",
#     2 : "[A, B] Entity B is the capital of Entity A",
#     3 : "[A, B] Entity B is a neighborhood that contains Entity A",
#     4 : "[A, B] Entity B is located in the administrative divisions of Entity A",
#     5 : "[A, B] Entity A is a national of Entity B",
#     6 : "[A, B] Entity A has lived in Entity B",
#     7 : "[A, B] Entity A was born in Entity B",
#     8 : "[A, B] Entity A died in Entity B",
#     9 : "[A, B] Entity B is the child of Entity A",
#     10 : "[A, B] Entity A is a member Entity B",
#     11 : "[A, B] Entity A is a member of Entity B's geographic distribution",
#     12 : "[A, B] Entity A is of ethnicity Entity B",
#     13 : "[A, B] Entity B is the ethnicity of Entity A",
#     14 : "[A, B] Entity B is the profession of Entity A",
#     15 : "[A, B] Entity A is a member of company Entity B",
#     16 : "[A, B] Entity A was founded by Entity B",
#     17 : "[A, B] Entity A was founded in Entity B",
#     18 : "[A, B] Entity B is a major shareholder of Entity A",
#     19 : "[A, B] Entity B is a major shareholder of Entity A",
#     20 : "[A, B] Entity B advises to Entity A",
#     21 : "[A, B] Entity A is in the industry Entity B",
#     22 : "[A, B] Entity B is a team located in Entity A",
#     23 : "[A, B] Entity B is a location that contains sports team Entity A",
#
# TEXT:

# %%
prefix = """ Find the following relations in the TEXT below and provide brief explanation:

TEXT: """

print(prefix)
# Out:
#  Find the following relations in the TEXT below and provide brief explanation:
#
# TEXT:

# %%
targets = [gold_label + "\n" + explanation for gold_label, explanation in zip(nyt["gold_relations"], nyt["explanations"])]
print (targets[10])
# Out:
# [['Saddam Hussein', 'PEO_PLACE_OF_DEATH', 'Iraq'], ['Saddam Hussein', 'PEO_PLACE_OF_BIRTH', 'Iraq'], ['Saddam Hussein', 'PEO_NATIONALITY', 'Iraq']]
# Explanations: Saddam Hussein died in Iraq; Saddam Hussein was from Iraq; Saddam Hussein was the president of Iraq;

# %%
def preprocess_function(examples):
    inputs = [prefix + example for example in examples["text"]]
    model_inputs = tokenizer(inputs, max_length=1024, truncation=True)
    targets = [gold_label + "\n" + explanation for gold_label, explanation in zip(nyt["gold_relations"], nyt["explanations"])]
    labels = tokenizer(text_target=targets, max_length=512, truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_nyt = nyt.map(preprocess_function, batched=True)
# Out:
# Loading cached processed dataset at /home/wadhwa.s/.cache/huggingface/datasets/csv/default-2c630774495b6253/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-1bd9d11c5f7a2275.arrow

# %%
tokenized_nyt
# Out:
# Dataset({
#     features: ['text', 'true_relations', 'gold_relations', 'explanations', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 20
# })

# %%
torch.cuda.empty_cache()

# %%
torch.cuda.empty_cache()

training_args = Seq2SeqTrainingArguments(
    output_dir="/scratch/wadhwa.s/cache/myawesomemodel_nyt",
    evaluation_strategy="no",
    learning_rate=3e-5,
    per_device_train_batch_size=2,
    # per_device_eval_batch_size=2,
    logging_steps=8,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=12,
    predict_with_generate=False,
    # gradient_accumulation_steps=4,
    # fp16=True,
    # push_to_hub=True,
)

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_nyt,
    # eval_dataset=tokenized_ade["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: text, explanations, true_relations, gold_relations. If text, explanations, true_relations, gold_relations are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 20
#   Num Epochs = 12
#   Instantaneous batch size per device = 2
#   Total train batch size (w. parallel, distributed & accumulation) = 2
#   Gradient Accumulation steps = 1
#   Total optimization steps = 120
#   Number of trainable parameters = 783150080
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: sw7. Use `wandb login --relogin` to force relogin
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/wadhwa.s/gpt3/wandb/run-20221221_215610-222t7dsa</code>
# Syncing run <strong><a href="https://wandb.ai/sw7/huggingface/runs/222t7dsa" target="_blank">/scratch/wadhwa.s/cache/myawesomemodel_nyt</a></strong> to <a href="https://wandb.ai/sw7/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 00:45, Epoch 12/12]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>8</td>
#       <td>2.052400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.558300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.270800</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.000400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.905400</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.819300</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.776800</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.665800</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.656700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.537800</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.506800</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.599100</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.455500</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.518800</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.491000</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=120, training_loss=0.8543308993180593, metrics={'train_runtime': 54.2754, 'train_samples_per_second': 4.422, 'train_steps_per_second': 2.211, 'total_flos': 95665875959808.0, 'train_loss': 0.8543308993180593, 'epoch': 12.0})

# %%
torch.cuda.empty_cache()

# %%
tuned_model = AutoModelForSeq2SeqLM.from_pretrained("/scratch/wadhwa.s/cache/myawesomemodel/checkpoint-1000")
tokenizer = AutoTokenizer.from_pretrained("/scratch/wadhwa.s/cache/myawesomemodel/checkpoint-1000")
# Out:
# loading configuration file /scratch/wadhwa.s/cache/myawesomemodel/checkpoint-1000/config.json
# Model config T5Config {
#   "_name_or_path": "/scratch/wadhwa.s/cache/myawesomemodel/checkpoint-1000",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2816,
#   "d_kv": 64,
#   "d_model": 1024,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 24,
#   "num_heads": 16,
#   "num_layers": 24,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading weights file /scratch/wadhwa.s/cache/myawesomemodel/checkpoint-1000/pytorch_model.bin
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at /scratch/wadhwa.s/cache/myawesomemodel/checkpoint-1000.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# loading file spiece.model
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json

# %%
df = pd.read_csv("conll_fewshot_reference.csv")
df.head()
# Out:
#                                                 text  \
# 0  John Wilkes Booth , who assassinated President...
# 1  The opera company performed at the Palace of F...
# 2  In the field of mechanics , Wang Ziqiang at th...
# 3  Sun Hung Kai Properties , a Hong Kong construc...
# 4  Marie Magdefrau Ferraro , 50 , of Bethany , Co...
#
#                                          gold_labels explanations
# 0  [['John Wilkes Booth', 'Kill', 'President Linc...     ********
# 1  [['Palace of Fine Arts', 'Located_In', 'San Fr...     ********
# 2  [['Wang Ziqiang', 'Work_For', 'Institute of Me...     ********
# 3  [['Sun Hung Kai Properties', 'OrgBased_In', 'H...     ********
# 4  [['Marie Magdefrau Ferraro', 'Live_In', 'Betha...     ********

# %%
ip = []
gold = []
generated = []

for ix, row in df.iterrows():
    text = prefix + row["text"]
    inputs = tokenizer(text, return_tensors="pt").input_ids
    outputs = model.generate(inputs, max_new_tokens=256, do_sample=False)
    out = tokenizer.decode(outputs[0], skip_special_tokens=True)
    torch.cuda.empty_cache()
    print (row["text"])
    print ("GOLD: " + row["gold_labels"])
    try:
        generated.append(out.split(" Explanation: ")[0])
        ip.append(row["text"])
        gold.append(row["gold_labels"])
        print ("PRED: " + out)
    except:
        print ("PRED ---- NON CONFORMING OUTPUT: " + out)

    print ("\n----------------\n")
# Out:
# John Wilkes Booth , who assassinated President Lincoln , was an actor .
# GOLD: [['John Wilkes Booth', 'Kill', 'President Lincoln']]
# PRED: [['John Wilkes Booth', 'Work_For', 'John Wilkes Booth']] Explanation: John Wilkes Booth was an actor who assassinated President Lincoln.
#
# ----------------
#
# The opera company performed at the Palace of Fine Arts , in San Francisco , on June 30 and July 1-2 , said Kevin O 'Brien , a spokesman for the theater.
# GOLD: [['Palace of Fine Arts', 'Located_In', 'San Francisco']]
# PRED: [['Kevin O'Brien', 'Work_For', 'Palace of Fine Arts'], ['Kevin O'Brien', 'Work_For', 'San Francisco']] Explanation: The opera company performed at the Palace of Fine Arts, which is located in San Francisco.
#
# ----------------
#
# In the field of mechanics , Wang Ziqiang at the Institute of Mechanics has made considerable headway in the area of elastoplastic crack mechanics .
# GOLD: [['Wang Ziqiang', 'Work_For', 'Institute of Mechanics']]
# PRED: [['Wang Ziqiang', 'Work_For', 'Institute of Mechanics']] Explanation: Wang Ziqiang works for the Institute of Mechanics.
#
# ----------------
#
# Sun Hung Kai Properties , a Hong Kong construction firm with a 27 percent share ;
# GOLD: [['Sun Hung Kai Properties', 'OrgBased_In', 'Hong Kong']]
# PRED: [['Sun Hung Kai Properties', 'Work_For', 'Hong Kong']] Explanation: Sun Hung Kai Properties is a construction firm based in Hong Kong.
#
# ----------------
#
# Marie Magdefrau Ferraro , 50 , of Bethany , Conn. , was shot to death Thursday when two bandits armed with assault rifles emerged from nearby bushes and began firing at a van carrying a Connecticut Audubon Society wildlife wild tour group .
# GOLD: [['Marie Magdefrau Ferraro', 'Live_In', 'Bethany'], ['Marie Magdefrau Ferraro', 'Live_In', 'Conn.'], ['Bethany', 'Located_In', 'Conn.']]
# PRED: [['Marie Magdefrau Ferraro', 'Live_In', 'Bethany, Conn.']] Explanation: Marie Magdefrau Ferraro was killed by two bandits, so it can be concluded that Marie Magdefrau Ferraro Lives In Bethany, Conn.
#
# ----------------
#
# Ten oil workers were missing off Morgan City , La. , after their rig capsized while heading inland Monday to escape the storm.
# GOLD: [['Morgan City', 'Located_In', 'La.']]
# PRED: [['10', 'Live_In', 'Lancaster, Pennsylvania']] Explanation: Ten oil workers were missing off Morgan City, La., because their rig capsized while heading inland to escape the storm.
#
# ----------------
#
# Lightning ignited a firestorm that charred 10 , 000 acres in central Idaho , including much of the small resort town of Lowman , about 70 miles northeast of Boise.
# GOLD: [['Lowman', 'Located_In', 'Idaho']]
# PRED: [['Lowman', 'Located_In', 'Boise']] Explanation: Lowman is a resort town in Idaho. Therefore, the answer is Idaho.
#
# ----------------
#
# " It ( Arrow ) is not practical in the short term , " says former Air Force commander Avihu Bin-Nun .
# GOLD: [['Avihu Bin-Nun', 'Work_For', 'Air Force']]
# PRED: [['Avihu Bin-Nun', 'Work_For', 'Air Force']] Explanation: Avihu Bin-Nun is a former Air Force commander. Avihu Bin-Nun is a person who works for Air Force.
#
# ----------------
#
# The three reactors , all at the Savannah River Plant , in Aiken , S.C. , have been shut down since last April undergoing changes to make them safer .
# GOLD: [['Savannah River Plant', 'Located_In', 'Aiken'], ['Savannah River Plant', 'Located_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# PRED: [['Savann River Plant', 'Located_In', 'Aiken'], ['Savann River Plant', 'OrgBased_In', 'S.C.']] Explanation: The reactors at the Savannah River Plant are operated by the SC. They are located in Aiken, SC. Therefore, the SC is an organization.
#
# ----------------
#
# Composer Thomas is a native of Chisholm , Minn .
# GOLD: [['Thomas', 'Live_In', 'Chisholm'], ['Thomas', 'Live_In', 'Minn .'], ['Chisholm', 'Located_In', 'Minn .']]
# PRED: [['Thomas', 'Live_In', 'Chisholm, Minn']] Explanation: Thomas is a native of Chisholm, Minn. Therefore, it can be concluded that Thomas Lives In Chisholm, Minn.
#
# ----------------
#
# Illinois Gov. James Thompson signed legislation last month scrapping Chicago 's central school board next July , to be replaced by parent-run councils empowered to set budgets and hire and fire principals .
# GOLD: [['James Thompson', 'Live_In', 'Illinois']]
# PRED: [['James Thompson', 'Work_For', 'Illinois']] Explanation: James Thompson worked for Illinois Govt.
#
# ----------------
#
# During the 10-hour rescue , diver Brian Michaud of Millinocket hooked the men to harnesses , and rescuers dragged them to the surface with winches .
# GOLD: [['Brian Michaud', 'Live_In', 'Millinocket']]
# PRED: [['Bishop Michaud', 'Live_In', 'Millinocket']] Explanation: The rescue of the men was performed by the rescuers, not by the diver.
#
# ----------------
#
# The Warren Commission found Oswald acted alone in killing Kennedy .
# GOLD: [['Oswald', 'Kill', 'Kennedy']]
# PRED: [['Oswald', 'Acted_Alone', 'Kill'], ['Oswald', 'Live_In', 'Williams County'], ['Oswald', 'Live_In', 'Williams County']] Explanation: Oswald killed Kennedy, therefore it can be concluded that Oswald killed Kennedy.
#
# ----------------
#
# ( By Yang Jianbai ( 2799 1017 4101 ) of the Economic Research
# GOLD: [['Yang Jianbai', 'Work_For', 'Economic Research']]
# PRED: [['Yang Jianbai', 'Live_In', 'OrgBased_In', 'Yang Jianbai']] Explanation: Yang Jianbai is the author of the article "Yang Jianbai: Economic Research" and therefore it can be concluded that Yang Jianbai is the author of the article.
#
# ----------------
#
# ` ` He was going pretty fast , wasn 't he ? ' ' said Daniel Urquhart , 8 , of Aumsville , whose slug crept to the championship.
# GOLD: [['Daniel Urquhart', 'Live_In', 'Aumsville']]
# PRED: [['Daniel Urquhart', 'Live_In', 'Aumsville']] Explanation: Daniel Urquhart is a member of Aumsville, which is based in the United States.
#
# ----------------
#
# Kovacevic , a Serb , has come under fire from Serbian politicians and the republic 's press since the U.S. Congress last month passed two resolutions claiming there were human rights violations in the strife-torn southern province of Kosovo.
# GOLD: [['Congress', 'OrgBased_In', 'U.S.']]
# PRED: [['Kovavacevic', 'Live_In', 'Serbia']] Explanation: Kovacevic is a Serb, so it can be concluded that Kovacevic Lives In Serbia.
#
# ----------------
#
# Martin Luther King III , a son of the slain civil rights leader , said the execution of King assassin James Earl Ray ` ` would not bring my father back. ' '
# GOLD: [['James Earl Ray', 'Kill', 'Martin Luther King III']]
# PRED: [['Martin Luther King III', 'Son', 'Martin Luther King III']] Explanation: Martin Luther King III is the son of the slain civil rights leader, James Earl Ray. Therefore, it can be concluded that Martin Luther King III is the son of James Earl Ray.
#
# ----------------
#
# On this date : In 1833 , Benjamin Harrison , the 23rd President of the United States , was born in North Bend , Ohio .
# GOLD: [['Benjamin Harrison', 'Live_In', 'North Bend , Ohio']]
# PRED: [['Benjamin Harrison', 'Live_In', 'North Bend, Ohio']] Explanation: Benjamin Harrison (born 1833) was born in North Bend, Ohio.
#
# ----------------
#
# The book said Khrushchev 's order to ignore the blockade was disclosed in a largely unknown work by dissident Soviet historian Roy Medvedev .
# GOLD: [['Khrushchev', 'Live_In', 'Soviet'], ['Roy Medvedev', 'Live_In', 'Soviet']]
# PRED: [['Ryan Medvedev', 'Work_For', 'Dissident Soviet Historian Roy Medvedev']] Explanation: The book said Khrushchev's order to ignore the blockade was disclosed in a work by dissident Soviet historian Roy Medvedev.
#
# ----------------
#
# EDITOR 'S NOTE : Walter R. Mears , vice and columnist for The Associated Press , has reported on Washington and national politics for more than 25 years .
# GOLD: [['Walter R. Mears', 'Work_For', 'The Associated Press']]
# PRED: [['Walter R. Mears', 'Work_For', 'The Associated Press']] Explanation: Walter R. Mears is a vice and columnist for The Associated Press, therefore it can be concluded that Walter R. Mears Work For The Associated Press.
#
# ----------------
#
# ` ` The Germans just tunneled like rabbits , ' ' said Gerald Przenislawski , who operates La Valette Underground Military Museum.
# GOLD: [['Gerald Przenislawski', 'Work_For', 'La Valette Underground Military Museum.']]
# PRED: [['Meredith Przenislawski', 'Work_For', 'La Valette Underground Military Museum']] Explanation: Gerald Przenislawski is the person who operates La Valette Underground Military Museum.
#
# ----------------
#
# ` ` With South Carolina being Jesse Jackson 's home state , there was a very strong incentive in the black community. ' '
# GOLD: [['Jesse Jackson', 'Live_In', 'South Carolina']]
# PRED: [['Jesse Jackson', 'Home_State', 'South Carolina']] Explanation: Jesse Jackson is a black person.
#
# ----------------
#
# Photo , Dueling Over a GunIt is a scene seared into the memories of Americans old enough to have watched it that November day in 1963 : Jack Ruby firing his .38-caliber Colt Cobra , above , at Lee Harvey Oswald , the man who had assassinated President John F. Kennedy two days earlier.
# GOLD: [['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# PRED: [['Jack Ruby', 'Live_In', 'United States']] Explanation: Jack Ruby is the man who killed Lee Harvey Oswald.
#
# ----------------
#
# In a statement at the airport before his departure , Cetin said that Turkey welcomed this step taken by Bosnians and Croats and hoped that real peace comes to Bosnia-Herzegovina when Serbs join this process too .
# GOLD: [['Cetin', 'Live_In', 'Turkey']]
# PRED: [['Cetin', 'Work_For', 'Turkish People']] Explanation: Cetin worked for a group that is based in Bosnia-Herzegovina.
#
# ----------------
#
# On Friday , U.S. Ambassador Vernon A. Walters displayed photographs of one Libyan jet showing shapes resembling missile pods on its wings and fuselage .
# GOLD: [['Vernon A. Walters', 'Live_In', 'U.S.']]
# PRED: [['Von A. Walters', 'Work_For', 'United States']] Explanation: The Libyan jet displayed photographs of one U.S. Ambassador Vernon A. Walters on Friday.
#
# ----------------
#
# Ms. Carpenter 's brother , retired National Football League placekicker Mark Moseley , was in the courtroom Wednesday and told reporters afterward , ` ` It 's been nine years of hell for myself and my family. ' '
# GOLD: [['Mark Moseley', 'Work_For', 'National Football League']]
# PRED: [['Mark Moseley', 'Live_In', 'National Football League']] Explanation: Mark Moseley is a former placekicker in the National Football League.
#
# ----------------
#
# Hernandez Galicia 's allegedly corrupt Mexican Oil Workers Union controls more than half the lucrative drilling contracts issued by the state oil monopoly , Pemex .
# GOLD: [['Hernandez Galicia', 'Work_For', 'Mexican Oil Workers Union']]
# PRED: [['Mexican Oil Workers Union', 'Work_For', 'Pemex']] Explanation: The Mexican Oil Workers Union is a part of the Mexican Oil monopoly, which is located in Mexico. Therefore, the Mexican Oil Workers Union is a part of the Pemex monopoly.
#
# ----------------
#
# You 'll pass through Rolling Fork , where Muddy Waters was born , close to Greenville , home of Nelson Street 's funky strip of blues clubs , and into Clarksdale , at the intersection of Highway 61 and another major road in blues lore , U.S. Highway 49. ;
# GOLD: [['Muddy Waters', 'Live_In', 'Rolling Fork']]
# PRED: [['Muddy Waters', 'Live In', 'Rolling Fork']] Explanation: Muddy Waters was born in Rolling Fork, which is located in Nelson Street. Therefore, the location of Muddy Waters is Clarksdale.
#
# ----------------
#
# ` ` The Challenger accident marked a major change in the U.S. outlook and policies with respect to the flight of other than NASA astronauts , ' ' the National Aeronautics and Space Administration said in a policy statement .
# GOLD: [['NASA', 'OrgBased_In', 'U.S.'], ['National Aeronautics and Space Administration', 'OrgBased_In', 'U.S.']]
# PRED: [['Challenger', 'Work_For', 'National Aeronautics and Space Administration']] Explanation: The National Aeronautics and Space Administration is a United States based organization.
#
# ----------------
#
# ` ` It 's not going to make you a whole bunch of money , but that 's not why we 're doing it , ' ' said Phil Fuhrer , vice of Gannett New Media. 1-900-WEATHER offers callers the current weather and a three-day forecast , plus skiing and highway conditions in the winter and coastal reports during the summer.
# GOLD: [['Phil Fuhrer', 'Work_For', 'Gannett New Media.']]
# PRED: [['Phil Fuhrer', 'Work_For', 'Gannett New Media']] Explanation: Phil Fuhrer is vice of Gannett New Media. Phil Fuhrer works for Gannett New Media.
#
# ----------------
#
# PA2904034294 Guatemala City Teleonce Television in Spanish 0400 GMT 26 Apr 94
# GOLD: [['Teleonce Television', 'OrgBased_In', 'Guatemala City']]
# PRED: [['PA2904034294', 'Located_In', 'Guatemala City']] Explanation: The station name is PA2904034294 Guatemala City Teleonce Television in Spanish, the station is located in Guatemala City, the station is broadcasting in Spanish, and the station is based in Guatemala City.
#
# ----------------
#
# DAYTON , Ohio ( AP )
# GOLD: [['DAYTON', 'Located_In', 'Ohio'], ['AP', 'OrgBased_In', 'DAYTON'], ['AP', 'OrgBased_In', 'Ohio']]
# PRED: [['AP', 'Located_In', 'Dayton, Ohio']] Explanation: 'AP' is an organization based in Ohio.
#
# ----------------
#
# In 1865 , four people were hanged in Washington , D.C. , after being convicted of conspiring with John Wilkes Booth in the assassination of President Lincoln .
# GOLD: [['John Wilkes Booth', 'Kill', 'President Lincoln']]
# PRED: [['Washington', 'D.C.']] Explanation: In 1865, four people were hanged in Washington, D.C., after being convicted of conspiring with John Wilkes Booth in the assassination of President Lincoln.
#
# ----------------
#
# San Gabriel River Channel , Azusa , Calif. ;
# GOLD: [['San Gabriel River Channel', 'Located_In', 'Azusa'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azusa', 'Located_In', 'Calif.']]
# PRED: [['San Gabriel River Channel', 'Located_In', 'Azusa'], ['San Gabriel River Channel', 'Located_In', 'California']] Explanation: San Gabriel River Channel is located in Azusa, California. Therefore, it can be concluded that San Gabriel River Channel is Located In California.
#
# ----------------
#
# He said that the Phnom Penh government has worked out several incentives to attract foreign investment in Cambodia .
# GOLD: [['Phnom Penh government', 'OrgBased_In', 'Cambodia']]
# PRED: [['He', 'Work_For', 'Phnom Penh']] Explanation: He worked out several incentives to attract foreign investment in Cambodia.
#
# ----------------
#
# Derwinski , a Republican from Chicago who served 24 years in Congress , publicly denied 1978 allegations that he leaked the information and refused to testify in the matter before a federal grand jury and the House Ethics Committee .
# GOLD: [['Derwinski', 'Live_In', 'Chicago'], ['Derwinski', 'Work_For', 'Congress']]
# PRED: [['Derwinski', 'Live_In', 'Chicago']] Explanation: Derwinski is a Republican from Chicago, who was a member of the House Ethics Committee. Therefore, he worked for the House Ethics Committee.
#
# ----------------
#
# BANGKOK , Thailand ( AP )
# GOLD: [['BANGKOK', 'Located_In', 'Thailand'], ['AP', 'OrgBased_In', 'BANGKOK'], ['AP', 'OrgBased_In', 'Thailand']]
# PRED: [['Bangkok', 'Located_In', 'Thailand']] Explanation: Located_In: AP is located in Bangkok, which is in Thailand. Therefore, AP is located in Thailand.
#
# ----------------
#
# ( Text ) Police Major Pramot Pansakun , the commander of the Region 2 Border Patrol Police ( BPP ) , Khon Kaen , and Thai and American narcotics suppression officials accompanied by reporters , spent more than 2 hours climbing a high mountain to destroy a Hmong poppy field located along the border between Dan Sai District in Loei Province , Nakhon Thai District in Phitsanulok Province , and Lomsak District in Phetchabun Province .
# GOLD: [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Dan Sai District', 'Located_In', 'Loei Province'], ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province'], ['Lomsak District', 'Located_In', 'Phetchabun Province']]
# PRED: [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police ( BPP ) ', 'Khon Kaen', 'Loei Province', 'Nakhon Thai District', 'Phetchabun Province']] Explanation: Pramot Pansakun is the commander of the Border Patrol Police, therefore it can be concluded that he is the commander of the Border Patrol Police.
#
# ----------------
#
# Further buying was linked to rumors that the Chilean copper company Codelco was considering shutting down its smelter at Chuquicamata , the world 's largest copper mine , due to persistent mechanical problems , said Fred Demler , metals economist with Drexel Burnham Lambert Inc. in New York .
# GOLD: [['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.'], ['Fred Demler', 'Live_In', 'New York'], ['Drexel Burnham Lambert Inc.', 'OrgBased_In', 'New York']]
# PRED: [['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.']] Explanation: Fred Demler is an economist at Drexel Burnham Lambert Inc., which is based in New York.
#
# ----------------
#
# An urgent call for international help to avert food shortages in Poland went out both from last month 's Western economic summit in Paris and from Monday 's meeting in Brussels of 24 concerned nations chaired by the European Community Commission.
# GOLD: [['European Community Commission.', 'OrgBased_In', 'Brussels']]
# PRED: [['European Community Commission', 'Located_In', 'Paris']] Explanation: 'European Community Commission' is an organization based in Brussels.
#
# ----------------
#
# Cheek , 53 , is a former chief and charge in Addis Ababa , Ethiopia.
# GOLD: [['Addis Ababa', 'Located_In', 'Ethiopia.']]
# PRED: [['Cheek', 'Located_In', 'Addis Ababa']] Explanation: Cheek is a former chief and he is based in Addis Ababa, Ethiopia.
#
# ----------------
#
# In 1881 , President James A. Garfield was shot by Charles J. Guiteau , a disappointed office-seeker , at the Washington railroad station .
# GOLD: [['Charles J. Guiteau', 'Kill', 'President James A. Garfield']]
# PRED: [['Charles J. Guiteau', 'Live_In', 'Washington']] Explanation: In 1881, James A. Garfield was shot by Charles J. Guiteau, a disappointed office-seeker, at the Washington railroad station.
#
# ----------------
#
# Middle-class Argentines , among the most affluent in Latin America at one time , are so strapped now that they are selling off heirlooms that had been in their families since the days when beef and grain made Argentina one of the world 's wealthiest nations.
# GOLD: [['Argentina', 'Located_In', 'Latin America']]
# PRED: [['Argentines', 'Live_In', 'Latin America']] Explanation: The Argentines are the most affluent people in Latin America. Therefore, the Argentines are located in Latin America.
#
# ----------------
#
# ` ` I don 't think there are any good answers why , ' ' said Virginia Towle of Wallingford , a family friend.
# GOLD: [['Virginia Towle', 'Live_In', 'Wallingford']]
# PRED: [['Virginia Towle', 'Live_In', 'Walingford']] Explanation: Virginia Towle is a family friend, therefore it can be concluded that Virginia Towle Lives In Wallingford.
#
# ----------------
#
# The meeting will be held at the request of the Soviet Union , which also plans direct talks with resistance leader Prince Norodom Sihanouk , said Sihanouk 's son and representative in Thailand , Prince Norodom Ranariddh .
# GOLD: [['Prince Norodom Ranariddh', 'Live_In', 'Thailand']]
# PRED: [['Prince Norodom Ranariddh', 'Work_For', 'Soviet Union']] Explanation: The meeting will be held at the request of the Soviet Union, which also plans direct talks with resistance leader Prince Norodom Sihanouk, which is the leader of the resistance.
#
# ----------------
#
# Hundreds of children and adults sporting cowboy boots and hats turned out Wednesday to watch as Winterset 's busiest street was named for John Wayne , the community 's most famous native son .
# GOLD: [['John Wayne', 'Live_In', 'Winterset']]
# PRED: [['John Wayne', 'Live_In', 'Winterset']] Explanation: Winterset is a community located in Winterset, which is a part of the United States. John Wayne is the name of a famous native son of Winterset.
#
# ----------------
#
# River North 's nouvelle sensibilities also might be offended by the Ranch 's menu , which features items such as the ` ` Jesse James Steak ( A Steal ! ) , ' ' and the occasional ornery patron .
# GOLD: [['Ranch', 'OrgBased_In', 'River North']]
# PRED: [['Jesse James Steak', 'A Steak!', 'Offended']] Explanation: The Ranch is a restaurant. It is located in the city of River North. It is a restaurant.
#
# ----------------
#
# Police Find No Signs of Radiation Leak AU0202111694 Paris AFP in English 0107 GMT 2 Feb 94
# GOLD: [['AFP', 'OrgBased_In', 'Paris']]
# PRED: [['Paris AFP', 'Located_In', 'Paris']] Explanation: The AFP is an organization based in Paris.
#
# ----------------
#
# It was filmed on location in Tokyo and Kyoto and is a co-production of Children 's Television Worship and NHK network in Japan .
# GOLD: [['Tokyo', 'Located_In', 'Japan'], ['Kyoto', 'Located_In', 'Japan']]
# PRED: [['Tokyo', 'Yoyogi', 'OrgBasedIn', 'Japan']] Explanation: It was filmed on location in Tokyo and Kyoto, so it can be concluded that NHK network in Japan is based in Japan.
#
# ----------------
#
# The self-propelled rig Avco 5 with 14 people aboard was headed to shore early Monday when it capsized about 20 miles off the Louisiana coast , near Morgan City , Chevron spokesman Jonathan Lifa said.
# GOLD: [['Jonathan Lifa', 'Work_For', 'Chevron']]
# PRED: [['Jonathan Lifa', 'Work_For', 'Chevron']] Explanation: The self-propelled rig Avco 5 was headed to shore when it capsized about 20 miles off the Louisiana coast, near Morgan City, so it can be concluded that Avco 5 was killed.
#
# ----------------
#
# Sen. Jake Garn , R-Utah , flew on the shuttle in April 1985 and Rep. Bill Nelson , D-Fla. , was aboard in January 1986 , at the invitation of NASA 's administrator .
# GOLD: [['Jake Garn', 'Work_For', 'NASA'], ['Bill Nelson', 'Work_For', 'NASA']]
# PRED: [['Jake Garn', 'Work_For', 'NASA']] Explanation: Jake Garn is a member of the Republican Party of Utah. Jake Garn is also a member of NASA.
#
# ----------------
#
# Ten Soviet volunteers and their American counterparts plan to spend August in Washington building homes for the poor as a return favor for help in earthquake-devastated Soviet Armenia.
# GOLD: [['Armenia.', 'Located_In', 'Soviet']]
# PRED: [['Soviet volunteers', 'Live_In', 'Washington']] Explanation: Ten Soviet volunteers and their American counterparts plan to spend August in Washington building homes for the poor as a return favor for help in earthquake-devastated Soviet Armenia.
#
# ----------------
#
# Evaluating Juppe 's visit , Cetin said that the French Government was not displaying a disturbing stand toward Turkey and was very careful in not intervening in Turkey 's internal affairs .
# GOLD: [['Juppe', 'Work_For', 'French Government'], ['Cetin', 'Live_In', 'Turkey'], ['Cetin', 'Live_In', 'Turkey']]
# PRED: [['Jumppe', 'Work_For', 'French Government']] Explanation: Evaluating Juppe's visit, Cetin said that Juppe was not displaying a disturbing stand toward Turkey, and that Juppe was not displaying a disturbing stand toward Turkey.
#
# ----------------
#
# Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
# GOLD: [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# PRED: [['Juan Vicente Maldonado', 'Work_For', 'Andean Group']] Explanation: Jose Vicente Maldonado is the Ecuadoran minister of industry, commerce, and integration. Therefore, it can be concluded that Jose Vicente Maldonado Works For the Andean Group.
#
# ----------------
#
# Dole 's wife , Elizabeth , is a native of Salisbury , N.C .
# GOLD: [['Elizabeth', 'Live_In', 'Salisbury , N.C']]
# PRED: [['Elizabeth', 'Live_In', 'Salisbury']] Explanation: Elizabeth Dole is a native of Salisbury, N.C..
#
# ----------------
#
# ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
# GOLD: [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# PRED: [['BTA', 'Live_In', 'Bulgaria']] Explanation: 'Bulgaria' is a country in Europe. ''BTA' is a political force in Bulgaria. ''Bulgaria' is a country in Europe. ''Bulgaria' is a country in Europe. ''BTA' is a political force in Bulgaria. ''BTA' is a political force in Bulgaria. ''BTA' is a political force in Bulgaria. ''BTA' is a political force in Bulgaria. ''BTA' is a political force in Bulgaria. ''BTA' is a political force in Bulgaria. ''BTA' is a country in Europe.
#
# ----------------
#
# Starr , who served as counselor to Attorney William French Smith from 1981 prior to taking the bench in 1983 , had been mentioned as a possible Supreme Court nominee after his former colleague on the District of Columbia circuit , Robert Bork , failed to win Senate confirmation in 1987 .
# GOLD: [['Supreme Court', 'OrgBased_In', 'District of Columbia'], ['Senate', 'OrgBased_In', 'District of Columbia']]
# PRED: [['Starr', 'Work_For', 'Atty. William French Smith']] Explanation: Starr was a member of the District of Columbia circuit for Robert Bork, who was a colleague of Attorney William Bork. Robert Bork was a member of the District of Columbia circuit for Robert Bork, who was a colleague of Starr.
#
# ----------------
#
# The program , financed with a grant from the United States Agency for International Development , is aimed at reducing infant mortality in Madagascar , an island nation in the Indian Ocean off the eastern coast of Africa.
# GOLD: [['Madagascar', 'Located_In', 'Indian Ocean']]
# PRED: [['Madagascar', 'Located_In', 'Indian Ocean'], ['Madagascar', 'Located_In', 'Africa']] Explanation: Madagascar is an island nation in the Indian Ocean, and the United States Agency for International Development is a United States based organization.
#
# ----------------
#
# JN0704183294 Paris Radio Monte Carlo in Arabic 1700 GMT 7 Apr 94
# GOLD: [['Radio Monte Carlo', 'OrgBased_In', 'Paris']]
# PRED: [['JN0704183294', 'Live_In', 'Pasadena']] Explanation: JN0704183294 is a date in the past. It is therefore not possible to say whether JN0704183294 is a date in the past.
#
# ----------------
#
# On this date : In 1533 , the last Incan King of Peru , Atahualpa , was murdered on the orders of Spanish conqueror Francisco Pizarro .
# GOLD: [['Francisco Pizarro', 'Kill', 'Atahualpa']]
# PRED: [['Atahualpa', 'Live_In', 'Peru']] Explanation: On the orders of Spanish conqueror Francisco Pizarro, the last Incan King of Peru, was murdered.
#
# ----------------
#
# ` ` We 'd play hearts for hours at a time , ' ' said Atlanta businessman Neil Estes.
# GOLD: [['Neil Estes.', 'Live_In', 'Atlanta']]
# PRED: [['Neil Estes', 'Work_For', 'Atlanta']] Explanation: The businessman, Neil Estes, lives in Atlanta, which is in the United States.
#
# ----------------
#
# Minox has not shown a profit since 1981 , and on April 1 , 1988 , Robert C. Corduwener , a Netherlands businessman bought a 51 percent share of the company to take control from the Rinn family .
# GOLD: [['Robert C. Corduwener', 'Live_In', 'Netherlands']]
# PRED: [['Robert C. Corduwener', 'Live_In', 'Netherlands']] Explanation: Robert C. Corduwener is a Netherlands businessman. Robert C. Corduwener bought a 51 percent share of the company on April 1st, 1988.
#
# ----------------
#
# Volcanoes in Nicaragua and Indonesia , deforestation in Brazil and Madagascar , the Sahara desert in Africa and global beach erosion are among the subjects to be photographed .
# GOLD: [['Sahara desert', 'Located_In', 'Africa']]
# PRED: [['Nicaragua', 'Located_In', 'Indonesia']] Explanation: Volcanoes in Nicaragua and Indonesia are among the subjects to be photographed. Therefore, it can be concluded that Volcanoes in Nicaragua and Indonesia are Located In Indonesia.
#
# ----------------
#
# ` ` This is really hurting Heuchelheim , ' ' the town 's mayor Willi Marx told The Associated Press in an interview at his office earlier this month .
# GOLD: [['Willi Marx', 'Live_In', 'Heuchelheim']]
# PRED: [['Wildi Marx', 'Work_For', 'The Associated Press']] Explanation: Willi Marx is the mayor of Heuchelheim, therefore it can be concluded that Willi Marx Works For The Associated Press.
#
# ----------------
#
# ` ` I think at this moment they fear making a wrong move _ whether they should seek political asylum or use other reasons to remain here , ' ' said Jeff Shia , president of the Kiangsu Chekiang Association , a non-profit group that helps new Chinese immigrants establish themselves in the city.
# GOLD: [['Jeff Shia', 'Work_For', 'Kiangsu Chekiang Association']]
# PRED: [['Jeff Shia', 'Live_In', 'OrgBased_In']] Explanation: Jeff Shia is the president of Kiangsu Chekiang Association, which is a non-profit group that helps new Chinese immigrants establish themselves in the city. Jeff Shia Lives in OrgBased In.
#
# ----------------
#
# The term ` ` 30 Seconds Over Tokyo ' ' was the title of a popular movie about the raid. _Anzio _ The Anzio beachhead , 33 miles south of Rome , saw some of the bloodiest fighting of World War II and accounted for many of the 10 , 000 U.S. battle deaths in Italy the first half of 1944 .
# GOLD: [['Anzio', 'Located_In', 'Italy']]
# PRED: [['Anzio', 'Live_In', 'Italy']] Explanation: Anzio Beachhead is located in Italy, and it is the location of the U.S. Battle Deaths in Italy.
#
# ----------------
#
# Anna Sandhu Ray , who 10 years ago Thursday wed the man convicted of killing the Rev. Martin Luther King Jr. , said on her anniversary that she plans to divorce James Earl Ray .
# GOLD: [['James Earl Ray', 'Kill', 'Rev. Martin Luther King Jr.']]
# PRED: [['Anne Sandhu Ray', 'Kill', 'Rever. Martin Luther King Jr.']] Explanation: Anna Sandhu Ray was the one who killed Martin Luther King Jr.
#
# ----------------
#
# The 23-foot-tall statue was modeled after the 30-foot-tall Goddess of Democracy raised by Chinese pro-democracy demonstrators in Beijing 's Tiananmen Square on May 30.
# GOLD: [['Tiananmen Square', 'Located_In', 'Beijing']]
# PRED: [['Georgie of Democracy', 'Located_In', 'Beijing']] Explanation: The 23-foot-tall statue was modeled after the 30-foot-tall Goddess of Democracy raised by Chinese pro-democracy demonstrators in Beijing's Tiananmen Square on May 30. ['Tiananmen', 'Located_In', 'Beijing']] Explanation: The 23-foot-tall statue was modeled after the 30-foot-tall Goddess of Democracy raised by Chinese pro-democracy demonstrators in Beijing's Tiananmen Square on May 30.
#
# ----------------
#
# ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
# GOLD: [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# PRED: [['Li Peng', 'Work_For', 'China']] Explanation: Li Peng is the Prime Minister of China, therefore it can be concluded that Li Peng is the Prime Minister of China.
#
# ----------------
#
# In 1874 , Herbert Clark Hoover , the 31st president of the United States , was born in West Branch , Iowa .
# GOLD: [['Herbert Clark Hoover', 'Live_In', 'West Branch , Iowa']]
# PRED: [['Herbert Clark Hoover', 'Live_In', 'West Branch, Iowa']] Explanation: Herbert Clark Hoover was born in West Branch, Iowa. Therefore, it can be concluded that Herbert Clark Hoover was born in West Branch, Iowa.
#
# ----------------
#
# ( Text ) The Rwandan Patriotic Front ( RPF ) has rescued 2 , 000 people in Bugesera in the southeastern part of Rwanda .
# GOLD: [['Bugesera', 'Located_In', 'Rwanda']]
# PRED: [['RPF', 'Located_In', 'Bugesera'], ['RPF', 'Origin', 'Rwanda'], ['RPF', 'Organized_In', 'Ruskonia'], ['RPF', 'Origin', 'Rwanda']] Explanation: The Rwandan Patriotic Front (RPF) is an organization based in Rwanda.
#
# ----------------
#
# One of Warner 's lawyers , Andrew Hall of Miami , Fla. , confirmed Tuesday that Warner is trying to settle the case.
# GOLD: [['Andrew Hall', 'Live_In', 'Miami'], ['Andrew Hall', 'Live_In', 'Fla.'], ['Miami', 'Located_In', 'Fla.']]
# PRED: [['Andrew Hall', 'Work_For', 'Miami, Fla.']] Explanation: Andrew Hall is a lawyer for Warner. Andrew Hall is a lawyer for Warner.
#
# ----------------
#
# GRAND RAPIDS , Mich .
# GOLD: [['GRAND RAPIDS', 'Located_In', 'Mich .']]
# PRED: [['Grand RAPIDS', 'Live_In', 'Mich']] Explanation: GRAND RAPIDS, Mich is located in Mich.
#
# ----------------
#
# New Jersey Gov. Thomas Kean , who is leaving office after two terms at the end of this year , was greeted with effuse public praise by his colleagues during the conference.
# GOLD: [['Thomas Kean', 'Live_In', 'New Jersey']]
# PRED: [['Thomas Kean', 'Live_In', New Jersey']] Explanation: Thomas Kean is leaving office after two terms in office, so he is a New Jersey governor. He is a member of the New Jersey General Assembly. Thomas Kean is a member of the New Jersey State Assembly.
#
# ----------------
#
# ` ` The country was starved of resources , ' ' said Marcos Victorica , director of the Institute of Contemporary Studies.
# GOLD: [['Marcos Victorica', 'Work_For', 'Institute of Contemporary Studies.']]
# PRED: [['Marcos Victorica', 'Work_For', 'Institute of Contemporary Studies']] Explanation: Marcos Victorica is the director of the Institute of Contemporary Studies, so it can be concluded that Marcos Victorica Lives In the org. Based In the org.
#
# ----------------
#
# Excess Lira Reportedly Causes Currency Crisis NC1901223094 London Kanal-6 Television in Turkish 1700 GMT 19 Jan 94
# GOLD: [['Kanal-6 Television', 'OrgBased_In', 'London']]
# PRED: [['London Kanal-6 Television', 'Located_In', 'London Kanal-6 Television']] Excess Lira Reportedly Causes Currency Crisis is a newspaper article from the month of January, 2019. It is published in Turkish.
#
# ----------------
#
# " This is the Garrett place where John Wilkes Booth , assassin of Lincoln , was cornered by Union soldiers and killed April 26 , 1865 .
# GOLD: [['John Wilkes Booth', 'Kill', 'Lincoln']]
# PRED: [['John Wilkes Booth', 'Kill', 'Kill'], ['John Wilkes Booth', 'Kill', 'April 26, 1865']] Explanation: John Wilkes Booth was killed on April 26, 1865.
#
# ----------------
#
# BANGKOK , Thailand ( AP )
# GOLD: [['BANGKOK', 'Located_In', 'Thailand']]
# PRED: [['BANGKOK', 'Work_For', 'AP']] Explanation: BANGKOK, Thailand ( AP) is located in Thailand.
#
# ----------------
#
# Joseph Cicippio , 58 , was acting comptroller at the American University of Beirut when he was kidnapped from the campus Sept. 12 , 1986.
# GOLD: [['Joseph Cicippio', 'Work_For', 'American University of Beirut']]
# PRED: [['Joe Cicippio', 'Live_In', 'American University of Beirut']] Explanation: Joseph Cicippio lived in the American University of Beirut, and therefore it can be concluded that Joseph Cicippio Work For the American University of Beirut.
#
# ----------------
#
# The Santa Ana winds _ also called ` ` devil winds ' ' _ are spun off by high pressure over the interior of the country , picking up speed as they move from Southern California 's deserts through mountain passes and roar down on adjacent communities .
# GOLD: [['Santa Ana', 'Located_In', 'Southern California']]
# PRED: [['Santa Ana winds', 'Live_In', 'Santa Ana California'], ['Santa Ana winds', 'Work_For', 'Santa Ana California']] Explanation: The Santa Ana winds are spun off by high pressure over the interior of the country, picking up speed as they move from Southern California's deserts through mountain passes and roar down on adjacent communities.
#
# ----------------
#
# FL2706231194 Havana Radio Reloj Network in Spanish 1402 GMT 27 Jun 94
# GOLD: [['Radio Reloj Network', 'OrgBased_In', 'Havana']]
# PRED: [['Havana Radio Reloj Network', 'Located_In', 'Spain']] Explanation: Havana Radio Reloj Network is based in the country of Spain. Therefore, it can be concluded that Havana Radio Reloj Network is Located In Spain.
#
# ----------------
#
# ` ` Our white paper , market pulp and packaging businesses turned in particularly impressive results in 1988 , ' ' said John A. Georges , International Paper 's chairman and chief executive officer .
# GOLD: [['John A. Georges', 'Work_For', 'International Paper']]
# PRED: [['John A. Georges', 'Work_For', 'International Paper']] Explanation: John A. Georges is the chairman and chief executive officer of International Paper, therefore it can be concluded that John A. Georges works for International Paper.
#
# ----------------
#
# The FA-18 Hornet was on a mission to Pinecastle Electronic Warfare Range in the Ocala National Forest when the bomb tumbled free at 1 : 50 p.m .
# GOLD: [['Pinecastle Electronic Warfare Range', 'Located_In', 'Ocala National Forest']]
# PRED: [['F-18 Hornet', 'Located_In', 'Ocala National Forest']] Explanation: The FA-18 Hornet was on a mission to Pinecastle Electronic Warfare Range in the Ocala National Forest.
#
# ----------------
#
# EAST LANSING , Mich.
# GOLD: [['EAST LANSING', 'Located_In', 'Mich.']]
# PRED: [['EAST LANSING, MI', 'Located_In', 'Mid-West Michigan']] Explanation: The text is about a city named East Lansing. Therefore, the answer is Located In.
#
# ----------------
#
# Born in Athens , Psacharopoulos came to the United States at age 17 to enter Oberlin College , where he studied art history .
# GOLD: [['Oberlin College', 'OrgBased_In', 'United States']]
# PRED: [['Psacharopoulos', 'Live_In', 'Athens']] Explanation: Psacharopoulos is a student at Oberlin College, so it can be concluded that Psacharopoulos is a student at Oberlin College.
#
# ----------------
#
# Two days later , Perry operated on Kennedy 's assassin , Lee Harvey Oswald , who had just been shot by Jack Ruby .
# GOLD: [['Lee Harvey Oswald', 'Kill', 'Kennedy'], ['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# PRED: ['Jack Ruby', 'Live_In', 'Kingston']] Explanation: Lee Harvey Oswald was an assassin for Kennedy, so it can be concluded that Lee Harvey Oswald Lives In Kingston.
#
# ----------------
#
# The prime was accompanied by his wife , Datuk Sri Datin Paduka Dr. Siti Hasmah and the deputy secretary of the Foreign Ministry , Datuk Abdul Halim Ali , during his brief visit to South Africa .
# GOLD: [['Datuk Abdul Halim Ali', 'Work_For', 'Foreign Ministry']]
# PRED: [['Datuk Sri Datin Paduka Dr. Siti Hasmah', 'Live_In', 'South Africa']] Explanation: The prime was accompanied by his wife, Datuk Sri Datin Paduka Dr. Siti Hasmah, and the deputy secretary of the Foreign Ministry, Datuk Abdul Halim Ali, during his brief visit to South Africa.
#
# ----------------
#
# The federal appeals court previously overturned a key provision of Arizona 's death penalty statute in the case of John Harvey Adamson , convicted of murdering reporter Don Bolles .
# GOLD: [['John Harvey Adamson', 'Kill', 'Don Bolles']]
# PRED: [['John Harvey Adamson', 'Kill', 'Don Bolles']] Explanation: John Harvey Adamson was convicted of murdering Don Bolles. Therefore, it can be concluded that John Harvey Adamson killed Don Bolles.
#
# ----------------
#
# The movie 's script remains a secret , but Stone has said Kevin Costner will star as New Orleans prosecutor Jim Garrison , who said that Kennedy was the victim of an FBI and CIA conspiracy and that Lee Harvey Oswald , identified by a presidential commission as the lone assassin , was set up to take the blame. ;
# GOLD: [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# PRED: [['Kevin Costner', 'Work_For', 'FBI']] Explanation: Kevin Costner is the star of the movie, but Stone has said that Jim Garrison will star in the movie. Kevin Costner Lives In The United States
#
# ----------------
#
# Becton Dickinson sells needle containers to doctors and hospitals but may develop a container for home use , said Linda Schmitt , an assistant product manager.
# GOLD: [['Linda Schmitt', 'Work_For', 'Becton Dickinson']]
# PRED: [['Linda Schmitt', 'Work_For', 'Becton Dickinson']] Explanation: Linda Schmitt is the assistant product manager of Becton Dickinson, therefore it can be concluded that Linda Schmitt works for Becton Dickinson.
#
# ----------------
#
# The police files on Kennedy 's shooting could shed new light on persistent questions about whether Sirhan Bishara Sirhan was the only gunman in the shooting .
# GOLD: [['Sirhan Bishara Sirhan', 'Kill', 'Kennedy']]
# PRED: [['Sirhan Bishara Sirhan', 'Live_In', 'Kennedy']] Explanation: The police files on Kennedy's shooting could shed new light on persistent questions about whether Sirhan Bishara Sirhan was the only gunman in the shooting.
#
# ----------------
#
# NC1404123794 Cairo AL-AHALI in Arabic 6 Apr 94 p 6
# GOLD: [['AL-AHALI', 'OrgBased_In', 'Cairo']]
# PRED: [['Cairo AL-AHALI', 'Live_In', 'Cairo']] Explanation: The al-Ahli in Arabic 6 Apr 94 p 6 is a publication of the NC1404123794.
#
# ----------------
#
# In 1936 , rock legend Buddy Holly was born Charles Hardin Holley in Lubbock , Texas .
# GOLD: [['Buddy Holly', 'Live_In', 'Lubbock , Texas'], ['Charles Hardin Holley', 'Live_In', 'Lubbock , Texas']]
# PRED: [['Charles Hardin Holley', 'Live_In', 'Lubbock'], Explanation: Buddy Holly was born in Lubbock, Texas. He Lives In Lubbock, Texas.
#
# ----------------
#
# Belli 's clients have included Jack Ruby , who killed John F. Kennedy assassin Lee Harvey Oswald , and Jim and Tammy Bakker .
# GOLD: [['Jack Ruby', 'Kill', 'Lee Harvey Oswald'], ['Lee Harvey Oswald', 'Kill', 'John F. Kennedy']]
# PRED: [['Jimmy Bakker', 'Kill', 'John F. Kennedy'], ['Jimmy Bakker', 'Kill', 'Lee Harvey Oswald', 'John F. Kennedy', 'Live_In']] Explanation: Jack Ruby is a person that killed Lee Harvey Oswald. Jack Ruby is a person that killed John F. Kennedy.
#
# ----------------
#
# Bosnia 's capital , Sarajevo , is best-known as the site of the assassination in 1914 of Austrian Archduke Franz Ferdinand by young Bosnian nationalist Gavrilo Princip , which was the spark that ignited World War I. No single party appeared likely to win a clear majority in Bosnia 's 240-seat bicameral parliament .
# GOLD: [['Sarajevo', 'Located_In', 'Bosnia'], ['Gavrilo Princip', 'Kill', 'Austrian Archduke Franz Ferdinand']]
# PRED: [['Gavrilo Princip', 'Live_In', 'Bosnia']] Explanation: Gavrilo Princip is a Bosnian nationalist, therefore, it can be concluded that Gavrilo Princip Lives In Bosnia.
#
# ----------------
#
# Walesa said Solidarity wants to avoid unrest .
# GOLD: [['Walesa', 'Work_For', 'Solidarity']]
# PRED: [['Standards', 'Work_For', 'Solvium']] Explanation: Walesa is a person who speaks for Solidarity.
#
# ----------------
#
# In 1817 , naturalist-author Henry David Thoreau was born in Concord , Mass .
# GOLD: [['Henry David Thoreau', 'Live_In', 'Concord , Mass']]
# PRED: [['Henry David Thoreau', 'Live_In', 'Concord, Mass']] Explanation: Henry David Thoreau was a naturalist born in Concord, Mass.
#
# ----------------
#
# The nine sentences noting the spot where Dallas was settled are followed by this : ` ` On Nov. 22 , 1963 , the building gained national notoriety when Lee Harvey Oswald allegedly shot and killed President John F. Kennedy from a sixth floor window as the presidential motorcade passed the site. ' '
# GOLD: [['Lee Harvey Oswald', 'Kill', 'President John F. Kennedy']]
# PRED: [['Lou Harvey Oswald', 'Live_In', 'Dallas']] Explanation: On Nov. 22, 1963, the building gained national notoriety when Lee Harvey Oswald allegedly shot and killed President John F. Kennedy from a sixth floor window as the presidential motorcade passed the site.
#
# ----------------
#
# It almost makes me want to laugh. ( Minoli ) Why ? ( Fini ) Bossi is a very strange character and his extreme envy has been demonstrated. ( passage omitted ) He tried to get votes from the south , those votes which he now despises so much , but the south sent him back to the valleys. ( Minoli ) You said that Bossi reminded you of Hitler trapped in his Berlin bunker , a man with delusions of grandeur and a tendency towards suicide .
# GOLD: [['Hitler', 'Live_In', 'Berlin']]
# PRED: [['Minoli', 'Bossi', 'Hedder', 'Located_In']] Explanation: Minoli is a character in the text. Bossi is a character in the text. Bossi is a character in the text.
#
# ----------------
#
# ` ` One thing I have learned over the past 17 months is that the truth is hard to find , and it remains so , ' ' said Mrs. Higgins , 37 , who is a major inthe Marine Corps and works at the Pentagon as a public information officer.
# GOLD: [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Pentagon']]
# PRED: [['Mrs. Higgins', 'Work_For', 'Marine Corps'] Explanation: Mrs. Higgins is a major in the Marine Corps and works for the Pentagon.
#
# ----------------
#
# Sam Kadet of the corporate law firm of Skadden , Arps said Popeyes could give Church 's notice on Thursday that it planned to proceed with the takeover attempt and deliver the information to Church 's after five business days .
# GOLD: [['Sam Kadet', 'Work_For', 'Skadden , Arps']]
# PRED: [['Sam Kadet', 'Work_For', 'Skadden, Arps']] Explanation: Sam Kadet is a lawyer at Skadden, Arps. He works for Skadden, Arps. He is not associated with Church.
#
# ----------------
#
# Yisrael Tal , one of the top military strategists in Israel , says the Arabs have reached a strategic balance with Israel through their acquisition of ground-to-ground missiles .
# GOLD: [['Yisrael Tal', 'Live_In', 'Israel'], ['Yisrael Tal', 'Live_In', 'Israel']]
# PRED: [['Yisrael Tal', 'Live_In', 'Israel']] Explanation: Yisrael Tal is a top military strategist in Israel. Therefore, the answer is Israel.
#
# ----------------
#
# Some people in the United States are saying that Clinton " gave away " $12 billion to Russia -- this is the amount it is proposed to pay for uranium destined for U.S. nuclear electric power stations , which will be obtained from our nuclear warheads .
# GOLD: [['Clinton', 'Live_In', 'United States'], ['Clinton', 'Live_In', 'U.S.']]
# PRED: [['Clinton', 'Work_For', 'United States']] Explanation: People in the United States are people who work for the United States. Therefore, it can be concluded that Clinton worked for the United States.
#
# ----------------
#
# Guy M. Struve , the New York attorney representing Church 's , said he was disappointed and did not know when the chain would decide whether to appeal Thursday 's ruling .
# GOLD: [['Guy M. Struve', 'Live_In', 'New York'], ['Guy M. Struve', 'Work_For', "Church 's"]]
# PRED: [['Guy M. Struve', 'Work_For', 'Church's']] Explanation: Guy M. Struve is an attorney for Church's, so it can be concluded that Guy M. Struve Works For Church's.
#
# ----------------
#
# A golden future seemed assured when , at 25 , Ogdon shared top place with Soviet pianist Vladimir Ashkenazy in the piano section of the 1962 Moscow Tchaikovsky International Competition for young musicians.
# GOLD: [['Vladimir Ashkenazy', 'Live_In', 'Soviet']]
# PRED: [['Ogdon', 'Live_In', 'Moscow']] Explanation: Ogdon shared a golden future with Vladimir Ashkenazy, who is a Soviet pianist, at the 1962 Moscow Tchaikovsky International Competition for young musicians.
#
# ----------------
#
# Illinois born Charlton Heston was a 27-year-old actor from Broadway and television when he arrived in Hollywood for a five-picture contract with Hal Wallis .
# GOLD: [['Charlton Heston', 'Live_In', 'Illinois']]
# PRED: [['Charlton Heston', 'Live_In', 'Illinois']] Explanation: Charlton Heston is an actor from Illinois. He arrived in Hollywood for a five-picture contract with Hal Wallis.
#
# ----------------
#
# The justices heard 60 minutes of arguments Wednesday on whether they will allow the execution of Johnny Paul Penry , 32 , a convicted rapist-murderer sentenced to die in Texas .
# GOLD: [['Johnny Paul Penry', 'Live_In', 'Texas']]
# ...
# GOLD: [['TASS', 'OrgBased_In', 'Moscow']]
# PRED: [['Moscow', 'Destic', 'Russia']] Explanation: Moscow April 25 TASS is located in Russia.
#
# ----------------
#
# Police arrested 10 Spanish Basque militants , including Jose Antonio Urutigoechea , considered by Madrid to be a top leader of the Spanish Basque separatist organization ETA , authorities said today .
# GOLD: [['Jose Antonio Urutigoechea', 'Work_For', 'ETA']]
# PRED: [['Jose Antonio Urutigoechea', 'Work_For','Madrid']] Explanation: Jose Antonio Urutigoechea is a leader of ETA.
#
# ----------------
#
# The Warren Commission concluded that Oswald , acting alone , fired the shots that killed Kennedy and wounded John Connally , then the Texas governor .
# GOLD: [['Oswald', 'Kill', 'Kennedy']]
# PRED: [['Oswald', 'Kill', 'Knighted', 'John Connally']] Explanation: The Warren Commission concluded that Oswald killed Kennedy and John Connally was the Texas governor. Oswald, therefore, killed Kennedy.
#
# ----------------
#
# The advisory committee voted 7-1 to recommend that the drug remain a prescription ingredient , said Susan Cruzan , an FDA spokeswoman.
# GOLD: [['Susan Cruzan', 'Work_For', 'FDA']]
# PRED: [['Susan Cruzan', 'Work_For', 'FDA']] Explanation: Susan Cruzan is a spokeswoman for the FDA, therefore it can be concluded that Susan Cruzan works for the FDA.
#
# ----------------
#
# ` ` It 's been a nightmare , ' ' said Shelley Yeager , director of the Clara Barton camp at Oxford in central Massachusetts.
# GOLD: [['Oxford', 'Located_In', 'Massachusetts.']]
# PRED: [['Sheley Yeager', 'Live_In', 'Oxford']] Explanation: Shelley Yeager is the director of the Clara Barton camp in Oxford, so it can be concluded that Yeager Lives in Oxford.
#
# ----------------
#
# And William McKinley 's assassin Leon Czolgosz croons " The Ballad of Czolgosz " from the electric chair .
# GOLD: [['Leon Czolgosz', 'Kill', 'William McKinley']]
# PRED: [['Leon Czolgosz', 'Live_In', 'William McKinley']] Explanation: Leon Czolgosz is the assassin of William McKinley. Leon Czolgosz is a person.
#
# ----------------
#
# Yeltsin Orders Audit of Ostankino Finances MK1401103094 Moscow MOSKOVSKIY KOMSOMOLETS in Russian 14 Jan 94 p 1
# GOLD: [['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']]
# PRED: [['Moscow', 'Located_In', 'Moscow']] Explanation: The MOSKOVSKIY KOMSOMOLETT's Located In MOSCOVSKIY KOMSOMOLETT is the same as the MOSKOVSKIY KOMSOMOLETT in Russian.
#
# ----------------
#
# ` ` We are constantly getting confirmation that the U.S. economy is no longer in a boom phase , and that interest rates are falling , ' ' said a dealer at a U.S. bank in Frankfurt , West Germany.
# GOLD: [['Frankfurt', 'Located_In', 'West Germany.']]
# PRED: [['A', 'Located_In', 'West Germany']] Explanation: A dealer at a U.S. bank in Frankfurt, West Germany is a member of the U.S. bank.
#
# ----------------
#
# In 1969 , Sirhan Sirhan was convicted of assassinating U.S. Sen. Robert F. Kennedy .
# GOLD: [['Sirhan Sirhan', 'Kill', 'U.S. Sen. Robert F. Kennedy']]
# PRED: [['Sirhan Sirhan', 'Live_In', 'U.S.'], ['Sirhan Sirhan', 'Work_For', 'U.S.'], ['Sirhan Sirhan', 'Kill', 'U.S.'], ['Sirhan Sirhan', 'Kather', 'Kill', 'Sen. Robert F. Kennedy']] Explanation: Sirhan Sirhan was convicted of killing U.S. Sen. Robert F. Kennedy.
#
# ----------------
#
# Jesse Jackson easily won the Democratic precinct caucuses Saturday in his native South Carolina , while Sen. Bob Dole went on Illinois television for a half-hour plea for Republican votes in a state where he said he is the underdog .
# GOLD: [['Jesse Jackson', 'Live_In', 'South Carolina']]
# PRED: [['Jesse Jackson', 'Live_In', 'South Carolina']] Explanation: Jesse Jackson easily won the Democratic precinct caucuses Saturday in his native South Carolina, while Sen. Bob Dole went on Illinois television for a half- hour plea for Republican votes in a state where he said he is underdog.
#
# ----------------
#
# MEXICO CITY ( AP )
# GOLD: [['AP', 'OrgBased_In', 'MEXICO CITY']]
# PRED: [['MEXICO CITY', 'Live_In', 'AP']] Explanation: ['AP', 'OrgBased_In', 'Mexico City'] can be used to denote that AP is an organization based in Mexico City.
#
# ----------------
#
# Temperatures around the nation at 2 a.m. EST ranged from 2 degrees at Jackson , Wyo. , and Gunnison , Colo. , to 89 degrees at McAllen , Texas .
# GOLD: [['Jackson', 'Located_In', 'Wyo.'], ['Gunnison', 'Located_In', 'Colo.'], ['McAllen', 'Located_In', 'Texas']]
# PRED: [['Jackson', 'Colo.', 'Gunnison']] Explanation: Jackson is located in Wyo., Colo., and McAllen is located in Texas, USA.
#
# ----------------
#
# ` ` We certainly believe it 's a prudent measure to go out and check to make sure there 's nothing wrong with the fleet , ' ' Boeing Commercial Airplanes spokesman Craig Martin said Wednesday in Seattle .
# GOLD: [['Craig Martin', 'Work_For', 'Boeing Commercial Airplanes']]
# PRED: [['Craig Martin', 'Work_For', 'Boeing Commercial Airplanes']] Explanation: Craig Martin is a spokesman for Boeing Commercial Airplanes, therefore it can be concluded that Craig Martin works for Boeing Commercial Airplanes.
#
# ----------------
#
# As Rochester teacher union leader Adam Urbanski put it : ` ` We have set the table ; we have not served the meal yet. ' '
# GOLD: [['Adam Urbanski', 'Live_In', 'Rochester']]
# PRED: [['Adam Urbanski', 'Live_In', 'Rochester']] Explanation: Adam Urbanski is a union leader whose name is Adam Urbanski. Adam Urbanski Lives In Rochester, which is located in the state of New York.
#
# ----------------
#
# Tokyo MAINICHI SHIMBUN
# GOLD: [['MAINICHI SHIMBUN', 'OrgBased_In', 'Tokyo']]
# PRED: [['Tokyo', 'Live_In', 'Tokyo']] Explanation: Tokyo MAINICHI SHIMBUN is a city in the city of Tokyo.
#
# ----------------
#
# If the elections had been held during the last 10 days of May , that is , after the debate , Fernandez de Cevallos would reportedly be the next president of Mexico with 33.2 percent of the vote .
# GOLD: [['Fernandez de Cevallos', 'Live_In', 'Mexico']]
# PRED: [['Fernandez de Cevallos', 'Live_In', 'Mexico']] Explanation: If the elections were held during the last 10 days of May, Fernandez de Cevallos would reportedly be the next president of Mexico.
#
# ----------------
#
# Authorities say Oswald opened fire from a sixth-floor window there into Kennedy 's motorcade .
# GOLD: [['Oswald', 'Kill', 'Kennedy']]
# PRED: [['Oswald', 'Work_For', 'Kill']] Explanation: Oswald opened fire from a sixth-floor window into Kennedy's motorcade.
#
# ----------------
#
# Meanwhile , the historical society in Beaumont , Texas , Richardson 's hometown , plans to raise two statues on Feb. 3 _ one of Buddy Holly , Richardson and Valens , and a second of the Big Bopper alone .
# GOLD: [['Richardson', 'Live_In', 'Beaumont , Texas']]
# PRED: [['Richardson', 'Live_In', 'Beaumont, Texas']] Explanation: Richardson's hometown is Beaumont, Texas, which is located in the United States.
#
# ----------------
#
# At a briefing at NRC headquarters in nearby Rockville , Md. , Bernero said the volcanic cones in the area of Yucca Mountain have been a cause of concern for NRC experts.
# GOLD: [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.'], ['Bernero', 'Work_For', 'NRC'], ['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.']]
# PRED: [['Bernero', 'Located_In', 'Rockville, Md.']] Explanation: Bernero Lives In Rockville, Md., while NRC is located in Rockville, Md.
#
# ----------------
#
# ( Text ) Saint-Gall , Switzerland , Feb 2 ( AFP ) -- The wreck of a twin-engine aircraft has been found 160 metres below the surface of Lake Constance , Swiss police said Tuesday ( 1 February ) .
# GOLD: [['Saint-Gall', 'Located_In', 'Switzerland'], ['AFP', 'OrgBased_In', 'Saint-Gall'], ['AFP', 'OrgBased_In', 'Switzerland']]
# PRED: [['St.-Gall', 'Located_In', 'Switzerland']] Explanation: The wreck of a twin-engine aircraft has been found 160 metres below the surface of Lake Constance, Switzerland.
#
# ----------------
#
# According to the communique , clashes are continuing mainly in the Rancho Nuevo area at the military base in the southern Chiapas State .
# GOLD: [['Rancho Nuevo', 'Located_In', 'Chiapas State']]
# PRED: [['Rando Nuevo', 'Located_In', 'Chiapas State']] Explanation: According to the communique, the clashes are mainly in the Rancho Nuevo area at the military base in the southern Chiapas State.
#
# ----------------
#
# Dallas police arrested Oswald there on Nov. 22 , 1963 , after the assassination of President John F. Kennedy .
# GOLD: [['Oswald', 'Kill', 'President John F. Kennedy']]
# PRED: [['Oswald', 'Live_In', 'Dallas']] Explanation: Oswald was arrested in Dallas by Dallas Police after the assassination of President John F. Kennedy.
#
# ----------------
#
# In Washington state , near the Canadian border , firefighters hoped to contain an 850-acre fire by tonight , said Greg Thayer of the Forest Service.
# GOLD: [['Greg Thayer', 'Work_For', 'Forest Service.']]
# PRED: [['George Thayer', 'Work_For', 'Forest Service']] Explanation: The Canadian border is located in Washington state, which is a part of the United States. The United States is a country located in the Pacific Ocean. Therefore, the United States is a country based in the Pacific Ocean.
#
# ----------------
#
# In an " electoral communique " signed by CNTP Secretary Luis Cobos R. , the organization said it hopes that with this decision " we will achieve the return of the Torrijist forces to power to stimulate the process of national liberation . "
# GOLD: [['Luis Cobos R.', 'Work_For', 'CNTP']]
# PRED: [['CNTP', 'OrgBased_In', 'Luis Cobos R']] Explanation: CNTP Secretary Luis Cobos R. is an organization based in the United States.
#
# ----------------
#
# In it , actor Edwin Booth tells us his version of his life story , in which he and not his brother John Wilkes shoots Abraham Lincoln at Ford 's Theater .
# GOLD: [['John Wilkes', 'Kill', 'Abraham Lincoln']]
# PRED: [['Edwin Booth', 'Work_For', 'John Wilkes']] Explanation: In it, Edwin Booth tells us his version of his life story, which includes Abraham Lincoln, in which Edwin Booth and John Wilkes shoot Lincoln at Ford's Theater.
#
# ----------------
#
# In 1801 , Mormon leader Brigham Young was born in Whitingham , Vt .
# GOLD: [['Brigham Young', 'Live_In', 'Whitingham , Vt']]
# PRED: [['Brigham Young', 'Live_In', 'Whitingham, Vt.']] Explanation: Brigham Young was born in Whitingham, Vt., so it can be concluded that Brigham Young Lived In Whitingham, Vt.
#
# ----------------
#
# The Warren Commission concluded that Lee Harvey Oswald , acting alone , fired the shots that killed Kennedy and wounded John Connally , then the Texas governor , on Nov. 22 , 1963 in Dallas .
# GOLD: [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# PRED: [['Lee Harvey Oswald', 'Kill', 'Karen']] Explanation: Lee Harvey Oswald killed Kennedy and wounded John Connally in Dallas on Nov. 22, 1963. Therefore, the answer is 1.
#
# ----------------
#
# The spilled fuel covered an area two miles long and nearly a half-mile wide , said Whitefish City Attorney Tom Muri.
# GOLD: [['Tom Muri.', 'Live_In', 'Whitefish City']]
# PRED: [['Tom Muri', 'Live_In', 'Whitefish City']] Explanation: Tom Muri lives in Whitefish City, not Muri's home town.
#
# ----------------
#
# In California 's Sierra Nevada foothills , firefighters today declared they had contained a fire that blackened 11 , 700 acres of brush and grassland and destroyed seven homes.
# GOLD: [['Sierra Nevada', 'Located_In', 'California']]
# PRED: [['Sierra Nevada', 'Foxhill', 'Sierra Nevada']] Explanation: The fire blackened 11 acres of brush and grassland in California, and destroyed seven homes.
#
# ----------------
#
# " I was hearing the same story , " says James Hackett , an executive with Titan Systems and one of the leading missile experts in the U.S .
# GOLD: [['James Hackett', 'Work_For', 'Titan Systems'], ['James Hackett', 'Live_In', 'U.S .']]
# PRED: [['James Hackett', 'Live_In', 'U.S.'], ['James Hackett', 'Work_For', 'Titan Systems']] Explanation: James Hackett is an executive with Titan Systems.
#
# ----------------
#
# The quake leveled much of Leninakan , Armenia 's second-largest city 10 miles east of the Turkish border and left thousands homeless .
# GOLD: [['Leninakan', 'Located_In', 'Armenia']]
# PRED: [['Leninakan', 'Located_In', 'Armenia']] Explanation: The quake leveled much of Leninakan, which is a city in Armenia, 10 miles east of the Turkish border.
#
# ----------------
#
# Pittsburgh-Corning Corp. of Pittsburgh ;
# GOLD: [['Pittsburgh-Corning Corp.', 'OrgBased_In', 'Pittsburgh']]
# PRED: [['Pittsburg-Corning Corp. of Pittsburgh', 'Live_In', 'Pittsburg']] Explanation: Pittsburgh-Corning Corp. of Pittsburgh is an organization based in Pittsburgh, which is located in the city of Pittsburgh.
#
# ----------------
#
# Barrett is a member of the Illinois Commerce Commission , and Marshall is a lawyer and former legislative aide to Patrick.
# GOLD: [['Barrett', 'Work_For', 'Illinois Commerce Commission']]
# PRED: [['Marshall', 'Work_For', 'Illinois Commerce Commission']] Explanation: Marshall is a lawyer and Patrick is a legislative aide.
#
# ----------------
#
# During my recent tour , I met with Sultan Qabus Bin-Sa 'id of Oman .
# GOLD: [["Sultan Qabus Bin-Sa 'id", 'Live_In', 'Oman']]
# PRED: [['I', 'Live_In', 'Oman']] Explanation: I met Sultan Qabus Bin-Sa 'id of Oman, so I met with Sultan Qabus Bin-Sa 'id of Oman.
#
# ----------------
#
# Ten years ago : James Earl Ray , convicted of assassinating Dr. Martin Luther King Jr. in 1968 , repeated his assertion at a Capitol Hill hearing that he did not commit the crime , saying he 'd been set up to take the blame by a mysterious man called Raoul .
# GOLD: [['James Earl Ray', 'Kill', 'Dr. Martin Luther King Jr.']]
# PRED: [['James Earl Ray', 'Live_In', 'Montana']] Explanation: James Earl Ray was convicted of assassinating Dr. Martin Luther King Jr., therefore it can be concluded that James Earl Ray Lived In Monte Carlo.
#
# ----------------
#
# They will also be cleaning the car Oswald drove on the day Kennedy was shot and the ambulance that took Oswald to hospital after he was shot by Jack Ruby .
# GOLD: [['Jack Ruby', 'Kill', 'Oswald']]
# PRED: [['Jack Ruby', 'Live_In', 'Jack Ruby']] Explanation: They will also be cleaning the car Oswald drove on the day Kennedy was shot and the ambulance that took Oswald to hospital after he was shot by Jack Ruby.
#
# ----------------
#
# Widespread street flooding was reported throughout Brazoria , Fort Bend , Galveston and southern Harris Counties in southeast Texas.
# GOLD: [['Brazoria', 'Located_In', 'Texas.'], ['Fort Bend', 'Located_In', 'Texas.'], ['Galveston', 'Located_In', 'Texas.'], ['Harris Counties', 'Located_In', 'Texas.']]
# PRED: [['Fort Bend', 'Located_In', 'Tennessee']] Explanation: The floods were reported in Brazoria, Fort Bend, Galveston and southern Harris Counties, Texas.
#
# ----------------
#
# LD2804174994 Moscow INTERFAX in English 1601 GMT 28 Apr 94
# GOLD: [['INTERFAX', 'OrgBased_In', 'Moscow']]
# PRED: [['St. Petersburg', 'Live_In', 'St. Petersburg']]] Explanation: LD2804174994 Moscow INTERFAX in English 1601 GMT 28 Apr 94 is a publication of LD2804174994 Moscow.
#
# ----------------
#
# Navy sources said the Coral Sea , on duty with the 6th Fleet in the Mediterranean , left ` ` a few hours ' ' ahead of its scheduled departure.
# GOLD: [['6th Fleet', 'OrgBased_In', 'Mediterranean']]
# PRED: [['Coral Sea', 'OrgBased_In', 'Mediterranean']] Explanation: The 6th Fleet is an organization based in the Mediterranean. The Coral Sea is on duty with the 6th Fleet. Therefore, the 6th Fleet is the organization based in the Mediterranean.
#
# ----------------
#
# It is one of many deep below the arid surface , fed by underground channels that carry rainwater from the Najd plateau in northern Saudi Arabia to the west.
# GOLD: [['Najd plateau', 'Located_In', 'Saudi Arabia']]
# PRED: [['Najd', 'Located_In', 'Saudi Arabia']] Explanation: It is one of many deep below the arid surface, fed by underground channels that carry rainwater from the Najd plateau in northern Saudi Arabia to the west.
#
# ----------------

# %%
df = pd.DataFrame({"text": ip, "gold_labels": gold, "generated": generated})
#df.to_csv("conll_fewshot_flan_generated.csv", index=False)
print (df.shape)
# Out:
# (231, 3)

# %%
invalid_count = 0
total_count = 0
valid_parsed = 0
for ix, row in df.iterrows():
    # print ("GOLD: " + row["gold_labels"])
    try:
        pred = ast.literal_eval(row["generated"])
        total_count += len(pred)
        valid_parsed += 1
        for relation in pred:
            if relation[1] not in valid:
                print (row["text"])
                print ("PRED: " + relation)
                print ("\n----------------\n")
    except:
        print ("NON CONFORMING PRED: ", row["generated"])
        print ("\n----------------\n")
# Out:
# NON CONFORMING PRED:  [['Kevin O'Brien', 'Work_For', 'Palace of Fine Arts'], ['Kevin O'Brien', 'Work_For', 'San Francisco']]
#
# ----------------
#
# The Warren Commission found Oswald acted alone in killing Kennedy .
# NON CONFORMING PRED:  [['Oswald', 'Acted_Alone', 'Kill'], ['Oswald', 'Live_In', 'Williams County'], ['Oswald', 'Live_In', 'Williams County']]
#
# ----------------
#
# Martin Luther King III , a son of the slain civil rights leader , said the execution of King assassin James Earl Ray ` ` would not bring my father back. ' '
# NON CONFORMING PRED:  [['Martin Luther King III', 'Son', 'Martin Luther King III']]
#
# ----------------
#
# ` ` With South Carolina being Jesse Jackson 's home state , there was a very strong incentive in the black community. ' '
# NON CONFORMING PRED:  [['Jesse Jackson', 'Home_State', 'South Carolina']]
#
# ----------------
#
# You 'll pass through Rolling Fork , where Muddy Waters was born , close to Greenville , home of Nelson Street 's funky strip of blues clubs , and into Clarksdale , at the intersection of Highway 61 and another major road in blues lore , U.S. Highway 49. ;
# NON CONFORMING PRED:  [['Muddy Waters', 'Live In', 'Rolling Fork']]
#
# ----------------
#
# In 1865 , four people were hanged in Washington , D.C. , after being convicted of conspiring with John Wilkes Booth in the assassination of President Lincoln .
# NON CONFORMING PRED:  [['Washington', 'D.C.']]
#
# ----------------
#
# River North 's nouvelle sensibilities also might be offended by the Ranch 's menu , which features items such as the ` ` Jesse James Steak ( A Steal ! ) , ' ' and the occasional ornery patron .
# NON CONFORMING PRED:  [['Jesse James Steak', 'A Steak!', 'Offended']]
#
# ----------------
#
# It was filmed on location in Tokyo and Kyoto and is a co-production of Children 's Television Worship and NHK network in Japan .
# NON CONFORMING PRED:  [['Tokyo', 'Yoyogi', 'OrgBasedIn', 'Japan']]
#
# ----------------
#
# ( Text ) The Rwandan Patriotic Front ( RPF ) has rescued 2 , 000 people in Bugesera in the southeastern part of Rwanda .
# NON CONFORMING PRED:  [['RPF', 'Located_In', 'Bugesera'], ['RPF', 'Origin', 'Rwanda'], ['RPF', 'Organized_In', 'Ruskonia'], ['RPF', 'Origin', 'Rwanda']]
#
# ----------------
#
# NON CONFORMING PRED:  [['Thomas Kean', 'Live_In', New Jersey']]
#
# ----------------
#
# NON CONFORMING PRED:  [['London Kanal-6 Television', 'Located_In', 'London Kanal-6 Television']] Excess Lira Reportedly Causes Currency Crisis is a newspaper article from the month of January, 2019. It is published in Turkish.
#
# ----------------
#
# NON CONFORMING PRED:  ['Jack Ruby', 'Live_In', 'Kingston']]
#
# ----------------
#
# NON CONFORMING PRED:  [['Charles Hardin Holley', 'Live_In', 'Lubbock'],
#
# ----------------
#
# It almost makes me want to laugh. ( Minoli ) Why ? ( Fini ) Bossi is a very strange character and his extreme envy has been demonstrated. ( passage omitted ) He tried to get votes from the south , those votes which he now despises so much , but the south sent him back to the valleys. ( Minoli ) You said that Bossi reminded you of Hitler trapped in his Berlin bunker , a man with delusions of grandeur and a tendency towards suicide .
# NON CONFORMING PRED:  [['Minoli', 'Bossi', 'Hedder', 'Located_In']]
#
# ----------------
#
# NON CONFORMING PRED:  [['Mrs. Higgins', 'Work_For', 'Marine Corps']
#
# ----------------
#
# NON CONFORMING PRED:  [['Guy M. Struve', 'Work_For', 'Church's']]
#
# ----------------
#
# Prime Minister Felipe Gonzalez of Spain told reporters , ` ` The police actions and the arrests are of great importance to Spanish society on such a major matter as the battle against terrorism. ' '
# NON CONFORMING PRED:  [['Federal', 'Federation', 'Spain']]
#
# ----------------
#
# NON CONFORMING PRED:  [['MOSTHOW_TO_HELP_LAZUTKIN_(FOLLOWED_BY OTHER_NUMBER)]]
#
# ----------------
#
# NON CONFORMING PRED:  1. Kill 2. Sirhan killed Kennedy 3. Located In 4. Live_In 5.
#
# ----------------
#
# NON CONFORMING PRED:  [['Brutus', 'Live_In', 'Casius']] Entity A was killed by a group of nobles, therefore it can be concluded that Entity A Lives In Caesar.
#
# ----------------
#
# NON CONFORMING PRED:  [['Dr. Lee DeForest', 'Live_In', 'Chair Bluffs, Iowa']]]
#
# ----------------
#
# The Internal Revenue Service and Manufacturers Hanover Trust Co. of New York , two of the largest creditors in the Herbert Hunt bankruptcy , said they will file a repayment plan by Friday.
# NON CONFORMING PRED:  [['Internal Revenue Service', 'Henry Hunt']]
#
# ----------------
#
# Announces Offer to End Strike PA0302025694 Panama City ACAN in Spanish 2153 GMT 2 Feb 94
# NON CONFORMING PRED:  [['Anthony', 'Acan', 'OrgBased_In', 'Panamaca City']]
#
# ----------------
#
# The six men were found under the rubble in the basement of a nine-story apartment building which had collapsed on them , the official Soviet news agency said in a report from Yerevan , the capital of Armenia .
# NON CONFORMING PRED:  [['Yrevan', 'Olympic', 'Estonia', 'OrgBased_In', 'Soviets']]
#
# ----------------
#
# NON CONFORMING PRED:  [['James Earl Ray', 'Kill', 'King']]]
#
# ----------------
#
# Such theories , which are not alone in the international press , find support in another agreement that was also signed in Geneva -- which the Croatian opposition ostensibly did not notice , to the great surprise and almost astonishment of all , and consequently did not comment on , although the integral text was published in Croatian newspapers -- the agreement signed between Mile Akmadzic , on behalf of the Croatian Republic of Herceg-Bosna , and Nikola Koljevic , on behalf of the Serbian Republic , in which both sides emphasize that " there are no disputed issues between them that cannot be solved in a peaceful way . "
# NON CONFORMING PRED:  [['mile akmadzic', 'live_in', 'Croatian Republic of Herceg-Bosna']]
#
# ----------------
#
# NON CONFORMING PRED:  [['Van Anleu', 'Work_For', 'National Congress']
#
# ----------------
#
# NON CONFORMING PRED:  [[['Eduardo Baltin', 'Live_In', 'Black Sea Fleet']]]
#
# ----------------
#
# A chart used to decipher the code was found among Booth 's effects after he was shot by Union soldiers 11 days after the assassination of Lincoln .
# NON CONFORMING PRED:  [['Lincoln', 'Kit', 'Sir William Booth']]
#
# ----------------
#
# Moscow MOSKOVSKIY KOMSOMOLETS
# NON CONFORMING PRED:  [['Moscove', 'ORGBased_In', 'Moscove']]
#
# ----------------
#
# ( Text ) In an interview with Interfax the chief of Belarus 's Security Committee , Eduard Shirkovskiy , has dismissed rumors that the copies of the files relating to Lee Harvey Oswald , who was charged with having assassinated President John Kennedy , will be handed to President Bill Clinton during his visit to Minsk .
# NON CONFORMING PRED:  [['Explanation', 'Explanation', 'Interfax']]
#
# ----------------
#
# ( Text ) Moscow April 25 TASS -- Preliminary marine pollution measurements taken from the sites of radioactive waste dumping by the former Soviet Union and Japan in the Sea of Japan did not reveal any Caesium-137 radioactive level fluctuations .
# NON CONFORMING PRED:  [['Moscow', 'Destic', 'Russia']]
#
# ----------------
#
# In 1969 , Sirhan Sirhan was convicted of assassinating U.S. Sen. Robert F. Kennedy .
# NON CONFORMING PRED:  [['Sirhan Sirhan', 'Live_In', 'U.S.'], ['Sirhan Sirhan', 'Work_For', 'U.S.'], ['Sirhan Sirhan', 'Kill', 'U.S.'], ['Sirhan Sirhan', 'Kather', 'Kill', 'Sen. Robert F. Kennedy']]
#
# ----------------
#
# Temperatures around the nation at 2 a.m. EST ranged from 2 degrees at Jackson , Wyo. , and Gunnison , Colo. , to 89 degrees at McAllen , Texas .
# NON CONFORMING PRED:  [['Jackson', 'Colo.', 'Gunnison']]
#
# ----------------
#
# In California 's Sierra Nevada foothills , firefighters today declared they had contained a fire that blackened 11 , 700 acres of brush and grassland and destroyed seven homes.
# NON CONFORMING PRED:  [['Sierra Nevada', 'Foxhill', 'Sierra Nevada']]
#
# ----------------
#
# NON CONFORMING PRED:  [['St. Petersburg', 'Live_In', 'St. Petersburg']]]
#
# ----------------

# %%
print (invalid_count, total_count, valid_parsed)
# Out:
# 0 244 217

# %%
s1 = "It is my sincere hope that we will reignite our united purpose , '' Senator Mitch McConnell of Kentucky , the Republican whip , said on the Senate floor before the ceremony ."

# %%
text = [prefix + s1]
print (text[0])
# Out:
#  Find the following relations in the TEXT below and provide brief explanation:
#
# TEXT: It is my sincere hope that we will reignite our united purpose , '' Senator Mitch McConnell of Kentucky , the Republican whip , said on the Senate floor before the ceremony .

# %%
torch.cuda.empty_cache()
inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True).input_ids

# %%
len(inputs)
# Out:
# 1

# %%
outputs = model.generate(inputs, max_new_tokens=256, do_sample=False)

# %%
out = tokenizer.decode(outputs[0], skip_special_tokens=True)
print (out)
# Out:
# [['Mitch McConnell', 'RELATIVE', 'Republican']] Explanations: Senator Mitch McConnell is the Republican whip of the Senate; he is the speaker of the Senate;

# %%
out = out.split(" Explanation")[0]

# %%
import ast

# %%
print (ast.literal_eval(out))
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────╮
# │  <unknown>:1                                                                                     │
# │ [['Sultan Qabus Bin-Sa'id', 'Work_For', 'Oman']]                                                 │
# │                        ▲                                                                         │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# SyntaxError: invalid syntax
