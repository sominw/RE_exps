# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset
import json
from tqdm import tqdm
from transformers import DataCollatorForSeq2Seq
import torch
import os
import evaluate
import numpy as np
import glob
import ast
import re
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 warnings.filterwarnings("ignore")
#       4 import pandas as pd
# ----> 5 from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, Seq2SeqTrainingArguments, Seq2SeqTrainer
#       6 from datasets import load_dataset
#       7 import json
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/transformers/utils/import_utils.py:1100, in _LazyModule.__getattr__(self, name)
#    1098     value = self._get_module(name)
#    1099 elif name in self._class_to_module.keys():
# -> 1100     module = self._get_module(self._class_to_module[name])
#    1101     value = getattr(module, name)
#    1102 else:
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/transformers/utils/import_utils.py:1110, in _LazyModule._get_module(self, module_name)
#    1108 def _get_module(self, module_name: str):
#    1109     try:
# -> 1110         return importlib.import_module("." + module_name, self.__name__)
#    1111     except Exception as e:
#    1112         raise RuntimeError(
#    1113             f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1114             f" traceback):\n{e}"
#    1115         ) from e
#
# File ~/.conda/envs/py39/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/transformers/trainer_seq2seq.py:22
#      19 from torch.utils.data import Dataset
#      21 from .deepspeed import is_deepspeed_zero3_enabled
# ---> 22 from .trainer import Trainer
#      23 from .trainer_utils import PredictionOutput
#      24 from .utils import logging
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/transformers/trainer.py:168
#     165     from apex import amp
#     167 if is_datasets_available():
# --> 168     import datasets
#     170 if is_torch_tpu_available(check_device=False):
#     171     import torch_xla.core.xla_model as xm
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/datasets/__init__.py:43
#      40 del pyarrow
#      41 del version
# ---> 43 from .arrow_dataset import Dataset
#      44 from .arrow_reader import ReadInstruction
#      45 from .builder import ArrowBasedBuilder, BeamBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/datasets/arrow_dataset.py:65
#      62 from tqdm.auto import tqdm
#      64 from . import config
# ---> 65 from .arrow_reader import ArrowReader
#      66 from .arrow_writer import ArrowWriter, OptimizedTypedSequence
#      67 from .download.download_config import DownloadConfig
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/datasets/arrow_reader.py:30
#      27 import pyarrow as pa
#      28 import pyarrow.parquet as pq
# ---> 30 from .download.download_config import DownloadConfig
#      31 from .naming import _split_re, filenames_for_dataset_split
#      32 from .table import InMemoryTable, MemoryMappedTable, Table, concat_tables
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/datasets/download/__init__.py:10
#       8 from .download_config import DownloadConfig
#       9 from .download_manager import DownloadManager, DownloadMode
# ---> 10 from .streaming_download_manager import StreamingDownloadManager
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/datasets/download/streaming_download_manager.py:18
#      15 from xml.etree import ElementTree as ET
#      17 import fsspec
# ---> 18 from aiohttp.client_exceptions import ClientError
#      20 from .. import config
#      21 from ..filesystems import COMPRESSION_FILESYSTEMS
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/aiohttp/__init__.py:6
#       3 from typing import Tuple
#       5 from . import hdrs as hdrs
# ----> 6 from .client import (
#       7     BaseConnector as BaseConnector,
#       8     ClientConnectionError as ClientConnectionError,
#       9     ClientConnectorCertificateError as ClientConnectorCertificateError,
#      10     ClientConnectorError as ClientConnectorError,
#      11     ClientConnectorSSLError as ClientConnectorSSLError,
#      12     ClientError as ClientError,
#      13     ClientHttpProxyError as ClientHttpProxyError,
#      14     ClientOSError as ClientOSError,
#      15     ClientPayloadError as ClientPayloadError,
#      16     ClientProxyConnectionError as ClientProxyConnectionError,
#      17     ClientRequest as ClientRequest,
#      18     ClientResponse as ClientResponse,
#      19     ClientResponseError as ClientResponseError,
#      20     ClientSession as ClientSession,
#      21     ClientSSLError as ClientSSLError,
#      22     ClientTimeout as ClientTimeout,
#      23     ClientWebSocketResponse as ClientWebSocketResponse,
#      24     ContentTypeError as ContentTypeError,
#      25     Fingerprint as Fingerprint,
#      26     InvalidURL as InvalidURL,
#      27     NamedPipeConnector as NamedPipeConnector,
#      28     RequestInfo as RequestInfo,
#      29     ServerConnectionError as ServerConnectionError,
#      30     ServerDisconnectedError as ServerDisconnectedError,
#      31     ServerFingerprintMismatch as ServerFingerprintMismatch,
#      32     ServerTimeoutError as ServerTimeoutError,
#      33     TCPConnector as TCPConnector,
#      34     TooManyRedirects as TooManyRedirects,
#      35     UnixConnector as UnixConnector,
#      36     WSServerHandshakeError as WSServerHandshakeError,
#      37     request as request,
#      38 )
#      39 from .cookiejar import CookieJar as CookieJar, DummyCookieJar as DummyCookieJar
#      40 from .formdata import FormData as FormData
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/aiohttp/client.py:36
#      33 from multidict import CIMultiDict, MultiDict, MultiDictProxy, istr
#      34 from yarl import URL
# ---> 36 from . import hdrs, http, payload
#      37 from .abc import AbstractCookieJar
#      38 from .client_exceptions import (
#      39     ClientConnectionError as ClientConnectionError,
#      40     ClientConnectorCertificateError as ClientConnectorCertificateError,
#    (...)
#      57     WSServerHandshakeError as WSServerHandshakeError,
#      58 )
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/aiohttp/http.py:7
#       5 from . import __version__
#       6 from .http_exceptions import HttpProcessingError as HttpProcessingError
# ----> 7 from .http_parser import (
#       8     HeadersParser as HeadersParser,
#       9     HttpParser as HttpParser,
#      10     HttpRequestParser as HttpRequestParser,
#      11     HttpResponseParser as HttpResponseParser,
#      12     RawRequestMessage as RawRequestMessage,
#      13     RawResponseMessage as RawResponseMessage,
#      14 )
#      15 from .http_websocket import (
#      16     WS_CLOSED_MESSAGE as WS_CLOSED_MESSAGE,
#      17     WS_CLOSING_MESSAGE as WS_CLOSING_MESSAGE,
#    (...)
#      26     ws_ext_parse as ws_ext_parse,
#      27 )
#      28 from .http_writer import (
#      29     HttpVersion as HttpVersion,
#      30     HttpVersion10 as HttpVersion10,
#      31     HttpVersion11 as HttpVersion11,
#      32     StreamWriter as StreamWriter,
#      33 )
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/aiohttp/http_parser.py:39
#      29 from .helpers import NO_EXTENSIONS, BaseTimerContext
#      30 from .http_exceptions import (
#      31     BadHttpMessage,
#      32     BadStatusLine,
#    (...)
#      37     TransferEncodingError,
#      38 )
# ---> 39 from .http_writer import HttpVersion, HttpVersion10
#      40 from .log import internal_logger
#      41 from .streams import EMPTY_PAYLOAD, StreamReader
#
# File ~/.conda/envs/py39/lib/python3.9/site-packages/aiohttp/http_writer.py:9
#       5 from typing import Any, Awaitable, Callable, NamedTuple, Optional, Union  # noqa
#       7 from multidict import CIMultiDict
# ----> 9 from .abc import AbstractStreamWriter
#      10 from .base_protocol import BaseProtocol
#      11 from .helpers import NO_EXTENSIONS
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:846, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:941, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1040, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
torch.cuda.empty_cache()

# %%
path = "reuters-data-for-ACL-analysis/"
li = []
all_files = glob.glob(os.path.join(path, "*.csv"))
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)

# %%
valid = ["Work_For", "Live_In", "OrgBased_In", "Kill", "Located_In"]
# df = pd.read_csv("dataset_reuters-scraper_2023-05-30_14-18-42-403_WORLD.csv")
print (df.shape)
print (df.columns)
# Out:
# (196, 113)
# Index(['author/0', 'canonicalLink', 'copyright', 'date', 'depth',
#        'description', 'favicon', 'image', 'keywords', 'lang',
#        ...
#        'links/35/text', 'links/36/href', 'links/36/text', 'links/37/href',
#        'links/37/text', 'links/38/href', 'links/38/text', 'videos/0/height',
#        'videos/0/src', 'videos/0/width'],
#       dtype='object', length=113)

# %%
df = df[["date", "description", "keywords"]]
df.drop_duplicates(inplace=True)
print (df.shape)
df.head()
# Out:
# (158, 3)
#                        date  \
# 0  2023-05-31T12:00:00.000Z
# 1  2023-05-31T12:00:00.000Z
# 2  2023-05-30T12:00:00.000Z
# 3  2023-05-30T12:00:00.000Z
# 4  2023-05-31T12:00:00.000Z
#
#                                          description  \
# 0  The president of the Confederation of British ...
# 1  Sales of own-label products at British superma...
# 2  Sentiment among British businesses fell for th...
# 3  Britain's competition regulator told supermark...
# 4  UK's FTSE 100 slid on Wednesday to a two-month...
#
#                                             keywords
# 0  MTPIX,BACT,BIZ,BOSS1,ECO,GEN,MCE,MNGISS,PLCY,P...
# 1  BACT,BIZ,CMPNY,ECI,ECO,FDRT,GEN,INFL,MCE,NCYC,...
# 2  BOE,BSENT,CEN,ECI,ECO,GDP,INFL,INT,MCE,PMI,GB,...
# 3  EF:BUSINESS-MACROMATTERS,CMPNY,ECI,ECO,FDRT,FO...
# 4  MKTREP,REP,CMPNY,DBT,EUB,FIN,FINS,FINS08,HOT,I...

# %%
# df.to_csv("conll23_test_examples.csv", index=False)

# %%
prefix = """List all relations of the following type in the given text and provide reasonable explanations for your answers - \n1. Kill: Entity A killed Entity B.\n2. Work_For: Entity A works for Entity B.\n3. Located_In: Entity A is located in Entity B.\n4. Live_In: Entity A lives in Entity B.\n5. OrgBased_In: Entity A is an organization based in Entity B.\n\n"""

print (prefix)
# Out:
# List all relations of the following type in the given text and provide reasonable explanations for your answers -
# 1. Kill: Entity A killed Entity B.
# 2. Work_For: Entity A works for Entity B.
# 3. Located_In: Entity A is located in Entity B.
# 4. Live_In: Entity A lives in Entity B.
# 5. OrgBased_In: Entity A is an organization based in Entity B.

# %%
tuned_model = AutoModelForSeq2SeqLM.from_pretrained("/home/wadhwa.s/gpt3/models/conll/checkpoint-2000/")
tokenizer = AutoTokenizer.from_pretrained("/home/wadhwa.s/gpt3/models/conll/checkpoint-2000/")

# %%
ip = []
date = []
generated = []
nc_count = 0

for ix, row in tqdm(df.iterrows(), total=df.shape[0]):
    text = prefix + row["description"]
    inputs = tokenizer(text, return_tensors="pt").input_ids
    outputs = tuned_model.generate(inputs, max_new_tokens=256, do_sample=False)
    out = tokenizer.decode(outputs[0], skip_special_tokens=True)
    torch.cuda.empty_cache()
    try:
        generated.append(out.split(" Explanation: ")[0])
        ip.append(row["description"])
        date.append(row["date"])
        # gold.append(row["gold_labels"])
        # print ("PRED: " + out)
    except:
        nc_count += 1
        print (row["text"])
        # print ("GOLD: " + row["gold_labels"])
        print ("PRED ---- NON CONFORMING OUTPUT: " + out)
        print ("\n----------------\n")
# Out:
# 100%|██████████| 158/158 [44:51<00:00, 17.04s/it]

# %%
df = pd.DataFrame({"text": ip, 
                   "date": date, 
                   "generated": generated})
# df.to_csv("conll_flan_explanations_generated_ckpt500.csv", index=False)
print (df.shape)
# Out:
# (158, 3)

# %%
invalid_count = 0
total_count = 0
valid_parsed = 0
for ix, row in df.iterrows():
    # print ("GOLD: " + row["gold_labels"])
    try:
        pred = ast.literal_eval(row["generated"])
        total_count += len(pred)
        valid_parsed += 1
        for relation in pred:
            if relation[1] not in valid:
                print ("TEXT: ", row["text"])
                print ("PRED: " + relation)
                print ("\n*********************\n")
    except:
        invalid_count += 1
        print ("TEXT: ", row["text"])
        print ("NON CONFORMING PRED: ", row["generated"])
        print ("\n----------------\n")
# Out:
# TEXT:  Two Just Stop Oil protesters were charged with aggravated trespass after they briefly brought Saturday's Rugby Premiership final at the Twickenham stadium in London to a halt by hurling orange powder on the pitch during the match.
# NON CONFORMING PRED:  [['Two Just Stop Oil protesters', 'Live_In', 'London'], ['Two Just Stop Oil protesters', 'Live_In', 'Twockenham stadium'], ['Two Just Stop Oil protesters', 'Live_In', 'London'], ['Two Just Stop Oil protesters', 'Live_In', 'Twockenham stadium'], ['Two Just Stop Oil protesters', 'Live_In', 'London'], ['Two Just Stop Oil protesters', 'Live_In', 'Twockenham stadium'], ['Two Just Stop Oil protesters', 'Live_In', 'London'], ['Two Just Stop Oil protesters', 'Live_In', 'Twockenham stadium'], ['Two Just Stop Oil protesters', 'Live_In', 'London'], ['Two Just Stop Oil protesters', 'Live_In',
#
# ----------------

# %%
print (invalid_count, total_count, valid_parsed)
# Out:
# 1 185 157

# %%
for ix, row in df.iterrows():
    print ("DATE: ", row["date"])
    print ("TEXT: ", row["text"])
    print ("GENERATED RELATIONS: ", row["generated"])
    print ("\n-----------------------------------------\n")
# Out:
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  The president of the Confederation of British Industry (CBI), which is fighting for its survival after a series of workplace misconduct incidents, will step down early next year, the lobbying organisation said on Wednesday.
# GENERATED RELATIONS:  [['Confederation of British Industry', 'OrgBased_In', 'Britain'], ['CBI', 'OrgBased_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Sales of own-label products at British supermarkets have grown at double the speed of branded goods in 2023, data from market researchers NIQ showed on Wednesday, as customers adjust to soaring prices.
# GENERATED RELATIONS:  [['NIQ', 'OrgBased_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Sentiment among British businesses fell for the first time in three months in May as firms were less optimistic about the economy and their trading prospects despite some signs of resilience in the economy, a survey showed on Wednesday.
# GENERATED RELATIONS:  [['British', 'Located_In', 'UK']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Britain's competition regulator told supermarkets on Tuesday it was looking at their earnings to identify which supply chains it needed to examine more closely as part of efforts to tackle food price inflation.
# GENERATED RELATIONS:  [['Competitive_Regulatory', 'OrgBased_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  UK's FTSE 100 slid on Wednesday to a two-month low weighed down by energy firms, as investors were worried that economic recovery in top consumer China might be stalling, while power firm Drax logged its worst day in over a year on a regulatory probe.
# GENERATED RELATIONS:  [['FTSE 100', 'OrgBased_In', 'UK'], ['Drax', 'OrgBased_In', 'UK']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  WH Smith on Wednesday forecast higher full-year profit as the British retailer bet on strong travel demand during the summer after it witnessed robust trading across its global travel business.
# GENERATED RELATIONS:  [['WH Smith', 'OrgBased_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Britain's highest inflation in four decades failed to boost company profits last year, with the exception of oil and gas extractors who benefited from a surge in energy prices, official figures showed on Tuesday.
# GENERATED RELATIONS:  [['Britain', 'Located_In', 'UK']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  The Bank of England will be far more aggressive in policy tightening than previously thought as it battles to contain stubbornly-high inflation running at the joint-highest rate among Group of Seven advanced economies, a Reuters poll found.
# GENERATED RELATIONS:  [['The Bank of England', 'OrgBased_In', 'England'], ['Reuters', 'OrgBased_In', 'Group of Seven']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Ladbrokes-owner Entain Plc said on Wednesday it was likely to incur a "substantial financial penalty" as part of an investigation by Britain's tax authority into issues including possible misconduct involving former third-party suppliers.
# GENERATED RELATIONS:  [['Entain Plc', 'OrgBased_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  New Zealand companies will start to benefit from the country’s new free trade agreement (FTA) with the United Kingdom with the pact now in force, the government said on Wednesday.
# GENERATED RELATIONS:  [['New Zealand', 'Located_In', 'United Kingdom']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Britain's competition regulator said on Tuesday it had cleared supermarket group Asda's 611 million pound ($771.14 million)acquisition of Co-operative Group's Arthur Foodstores.
# GENERATED RELATIONS:  [['Asda', 'OrgBased_In', 'Britain'], ['Arthur Foodstores', 'OrgBased_In', 'Co-operative Group']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  British discount retailer B&M on Wednesday forecast higher core earnings for its 2023-24 financial year, as customers snap up budget food and goods in a cost-of-living crunch, sending its shares nearly 6% higher.
# GENERATED RELATIONS:  [['B&M', 'OrgBased_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-29T12:00:00.000Z
# TEXT:  British shop price inflation picked up this month to reach its highest rate since industry records began in 2005, although growth in food prices cooled slightly, a survey showed on Tuesday.
# GENERATED RELATIONS:  [['Shop price inflation', 'Located_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  British ministers have been given more time to hand over unredacted messages from former prime minister Boris Johnson to a public inquiry looking into the handling of the COVID-19 pandemic, in a stand-off that could lead to criminal sanctions.
# GENERATED RELATIONS:  [['Boris Johnson', 'Live_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  British Prime Minister Rishi Sunak will hold talks with U.S. President Joe Biden next week when they will discuss improving economic ties and how to sustain military support for Ukraine in its conflict with Russia.
# GENERATED RELATIONS:  [['Joe Biden', 'Live_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Unilever Plc said on Tuesday Chief Financial Officer Graeme Pitkethly would leave the consumer goods giant by the end of May 2024 after more than two decades.
# GENERATED RELATIONS:  [['Graeme Pitkethly', 'Work_For', 'Unilever Plc']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  The United Nations human rights chief said on Tuesday he has formally conveyed his concerns over a new British migration law to the government, saying he was worried it would bar people from seeking asylum.
# GENERATED RELATIONS:  [['The United Nations', 'OrgBased_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  British supermarket Asda said it would buy the bulk of petrol station operator EG Group's UK and Ireland business to speed up its move into the convenience sector, creating a company with combined revenue of nearly 30 billion pounds ($38 billion).
# GENERATED RELATIONS:  [['Asda', 'OrgBased_In', 'Britain'], ['EG Group', 'OrgBased_In', 'UK and Ireland']]
#
# -----------------------------------------
#
# DATE:  2023-05-28T12:00:00.000Z
# TEXT:  Britain's health minister, Steve Barclay, said on Sunday that the government would not negotiate on pay with the nurses' union, as the threat of further strikes looms.
# GENERATED RELATIONS:  [['Steve Barclay', 'Live_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-29T12:00:00.000Z
# TEXT:  The British government said on Tuesday it would close a loophole that lets retailers give free samples of vapes to children in a clampdown on e-cigarettes, whose colourful designs and fruity flavours make them stand out on grocery store shelves.
# GENERATED RELATIONS:  [['British government', 'OrgBased_In', 'UK']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Luton Town captain Tom Lockyear remains in hospital after collapsing on the pitch during Saturday's Championship play-off final victory over Coventry City at Wembley, manager Rob Edwards said on Tuesday.
# GENERATED RELATIONS:  [['Tom Lockyear', 'Work_For', 'Luton Town']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  British ministers have been given more time to hand over unredacted messages from former prime minister Boris Johnson to a public inquiry looking into the handling of the COVID-19 pandemic, in a stand-off that could lead to criminal sanctions.
# GENERATED RELATIONS:  [['Boris Johnson', 'Live_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-28T12:00:00.000Z
# TEXT:  Everton emerged from a nerve-shredding afternoon with their Premier League status intact thanks to a 1-0 victory over Bournemouth at Goodison Park as Leicester City and Leeds United were relegated in a dramatic season finale on Sunday.
# GENERATED RELATIONS:  [['Goodison Park', 'Located_In', 'Premier League']]
#
# -----------------------------------------
#
# DATE:  2023-05-28T12:00:00.000Z
# TEXT:  The British government is looking at plans to have retailers cap the prices of basic food items such as bread and milk, the Telegraph reported, as the cost of such essentials continued to rise in the double digits.
# GENERATED RELATIONS:  [['The Telegraph', 'OrgBased_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  UK's FTSE 100 edged lower on Tuesday after a long weekend, with investors avoiding big bets on fresh worries over the U.S. debt deal, while advertising firm WPP logged its best day in over three weeks on its partnership with chipmaker Nvidia.
# GENERATED RELATIONS:  [['FTSE 100', 'OrgBased_In', 'UK']]
#
# -----------------------------------------
#
# DATE:  2023-05-27T12:00:00.000Z
# TEXT:  Seven men have been charged with the attempted murder of senior Police Service of Northern Ireland (PSNI) detective John Caldwell, according to a police statement.
# GENERATED RELATIONS:  [['John Caldwell', 'Work_For', 'Police Service of Northern Ireland']]
#
# -----------------------------------------
#
# DATE:  2023-05-28T12:00:00.000Z
# TEXT:  Two Just Stop Oil protesters were charged with aggravated trespass after they briefly brought Saturday's Rugby Premiership final at the Twickenham stadium in London to a halt by hurling orange powder on the pitch during the match.
# GENERATED RELATIONS:  [['Two Just Stop Oil protesters', 'Live_In', 'London'], ['Two Just Stop Oil protesters', 'Live_In', 'Twockenham stadium'], ['Two Just Stop Oil protesters', 'Live_In', 'London'], ['Two Just Stop Oil protesters', 'Live_In', 'Twockenham stadium'], ['Two Just Stop Oil protesters', 'Live_In', 'London'], ['Two Just Stop Oil protesters', 'Live_In', 'Twockenham stadium'], ['Two Just Stop Oil protesters', 'Live_In', 'London'], ['Two Just Stop Oil protesters', 'Live_In', 'Twockenham stadium'], ['Two Just Stop Oil protesters', 'Live_In', 'London'], ['Two Just Stop Oil protesters', 'Live_In',
#
# -----------------------------------------
#
# DATE:  2023-05-28T12:00:00.000Z
# TEXT:  Britain's automated border control gates have returned to normal operation, the Home Office said on Saturday, after a nationwide system issue caused major delays.
# GENERATED RELATIONS:  [['Home Office', 'OrgBased_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-26T12:00:00.000Z
# TEXT:  British Cycling became the latest sports governing body to ban transgender women from competing in the female category of competitive events on Friday, to "safeguard the fairness" of the sport.
# GENERATED RELATIONS:  [['British Cycling', 'OrgBased_In', 'UK']]
#
# -----------------------------------------
#
# DATE:  2023-05-27T12:00:00.000Z
# TEXT:  London police said on Saturday that a man arrested after a car collision into the gates of Downing Street, the site of British Prime Minister Rishi Sunak's office, had been separately charged with making indecent images of children.
# GENERATED RELATIONS:  [['Dewing Street', 'Located_In', 'London'], ['Rishi Sunak', 'Live_In', 'London'], ['Rishi Sunak', 'Work_For', 'British Prime Minister']]
#
# -----------------------------------------
#
# DATE:  2023-05-26T12:00:00.000Z
# TEXT:  Britain's departure from the European Union has accounted for about a third of the increase in food bills for households since 2019, equivalent to about 250 pounds ($316), researchers from the London School of Economics and other universities said.
# GENERATED RELATIONS:  [['London School of Economics', 'OrgBased_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Florida Governor Ron DeSantis, following his presidential campaign debut online, will dive into old-school retail politicking in key early voting states this week, his first chance to connect with voters since announcing his bid for the 2024 Republican nomination.
# GENERATED RELATIONS:  [['Ron DeSantis', 'Live_In', 'Florida']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  The U.S. Supreme Court on Tuesday declined to hear a bid by child pornography victims to overcome a legal shield for internet companies in a case involving a lawsuit accusing Reddit Inc of violating federal law by failing to rid the discussion website of this illegal content.
# GENERATED RELATIONS:  [['Supreme Court', 'OrgBased_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  A bipartisan deal to raise the $31.4 trillion debt ceiling faces its first test in Congress on Tuesday, setting up what could be a nail-biting week of voting before the US runs out of money to pay its bills.
# GENERATED RELATIONS:  [['Congress', 'OrgBased_In', 'United States']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  What could happen on Main Street if Washington's political showdown over the debt ceiling stopped the government from cutting checks that fund a quarter of the economy?
# GENERATED RELATIONS:  [['Main Street', 'Located_In', 'Washington']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Wall Street was tipped for a strong open on Tuesday, while the cost of insuring against a U.S. debt default fell and the safe-haven dollar weakened in a sign of broad optimism across markets that a U.S. debt ceiling crisis might be averted.
# GENERATED RELATIONS:  [['Wall Street', 'OrgBased_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Former U.S. State Department and nuclear regulatory officials on Tuesday urged the U.S. Energy Department to reconsider a plan to use bomb-grade uranium in a nuclear power experiment, saying that its use could encourage such tests in other countries.
# GENERATED RELATIONS:  [['State Department', 'OrgBased_In', 'U.S.'], ['U.S. Energy Department', 'OrgBased_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  U.S. single-family home prices increased solidly on a monthly basis in March, boosted by a persistent shortage of properties on the market, though the overall trend continued to point to a slowdown in house price inflation.
# GENERATED RELATIONS:  [['U.S.', 'Located_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-29T12:00:00.000Z
# TEXT:  Search and rescue teams working throughout the night rescued an eighth victim from an apartment building that collapsed in Davenport, Iowa, officials said on Monday.
# GENERATED RELATIONS:  [['Davenport', 'Located_In', 'Iowa']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  The U.S. Supreme Court on Tuesday declined to hear a bid by a New York lawyer to restrict how much money federal prosecutors can take from his 401(k) retirement accounts to compensate fraud victims after he was convicted in a scheme involving former pharmaceutical executive Martin Shkreli.
# GENERATED RELATIONS:  [['Martin Shkreli', 'Live_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-29T12:00:00.000Z
# TEXT:  The debt ceiling deal that U.S. President Joe Biden and House Republican Kevin McCarthy agreed over the weekend adds new conditions to food aid that will impact one segment of the U.S. population specifically - GenXers with no dependents.
# GENERATED RELATIONS:  [['Joe Biden', 'Live_In', 'U.S.'], ['Kevin McCarthy', 'Live_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-29T12:00:00.000Z
# TEXT:  The U.S. House Rules Committee said it will meet on Tuesday afternoon to discuss the debt ceiling bill, which needs to pass a narrowly divided Congress before June 5, when the U.S. Treasury says it would run short of money to cover all its obligations.
# GENERATED RELATIONS:  [['House Rules Committee', 'OrgBased_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-29T12:00:00.000Z
# TEXT:  A handful of hard-right Republican lawmakers said on Monday they would oppose a deal to raise the United States' $31.4 trillion debt ceiling, in a sign that the bipartisan agreement could face a rocky path through Congress before the U.S. runs out of money next week.
# GENERATED RELATIONS:  [['Congress', 'OrgBased_In', 'United States']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Thousands of deepfakes are surfacing on social media, blurring fact and fiction in the polarized world of U.S. politics.
# GENERATED RELATIONS:  [['U.S.', 'Located_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  In the last few weeks, both men have stopped the put-downs and cobbled together an agreement that will now lead to a congressional vote to suspend the U.S. debt ceiling and avoid a default.
# GENERATED RELATIONS:  [['Congress', 'OrgBased_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  U.S. holiday air passenger travel topped 2019 pre-COVID levels over the Memorial Day weekend, which typically marks the start of the busy U.S. summer air travel season, figures from the U.S. Transportation Security Administration (TSA) showed on Tuesday.
# GENERATED RELATIONS:  [['U.S. Transportation Security Administration', 'OrgBased_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-28T12:00:00.000Z
# TEXT:  A biker was charged with murder after a shootout between rival motorbike gangs at a motorcycle rally in Red River, northern New Mexico, on Saturday in which three gang members were killed and five wounded, police said.
# GENERATED RELATIONS:  [['Red River', 'Located_In', 'New Mexico']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  He will now be temporarily removed from office pending a trial in the Senate, where his wife, Angela Paxton, is a senator.
# GENERATED RELATIONS:  [['Angela Paxton', 'Work_For', 'Senate']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Alberta's election of conservative leader Danielle Smith puts her on a collision course with Canada's Liberal Prime Minister Justin Trudeau over climate policies that she claims will undermine the province's massive fossil fuel industry.
# GENERATED RELATIONS:  [['Danielle Smith', 'Live_In', 'Alberta']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  On a hot summer afternoon, 23-year old Nizamudin Abdul Rahim Khan is playing cricket on a muddy, unpaved road in the Rafiq Nagar slum in India's financial capital, Mumbai.
# GENERATED RELATIONS:  [['Rafiq Nagar', 'Located_In', 'India'], ['Nizamudin Abdul Rahim Khan', 'Live_In', 'India'], ['Nizamudin Abdul Rahim Khan', 'Live_In', 'Mumbai']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  China has declined a request from the United States for a meeting between their defense chiefs at an annual security forum in Singapore this weekend, media reported on Monday, a new sign of strain between the powers.
# GENERATED RELATIONS:  [['Singapore', 'Located_In', 'Singapore']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Ukrainian drones struck wealthy districts of Moscow on Tuesday, Russia said in what one politician called the most dangerous attack since World War Two, while Kyiv was also hit by air for the third time in 24 hours.
# GENERATED RELATIONS:  [['Moscow', 'Located_In', 'Russia']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Wang Chunxiang pushes a cart around busy areas of Shanghai, playing cat and mouse with the authorities as she tries to sell pastries. The jobs she could get do not pay enough for her to make ends meet.
# GENERATED RELATIONS:  [['Wang Chunxiang', 'Live_In', 'Shanghai']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Serbian protesters smashed two cars belonging to journalists in Kosovo's Leposavic town on Tuesday, a day after 30 NATO soldiers and 52 protesters were hurt in clashes, as EU and NATO officials urged a de-escalation of the violence.
# GENERATED RELATIONS:  [['Leposavic', 'Located_In', 'Kosovo']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  President Vladimir Putin said on Tuesday that Ukraine's biggest ever drone strike on Moscow was an attempt to scare and provoke Russia, and air defences around the capital would be strengthened.
# GENERATED RELATIONS:  [['Vladimir Putin', 'Live_In', 'Russia']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Russian Foreign Minister Sergei Lavrov said on Tuesday that the West was "supporting genocide" in Ukraine through its backing for President Volodymyr Zelenskiy's peace plan, which he claimed would "destroy everything Russian" in east Ukraine and Crimea.
# GENERATED RELATIONS:  [['Sergei Lavrov', 'Live_In', 'Russia']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  India's top wrestlers have threatened to hurl their medals into the river Ganges on Tuesday as they demand the arrest of the head of the Wrestling Federation of India over sexual harassment allegations.
# GENERATED RELATIONS:  [['Wrestling Federation', 'OrgBased_In', 'India']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Top artificial intelligence executives including OpenAI CEO Sam Altman on Tuesday joined experts and professors in raising the "risk of extinction from AI", which they urged policymakers to equate at par with risks posed by pandemics and nuclear war.
# GENERATED RELATIONS:  [['Sam Altman', 'Work_For', 'OpenAI']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Barbara Jatta, the first woman to head the Vatican Museums, wants visitors to avoid being suffocated by the crowds and take in the lesser-known - but spectacular - attractions she helps to oversee.
# GENERATED RELATIONS:  [['Barbara Jatta', 'Work_For', 'Vatican Museums']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  NATO foreign ministers will seek to narrow divisions over Ukraine's membership bid at a meeting in Oslo this week, with allies at odds over calls to grant Kyiv a road map to accession at their July summit.
# GENERATED RELATIONS:  [['NATO', 'OrgBased_In', 'Oslo']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  The Kremlin said on Tuesday that Russia would take part at the "proper level" in a planned summit in South Africa of the BRICS nations, responding to a question on whether President Vladimir Putin would attend the gathering.
# GENERATED RELATIONS:  [['Vladimir Putin', 'Live_In', 'Russia']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Turkey called on NATO hopeful Sweden on Tuesday to prosecute those responsible for projecting the flag of an outlawed group onto the parliament building in Stockholm, on the day of Turkish elections that extended President Tayyip Erdogan's rule.
# GENERATED RELATIONS:  [['Sweden', 'Located_In', 'Sweden']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  South American presidents are gathering in Brasilia on Tuesday for their first summit in almost a decade at the invitation of Brazil's leftist leader Luiz Inacio Lula da Silva, who aims to regain his country's active role in regional affairs.
# GENERATED RELATIONS:  [['Luiz Inacio Lula da Silva', 'Live_In', 'Brazil']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Ukraine launched its biggest ever drone attack on Moscow on Tuesday but air defences destroyed all eight of the drones, Russia said, bringing the 15-month war in Ukraine to the heart of the capital.
# GENERATED RELATIONS:  [['Moscow', 'Located_In', 'Ukraine']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  India's monsoon rains advanced into some more parts of southwest Bay of Bengal after stalling for the past 11 days at a far-flung island, weather department said on Tuesday.
# GENERATED RELATIONS:  [['Bay of Bengal', 'Located_In', 'India']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Kyiv's peace plan is the only way to end Russia's war in Ukraine and the time for mediation efforts has passed, a top aide to President Volodymyr Zelenskiy said.
# GENERATED RELATIONS:  [['Volodymyr Zelenskiy', 'Live_In', 'Ukraine']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  The U.S. House of Representatives is due to vote on Wednesday on a bill to lift the government's debt ceiling, a critical step to avoid a potential economically destabilizing default that could come early next week without congressional action.
# GENERATED RELATIONS:  [['House of Representatives', 'OrgBased_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Florida's governor kicked off his first in-person campaign event as he seeks the Republican 2024 presidential nomination.
# GENERATED RELATIONS:  [['Fla.', 'Located_In', 'Florida']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Former New Jersey Governor Chris Christie, who advised Donald Trump's White House campaign in 2016 only to become a vocal critic of the former president in recent months, will launch a bid for the 2024 Republican presidential nomination next week, a person familiar with the matter said.
# GENERATED RELATIONS:  [['Chris Christie', 'Live_In', 'New Jersey']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  A U.S. judge ruled late on Tuesday that relatives of those killed in a 2019 Boeing 737 MAX Ethiopian Airlines crash may seek compensation for pain and suffering of passengers before the plane hit the ground.
# GENERATED RELATIONS:  [['Boeing 737 MAX', 'OrgBased_In', 'Ethiopia']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  A NASA panel formed last year to study what the government calls "unidentified aerial phenomena," commonly termed UFOs, was due to hold its first public meeting on Wednesday, ahead of a report expected in coming weeks.
# GENERATED RELATIONS:  [['NASA', 'OrgBased_In', 'Unidentified aerial phenomena']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  U.S. health and advocacy groups have declared June 2 as National Gun Violence Awareness Day. People are asked to wear orange - traditionally a color worn by hunters - to remember shooting victims.
# GENERATED RELATIONS:  [['National Gun Violence Awareness Day', 'Located_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Manhattan District Attorney Alvin Bragg on Tuesday moved to block former President Donald Trump's attempt to persuade a federal court to take over a state criminal case in which he is charged with falsifying business records prior to the 2016 election.
# GENERATED RELATIONS:  [['Alvin Bragg', 'Live_In', 'Manhattan']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Donald Trump said on Tuesday that if elected president again in 2024 he would seek to end automatic citizenship for children born in the United States to immigrants in the country illegally, a plan that contradicts how a 19th century amendment to the U.S. Constitution long has been interpreted.
# GENERATED RELATIONS:  [['Donald Trump', 'Live_In', 'United States']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Three men accused of acting as illegal agents of China will face trial on Wednesday in the United States, part of an escalating crackdown on what U.S. prosecutors call Chinese state-backed intimidation of dissidents and fugitives overseas.
# GENERATED RELATIONS:  [['China', 'Located_In', 'United States']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  The White House said on Tuesday that President Joe Biden is withdrawing the nomination of the acting head of the National Highway Traffic Safety Administration (NHTSA) to take the top job on a permanent basis.
# GENERATED RELATIONS:  [['Joe Biden', 'Work_For', 'National Highway Traffic Safety Administration']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Two people still counted as missing after the partial collapse of an Iowa apartment building on the weekend were likely inside at the time, officials said on Tuesday, but the structure was too unstable to resume a search for them.
# GENERATED RELATIONS:  [['Iowa', 'Located_In', 'Iowa']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Los Angeles on Tuesday announced a settlement with a Nevada-based company it accused of illegally selling so-called "ghost guns," components without serial numbers that a purchaser can easily assemble into a complete gun, in California.
# GENERATED RELATIONS:  [['Nevada-based', 'OrgBased_In', 'California.']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  The man accused of killing 11 worshippers at a Pittsburgh synagogue five years ago in the deadliest antisemitic attack in U.S. history could face the death penalty if found guilty in a federal trial that opened on Tuesday.
# GENERATED RELATIONS:  [['The man accused of killing 11 worshippers at a Pittsburgh synagogue', 'Kill', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Former US State Department and nuclear regulatory officials said its use could encourage such tests in other countries.
# GENERATED RELATIONS:  [['State Department', 'OrgBased_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Thousands of deepfakes are surfacing on social media, blurring fact and fiction in the polarized world of U.S. politics.
# GENERATED RELATIONS:  [['U.S.', 'Located_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  A California appeals court overruled Governor Gavin Newsom on Tuesday to find Leslie Van Houten, one of Charles Manson's murderous "family" of followers, entitled to parole after more than 50 years in prison for her part in the cult's 1969 killing spree.
# GENERATED RELATIONS:  [['Leslie Van Houten', 'Kill', 'Charles Manson']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Legislation brokered by President Joe Biden and House Speaker Kevin McCarthy to lift the $31.4 trillion US debt ceiling and achieve new federal spending cuts passed an important hurdle, advancing to the full House of Representatives for an expected vote on passage on Wednesday.
# GENERATED RELATIONS:  [['Joe Biden', 'Work_For', 'United States'], ['Kevin McCarthy', 'Work_For', 'House']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  BlackRock, Korea's SK, Switzerland's UBS and other companies are chasing an investment boom in battery storage plants in Texas, lured by the prospect of earning double-digit returns from the power grid problems plaguing the state, according to project owners, developers and suppliers.
# GENERATED RELATIONS:  [['BlackRock', 'OrgBased_In', 'Texas'], ['SK', 'OrgBased_In', 'Korea'], ['UBS', 'OrgBased_In', 'Switzerland']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T10:00:00.000Z
# TEXT:  For years Russia and Germany had an unbreakable bond. A German soccer club and its chairman were especially useful in advancing Russian interests, Reuters reporting shows
# GENERATED RELATIONS:  [['Reuters', 'OrgBased_In', 'Russia']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Russia's most powerful mercenary, Yevgeny Prigozhin, said that he had asked prosecutors to investigate whether senior Russian defence officials had committed any "crime" before or during the war in Ukraine.
# GENERATED RELATIONS:  [['Yevgeny Prigozhin', 'Live_In', 'Russia']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  For the ambitious Chinese tech entrepreneur, expanding into the U.S. just keeps getting harder.
# GENERATED RELATIONS:  [['Chinese tech entrepreneur', 'Live_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Markets participants have a month to stop using Libor, the tarnished interest rate banks were fined for trying to rig, Britain's Financial Conduct Authority (FCA) said on Wednesday.
# GENERATED RELATIONS:  [['Financial Conduct Authority', 'OrgBased_In', 'Britain']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Moscow said Ukrainian artillery had hit a town inside Russia for a third time this week and reported drone strikes on two Russian oil refineries on Wednesday, while Ukrainian shelling in Russian-occupied eastern Ukraine killed five people.
# GENERATED RELATIONS:  [['Moscow', 'Located_In', 'Russia']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Russian designers and brands are helping the retail sector gradually recover from a turbulent 15 months of store closures and slumping demand, with new labels plugging the gap left by foreign rivals and shoppers tentatively returning.
# GENERATED RELATIONS:  [['Russian', 'OrgBased_In', 'Russia']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  U.S. home prices will decline less than previously expected this year before stagnating in 2024, despite widespread expectations interest rates will remain higher for longer, according to property analysts polled by Reuters.
# GENERATED RELATIONS:  [['Reuters', 'OrgBased_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  U.S. retailer Target's decision to remove some LGBTQ-themed merchandise after customer backlash in its stores highlights the problem with companies' "rainbow capitalism," said Erik Carnell, a transgender designer whose products were pulled from its stores.
# GENERATED RELATIONS:  [['Target', 'OrgBased_In', 'U.S.'], ['Erik Carnell', 'Live_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Credit Suisse has scrapped plans to set up a locally incorporated bank in China to sidestep a potential regulatory conflict arising from its merger with UBS , said two sources with direct knowledge of the matter.
# GENERATED RELATIONS:  [['Credit Suisse', 'OrgBased_In', 'China']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  A look at the day ahead in U.S. and global markets from Mike Dolan
# GENERATED RELATIONS:  [['Mike Dolan', 'Live_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  NATO peacekeepers stood behind a razor-wire barrier that prevented the approach of protesters outside a municipal hall in ethnically divided northern Kosovo, where days of unrest have prompted NATO to send additional troops to stave off violence.
# GENERATED RELATIONS:  [['NATO', 'OrgBased_In', 'Kosovo']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Spanish startup PLD Space called off the test launch of its first suborbital reusable rocket scheduled for Wednesday morning, citing strong high-altitude winds.
# GENERATED RELATIONS:  [['PLD Space', 'OrgBased_In', 'Spain']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  U.N. judges on Wednesday sentenced two former Serbian spymasters who worked for Yugoslav ex-President Slobodan Milosevic to 15 years in jail as it beefed up their initial convictions in the last case before The Hague tribunal dating from the Balkan wars.
# GENERATED RELATIONS:  [['Slobodan Milosevic', 'Work_For', 'U.N.']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  From the purchase of surveillance drones and armoured vehicles to providing access to a satellite, fundraiser Serhiy Prytula has helped power Ukraine's army during Russia's invasion.
# GENERATED RELATIONS:  [['Serhiy Prytula', 'Live_In', 'Ukraine']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Japan's government will set aside $26 billion for new child care measures, slightly more than earlier estimated, in a move likely to add more debt to the industrial world's heaviest public debt burden.
# GENERATED RELATIONS:  [['Japan', 'Located_In', 'Japan']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  South Korean nuclear safety experts who visited Japan's wrecked Fukushima nuclear power plant said on Wednesday that detailed analysis was needed to verify Japan's plan to release tonnes of contaminated water from it into the sea.
# GENERATED RELATIONS:  [['Fukushima nuclear power plant', 'Located_In', 'Japan']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Jeong Se-ah feels happy to see Tanaka, a Japanese bar host character from the early 2000s created by a South Korean comedian, because he revives her teenage memories of watching animations from the neighbouring nation.
# GENERATED RELATIONS:  [['Tanaka', 'Live_In', 'Japanese']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  An absence of women among China's top leadership is concerning, the United Nations said in a report, as it recommended China adopt statutory quotas and a gender parity system to quicken equal representation of women in government.
# GENERATED RELATIONS:  [['United Nations', 'OrgBased_In', 'China']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Lightmatter, a Boston-based startup using light for AI computing, said on Wednesday it raised $154 million and tripled its valuation as customers in need of faster, more energy efficient computing for AI work are buying its systems.
# GENERATED RELATIONS:  [['Lightmatter', 'OrgBased_In', 'Boston']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Chinese search giant Baidu Inc will set up a venture capital fund of 1 billion yuan ($145 million) to back start-ups focused on content generated by artificial intelligence applications, it said on Wednesday.
# GENERATED RELATIONS:  [['Baidu Inc', 'OrgBased_In', 'China']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Apple Inc supplier Foxconn said on Wednesday artificial intelligence applications would strongly drive demand for its server business this year but reiterated 2023 overall would be a flat one for the company on global economic woes.
# GENERATED RELATIONS:  [['Foxconn', 'OrgBased_In', 'Apple Inc.']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Turkey's broadcasting watchdog has launched an inquiry into six opposition TV channels for "insulting the public" with their coverage of Sunday's presidential election runoff, it said on Tuesday, without detailing what the insults were.
# GENERATED RELATIONS:  [['Turkey', 'OrgBased_In', 'Radio'], ['Operational_TV_channels', 'OrgBased_In', 'Turkey']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Turkish President Tayyip Erdogan is viewed as almost certain to include former economy chief Mehmet Simsek in his new cabinet, either as finance minister or as a vice president responsible for the economy, four senior officials said.
# GENERATED RELATIONS:  [['Tayyip Erdogan', 'Live_In', 'Turkey'], ['Mehmet Simsek', 'Live_In', 'Turkey']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  The United States and European Union should push the artificial intelligence (AI) industry to adopt a voluntary code of conduct within months to provide safeguards while new laws are developed, EU tech chief Margrethe Vestager said on Wednesday.
# GENERATED RELATIONS:  [['Margrethe Vestager', 'Work_For', 'European Union']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Operations to salvage 1.1 million barrels of oil from a decaying tanker moored off Yemen's coast will soon begin after a technical support ship arrived on site on Tuesday, the United Nations said.
# GENERATED RELATIONS:  [['United Nations', 'OrgBased_In', 'Yemen']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Stefanos Tsitsipas enjoyed an incident-free path into the third round of the French Open with a win over Roberto Carballes Baena on Wednesday but all eyes will be on Novak Djokovoic later as a political row sparked by the two-times champion intensified.
# GENERATED RELATIONS:  [['Stefanos Tsitsipas', 'Work_For', 'French Open'], ['Roberto Carballes Baena', 'Work_For', 'French Open']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  The Miami Heat have the chance to make history when the NBA Finals kick off on Thursday, facing a well-rested Denver Nuggets squad that is uninterested in letting the Heat's Cinderella story go any further.
# GENERATED RELATIONS:  [['Miami Heat', 'OrgBased_In', 'Miami']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Kosovo Olympic authorities have asked the International Olympic Committee (IOC) to open disciplinary proceedings against Novak Djokovic, accusing the Serbian of stirring up political tension by saying "Kosovo is the heart of Serbia" at the French Open.
# GENERATED RELATIONS:  [['Nikolaj Djokovic', 'Live_In', 'Kosovo']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Kyle Hendricks allowed one run over five innings in his second 2023 start and Mike Tauchman's tiebreaking RBI single in the sixth made the Tampa Bay Rays pay for some shoddy defense, sending the host Chicago Cubs to a 2-1 victory on Tuesday night.
# GENERATED RELATIONS:  [['Kyle Hendricks', 'Work_For', 'Tampa Bay Rays']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  While songwriter Justin Tranter has attained success by penning hit pop anthems like Justin Bieber's "Sorry" and Imagine Dragons' "Believer," writing music for the Paramount+ prequel "Grease: Rise of the Pink Ladies" took him in a new direction.
# GENERATED RELATIONS:  [['Justin Tranter', 'Work_For', 'Paramount+']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  For Canadian celebrity chef Suzanne Husseini, a first culinary tour of the Palestinian territories was a chance to preserve and promote the dishes and folk-remedies of her ancestry.
# GENERATED RELATIONS:  [['Suzanne Husseini', 'Live_In', 'Canada']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  An all-private astronaut team of two Americans and two Saudis, including the first Arab woman sent into orbit, splashed down safely off Florida on Tuesday night, capping an eight-day research mission aboard the International Space Station (ISS).
# GENERATED RELATIONS:  [['International Space Station', 'OrgBased_In', 'Florida']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Italy is proposing a disused mineral mine in a remote corner of Sardinia to house one of the world's most advanced telescopes, hoping that the uncommon stillness of the spot will clinch European Union approval and funds.
# GENERATED RELATIONS:  [['Sardinia', 'Located_In', 'Italy']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  A senior U.S. senator who has long opposed the potential sale of F-16 fighter jets to Turkey said on Tuesday he wants Turkish President Tayyip Erdogan to take a “less belligerent” stance toward NATO allies and Turkey's neighbors before lifting his opposition to the deal.
# GENERATED RELATIONS:  [['Tayyip Erdogan', 'Live_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-29T19:59:08.000Z
# TEXT:  Brad Fromm and his son, Tyler Fromm, visit Brad's friend and former White House Chief of Staff Gen. John Kelly's son, Robert Kelly in Section 60 at Arlington National Cemetery on Memorial Day in Washi
# GENERATED RELATIONS:  [['Arlington National Cemetery', 'Located_In', 'Washington']]
#
# -----------------------------------------
#
# DATE:  2023-05-29T17:52:07.000Z
# TEXT:  People shelter inside a subway station during an air raid alert, amid Russia's attack on Ukraine, in Kyiv, Ukraine, May 29, 2023. REUTERS/Alina Smutko
# GENERATED RELATIONS:  [['Kyiv', 'Located_In', 'Ukraine']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T00:54:14.000Z
# TEXT:  Britain's King Charles waves as he stands on the Buckingham Palace balcony following his coronation ceremony in London, May 6.      REUTERS/Paul Childs
# GENERATED RELATIONS:  [['King Charles', 'Live_In', 'Britain'], ['King Charles', 'Live_In', 'London'], ['Buckingham Palace', 'Located_In', 'Britain'], ['Buckingham Palace', 'Located_In', 'London']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Drones attacked two oil refineries just 40-50 miles (65-80 km) east of Russia's biggest oil export terminals on Wednesday, sparking a fire at one and causing no damage to the other, according to Russian officials.
# GENERATED RELATIONS:  [['Drones', 'Located_In', 'Russia']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Amid supply chain disruptions, soaring costs and currency volatility, Unilever working to make its African operations more self-reliant, ramping up local sourcing in part to reduce its foreign exchange exposure.
# GENERATED RELATIONS:  [['Unilever', 'OrgBased_In', 'Africa']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  The Qatari prime minister held secret talks with the supreme leader of the Taliban this month on resolving tension with the international community, a source briefed on the meeting said, signaling a new willingness by Afghanistan's rulers to discuss ways to end their isolation.
# GENERATED RELATIONS:  [['Taliban', 'OrgBased_In', 'Afghanistan']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  The United Arab Emirates said on Wednesday it was no longer taking part in operations by a U.S.-led task force protecting Gulf shipping, which has been subjected to renewed tanker seizures by Iranian naval forces in recent weeks.
# GENERATED RELATIONS:  [['United Arab Emirates', 'OrgBased_In', 'Gulf']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  China's factory activity shrank faster than expected in May on weakening demand, heaping pressure on policymakers to shore up a patchy economic recovery and knocking Asian financial markets lower.
# GENERATED RELATIONS:  [['China', 'Located_In', 'China']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Russia's most powerful mercenary, Yevgeny Prigozhin, said that he had asked prosecutors to investigate whether senior Russian defence officials had committed any "crime" before or during the war in Ukraine.
# GENERATED RELATIONS:  [['Yevgeny Prigozhin', 'Live_In', 'Russia']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  He's "a pioneer", "Brother Ma" and some want him to be U.S. president. Billionaire Elon Musk has been showered with praise by the Chinese public during his trip to the country while also securing audiences with three government ministers.
# GENERATED RELATIONS:  [['Elon Musk', 'Live_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  A North Korean satellite launch on Wednesday ended in failure, sending the booster and payload plunging into the sea, North Korean state media said, and the South's military said it had recovered parts of the launch vehicle.
# GENERATED RELATIONS:  [['North Korea', 'OrgBased_In', 'North Korea']]
#
# -----------------------------------------
#
# DATE:  2023-05-31T12:00:00.000Z
# TEXT:  Russia's defence ministry said on Wednesday that its forces had destroyed what it described as Ukraine's "last warship" two days ago in the port of Odesa in a missile strike.
# GENERATED RELATIONS:  [['Russia', 'OrgBased_In', 'Defense Ministry'], ['Odesa', 'Located_In', 'Ukraine']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  OPEC and its allies, including Russia, meet in Vienna on June 4 to decide on their output policy.
# GENERATED RELATIONS:  [['OPEC', 'OrgBased_In', 'Vienna'], ['OPEC', 'OrgBased_In', 'Russia']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  The euro zone's top banks may take a hit if their financial clients, such as funds, insurers and clearing houses, withdrew their deposits or otherwise ran into trouble, the European Central Bank warned on Tuesday.
# GENERATED RELATIONS:  [['European Central Bank', 'OrgBased_In', 'euro zone']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  The National Highway Traffic Safety Administration (NHTSA) said Tuesday it is closing its investigation into 580,000 Tesla vehicles over the automaker's decision to initially allow games to be played on the front center touchscreen.
# GENERATED RELATIONS:  [['National Highway Traffic Safety Administration', 'OrgBased_In', 'NHTSA']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Prosecutors urged a Manhattan federal court judge on Monday to deny a request by FTX founder Sam Bankman-Fried to dismiss criminal charges accusing him of stealing billions of dollars from customers to plug losses at his hedge fund.
# GENERATED RELATIONS:  [['Sam Bankman-Fried', 'Work_For', 'FTX']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Tesla Inc CEO Elon Musk told Chinese foreign minister Qin Gang on Tuesday that he was willing to expand business in the country, the Chinese foreign ministry said on Tuesday after a meeting between the two in Beijing.
# GENERATED RELATIONS:  [['Elon Musk', 'Work_For', 'Tesla Inc']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Ukraine "desperately hopes" that South Korea will provide defensive military equipment such as anti-aircraft systems to fend off Russian attacks, President Volodymyr Zelenskiy was cited as saying in an interview with a South Korean newspaper.
# GENERATED RELATIONS:  [['Volodymyr Zelenskiy', 'Live_In', 'Ukraine']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Three more insurance companies including Tokio Marine have left a United Nations-backed net-zero climate alliance, leaving the group with about half the number of members it counted two months ago as insurers take fright at U.S. political pressure.
# GENERATED RELATIONS:  [['Tokio Marine', 'OrgBased_In', 'United Nations']]
#
# -----------------------------------------
#
# DATE:  2023-05-29T12:00:00.000Z
# TEXT:  Artificial intelligence means everyone can now be a computer programmer as all they need to do is speak to the computer, Nvidia Corp CEO Jensen Huang said on Monday, hailing the end of the "digital divide".
# GENERATED RELATIONS:  [['Jensen Huang', 'Work_For', 'Nvidia Corp']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  North Korea will launch its first military reconnaissance satellite in June for monitoring U.S. activities, state media KCNA reported on Tuesday, drawing criticism over its potential use of banned missile technology.
# GENERATED RELATIONS:  [['North Korea', 'OrgBased_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Clashes subsided in Sudan's capital on Tuesday though fighting could be heard in some areas, residents said, after military factions battling for more than six weeks agreed to extend a ceasefire aimed at allowing aid to reach civilians.
# GENERATED RELATIONS:  [['Sudan', 'Located_In', 'Sudan']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  There used to be one family in Fanna Hamit's compound, now there are 11 families struggling to get by selling roasted crickets after she took in relatives fleeing the conflict in Sudan.
# GENERATED RELATIONS:  [['Fanna Hamit', 'Live_In', 'Sudan']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  A Libyan court sentenced 23 people to death and another 14 to life in prison on Monday for their role in a deadly Islamic State militant campaign that included beheading a group of Egyptian Christians and seizing the city of Sirte in 2015.
# GENERATED RELATIONS:  [['Islamic State', 'OrgBased_In', 'Libya']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  A bipartisan deal to raise the $31.4 trillion debt ceiling faces its first test in Congress on Tuesday, setting up what could be a nail-biting week of voting before the US runs out of money to pay its bills.
# GENERATED RELATIONS:  [['Congress', 'OrgBased_In', 'United States']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  U.S. holiday air passenger travel topped 2019 pre-COVID levels over the Memorial Day weekend, which typically marks the start of the busy U.S. summer air travel season, figures from the U.S. Transportation Security Administration (TSA) showed on Tuesday.
# GENERATED RELATIONS:  [['U.S. Transportation Security Administration', 'OrgBased_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-29T12:00:00.000Z
# TEXT:  Mexico's ruling party next month looks likely to seize one of the last major opposition strongholds in a gubernatorial election that could also help determine its candidate to succeed leftist President Andres Manuel Lopez Obrador next year.
# GENERATED RELATIONS:  [['Andres Manuel Lopez Obrador', 'Live_In', 'Mexico']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Australian special forces soldier Ben Roberts-Smith was lauded as a hero and awarded Australia's highest military honour for "conspicuous gallantry" during a 2010 attack on two Taliban machine-gun posts during his fifth tour of Afghanistan.
# GENERATED RELATIONS:  [['Ben Roberts-Smith', 'Live_In', 'Australia']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  The Miami Heat avoided becoming the first team to squander a 3-0 NBA playoff series lead after beating the Boston Celtics 103-84 in Game 7 of the Eastern Conference Finals on Monday.
# GENERATED RELATIONS:  [['Miami Heat', 'OrgBased_In', 'NBA']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Uganda's President Yoweri Museveni signed one of the world's toughest anti-LGBTQ laws, including the death penalty for "aggravated homosexuality", drawing Western condemnation and risking sanctions from aid donors.
# GENERATED RELATIONS:  [['Yoweri Museveni', 'Live_In', 'Uganda']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  The highest price target valued it at about $1.6 trillion, on par with Google-parent Alphabet.
# GENERATED RELATIONS:  [['Alphabet.', 'OrgBased_In', 'Google']]
#
# -----------------------------------------
#
# DATE:  2023-05-29T12:00:00.000Z
# TEXT:  Venezuelan President Nicolas Maduro and Brazilian leader Luis Inacio Lula de Silva on Monday assailed U.S. sanctions against Venezuela and Maduro said he hopes a regional South American summit in Brasilia will call for their removal.
# GENERATED RELATIONS:  [['Nicolas Maduro', 'Live_In', 'Venezuela'], ['Luis Inacio Lula de Silva', 'Live_In', 'Brazil']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  American sixth seed Coco Gauff recovered from an error-strewn start to begin her French Open quest with a 3-6 6-1 6-2 victory over Spain's Rebeka Masarova on Tuesday.
# GENERATED RELATIONS:  [['Coco Gauff', 'Live_In', 'America'], ['Rebeka Masarova', 'Live_In', 'Spain']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Fourth seed Casper Ruud coasted into the French Open second round with a 6-4 6-3 6-2 victory over Swedish qualifier Elias Ymer on Tuesday to kick off his bid for a second straight final in Paris.
# GENERATED RELATIONS:  [['Casper Ruud', 'Live_In', 'Paris']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Russian teenager Mirra Andreeva has been as cool as ice, cruising through three qualifying rounds and her first round match against Alison Riske-Amritraj at the French Open on Tuesday without dropping a set.
# GENERATED RELATIONS:  [['Mirra Andreeva', 'Live_In', 'Russia'], ['Alison Riske-Amritraj', 'Live_In', 'Russia']]
#
# -----------------------------------------
#
# DATE:  2023-05-29T12:00:00.000Z
# TEXT:  Funes and his justice minister were sentenced their ties with criminal groups and failure to comply with duties.
# GENERATED RELATIONS:  [['Funes', 'Work_For', 'justice minister']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  A renowned U.S. mountain guide, who recently achieved the rare feat of climbing Mount Everest and two nearby peaks in less than three weeks, said on Tuesday Nepal needs to do a better job of policing the world's highest mountain to save it from garbage.
# GENERATED RELATIONS:  [['Mount Everest', 'Located_In', 'U.S.']]
#
# -----------------------------------------
#
# DATE:  2023-05-27T00:00:00.000Z
# TEXT:  Kim Jong Un upgraded security on the Chinese and Russian frontiers, blocking routes for smugglers and defectors
# GENERATED RELATIONS:  [['Kim Jong Un', 'Live_In', 'North Korea']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T11:56:13.000Z
# TEXT:  A woman with a dog looks at her apartment building heavily damaged during a massive Russian drone strike in Kyiv, Ukraine. REUTERS/Valentyn Ogirenko
# GENERATED RELATIONS:  [['Kyiv', 'Located_In', 'Ukraine.'], ['Valentyn Ogirenko', 'Live_In', 'Kyiv'], ['REUTERS', 'OrgBased_In', 'Ukraine.']]
#
# -----------------------------------------
#
# DATE:  2023-05-30T12:00:00.000Z
# TEXT:  Bridget Magasu is the first to arrive for the training session, clutching a rugby ball while she waits for other members of her all-female rugby team to arrive.
# GENERATED RELATIONS:  [['Bridget Magasu', 'Work_For', 'all-female rugby team']]
#
# -----------------------------------------

# %%
df.to_csv("conll23_flan_test.csv", index=False)
