# %%
import os
from tqdm import tqdm
import json
import jsonlines
import pandas as pd
from collections import Counter
import random
import re
import ast

# %%
valid_relations = ("Kill", "Located_In", "Live_In", "Work_For", "OrgBased_In")

# %%
df = pd.read_csv("conll_flan_explanations_generated.csv")
# df = df.apply(lambda x: x.astype(str).str.lower())
df.head()
# Out:
#                                                 text  \
# 0  John Wilkes Booth , who assassinated President...
# 1  The opera company performed at the Palace of F...
# 2  In the field of mechanics , Wang Ziqiang at th...
# 3  Sun Hung Kai Properties , a Hong Kong construc...
# 4  Marie Magdefrau Ferraro , 50 , of Bethany , Co...
#
#                                          gold_labels  \
# 0  [['John Wilkes Booth', 'Kill', 'President Linc...
# 1  [['Palace of Fine Arts', 'Located_In', 'San Fr...
# 2  [['Wang Ziqiang', 'Work_For', 'Institute of Me...
# 3  [['Sun Hung Kai Properties', 'OrgBased_In', 'H...
# 4  [['Marie Magdefrau Ferraro', 'Live_In', 'Betha...
#
#                                            generated
# 0  [['John Wilkes Booth', 'Kill', 'President Linc...
# 1  [['Palace of Fine Arts', 'OrgBased_In', 'San F...
# 2  [['Wang Ziqiang', 'Work_For', 'Institute of Me...
# 3  [['Sun Hung Kai Properties', 'OrgBased_In', 'H...
# 4  [['Marie Magdefrau Ferraro', 'Live_In', 'Betha...

# %%
print ("TOTAL ROWS: ", len(df))

text = []
gold = []
unique_types = set()
generated = []

c = Counter()

errors = 0
for ix, row in df.iterrows():
    try:
        t = ast.literal_eval(row["gold_labels"])
        g = ast.literal_eval(row["generated"])
        for r in g:
            c[r[1]] += 1
            if r[1] not in unique_types:
                unique_types.add(r[1])
            if r[1] not in valid_relations:
                errors += 1
                raise Exception("Invalid relation")
        print (row["text"])
        print ("GOLD: ", t)
        print ("GENERATED", g)
        text.append(row["text"])
        gold.append(t)
        generated.append(g)
    except:
        errors += 1
        print ("ERROR SOMEWHERE")
        print (row["text"])
        print ("GOLD: ", row["gold_labels"])
        print ("GENERATED", row["generated"])
        df.drop(ix, inplace=True)
    print ("\n-----------------------\n")

df = pd.DataFrame({"text": text, "gold": gold, "generated": generated})
# Out:
# TOTAL ROWS:  231
# John Wilkes Booth , who assassinated President Lincoln , was an actor .
# GOLD:  [['John Wilkes Booth', 'Kill', 'President Lincoln']]
# GENERATED [['John Wilkes Booth', 'Kill', 'President Lincoln']]
#
# -----------------------
#
# ERROR SOMEWHERE
# The opera company performed at the Palace of Fine Arts , in San Francisco , on June 30 and July 1-2 , said Kevin O 'Brien , a spokesman for the theater.
# GOLD:  [['Palace of Fine Arts', 'Located_In', 'San Francisco']]
# GENERATED [['Palace of Fine Arts', 'OrgBased_In', 'San Francisco'], ['Kevin O'Brien', 'Work_For', 'the Palace of Fine Arts'], ['Kevin O'Brien', 'Live_In', 'San Francisco']]
#
# -----------------------
#
# In the field of mechanics , Wang Ziqiang at the Institute of Mechanics has made considerable headway in the area of elastoplastic crack mechanics .
# GOLD:  [['Wang Ziqiang', 'Work_For', 'Institute of Mechanics']]
# GENERATED [['Wang Ziqiang', 'Work_For', 'Institute of Mechanics']]
#
# -----------------------
#
# Sun Hung Kai Properties , a Hong Kong construction firm with a 27 percent share ;
# GOLD:  [['Sun Hung Kai Properties', 'OrgBased_In', 'Hong Kong']]
# GENERATED [['Sun Hung Kai Properties', 'OrgBased_In', 'Hong Kong']]
#
# -----------------------
#
# Marie Magdefrau Ferraro , 50 , of Bethany , Conn. , was shot to death Thursday when two bandits armed with assault rifles emerged from nearby bushes and began firing at a van carrying a Connecticut Audubon Society wildlife wild tour group .
# GOLD:  [['Marie Magdefrau Ferraro', 'Live_In', 'Bethany'], ['Marie Magdefrau Ferraro', 'Live_In', 'Conn.'], ['Bethany', 'Located_In', 'Conn.']]
# GENERATED [['Marie Magdefrau Ferraro', 'Live_In', 'Bethany'], ['Magdefrau Ferraro', 'Live_In', 'Conn.'], ['Bethany', 'Located_In', 'Conn.']]
#
# -----------------------
#
# Ten oil workers were missing off Morgan City , La. , after their rig capsized while heading inland Monday to escape the storm.
# GOLD:  [['Morgan City', 'Located_In', 'La.']]
# GENERATED [['Morgan City', 'Located_In', 'La.']]
#
# -----------------------
#
# Lightning ignited a firestorm that charred 10 , 000 acres in central Idaho , including much of the small resort town of Lowman , about 70 miles northeast of Boise.
# GOLD:  [['Lowman', 'Located_In', 'Idaho']]
# GENERATED [['Lotman', 'Located_In', 'Idaho']]
#
# -----------------------
#
# " It ( Arrow ) is not practical in the short term , " says former Air Force commander Avihu Bin-Nun .
# GOLD:  [['Avihu Bin-Nun', 'Work_For', 'Air Force']]
# GENERATED [['Avihu Bin-Nun', 'Work_For', 'Air Force']]
#
# -----------------------
#
# The three reactors , all at the Savannah River Plant , in Aiken , S.C. , have been shut down since last April undergoing changes to make them safer .
# GOLD:  [['Savannah River Plant', 'Located_In', 'Aiken'], ['Savannah River Plant', 'Located_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# GENERATED [['Savana River Plant', 'OrgBased_In', 'Aiken'], ['Savana River Plant', 'OrgBased_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
#
# -----------------------
#
# Composer Thomas is a native of Chisholm , Minn .
# GOLD:  [['Thomas', 'Live_In', 'Chisholm'], ['Thomas', 'Live_In', 'Minn .'], ['Chisholm', 'Located_In', 'Minn .']]
# GENERATED [['Thomas', 'Live_In', 'Chisholm, Minn']]
#
# -----------------------
#
# Illinois Gov. James Thompson signed legislation last month scrapping Chicago 's central school board next July , to be replaced by parent-run councils empowered to set budgets and hire and fire principals .
# GOLD:  [['James Thompson', 'Live_In', 'Illinois']]
# GENERATED [['James Thompson', 'Live_In', 'Illinois']]
#
# -----------------------
#
# During the 10-hour rescue , diver Brian Michaud of Millinocket hooked the men to harnesses , and rescuers dragged them to the surface with winches .
# GOLD:  [['Brian Michaud', 'Live_In', 'Millinocket']]
# GENERATED [['Brian Michaud', 'Live_In', 'Millinocket']]
#
# -----------------------
#
# The Warren Commission found Oswald acted alone in killing Kennedy .
# GOLD:  [['Oswald', 'Kill', 'Kennedy']]
# GENERATED [['Oswald', 'Kill', 'Kennedy']]
#
# -----------------------
#
# ( By Yang Jianbai ( 2799 1017 4101 ) of the Economic Research
# GOLD:  [['Yang Jianbai', 'Work_For', 'Economic Research']]
# GENERATED [['Yang Jianbai', 'Work_For', 'Economic Research']]
#
# -----------------------
#
# ` ` He was going pretty fast , wasn 't he ? ' ' said Daniel Urquhart , 8 , of Aumsville , whose slug crept to the championship.
# GOLD:  [['Daniel Urquhart', 'Live_In', 'Aumsville']]
# GENERATED [['Daniel Urquhart', 'Live_In', 'Aumsville']]
#
# -----------------------
#
# Kovacevic , a Serb , has come under fire from Serbian politicians and the republic 's press since the U.S. Congress last month passed two resolutions claiming there were human rights violations in the strife-torn southern province of Kosovo.
# GOLD:  [['Congress', 'OrgBased_In', 'U.S.']]
# GENERATED [['Kovacevic', 'Live_In', 'Serbia']]
#
# -----------------------
#
# Martin Luther King III , a son of the slain civil rights leader , said the execution of King assassin James Earl Ray ` ` would not bring my father back. ' '
# GOLD:  [['James Earl Ray', 'Kill', 'Martin Luther King III']]
# GENERATED [['James Earl Ray', 'Kill', 'Martin Luther King III']]
#
# -----------------------
#
# On this date : In 1833 , Benjamin Harrison , the 23rd President of the United States , was born in North Bend , Ohio .
# GOLD:  [['Benjamin Harrison', 'Live_In', 'North Bend , Ohio']]
# GENERATED [['Benjamin Harrison', 'Live_In', 'North Bend, Ohio']]
#
# -----------------------
#
# The book said Khrushchev 's order to ignore the blockade was disclosed in a largely unknown work by dissident Soviet historian Roy Medvedev .
# GOLD:  [['Khrushchev', 'Live_In', 'Soviet'], ['Roy Medvedev', 'Live_In', 'Soviet']]
# GENERATED [['Roy Medvedev', 'Live_In', 'Soviet']]
#
# -----------------------
#
# EDITOR 'S NOTE : Walter R. Mears , vice and columnist for The Associated Press , has reported on Washington and national politics for more than 25 years .
# GOLD:  [['Walter R. Mears', 'Work_For', 'The Associated Press']]
# GENERATED [['Walter R. Mears', 'Work_For', 'The Associated Press']]
#
# -----------------------
#
# ` ` The Germans just tunneled like rabbits , ' ' said Gerald Przenislawski , who operates La Valette Underground Military Museum.
# GOLD:  [['Gerald Przenislawski', 'Work_For', 'La Valette Underground Military Museum.']]
# GENERATED [['Gerald Przenislawski', 'Work_For', 'La Valette Underground Military Museum']]
#
# -----------------------
#
# ` ` With South Carolina being Jesse Jackson 's home state , there was a very strong incentive in the black community. ' '
# GOLD:  [['Jesse Jackson', 'Live_In', 'South Carolina']]
# GENERATED [['Jesse Jackson', 'Live_In', 'South Carolina']]
#
# -----------------------
#
# Photo , Dueling Over a GunIt is a scene seared into the memories of Americans old enough to have watched it that November day in 1963 : Jack Ruby firing his .38-caliber Colt Cobra , above , at Lee Harvey Oswald , the man who had assassinated President John F. Kennedy two days earlier.
# GOLD:  [['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# GENERATED [['Lee Harvey Oswald', 'Kill', 'President John F. Kennedy']]
#
# -----------------------
#
# In a statement at the airport before his departure , Cetin said that Turkey welcomed this step taken by Bosnians and Croats and hoped that real peace comes to Bosnia-Herzegovina when Serbs join this process too .
# GOLD:  [['Cetin', 'Live_In', 'Turkey']]
# GENERATED [['Cetin', 'Live_In', 'Turkey']]
#
# -----------------------
#
# On Friday , U.S. Ambassador Vernon A. Walters displayed photographs of one Libyan jet showing shapes resembling missile pods on its wings and fuselage .
# GOLD:  [['Vernon A. Walters', 'Live_In', 'U.S.']]
# GENERATED [['Vernon A. Walters', 'Live_In', 'U.S.']]
#
# -----------------------
#
# Ms. Carpenter 's brother , retired National Football League placekicker Mark Moseley , was in the courtroom Wednesday and told reporters afterward , ` ` It 's been nine years of hell for myself and my family. ' '
# GOLD:  [['Mark Moseley', 'Work_For', 'National Football League']]
# GENERATED [['Mark Moseley', 'Work_For', 'National Football League']]
#
# -----------------------
#
# Hernandez Galicia 's allegedly corrupt Mexican Oil Workers Union controls more than half the lucrative drilling contracts issued by the state oil monopoly , Pemex .
# GOLD:  [['Hernandez Galicia', 'Work_For', 'Mexican Oil Workers Union']]
# GENERATED [['Hernandez Galicia', 'Work_For', 'Mexican Oil Workers Union'], ['Mexican Oil Workers Union', 'OrgBased_In', 'Hernandez Galicia'], ['Mexican Oil Workers Union', 'OrgBased_In', 'Mexico'], ['Pemex', 'OrgBased_In', 'Mexico']]
#
# -----------------------
#
# You 'll pass through Rolling Fork , where Muddy Waters was born , close to Greenville , home of Nelson Street 's funky strip of blues clubs , and into Clarksdale , at the intersection of Highway 61 and another major road in blues lore , U.S. Highway 49. ;
# GOLD:  [['Muddy Waters', 'Live_In', 'Rolling Fork']]
# GENERATED [['Muddy Waters', 'Live_In', 'Rolling Fork']]
#
# -----------------------
#
# ` ` The Challenger accident marked a major change in the U.S. outlook and policies with respect to the flight of other than NASA astronauts , ' ' the National Aeronautics and Space Administration said in a policy statement .
# GOLD:  [['NASA', 'OrgBased_In', 'U.S.'], ['National Aeronautics and Space Administration', 'OrgBased_In', 'U.S.']]
# GENERATED [['NASA', 'OrgBased_In', 'U.S.']]
#
# -----------------------
#
# ` ` It 's not going to make you a whole bunch of money , but that 's not why we 're doing it , ' ' said Phil Fuhrer , vice of Gannett New Media. 1-900-WEATHER offers callers the current weather and a three-day forecast , plus skiing and highway conditions in the winter and coastal reports during the summer.
# GOLD:  [['Phil Fuhrer', 'Work_For', 'Gannett New Media.']]
# GENERATED [['Phil Fuhrer', 'Work_For', 'Gainnet New Media']]
#
# -----------------------
#
# PA2904034294 Guatemala City Teleonce Television in Spanish 0400 GMT 26 Apr 94
# GOLD:  [['Teleonce Television', 'OrgBased_In', 'Guatemala City']]
# GENERATED [['Teleonce Television', 'OrgBased_In', 'Guatemala City']]
#
# -----------------------
#
# DAYTON , Ohio ( AP )
# GOLD:  [['DAYTON', 'Located_In', 'Ohio'], ['AP', 'OrgBased_In', 'DAYTON'], ['AP', 'OrgBased_In', 'Ohio']]
# GENERATED [['Dayton', 'Located_In', 'Ohio']]
#
# -----------------------
#
# In 1865 , four people were hanged in Washington , D.C. , after being convicted of conspiring with John Wilkes Booth in the assassination of President Lincoln .
# GOLD:  [['John Wilkes Booth', 'Kill', 'President Lincoln']]
# GENERATED [['John Wilkes Booth', 'Kill', 'President Lincoln']]
#
# -----------------------
#
# San Gabriel River Channel , Azusa , Calif. ;
# GOLD:  [['San Gabriel River Channel', 'Located_In', 'Azusa'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azusa', 'Located_In', 'Calif.']]
# GENERATED [['San Gabriel River Channel', 'Located_In', 'Azure'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azure', 'Located_In', 'Calif.']]
#
# -----------------------
#
# He said that the Phnom Penh government has worked out several incentives to attract foreign investment in Cambodia .
# GOLD:  [['Phnom Penh government', 'OrgBased_In', 'Cambodia']]
# GENERATED [['Phnom Penh', 'OrgBased_In', 'Cambodia']]
#
# -----------------------
#
# Derwinski , a Republican from Chicago who served 24 years in Congress , publicly denied 1978 allegations that he leaked the information and refused to testify in the matter before a federal grand jury and the House Ethics Committee .
# GOLD:  [['Derwinski', 'Live_In', 'Chicago'], ['Derwinski', 'Work_For', 'Congress']]
# GENERATED [['Derwinski', 'Work_For', 'Congress']]
#
# -----------------------
#
# BANGKOK , Thailand ( AP )
# GOLD:  [['BANGKOK', 'Located_In', 'Thailand'], ['AP', 'OrgBased_In', 'BANGKOK'], ['AP', 'OrgBased_In', 'Thailand']]
# GENERATED [['BANGKOK', 'Located_In', 'Thailand'], ['AP', 'OrgBased_In', 'BANGKOK'], ['AP', 'OrgBased_In', 'Thailand']]
#
# -----------------------
#
# ( Text ) Police Major Pramot Pansakun , the commander of the Region 2 Border Patrol Police ( BPP ) , Khon Kaen , and Thai and American narcotics suppression officials accompanied by reporters , spent more than 2 hours climbing a high mountain to destroy a Hmong poppy field located along the border between Dan Sai District in Loei Province , Nakhon Thai District in Phitsanulok Province , and Lomsak District in Phetchabun Province .
# GOLD:  [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Dan Sai District', 'Located_In', 'Loei Province'], ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province'], ['Lomsak District', 'Located_In', 'Phetchabun Province']]
# GENERATED [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Pramot Pansakun', 'Work_For', 'Border Patrol'], ['Pramot Pansakun', 'Work_For', 'BPP']]
#
# -----------------------
#
# Further buying was linked to rumors that the Chilean copper company Codelco was considering shutting down its smelter at Chuquicamata , the world 's largest copper mine , due to persistent mechanical problems , said Fred Demler , metals economist with Drexel Burnham Lambert Inc. in New York .
# GOLD:  [['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.'], ['Fred Demler', 'Live_In', 'New York'], ['Drexel Burnham Lambert Inc.', 'OrgBased_In', 'New York']]
# GENERATED [['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.'], ['Fred Demler', 'Live_In', 'New York']]
#
# -----------------------
#
# An urgent call for international help to avert food shortages in Poland went out both from last month 's Western economic summit in Paris and from Monday 's meeting in Brussels of 24 concerned nations chaired by the European Community Commission.
# GOLD:  [['European Community Commission.', 'OrgBased_In', 'Brussels']]
# GENERATED [['European Community', 'OrgBased_In', 'Paris']]
#
# -----------------------
#
# Cheek , 53 , is a former chief and charge in Addis Ababa , Ethiopia.
# GOLD:  [['Addis Ababa', 'Located_In', 'Ethiopia.']]
# GENERATED [['Cheek', 'Live_In', 'Addis Ababa'], ['Cheek', 'Live_In', 'Ethiopia.'], ['Addis Ababa', 'Located_In', 'Ethiopia.']]
#
# -----------------------
#
# In 1881 , President James A. Garfield was shot by Charles J. Guiteau , a disappointed office-seeker , at the Washington railroad station .
# GOLD:  [['Charles J. Guiteau', 'Kill', 'President James A. Garfield']]
# GENERATED [['Charles J. Guiteau', 'Kill', 'President James A. Garfield']]
#
# -----------------------
#
# Middle-class Argentines , among the most affluent in Latin America at one time , are so strapped now that they are selling off heirlooms that had been in their families since the days when beef and grain made Argentina one of the world 's wealthiest nations.
# GOLD:  [['Argentina', 'Located_In', 'Latin America']]
# GENERATED [['Argentines', 'Live_In', 'Argentina'], ['Argentina', 'Live_In', 'Lat. America']]
#
# -----------------------
#
# ` ` I don 't think there are any good answers why , ' ' said Virginia Towle of Wallingford , a family friend.
# GOLD:  [['Virginia Towle', 'Live_In', 'Wallingford']]
# GENERATED [['Virginia Towle', 'Live_In', 'Wildenbrook']]
#
# -----------------------
#
# The meeting will be held at the request of the Soviet Union , which also plans direct talks with resistance leader Prince Norodom Sihanouk , said Sihanouk 's son and representative in Thailand , Prince Norodom Ranariddh .
# GOLD:  [['Prince Norodom Ranariddh', 'Live_In', 'Thailand']]
# GENERATED [['Pearl Norodom Sihanouk', 'Live_In', 'Soviet Union'], ['Prince Norodom Ranariddh', 'Live_In', 'Thailand']]
#
# -----------------------
#
# Hundreds of children and adults sporting cowboy boots and hats turned out Wednesday to watch as Winterset 's busiest street was named for John Wayne , the community 's most famous native son .
# GOLD:  [['John Wayne', 'Live_In', 'Winterset']]
# GENERATED [['John Wayne', 'Live_In', 'Winterset']]
#
# -----------------------
#
# River North 's nouvelle sensibilities also might be offended by the Ranch 's menu , which features items such as the ` ` Jesse James Steak ( A Steal ! ) , ' ' and the occasional ornery patron .
# GOLD:  [['Ranch', 'OrgBased_In', 'River North']]
# GENERATED [['River North', 'OrgBased_In', 'California'], ['River North', 'OrgBased_In', 'Maine'], ['Jesse James Steak', 'OrgBased_In', 'California'], ['Jesse James Steak', 'OrgBased_In', 'Maine']]
#
# -----------------------
#
# Police Find No Signs of Radiation Leak AU0202111694 Paris AFP in English 0107 GMT 2 Feb 94
# GOLD:  [['AFP', 'OrgBased_In', 'Paris']]
# GENERATED [['AFP', 'OrgBased_In', 'Paris']]
#
# -----------------------
#
# It was filmed on location in Tokyo and Kyoto and is a co-production of Children 's Television Worship and NHK network in Japan .
# GOLD:  [['Tokyo', 'Located_In', 'Japan'], ['Kyoto', 'Located_In', 'Japan']]
# GENERATED [['Tokyo', 'Located_In', 'Japan'], ['NHK network', 'OrgBased_In', 'Japan']]
#
# -----------------------
#
# The self-propelled rig Avco 5 with 14 people aboard was headed to shore early Monday when it capsized about 20 miles off the Louisiana coast , near Morgan City , Chevron spokesman Jonathan Lifa said.
# GOLD:  [['Jonathan Lifa', 'Work_For', 'Chevron']]
# GENERATED [['Avco 5', 'Located_In', 'Louisiana'], ['Jonas Lifa', 'Work_For', 'Chryslel'], ['Jonas Lifa', 'Work_For', 'Chevron'], ['Morgan City', 'Located_In', 'Louisiana']]
#
# -----------------------
#
# Sen. Jake Garn , R-Utah , flew on the shuttle in April 1985 and Rep. Bill Nelson , D-Fla. , was aboard in January 1986 , at the invitation of NASA 's administrator .
# GOLD:  [['Jake Garn', 'Work_For', 'NASA'], ['Bill Nelson', 'Work_For', 'NASA']]
# GENERATED [['Jake Garn', 'Work_For', 'NASA']]
#
# -----------------------
#
# Ten Soviet volunteers and their American counterparts plan to spend August in Washington building homes for the poor as a return favor for help in earthquake-devastated Soviet Armenia.
# GOLD:  [['Armenia.', 'Located_In', 'Soviet']]
# GENERATED [['Washington', 'Located_In', 'Soviet']]
#
# -----------------------
#
# Evaluating Juppe 's visit , Cetin said that the French Government was not displaying a disturbing stand toward Turkey and was very careful in not intervening in Turkey 's internal affairs .
# GOLD:  [['Juppe', 'Work_For', 'French Government'], ['Cetin', 'Live_In', 'Turkey'], ['Cetin', 'Live_In', 'Turkey']]
# GENERATED [['Cetin', 'Live_In', 'Turkey']]
#
# -----------------------
#
# Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
# GOLD:  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# GENERATED [['Juan Vicente Maldonado', 'Live_In', 'Ecuador'], ['Juan Vicente Maldonado', 'Work_For', 'Ecuador']]
#
# -----------------------
#
# Dole 's wife , Elizabeth , is a native of Salisbury , N.C .
# GOLD:  [['Elizabeth', 'Live_In', 'Salisbury , N.C']]
# GENERATED [['Elizabeth', 'Live_In', 'Salisbury, N.C']]
#
# -----------------------
#
# ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
# GOLD:  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# GENERATED [['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Union of Democratic Forces', 'OrgBased_In', 'Sofia'], ['SDS', 'OrgBased_In', 'Sofia']]
#
# -----------------------
#
# Starr , who served as counselor to Attorney William French Smith from 1981 prior to taking the bench in 1983 , had been mentioned as a possible Supreme Court nominee after his former colleague on the District of Columbia circuit , Robert Bork , failed to win Senate confirmation in 1987 .
# GOLD:  [['Supreme Court', 'OrgBased_In', 'District of Columbia'], ['Senate', 'OrgBased_In', 'District of Columbia']]
# GENERATED [['Starr', 'Work_For', 'Supreme Court'], ['Robert Bork', 'Work_For', 'District of Columbia circuit']]
#
# -----------------------
#
# The program , financed with a grant from the United States Agency for International Development , is aimed at reducing infant mortality in Madagascar , an island nation in the Indian Ocean off the eastern coast of Africa.
# GOLD:  [['Madagascar', 'Located_In', 'Indian Ocean']]
# GENERATED [['Madanic', 'Located_In', 'Indian Ocean']]
#
# -----------------------
#
# JN0704183294 Paris Radio Monte Carlo in Arabic 1700 GMT 7 Apr 94
# GOLD:  [['Radio Monte Carlo', 'OrgBased_In', 'Paris']]
# GENERATED [['Radio Monte Carlo', 'OrgBased_In', 'Paris']]
#
# -----------------------
#
# On this date : In 1533 , the last Incan King of Peru , Atahualpa , was murdered on the orders of Spanish conqueror Francisco Pizarro .
# GOLD:  [['Francisco Pizarro', 'Kill', 'Atahualpa']]
# GENERATED [['Francisco Pizarro', 'Kill', 'Atahualpa']]
#
# -----------------------
#
# ` ` We 'd play hearts for hours at a time , ' ' said Atlanta businessman Neil Estes.
# GOLD:  [['Neil Estes.', 'Live_In', 'Atlanta']]
# GENERATED [['Neil Estes.', 'Live_In', 'Atlanta']]
#
# -----------------------
#
# Minox has not shown a profit since 1981 , and on April 1 , 1988 , Robert C. Corduwener , a Netherlands businessman bought a 51 percent share of the company to take control from the Rinn family .
# GOLD:  [['Robert C. Corduwener', 'Live_In', 'Netherlands']]
# GENERATED [['Robert C. Corduwener', 'Live_In', 'Norway']]
#
# -----------------------
#
# Volcanoes in Nicaragua and Indonesia , deforestation in Brazil and Madagascar , the Sahara desert in Africa and global beach erosion are among the subjects to be photographed .
# GOLD:  [['Sahara desert', 'Located_In', 'Africa']]
# GENERATED [['Sahara desert', 'Located_In', 'Africa']]
#
# -----------------------
#
# ` ` This is really hurting Heuchelheim , ' ' the town 's mayor Willi Marx told The Associated Press in an interview at his office earlier this month .
# GOLD:  [['Willi Marx', 'Live_In', 'Heuchelheim']]
# GENERATED [['Willi Marx', 'Live_In', 'Heuchelheim']]
#
# -----------------------
#
# ` ` I think at this moment they fear making a wrong move _ whether they should seek political asylum or use other reasons to remain here , ' ' said Jeff Shia , president of the Kiangsu Chekiang Association , a non-profit group that helps new Chinese immigrants establish themselves in the city.
# GOLD:  [['Jeff Shia', 'Work_For', 'Kiangsu Chekiang Association']]
# GENERATED [['Jeff Shia', 'Work_For', 'Kiangsu Chekiang Association']]
#
# -----------------------
#
# The term ` ` 30 Seconds Over Tokyo ' ' was the title of a popular movie about the raid. _Anzio _ The Anzio beachhead , 33 miles south of Rome , saw some of the bloodiest fighting of World War II and accounted for many of the 10 , 000 U.S. battle deaths in Italy the first half of 1944 .
# GOLD:  [['Anzio', 'Located_In', 'Italy']]
# GENERATED [['Anzio', 'Located_In', 'Italy']]
#
# -----------------------
#
# Anna Sandhu Ray , who 10 years ago Thursday wed the man convicted of killing the Rev. Martin Luther King Jr. , said on her anniversary that she plans to divorce James Earl Ray .
# GOLD:  [['James Earl Ray', 'Kill', 'Rev. Martin Luther King Jr.']]
# GENERATED [['James Earl Ray', 'Kill', 'Rev. Martin Luther King Jr.']]
#
# -----------------------
#
# The 23-foot-tall statue was modeled after the 30-foot-tall Goddess of Democracy raised by Chinese pro-democracy demonstrators in Beijing 's Tiananmen Square on May 30.
# GOLD:  [['Tiananmen Square', 'Located_In', 'Beijing']]
# GENERATED [['Goddess of Democracy', 'Located_In', 'Beijing'], ['Tiananmen Square', 'Located_In', 'Beijing']]
#
# -----------------------
#
# ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
# GOLD:  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# GENERATED [['XINHUA', 'OrgBased_In', 'Ulanbaatar'], ['XINHUA', 'OrgBased_In', 'Mongolian']]
#
# -----------------------
#
# In 1874 , Herbert Clark Hoover , the 31st president of the United States , was born in West Branch , Iowa .
# GOLD:  [['Herbert Clark Hoover', 'Live_In', 'West Branch , Iowa']]
# GENERATED [['Herbert Clark Hoover', 'Live_In', 'West Branch, Iowa']]
#
# -----------------------
#
# ( Text ) The Rwandan Patriotic Front ( RPF ) has rescued 2 , 000 people in Bugesera in the southeastern part of Rwanda .
# GOLD:  [['Bugesera', 'Located_In', 'Rwanda']]
# GENERATED [['Bugesera', 'Located_In', 'Ruand']]
#
# -----------------------
#
# One of Warner 's lawyers , Andrew Hall of Miami , Fla. , confirmed Tuesday that Warner is trying to settle the case.
# GOLD:  [['Andrew Hall', 'Live_In', 'Miami'], ['Andrew Hall', 'Live_In', 'Fla.'], ['Miami', 'Located_In', 'Fla.']]
# GENERATED [['Andrew Hall', 'Live_In', 'Miami'], ['Andrew Hall', 'Live_In', 'Fla.']]
#
# -----------------------
#
# GRAND RAPIDS , Mich .
# GOLD:  [['GRAND RAPIDS', 'Located_In', 'Mich .']]
# GENERATED [['GRAND RAPIDS', 'Located_In', 'Mich.']]
#
# -----------------------
#
# New Jersey Gov. Thomas Kean , who is leaving office after two terms at the end of this year , was greeted with effuse public praise by his colleagues during the conference.
# GOLD:  [['Thomas Kean', 'Live_In', 'New Jersey']]
# GENERATED [['Thomas Kean', 'Live_In', 'New Jersey']]
#
# -----------------------
#
# ` ` The country was starved of resources , ' ' said Marcos Victorica , director of the Institute of Contemporary Studies.
# GOLD:  [['Marcos Victorica', 'Work_For', 'Institute of Contemporary Studies.']]
# GENERATED [['Marcos Victorica', 'Work_For', 'Institute of Contemporary Studies']]
#
# -----------------------
#
# Excess Lira Reportedly Causes Currency Crisis NC1901223094 London Kanal-6 Television in Turkish 1700 GMT 19 Jan 94
# GOLD:  [['Kanal-6 Television', 'OrgBased_In', 'London']]
# GENERATED [['Kanal-6 Television', 'OrgBased_In', 'London']]
#
# -----------------------
#
# " This is the Garrett place where John Wilkes Booth , assassin of Lincoln , was cornered by Union soldiers and killed April 26 , 1865 .
# GOLD:  [['John Wilkes Booth', 'Kill', 'Lincoln']]
# GENERATED [['John Wilkes Booth', 'Kill', 'Lincoln']]
#
# -----------------------
#
# BANGKOK , Thailand ( AP )
# GOLD:  [['BANGKOK', 'Located_In', 'Thailand']]
# GENERATED [['BANGKOK', 'Located_In', 'Thailand'], ['AP', 'OrgBased_In', 'BANGKOK'], ['AP', 'OrgBased_In', 'Thailand']]
#
# -----------------------
#
# Joseph Cicippio , 58 , was acting comptroller at the American University of Beirut when he was kidnapped from the campus Sept. 12 , 1986.
# GOLD:  [['Joseph Cicippio', 'Work_For', 'American University of Beirut']]
# GENERATED [['Joe Cicippio', 'Work_For', 'American University']]
#
# -----------------------
#
# The Santa Ana winds _ also called ` ` devil winds ' ' _ are spun off by high pressure over the interior of the country , picking up speed as they move from Southern California 's deserts through mountain passes and roar down on adjacent communities .
# GOLD:  [['Santa Ana', 'Located_In', 'Southern California']]
# GENERATED [['Santa Ana winds', 'Located_In', 'Southern California']]
#
# -----------------------
#
# FL2706231194 Havana Radio Reloj Network in Spanish 1402 GMT 27 Jun 94
# GOLD:  [['Radio Reloj Network', 'OrgBased_In', 'Havana']]
# GENERATED [['Radio Reloj Network', 'OrgBased_In', 'Havana']]
#
# -----------------------
#
# ` ` Our white paper , market pulp and packaging businesses turned in particularly impressive results in 1988 , ' ' said John A. Georges , International Paper 's chairman and chief executive officer .
# GOLD:  [['John A. Georges', 'Work_For', 'International Paper']]
# GENERATED [['John A. Georges', 'Work_For', 'International Paper']]
#
# -----------------------
#
# The FA-18 Hornet was on a mission to Pinecastle Electronic Warfare Range in the Ocala National Forest when the bomb tumbled free at 1 : 50 p.m .
# GOLD:  [['Pinecastle Electronic Warfare Range', 'Located_In', 'Ocala National Forest']]
# GENERATED [['Pinnacle Electronic Warfare Range', 'Located_In', 'Ocala National Forest']]
#
# -----------------------
#
# EAST LANSING , Mich.
# GOLD:  [['EAST LANSING', 'Located_In', 'Mich.']]
# GENERATED [['LANSING', 'Located_In', 'Mich.']]
#
# -----------------------
#
# Born in Athens , Psacharopoulos came to the United States at age 17 to enter Oberlin College , where he studied art history .
# GOLD:  [['Oberlin College', 'OrgBased_In', 'United States']]
# GENERATED [['Psacharopoulos', 'Live_In', 'Athens']]
#
# -----------------------
#
# Two days later , Perry operated on Kennedy 's assassin , Lee Harvey Oswald , who had just been shot by Jack Ruby .
# GOLD:  [['Lee Harvey Oswald', 'Kill', 'Kennedy'], ['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# GENERATED [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
#
# -----------------------
#
# The prime was accompanied by his wife , Datuk Sri Datin Paduka Dr. Siti Hasmah and the deputy secretary of the Foreign Ministry , Datuk Abdul Halim Ali , during his brief visit to South Africa .
# GOLD:  [['Datuk Abdul Halim Ali', 'Work_For', 'Foreign Ministry']]
# GENERATED [['Datuk Sri Datin Paduka Dr. Siti Hasmah', 'Work_For', 'Foreign Ministry'], ['Datuk Abdul Halim Ali', 'Work_For', 'Foreign Ministry']]
#
# -----------------------
#
# The federal appeals court previously overturned a key provision of Arizona 's death penalty statute in the case of John Harvey Adamson , convicted of murdering reporter Don Bolles .
# GOLD:  [['John Harvey Adamson', 'Kill', 'Don Bolles']]
# GENERATED [['John Harvey Adamson', 'Kill', 'Don Bolles']]
#
# -----------------------
#
# The movie 's script remains a secret , but Stone has said Kevin Costner will star as New Orleans prosecutor Jim Garrison , who said that Kennedy was the victim of an FBI and CIA conspiracy and that Lee Harvey Oswald , identified by a presidential commission as the lone assassin , was set up to take the blame. ;
# GOLD:  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# GENERATED [['Kenneth Costner', 'Kill', 'Kenneth Kennedy']]
#
# -----------------------
#
# Becton Dickinson sells needle containers to doctors and hospitals but may develop a container for home use , said Linda Schmitt , an assistant product manager.
# GOLD:  [['Linda Schmitt', 'Work_For', 'Becton Dickinson']]
# GENERATED [['Becton Dickinson', 'Work_For', 'Doctors'], ['Linda Schmitt', 'Work_For', 'Assist Product Manager']]
#
# -----------------------
#
# The police files on Kennedy 's shooting could shed new light on persistent questions about whether Sirhan Bishara Sirhan was the only gunman in the shooting .
# GOLD:  [['Sirhan Bishara Sirhan', 'Kill', 'Kennedy']]
# GENERATED [['Serhan Bishara Sirhan', 'Kill', 'Kennedy']]
#
# -----------------------
#
# NC1404123794 Cairo AL-AHALI in Arabic 6 Apr 94 p 6
# GOLD:  [['AL-AHALI', 'OrgBased_In', 'Cairo']]
# GENERATED [['AL-AHALI', 'OrgBased_In', 'Cairo']]
#
# -----------------------
#
# In 1936 , rock legend Buddy Holly was born Charles Hardin Holley in Lubbock , Texas .
# GOLD:  [['Buddy Holly', 'Live_In', 'Lubbock , Texas'], ['Charles Hardin Holley', 'Live_In', 'Lubbock , Texas']]
# GENERATED [['Buddy Holly', 'Live_In', 'Lucbock, Texas']]
#
# -----------------------
#
# Belli 's clients have included Jack Ruby , who killed John F. Kennedy assassin Lee Harvey Oswald , and Jim and Tammy Bakker .
# GOLD:  [['Jack Ruby', 'Kill', 'Lee Harvey Oswald'], ['Lee Harvey Oswald', 'Kill', 'John F. Kennedy']]
# GENERATED [['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
#
# -----------------------
#
# Bosnia 's capital , Sarajevo , is best-known as the site of the assassination in 1914 of Austrian Archduke Franz Ferdinand by young Bosnian nationalist Gavrilo Princip , which was the spark that ignited World War I. No single party appeared likely to win a clear majority in Bosnia 's 240-seat bicameral parliament .
# GOLD:  [['Sarajevo', 'Located_In', 'Bosnia'], ['Gavrilo Princip', 'Kill', 'Austrian Archduke Franz Ferdinand']]
# GENERATED [['Gavrilo Princip', 'Kill', 'Austrian Archduke Franz Ferdinand']]
#
# -----------------------
#
# Walesa said Solidarity wants to avoid unrest .
# GOLD:  [['Walesa', 'Work_For', 'Solidarity']]
# GENERATED [['So Solidarity', 'OrgBased_In', 'Wales']]
#
# -----------------------
#
# In 1817 , naturalist-author Henry David Thoreau was born in Concord , Mass .
# GOLD:  [['Henry David Thoreau', 'Live_In', 'Concord , Mass']]
# GENERATED [['Henry David Thoreau', 'Live_In', 'Concordia, Mass']]
#
# -----------------------
#
# The nine sentences noting the spot where Dallas was settled are followed by this : ` ` On Nov. 22 , 1963 , the building gained national notoriety when Lee Harvey Oswald allegedly shot and killed President John F. Kennedy from a sixth floor window as the presidential motorcade passed the site. ' '
# GOLD:  [['Lee Harvey Oswald', 'Kill', 'President John F. Kennedy']]
# GENERATED [['Lee Harvey Oswald', 'Kill', 'President John F. Kennedy']]
#
# -----------------------
#
# It almost makes me want to laugh. ( Minoli ) Why ? ( Fini ) Bossi is a very strange character and his extreme envy has been demonstrated. ( passage omitted ) He tried to get votes from the south , those votes which he now despises so much , but the south sent him back to the valleys. ( Minoli ) You said that Bossi reminded you of Hitler trapped in his Berlin bunker , a man with delusions of grandeur and a tendency towards suicide .
# GOLD:  [['Hitler', 'Live_In', 'Berlin']]
# GENERATED [['Bossi', 'Live_In', 'Berlin']]
#
# -----------------------
#
# ` ` One thing I have learned over the past 17 months is that the truth is hard to find , and it remains so , ' ' said Mrs. Higgins , 37 , who is a major inthe Marine Corps and works at the Pentagon as a public information officer.
# GOLD:  [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Pentagon']]
# GENERATED [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Potentially'], ['Mrs. Higgins', 'Work_For', 'Potentially'], ['Mrs. Higgins', 'Work_For', 'Potentially'], ['Mrs. Higgins', 'Work_For', 'Potentially'], ['Potentially', 'Work_For', 'Potentially']]
#
# -----------------------
#
# Sam Kadet of the corporate law firm of Skadden , Arps said Popeyes could give Church 's notice on Thursday that it planned to proceed with the takeover attempt and deliver the information to Church 's after five business days .
# GOLD:  [['Sam Kadet', 'Work_For', 'Skadden , Arps']]
# GENERATED [['Sam Kadet', 'Work_For', 'Skadden']]
#
# -----------------------
#
# Yisrael Tal , one of the top military strategists in Israel , says the Arabs have reached a strategic balance with Israel through their acquisition of ground-to-ground missiles .
# GOLD:  [['Yisrael Tal', 'Live_In', 'Israel'], ['Yisrael Tal', 'Live_In', 'Israel']]
# GENERATED [['Yisrael Tal', 'Live_In', 'Israel']]
#
# -----------------------
#
# Some people in the United States are saying that Clinton " gave away " $12 billion to Russia -- this is the amount it is proposed to pay for uranium destined for U.S. nuclear electric power stations , which will be obtained from our nuclear warheads .
# GOLD:  [['Clinton', 'Live_In', 'United States'], ['Clinton', 'Live_In', 'U.S.']]
# GENERATED [['Clinton', 'Live_In', 'United States']]
#
# -----------------------
#
# ERROR SOMEWHERE
# Guy M. Struve , the New York attorney representing Church 's , said he was disappointed and did not know when the chain would decide whether to appeal Thursday 's ruling .
# GOLD:  [['Guy M. Struve', 'Live_In', 'New York'], ['Guy M. Struve', 'Work_For', "Church 's"]]
# GENERATED [['Guy M. Struve', 'Live_In', 'New York'], ['Guy M. Struve', 'Work_For', 'Church's']]
#
# -----------------------
#
# A golden future seemed assured when , at 25 , Ogdon shared top place with Soviet pianist Vladimir Ashkenazy in the piano section of the 1962 Moscow Tchaikovsky International Competition for young musicians.
# GOLD:  [['Vladimir Ashkenazy', 'Live_In', 'Soviet']]
# GENERATED [['Tchaikovsky International Competition', 'OrgBased_In', 'Moscow'], ['Tchaikovsky International Competition', 'OrgBased_In', 'Moscow'], ['Tchaikovsky International Competition', 'OrgBased_In', 'Moscow']]
#
# -----------------------
#
# Illinois born Charlton Heston was a 27-year-old actor from Broadway and television when he arrived in Hollywood for a five-picture contract with Hal Wallis .
# GOLD:  [['Charlton Heston', 'Live_In', 'Illinois']]
# GENERATED [['Charlton Heston', 'Live_In', 'Illinois']]
#
# -----------------------
#
# The justices heard 60 minutes of arguments Wednesday on whether they will allow the execution of Johnny Paul Penry , 32 , a convicted rapist-murderer sentenced to die in Texas .
# GOLD:  [['Johnny Paul Penry', 'Live_In', 'Texas']]
# GENERATED [['Johnny Paul Penry', 'Live_In', 'Texas']]
#
# -----------------------
#
# 1911 , playwright Tennessee Williams was born in Columbus , Miss.
# GOLD:  [['Tennessee Williams', 'Live_In', 'Columbus , Miss.']]
# GENERATED [['Tennessee Williams', 'Live_In', 'Columbus, Miss.']]
#
# -----------------------
#
# BRISBANE , Australia ( AP )
# GOLD:  [['BRISBANE', 'Located_In', 'Australia'], ['AP', 'OrgBased_In', 'BRISBANE'], ['AP', 'OrgBased_In', 'Australia']]
# GENERATED [['BRISANBRIE', 'Located_In', 'Australia'], ['AP', 'OrgBased_In', 'BRISANBRIE'], ['AP', 'OrgBased_In', 'Australia']]
#
# -----------------------
#
# CNEN Radioprotection Director Laercio Vinhas yesterday reported by fax that the thyroid dysfunctions detected in the employees have no relation whatsoever with their work at the laboratory and that this problem is detected in 3 percent of the overall population .
# GOLD:  [['Laercio Vinhas', 'Work_For', 'CNEN']]
# GENERATED [['Laercio Vinhas', 'Work_For', 'CNEN']]
#
# -----------------------
#
# Photographer , author , filmmaker and composer Gordon Parks , 76 , born in Fort Scott , Kan. , who was on the photographic staff of Life Magazine for 19 years before branching out into other activities.
# GOLD:  [['Gordon Parks', 'Live_In', 'Fort Scott , Kan.']]
# GENERATED [['G Gordon Parks', 'Live_In', 'Fort Scott, Kan.']]
#
# -----------------------
#
# In 1830 , poet Emily Dickinson was born in Amherst , Mass.
# GOLD:  [['Emily Dickinson', 'Live_In', 'Amherst , Mass.']]
# GENERATED [['Emily Dickinson', 'Live_In', 'Amherst, Mass.']]
#
# -----------------------
#
# ` ` This is not a good idea for a lot of environmental reasons , ' ' Stephanie Powell , of the DEM 's division of groundwater and freshwater wetlands , said Tuesday.
# GOLD:  [['Stephanie Powell', 'Work_For', 'DEM']]
# GENERATED [['Stephanie Powell', 'Work_For', 'DEM']]
#
# -----------------------
#
# Nihat ( Marka ) , deputy leader of SHP ( Social Democrat Populist Party ) parliamentary group , said : They should have run in the elections for the sake of democracy .
# GOLD:  [['Nihat', 'Work_For', 'SHP'], ['Nihat', 'Work_For', 'Social Democrat Populist Party'], ['Marka', 'Work_For', 'SHP'], ['Marka', 'Work_For', 'Social Democrat Populist Party']]
# GENERATED [['Nihat', 'Work_For', 'SHP'], ['Marka', 'Work_For', 'SHP'], ['Nihat', 'Work_For', 'Social Democrat Populist Party']]
#
# -----------------------
#
# A statement from military headquarters said the aircraft crashed during a 260-mile flight to Khartoum from Kassala in eastern Sudan near the Ethiopian border.
# GOLD:  [['Kassala', 'Located_In', 'Sudan']]
# GENERATED [['Kansala', 'Located_In', 'Sudan']]
#
# -----------------------
#
# Harrington , a professor of political science at Queens College of the City University of New York and honorary president of the Socialist International , died Monday night at his home in suburban Larchmont , the university said in a statement Tuesday.
# GOLD:  [['Harrington', 'Work_For', 'Queens College'], ['Harrington', 'Work_For', 'City University of New York'], ['Harrington', 'Work_For', 'Socialist International'], ['Harrington', 'Live_In', 'Larchmont']]
# GENERATED [['Harrington', 'Work_For', 'Queens College'], ['Harrington', 'Work_For', 'City University of New York'], ['Harrington', 'Work_For', 'Socialist International']]
#
# -----------------------
#
# Norton Winfred Simon was born on Feb. 5 , 1907 , in Portland , Ore. , and spent his teen-age years in San Francisco .
# GOLD:  [['Norton Winfred Simon', 'Live_In', 'Portland , Ore.']]
# GENERATED [['Montgomery', 'Located_In', 'Portland, Ore.'], ['Montgomery', 'Live_In', 'Portland, Ore.']]
#
# -----------------------
#
# The National Aeronautics and Space Administration announced Thursday that Ulf D. Merbold , 47 , of the European Space Agency and Roger K. Crouch of NASA have been chosen to train to perform materials sciences experiments on the International Microgravity Laboratory-1 mission scheduled for April 1991 .
# GOLD:  [['Ulf D. Merbold', 'Work_For', 'European Space Agency'], ['Roger K. Crouch', 'Work_For', 'National Aeronautics and Space Administration'], ['Roger K. Crouch', 'Work_For', 'NASA']]
# GENERATED [['Ulf D. Merbold', 'Work_For', 'European Space Agency'], ['Roger K. Crouch', 'Work_For', 'NASA']]
#
# -----------------------
#
# Prime Minister Felipe Gonzalez of Spain told reporters , ` ` The police actions and the arrests are of great importance to Spanish society on such a major matter as the battle against terrorism. ' '
# GOLD:  [['Felipe Gonzalez', 'Live_In', 'Spain']]
# GENERATED [['Felipe Gonzalez', 'Live_In', 'Spain']]
#
# -----------------------
#
# In 1752 , flagmaker Betsy Ross was born in Philadelphia .
# GOLD:  [['Betsy Ross', 'Live_In', 'Philadelphia']]
# GENERATED [['Betsy Ross', 'Live_In', 'Philadelphia']]
#
# -----------------------
#
# This Latin American group 's reaction came two days after the military leaders of Haiti made Emile Jonassaint provisional president of Haiti , following the Haitian Parliament 's declaration that the post was vacant .
# GOLD:  [['Emile Jonassaint', 'Live_In', 'Haiti'], ['Emile Jonassaint', 'Live_In', 'Haiti'], ['Haitian Parliament', 'OrgBased_In', 'Haiti'], ['Haitian Parliament', 'OrgBased_In', 'Haiti']]
# GENERATED [['Emmel Jonassaint', 'Live_In', 'Haiti']]
#
# -----------------------
#
# No. 1 is the West Coast 's tallest building , the 76-story black-glass Columbia Seafirst Center built in 1985 , before downtown zoning went into effect .
# GOLD:  [['Columbia Seafirst Center', 'Located_In', 'West Coast']]
# GENERATED [['Columbia Seafirst Center', 'Located_In', 'West Coast']]
#
# -----------------------
#
# Yahia Bouguettaya , the former mayor of Mohammadia , south-east Algeria , and Mohamed Touali , an activist in Algeria 's Ettahadi ( Challenge ) political party , were assassinated Wednesday .
# GOLD:  [['Mohammadia', 'Located_In', 'Algeria'], ['Mohamed Touali', 'Work_For', 'Ettahadi ( Challenge ) political party'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria']]
# GENERATED [['Yahia Bouguettaya', 'Live_In', 'Mohammadia'], ['Mohamed Touali', 'Work_For', 'Ettahadi (Challenge)'], ['Ettahadi (Challenge)', 'OrgBased_In', 'Algeria']]
#
# -----------------------
#
# He developed evidence regarding the assassination of President Kennedy which supported the findings of the Warren Commission that Lee Harvey Oswald was the lone assassin .
# GOLD:  [['Lee Harvey Oswald', 'Kill', 'President Kennedy']]
# GENERATED [['Lee Harvey Oswald', 'Kill', 'President Kennedy']]
#
# -----------------------
#
# Montana : A fire burning in grassland and scattered timber in the Custer National Forest became the state 's biggest fire of the summer Tuesday when it surpassed 1 , 200 acres.
# GOLD:  [['Custer National Forest', 'Located_In', 'Montana']]
# GENERATED [['Custer National Forest', 'Located_In', 'Montana']]
#
# -----------------------
#
# JOHANNESBURG , South Africa ( AP )
# GOLD:  [['JOHANNESBURG', 'Located_In', 'South Africa']]
# GENERATED [['JOHANNESBURG', 'Located_In', 'South Africa']]
#
# -----------------------
#
# The PRAVDA newspaper carries an interview with Radovan Karadzic , leader of Bosnian Serbs and vice-president of the Union of Serb Writers .
# GOLD:  [['Radovan Karadzic', 'Work_For', 'Union of Serb Writers']]
# GENERATED [['Radovan Karadzic', 'Live_In', 'Bosnia and Herzegovina'], ['Radovan Karadzic', 'Work_For', 'Union of Serbian Writers']]
#
# -----------------------
#
# ( Text ) The National Central Organization of Panamanian Workers ( CNTP ) , which comprises three workers ' federations and 16 unions for a total of 12 , 000 workers , has proclaimed its determination to support Dr. Ernesto Perez Balladares for the presidency of the Republic .
# GOLD:  [['The National Central Organization of Panamanian Workers', 'OrgBased_In', 'the Republic'], ['CNTP', 'OrgBased_In', 'the Republic'], ['Ernesto Perez Balladares', 'Live_In', 'the Republic']]
# GENERATED [['The National Central Organization of Panamanian Workers', 'OrgBased_In', 'Panama'], ['Dr. Ernesto Perez Balladares', 'Live_In', 'Panama'], ['Dr. Ernesto Perez Balladares', 'Live_In', 'Republic']]
#
# -----------------------
#
# MOSKOVSKIY KOMSOMOLETS has learned from competent sources that the commission is supposed to pay special attention to Lazutkin , former first deputy general director of " Ostankino , " who currently holds the position of first deputy head of the Russian Federation Federal Service for Television and Radio Broadcasting.
# GOLD:  [['Lazutkin', 'Work_For', 'Russian Federation Federal Service for Television and Radio Broadcasting.']]
# GENERATED [['Lazutkin', 'Work_For', 'Russian Federation Federal Service for Television and Radio Broadcasting.']]
#
# -----------------------
#
# But trustee Daniel L. Bakst , a West Palm Beach , Fla. , lawyer , said he will not let the 11th-hour settlement efforts interfere with his assignment to track down Warner 's assets for distribution to creditors.
# GOLD:  [['Daniel L. Bakst', 'Live_In', 'West Palm Beach'], ['Daniel L. Bakst', 'Live_In', 'Fla.'], ['West Palm Beach', 'Located_In', 'Fla.']]
# GENERATED [['Daniel L. Bakst', 'Live_In', 'West Palm Beach'], ['Daniel L. Bakst', 'Live_In', 'Fla.'], ['West Palm Beach', 'Located_In', 'Fla.']]
#
# -----------------------
#
# Serbia is the largest of Yugoslavia 's six republics.
# GOLD:  [['Serbia', 'Located_In', 'Yugoslavia']]
# GENERATED [['Serbia', 'Located_In', 'Yugoslavia']]
#
# -----------------------
#
# Sirhan was convicted of Kennedy 's killing and is serving a life sentence .
# GOLD:  [['Sirhan', 'Kill', 'Kennedy']]
# GENERATED [['Sirhan', 'Kill', 'Kennedy']]
#
# -----------------------
#
# A mechanized infantry battalion belonging to the 21st Brigade of Cerro Muriano in Cordoba and to the 12th Brigade in Botoa in Badajoz , a company of the Special Operations Group in Alicante , and a squadron from the Jarama 1st Cavalry Brigade from Salamanca make up the Cordoba Group .
# GOLD:  [['21st Brigade of Cerro Muriano', 'OrgBased_In', 'Cordoba'], ['12th Brigade', 'OrgBased_In', 'Botoa'], ['12th Brigade', 'OrgBased_In', 'Badajoz'], ['Special Operations Group', 'OrgBased_In', 'Alicante'], ['Jarama 1st Cavalry Brigade', 'OrgBased_In', 'Salamanca']]
# GENERATED [['Cerro Muriano', 'OrgBased_In', 'Cordoba'], ['Cerro Muriano', 'Work_For', '21st Brigade'], ['12th Brigade', 'OrgBased_In', 'Botoa'], ['Badajoz', 'Located_In', 'Cordoba'], ['Badajoz', 'Located_In', 'Cordoba']]
#
# -----------------------
#
# Those honored were Jean Griffith , mother of a man killed on a Howard Beach , Queens , parkway after being chased by a gang of whites in December 1986 ;
# GOLD:  [['Howard Beach', 'Located_In', 'Queens']]
# GENERATED [['Howard Beach', 'Located_In', 'Queens']]
#
# -----------------------
#
# FBI agents arrived at Sohn 's New Jersey home and escorted him to safety only 30 minutes before KCIA agents showed up , an unidentified senior law enforcement official told the Times .
# GOLD:  [['Sohn', 'Live_In', 'New Jersey']]
# GENERATED [['Sohn', 'Live_In', 'New Jersey']]
#
# -----------------------
#
# Prime Brian Mulroney 's Progressive Conservative Party won its second consecutive majority government in the election , and he signed the trade pact with President Reagan in January 1988 .
# ...
#
# -----------------------
#
# ` ` ` Ryan 's Hope ' has not been rejected by the audience , it has simply been unavailable to viewers , ' ' Jo Ann Emmerich , vice president of daytime programs for ABC Entertainment , said at the time .
# GOLD:  [['Jo Ann Emmerich', 'Work_For', 'ABC Entertainment']]
# GENERATED [['Jo Ann Emmerich', 'Work_For', 'ABC Entertainment']]
#
# -----------------------
#
# On this date : In 1843 , the 25th President of the United States , William McKinley , was born in Niles , Ohio .
# GOLD:  [['William McKinley', 'Live_In', 'Niles , Ohio']]
# GENERATED [['William McKinley', 'Live_In', 'Niles, Ohio']]
#
# -----------------------
#
# Moscow MOSKOVSKIY KOMSOMOLETS
# GOLD:  [['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']]
# GENERATED [['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']]
#
# -----------------------
#
# In 1874 , Herbert Clark Hoover , the 31st president of the United States , was born in West Branch , Iowa .
# GOLD:  [['Herbert Clark Hoover', 'Live_In', 'West Branch , Iowa']]
# GENERATED [['Herbert Clark Hoover', 'Live_In', 'West Branch, Iowa']]
#
# -----------------------
#
# ERROR SOMEWHERE
# Many had hoped their loyality would convince the banks , primarily the Frankfurt-based Commerzbank and Giessen 's Bezirksparkasse bank , to continue to help Minox , but the hope backfired on those who were layed off , he said .
# GOLD:  [['Bezirksparkasse bank', 'OrgBased_In', 'Giessen']]
# GENERATED [['Commerzbank', 'OrgBased_In', 'Frankfurt'], ['Giessen's Bezirksparkasse bank', 'OrgBased_In', 'Frankfurt']]
#
# -----------------------
#
# An abstract theory explaining the structure of minimal surface in Riemann 's multi-dimensional space has been developed by Wang Guangyan , with the assistance of his PhD student , at the Institute of Mathematics .
# GOLD:  [['Wang Guangyan', 'Work_For', 'Institute of Mathematics']]
# GENERATED [['Wang Guangyan', 'Work_For', 'Institute of Mathematics']]
#
# -----------------------
#
# Owen Le Vallee , president of the Liberation Day Committee , said his mother found a starving German in the outhouse during the year after D-Day , the 1944 Allied invasion of Europe.
# GOLD:  [['Owen Le Vallee', 'Work_For', 'Liberation Day Committee']]
# GENERATED [['Owen Le Vallee', 'Work_For', 'Liberation Day Committee']]
#
# -----------------------
#
# KARBALA , Iraq ( AP )
# GOLD:  [['KARBALA', 'Located_In', 'Iraq'], ['AP', 'OrgBased_In', 'KARBALA'], ['AP', 'OrgBased_In', 'Iraq']]
# GENERATED [['AP', 'OrgBased_In', 'KARBALA'], ['AP', 'OrgBased_In', 'Iraq']]
#
# -----------------------
#
# Another beacon of the better life is Prateep Ungsongtham , known as the ` ` Slum Angel of Bangkok. ' '
# GOLD:  [['Prateep Ungsongtham', 'Live_In', 'Bangkok.']]
# GENERATED [['Prateeep Ungsongtham', 'Live_In', 'Bangkok']]
#
# -----------------------
#
# ( Text ) In an interview with Interfax the chief of Belarus 's Security Committee , Eduard Shirkovskiy , has dismissed rumors that the copies of the files relating to Lee Harvey Oswald , who was charged with having assassinated President John Kennedy , will be handed to President Bill Clinton during his visit to Minsk .
# GOLD:  [['Lee Harvey Oswald', 'Kill', 'President John Kennedy']]
# GENERATED [['Lee Harvey Oswald', 'Kill', 'President John Kennedy']]
#
# -----------------------
#
# Michael Henley Jr. , 10 , disappeared on a turkey hunt with his father in April 1988 in the mountains near their hometown of Grants , N.M. Ms. Calico , then 19 , disappeared five months later while bicycling on a country road near her hometown of Belen , N.M.
# GOLD:  [['Michael Henley Jr.', 'Live_In', 'Grants'], ['Michael Henley Jr.', 'Live_In', 'N.M.'], ['Grants', 'Located_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'Belen'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Belen', 'Located_In', 'N.M.']]
# GENERATED [['Ms. Calico', 'Live_In', 'Belen'], ['Michael Henley Jr.', 'Live_In', 'Grants'], ['Ms. Calico', 'Live_In', 'N.M.']]
#
# -----------------------
#
# ( Text ) Moscow April 25 TASS -- Preliminary marine pollution measurements taken from the sites of radioactive waste dumping by the former Soviet Union and Japan in the Sea of Japan did not reveal any Caesium-137 radioactive level fluctuations .
# GOLD:  [['TASS', 'OrgBased_In', 'Moscow']]
# GENERATED [['TASS', 'OrgBased_In', 'Moscow']]
#
# -----------------------
#
# Police arrested 10 Spanish Basque militants , including Jose Antonio Urutigoechea , considered by Madrid to be a top leader of the Spanish Basque separatist organization ETA , authorities said today .
# GOLD:  [['Jose Antonio Urutigoechea', 'Work_For', 'ETA']]
# GENERATED [['Joaquin Antonio Urutigoechea', 'Work_For', 'ETA']]
#
# -----------------------
#
# The Warren Commission concluded that Oswald , acting alone , fired the shots that killed Kennedy and wounded John Connally , then the Texas governor .
# GOLD:  [['Oswald', 'Kill', 'Kennedy']]
# GENERATED [['Oswald', 'Kill', 'Kennedy']]
#
# -----------------------
#
# The advisory committee voted 7-1 to recommend that the drug remain a prescription ingredient , said Susan Cruzan , an FDA spokeswoman.
# GOLD:  [['Susan Cruzan', 'Work_For', 'FDA']]
# GENERATED [['Susan Cruzan', 'Work_For', 'FDA']]
#
# -----------------------
#
# ` ` It 's been a nightmare , ' ' said Shelley Yeager , director of the Clara Barton camp at Oxford in central Massachusetts.
# GOLD:  [['Oxford', 'Located_In', 'Massachusetts.']]
# GENERATED [['Shandey Yeager', 'Live_In', 'Clara Barton'], ['Oxford', 'Located_In', 'Massachusetts.']]
#
# -----------------------
#
# And William McKinley 's assassin Leon Czolgosz croons " The Ballad of Czolgosz " from the electric chair .
# GOLD:  [['Leon Czolgosz', 'Kill', 'William McKinley']]
# GENERATED [['Leon Czolgosz', 'Kill', 'William McKinley']]
#
# -----------------------
#
# Yeltsin Orders Audit of Ostankino Finances MK1401103094 Moscow MOSKOVSKIY KOMSOMOLETS in Russian 14 Jan 94 p 1
# GOLD:  [['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']]
# GENERATED [['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']]
#
# -----------------------
#
# ` ` We are constantly getting confirmation that the U.S. economy is no longer in a boom phase , and that interest rates are falling , ' ' said a dealer at a U.S. bank in Frankfurt , West Germany.
# GOLD:  [['Frankfurt', 'Located_In', 'West Germany.']]
# GENERATED [['Frankfurt', 'Located_In', 'West Germany']]
#
# -----------------------
#
# In 1969 , Sirhan Sirhan was convicted of assassinating U.S. Sen. Robert F. Kennedy .
# GOLD:  [['Sirhan Sirhan', 'Kill', 'U.S. Sen. Robert F. Kennedy']]
# GENERATED [['Sirhan Sirhan', 'Kill', 'U.S. Sen. Robert F. Kennedy']]
#
# -----------------------
#
# Jesse Jackson easily won the Democratic precinct caucuses Saturday in his native South Carolina , while Sen. Bob Dole went on Illinois television for a half-hour plea for Republican votes in a state where he said he is the underdog .
# GOLD:  [['Jesse Jackson', 'Live_In', 'South Carolina']]
# GENERATED [['Jesse Jackson', 'Live_In', 'South Carolina']]
#
# -----------------------
#
# MEXICO CITY ( AP )
# GOLD:  [['AP', 'OrgBased_In', 'MEXICO CITY']]
# GENERATED [['AP', 'OrgBased_In', 'MEXICO CITY']]
#
# -----------------------
#
# Temperatures around the nation at 2 a.m. EST ranged from 2 degrees at Jackson , Wyo. , and Gunnison , Colo. , to 89 degrees at McAllen , Texas .
# GOLD:  [['Jackson', 'Located_In', 'Wyo.'], ['Gunnison', 'Located_In', 'Colo.'], ['McAllen', 'Located_In', 'Texas']]
# GENERATED [['Jackson', 'Located_In', 'Wyo.'], ['Gunnison', 'Located_In', 'Colo.'], ['McAllen', 'Located_In', 'Texas']]
#
# -----------------------
#
# ` ` We certainly believe it 's a prudent measure to go out and check to make sure there 's nothing wrong with the fleet , ' ' Boeing Commercial Airplanes spokesman Craig Martin said Wednesday in Seattle .
# GOLD:  [['Craig Martin', 'Work_For', 'Boeing Commercial Airplanes']]
# GENERATED [['Craig Martin', 'Work_For', 'Boeing Commercial Airplanes']]
#
# -----------------------
#
# As Rochester teacher union leader Adam Urbanski put it : ` ` We have set the table ; we have not served the meal yet. ' '
# GOLD:  [['Adam Urbanski', 'Live_In', 'Rochester']]
# GENERATED [['Adam Urbanski', 'Live_In', 'Rochester']]
#
# -----------------------
#
# Tokyo MAINICHI SHIMBUN
# GOLD:  [['MAINICHI SHIMBUN', 'OrgBased_In', 'Tokyo']]
# GENERATED [['MAINICHI SHIMBUN', 'OrgBased_In', 'Tokyo']]
#
# -----------------------
#
# If the elections had been held during the last 10 days of May , that is , after the debate , Fernandez de Cevallos would reportedly be the next president of Mexico with 33.2 percent of the vote .
# GOLD:  [['Fernandez de Cevallos', 'Live_In', 'Mexico']]
# GENERATED [['Fernandez de Cevallos', 'Live_In', 'Mexico']]
#
# -----------------------
#
# Authorities say Oswald opened fire from a sixth-floor window there into Kennedy 's motorcade .
# GOLD:  [['Oswald', 'Kill', 'Kennedy']]
# GENERATED [['Oswald', 'Kill', 'Kennedy']]
#
# -----------------------
#
# Meanwhile , the historical society in Beaumont , Texas , Richardson 's hometown , plans to raise two statues on Feb. 3 _ one of Buddy Holly , Richardson and Valens , and a second of the Big Bopper alone .
# GOLD:  [['Richardson', 'Live_In', 'Beaumont , Texas']]
# GENERATED [['Bearut', 'Located_In', 'Texas']]
#
# -----------------------
#
# At a briefing at NRC headquarters in nearby Rockville , Md. , Bernero said the volcanic cones in the area of Yucca Mountain have been a cause of concern for NRC experts.
# GOLD:  [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.'], ['Bernero', 'Work_For', 'NRC'], ['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.']]
# GENERATED [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.']]
#
# -----------------------
#
# ( Text ) Saint-Gall , Switzerland , Feb 2 ( AFP ) -- The wreck of a twin-engine aircraft has been found 160 metres below the surface of Lake Constance , Swiss police said Tuesday ( 1 February ) .
# GOLD:  [['Saint-Gall', 'Located_In', 'Switzerland'], ['AFP', 'OrgBased_In', 'Saint-Gall'], ['AFP', 'OrgBased_In', 'Switzerland']]
# GENERATED [['Stan-Gall', 'Located_In', 'Switzerland']]
#
# -----------------------
#
# According to the communique , clashes are continuing mainly in the Rancho Nuevo area at the military base in the southern Chiapas State .
# GOLD:  [['Rancho Nuevo', 'Located_In', 'Chiapas State']]
# GENERATED [['Rancho Nuevo', 'Located_In', 'Chiapas State']]
#
# -----------------------
#
# Dallas police arrested Oswald there on Nov. 22 , 1963 , after the assassination of President John F. Kennedy .
# GOLD:  [['Oswald', 'Kill', 'President John F. Kennedy']]
# GENERATED [['Oswald', 'Kill', 'President John F. Kennedy']]
#
# -----------------------
#
# In Washington state , near the Canadian border , firefighters hoped to contain an 850-acre fire by tonight , said Greg Thayer of the Forest Service.
# GOLD:  [['Greg Thayer', 'Work_For', 'Forest Service.']]
# GENERATED [['Washington state', 'Located_In', 'Canada'], ['Greg Thayer', 'Work_For', 'Forest Service']]
#
# -----------------------
#
# In an " electoral communique " signed by CNTP Secretary Luis Cobos R. , the organization said it hopes that with this decision " we will achieve the return of the Torrijist forces to power to stimulate the process of national liberation . "
# GOLD:  [['Luis Cobos R.', 'Work_For', 'CNTP']]
# GENERATED [['CNTP', 'OrgBased_In', 'Luis Cobos R.']]
#
# -----------------------
#
# In it , actor Edwin Booth tells us his version of his life story , in which he and not his brother John Wilkes shoots Abraham Lincoln at Ford 's Theater .
# GOLD:  [['John Wilkes', 'Kill', 'Abraham Lincoln']]
# GENERATED [['Edwin Booth', 'Kill', 'Abraham Lincoln']]
#
# -----------------------
#
# In 1801 , Mormon leader Brigham Young was born in Whitingham , Vt .
# GOLD:  [['Brigham Young', 'Live_In', 'Whitingham , Vt']]
# GENERATED [['Brigham Young', 'Live_In', 'Whitingham, Vt']]
#
# -----------------------
#
# The Warren Commission concluded that Lee Harvey Oswald , acting alone , fired the shots that killed Kennedy and wounded John Connally , then the Texas governor , on Nov. 22 , 1963 in Dallas .
# GOLD:  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# GENERATED [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
#
# -----------------------
#
# The spilled fuel covered an area two miles long and nearly a half-mile wide , said Whitefish City Attorney Tom Muri.
# GOLD:  [['Tom Muri.', 'Live_In', 'Whitefish City']]
# GENERATED [['Tom Muri.', 'Live_In', 'Whitefish City']]
#
# -----------------------
#
# In California 's Sierra Nevada foothills , firefighters today declared they had contained a fire that blackened 11 , 700 acres of brush and grassland and destroyed seven homes.
# GOLD:  [['Sierra Nevada', 'Located_In', 'California']]
# GENERATED [['Sierra Nevada', 'Located_In', 'California']]
#
# -----------------------
#
# " I was hearing the same story , " says James Hackett , an executive with Titan Systems and one of the leading missile experts in the U.S .
# GOLD:  [['James Hackett', 'Work_For', 'Titan Systems'], ['James Hackett', 'Live_In', 'U.S .']]
# GENERATED [['James Hackett', 'Work_For', 'Titan Systems']]
#
# -----------------------
#
# The quake leveled much of Leninakan , Armenia 's second-largest city 10 miles east of the Turkish border and left thousands homeless .
# GOLD:  [['Leninakan', 'Located_In', 'Armenia']]
# GENERATED [['Leninakan', 'Located_In', 'Armenia']]
#
# -----------------------
#
# Pittsburgh-Corning Corp. of Pittsburgh ;
# GOLD:  [['Pittsburgh-Corning Corp.', 'OrgBased_In', 'Pittsburgh']]
# GENERATED [['Pittsburgh-Corning Corp.', 'OrgBased_In', 'Pittsburgh']]
#
# -----------------------
#
# Barrett is a member of the Illinois Commerce Commission , and Marshall is a lawyer and former legislative aide to Patrick.
# GOLD:  [['Barrett', 'Work_For', 'Illinois Commerce Commission']]
# GENERATED [['Barrett', 'Work_For', 'Illinois Commerce Commission']]
#
# -----------------------
#
# ERROR SOMEWHERE
# During my recent tour , I met with Sultan Qabus Bin-Sa 'id of Oman .
# GOLD:  [["Sultan Qabus Bin-Sa 'id", 'Live_In', 'Oman']]
# GENERATED [['Sultan Qabus Bin-Sa 'id', 'Live_In', 'Oman']]
#
# -----------------------
#
# Ten years ago : James Earl Ray , convicted of assassinating Dr. Martin Luther King Jr. in 1968 , repeated his assertion at a Capitol Hill hearing that he did not commit the crime , saying he 'd been set up to take the blame by a mysterious man called Raoul .
# GOLD:  [['James Earl Ray', 'Kill', 'Dr. Martin Luther King Jr.']]
# GENERATED [['James Earl Ray', 'Kill', 'Dr. Martin Luther King Jr.']]
#
# -----------------------
#
# They will also be cleaning the car Oswald drove on the day Kennedy was shot and the ambulance that took Oswald to hospital after he was shot by Jack Ruby .
# GOLD:  [['Jack Ruby', 'Kill', 'Oswald']]
# GENERATED [['Oswald', 'Kill', 'Kennedy']]
#
# -----------------------
#
# Widespread street flooding was reported throughout Brazoria , Fort Bend , Galveston and southern Harris Counties in southeast Texas.
# GOLD:  [['Brazoria', 'Located_In', 'Texas.'], ['Fort Bend', 'Located_In', 'Texas.'], ['Galveston', 'Located_In', 'Texas.'], ['Harris Counties', 'Located_In', 'Texas.']]
# GENERATED [['Brazoria', 'Located_In', 'Fort Bend'], ['Fort Bend', 'Located_In', 'Galveston'], ['Harrisburg', 'Located_In', 'Texas'], ['Harrisburg', 'Located_In', 'Texas']]
#
# -----------------------
#
# LD2804174994 Moscow INTERFAX in English 1601 GMT 28 Apr 94
# GOLD:  [['INTERFAX', 'OrgBased_In', 'Moscow']]
# GENERATED [['INTERFAX', 'OrgBased_In', 'Moscow']]
#
# -----------------------
#
# Navy sources said the Coral Sea , on duty with the 6th Fleet in the Mediterranean , left ` ` a few hours ' ' ahead of its scheduled departure.
# GOLD:  [['6th Fleet', 'OrgBased_In', 'Mediterranean']]
# GENERATED [['Coral Sea', 'Located_In', 'Mediterranean']]
#
# -----------------------
#
# It is one of many deep below the arid surface , fed by underground channels that carry rainwater from the Najd plateau in northern Saudi Arabia to the west.
# GOLD:  [['Najd plateau', 'Located_In', 'Saudi Arabia']]
# GENERATED [['Najd plateau', 'Located_In', 'Saudi Arabia']]
#
# -----------------------

# %%
df.shape
# Out:
# (226, 3)

# %%
len(unique_types)
# Out:
# 6

# %%
c
# Out:
# Counter({'Kill': 40,
#          'Work_For': 76,
#          'OrgBased_In': 63,
#          'Live_In': 83,
#          'Located_In': 59,
#          'Creator': 1})

# %%
tp = ()

input = []
relations = []
prefix = []
gold_relations = []

count = 0
for row in df.iterrows():
    curr_tp = ()
    for t_triplet in row[1]["gold"]:
        if t_triplet in row[1]["generated"]:
            tp += (t_triplet,)
            curr_tp += (t_triplet,)
        else:
            for g_triplet in row[1]["generated"]:
                if ((str(t_triplet[0]) in str(g_triplet[0])) or (str(g_triplet[0]) in str(t_triplet[0]) )) and (( str(t_triplet[2]) in str(g_triplet[2])) or (str(g_triplet[2]) in str(t_triplet[2]) )) and ( str(t_triplet[1]) == str(g_triplet[1]) ):
                    tp += (g_triplet,)
                    curr_tp += (g_triplet,)
                    # print (row[1]["text"] + "\n")
                    # print ("TRUE: " + str(t_triplet))
                    # print ("PARTIAL TP GENERATED: " + str(g_triplet))
                    # print ("-----------------------------------------------")
    if len(curr_tp) > 0:
        count += 1
        print (row[1]["text"] + "\n")
        input.append(row[1]["text"])
        relations.append(list(curr_tp))
        prefix.append("CONLL04")
        gold_relations.append(row[1]["gold"])
        print ("TRUE (SET): ", row[1]["gold"])
        print ("TP (SET): ", list(curr_tp))
        print ("----------------")

print ("TOTAL TRUE RELATIONS: ", count)
# Out:
# John Wilkes Booth , who assassinated President Lincoln , was an actor .
#
# TRUE (SET):  [['John Wilkes Booth', 'Kill', 'President Lincoln']]
# TP (SET):  [['John Wilkes Booth', 'Kill', 'President Lincoln']]
# ----------------
# In the field of mechanics , Wang Ziqiang at the Institute of Mechanics has made considerable headway in the area of elastoplastic crack mechanics .
#
# TRUE (SET):  [['Wang Ziqiang', 'Work_For', 'Institute of Mechanics']]
# TP (SET):  [['Wang Ziqiang', 'Work_For', 'Institute of Mechanics']]
# ----------------
# Sun Hung Kai Properties , a Hong Kong construction firm with a 27 percent share ;
#
# TRUE (SET):  [['Sun Hung Kai Properties', 'OrgBased_In', 'Hong Kong']]
# TP (SET):  [['Sun Hung Kai Properties', 'OrgBased_In', 'Hong Kong']]
# ----------------
# Marie Magdefrau Ferraro , 50 , of Bethany , Conn. , was shot to death Thursday when two bandits armed with assault rifles emerged from nearby bushes and began firing at a van carrying a Connecticut Audubon Society wildlife wild tour group .
#
# TRUE (SET):  [['Marie Magdefrau Ferraro', 'Live_In', 'Bethany'], ['Marie Magdefrau Ferraro', 'Live_In', 'Conn.'], ['Bethany', 'Located_In', 'Conn.']]
# TP (SET):  [['Marie Magdefrau Ferraro', 'Live_In', 'Bethany'], ['Magdefrau Ferraro', 'Live_In', 'Conn.'], ['Bethany', 'Located_In', 'Conn.']]
# ----------------
# Ten oil workers were missing off Morgan City , La. , after their rig capsized while heading inland Monday to escape the storm.
#
# TRUE (SET):  [['Morgan City', 'Located_In', 'La.']]
# TP (SET):  [['Morgan City', 'Located_In', 'La.']]
# ----------------
# " It ( Arrow ) is not practical in the short term , " says former Air Force commander Avihu Bin-Nun .
#
# TRUE (SET):  [['Avihu Bin-Nun', 'Work_For', 'Air Force']]
# TP (SET):  [['Avihu Bin-Nun', 'Work_For', 'Air Force']]
# ----------------
# The three reactors , all at the Savannah River Plant , in Aiken , S.C. , have been shut down since last April undergoing changes to make them safer .
#
# TRUE (SET):  [['Savannah River Plant', 'Located_In', 'Aiken'], ['Savannah River Plant', 'Located_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# TP (SET):  [['Aiken', 'Located_In', 'S.C.']]
# ----------------
# Composer Thomas is a native of Chisholm , Minn .
#
# TRUE (SET):  [['Thomas', 'Live_In', 'Chisholm'], ['Thomas', 'Live_In', 'Minn .'], ['Chisholm', 'Located_In', 'Minn .']]
# TP (SET):  [['Thomas', 'Live_In', 'Chisholm, Minn']]
# ----------------
# Illinois Gov. James Thompson signed legislation last month scrapping Chicago 's central school board next July , to be replaced by parent-run councils empowered to set budgets and hire and fire principals .
#
# TRUE (SET):  [['James Thompson', 'Live_In', 'Illinois']]
# TP (SET):  [['James Thompson', 'Live_In', 'Illinois']]
# ----------------
# During the 10-hour rescue , diver Brian Michaud of Millinocket hooked the men to harnesses , and rescuers dragged them to the surface with winches .
#
# TRUE (SET):  [['Brian Michaud', 'Live_In', 'Millinocket']]
# TP (SET):  [['Brian Michaud', 'Live_In', 'Millinocket']]
# ----------------
# The Warren Commission found Oswald acted alone in killing Kennedy .
#
# TRUE (SET):  [['Oswald', 'Kill', 'Kennedy']]
# TP (SET):  [['Oswald', 'Kill', 'Kennedy']]
# ----------------
# ( By Yang Jianbai ( 2799 1017 4101 ) of the Economic Research
#
# TRUE (SET):  [['Yang Jianbai', 'Work_For', 'Economic Research']]
# TP (SET):  [['Yang Jianbai', 'Work_For', 'Economic Research']]
# ----------------
# ` ` He was going pretty fast , wasn 't he ? ' ' said Daniel Urquhart , 8 , of Aumsville , whose slug crept to the championship.
#
# TRUE (SET):  [['Daniel Urquhart', 'Live_In', 'Aumsville']]
# TP (SET):  [['Daniel Urquhart', 'Live_In', 'Aumsville']]
# ----------------
# Martin Luther King III , a son of the slain civil rights leader , said the execution of King assassin James Earl Ray ` ` would not bring my father back. ' '
#
# TRUE (SET):  [['James Earl Ray', 'Kill', 'Martin Luther King III']]
# TP (SET):  [['James Earl Ray', 'Kill', 'Martin Luther King III']]
# ----------------
# The book said Khrushchev 's order to ignore the blockade was disclosed in a largely unknown work by dissident Soviet historian Roy Medvedev .
#
# TRUE (SET):  [['Khrushchev', 'Live_In', 'Soviet'], ['Roy Medvedev', 'Live_In', 'Soviet']]
# TP (SET):  [['Roy Medvedev', 'Live_In', 'Soviet']]
# ----------------
# EDITOR 'S NOTE : Walter R. Mears , vice and columnist for The Associated Press , has reported on Washington and national politics for more than 25 years .
#
# TRUE (SET):  [['Walter R. Mears', 'Work_For', 'The Associated Press']]
# TP (SET):  [['Walter R. Mears', 'Work_For', 'The Associated Press']]
# ----------------
# ` ` The Germans just tunneled like rabbits , ' ' said Gerald Przenislawski , who operates La Valette Underground Military Museum.
#
# TRUE (SET):  [['Gerald Przenislawski', 'Work_For', 'La Valette Underground Military Museum.']]
# TP (SET):  [['Gerald Przenislawski', 'Work_For', 'La Valette Underground Military Museum']]
# ----------------
# ` ` With South Carolina being Jesse Jackson 's home state , there was a very strong incentive in the black community. ' '
#
# TRUE (SET):  [['Jesse Jackson', 'Live_In', 'South Carolina']]
# TP (SET):  [['Jesse Jackson', 'Live_In', 'South Carolina']]
# ----------------
# In a statement at the airport before his departure , Cetin said that Turkey welcomed this step taken by Bosnians and Croats and hoped that real peace comes to Bosnia-Herzegovina when Serbs join this process too .
#
# TRUE (SET):  [['Cetin', 'Live_In', 'Turkey']]
# TP (SET):  [['Cetin', 'Live_In', 'Turkey']]
# ----------------
# On Friday , U.S. Ambassador Vernon A. Walters displayed photographs of one Libyan jet showing shapes resembling missile pods on its wings and fuselage .
#
# TRUE (SET):  [['Vernon A. Walters', 'Live_In', 'U.S.']]
# TP (SET):  [['Vernon A. Walters', 'Live_In', 'U.S.']]
# ----------------
# Ms. Carpenter 's brother , retired National Football League placekicker Mark Moseley , was in the courtroom Wednesday and told reporters afterward , ` ` It 's been nine years of hell for myself and my family. ' '
#
# TRUE (SET):  [['Mark Moseley', 'Work_For', 'National Football League']]
# TP (SET):  [['Mark Moseley', 'Work_For', 'National Football League']]
# ----------------
# Hernandez Galicia 's allegedly corrupt Mexican Oil Workers Union controls more than half the lucrative drilling contracts issued by the state oil monopoly , Pemex .
#
# TRUE (SET):  [['Hernandez Galicia', 'Work_For', 'Mexican Oil Workers Union']]
# TP (SET):  [['Hernandez Galicia', 'Work_For', 'Mexican Oil Workers Union']]
# ----------------
# You 'll pass through Rolling Fork , where Muddy Waters was born , close to Greenville , home of Nelson Street 's funky strip of blues clubs , and into Clarksdale , at the intersection of Highway 61 and another major road in blues lore , U.S. Highway 49. ;
#
# TRUE (SET):  [['Muddy Waters', 'Live_In', 'Rolling Fork']]
# TP (SET):  [['Muddy Waters', 'Live_In', 'Rolling Fork']]
# ----------------
# ` ` The Challenger accident marked a major change in the U.S. outlook and policies with respect to the flight of other than NASA astronauts , ' ' the National Aeronautics and Space Administration said in a policy statement .
#
# TRUE (SET):  [['NASA', 'OrgBased_In', 'U.S.'], ['National Aeronautics and Space Administration', 'OrgBased_In', 'U.S.']]
# TP (SET):  [['NASA', 'OrgBased_In', 'U.S.']]
# ----------------
# PA2904034294 Guatemala City Teleonce Television in Spanish 0400 GMT 26 Apr 94
#
# TRUE (SET):  [['Teleonce Television', 'OrgBased_In', 'Guatemala City']]
# TP (SET):  [['Teleonce Television', 'OrgBased_In', 'Guatemala City']]
# ----------------
# In 1865 , four people were hanged in Washington , D.C. , after being convicted of conspiring with John Wilkes Booth in the assassination of President Lincoln .
#
# TRUE (SET):  [['John Wilkes Booth', 'Kill', 'President Lincoln']]
# TP (SET):  [['John Wilkes Booth', 'Kill', 'President Lincoln']]
# ----------------
# San Gabriel River Channel , Azusa , Calif. ;
#
# TRUE (SET):  [['San Gabriel River Channel', 'Located_In', 'Azusa'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azusa', 'Located_In', 'Calif.']]
# TP (SET):  [['San Gabriel River Channel', 'Located_In', 'Calif.']]
# ----------------
# He said that the Phnom Penh government has worked out several incentives to attract foreign investment in Cambodia .
#
# TRUE (SET):  [['Phnom Penh government', 'OrgBased_In', 'Cambodia']]
# TP (SET):  [['Phnom Penh', 'OrgBased_In', 'Cambodia']]
# ----------------
# Derwinski , a Republican from Chicago who served 24 years in Congress , publicly denied 1978 allegations that he leaked the information and refused to testify in the matter before a federal grand jury and the House Ethics Committee .
#
# TRUE (SET):  [['Derwinski', 'Live_In', 'Chicago'], ['Derwinski', 'Work_For', 'Congress']]
# TP (SET):  [['Derwinski', 'Work_For', 'Congress']]
# ----------------
# BANGKOK , Thailand ( AP )
#
# TRUE (SET):  [['BANGKOK', 'Located_In', 'Thailand'], ['AP', 'OrgBased_In', 'BANGKOK'], ['AP', 'OrgBased_In', 'Thailand']]
# TP (SET):  [['BANGKOK', 'Located_In', 'Thailand'], ['AP', 'OrgBased_In', 'BANGKOK'], ['AP', 'OrgBased_In', 'Thailand']]
# ----------------
# ( Text ) Police Major Pramot Pansakun , the commander of the Region 2 Border Patrol Police ( BPP ) , Khon Kaen , and Thai and American narcotics suppression officials accompanied by reporters , spent more than 2 hours climbing a high mountain to destroy a Hmong poppy field located along the border between Dan Sai District in Loei Province , Nakhon Thai District in Phitsanulok Province , and Lomsak District in Phetchabun Province .
#
# TRUE (SET):  [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Dan Sai District', 'Located_In', 'Loei Province'], ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province'], ['Lomsak District', 'Located_In', 'Phetchabun Province']]
# TP (SET):  [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police']]
# ----------------
# Further buying was linked to rumors that the Chilean copper company Codelco was considering shutting down its smelter at Chuquicamata , the world 's largest copper mine , due to persistent mechanical problems , said Fred Demler , metals economist with Drexel Burnham Lambert Inc. in New York .
#
# TRUE (SET):  [['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.'], ['Fred Demler', 'Live_In', 'New York'], ['Drexel Burnham Lambert Inc.', 'OrgBased_In', 'New York']]
# TP (SET):  [['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.'], ['Fred Demler', 'Live_In', 'New York']]
# ----------------
# Cheek , 53 , is a former chief and charge in Addis Ababa , Ethiopia.
#
# TRUE (SET):  [['Addis Ababa', 'Located_In', 'Ethiopia.']]
# TP (SET):  [['Addis Ababa', 'Located_In', 'Ethiopia.']]
# ----------------
# In 1881 , President James A. Garfield was shot by Charles J. Guiteau , a disappointed office-seeker , at the Washington railroad station .
#
# TRUE (SET):  [['Charles J. Guiteau', 'Kill', 'President James A. Garfield']]
# TP (SET):  [['Charles J. Guiteau', 'Kill', 'President James A. Garfield']]
# ----------------
# The meeting will be held at the request of the Soviet Union , which also plans direct talks with resistance leader Prince Norodom Sihanouk , said Sihanouk 's son and representative in Thailand , Prince Norodom Ranariddh .
#
# TRUE (SET):  [['Prince Norodom Ranariddh', 'Live_In', 'Thailand']]
# TP (SET):  [['Prince Norodom Ranariddh', 'Live_In', 'Thailand']]
# ----------------
# Hundreds of children and adults sporting cowboy boots and hats turned out Wednesday to watch as Winterset 's busiest street was named for John Wayne , the community 's most famous native son .
#
# TRUE (SET):  [['John Wayne', 'Live_In', 'Winterset']]
# TP (SET):  [['John Wayne', 'Live_In', 'Winterset']]
# ----------------
# Police Find No Signs of Radiation Leak AU0202111694 Paris AFP in English 0107 GMT 2 Feb 94
#
# TRUE (SET):  [['AFP', 'OrgBased_In', 'Paris']]
# TP (SET):  [['AFP', 'OrgBased_In', 'Paris']]
# ----------------
# It was filmed on location in Tokyo and Kyoto and is a co-production of Children 's Television Worship and NHK network in Japan .
#
# TRUE (SET):  [['Tokyo', 'Located_In', 'Japan'], ['Kyoto', 'Located_In', 'Japan']]
# TP (SET):  [['Tokyo', 'Located_In', 'Japan']]
# ----------------
# Sen. Jake Garn , R-Utah , flew on the shuttle in April 1985 and Rep. Bill Nelson , D-Fla. , was aboard in January 1986 , at the invitation of NASA 's administrator .
#
# TRUE (SET):  [['Jake Garn', 'Work_For', 'NASA'], ['Bill Nelson', 'Work_For', 'NASA']]
# TP (SET):  [['Jake Garn', 'Work_For', 'NASA']]
# ----------------
# Evaluating Juppe 's visit , Cetin said that the French Government was not displaying a disturbing stand toward Turkey and was very careful in not intervening in Turkey 's internal affairs .
#
# TRUE (SET):  [['Juppe', 'Work_For', 'French Government'], ['Cetin', 'Live_In', 'Turkey'], ['Cetin', 'Live_In', 'Turkey']]
# TP (SET):  [['Cetin', 'Live_In', 'Turkey'], ['Cetin', 'Live_In', 'Turkey']]
# ----------------
# JN0704183294 Paris Radio Monte Carlo in Arabic 1700 GMT 7 Apr 94
#
# TRUE (SET):  [['Radio Monte Carlo', 'OrgBased_In', 'Paris']]
# TP (SET):  [['Radio Monte Carlo', 'OrgBased_In', 'Paris']]
# ----------------
# On this date : In 1533 , the last Incan King of Peru , Atahualpa , was murdered on the orders of Spanish conqueror Francisco Pizarro .
#
# TRUE (SET):  [['Francisco Pizarro', 'Kill', 'Atahualpa']]
# TP (SET):  [['Francisco Pizarro', 'Kill', 'Atahualpa']]
# ----------------
# ` ` We 'd play hearts for hours at a time , ' ' said Atlanta businessman Neil Estes.
#
# TRUE (SET):  [['Neil Estes.', 'Live_In', 'Atlanta']]
# TP (SET):  [['Neil Estes.', 'Live_In', 'Atlanta']]
# ----------------
# Volcanoes in Nicaragua and Indonesia , deforestation in Brazil and Madagascar , the Sahara desert in Africa and global beach erosion are among the subjects to be photographed .
#
# TRUE (SET):  [['Sahara desert', 'Located_In', 'Africa']]
# TP (SET):  [['Sahara desert', 'Located_In', 'Africa']]
# ----------------
# ` ` This is really hurting Heuchelheim , ' ' the town 's mayor Willi Marx told The Associated Press in an interview at his office earlier this month .
#
# TRUE (SET):  [['Willi Marx', 'Live_In', 'Heuchelheim']]
# TP (SET):  [['Willi Marx', 'Live_In', 'Heuchelheim']]
# ----------------
# ` ` I think at this moment they fear making a wrong move _ whether they should seek political asylum or use other reasons to remain here , ' ' said Jeff Shia , president of the Kiangsu Chekiang Association , a non-profit group that helps new Chinese immigrants establish themselves in the city.
#
# TRUE (SET):  [['Jeff Shia', 'Work_For', 'Kiangsu Chekiang Association']]
# TP (SET):  [['Jeff Shia', 'Work_For', 'Kiangsu Chekiang Association']]
# ----------------
# The term ` ` 30 Seconds Over Tokyo ' ' was the title of a popular movie about the raid. _Anzio _ The Anzio beachhead , 33 miles south of Rome , saw some of the bloodiest fighting of World War II and accounted for many of the 10 , 000 U.S. battle deaths in Italy the first half of 1944 .
#
# TRUE (SET):  [['Anzio', 'Located_In', 'Italy']]
# TP (SET):  [['Anzio', 'Located_In', 'Italy']]
# ----------------
# Anna Sandhu Ray , who 10 years ago Thursday wed the man convicted of killing the Rev. Martin Luther King Jr. , said on her anniversary that she plans to divorce James Earl Ray .
#
# TRUE (SET):  [['James Earl Ray', 'Kill', 'Rev. Martin Luther King Jr.']]
# TP (SET):  [['James Earl Ray', 'Kill', 'Rev. Martin Luther King Jr.']]
# ----------------
# The 23-foot-tall statue was modeled after the 30-foot-tall Goddess of Democracy raised by Chinese pro-democracy demonstrators in Beijing 's Tiananmen Square on May 30.
#
# TRUE (SET):  [['Tiananmen Square', 'Located_In', 'Beijing']]
# TP (SET):  [['Tiananmen Square', 'Located_In', 'Beijing']]
# ----------------
# One of Warner 's lawyers , Andrew Hall of Miami , Fla. , confirmed Tuesday that Warner is trying to settle the case.
#
# TRUE (SET):  [['Andrew Hall', 'Live_In', 'Miami'], ['Andrew Hall', 'Live_In', 'Fla.'], ['Miami', 'Located_In', 'Fla.']]
# TP (SET):  [['Andrew Hall', 'Live_In', 'Miami'], ['Andrew Hall', 'Live_In', 'Fla.']]
# ----------------
# New Jersey Gov. Thomas Kean , who is leaving office after two terms at the end of this year , was greeted with effuse public praise by his colleagues during the conference.
#
# TRUE (SET):  [['Thomas Kean', 'Live_In', 'New Jersey']]
# TP (SET):  [['Thomas Kean', 'Live_In', 'New Jersey']]
# ----------------
# ` ` The country was starved of resources , ' ' said Marcos Victorica , director of the Institute of Contemporary Studies.
#
# TRUE (SET):  [['Marcos Victorica', 'Work_For', 'Institute of Contemporary Studies.']]
# TP (SET):  [['Marcos Victorica', 'Work_For', 'Institute of Contemporary Studies']]
# ----------------
# Excess Lira Reportedly Causes Currency Crisis NC1901223094 London Kanal-6 Television in Turkish 1700 GMT 19 Jan 94
#
# TRUE (SET):  [['Kanal-6 Television', 'OrgBased_In', 'London']]
# TP (SET):  [['Kanal-6 Television', 'OrgBased_In', 'London']]
# ----------------
# " This is the Garrett place where John Wilkes Booth , assassin of Lincoln , was cornered by Union soldiers and killed April 26 , 1865 .
#
# TRUE (SET):  [['John Wilkes Booth', 'Kill', 'Lincoln']]
# TP (SET):  [['John Wilkes Booth', 'Kill', 'Lincoln']]
# ----------------
# BANGKOK , Thailand ( AP )
#
# TRUE (SET):  [['BANGKOK', 'Located_In', 'Thailand']]
# TP (SET):  [['BANGKOK', 'Located_In', 'Thailand']]
# ----------------
# The Santa Ana winds _ also called ` ` devil winds ' ' _ are spun off by high pressure over the interior of the country , picking up speed as they move from Southern California 's deserts through mountain passes and roar down on adjacent communities .
#
# TRUE (SET):  [['Santa Ana', 'Located_In', 'Southern California']]
# TP (SET):  [['Santa Ana winds', 'Located_In', 'Southern California']]
# ----------------
# FL2706231194 Havana Radio Reloj Network in Spanish 1402 GMT 27 Jun 94
#
# TRUE (SET):  [['Radio Reloj Network', 'OrgBased_In', 'Havana']]
# TP (SET):  [['Radio Reloj Network', 'OrgBased_In', 'Havana']]
# ----------------
# ` ` Our white paper , market pulp and packaging businesses turned in particularly impressive results in 1988 , ' ' said John A. Georges , International Paper 's chairman and chief executive officer .
#
# TRUE (SET):  [['John A. Georges', 'Work_For', 'International Paper']]
# TP (SET):  [['John A. Georges', 'Work_For', 'International Paper']]
# ----------------
# EAST LANSING , Mich.
#
# TRUE (SET):  [['EAST LANSING', 'Located_In', 'Mich.']]
# TP (SET):  [['LANSING', 'Located_In', 'Mich.']]
# ----------------
# Two days later , Perry operated on Kennedy 's assassin , Lee Harvey Oswald , who had just been shot by Jack Ruby .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy'], ['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# TP (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# ----------------
# The prime was accompanied by his wife , Datuk Sri Datin Paduka Dr. Siti Hasmah and the deputy secretary of the Foreign Ministry , Datuk Abdul Halim Ali , during his brief visit to South Africa .
#
# TRUE (SET):  [['Datuk Abdul Halim Ali', 'Work_For', 'Foreign Ministry']]
# TP (SET):  [['Datuk Abdul Halim Ali', 'Work_For', 'Foreign Ministry']]
# ----------------
# The federal appeals court previously overturned a key provision of Arizona 's death penalty statute in the case of John Harvey Adamson , convicted of murdering reporter Don Bolles .
#
# TRUE (SET):  [['John Harvey Adamson', 'Kill', 'Don Bolles']]
# TP (SET):  [['John Harvey Adamson', 'Kill', 'Don Bolles']]
# ----------------
# NC1404123794 Cairo AL-AHALI in Arabic 6 Apr 94 p 6
#
# TRUE (SET):  [['AL-AHALI', 'OrgBased_In', 'Cairo']]
# TP (SET):  [['AL-AHALI', 'OrgBased_In', 'Cairo']]
# ----------------
# Belli 's clients have included Jack Ruby , who killed John F. Kennedy assassin Lee Harvey Oswald , and Jim and Tammy Bakker .
#
# TRUE (SET):  [['Jack Ruby', 'Kill', 'Lee Harvey Oswald'], ['Lee Harvey Oswald', 'Kill', 'John F. Kennedy']]
# TP (SET):  [['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# ----------------
# Bosnia 's capital , Sarajevo , is best-known as the site of the assassination in 1914 of Austrian Archduke Franz Ferdinand by young Bosnian nationalist Gavrilo Princip , which was the spark that ignited World War I. No single party appeared likely to win a clear majority in Bosnia 's 240-seat bicameral parliament .
#
# TRUE (SET):  [['Sarajevo', 'Located_In', 'Bosnia'], ['Gavrilo Princip', 'Kill', 'Austrian Archduke Franz Ferdinand']]
# TP (SET):  [['Gavrilo Princip', 'Kill', 'Austrian Archduke Franz Ferdinand']]
# ----------------
# The nine sentences noting the spot where Dallas was settled are followed by this : ` ` On Nov. 22 , 1963 , the building gained national notoriety when Lee Harvey Oswald allegedly shot and killed President John F. Kennedy from a sixth floor window as the presidential motorcade passed the site. ' '
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'President John F. Kennedy']]
# TP (SET):  [['Lee Harvey Oswald', 'Kill', 'President John F. Kennedy']]
# ----------------
# ` ` One thing I have learned over the past 17 months is that the truth is hard to find , and it remains so , ' ' said Mrs. Higgins , 37 , who is a major inthe Marine Corps and works at the Pentagon as a public information officer.
#
# TRUE (SET):  [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Pentagon']]
# TP (SET):  [['Mrs. Higgins', 'Work_For', 'Marine Corps']]
# ----------------
# Sam Kadet of the corporate law firm of Skadden , Arps said Popeyes could give Church 's notice on Thursday that it planned to proceed with the takeover attempt and deliver the information to Church 's after five business days .
#
# TRUE (SET):  [['Sam Kadet', 'Work_For', 'Skadden , Arps']]
# TP (SET):  [['Sam Kadet', 'Work_For', 'Skadden']]
# ----------------
# Yisrael Tal , one of the top military strategists in Israel , says the Arabs have reached a strategic balance with Israel through their acquisition of ground-to-ground missiles .
#
# TRUE (SET):  [['Yisrael Tal', 'Live_In', 'Israel'], ['Yisrael Tal', 'Live_In', 'Israel']]
# TP (SET):  [['Yisrael Tal', 'Live_In', 'Israel'], ['Yisrael Tal', 'Live_In', 'Israel']]
# ----------------
# Some people in the United States are saying that Clinton " gave away " $12 billion to Russia -- this is the amount it is proposed to pay for uranium destined for U.S. nuclear electric power stations , which will be obtained from our nuclear warheads .
#
# TRUE (SET):  [['Clinton', 'Live_In', 'United States'], ['Clinton', 'Live_In', 'U.S.']]
# TP (SET):  [['Clinton', 'Live_In', 'United States']]
# ----------------
# Illinois born Charlton Heston was a 27-year-old actor from Broadway and television when he arrived in Hollywood for a five-picture contract with Hal Wallis .
#
# TRUE (SET):  [['Charlton Heston', 'Live_In', 'Illinois']]
# TP (SET):  [['Charlton Heston', 'Live_In', 'Illinois']]
# ----------------
# The justices heard 60 minutes of arguments Wednesday on whether they will allow the execution of Johnny Paul Penry , 32 , a convicted rapist-murderer sentenced to die in Texas .
#
# TRUE (SET):  [['Johnny Paul Penry', 'Live_In', 'Texas']]
# TP (SET):  [['Johnny Paul Penry', 'Live_In', 'Texas']]
# ----------------
# BRISBANE , Australia ( AP )
#
# TRUE (SET):  [['BRISBANE', 'Located_In', 'Australia'], ['AP', 'OrgBased_In', 'BRISBANE'], ['AP', 'OrgBased_In', 'Australia']]
# TP (SET):  [['AP', 'OrgBased_In', 'Australia']]
# ----------------
# CNEN Radioprotection Director Laercio Vinhas yesterday reported by fax that the thyroid dysfunctions detected in the employees have no relation whatsoever with their work at the laboratory and that this problem is detected in 3 percent of the overall population .
#
# TRUE (SET):  [['Laercio Vinhas', 'Work_For', 'CNEN']]
# TP (SET):  [['Laercio Vinhas', 'Work_For', 'CNEN']]
# ----------------
# ` ` This is not a good idea for a lot of environmental reasons , ' ' Stephanie Powell , of the DEM 's division of groundwater and freshwater wetlands , said Tuesday.
#
# TRUE (SET):  [['Stephanie Powell', 'Work_For', 'DEM']]
# TP (SET):  [['Stephanie Powell', 'Work_For', 'DEM']]
# ----------------
# Nihat ( Marka ) , deputy leader of SHP ( Social Democrat Populist Party ) parliamentary group , said : They should have run in the elections for the sake of democracy .
#
# TRUE (SET):  [['Nihat', 'Work_For', 'SHP'], ['Nihat', 'Work_For', 'Social Democrat Populist Party'], ['Marka', 'Work_For', 'SHP'], ['Marka', 'Work_For', 'Social Democrat Populist Party']]
# TP (SET):  [['Nihat', 'Work_For', 'SHP'], ['Nihat', 'Work_For', 'Social Democrat Populist Party'], ['Marka', 'Work_For', 'SHP']]
# ----------------
# Harrington , a professor of political science at Queens College of the City University of New York and honorary president of the Socialist International , died Monday night at his home in suburban Larchmont , the university said in a statement Tuesday.
#
# TRUE (SET):  [['Harrington', 'Work_For', 'Queens College'], ['Harrington', 'Work_For', 'City University of New York'], ['Harrington', 'Work_For', 'Socialist International'], ['Harrington', 'Live_In', 'Larchmont']]
# TP (SET):  [['Harrington', 'Work_For', 'Queens College'], ['Harrington', 'Work_For', 'City University of New York'], ['Harrington', 'Work_For', 'Socialist International']]
# ----------------
# The National Aeronautics and Space Administration announced Thursday that Ulf D. Merbold , 47 , of the European Space Agency and Roger K. Crouch of NASA have been chosen to train to perform materials sciences experiments on the International Microgravity Laboratory-1 mission scheduled for April 1991 .
#
# TRUE (SET):  [['Ulf D. Merbold', 'Work_For', 'European Space Agency'], ['Roger K. Crouch', 'Work_For', 'National Aeronautics and Space Administration'], ['Roger K. Crouch', 'Work_For', 'NASA']]
# TP (SET):  [['Ulf D. Merbold', 'Work_For', 'European Space Agency'], ['Roger K. Crouch', 'Work_For', 'NASA']]
# ----------------
# Prime Minister Felipe Gonzalez of Spain told reporters , ` ` The police actions and the arrests are of great importance to Spanish society on such a major matter as the battle against terrorism. ' '
#
# TRUE (SET):  [['Felipe Gonzalez', 'Live_In', 'Spain']]
# TP (SET):  [['Felipe Gonzalez', 'Live_In', 'Spain']]
# ----------------
# In 1752 , flagmaker Betsy Ross was born in Philadelphia .
#
# TRUE (SET):  [['Betsy Ross', 'Live_In', 'Philadelphia']]
# TP (SET):  [['Betsy Ross', 'Live_In', 'Philadelphia']]
# ----------------
# No. 1 is the West Coast 's tallest building , the 76-story black-glass Columbia Seafirst Center built in 1985 , before downtown zoning went into effect .
#
# TRUE (SET):  [['Columbia Seafirst Center', 'Located_In', 'West Coast']]
# TP (SET):  [['Columbia Seafirst Center', 'Located_In', 'West Coast']]
# ----------------
# He developed evidence regarding the assassination of President Kennedy which supported the findings of the Warren Commission that Lee Harvey Oswald was the lone assassin .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'President Kennedy']]
# TP (SET):  [['Lee Harvey Oswald', 'Kill', 'President Kennedy']]
# ----------------
# Montana : A fire burning in grassland and scattered timber in the Custer National Forest became the state 's biggest fire of the summer Tuesday when it surpassed 1 , 200 acres.
#
# TRUE (SET):  [['Custer National Forest', 'Located_In', 'Montana']]
# TP (SET):  [['Custer National Forest', 'Located_In', 'Montana']]
# ----------------
# JOHANNESBURG , South Africa ( AP )
#
# TRUE (SET):  [['JOHANNESBURG', 'Located_In', 'South Africa']]
# TP (SET):  [['JOHANNESBURG', 'Located_In', 'South Africa']]
# ----------------
# ( Text ) The National Central Organization of Panamanian Workers ( CNTP ) , which comprises three workers ' federations and 16 unions for a total of 12 , 000 workers , has proclaimed its determination to support Dr. Ernesto Perez Balladares for the presidency of the Republic .
#
# TRUE (SET):  [['The National Central Organization of Panamanian Workers', 'OrgBased_In', 'the Republic'], ['CNTP', 'OrgBased_In', 'the Republic'], ['Ernesto Perez Balladares', 'Live_In', 'the Republic']]
# TP (SET):  [['Dr. Ernesto Perez Balladares', 'Live_In', 'Republic']]
# ----------------
# MOSKOVSKIY KOMSOMOLETS has learned from competent sources that the commission is supposed to pay special attention to Lazutkin , former first deputy general director of " Ostankino , " who currently holds the position of first deputy head of the Russian Federation Federal Service for Television and Radio Broadcasting.
#
# TRUE (SET):  [['Lazutkin', 'Work_For', 'Russian Federation Federal Service for Television and Radio Broadcasting.']]
# TP (SET):  [['Lazutkin', 'Work_For', 'Russian Federation Federal Service for Television and Radio Broadcasting.']]
# ----------------
# But trustee Daniel L. Bakst , a West Palm Beach , Fla. , lawyer , said he will not let the 11th-hour settlement efforts interfere with his assignment to track down Warner 's assets for distribution to creditors.
#
# TRUE (SET):  [['Daniel L. Bakst', 'Live_In', 'West Palm Beach'], ['Daniel L. Bakst', 'Live_In', 'Fla.'], ['West Palm Beach', 'Located_In', 'Fla.']]
# TP (SET):  [['Daniel L. Bakst', 'Live_In', 'West Palm Beach'], ['Daniel L. Bakst', 'Live_In', 'Fla.'], ['West Palm Beach', 'Located_In', 'Fla.']]
# ----------------
# Serbia is the largest of Yugoslavia 's six republics.
#
# TRUE (SET):  [['Serbia', 'Located_In', 'Yugoslavia']]
# TP (SET):  [['Serbia', 'Located_In', 'Yugoslavia']]
# ----------------
# Sirhan was convicted of Kennedy 's killing and is serving a life sentence .
#
# TRUE (SET):  [['Sirhan', 'Kill', 'Kennedy']]
# TP (SET):  [['Sirhan', 'Kill', 'Kennedy']]
# ----------------
# A mechanized infantry battalion belonging to the 21st Brigade of Cerro Muriano in Cordoba and to the 12th Brigade in Botoa in Badajoz , a company of the Special Operations Group in Alicante , and a squadron from the Jarama 1st Cavalry Brigade from Salamanca make up the Cordoba Group .
#
# TRUE (SET):  [['21st Brigade of Cerro Muriano', 'OrgBased_In', 'Cordoba'], ['12th Brigade', 'OrgBased_In', 'Botoa'], ['12th Brigade', 'OrgBased_In', 'Badajoz'], ['Special Operations Group', 'OrgBased_In', 'Alicante'], ['Jarama 1st Cavalry Brigade', 'OrgBased_In', 'Salamanca']]
# TP (SET):  [['Cerro Muriano', 'OrgBased_In', 'Cordoba'], ['12th Brigade', 'OrgBased_In', 'Botoa']]
# ----------------
# Those honored were Jean Griffith , mother of a man killed on a Howard Beach , Queens , parkway after being chased by a gang of whites in December 1986 ;
#
# TRUE (SET):  [['Howard Beach', 'Located_In', 'Queens']]
# TP (SET):  [['Howard Beach', 'Located_In', 'Queens']]
# ----------------
# FBI agents arrived at Sohn 's New Jersey home and escorted him to safety only 30 minutes before KCIA agents showed up , an unidentified senior law enforcement official told the Times .
#
# TRUE (SET):  [['Sohn', 'Live_In', 'New Jersey']]
# TP (SET):  [['Sohn', 'Live_In', 'New Jersey']]
# ----------------
# Prime Brian Mulroney 's Progressive Conservative Party won its second consecutive majority government in the election , and he signed the trade pact with President Reagan in January 1988 .
#
# TRUE (SET):  [['Brian Mulroney', 'Work_For', 'Progressive Conservative Party']]
# TP (SET):  [['Brian Mulroney', 'Work_For', 'Progressive Conservative Party']]
# ----------------
# BANGKOK , Thailand ( AP )
#
# TRUE (SET):  [['BANGKOK', 'Located_In', 'Thailand'], ['AP', 'OrgBased_In', 'BANGKOK'], ['AP', 'OrgBased_In', 'Thailand']]
# TP (SET):  [['BANGKOK', 'Located_In', 'Thailand'], ['AP', 'OrgBased_In', 'BANGKOK'], ['AP', 'OrgBased_In', 'Thailand']]
# ----------------
# In Washington , the General Accounting Office ( GAO ) , the congressional watchdog of government spending , says in a report released last August that Israel might be underestimating the costs of producing and deploying the Arrow system .
#
# TRUE (SET):  [['General Accounting Office', 'OrgBased_In', 'Washington'], ['GAO', 'OrgBased_In', 'Washington']]
# TP (SET):  [['General Accounting Office', 'OrgBased_In', 'Washington'], ['GAO', 'OrgBased_In', 'Washington']]
# ----------------
# Today 's highlight in history : On the Ides of March , 44 B.C. , Roman Emperor Julius Caesar was assassinated by a group of nobles that included Brutus and Cassius .
#
# TRUE (SET):  [['Brutus', 'Kill', 'Roman Emperor Julius Caesar'], ['Cassius', 'Kill', 'Roman Emperor Julius Caesar']]
# TP (SET):  [['Brutus', 'Kill', 'Roman Emperor Julius Caesar'], ['Cassius', 'Kill', 'Roman Emperor Julius Caesar']]
# ----------------
# Until President 's Day of this year , the public could not enter the sixth floor of the old school book depository in downtown Dallas , where it 's believed Lee Harvey Oswald fired the shots that killed Kennedy .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# TP (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# ----------------
# An electrical train has arrived at Novonezhino to evacuate local inhabitants , and a special group from the Russian Defence Ministry has left Moscow by plane en route to Vladivostok and the site of the explosion .
#
# TRUE (SET):  [['Russian Defence Ministry', 'OrgBased_In', 'Moscow']]
# TP (SET):  [['Russian Defence Ministry', 'OrgBased_In', 'Moscow']]
# ----------------
# Deputy U.S. Ambassador Herbert S. Okun announced the cancellation just before the council began debate , and officials in Washington confirmed it .
#
# TRUE (SET):  [['Herbert S. Okun', 'Live_In', 'U.S.']]
# TP (SET):  [['Herbert S. Okun', 'Live_In', 'U.S.']]
# ----------------
# Moscow March 5 ( ITAR-TASS ) -- Moscow leading newspapers concentrate on the speeches by President Boris Yeltsin and Premier Viktor Chernomyrdin at the government 's enlarged meeting on Friday .
#
# TRUE (SET):  [['ITAR-TASS', 'OrgBased_In', 'Moscow'], ['ITAR-TASS', 'OrgBased_In', 'Moscow'], ['Boris Yeltsin', 'Live_In', 'Moscow'], ['Boris Yeltsin', 'Live_In', 'Moscow'], ['Viktor Chernomyrdin', 'Live_In', 'Moscow'], ['Viktor Chernomyrdin', 'Live_In', 'Moscow']]
# TP (SET):  [['Boris Yeltsin', 'Live_In', 'Moscow'], ['Boris Yeltsin', 'Live_In', 'Moscow'], ['Viktor Chernomyrdin', 'Live_In', 'Moscow'], ['Viktor Chernomyrdin', 'Live_In', 'Moscow']]
# ----------------
# Winter , 53 , a former Yale University law professor who took the bench in 1982 , and Starr , a fellow appointee of President Reagan , are both known as judicial conservatives .
#
# TRUE (SET):  [['Winter', 'Work_For', 'Yale University']]
# TP (SET):  [['Winter', 'Work_For', 'Yale University']]
# ----------------
# The Internal Revenue Service and Manufacturers Hanover Trust Co. of New York , two of the largest creditors in the Herbert Hunt bankruptcy , said they will file a repayment plan by Friday.
#
# TRUE (SET):  [['Manufacturers Hanover Trust Co.', 'OrgBased_In', 'New York']]
# TP (SET):  [['The Manufacturers Hanover Trust Co.', 'OrgBased_In', 'New York']]
# ----------------
# The committee reported in July 1979 that Lee Harvey Oswald had shot Kennedy and that neither the Soviet Union nor Cuba nor any U.S. government agency was involved in the killing. ;
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# TP (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# ----------------
# Announces Offer to End Strike PA0302025694 Panama City ACAN in Spanish 2153 GMT 2 Feb 94
#
# TRUE (SET):  [['ACAN', 'OrgBased_In', 'Panama City']]
# TP (SET):  [['ACAN', 'OrgBased_In', 'Panama City']]
# ----------------
# Other winners are : _ Actress Helen Hayes , 87 , born in Washington , who first appeared on stage at the age of 5 , made her New York debut in 1909 and has played in works of Shakespeare , Tennessee Williams and Eugene O'Neill during her long career as a stage and movie actress.
#
# TRUE (SET):  [['Actress Helen Hayes', 'Live_In', 'Washington']]
# TP (SET):  [['Helen Hayes', 'Live_In', 'Washington']]
# ----------------
# Bossi set up the Freedom Alliance not because he believed in it , but because he found that it was necessary to do so. ( Minoli ) Do you think that this continual exchange of insults is advantageous to the common cause ? ( Fini ) It is advantageous because whoever listens does not vote for Occhetto ( leader of the Democratic Party of the Left ) .
#
# TRUE (SET):  [['Bossi', 'Work_For', 'Freedom Alliance'], ['Occhetto', 'Work_For', 'Democratic Party']]
# TP (SET):  [['Bossi', 'Work_For', 'Freedom Alliance'], ['Occhetto', 'Work_For', 'Democratic Party of the Left']]
# ----------------
# The law , patterned after similar measures in Michigan and California , gives victims ` ` a maximum opportunity to participate , ' ' said Fran Sepler , executive of the state Crime Victim and Witness Advisory Council.
#
# TRUE (SET):  [['Fran Sepler', 'Work_For', 'state Crime Victim and Witness Advisory Council.']]
# TP (SET):  [['Fran Sepler', 'Work_For', 'Crime Victim and Witness Advisory Council']]
# ----------------
# Gary Hess , an Emery employee , saw the plane go down as he was getting off work at the airport .
#
# TRUE (SET):  [['Gary Hess', 'Work_For', 'Emery']]
# TP (SET):  [['Gary Hess', 'Work_For', 'Emery']]
# ----------------
# The six men were found under the rubble in the basement of a nine-story apartment building which had collapsed on them , the official Soviet news agency said in a report from Yerevan , the capital of Armenia .
#
# TRUE (SET):  [['Yerevan', 'Located_In', 'Armenia']]
# TP (SET):  [['Yerevan', 'Located_In', 'Armenia']]
# ----------------
# In 1963 , the year he joined the Herald Tribune , he was riding in the motorcade with President Kennedy when Kennedy was fatally shot by Lee Harvey Oswald in Dallas. ;
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# TP (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# ----------------
# ` ` If we 're going to address this problem it will be a grass-roots effort by activists throughout the cities of the world , ' ' said Jeremy Rifkin , director of the Foundation on Economic Trends and a member of the Global Greenhouse Network , a coalition of environmental activists in 35 countries .
#
# TRUE (SET):  [['Jeremy Rifkin', 'Work_For', 'Foundation on Economic Trends'], ['Jeremy Rifkin', 'Work_For', 'Global Greenhouse Network']]
# TP (SET):  [['Jeremy Rifkin', 'Work_For', 'Foundation on Economic Trends'], ['Jeremy Rifkin', 'Work_For', 'Global Greenhouse Network']]
# ----------------
# When he was called to examine Robert F. Kennedy 's assassin , Sirhan Sirhan , a Jordanian residing in the United States , Markman refused .
#
# TRUE (SET):  [['Sirhan Sirhan', 'Kill', 'Robert F. Kennedy']]
# TP (SET):  [['Sirhan Sirhan', 'Kill', 'Robert F. Kennedy']]
# ----------------
# Tokyo NIHON KEIZAI SHIMBUN
#
# TRUE (SET):  [['NIHON KEIZAI SHIMBUN', 'OrgBased_In', 'Tokyo']]
# TP (SET):  [['NIHON KEIZAI SHIMBUN', 'OrgBased_In', 'Tokyo']]
# ----------------
# Jeffrey Bander , vice for development of new products at American Express , said the credit card company conducted two different research projects before launching its weather phone.
#
# TRUE (SET):  [['Jeffrey Bander', 'Work_For', 'American Express']]
# TP (SET):  [['Jeffrey Bander', 'Work_For', 'American Express']]
# ----------------
# In 1968 , authorities announced the capture in London of James Earl Ray , suspected of the assassination of civil rights leader Dr. Martin Luther King Jr .
#
# TRUE (SET):  [['James Earl Ray', 'Kill', 'Dr. Martin Luther King Jr']]
# TP (SET):  [['James Earl Ray', 'Kill', 'Dr. Martin Luther King Jr']]
# ----------------
# James Earl Ray , 60 , is serving 99 years in prison for first-degree murder of King in Memphis on April 4 , 1968 .
#
# TRUE (SET):  [['James Earl Ray', 'Kill', 'King']]
# TP (SET):  [['James Earl Ray', 'Kill', 'King']]
# ----------------
# ( Excerpts ) US President Bill Clinton 's decision to lift a long-standing trade embargo against Vietnam had been expected. ( passage omitted ) In his White House speech , Clinton said the time for bitterness was over and now was the time for a new beginning between Hanoi and Washington .
#
# TRUE (SET):  [['Bill Clinton', 'Live_In', 'US']]
# TP (SET):  [['Bill Clinton', 'Live_In', 'US']]
# ----------------
# In Washington , U.S officials announced that the Navy will rotate two aircraft carrier battle groups well away from Libya as one replaces the other .
#
# TRUE (SET):  [['Washington', 'Located_In', 'U.S'], ['Navy', 'OrgBased_In', 'U.S']]
# TP (SET):  [['Washington', 'Located_In', 'U.S.']]
# ----------------
# Tal , a senior Defense Ministry official , has not repeated these views in public .
#
# TRUE (SET):  [['Tal', 'Work_For', 'Defense Ministry']]
# TP (SET):  [['Tal', 'Work_For', 'Defense Ministry']]
# ----------------
# Lennon was shot to death Dec. 8 , 1980 , in the courtyard of his New York City apartment building by Mark David Chapman , a former Beatles ' fan who was convicted of the killing and sentenced to prison for a term of 20 years to life .
#
# TRUE (SET):  [['Mark David Chapman', 'Kill', 'Lennon']]
# TP (SET):  [['Mark David Chapman', 'Kill', 'Lennon']]
# ----------------
# By contrast , nearly 6 million square feet of downtown office space is newly completed , under construction or has received city permits , said Virginia Galle , a City Council member and CAP supporter .
#
# TRUE (SET):  [['Virginia Galle', 'Work_For', 'City Council']]
# TP (SET):  [['Virginia Galle', 'Work_For', 'City Council']]
# ----------------
# Harrington taught at Harvard University and the National War College.
#
# TRUE (SET):  [['Harrington', 'Work_For', 'Harvard University'], ['Harrington', 'Work_For', 'National War College.']]
# TP (SET):  [['Harrington', 'Work_For', 'Harvard University'], ['Harrington', 'Work_For', 'National War College']]
# ----------------
# Fred Farrar , another FAA spokesman , said airlines flying the 737-300s are Aloha , America West , American , Continental , Delta , Orion , Piedmont , Southwest , United and U.S. Air .
#
# TRUE (SET):  [['Fred Farrar', 'Work_For', 'FAA']]
# TP (SET):  [['Fred Farrar', 'Work_For', 'FAA']]
# ----------------
# The trud newspaper features the last part of the memoirs by former commander of the Soviet Navy Nikolai Kuznetsov who personally knew Stalin , under the headline " Stalin 's Death . "
#
# TRUE (SET):  [['Navy', 'OrgBased_In', 'Soviet'], ['Nikolai Kuznetsov', 'Live_In', 'Soviet'], ['Nikolai Kuznetsov', 'Work_For', 'Navy'], ['Stalin', 'Live_In', 'Soviet'], ['Stalin', 'Live_In', 'Soviet']]
# TP (SET):  [['Nikolai Kuznetsov', 'Work_For', 'Soviet Navy']]
# ----------------
# National Congress President Vinicio Villar Anleu commented on the implications of the case : ( Begin recording ) ( Villar Anleu ) It seems to us -- and we uphold Congress ' institutional policy -- that the nation 's laws must be respected and that the Constitution must be respected .
#
# TRUE (SET):  [['Vinicio Villar Anleu', 'Work_For', 'National Congress']]
# TP (SET):  [['Vinicio Villar Anleu', 'Work_For', 'National Congress']]
# ----------------
# Several organizations planned remembrances later today at Parkland Memorial Hospital , where Kennedy was taken after being shot , and the Texas Theater , where Lee Harvey Oswald was arrested hours after the assassination .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# TP (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# ----------------
# ` ` I think the longer they talk , the longer they delay , the greater the chances that we may turn this around and get them all home , ' ' said Ms. Say in Nashville , Tenn.
#
# TRUE (SET):  [['Nashville', 'Located_In', 'Tenn.']]
# TP (SET):  [['Nashville', 'Located_In', 'Tenn.']]
# ----------------
# A chart used to decipher the code was found among Booth 's effects after he was shot by Union soldiers 11 days after the assassination of Lincoln .
#
# TRUE (SET):  [['Booth', 'Kill', 'Lincoln']]
# TP (SET):  [['Booth', 'Kill', 'Lincoln']]
# ----------------
# ` ` ` Ryan 's Hope ' has not been rejected by the audience , it has simply been unavailable to viewers , ' ' Jo Ann Emmerich , vice president of daytime programs for ABC Entertainment , said at the time .
#
# TRUE (SET):  [['Jo Ann Emmerich', 'Work_For', 'ABC Entertainment']]
# TP (SET):  [['Jo Ann Emmerich', 'Work_For', 'ABC Entertainment']]
# ----------------
# Moscow MOSKOVSKIY KOMSOMOLETS
#
# TRUE (SET):  [['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']]
# TP (SET):  [['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']]
# ----------------
# An abstract theory explaining the structure of minimal surface in Riemann 's multi-dimensional space has been developed by Wang Guangyan , with the assistance of his PhD student , at the Institute of Mathematics .
#
# TRUE (SET):  [['Wang Guangyan', 'Work_For', 'Institute of Mathematics']]
# TP (SET):  [['Wang Guangyan', 'Work_For', 'Institute of Mathematics']]
# ----------------
# Owen Le Vallee , president of the Liberation Day Committee , said his mother found a starving German in the outhouse during the year after D-Day , the 1944 Allied invasion of Europe.
#
# TRUE (SET):  [['Owen Le Vallee', 'Work_For', 'Liberation Day Committee']]
# TP (SET):  [['Owen Le Vallee', 'Work_For', 'Liberation Day Committee']]
# ----------------
# KARBALA , Iraq ( AP )
#
# TRUE (SET):  [['KARBALA', 'Located_In', 'Iraq'], ['AP', 'OrgBased_In', 'KARBALA'], ['AP', 'OrgBased_In', 'Iraq']]
# TP (SET):  [['AP', 'OrgBased_In', 'KARBALA'], ['AP', 'OrgBased_In', 'Iraq']]
# ----------------
# ( Text ) In an interview with Interfax the chief of Belarus 's Security Committee , Eduard Shirkovskiy , has dismissed rumors that the copies of the files relating to Lee Harvey Oswald , who was charged with having assassinated President John Kennedy , will be handed to President Bill Clinton during his visit to Minsk .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'President John Kennedy']]
# TP (SET):  [['Lee Harvey Oswald', 'Kill', 'President John Kennedy']]
# ----------------
# Michael Henley Jr. , 10 , disappeared on a turkey hunt with his father in April 1988 in the mountains near their hometown of Grants , N.M. Ms. Calico , then 19 , disappeared five months later while bicycling on a country road near her hometown of Belen , N.M.
#
# TRUE (SET):  [['Michael Henley Jr.', 'Live_In', 'Grants'], ['Michael Henley Jr.', 'Live_In', 'N.M.'], ['Grants', 'Located_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'Belen'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Belen', 'Located_In', 'N.M.']]
# TP (SET):  [['Michael Henley Jr.', 'Live_In', 'Grants'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'Belen'], ['Ms. Calico', 'Live_In', 'N.M.']]
# ----------------
# ( Text ) Moscow April 25 TASS -- Preliminary marine pollution measurements taken from the sites of radioactive waste dumping by the former Soviet Union and Japan in the Sea of Japan did not reveal any Caesium-137 radioactive level fluctuations .
#
# TRUE (SET):  [['TASS', 'OrgBased_In', 'Moscow']]
# TP (SET):  [['TASS', 'OrgBased_In', 'Moscow']]
# ----------------
# The Warren Commission concluded that Oswald , acting alone , fired the shots that killed Kennedy and wounded John Connally , then the Texas governor .
#
# TRUE (SET):  [['Oswald', 'Kill', 'Kennedy']]
# TP (SET):  [['Oswald', 'Kill', 'Kennedy']]
# ----------------
# The advisory committee voted 7-1 to recommend that the drug remain a prescription ingredient , said Susan Cruzan , an FDA spokeswoman.
#
# TRUE (SET):  [['Susan Cruzan', 'Work_For', 'FDA']]
# TP (SET):  [['Susan Cruzan', 'Work_For', 'FDA']]
# ----------------
# ` ` It 's been a nightmare , ' ' said Shelley Yeager , director of the Clara Barton camp at Oxford in central Massachusetts.
#
# TRUE (SET):  [['Oxford', 'Located_In', 'Massachusetts.']]
# TP (SET):  [['Oxford', 'Located_In', 'Massachusetts.']]
# ----------------
# And William McKinley 's assassin Leon Czolgosz croons " The Ballad of Czolgosz " from the electric chair .
#
# TRUE (SET):  [['Leon Czolgosz', 'Kill', 'William McKinley']]
# TP (SET):  [['Leon Czolgosz', 'Kill', 'William McKinley']]
# ----------------
# Yeltsin Orders Audit of Ostankino Finances MK1401103094 Moscow MOSKOVSKIY KOMSOMOLETS in Russian 14 Jan 94 p 1
#
# TRUE (SET):  [['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']]
# TP (SET):  [['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']]
# ----------------
# ` ` We are constantly getting confirmation that the U.S. economy is no longer in a boom phase , and that interest rates are falling , ' ' said a dealer at a U.S. bank in Frankfurt , West Germany.
#
# TRUE (SET):  [['Frankfurt', 'Located_In', 'West Germany.']]
# TP (SET):  [['Frankfurt', 'Located_In', 'West Germany']]
# ----------------
# In 1969 , Sirhan Sirhan was convicted of assassinating U.S. Sen. Robert F. Kennedy .
#
# TRUE (SET):  [['Sirhan Sirhan', 'Kill', 'U.S. Sen. Robert F. Kennedy']]
# TP (SET):  [['Sirhan Sirhan', 'Kill', 'U.S. Sen. Robert F. Kennedy']]
# ----------------
# Jesse Jackson easily won the Democratic precinct caucuses Saturday in his native South Carolina , while Sen. Bob Dole went on Illinois television for a half-hour plea for Republican votes in a state where he said he is the underdog .
#
# TRUE (SET):  [['Jesse Jackson', 'Live_In', 'South Carolina']]
# TP (SET):  [['Jesse Jackson', 'Live_In', 'South Carolina']]
# ----------------
# MEXICO CITY ( AP )
#
# TRUE (SET):  [['AP', 'OrgBased_In', 'MEXICO CITY']]
# TP (SET):  [['AP', 'OrgBased_In', 'MEXICO CITY']]
# ----------------
# Temperatures around the nation at 2 a.m. EST ranged from 2 degrees at Jackson , Wyo. , and Gunnison , Colo. , to 89 degrees at McAllen , Texas .
#
# TRUE (SET):  [['Jackson', 'Located_In', 'Wyo.'], ['Gunnison', 'Located_In', 'Colo.'], ['McAllen', 'Located_In', 'Texas']]
# TP (SET):  [['Jackson', 'Located_In', 'Wyo.'], ['Gunnison', 'Located_In', 'Colo.'], ['McAllen', 'Located_In', 'Texas']]
# ----------------
# ` ` We certainly believe it 's a prudent measure to go out and check to make sure there 's nothing wrong with the fleet , ' ' Boeing Commercial Airplanes spokesman Craig Martin said Wednesday in Seattle .
#
# TRUE (SET):  [['Craig Martin', 'Work_For', 'Boeing Commercial Airplanes']]
# TP (SET):  [['Craig Martin', 'Work_For', 'Boeing Commercial Airplanes']]
# ----------------
# As Rochester teacher union leader Adam Urbanski put it : ` ` We have set the table ; we have not served the meal yet. ' '
#
# TRUE (SET):  [['Adam Urbanski', 'Live_In', 'Rochester']]
# TP (SET):  [['Adam Urbanski', 'Live_In', 'Rochester']]
# ----------------
# Tokyo MAINICHI SHIMBUN
#
# TRUE (SET):  [['MAINICHI SHIMBUN', 'OrgBased_In', 'Tokyo']]
# TP (SET):  [['MAINICHI SHIMBUN', 'OrgBased_In', 'Tokyo']]
# ----------------
# If the elections had been held during the last 10 days of May , that is , after the debate , Fernandez de Cevallos would reportedly be the next president of Mexico with 33.2 percent of the vote .
#
# TRUE (SET):  [['Fernandez de Cevallos', 'Live_In', 'Mexico']]
# TP (SET):  [['Fernandez de Cevallos', 'Live_In', 'Mexico']]
# ----------------
# Authorities say Oswald opened fire from a sixth-floor window there into Kennedy 's motorcade .
#
# TRUE (SET):  [['Oswald', 'Kill', 'Kennedy']]
# TP (SET):  [['Oswald', 'Kill', 'Kennedy']]
# ----------------
# At a briefing at NRC headquarters in nearby Rockville , Md. , Bernero said the volcanic cones in the area of Yucca Mountain have been a cause of concern for NRC experts.
#
# TRUE (SET):  [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.'], ['Bernero', 'Work_For', 'NRC'], ['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.']]
# TP (SET):  [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.'], ['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.']]
# ----------------
# According to the communique , clashes are continuing mainly in the Rancho Nuevo area at the military base in the southern Chiapas State .
#
# TRUE (SET):  [['Rancho Nuevo', 'Located_In', 'Chiapas State']]
# TP (SET):  [['Rancho Nuevo', 'Located_In', 'Chiapas State']]
# ----------------
# Dallas police arrested Oswald there on Nov. 22 , 1963 , after the assassination of President John F. Kennedy .
#
# TRUE (SET):  [['Oswald', 'Kill', 'President John F. Kennedy']]
# TP (SET):  [['Oswald', 'Kill', 'President John F. Kennedy']]
# ----------------
# In Washington state , near the Canadian border , firefighters hoped to contain an 850-acre fire by tonight , said Greg Thayer of the Forest Service.
#
# TRUE (SET):  [['Greg Thayer', 'Work_For', 'Forest Service.']]
# TP (SET):  [['Greg Thayer', 'Work_For', 'Forest Service']]
# ----------------
# The Warren Commission concluded that Lee Harvey Oswald , acting alone , fired the shots that killed Kennedy and wounded John Connally , then the Texas governor , on Nov. 22 , 1963 in Dallas .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# TP (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# ----------------
# The spilled fuel covered an area two miles long and nearly a half-mile wide , said Whitefish City Attorney Tom Muri.
#
# TRUE (SET):  [['Tom Muri.', 'Live_In', 'Whitefish City']]
# TP (SET):  [['Tom Muri.', 'Live_In', 'Whitefish City']]
# ----------------
# In California 's Sierra Nevada foothills , firefighters today declared they had contained a fire that blackened 11 , 700 acres of brush and grassland and destroyed seven homes.
#
# TRUE (SET):  [['Sierra Nevada', 'Located_In', 'California']]
# TP (SET):  [['Sierra Nevada', 'Located_In', 'California']]
# ----------------
# " I was hearing the same story , " says James Hackett , an executive with Titan Systems and one of the leading missile experts in the U.S .
#
# TRUE (SET):  [['James Hackett', 'Work_For', 'Titan Systems'], ['James Hackett', 'Live_In', 'U.S .']]
# TP (SET):  [['James Hackett', 'Work_For', 'Titan Systems']]
# ----------------
# The quake leveled much of Leninakan , Armenia 's second-largest city 10 miles east of the Turkish border and left thousands homeless .
#
# TRUE (SET):  [['Leninakan', 'Located_In', 'Armenia']]
# TP (SET):  [['Leninakan', 'Located_In', 'Armenia']]
# ----------------
# Pittsburgh-Corning Corp. of Pittsburgh ;
#
# TRUE (SET):  [['Pittsburgh-Corning Corp.', 'OrgBased_In', 'Pittsburgh']]
# TP (SET):  [['Pittsburgh-Corning Corp.', 'OrgBased_In', 'Pittsburgh']]
# ----------------
# Barrett is a member of the Illinois Commerce Commission , and Marshall is a lawyer and former legislative aide to Patrick.
#
# TRUE (SET):  [['Barrett', 'Work_For', 'Illinois Commerce Commission']]
# TP (SET):  [['Barrett', 'Work_For', 'Illinois Commerce Commission']]
# ----------------
# Ten years ago : James Earl Ray , convicted of assassinating Dr. Martin Luther King Jr. in 1968 , repeated his assertion at a Capitol Hill hearing that he did not commit the crime , saying he 'd been set up to take the blame by a mysterious man called Raoul .
#
# TRUE (SET):  [['James Earl Ray', 'Kill', 'Dr. Martin Luther King Jr.']]
# TP (SET):  [['James Earl Ray', 'Kill', 'Dr. Martin Luther King Jr.']]
# ----------------
# LD2804174994 Moscow INTERFAX in English 1601 GMT 28 Apr 94
#
# TRUE (SET):  [['INTERFAX', 'OrgBased_In', 'Moscow']]
# TP (SET):  [['INTERFAX', 'OrgBased_In', 'Moscow']]
# ----------------
# It is one of many deep below the arid surface , fed by underground channels that carry rainwater from the Najd plateau in northern Saudi Arabia to the west.
#
# TRUE (SET):  [['Najd plateau', 'Located_In', 'Saudi Arabia']]
# TP (SET):  [['Najd plateau', 'Located_In', 'Saudi Arabia']]
# ----------------
# TOTAL TRUE RELATIONS:  165

# %%
fp = ()

fp_list = []
text = []

for row in df.iterrows():
    for g_triplet in row[1]["generated"]:
        flag = True
        if g_triplet in row[1]["gold"]:
            continue
        else:
            for t_triplet in row[1]["gold"]:
                if ((str(t_triplet[0]) in str(g_triplet[0]) ) or (str(g_triplet[0]) in str(t_triplet[0]) )) and ((str(t_triplet[2]) in str(g_triplet[2])) or (str(g_triplet[2]) in str(t_triplet[2]))) and (str(t_triplet[1]) == str(g_triplet[1])):
                    flag = False
            if flag:
                text.append(row[1]["text"])
                fp_list.append(g_triplet)
                fp += (g_triplet,)
                print (row[1]["text"] + "\n")
                print ("TRUE (SET): ", row[1]["gold"])
                print ("FALSE POSITIVE GENERATED: " + str(g_triplet))
                print ("-----------------------------------------------")
# Out:
# Lightning ignited a firestorm that charred 10 , 000 acres in central Idaho , including much of the small resort town of Lowman , about 70 miles northeast of Boise.
#
# TRUE (SET):  [['Lowman', 'Located_In', 'Idaho']]
# FALSE POSITIVE GENERATED: ['Lotman', 'Located_In', 'Idaho']
# -----------------------------------------------
# The three reactors , all at the Savannah River Plant , in Aiken , S.C. , have been shut down since last April undergoing changes to make them safer .
#
# TRUE (SET):  [['Savannah River Plant', 'Located_In', 'Aiken'], ['Savannah River Plant', 'Located_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# FALSE POSITIVE GENERATED: ['Savana River Plant', 'OrgBased_In', 'Aiken']
# -----------------------------------------------
# The three reactors , all at the Savannah River Plant , in Aiken , S.C. , have been shut down since last April undergoing changes to make them safer .
#
# TRUE (SET):  [['Savannah River Plant', 'Located_In', 'Aiken'], ['Savannah River Plant', 'Located_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# FALSE POSITIVE GENERATED: ['Savana River Plant', 'OrgBased_In', 'S.C.']
# -----------------------------------------------
# Kovacevic , a Serb , has come under fire from Serbian politicians and the republic 's press since the U.S. Congress last month passed two resolutions claiming there were human rights violations in the strife-torn southern province of Kosovo.
#
# TRUE (SET):  [['Congress', 'OrgBased_In', 'U.S.']]
# FALSE POSITIVE GENERATED: ['Kovacevic', 'Live_In', 'Serbia']
# -----------------------------------------------
# On this date : In 1833 , Benjamin Harrison , the 23rd President of the United States , was born in North Bend , Ohio .
#
# TRUE (SET):  [['Benjamin Harrison', 'Live_In', 'North Bend , Ohio']]
# FALSE POSITIVE GENERATED: ['Benjamin Harrison', 'Live_In', 'North Bend, Ohio']
# -----------------------------------------------
# Photo , Dueling Over a GunIt is a scene seared into the memories of Americans old enough to have watched it that November day in 1963 : Jack Ruby firing his .38-caliber Colt Cobra , above , at Lee Harvey Oswald , the man who had assassinated President John F. Kennedy two days earlier.
#
# TRUE (SET):  [['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# FALSE POSITIVE GENERATED: ['Lee Harvey Oswald', 'Kill', 'President John F. Kennedy']
# -----------------------------------------------
# Hernandez Galicia 's allegedly corrupt Mexican Oil Workers Union controls more than half the lucrative drilling contracts issued by the state oil monopoly , Pemex .
#
# TRUE (SET):  [['Hernandez Galicia', 'Work_For', 'Mexican Oil Workers Union']]
# FALSE POSITIVE GENERATED: ['Mexican Oil Workers Union', 'OrgBased_In', 'Hernandez Galicia']
# -----------------------------------------------
# Hernandez Galicia 's allegedly corrupt Mexican Oil Workers Union controls more than half the lucrative drilling contracts issued by the state oil monopoly , Pemex .
#
# TRUE (SET):  [['Hernandez Galicia', 'Work_For', 'Mexican Oil Workers Union']]
# FALSE POSITIVE GENERATED: ['Mexican Oil Workers Union', 'OrgBased_In', 'Mexico']
# -----------------------------------------------
# Hernandez Galicia 's allegedly corrupt Mexican Oil Workers Union controls more than half the lucrative drilling contracts issued by the state oil monopoly , Pemex .
#
# TRUE (SET):  [['Hernandez Galicia', 'Work_For', 'Mexican Oil Workers Union']]
# FALSE POSITIVE GENERATED: ['Pemex', 'OrgBased_In', 'Mexico']
# -----------------------------------------------
# ` ` It 's not going to make you a whole bunch of money , but that 's not why we 're doing it , ' ' said Phil Fuhrer , vice of Gannett New Media. 1-900-WEATHER offers callers the current weather and a three-day forecast , plus skiing and highway conditions in the winter and coastal reports during the summer.
#
# TRUE (SET):  [['Phil Fuhrer', 'Work_For', 'Gannett New Media.']]
# FALSE POSITIVE GENERATED: ['Phil Fuhrer', 'Work_For', 'Gainnet New Media']
# -----------------------------------------------
# DAYTON , Ohio ( AP )
#
# TRUE (SET):  [['DAYTON', 'Located_In', 'Ohio'], ['AP', 'OrgBased_In', 'DAYTON'], ['AP', 'OrgBased_In', 'Ohio']]
# FALSE POSITIVE GENERATED: ['Dayton', 'Located_In', 'Ohio']
# -----------------------------------------------
# San Gabriel River Channel , Azusa , Calif. ;
#
# TRUE (SET):  [['San Gabriel River Channel', 'Located_In', 'Azusa'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azusa', 'Located_In', 'Calif.']]
# FALSE POSITIVE GENERATED: ['San Gabriel River Channel', 'Located_In', 'Azure']
# -----------------------------------------------
# San Gabriel River Channel , Azusa , Calif. ;
#
# TRUE (SET):  [['San Gabriel River Channel', 'Located_In', 'Azusa'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azusa', 'Located_In', 'Calif.']]
# FALSE POSITIVE GENERATED: ['Azure', 'Located_In', 'Calif.']
# -----------------------------------------------
# ( Text ) Police Major Pramot Pansakun , the commander of the Region 2 Border Patrol Police ( BPP ) , Khon Kaen , and Thai and American narcotics suppression officials accompanied by reporters , spent more than 2 hours climbing a high mountain to destroy a Hmong poppy field located along the border between Dan Sai District in Loei Province , Nakhon Thai District in Phitsanulok Province , and Lomsak District in Phetchabun Province .
#
# TRUE (SET):  [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Dan Sai District', 'Located_In', 'Loei Province'], ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province'], ['Lomsak District', 'Located_In', 'Phetchabun Province']]
# FALSE POSITIVE GENERATED: ['Pramot Pansakun', 'Work_For', 'BPP']
# -----------------------------------------------
# An urgent call for international help to avert food shortages in Poland went out both from last month 's Western economic summit in Paris and from Monday 's meeting in Brussels of 24 concerned nations chaired by the European Community Commission.
#
# TRUE (SET):  [['European Community Commission.', 'OrgBased_In', 'Brussels']]
# FALSE POSITIVE GENERATED: ['European Community', 'OrgBased_In', 'Paris']
# -----------------------------------------------
# Cheek , 53 , is a former chief and charge in Addis Ababa , Ethiopia.
#
# TRUE (SET):  [['Addis Ababa', 'Located_In', 'Ethiopia.']]
# FALSE POSITIVE GENERATED: ['Cheek', 'Live_In', 'Addis Ababa']
# -----------------------------------------------
# Cheek , 53 , is a former chief and charge in Addis Ababa , Ethiopia.
#
# TRUE (SET):  [['Addis Ababa', 'Located_In', 'Ethiopia.']]
# FALSE POSITIVE GENERATED: ['Cheek', 'Live_In', 'Ethiopia.']
# -----------------------------------------------
# Middle-class Argentines , among the most affluent in Latin America at one time , are so strapped now that they are selling off heirlooms that had been in their families since the days when beef and grain made Argentina one of the world 's wealthiest nations.
#
# TRUE (SET):  [['Argentina', 'Located_In', 'Latin America']]
# FALSE POSITIVE GENERATED: ['Argentines', 'Live_In', 'Argentina']
# -----------------------------------------------
# Middle-class Argentines , among the most affluent in Latin America at one time , are so strapped now that they are selling off heirlooms that had been in their families since the days when beef and grain made Argentina one of the world 's wealthiest nations.
#
# TRUE (SET):  [['Argentina', 'Located_In', 'Latin America']]
# FALSE POSITIVE GENERATED: ['Argentina', 'Live_In', 'Lat. America']
# -----------------------------------------------
# ` ` I don 't think there are any good answers why , ' ' said Virginia Towle of Wallingford , a family friend.
#
# TRUE (SET):  [['Virginia Towle', 'Live_In', 'Wallingford']]
# FALSE POSITIVE GENERATED: ['Virginia Towle', 'Live_In', 'Wildenbrook']
# -----------------------------------------------
# The meeting will be held at the request of the Soviet Union , which also plans direct talks with resistance leader Prince Norodom Sihanouk , said Sihanouk 's son and representative in Thailand , Prince Norodom Ranariddh .
#
# TRUE (SET):  [['Prince Norodom Ranariddh', 'Live_In', 'Thailand']]
# FALSE POSITIVE GENERATED: ['Pearl Norodom Sihanouk', 'Live_In', 'Soviet Union']
# -----------------------------------------------
# River North 's nouvelle sensibilities also might be offended by the Ranch 's menu , which features items such as the ` ` Jesse James Steak ( A Steal ! ) , ' ' and the occasional ornery patron .
#
# TRUE (SET):  [['Ranch', 'OrgBased_In', 'River North']]
# FALSE POSITIVE GENERATED: ['River North', 'OrgBased_In', 'California']
# -----------------------------------------------
# River North 's nouvelle sensibilities also might be offended by the Ranch 's menu , which features items such as the ` ` Jesse James Steak ( A Steal ! ) , ' ' and the occasional ornery patron .
#
# TRUE (SET):  [['Ranch', 'OrgBased_In', 'River North']]
# FALSE POSITIVE GENERATED: ['River North', 'OrgBased_In', 'Maine']
# -----------------------------------------------
# River North 's nouvelle sensibilities also might be offended by the Ranch 's menu , which features items such as the ` ` Jesse James Steak ( A Steal ! ) , ' ' and the occasional ornery patron .
#
# TRUE (SET):  [['Ranch', 'OrgBased_In', 'River North']]
# FALSE POSITIVE GENERATED: ['Jesse James Steak', 'OrgBased_In', 'California']
# -----------------------------------------------
# River North 's nouvelle sensibilities also might be offended by the Ranch 's menu , which features items such as the ` ` Jesse James Steak ( A Steal ! ) , ' ' and the occasional ornery patron .
#
# TRUE (SET):  [['Ranch', 'OrgBased_In', 'River North']]
# FALSE POSITIVE GENERATED: ['Jesse James Steak', 'OrgBased_In', 'Maine']
# -----------------------------------------------
# It was filmed on location in Tokyo and Kyoto and is a co-production of Children 's Television Worship and NHK network in Japan .
#
# TRUE (SET):  [['Tokyo', 'Located_In', 'Japan'], ['Kyoto', 'Located_In', 'Japan']]
# FALSE POSITIVE GENERATED: ['NHK network', 'OrgBased_In', 'Japan']
# -----------------------------------------------
# The self-propelled rig Avco 5 with 14 people aboard was headed to shore early Monday when it capsized about 20 miles off the Louisiana coast , near Morgan City , Chevron spokesman Jonathan Lifa said.
#
# TRUE (SET):  [['Jonathan Lifa', 'Work_For', 'Chevron']]
# FALSE POSITIVE GENERATED: ['Avco 5', 'Located_In', 'Louisiana']
# -----------------------------------------------
# The self-propelled rig Avco 5 with 14 people aboard was headed to shore early Monday when it capsized about 20 miles off the Louisiana coast , near Morgan City , Chevron spokesman Jonathan Lifa said.
#
# TRUE (SET):  [['Jonathan Lifa', 'Work_For', 'Chevron']]
# FALSE POSITIVE GENERATED: ['Jonas Lifa', 'Work_For', 'Chryslel']
# -----------------------------------------------
# The self-propelled rig Avco 5 with 14 people aboard was headed to shore early Monday when it capsized about 20 miles off the Louisiana coast , near Morgan City , Chevron spokesman Jonathan Lifa said.
#
# TRUE (SET):  [['Jonathan Lifa', 'Work_For', 'Chevron']]
# FALSE POSITIVE GENERATED: ['Jonas Lifa', 'Work_For', 'Chevron']
# -----------------------------------------------
# The self-propelled rig Avco 5 with 14 people aboard was headed to shore early Monday when it capsized about 20 miles off the Louisiana coast , near Morgan City , Chevron spokesman Jonathan Lifa said.
#
# TRUE (SET):  [['Jonathan Lifa', 'Work_For', 'Chevron']]
# FALSE POSITIVE GENERATED: ['Morgan City', 'Located_In', 'Louisiana']
# -----------------------------------------------
# Ten Soviet volunteers and their American counterparts plan to spend August in Washington building homes for the poor as a return favor for help in earthquake-devastated Soviet Armenia.
#
# TRUE (SET):  [['Armenia.', 'Located_In', 'Soviet']]
# FALSE POSITIVE GENERATED: ['Washington', 'Located_In', 'Soviet']
# -----------------------------------------------
# Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# FALSE POSITIVE GENERATED: ['Juan Vicente Maldonado', 'Live_In', 'Ecuador']
# -----------------------------------------------
# Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# FALSE POSITIVE GENERATED: ['Juan Vicente Maldonado', 'Work_For', 'Ecuador']
# -----------------------------------------------
# Dole 's wife , Elizabeth , is a native of Salisbury , N.C .
#
# TRUE (SET):  [['Elizabeth', 'Live_In', 'Salisbury , N.C']]
# FALSE POSITIVE GENERATED: ['Elizabeth', 'Live_In', 'Salisbury, N.C']
# -----------------------------------------------
# ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# FALSE POSITIVE GENERATED: ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia']
# -----------------------------------------------
# ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# FALSE POSITIVE GENERATED: ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia']
# -----------------------------------------------
# ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# FALSE POSITIVE GENERATED: ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia']
# -----------------------------------------------
# ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# FALSE POSITIVE GENERATED: ['Union of Democratic Forces', 'OrgBased_In', 'Sofia']
# -----------------------------------------------
# ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# FALSE POSITIVE GENERATED: ['SDS', 'OrgBased_In', 'Sofia']
# -----------------------------------------------
# Starr , who served as counselor to Attorney William French Smith from 1981 prior to taking the bench in 1983 , had been mentioned as a possible Supreme Court nominee after his former colleague on the District of Columbia circuit , Robert Bork , failed to win Senate confirmation in 1987 .
#
# TRUE (SET):  [['Supreme Court', 'OrgBased_In', 'District of Columbia'], ['Senate', 'OrgBased_In', 'District of Columbia']]
# FALSE POSITIVE GENERATED: ['Starr', 'Work_For', 'Supreme Court']
# -----------------------------------------------
# Starr , who served as counselor to Attorney William French Smith from 1981 prior to taking the bench in 1983 , had been mentioned as a possible Supreme Court nominee after his former colleague on the District of Columbia circuit , Robert Bork , failed to win Senate confirmation in 1987 .
#
# TRUE (SET):  [['Supreme Court', 'OrgBased_In', 'District of Columbia'], ['Senate', 'OrgBased_In', 'District of Columbia']]
# FALSE POSITIVE GENERATED: ['Robert Bork', 'Work_For', 'District of Columbia circuit']
# -----------------------------------------------
# The program , financed with a grant from the United States Agency for International Development , is aimed at reducing infant mortality in Madagascar , an island nation in the Indian Ocean off the eastern coast of Africa.
#
# TRUE (SET):  [['Madagascar', 'Located_In', 'Indian Ocean']]
# FALSE POSITIVE GENERATED: ['Madanic', 'Located_In', 'Indian Ocean']
# -----------------------------------------------
# Minox has not shown a profit since 1981 , and on April 1 , 1988 , Robert C. Corduwener , a Netherlands businessman bought a 51 percent share of the company to take control from the Rinn family .
#
# TRUE (SET):  [['Robert C. Corduwener', 'Live_In', 'Netherlands']]
# FALSE POSITIVE GENERATED: ['Robert C. Corduwener', 'Live_In', 'Norway']
# -----------------------------------------------
# The 23-foot-tall statue was modeled after the 30-foot-tall Goddess of Democracy raised by Chinese pro-democracy demonstrators in Beijing 's Tiananmen Square on May 30.
#
# TRUE (SET):  [['Tiananmen Square', 'Located_In', 'Beijing']]
# FALSE POSITIVE GENERATED: ['Goddess of Democracy', 'Located_In', 'Beijing']
# -----------------------------------------------
# ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
#
# TRUE (SET):  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# FALSE POSITIVE GENERATED: ['XINHUA', 'OrgBased_In', 'Ulanbaatar']
# -----------------------------------------------
# ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
#
# TRUE (SET):  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# FALSE POSITIVE GENERATED: ['XINHUA', 'OrgBased_In', 'Mongolian']
# -----------------------------------------------
# In 1874 , Herbert Clark Hoover , the 31st president of the United States , was born in West Branch , Iowa .
#
# TRUE (SET):  [['Herbert Clark Hoover', 'Live_In', 'West Branch , Iowa']]
# FALSE POSITIVE GENERATED: ['Herbert Clark Hoover', 'Live_In', 'West Branch, Iowa']
# -----------------------------------------------
# ( Text ) The Rwandan Patriotic Front ( RPF ) has rescued 2 , 000 people in Bugesera in the southeastern part of Rwanda .
#
# TRUE (SET):  [['Bugesera', 'Located_In', 'Rwanda']]
# FALSE POSITIVE GENERATED: ['Bugesera', 'Located_In', 'Ruand']
# -----------------------------------------------
# GRAND RAPIDS , Mich .
#
# TRUE (SET):  [['GRAND RAPIDS', 'Located_In', 'Mich .']]
# FALSE POSITIVE GENERATED: ['GRAND RAPIDS', 'Located_In', 'Mich.']
# -----------------------------------------------
# BANGKOK , Thailand ( AP )
#
# TRUE (SET):  [['BANGKOK', 'Located_In', 'Thailand']]
# FALSE POSITIVE GENERATED: ['AP', 'OrgBased_In', 'BANGKOK']
# -----------------------------------------------
# BANGKOK , Thailand ( AP )
#
# TRUE (SET):  [['BANGKOK', 'Located_In', 'Thailand']]
# FALSE POSITIVE GENERATED: ['AP', 'OrgBased_In', 'Thailand']
# -----------------------------------------------
# Joseph Cicippio , 58 , was acting comptroller at the American University of Beirut when he was kidnapped from the campus Sept. 12 , 1986.
#
# TRUE (SET):  [['Joseph Cicippio', 'Work_For', 'American University of Beirut']]
# FALSE POSITIVE GENERATED: ['Joe Cicippio', 'Work_For', 'American University']
# -----------------------------------------------
# The FA-18 Hornet was on a mission to Pinecastle Electronic Warfare Range in the Ocala National Forest when the bomb tumbled free at 1 : 50 p.m .
#
# TRUE (SET):  [['Pinecastle Electronic Warfare Range', 'Located_In', 'Ocala National Forest']]
# FALSE POSITIVE GENERATED: ['Pinnacle Electronic Warfare Range', 'Located_In', 'Ocala National Forest']
# -----------------------------------------------
# Born in Athens , Psacharopoulos came to the United States at age 17 to enter Oberlin College , where he studied art history .
#
# TRUE (SET):  [['Oberlin College', 'OrgBased_In', 'United States']]
# FALSE POSITIVE GENERATED: ['Psacharopoulos', 'Live_In', 'Athens']
# -----------------------------------------------
# The prime was accompanied by his wife , Datuk Sri Datin Paduka Dr. Siti Hasmah and the deputy secretary of the Foreign Ministry , Datuk Abdul Halim Ali , during his brief visit to South Africa .
#
# TRUE (SET):  [['Datuk Abdul Halim Ali', 'Work_For', 'Foreign Ministry']]
# FALSE POSITIVE GENERATED: ['Datuk Sri Datin Paduka Dr. Siti Hasmah', 'Work_For', 'Foreign Ministry']
# -----------------------------------------------
# The movie 's script remains a secret , but Stone has said Kevin Costner will star as New Orleans prosecutor Jim Garrison , who said that Kennedy was the victim of an FBI and CIA conspiracy and that Lee Harvey Oswald , identified by a presidential commission as the lone assassin , was set up to take the blame. ;
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# FALSE POSITIVE GENERATED: ['Kenneth Costner', 'Kill', 'Kenneth Kennedy']
# -----------------------------------------------
# Becton Dickinson sells needle containers to doctors and hospitals but may develop a container for home use , said Linda Schmitt , an assistant product manager.
#
# TRUE (SET):  [['Linda Schmitt', 'Work_For', 'Becton Dickinson']]
# FALSE POSITIVE GENERATED: ['Becton Dickinson', 'Work_For', 'Doctors']
# -----------------------------------------------
# Becton Dickinson sells needle containers to doctors and hospitals but may develop a container for home use , said Linda Schmitt , an assistant product manager.
#
# TRUE (SET):  [['Linda Schmitt', 'Work_For', 'Becton Dickinson']]
# FALSE POSITIVE GENERATED: ['Linda Schmitt', 'Work_For', 'Assist Product Manager']
# -----------------------------------------------
# The police files on Kennedy 's shooting could shed new light on persistent questions about whether Sirhan Bishara Sirhan was the only gunman in the shooting .
#
# TRUE (SET):  [['Sirhan Bishara Sirhan', 'Kill', 'Kennedy']]
# FALSE POSITIVE GENERATED: ['Serhan Bishara Sirhan', 'Kill', 'Kennedy']
# -----------------------------------------------
# In 1936 , rock legend Buddy Holly was born Charles Hardin Holley in Lubbock , Texas .
#
# TRUE (SET):  [['Buddy Holly', 'Live_In', 'Lubbock , Texas'], ['Charles Hardin Holley', 'Live_In', 'Lubbock , Texas']]
# FALSE POSITIVE GENERATED: ['Buddy Holly', 'Live_In', 'Lucbock, Texas']
# -----------------------------------------------
# Walesa said Solidarity wants to avoid unrest .
#
# TRUE (SET):  [['Walesa', 'Work_For', 'Solidarity']]
# FALSE POSITIVE GENERATED: ['So Solidarity', 'OrgBased_In', 'Wales']
# -----------------------------------------------
# In 1817 , naturalist-author Henry David Thoreau was born in Concord , Mass .
#
# TRUE (SET):  [['Henry David Thoreau', 'Live_In', 'Concord , Mass']]
# FALSE POSITIVE GENERATED: ['Henry David Thoreau', 'Live_In', 'Concordia, Mass']
# -----------------------------------------------
# It almost makes me want to laugh. ( Minoli ) Why ? ( Fini ) Bossi is a very strange character and his extreme envy has been demonstrated. ( passage omitted ) He tried to get votes from the south , those votes which he now despises so much , but the south sent him back to the valleys. ( Minoli ) You said that Bossi reminded you of Hitler trapped in his Berlin bunker , a man with delusions of grandeur and a tendency towards suicide .
#
# TRUE (SET):  [['Hitler', 'Live_In', 'Berlin']]
# FALSE POSITIVE GENERATED: ['Bossi', 'Live_In', 'Berlin']
# -----------------------------------------------
# ` ` One thing I have learned over the past 17 months is that the truth is hard to find , and it remains so , ' ' said Mrs. Higgins , 37 , who is a major inthe Marine Corps and works at the Pentagon as a public information officer.
#
# TRUE (SET):  [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Pentagon']]
# FALSE POSITIVE GENERATED: ['Mrs. Higgins', 'Work_For', 'Potentially']
# -----------------------------------------------
# ` ` One thing I have learned over the past 17 months is that the truth is hard to find , and it remains so , ' ' said Mrs. Higgins , 37 , who is a major inthe Marine Corps and works at the Pentagon as a public information officer.
#
# TRUE (SET):  [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Pentagon']]
# FALSE POSITIVE GENERATED: ['Mrs. Higgins', 'Work_For', 'Potentially']
# -----------------------------------------------
# ` ` One thing I have learned over the past 17 months is that the truth is hard to find , and it remains so , ' ' said Mrs. Higgins , 37 , who is a major inthe Marine Corps and works at the Pentagon as a public information officer.
#
# TRUE (SET):  [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Pentagon']]
# FALSE POSITIVE GENERATED: ['Mrs. Higgins', 'Work_For', 'Potentially']
# -----------------------------------------------
# ` ` One thing I have learned over the past 17 months is that the truth is hard to find , and it remains so , ' ' said Mrs. Higgins , 37 , who is a major inthe Marine Corps and works at the Pentagon as a public information officer.
#
# TRUE (SET):  [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Pentagon']]
# FALSE POSITIVE GENERATED: ['Mrs. Higgins', 'Work_For', 'Potentially']
# -----------------------------------------------
# ` ` One thing I have learned over the past 17 months is that the truth is hard to find , and it remains so , ' ' said Mrs. Higgins , 37 , who is a major inthe Marine Corps and works at the Pentagon as a public information officer.
#
# TRUE (SET):  [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Pentagon']]
# FALSE POSITIVE GENERATED: ['Potentially', 'Work_For', 'Potentially']
# -----------------------------------------------
# A golden future seemed assured when , at 25 , Ogdon shared top place with Soviet pianist Vladimir Ashkenazy in the piano section of the 1962 Moscow Tchaikovsky International Competition for young musicians.
#
# TRUE (SET):  [['Vladimir Ashkenazy', 'Live_In', 'Soviet']]
# FALSE POSITIVE GENERATED: ['Tchaikovsky International Competition', 'OrgBased_In', 'Moscow']
# -----------------------------------------------
# A golden future seemed assured when , at 25 , Ogdon shared top place with Soviet pianist Vladimir Ashkenazy in the piano section of the 1962 Moscow Tchaikovsky International Competition for young musicians.
#
# TRUE (SET):  [['Vladimir Ashkenazy', 'Live_In', 'Soviet']]
# FALSE POSITIVE GENERATED: ['Tchaikovsky International Competition', 'OrgBased_In', 'Moscow']
# -----------------------------------------------
# A golden future seemed assured when , at 25 , Ogdon shared top place with Soviet pianist Vladimir Ashkenazy in the piano section of the 1962 Moscow Tchaikovsky International Competition for young musicians.
#
# TRUE (SET):  [['Vladimir Ashkenazy', 'Live_In', 'Soviet']]
# FALSE POSITIVE GENERATED: ['Tchaikovsky International Competition', 'OrgBased_In', 'Moscow']
# -----------------------------------------------
# 1911 , playwright Tennessee Williams was born in Columbus , Miss.
#
# TRUE (SET):  [['Tennessee Williams', 'Live_In', 'Columbus , Miss.']]
# FALSE POSITIVE GENERATED: ['Tennessee Williams', 'Live_In', 'Columbus, Miss.']
# -----------------------------------------------
# BRISBANE , Australia ( AP )
#
# TRUE (SET):  [['BRISBANE', 'Located_In', 'Australia'], ['AP', 'OrgBased_In', 'BRISBANE'], ['AP', 'OrgBased_In', 'Australia']]
# FALSE POSITIVE GENERATED: ['BRISANBRIE', 'Located_In', 'Australia']
# -----------------------------------------------
# BRISBANE , Australia ( AP )
#
# TRUE (SET):  [['BRISBANE', 'Located_In', 'Australia'], ['AP', 'OrgBased_In', 'BRISBANE'], ['AP', 'OrgBased_In', 'Australia']]
# FALSE POSITIVE GENERATED: ['AP', 'OrgBased_In', 'BRISANBRIE']
# -----------------------------------------------
# Photographer , author , filmmaker and composer Gordon Parks , 76 , born in Fort Scott , Kan. , who was on the photographic staff of Life Magazine for 19 years before branching out into other activities.
#
# TRUE (SET):  [['Gordon Parks', 'Live_In', 'Fort Scott , Kan.']]
# FALSE POSITIVE GENERATED: ['G Gordon Parks', 'Live_In', 'Fort Scott, Kan.']
# -----------------------------------------------
# In 1830 , poet Emily Dickinson was born in Amherst , Mass.
#
# TRUE (SET):  [['Emily Dickinson', 'Live_In', 'Amherst , Mass.']]
# FALSE POSITIVE GENERATED: ['Emily Dickinson', 'Live_In', 'Amherst, Mass.']
# -----------------------------------------------
# A statement from military headquarters said the aircraft crashed during a 260-mile flight to Khartoum from Kassala in eastern Sudan near the Ethiopian border.
#
# TRUE (SET):  [['Kassala', 'Located_In', 'Sudan']]
# FALSE POSITIVE GENERATED: ['Kansala', 'Located_In', 'Sudan']
# -----------------------------------------------
# Norton Winfred Simon was born on Feb. 5 , 1907 , in Portland , Ore. , and spent his teen-age years in San Francisco .
#
# TRUE (SET):  [['Norton Winfred Simon', 'Live_In', 'Portland , Ore.']]
# FALSE POSITIVE GENERATED: ['Montgomery', 'Located_In', 'Portland, Ore.']
# -----------------------------------------------
# Norton Winfred Simon was born on Feb. 5 , 1907 , in Portland , Ore. , and spent his teen-age years in San Francisco .
#
# TRUE (SET):  [['Norton Winfred Simon', 'Live_In', 'Portland , Ore.']]
# FALSE POSITIVE GENERATED: ['Montgomery', 'Live_In', 'Portland, Ore.']
# -----------------------------------------------
# This Latin American group 's reaction came two days after the military leaders of Haiti made Emile Jonassaint provisional president of Haiti , following the Haitian Parliament 's declaration that the post was vacant .
#
# TRUE (SET):  [['Emile Jonassaint', 'Live_In', 'Haiti'], ['Emile Jonassaint', 'Live_In', 'Haiti'], ['Haitian Parliament', 'OrgBased_In', 'Haiti'], ['Haitian Parliament', 'OrgBased_In', 'Haiti']]
# FALSE POSITIVE GENERATED: ['Emmel Jonassaint', 'Live_In', 'Haiti']
# -----------------------------------------------
# Yahia Bouguettaya , the former mayor of Mohammadia , south-east Algeria , and Mohamed Touali , an activist in Algeria 's Ettahadi ( Challenge ) political party , were assassinated Wednesday .
#
# TRUE (SET):  [['Mohammadia', 'Located_In', 'Algeria'], ['Mohamed Touali', 'Work_For', 'Ettahadi ( Challenge ) political party'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria']]
# FALSE POSITIVE GENERATED: ['Yahia Bouguettaya', 'Live_In', 'Mohammadia']
# -----------------------------------------------
# Yahia Bouguettaya , the former mayor of Mohammadia , south-east Algeria , and Mohamed Touali , an activist in Algeria 's Ettahadi ( Challenge ) political party , were assassinated Wednesday .
#
# TRUE (SET):  [['Mohammadia', 'Located_In', 'Algeria'], ['Mohamed Touali', 'Work_For', 'Ettahadi ( Challenge ) political party'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria']]
# FALSE POSITIVE GENERATED: ['Mohamed Touali', 'Work_For', 'Ettahadi (Challenge)']
# -----------------------------------------------
# Yahia Bouguettaya , the former mayor of Mohammadia , south-east Algeria , and Mohamed Touali , an activist in Algeria 's Ettahadi ( Challenge ) political party , were assassinated Wednesday .
#
# TRUE (SET):  [['Mohammadia', 'Located_In', 'Algeria'], ['Mohamed Touali', 'Work_For', 'Ettahadi ( Challenge ) political party'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria']]
# FALSE POSITIVE GENERATED: ['Ettahadi (Challenge)', 'OrgBased_In', 'Algeria']
# -----------------------------------------------
# The PRAVDA newspaper carries an interview with Radovan Karadzic , leader of Bosnian Serbs and vice-president of the Union of Serb Writers .
#
# TRUE (SET):  [['Radovan Karadzic', 'Work_For', 'Union of Serb Writers']]
# FALSE POSITIVE GENERATED: ['Radovan Karadzic', 'Live_In', 'Bosnia and Herzegovina']
# -----------------------------------------------
# The PRAVDA newspaper carries an interview with Radovan Karadzic , leader of Bosnian Serbs and vice-president of the Union of Serb Writers .
#
# TRUE (SET):  [['Radovan Karadzic', 'Work_For', 'Union of Serb Writers']]
# FALSE POSITIVE GENERATED: ['Radovan Karadzic', 'Work_For', 'Union of Serbian Writers']
# -----------------------------------------------
# ( Text ) The National Central Organization of Panamanian Workers ( CNTP ) , which comprises three workers ' federations and 16 unions for a total of 12 , 000 workers , has proclaimed its determination to support Dr. Ernesto Perez Balladares for the presidency of the Republic .
#
# TRUE (SET):  [['The National Central Organization of Panamanian Workers', 'OrgBased_In', 'the Republic'], ['CNTP', 'OrgBased_In', 'the Republic'], ['Ernesto Perez Balladares', 'Live_In', 'the Republic']]
# FALSE POSITIVE GENERATED: ['The National Central Organization of Panamanian Workers', 'OrgBased_In', 'Panama']
# -----------------------------------------------
# ( Text ) The National Central Organization of Panamanian Workers ( CNTP ) , which comprises three workers ' federations and 16 unions for a total of 12 , 000 workers , has proclaimed its determination to support Dr. Ernesto Perez Balladares for the presidency of the Republic .
#
# TRUE (SET):  [['The National Central Organization of Panamanian Workers', 'OrgBased_In', 'the Republic'], ['CNTP', 'OrgBased_In', 'the Republic'], ['Ernesto Perez Balladares', 'Live_In', 'the Republic']]
# FALSE POSITIVE GENERATED: ['Dr. Ernesto Perez Balladares', 'Live_In', 'Panama']
# -----------------------------------------------
# A mechanized infantry battalion belonging to the 21st Brigade of Cerro Muriano in Cordoba and to the 12th Brigade in Botoa in Badajoz , a company of the Special Operations Group in Alicante , and a squadron from the Jarama 1st Cavalry Brigade from Salamanca make up the Cordoba Group .
#
# TRUE (SET):  [['21st Brigade of Cerro Muriano', 'OrgBased_In', 'Cordoba'], ['12th Brigade', 'OrgBased_In', 'Botoa'], ['12th Brigade', 'OrgBased_In', 'Badajoz'], ['Special Operations Group', 'OrgBased_In', 'Alicante'], ['Jarama 1st Cavalry Brigade', 'OrgBased_In', 'Salamanca']]
# FALSE POSITIVE GENERATED: ['Cerro Muriano', 'Work_For', '21st Brigade']
# -----------------------------------------------
# A mechanized infantry battalion belonging to the 21st Brigade of Cerro Muriano in Cordoba and to the 12th Brigade in Botoa in Badajoz , a company of the Special Operations Group in Alicante , and a squadron from the Jarama 1st Cavalry Brigade from Salamanca make up the Cordoba Group .
#
# TRUE (SET):  [['21st Brigade of Cerro Muriano', 'OrgBased_In', 'Cordoba'], ['12th Brigade', 'OrgBased_In', 'Botoa'], ['12th Brigade', 'OrgBased_In', 'Badajoz'], ['Special Operations Group', 'OrgBased_In', 'Alicante'], ['Jarama 1st Cavalry Brigade', 'OrgBased_In', 'Salamanca']]
# FALSE POSITIVE GENERATED: ['Badajoz', 'Located_In', 'Cordoba']
# -----------------------------------------------
# A mechanized infantry battalion belonging to the 21st Brigade of Cerro Muriano in Cordoba and to the 12th Brigade in Botoa in Badajoz , a company of the Special Operations Group in Alicante , and a squadron from the Jarama 1st Cavalry Brigade from Salamanca make up the Cordoba Group .
#
# TRUE (SET):  [['21st Brigade of Cerro Muriano', 'OrgBased_In', 'Cordoba'], ['12th Brigade', 'OrgBased_In', 'Botoa'], ['12th Brigade', 'OrgBased_In', 'Badajoz'], ['Special Operations Group', 'OrgBased_In', 'Alicante'], ['Jarama 1st Cavalry Brigade', 'OrgBased_In', 'Salamanca']]
# FALSE POSITIVE GENERATED: ['Badajoz', 'Located_In', 'Cordoba']
# -----------------------------------------------
# Treiki disclosed the planned missile tests during Security Council debate Tuesday night after the U.S. 6th Fleet informed Libyan air traffic controllers so they could divert civilian air traffic .
#
# TRUE (SET):  [['6th Fleet', 'OrgBased_In', 'U.S.']]
# FALSE POSITIVE GENERATED: ['Treiki', 'Live_In', 'U.S.']
# -----------------------------------------------
# Britain 's Duchess of York and former Philippines first lady Imelda Marcos topped the list by Blackwell , a designer and self-appointed fashion arbiter whose real name is Richard Sylvan Selzer .
#
# TRUE (SET):  [['Duchess of York', 'Live_In', 'Britain'], ['Imelda Marcos', 'Live_In', 'Philippines']]
# FALSE POSITIVE GENERATED: ['Blackwell', 'Live_In', 'Britain']
# -----------------------------------------------
# Britain 's Duchess of York and former Philippines first lady Imelda Marcos topped the list by Blackwell , a designer and self-appointed fashion arbiter whose real name is Richard Sylvan Selzer .
#
# TRUE (SET):  [['Duchess of York', 'Live_In', 'Britain'], ['Imelda Marcos', 'Live_In', 'Philippines']]
# FALSE POSITIVE GENERATED: ['Richard Sylvan Selzer', 'Live_In', 'Philippines']
# -----------------------------------------------
# Winter , 53 , a former Yale University law professor who took the bench in 1982 , and Starr , a fellow appointee of President Reagan , are both known as judicial conservatives .
#
# TRUE (SET):  [['Winter', 'Work_For', 'Yale University']]
# FALSE POSITIVE GENERATED: ['Starter', 'Work_For', 'President Reagan']
# -----------------------------------------------
# In 1873 , radio electronics pioneer Dr. Lee DeForest was born in Council Bluffs , Iowa .
#
# TRUE (SET):  [['Dr. Lee DeForest', 'Live_In', 'Council Bluffs , Iowa']]
# FALSE POSITIVE GENERATED: ['Dr. Lee DeForest', 'Live_In', 'Council Bluffs, Iowa']
# -----------------------------------------------
# In southwest Louisiana 's Cameron Parish ( county ) , civil defense director Hayes Picou about 8 , 500 of the low-lying parish 's 10 , 000 residents had evacuated the southern coast , most to stay with friends or relatives.
#
# TRUE (SET):  [['Cameron Parish', 'Located_In', 'Louisiana'], ['Hayes Picou', 'Live_In', 'Louisiana'], ['Hayes Picou', 'Live_In', 'Cameron Parish']]
# FALSE POSITIVE GENERATED: ['Cardamo Parish', 'Located_In', 'Louisiana']
# -----------------------------------------------
# The Internal Revenue Service and Manufacturers Hanover Trust Co. of New York , two of the largest creditors in the Herbert Hunt bankruptcy , said they will file a repayment plan by Friday.
#
# TRUE (SET):  [['Manufacturers Hanover Trust Co.', 'OrgBased_In', 'New York']]
# FALSE POSITIVE GENERATED: ['The Internal Revenue Service', 'OrgBased_In', 'New York']
# -----------------------------------------------
# Such theories , which are not alone in the international press , find support in another agreement that was also signed in Geneva -- which the Croatian opposition ostensibly did not notice , to the great surprise and almost astonishment of all , and consequently did not comment on , although the integral text was published in Croatian newspapers -- the agreement signed between Mile Akmadzic , on behalf of the Croatian Republic of Herceg-Bosna , and Nikola Koljevic , on behalf of the Serbian Republic , in which both sides emphasize that " there are no disputed issues between them that cannot be solved in a peaceful way . "
#
# TRUE (SET):  [['Mile Akmadzic', 'Live_In', 'Croatian Republic of Herceg-Bosna'], ['Nikola Koljevic', 'Live_In', 'Serbian Republic']]
# FALSE POSITIVE GENERATED: ['Mile Akmadzic', 'Work_For', 'Croatian Republic of Herceg-Bosna']
# -----------------------------------------------
# Such theories , which are not alone in the international press , find support in another agreement that was also signed in Geneva -- which the Croatian opposition ostensibly did not notice , to the great surprise and almost astonishment of all , and consequently did not comment on , although the integral text was published in Croatian newspapers -- the agreement signed between Mile Akmadzic , on behalf of the Croatian Republic of Herceg-Bosna , and Nikola Koljevic , on behalf of the Serbian Republic , in which both sides emphasize that " there are no disputed issues between them that cannot be solved in a peaceful way . "
#
# TRUE (SET):  [['Mile Akmadzic', 'Live_In', 'Croatian Republic of Herceg-Bosna'], ['Nikola Koljevic', 'Live_In', 'Serbian Republic']]
# FALSE POSITIVE GENERATED: ['Nikokoljevic', 'Work_For', 'Serbian Republic']
# -----------------------------------------------
# In 1890 , the 34th President of the United States , Dwight D. Eisenhower , was born in Denison , Texas .
#
# TRUE (SET):  [['Dwight D. Eisenhower', 'Live_In', 'Denison , Texas']]
# FALSE POSITIVE GENERATED: ['Dwight D. Eisenhower', 'Live_In', 'Denison, Texas']
# -----------------------------------------------
# The federal appeals court threw out the death sentence of John Harvey Adamson , convicted of murdering Phoenix newspaper reporter Don Bolles in 1976 .
#
# TRUE (SET):  [['John Harvey Adamson', 'Kill', 'Don Bolles']]
# FALSE POSITIVE GENERATED: ['John Harvey Adamson', 'Kill', 'Phoenix newspaper reporter']
# -----------------------------------------------
# ` ` I think the longer they talk , the longer they delay , the greater the chances that we may turn this around and get them all home , ' ' said Ms. Say in Nashville , Tenn.
#
# TRUE (SET):  [['Nashville', 'Located_In', 'Tenn.']]
# FALSE POSITIVE GENERATED: ['Ms. Say', 'Live_In', 'Nashville']
# -----------------------------------------------
# ` ` I think the longer they talk , the longer they delay , the greater the chances that we may turn this around and get them all home , ' ' said Ms. Say in Nashville , Tenn.
#
# TRUE (SET):  [['Nashville', 'Located_In', 'Tenn.']]
# FALSE POSITIVE GENERATED: ['Ms. Say', 'Live_In', 'Tenn.']
# -----------------------------------------------
# ( Text ) Taipei , Jan. 20 ( CNA ) -- Foreign Chien Fu will leave for the United States on January 29 to give two speeches in the Boston area .
#
# TRUE (SET):  [['Chien Fu', 'Live_In', 'Taipei']]
# FALSE POSITIVE GENERATED: ['CNA', 'OrgBased_In', 'Taipei']
# -----------------------------------------------
# ( Text ) Taipei , Jan. 20 ( CNA ) -- Foreign Chien Fu will leave for the United States on January 29 to give two speeches in the Boston area .
#
# TRUE (SET):  [['Chien Fu', 'Live_In', 'Taipei']]
# FALSE POSITIVE GENERATED: ['Chen Fu', 'Live_In', 'Taipei']
# -----------------------------------------------
# ( Text ) Taipei , Jan. 20 ( CNA ) -- Foreign Chien Fu will leave for the United States on January 29 to give two speeches in the Boston area .
#
# TRUE (SET):  [['Chien Fu', 'Live_In', 'Taipei']]
# FALSE POSITIVE GENERATED: ['Chen Fu', 'Live_In', 'United States']
# -----------------------------------------------
# On this date : In 1843 , the 25th President of the United States , William McKinley , was born in Niles , Ohio .
#
# TRUE (SET):  [['William McKinley', 'Live_In', 'Niles , Ohio']]
# FALSE POSITIVE GENERATED: ['William McKinley', 'Live_In', 'Niles, Ohio']
# -----------------------------------------------
# In 1874 , Herbert Clark Hoover , the 31st president of the United States , was born in West Branch , Iowa .
#
# TRUE (SET):  [['Herbert Clark Hoover', 'Live_In', 'West Branch , Iowa']]
# FALSE POSITIVE GENERATED: ['Herbert Clark Hoover', 'Live_In', 'West Branch, Iowa']
# -----------------------------------------------
# Another beacon of the better life is Prateep Ungsongtham , known as the ` ` Slum Angel of Bangkok. ' '
#
# TRUE (SET):  [['Prateep Ungsongtham', 'Live_In', 'Bangkok.']]
# FALSE POSITIVE GENERATED: ['Prateeep Ungsongtham', 'Live_In', 'Bangkok']
# -----------------------------------------------
# Police arrested 10 Spanish Basque militants , including Jose Antonio Urutigoechea , considered by Madrid to be a top leader of the Spanish Basque separatist organization ETA , authorities said today .
#
# TRUE (SET):  [['Jose Antonio Urutigoechea', 'Work_For', 'ETA']]
# FALSE POSITIVE GENERATED: ['Joaquin Antonio Urutigoechea', 'Work_For', 'ETA']
# -----------------------------------------------
# ` ` It 's been a nightmare , ' ' said Shelley Yeager , director of the Clara Barton camp at Oxford in central Massachusetts.
#
# TRUE (SET):  [['Oxford', 'Located_In', 'Massachusetts.']]
# FALSE POSITIVE GENERATED: ['Shandey Yeager', 'Live_In', 'Clara Barton']
# -----------------------------------------------
# Meanwhile , the historical society in Beaumont , Texas , Richardson 's hometown , plans to raise two statues on Feb. 3 _ one of Buddy Holly , Richardson and Valens , and a second of the Big Bopper alone .
#
# TRUE (SET):  [['Richardson', 'Live_In', 'Beaumont , Texas']]
# FALSE POSITIVE GENERATED: ['Bearut', 'Located_In', 'Texas']
# -----------------------------------------------
# ( Text ) Saint-Gall , Switzerland , Feb 2 ( AFP ) -- The wreck of a twin-engine aircraft has been found 160 metres below the surface of Lake Constance , Swiss police said Tuesday ( 1 February ) .
#
# TRUE (SET):  [['Saint-Gall', 'Located_In', 'Switzerland'], ['AFP', 'OrgBased_In', 'Saint-Gall'], ['AFP', 'OrgBased_In', 'Switzerland']]
# FALSE POSITIVE GENERATED: ['Stan-Gall', 'Located_In', 'Switzerland']
# -----------------------------------------------
# In Washington state , near the Canadian border , firefighters hoped to contain an 850-acre fire by tonight , said Greg Thayer of the Forest Service.
#
# TRUE (SET):  [['Greg Thayer', 'Work_For', 'Forest Service.']]
# FALSE POSITIVE GENERATED: ['Washington state', 'Located_In', 'Canada']
# -----------------------------------------------
# In an " electoral communique " signed by CNTP Secretary Luis Cobos R. , the organization said it hopes that with this decision " we will achieve the return of the Torrijist forces to power to stimulate the process of national liberation . "
#
# TRUE (SET):  [['Luis Cobos R.', 'Work_For', 'CNTP']]
# FALSE POSITIVE GENERATED: ['CNTP', 'OrgBased_In', 'Luis Cobos R.']
# -----------------------------------------------
# In it , actor Edwin Booth tells us his version of his life story , in which he and not his brother John Wilkes shoots Abraham Lincoln at Ford 's Theater .
#
# TRUE (SET):  [['John Wilkes', 'Kill', 'Abraham Lincoln']]
# FALSE POSITIVE GENERATED: ['Edwin Booth', 'Kill', 'Abraham Lincoln']
# -----------------------------------------------
# In 1801 , Mormon leader Brigham Young was born in Whitingham , Vt .
#
# TRUE (SET):  [['Brigham Young', 'Live_In', 'Whitingham , Vt']]
# FALSE POSITIVE GENERATED: ['Brigham Young', 'Live_In', 'Whitingham, Vt']
# -----------------------------------------------
# They will also be cleaning the car Oswald drove on the day Kennedy was shot and the ambulance that took Oswald to hospital after he was shot by Jack Ruby .
#
# TRUE (SET):  [['Jack Ruby', 'Kill', 'Oswald']]
# FALSE POSITIVE GENERATED: ['Oswald', 'Kill', 'Kennedy']
# -----------------------------------------------
# Widespread street flooding was reported throughout Brazoria , Fort Bend , Galveston and southern Harris Counties in southeast Texas.
#
# TRUE (SET):  [['Brazoria', 'Located_In', 'Texas.'], ['Fort Bend', 'Located_In', 'Texas.'], ['Galveston', 'Located_In', 'Texas.'], ['Harris Counties', 'Located_In', 'Texas.']]
# FALSE POSITIVE GENERATED: ['Brazoria', 'Located_In', 'Fort Bend']
# -----------------------------------------------
# Widespread street flooding was reported throughout Brazoria , Fort Bend , Galveston and southern Harris Counties in southeast Texas.
#
# TRUE (SET):  [['Brazoria', 'Located_In', 'Texas.'], ['Fort Bend', 'Located_In', 'Texas.'], ['Galveston', 'Located_In', 'Texas.'], ['Harris Counties', 'Located_In', 'Texas.']]
# FALSE POSITIVE GENERATED: ['Fort Bend', 'Located_In', 'Galveston']
# -----------------------------------------------
# Widespread street flooding was reported throughout Brazoria , Fort Bend , Galveston and southern Harris Counties in southeast Texas.
#
# TRUE (SET):  [['Brazoria', 'Located_In', 'Texas.'], ['Fort Bend', 'Located_In', 'Texas.'], ['Galveston', 'Located_In', 'Texas.'], ['Harris Counties', 'Located_In', 'Texas.']]
# FALSE POSITIVE GENERATED: ['Harrisburg', 'Located_In', 'Texas']
# -----------------------------------------------
# Widespread street flooding was reported throughout Brazoria , Fort Bend , Galveston and southern Harris Counties in southeast Texas.
#
# TRUE (SET):  [['Brazoria', 'Located_In', 'Texas.'], ['Fort Bend', 'Located_In', 'Texas.'], ['Galveston', 'Located_In', 'Texas.'], ['Harris Counties', 'Located_In', 'Texas.']]
# FALSE POSITIVE GENERATED: ['Harrisburg', 'Located_In', 'Texas']
# -----------------------------------------------
# Navy sources said the Coral Sea , on duty with the 6th Fleet in the Mediterranean , left ` ` a few hours ' ' ahead of its scheduled departure.
#
# TRUE (SET):  [['6th Fleet', 'OrgBased_In', 'Mediterranean']]
# FALSE POSITIVE GENERATED: ['Coral Sea', 'Located_In', 'Mediterranean']
# -----------------------------------------------

# %%
print (len(fp_list))
print ("TP: ", len(tp))
precision = len(tp) / (len(tp) + len(fp))
print ("PRECISION: ", precision)
# Out:
# 123
# TP:  201
# PRECISION:  0.6203703703703703

# %%
fn = ()
fn_list = []
text = []
gen_list = []
for row in df.iterrows():
    for t_triplet in row[1]["gold"]:
        flag = True
        if t_triplet in row[1]["generated"]:
            continue
        else:
            for g_triplet in row[1]["generated"]:
                if ((str(t_triplet[0]) in str(g_triplet[0])) or (str(g_triplet[0]) in str(t_triplet[0]))) and ((str(t_triplet[2]) in str(g_triplet[2])) or (str(g_triplet[2]) in str(t_triplet[2]))) and (str(t_triplet[1]) == str(g_triplet[1])):
                    flag = False
            if flag:
                text.append(row[1]["text"])
                fn_list.append(t_triplet)
                gen_list.append(str(row[1]["generated"]))
                fn += (t_triplet,)
                print (row[1]["text"] + "\n")
                print ("TRUE (SET): ", row[1]["gold"])
                print ("GENERATED: " + str(row[1]["generated"]))
                print ("FALSE NEGATIVE: " + str(t_triplet))
                print ("-----------------------------------------------")
# Out:
# Lightning ignited a firestorm that charred 10 , 000 acres in central Idaho , including much of the small resort town of Lowman , about 70 miles northeast of Boise.
#
# TRUE (SET):  [['Lowman', 'Located_In', 'Idaho']]
# GENERATED: [['Lotman', 'Located_In', 'Idaho']]
# FALSE NEGATIVE: ['Lowman', 'Located_In', 'Idaho']
# -----------------------------------------------
# The three reactors , all at the Savannah River Plant , in Aiken , S.C. , have been shut down since last April undergoing changes to make them safer .
#
# TRUE (SET):  [['Savannah River Plant', 'Located_In', 'Aiken'], ['Savannah River Plant', 'Located_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# GENERATED: [['Savana River Plant', 'OrgBased_In', 'Aiken'], ['Savana River Plant', 'OrgBased_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# FALSE NEGATIVE: ['Savannah River Plant', 'Located_In', 'Aiken']
# -----------------------------------------------
# The three reactors , all at the Savannah River Plant , in Aiken , S.C. , have been shut down since last April undergoing changes to make them safer .
#
# TRUE (SET):  [['Savannah River Plant', 'Located_In', 'Aiken'], ['Savannah River Plant', 'Located_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# GENERATED: [['Savana River Plant', 'OrgBased_In', 'Aiken'], ['Savana River Plant', 'OrgBased_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# FALSE NEGATIVE: ['Savannah River Plant', 'Located_In', 'S.C.']
# -----------------------------------------------
# Composer Thomas is a native of Chisholm , Minn .
#
# TRUE (SET):  [['Thomas', 'Live_In', 'Chisholm'], ['Thomas', 'Live_In', 'Minn .'], ['Chisholm', 'Located_In', 'Minn .']]
# GENERATED: [['Thomas', 'Live_In', 'Chisholm, Minn']]
# FALSE NEGATIVE: ['Thomas', 'Live_In', 'Minn .']
# -----------------------------------------------
# Composer Thomas is a native of Chisholm , Minn .
#
# TRUE (SET):  [['Thomas', 'Live_In', 'Chisholm'], ['Thomas', 'Live_In', 'Minn .'], ['Chisholm', 'Located_In', 'Minn .']]
# GENERATED: [['Thomas', 'Live_In', 'Chisholm, Minn']]
# FALSE NEGATIVE: ['Chisholm', 'Located_In', 'Minn .']
# -----------------------------------------------
# Kovacevic , a Serb , has come under fire from Serbian politicians and the republic 's press since the U.S. Congress last month passed two resolutions claiming there were human rights violations in the strife-torn southern province of Kosovo.
#
# TRUE (SET):  [['Congress', 'OrgBased_In', 'U.S.']]
# GENERATED: [['Kovacevic', 'Live_In', 'Serbia']]
# FALSE NEGATIVE: ['Congress', 'OrgBased_In', 'U.S.']
# -----------------------------------------------
# On this date : In 1833 , Benjamin Harrison , the 23rd President of the United States , was born in North Bend , Ohio .
#
# TRUE (SET):  [['Benjamin Harrison', 'Live_In', 'North Bend , Ohio']]
# GENERATED: [['Benjamin Harrison', 'Live_In', 'North Bend, Ohio']]
# FALSE NEGATIVE: ['Benjamin Harrison', 'Live_In', 'North Bend , Ohio']
# -----------------------------------------------
# The book said Khrushchev 's order to ignore the blockade was disclosed in a largely unknown work by dissident Soviet historian Roy Medvedev .
#
# TRUE (SET):  [['Khrushchev', 'Live_In', 'Soviet'], ['Roy Medvedev', 'Live_In', 'Soviet']]
# GENERATED: [['Roy Medvedev', 'Live_In', 'Soviet']]
# FALSE NEGATIVE: ['Khrushchev', 'Live_In', 'Soviet']
# -----------------------------------------------
# Photo , Dueling Over a GunIt is a scene seared into the memories of Americans old enough to have watched it that November day in 1963 : Jack Ruby firing his .38-caliber Colt Cobra , above , at Lee Harvey Oswald , the man who had assassinated President John F. Kennedy two days earlier.
#
# TRUE (SET):  [['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# GENERATED: [['Lee Harvey Oswald', 'Kill', 'President John F. Kennedy']]
# FALSE NEGATIVE: ['Jack Ruby', 'Kill', 'Lee Harvey Oswald']
# -----------------------------------------------
# ` ` The Challenger accident marked a major change in the U.S. outlook and policies with respect to the flight of other than NASA astronauts , ' ' the National Aeronautics and Space Administration said in a policy statement .
#
# TRUE (SET):  [['NASA', 'OrgBased_In', 'U.S.'], ['National Aeronautics and Space Administration', 'OrgBased_In', 'U.S.']]
# GENERATED: [['NASA', 'OrgBased_In', 'U.S.']]
# FALSE NEGATIVE: ['National Aeronautics and Space Administration', 'OrgBased_In', 'U.S.']
# -----------------------------------------------
# ` ` It 's not going to make you a whole bunch of money , but that 's not why we 're doing it , ' ' said Phil Fuhrer , vice of Gannett New Media. 1-900-WEATHER offers callers the current weather and a three-day forecast , plus skiing and highway conditions in the winter and coastal reports during the summer.
#
# TRUE (SET):  [['Phil Fuhrer', 'Work_For', 'Gannett New Media.']]
# GENERATED: [['Phil Fuhrer', 'Work_For', 'Gainnet New Media']]
# FALSE NEGATIVE: ['Phil Fuhrer', 'Work_For', 'Gannett New Media.']
# -----------------------------------------------
# DAYTON , Ohio ( AP )
#
# TRUE (SET):  [['DAYTON', 'Located_In', 'Ohio'], ['AP', 'OrgBased_In', 'DAYTON'], ['AP', 'OrgBased_In', 'Ohio']]
# GENERATED: [['Dayton', 'Located_In', 'Ohio']]
# FALSE NEGATIVE: ['DAYTON', 'Located_In', 'Ohio']
# -----------------------------------------------
# DAYTON , Ohio ( AP )
#
# TRUE (SET):  [['DAYTON', 'Located_In', 'Ohio'], ['AP', 'OrgBased_In', 'DAYTON'], ['AP', 'OrgBased_In', 'Ohio']]
# GENERATED: [['Dayton', 'Located_In', 'Ohio']]
# FALSE NEGATIVE: ['AP', 'OrgBased_In', 'DAYTON']
# -----------------------------------------------
# DAYTON , Ohio ( AP )
#
# TRUE (SET):  [['DAYTON', 'Located_In', 'Ohio'], ['AP', 'OrgBased_In', 'DAYTON'], ['AP', 'OrgBased_In', 'Ohio']]
# GENERATED: [['Dayton', 'Located_In', 'Ohio']]
# FALSE NEGATIVE: ['AP', 'OrgBased_In', 'Ohio']
# -----------------------------------------------
# San Gabriel River Channel , Azusa , Calif. ;
#
# TRUE (SET):  [['San Gabriel River Channel', 'Located_In', 'Azusa'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azusa', 'Located_In', 'Calif.']]
# GENERATED: [['San Gabriel River Channel', 'Located_In', 'Azure'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azure', 'Located_In', 'Calif.']]
# FALSE NEGATIVE: ['San Gabriel River Channel', 'Located_In', 'Azusa']
# -----------------------------------------------
# San Gabriel River Channel , Azusa , Calif. ;
#
# TRUE (SET):  [['San Gabriel River Channel', 'Located_In', 'Azusa'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azusa', 'Located_In', 'Calif.']]
# GENERATED: [['San Gabriel River Channel', 'Located_In', 'Azure'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azure', 'Located_In', 'Calif.']]
# FALSE NEGATIVE: ['Azusa', 'Located_In', 'Calif.']
# -----------------------------------------------
# Derwinski , a Republican from Chicago who served 24 years in Congress , publicly denied 1978 allegations that he leaked the information and refused to testify in the matter before a federal grand jury and the House Ethics Committee .
#
# TRUE (SET):  [['Derwinski', 'Live_In', 'Chicago'], ['Derwinski', 'Work_For', 'Congress']]
# GENERATED: [['Derwinski', 'Work_For', 'Congress']]
# FALSE NEGATIVE: ['Derwinski', 'Live_In', 'Chicago']
# -----------------------------------------------
# ( Text ) Police Major Pramot Pansakun , the commander of the Region 2 Border Patrol Police ( BPP ) , Khon Kaen , and Thai and American narcotics suppression officials accompanied by reporters , spent more than 2 hours climbing a high mountain to destroy a Hmong poppy field located along the border between Dan Sai District in Loei Province , Nakhon Thai District in Phitsanulok Province , and Lomsak District in Phetchabun Province .
#
# TRUE (SET):  [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Dan Sai District', 'Located_In', 'Loei Province'], ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province'], ['Lomsak District', 'Located_In', 'Phetchabun Province']]
# GENERATED: [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Pramot Pansakun', 'Work_For', 'Border Patrol'], ['Pramot Pansakun', 'Work_For', 'BPP']]
# FALSE NEGATIVE: ['Dan Sai District', 'Located_In', 'Loei Province']
# -----------------------------------------------
# ( Text ) Police Major Pramot Pansakun , the commander of the Region 2 Border Patrol Police ( BPP ) , Khon Kaen , and Thai and American narcotics suppression officials accompanied by reporters , spent more than 2 hours climbing a high mountain to destroy a Hmong poppy field located along the border between Dan Sai District in Loei Province , Nakhon Thai District in Phitsanulok Province , and Lomsak District in Phetchabun Province .
#
# TRUE (SET):  [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Dan Sai District', 'Located_In', 'Loei Province'], ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province'], ['Lomsak District', 'Located_In', 'Phetchabun Province']]
# GENERATED: [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Pramot Pansakun', 'Work_For', 'Border Patrol'], ['Pramot Pansakun', 'Work_For', 'BPP']]
# FALSE NEGATIVE: ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province']
# -----------------------------------------------
# ( Text ) Police Major Pramot Pansakun , the commander of the Region 2 Border Patrol Police ( BPP ) , Khon Kaen , and Thai and American narcotics suppression officials accompanied by reporters , spent more than 2 hours climbing a high mountain to destroy a Hmong poppy field located along the border between Dan Sai District in Loei Province , Nakhon Thai District in Phitsanulok Province , and Lomsak District in Phetchabun Province .
#
# TRUE (SET):  [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Dan Sai District', 'Located_In', 'Loei Province'], ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province'], ['Lomsak District', 'Located_In', 'Phetchabun Province']]
# GENERATED: [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Pramot Pansakun', 'Work_For', 'Border Patrol'], ['Pramot Pansakun', 'Work_For', 'BPP']]
# FALSE NEGATIVE: ['Lomsak District', 'Located_In', 'Phetchabun Province']
# -----------------------------------------------
# Further buying was linked to rumors that the Chilean copper company Codelco was considering shutting down its smelter at Chuquicamata , the world 's largest copper mine , due to persistent mechanical problems , said Fred Demler , metals economist with Drexel Burnham Lambert Inc. in New York .
#
# TRUE (SET):  [['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.'], ['Fred Demler', 'Live_In', 'New York'], ['Drexel Burnham Lambert Inc.', 'OrgBased_In', 'New York']]
# GENERATED: [['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.'], ['Fred Demler', 'Live_In', 'New York']]
# FALSE NEGATIVE: ['Drexel Burnham Lambert Inc.', 'OrgBased_In', 'New York']
# -----------------------------------------------
# An urgent call for international help to avert food shortages in Poland went out both from last month 's Western economic summit in Paris and from Monday 's meeting in Brussels of 24 concerned nations chaired by the European Community Commission.
#
# TRUE (SET):  [['European Community Commission.', 'OrgBased_In', 'Brussels']]
# GENERATED: [['European Community', 'OrgBased_In', 'Paris']]
# FALSE NEGATIVE: ['European Community Commission.', 'OrgBased_In', 'Brussels']
# -----------------------------------------------
# Middle-class Argentines , among the most affluent in Latin America at one time , are so strapped now that they are selling off heirlooms that had been in their families since the days when beef and grain made Argentina one of the world 's wealthiest nations.
#
# TRUE (SET):  [['Argentina', 'Located_In', 'Latin America']]
# GENERATED: [['Argentines', 'Live_In', 'Argentina'], ['Argentina', 'Live_In', 'Lat. America']]
# FALSE NEGATIVE: ['Argentina', 'Located_In', 'Latin America']
# -----------------------------------------------
# ` ` I don 't think there are any good answers why , ' ' said Virginia Towle of Wallingford , a family friend.
#
# TRUE (SET):  [['Virginia Towle', 'Live_In', 'Wallingford']]
# GENERATED: [['Virginia Towle', 'Live_In', 'Wildenbrook']]
# FALSE NEGATIVE: ['Virginia Towle', 'Live_In', 'Wallingford']
# -----------------------------------------------
# River North 's nouvelle sensibilities also might be offended by the Ranch 's menu , which features items such as the ` ` Jesse James Steak ( A Steal ! ) , ' ' and the occasional ornery patron .
#
# TRUE (SET):  [['Ranch', 'OrgBased_In', 'River North']]
# GENERATED: [['River North', 'OrgBased_In', 'California'], ['River North', 'OrgBased_In', 'Maine'], ['Jesse James Steak', 'OrgBased_In', 'California'], ['Jesse James Steak', 'OrgBased_In', 'Maine']]
# FALSE NEGATIVE: ['Ranch', 'OrgBased_In', 'River North']
# -----------------------------------------------
# It was filmed on location in Tokyo and Kyoto and is a co-production of Children 's Television Worship and NHK network in Japan .
#
# TRUE (SET):  [['Tokyo', 'Located_In', 'Japan'], ['Kyoto', 'Located_In', 'Japan']]
# GENERATED: [['Tokyo', 'Located_In', 'Japan'], ['NHK network', 'OrgBased_In', 'Japan']]
# FALSE NEGATIVE: ['Kyoto', 'Located_In', 'Japan']
# -----------------------------------------------
# The self-propelled rig Avco 5 with 14 people aboard was headed to shore early Monday when it capsized about 20 miles off the Louisiana coast , near Morgan City , Chevron spokesman Jonathan Lifa said.
#
# TRUE (SET):  [['Jonathan Lifa', 'Work_For', 'Chevron']]
# GENERATED: [['Avco 5', 'Located_In', 'Louisiana'], ['Jonas Lifa', 'Work_For', 'Chryslel'], ['Jonas Lifa', 'Work_For', 'Chevron'], ['Morgan City', 'Located_In', 'Louisiana']]
# FALSE NEGATIVE: ['Jonathan Lifa', 'Work_For', 'Chevron']
# -----------------------------------------------
# Sen. Jake Garn , R-Utah , flew on the shuttle in April 1985 and Rep. Bill Nelson , D-Fla. , was aboard in January 1986 , at the invitation of NASA 's administrator .
#
# TRUE (SET):  [['Jake Garn', 'Work_For', 'NASA'], ['Bill Nelson', 'Work_For', 'NASA']]
# GENERATED: [['Jake Garn', 'Work_For', 'NASA']]
# FALSE NEGATIVE: ['Bill Nelson', 'Work_For', 'NASA']
# -----------------------------------------------
# Ten Soviet volunteers and their American counterparts plan to spend August in Washington building homes for the poor as a return favor for help in earthquake-devastated Soviet Armenia.
#
# TRUE (SET):  [['Armenia.', 'Located_In', 'Soviet']]
# GENERATED: [['Washington', 'Located_In', 'Soviet']]
# FALSE NEGATIVE: ['Armenia.', 'Located_In', 'Soviet']
# -----------------------------------------------
# Evaluating Juppe 's visit , Cetin said that the French Government was not displaying a disturbing stand toward Turkey and was very careful in not intervening in Turkey 's internal affairs .
#
# TRUE (SET):  [['Juppe', 'Work_For', 'French Government'], ['Cetin', 'Live_In', 'Turkey'], ['Cetin', 'Live_In', 'Turkey']]
# GENERATED: [['Cetin', 'Live_In', 'Turkey']]
# FALSE NEGATIVE: ['Juppe', 'Work_For', 'French Government']
# -----------------------------------------------
# Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# GENERATED: [['Juan Vicente Maldonado', 'Live_In', 'Ecuador'], ['Juan Vicente Maldonado', 'Work_For', 'Ecuador']]
# FALSE NEGATIVE: ['Andean Group', 'OrgBased_In', 'Colombia']
# -----------------------------------------------
# Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# GENERATED: [['Juan Vicente Maldonado', 'Live_In', 'Ecuador'], ['Juan Vicente Maldonado', 'Work_For', 'Ecuador']]
# FALSE NEGATIVE: ['Andean Group', 'OrgBased_In', 'Bolivia']
# -----------------------------------------------
# Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# GENERATED: [['Juan Vicente Maldonado', 'Live_In', 'Ecuador'], ['Juan Vicente Maldonado', 'Work_For', 'Ecuador']]
# FALSE NEGATIVE: ['Andean Group', 'OrgBased_In', 'Ecuador']
# -----------------------------------------------
# Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# GENERATED: [['Juan Vicente Maldonado', 'Live_In', 'Ecuador'], ['Juan Vicente Maldonado', 'Work_For', 'Ecuador']]
# FALSE NEGATIVE: ['Andean Group', 'OrgBased_In', 'Peru']
# -----------------------------------------------
# Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# GENERATED: [['Juan Vicente Maldonado', 'Live_In', 'Ecuador'], ['Juan Vicente Maldonado', 'Work_For', 'Ecuador']]
# FALSE NEGATIVE: ['Andean Group', 'OrgBased_In', 'Venezuela']
# -----------------------------------------------
# Dole 's wife , Elizabeth , is a native of Salisbury , N.C .
#
# TRUE (SET):  [['Elizabeth', 'Live_In', 'Salisbury , N.C']]
# GENERATED: [['Elizabeth', 'Live_In', 'Salisbury, N.C']]
# FALSE NEGATIVE: ['Elizabeth', 'Live_In', 'Salisbury , N.C']
# -----------------------------------------------
# ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# GENERATED: [['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Union of Democratic Forces', 'OrgBased_In', 'Sofia'], ['SDS', 'OrgBased_In', 'Sofia']]
# FALSE NEGATIVE: ['BTA', 'OrgBased_In', 'Sofia']
# -----------------------------------------------
# ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# GENERATED: [['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Union of Democratic Forces', 'OrgBased_In', 'Sofia'], ['SDS', 'OrgBased_In', 'Sofia']]
# FALSE NEGATIVE: ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria']
# -----------------------------------------------
# ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# GENERATED: [['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Union of Democratic Forces', 'OrgBased_In', 'Sofia'], ['SDS', 'OrgBased_In', 'Sofia']]
# FALSE NEGATIVE: ['BSP', 'OrgBased_In', 'Bulgaria']
# -----------------------------------------------
# ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# GENERATED: [['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Union of Democratic Forces', 'OrgBased_In', 'Sofia'], ['SDS', 'OrgBased_In', 'Sofia']]
# FALSE NEGATIVE: ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria']
# -----------------------------------------------
# ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# GENERATED: [['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist Party', 'OrgBased_In', 'Sofia'], ['Union of Democratic Forces', 'OrgBased_In', 'Sofia'], ['SDS', 'OrgBased_In', 'Sofia']]
# FALSE NEGATIVE: ['SDS', 'OrgBased_In', 'Bulgaria']
# -----------------------------------------------
# Starr , who served as counselor to Attorney William French Smith from 1981 prior to taking the bench in 1983 , had been mentioned as a possible Supreme Court nominee after his former colleague on the District of Columbia circuit , Robert Bork , failed to win Senate confirmation in 1987 .
#
# TRUE (SET):  [['Supreme Court', 'OrgBased_In', 'District of Columbia'], ['Senate', 'OrgBased_In', 'District of Columbia']]
# GENERATED: [['Starr', 'Work_For', 'Supreme Court'], ['Robert Bork', 'Work_For', 'District of Columbia circuit']]
# FALSE NEGATIVE: ['Supreme Court', 'OrgBased_In', 'District of Columbia']
# -----------------------------------------------
# Starr , who served as counselor to Attorney William French Smith from 1981 prior to taking the bench in 1983 , had been mentioned as a possible Supreme Court nominee after his former colleague on the District of Columbia circuit , Robert Bork , failed to win Senate confirmation in 1987 .
#
# TRUE (SET):  [['Supreme Court', 'OrgBased_In', 'District of Columbia'], ['Senate', 'OrgBased_In', 'District of Columbia']]
# GENERATED: [['Starr', 'Work_For', 'Supreme Court'], ['Robert Bork', 'Work_For', 'District of Columbia circuit']]
# FALSE NEGATIVE: ['Senate', 'OrgBased_In', 'District of Columbia']
# -----------------------------------------------
# The program , financed with a grant from the United States Agency for International Development , is aimed at reducing infant mortality in Madagascar , an island nation in the Indian Ocean off the eastern coast of Africa.
#
# TRUE (SET):  [['Madagascar', 'Located_In', 'Indian Ocean']]
# GENERATED: [['Madanic', 'Located_In', 'Indian Ocean']]
# FALSE NEGATIVE: ['Madagascar', 'Located_In', 'Indian Ocean']
# -----------------------------------------------
# Minox has not shown a profit since 1981 , and on April 1 , 1988 , Robert C. Corduwener , a Netherlands businessman bought a 51 percent share of the company to take control from the Rinn family .
#
# TRUE (SET):  [['Robert C. Corduwener', 'Live_In', 'Netherlands']]
# GENERATED: [['Robert C. Corduwener', 'Live_In', 'Norway']]
# FALSE NEGATIVE: ['Robert C. Corduwener', 'Live_In', 'Netherlands']
# -----------------------------------------------
# ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
#
# TRUE (SET):  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# GENERATED: [['XINHUA', 'OrgBased_In', 'Ulanbaatar'], ['XINHUA', 'OrgBased_In', 'Mongolian']]
# FALSE NEGATIVE: ['XINHUA', 'OrgBased_In', 'China']
# -----------------------------------------------
# ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
#
# TRUE (SET):  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# GENERATED: [['XINHUA', 'OrgBased_In', 'Ulanbaatar'], ['XINHUA', 'OrgBased_In', 'Mongolian']]
# FALSE NEGATIVE: ['XINHUA', 'OrgBased_In', "People 's Republic of China"]
# -----------------------------------------------
# ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
#
# TRUE (SET):  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# GENERATED: [['XINHUA', 'OrgBased_In', 'Ulanbaatar'], ['XINHUA', 'OrgBased_In', 'Mongolian']]
# FALSE NEGATIVE: ['Li Peng', 'Live_In', 'China']
# -----------------------------------------------
# ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
#
# TRUE (SET):  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# GENERATED: [['XINHUA', 'OrgBased_In', 'Ulanbaatar'], ['XINHUA', 'OrgBased_In', 'Mongolian']]
# FALSE NEGATIVE: ['Li Peng', 'Live_In', "People 's Republic of China"]
# -----------------------------------------------
# In 1874 , Herbert Clark Hoover , the 31st president of the United States , was born in West Branch , Iowa .
#
# TRUE (SET):  [['Herbert Clark Hoover', 'Live_In', 'West Branch , Iowa']]
# GENERATED: [['Herbert Clark Hoover', 'Live_In', 'West Branch, Iowa']]
# FALSE NEGATIVE: ['Herbert Clark Hoover', 'Live_In', 'West Branch , Iowa']
# -----------------------------------------------
# ( Text ) The Rwandan Patriotic Front ( RPF ) has rescued 2 , 000 people in Bugesera in the southeastern part of Rwanda .
#
# TRUE (SET):  [['Bugesera', 'Located_In', 'Rwanda']]
# GENERATED: [['Bugesera', 'Located_In', 'Ruand']]
# FALSE NEGATIVE: ['Bugesera', 'Located_In', 'Rwanda']
# -----------------------------------------------
# One of Warner 's lawyers , Andrew Hall of Miami , Fla. , confirmed Tuesday that Warner is trying to settle the case.
#
# TRUE (SET):  [['Andrew Hall', 'Live_In', 'Miami'], ['Andrew Hall', 'Live_In', 'Fla.'], ['Miami', 'Located_In', 'Fla.']]
# GENERATED: [['Andrew Hall', 'Live_In', 'Miami'], ['Andrew Hall', 'Live_In', 'Fla.']]
# FALSE NEGATIVE: ['Miami', 'Located_In', 'Fla.']
# -----------------------------------------------
# GRAND RAPIDS , Mich .
#
# TRUE (SET):  [['GRAND RAPIDS', 'Located_In', 'Mich .']]
# GENERATED: [['GRAND RAPIDS', 'Located_In', 'Mich.']]
# FALSE NEGATIVE: ['GRAND RAPIDS', 'Located_In', 'Mich .']
# -----------------------------------------------
# Joseph Cicippio , 58 , was acting comptroller at the American University of Beirut when he was kidnapped from the campus Sept. 12 , 1986.
#
# TRUE (SET):  [['Joseph Cicippio', 'Work_For', 'American University of Beirut']]
# GENERATED: [['Joe Cicippio', 'Work_For', 'American University']]
# FALSE NEGATIVE: ['Joseph Cicippio', 'Work_For', 'American University of Beirut']
# -----------------------------------------------
# The FA-18 Hornet was on a mission to Pinecastle Electronic Warfare Range in the Ocala National Forest when the bomb tumbled free at 1 : 50 p.m .
#
# TRUE (SET):  [['Pinecastle Electronic Warfare Range', 'Located_In', 'Ocala National Forest']]
# GENERATED: [['Pinnacle Electronic Warfare Range', 'Located_In', 'Ocala National Forest']]
# FALSE NEGATIVE: ['Pinecastle Electronic Warfare Range', 'Located_In', 'Ocala National Forest']
# -----------------------------------------------
# Born in Athens , Psacharopoulos came to the United States at age 17 to enter Oberlin College , where he studied art history .
#
# TRUE (SET):  [['Oberlin College', 'OrgBased_In', 'United States']]
# GENERATED: [['Psacharopoulos', 'Live_In', 'Athens']]
# FALSE NEGATIVE: ['Oberlin College', 'OrgBased_In', 'United States']
# -----------------------------------------------
# Two days later , Perry operated on Kennedy 's assassin , Lee Harvey Oswald , who had just been shot by Jack Ruby .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy'], ['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# GENERATED: [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# FALSE NEGATIVE: ['Jack Ruby', 'Kill', 'Lee Harvey Oswald']
# -----------------------------------------------
# The movie 's script remains a secret , but Stone has said Kevin Costner will star as New Orleans prosecutor Jim Garrison , who said that Kennedy was the victim of an FBI and CIA conspiracy and that Lee Harvey Oswald , identified by a presidential commission as the lone assassin , was set up to take the blame. ;
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# GENERATED: [['Kenneth Costner', 'Kill', 'Kenneth Kennedy']]
# FALSE NEGATIVE: ['Lee Harvey Oswald', 'Kill', 'Kennedy']
# -----------------------------------------------
# Becton Dickinson sells needle containers to doctors and hospitals but may develop a container for home use , said Linda Schmitt , an assistant product manager.
#
# TRUE (SET):  [['Linda Schmitt', 'Work_For', 'Becton Dickinson']]
# GENERATED: [['Becton Dickinson', 'Work_For', 'Doctors'], ['Linda Schmitt', 'Work_For', 'Assist Product Manager']]
# FALSE NEGATIVE: ['Linda Schmitt', 'Work_For', 'Becton Dickinson']
# -----------------------------------------------
# The police files on Kennedy 's shooting could shed new light on persistent questions about whether Sirhan Bishara Sirhan was the only gunman in the shooting .
#
# TRUE (SET):  [['Sirhan Bishara Sirhan', 'Kill', 'Kennedy']]
# GENERATED: [['Serhan Bishara Sirhan', 'Kill', 'Kennedy']]
# FALSE NEGATIVE: ['Sirhan Bishara Sirhan', 'Kill', 'Kennedy']
# -----------------------------------------------
# In 1936 , rock legend Buddy Holly was born Charles Hardin Holley in Lubbock , Texas .
#
# TRUE (SET):  [['Buddy Holly', 'Live_In', 'Lubbock , Texas'], ['Charles Hardin Holley', 'Live_In', 'Lubbock , Texas']]
# GENERATED: [['Buddy Holly', 'Live_In', 'Lucbock, Texas']]
# FALSE NEGATIVE: ['Buddy Holly', 'Live_In', 'Lubbock , Texas']
# -----------------------------------------------
# In 1936 , rock legend Buddy Holly was born Charles Hardin Holley in Lubbock , Texas .
#
# TRUE (SET):  [['Buddy Holly', 'Live_In', 'Lubbock , Texas'], ['Charles Hardin Holley', 'Live_In', 'Lubbock , Texas']]
# GENERATED: [['Buddy Holly', 'Live_In', 'Lucbock, Texas']]
# FALSE NEGATIVE: ['Charles Hardin Holley', 'Live_In', 'Lubbock , Texas']
# -----------------------------------------------
# Belli 's clients have included Jack Ruby , who killed John F. Kennedy assassin Lee Harvey Oswald , and Jim and Tammy Bakker .
#
# TRUE (SET):  [['Jack Ruby', 'Kill', 'Lee Harvey Oswald'], ['Lee Harvey Oswald', 'Kill', 'John F. Kennedy']]
# GENERATED: [['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# FALSE NEGATIVE: ['Lee Harvey Oswald', 'Kill', 'John F. Kennedy']
# -----------------------------------------------
# Bosnia 's capital , Sarajevo , is best-known as the site of the assassination in 1914 of Austrian Archduke Franz Ferdinand by young Bosnian nationalist Gavrilo Princip , which was the spark that ignited World War I. No single party appeared likely to win a clear majority in Bosnia 's 240-seat bicameral parliament .
#
# TRUE (SET):  [['Sarajevo', 'Located_In', 'Bosnia'], ['Gavrilo Princip', 'Kill', 'Austrian Archduke Franz Ferdinand']]
# GENERATED: [['Gavrilo Princip', 'Kill', 'Austrian Archduke Franz Ferdinand']]
# FALSE NEGATIVE: ['Sarajevo', 'Located_In', 'Bosnia']
# -----------------------------------------------
# Walesa said Solidarity wants to avoid unrest .
#
# TRUE (SET):  [['Walesa', 'Work_For', 'Solidarity']]
# GENERATED: [['So Solidarity', 'OrgBased_In', 'Wales']]
# FALSE NEGATIVE: ['Walesa', 'Work_For', 'Solidarity']
# -----------------------------------------------
# In 1817 , naturalist-author Henry David Thoreau was born in Concord , Mass .
#
# TRUE (SET):  [['Henry David Thoreau', 'Live_In', 'Concord , Mass']]
# GENERATED: [['Henry David Thoreau', 'Live_In', 'Concordia, Mass']]
# FALSE NEGATIVE: ['Henry David Thoreau', 'Live_In', 'Concord , Mass']
# -----------------------------------------------
# It almost makes me want to laugh. ( Minoli ) Why ? ( Fini ) Bossi is a very strange character and his extreme envy has been demonstrated. ( passage omitted ) He tried to get votes from the south , those votes which he now despises so much , but the south sent him back to the valleys. ( Minoli ) You said that Bossi reminded you of Hitler trapped in his Berlin bunker , a man with delusions of grandeur and a tendency towards suicide .
#
# TRUE (SET):  [['Hitler', 'Live_In', 'Berlin']]
# GENERATED: [['Bossi', 'Live_In', 'Berlin']]
# FALSE NEGATIVE: ['Hitler', 'Live_In', 'Berlin']
# -----------------------------------------------
# ` ` One thing I have learned over the past 17 months is that the truth is hard to find , and it remains so , ' ' said Mrs. Higgins , 37 , who is a major inthe Marine Corps and works at the Pentagon as a public information officer.
#
# TRUE (SET):  [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Pentagon']]
# GENERATED: [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Potentially'], ['Mrs. Higgins', 'Work_For', 'Potentially'], ['Mrs. Higgins', 'Work_For', 'Potentially'], ['Mrs. Higgins', 'Work_For', 'Potentially'], ['Potentially', 'Work_For', 'Potentially']]
# FALSE NEGATIVE: ['Mrs. Higgins', 'Work_For', 'Pentagon']
# -----------------------------------------------
# Some people in the United States are saying that Clinton " gave away " $12 billion to Russia -- this is the amount it is proposed to pay for uranium destined for U.S. nuclear electric power stations , which will be obtained from our nuclear warheads .
#
# TRUE (SET):  [['Clinton', 'Live_In', 'United States'], ['Clinton', 'Live_In', 'U.S.']]
# GENERATED: [['Clinton', 'Live_In', 'United States']]
# FALSE NEGATIVE: ['Clinton', 'Live_In', 'U.S.']
# -----------------------------------------------
# A golden future seemed assured when , at 25 , Ogdon shared top place with Soviet pianist Vladimir Ashkenazy in the piano section of the 1962 Moscow Tchaikovsky International Competition for young musicians.
#
# TRUE (SET):  [['Vladimir Ashkenazy', 'Live_In', 'Soviet']]
# GENERATED: [['Tchaikovsky International Competition', 'OrgBased_In', 'Moscow'], ['Tchaikovsky International Competition', 'OrgBased_In', 'Moscow'], ['Tchaikovsky International Competition', 'OrgBased_In', 'Moscow']]
# FALSE NEGATIVE: ['Vladimir Ashkenazy', 'Live_In', 'Soviet']
# -----------------------------------------------
# 1911 , playwright Tennessee Williams was born in Columbus , Miss.
#
# TRUE (SET):  [['Tennessee Williams', 'Live_In', 'Columbus , Miss.']]
# GENERATED: [['Tennessee Williams', 'Live_In', 'Columbus, Miss.']]
# FALSE NEGATIVE: ['Tennessee Williams', 'Live_In', 'Columbus , Miss.']
# -----------------------------------------------
# BRISBANE , Australia ( AP )
#
# TRUE (SET):  [['BRISBANE', 'Located_In', 'Australia'], ['AP', 'OrgBased_In', 'BRISBANE'], ['AP', 'OrgBased_In', 'Australia']]
# GENERATED: [['BRISANBRIE', 'Located_In', 'Australia'], ['AP', 'OrgBased_In', 'BRISANBRIE'], ['AP', 'OrgBased_In', 'Australia']]
# FALSE NEGATIVE: ['BRISBANE', 'Located_In', 'Australia']
# -----------------------------------------------
# BRISBANE , Australia ( AP )
#
# TRUE (SET):  [['BRISBANE', 'Located_In', 'Australia'], ['AP', 'OrgBased_In', 'BRISBANE'], ['AP', 'OrgBased_In', 'Australia']]
# GENERATED: [['BRISANBRIE', 'Located_In', 'Australia'], ['AP', 'OrgBased_In', 'BRISANBRIE'], ['AP', 'OrgBased_In', 'Australia']]
# FALSE NEGATIVE: ['AP', 'OrgBased_In', 'BRISBANE']
# -----------------------------------------------
# Photographer , author , filmmaker and composer Gordon Parks , 76 , born in Fort Scott , Kan. , who was on the photographic staff of Life Magazine for 19 years before branching out into other activities.
#
# TRUE (SET):  [['Gordon Parks', 'Live_In', 'Fort Scott , Kan.']]
# GENERATED: [['G Gordon Parks', 'Live_In', 'Fort Scott, Kan.']]
# FALSE NEGATIVE: ['Gordon Parks', 'Live_In', 'Fort Scott , Kan.']
# -----------------------------------------------
# In 1830 , poet Emily Dickinson was born in Amherst , Mass.
#
# TRUE (SET):  [['Emily Dickinson', 'Live_In', 'Amherst , Mass.']]
# GENERATED: [['Emily Dickinson', 'Live_In', 'Amherst, Mass.']]
# FALSE NEGATIVE: ['Emily Dickinson', 'Live_In', 'Amherst , Mass.']
# -----------------------------------------------
# Nihat ( Marka ) , deputy leader of SHP ( Social Democrat Populist Party ) parliamentary group , said : They should have run in the elections for the sake of democracy .
#
# TRUE (SET):  [['Nihat', 'Work_For', 'SHP'], ['Nihat', 'Work_For', 'Social Democrat Populist Party'], ['Marka', 'Work_For', 'SHP'], ['Marka', 'Work_For', 'Social Democrat Populist Party']]
# GENERATED: [['Nihat', 'Work_For', 'SHP'], ['Marka', 'Work_For', 'SHP'], ['Nihat', 'Work_For', 'Social Democrat Populist Party']]
# FALSE NEGATIVE: ['Marka', 'Work_For', 'Social Democrat Populist Party']
# -----------------------------------------------
# A statement from military headquarters said the aircraft crashed during a 260-mile flight to Khartoum from Kassala in eastern Sudan near the Ethiopian border.
#
# TRUE (SET):  [['Kassala', 'Located_In', 'Sudan']]
# GENERATED: [['Kansala', 'Located_In', 'Sudan']]
# FALSE NEGATIVE: ['Kassala', 'Located_In', 'Sudan']
# -----------------------------------------------
# Harrington , a professor of political science at Queens College of the City University of New York and honorary president of the Socialist International , died Monday night at his home in suburban Larchmont , the university said in a statement Tuesday.
#
# TRUE (SET):  [['Harrington', 'Work_For', 'Queens College'], ['Harrington', 'Work_For', 'City University of New York'], ['Harrington', 'Work_For', 'Socialist International'], ['Harrington', 'Live_In', 'Larchmont']]
# GENERATED: [['Harrington', 'Work_For', 'Queens College'], ['Harrington', 'Work_For', 'City University of New York'], ['Harrington', 'Work_For', 'Socialist International']]
# FALSE NEGATIVE: ['Harrington', 'Live_In', 'Larchmont']
# -----------------------------------------------
# Norton Winfred Simon was born on Feb. 5 , 1907 , in Portland , Ore. , and spent his teen-age years in San Francisco .
#
# TRUE (SET):  [['Norton Winfred Simon', 'Live_In', 'Portland , Ore.']]
# GENERATED: [['Montgomery', 'Located_In', 'Portland, Ore.'], ['Montgomery', 'Live_In', 'Portland, Ore.']]
# FALSE NEGATIVE: ['Norton Winfred Simon', 'Live_In', 'Portland , Ore.']
# -----------------------------------------------
# The National Aeronautics and Space Administration announced Thursday that Ulf D. Merbold , 47 , of the European Space Agency and Roger K. Crouch of NASA have been chosen to train to perform materials sciences experiments on the International Microgravity Laboratory-1 mission scheduled for April 1991 .
#
# TRUE (SET):  [['Ulf D. Merbold', 'Work_For', 'European Space Agency'], ['Roger K. Crouch', 'Work_For', 'National Aeronautics and Space Administration'], ['Roger K. Crouch', 'Work_For', 'NASA']]
# GENERATED: [['Ulf D. Merbold', 'Work_For', 'European Space Agency'], ['Roger K. Crouch', 'Work_For', 'NASA']]
# FALSE NEGATIVE: ['Roger K. Crouch', 'Work_For', 'National Aeronautics and Space Administration']
# -----------------------------------------------
# This Latin American group 's reaction came two days after the military leaders of Haiti made Emile Jonassaint provisional president of Haiti , following the Haitian Parliament 's declaration that the post was vacant .
#
# TRUE (SET):  [['Emile Jonassaint', 'Live_In', 'Haiti'], ['Emile Jonassaint', 'Live_In', 'Haiti'], ['Haitian Parliament', 'OrgBased_In', 'Haiti'], ['Haitian Parliament', 'OrgBased_In', 'Haiti']]
# GENERATED: [['Emmel Jonassaint', 'Live_In', 'Haiti']]
# FALSE NEGATIVE: ['Emile Jonassaint', 'Live_In', 'Haiti']
# -----------------------------------------------
# This Latin American group 's reaction came two days after the military leaders of Haiti made Emile Jonassaint provisional president of Haiti , following the Haitian Parliament 's declaration that the post was vacant .
#
# TRUE (SET):  [['Emile Jonassaint', 'Live_In', 'Haiti'], ['Emile Jonassaint', 'Live_In', 'Haiti'], ['Haitian Parliament', 'OrgBased_In', 'Haiti'], ['Haitian Parliament', 'OrgBased_In', 'Haiti']]
# GENERATED: [['Emmel Jonassaint', 'Live_In', 'Haiti']]
# FALSE NEGATIVE: ['Emile Jonassaint', 'Live_In', 'Haiti']
# -----------------------------------------------
# This Latin American group 's reaction came two days after the military leaders of Haiti made Emile Jonassaint provisional president of Haiti , following the Haitian Parliament 's declaration that the post was vacant .
#
# TRUE (SET):  [['Emile Jonassaint', 'Live_In', 'Haiti'], ['Emile Jonassaint', 'Live_In', 'Haiti'], ['Haitian Parliament', 'OrgBased_In', 'Haiti'], ['Haitian Parliament', 'OrgBased_In', 'Haiti']]
# GENERATED: [['Emmel Jonassaint', 'Live_In', 'Haiti']]
# FALSE NEGATIVE: ['Haitian Parliament', 'OrgBased_In', 'Haiti']
# -----------------------------------------------
# This Latin American group 's reaction came two days after the military leaders of Haiti made Emile Jonassaint provisional president of Haiti , following the Haitian Parliament 's declaration that the post was vacant .
#
# TRUE (SET):  [['Emile Jonassaint', 'Live_In', 'Haiti'], ['Emile Jonassaint', 'Live_In', 'Haiti'], ['Haitian Parliament', 'OrgBased_In', 'Haiti'], ['Haitian Parliament', 'OrgBased_In', 'Haiti']]
# GENERATED: [['Emmel Jonassaint', 'Live_In', 'Haiti']]
# FALSE NEGATIVE: ['Haitian Parliament', 'OrgBased_In', 'Haiti']
# -----------------------------------------------
# Yahia Bouguettaya , the former mayor of Mohammadia , south-east Algeria , and Mohamed Touali , an activist in Algeria 's Ettahadi ( Challenge ) political party , were assassinated Wednesday .
#
# TRUE (SET):  [['Mohammadia', 'Located_In', 'Algeria'], ['Mohamed Touali', 'Work_For', 'Ettahadi ( Challenge ) political party'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria']]
# GENERATED: [['Yahia Bouguettaya', 'Live_In', 'Mohammadia'], ['Mohamed Touali', 'Work_For', 'Ettahadi (Challenge)'], ['Ettahadi (Challenge)', 'OrgBased_In', 'Algeria']]
# FALSE NEGATIVE: ['Mohammadia', 'Located_In', 'Algeria']
# -----------------------------------------------
# Yahia Bouguettaya , the former mayor of Mohammadia , south-east Algeria , and Mohamed Touali , an activist in Algeria 's Ettahadi ( Challenge ) political party , were assassinated Wednesday .
#
# TRUE (SET):  [['Mohammadia', 'Located_In', 'Algeria'], ['Mohamed Touali', 'Work_For', 'Ettahadi ( Challenge ) political party'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria']]
# GENERATED: [['Yahia Bouguettaya', 'Live_In', 'Mohammadia'], ['Mohamed Touali', 'Work_For', 'Ettahadi (Challenge)'], ['Ettahadi (Challenge)', 'OrgBased_In', 'Algeria']]
# FALSE NEGATIVE: ['Mohamed Touali', 'Work_For', 'Ettahadi ( Challenge ) political party']
# -----------------------------------------------
# Yahia Bouguettaya , the former mayor of Mohammadia , south-east Algeria , and Mohamed Touali , an activist in Algeria 's Ettahadi ( Challenge ) political party , were assassinated Wednesday .
#
# TRUE (SET):  [['Mohammadia', 'Located_In', 'Algeria'], ['Mohamed Touali', 'Work_For', 'Ettahadi ( Challenge ) political party'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria']]
# GENERATED: [['Yahia Bouguettaya', 'Live_In', 'Mohammadia'], ['Mohamed Touali', 'Work_For', 'Ettahadi (Challenge)'], ['Ettahadi (Challenge)', 'OrgBased_In', 'Algeria']]
# FALSE NEGATIVE: ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria']
# -----------------------------------------------
# Yahia Bouguettaya , the former mayor of Mohammadia , south-east Algeria , and Mohamed Touali , an activist in Algeria 's Ettahadi ( Challenge ) political party , were assassinated Wednesday .
#
# TRUE (SET):  [['Mohammadia', 'Located_In', 'Algeria'], ['Mohamed Touali', 'Work_For', 'Ettahadi ( Challenge ) political party'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria'], ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria']]
# GENERATED: [['Yahia Bouguettaya', 'Live_In', 'Mohammadia'], ['Mohamed Touali', 'Work_For', 'Ettahadi (Challenge)'], ['Ettahadi (Challenge)', 'OrgBased_In', 'Algeria']]
# FALSE NEGATIVE: ['Ettahadi ( Challenge ) political party', 'OrgBased_In', 'Algeria']
# -----------------------------------------------
# The PRAVDA newspaper carries an interview with Radovan Karadzic , leader of Bosnian Serbs and vice-president of the Union of Serb Writers .
#
# TRUE (SET):  [['Radovan Karadzic', 'Work_For', 'Union of Serb Writers']]
# GENERATED: [['Radovan Karadzic', 'Live_In', 'Bosnia and Herzegovina'], ['Radovan Karadzic', 'Work_For', 'Union of Serbian Writers']]
# FALSE NEGATIVE: ['Radovan Karadzic', 'Work_For', 'Union of Serb Writers']
# -----------------------------------------------
# ...
#
# TRUE (SET):  [['Mile Akmadzic', 'Live_In', 'Croatian Republic of Herceg-Bosna'], ['Nikola Koljevic', 'Live_In', 'Serbian Republic']]
# GENERATED: [['Mile Akmadzic', 'Work_For', 'Croatian Republic of Herceg-Bosna'], ['Nikokoljevic', 'Work_For', 'Serbian Republic']]
# FALSE NEGATIVE: ['Mile Akmadzic', 'Live_In', 'Croatian Republic of Herceg-Bosna']
# -----------------------------------------------
# Such theories , which are not alone in the international press , find support in another agreement that was also signed in Geneva -- which the Croatian opposition ostensibly did not notice , to the great surprise and almost astonishment of all , and consequently did not comment on , although the integral text was published in Croatian newspapers -- the agreement signed between Mile Akmadzic , on behalf of the Croatian Republic of Herceg-Bosna , and Nikola Koljevic , on behalf of the Serbian Republic , in which both sides emphasize that " there are no disputed issues between them that cannot be solved in a peaceful way . "
#
# TRUE (SET):  [['Mile Akmadzic', 'Live_In', 'Croatian Republic of Herceg-Bosna'], ['Nikola Koljevic', 'Live_In', 'Serbian Republic']]
# GENERATED: [['Mile Akmadzic', 'Work_For', 'Croatian Republic of Herceg-Bosna'], ['Nikokoljevic', 'Work_For', 'Serbian Republic']]
# FALSE NEGATIVE: ['Nikola Koljevic', 'Live_In', 'Serbian Republic']
# -----------------------------------------------
# In 1890 , the 34th President of the United States , Dwight D. Eisenhower , was born in Denison , Texas .
#
# TRUE (SET):  [['Dwight D. Eisenhower', 'Live_In', 'Denison , Texas']]
# GENERATED: [['Dwight D. Eisenhower', 'Live_In', 'Denison, Texas']]
# FALSE NEGATIVE: ['Dwight D. Eisenhower', 'Live_In', 'Denison , Texas']
# -----------------------------------------------
# The federal appeals court threw out the death sentence of John Harvey Adamson , convicted of murdering Phoenix newspaper reporter Don Bolles in 1976 .
#
# TRUE (SET):  [['John Harvey Adamson', 'Kill', 'Don Bolles']]
# GENERATED: [['John Harvey Adamson', 'Kill', 'Phoenix newspaper reporter']]
# FALSE NEGATIVE: ['John Harvey Adamson', 'Kill', 'Don Bolles']
# -----------------------------------------------
# The trud newspaper features the last part of the memoirs by former commander of the Soviet Navy Nikolai Kuznetsov who personally knew Stalin , under the headline " Stalin 's Death . "
#
# TRUE (SET):  [['Navy', 'OrgBased_In', 'Soviet'], ['Nikolai Kuznetsov', 'Live_In', 'Soviet'], ['Nikolai Kuznetsov', 'Work_For', 'Navy'], ['Stalin', 'Live_In', 'Soviet'], ['Stalin', 'Live_In', 'Soviet']]
# GENERATED: [['Nikolai Kuznetsov', 'Work_For', 'Soviet Navy']]
# FALSE NEGATIVE: ['Navy', 'OrgBased_In', 'Soviet']
# -----------------------------------------------
# The trud newspaper features the last part of the memoirs by former commander of the Soviet Navy Nikolai Kuznetsov who personally knew Stalin , under the headline " Stalin 's Death . "
#
# TRUE (SET):  [['Navy', 'OrgBased_In', 'Soviet'], ['Nikolai Kuznetsov', 'Live_In', 'Soviet'], ['Nikolai Kuznetsov', 'Work_For', 'Navy'], ['Stalin', 'Live_In', 'Soviet'], ['Stalin', 'Live_In', 'Soviet']]
# GENERATED: [['Nikolai Kuznetsov', 'Work_For', 'Soviet Navy']]
# FALSE NEGATIVE: ['Nikolai Kuznetsov', 'Live_In', 'Soviet']
# -----------------------------------------------
# The trud newspaper features the last part of the memoirs by former commander of the Soviet Navy Nikolai Kuznetsov who personally knew Stalin , under the headline " Stalin 's Death . "
#
# TRUE (SET):  [['Navy', 'OrgBased_In', 'Soviet'], ['Nikolai Kuznetsov', 'Live_In', 'Soviet'], ['Nikolai Kuznetsov', 'Work_For', 'Navy'], ['Stalin', 'Live_In', 'Soviet'], ['Stalin', 'Live_In', 'Soviet']]
# GENERATED: [['Nikolai Kuznetsov', 'Work_For', 'Soviet Navy']]
# FALSE NEGATIVE: ['Stalin', 'Live_In', 'Soviet']
# -----------------------------------------------
# The trud newspaper features the last part of the memoirs by former commander of the Soviet Navy Nikolai Kuznetsov who personally knew Stalin , under the headline " Stalin 's Death . "
#
# TRUE (SET):  [['Navy', 'OrgBased_In', 'Soviet'], ['Nikolai Kuznetsov', 'Live_In', 'Soviet'], ['Nikolai Kuznetsov', 'Work_For', 'Navy'], ['Stalin', 'Live_In', 'Soviet'], ['Stalin', 'Live_In', 'Soviet']]
# GENERATED: [['Nikolai Kuznetsov', 'Work_For', 'Soviet Navy']]
# FALSE NEGATIVE: ['Stalin', 'Live_In', 'Soviet']
# -----------------------------------------------
# ( Text ) Taipei , Jan. 20 ( CNA ) -- Foreign Chien Fu will leave for the United States on January 29 to give two speeches in the Boston area .
#
# TRUE (SET):  [['Chien Fu', 'Live_In', 'Taipei']]
# GENERATED: [['CNA', 'OrgBased_In', 'Taipei'], ['Chen Fu', 'Live_In', 'Taipei'], ['Chen Fu', 'Live_In', 'United States']]
# FALSE NEGATIVE: ['Chien Fu', 'Live_In', 'Taipei']
# -----------------------------------------------
# On this date : In 1843 , the 25th President of the United States , William McKinley , was born in Niles , Ohio .
#
# TRUE (SET):  [['William McKinley', 'Live_In', 'Niles , Ohio']]
# GENERATED: [['William McKinley', 'Live_In', 'Niles, Ohio']]
# FALSE NEGATIVE: ['William McKinley', 'Live_In', 'Niles , Ohio']
# -----------------------------------------------
# In 1874 , Herbert Clark Hoover , the 31st president of the United States , was born in West Branch , Iowa .
#
# TRUE (SET):  [['Herbert Clark Hoover', 'Live_In', 'West Branch , Iowa']]
# GENERATED: [['Herbert Clark Hoover', 'Live_In', 'West Branch, Iowa']]
# FALSE NEGATIVE: ['Herbert Clark Hoover', 'Live_In', 'West Branch , Iowa']
# -----------------------------------------------
# KARBALA , Iraq ( AP )
#
# TRUE (SET):  [['KARBALA', 'Located_In', 'Iraq'], ['AP', 'OrgBased_In', 'KARBALA'], ['AP', 'OrgBased_In', 'Iraq']]
# GENERATED: [['AP', 'OrgBased_In', 'KARBALA'], ['AP', 'OrgBased_In', 'Iraq']]
# FALSE NEGATIVE: ['KARBALA', 'Located_In', 'Iraq']
# -----------------------------------------------
# Another beacon of the better life is Prateep Ungsongtham , known as the ` ` Slum Angel of Bangkok. ' '
#
# TRUE (SET):  [['Prateep Ungsongtham', 'Live_In', 'Bangkok.']]
# GENERATED: [['Prateeep Ungsongtham', 'Live_In', 'Bangkok']]
# FALSE NEGATIVE: ['Prateep Ungsongtham', 'Live_In', 'Bangkok.']
# -----------------------------------------------
# Michael Henley Jr. , 10 , disappeared on a turkey hunt with his father in April 1988 in the mountains near their hometown of Grants , N.M. Ms. Calico , then 19 , disappeared five months later while bicycling on a country road near her hometown of Belen , N.M.
#
# TRUE (SET):  [['Michael Henley Jr.', 'Live_In', 'Grants'], ['Michael Henley Jr.', 'Live_In', 'N.M.'], ['Grants', 'Located_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'Belen'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Belen', 'Located_In', 'N.M.']]
# GENERATED: [['Ms. Calico', 'Live_In', 'Belen'], ['Michael Henley Jr.', 'Live_In', 'Grants'], ['Ms. Calico', 'Live_In', 'N.M.']]
# FALSE NEGATIVE: ['Michael Henley Jr.', 'Live_In', 'N.M.']
# -----------------------------------------------
# Michael Henley Jr. , 10 , disappeared on a turkey hunt with his father in April 1988 in the mountains near their hometown of Grants , N.M. Ms. Calico , then 19 , disappeared five months later while bicycling on a country road near her hometown of Belen , N.M.
#
# TRUE (SET):  [['Michael Henley Jr.', 'Live_In', 'Grants'], ['Michael Henley Jr.', 'Live_In', 'N.M.'], ['Grants', 'Located_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'Belen'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Belen', 'Located_In', 'N.M.']]
# GENERATED: [['Ms. Calico', 'Live_In', 'Belen'], ['Michael Henley Jr.', 'Live_In', 'Grants'], ['Ms. Calico', 'Live_In', 'N.M.']]
# FALSE NEGATIVE: ['Grants', 'Located_In', 'N.M.']
# -----------------------------------------------
# Michael Henley Jr. , 10 , disappeared on a turkey hunt with his father in April 1988 in the mountains near their hometown of Grants , N.M. Ms. Calico , then 19 , disappeared five months later while bicycling on a country road near her hometown of Belen , N.M.
#
# TRUE (SET):  [['Michael Henley Jr.', 'Live_In', 'Grants'], ['Michael Henley Jr.', 'Live_In', 'N.M.'], ['Grants', 'Located_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'Belen'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Belen', 'Located_In', 'N.M.']]
# GENERATED: [['Ms. Calico', 'Live_In', 'Belen'], ['Michael Henley Jr.', 'Live_In', 'Grants'], ['Ms. Calico', 'Live_In', 'N.M.']]
# FALSE NEGATIVE: ['Belen', 'Located_In', 'N.M.']
# -----------------------------------------------
# Police arrested 10 Spanish Basque militants , including Jose Antonio Urutigoechea , considered by Madrid to be a top leader of the Spanish Basque separatist organization ETA , authorities said today .
#
# TRUE (SET):  [['Jose Antonio Urutigoechea', 'Work_For', 'ETA']]
# GENERATED: [['Joaquin Antonio Urutigoechea', 'Work_For', 'ETA']]
# FALSE NEGATIVE: ['Jose Antonio Urutigoechea', 'Work_For', 'ETA']
# -----------------------------------------------
# Meanwhile , the historical society in Beaumont , Texas , Richardson 's hometown , plans to raise two statues on Feb. 3 _ one of Buddy Holly , Richardson and Valens , and a second of the Big Bopper alone .
#
# TRUE (SET):  [['Richardson', 'Live_In', 'Beaumont , Texas']]
# GENERATED: [['Bearut', 'Located_In', 'Texas']]
# FALSE NEGATIVE: ['Richardson', 'Live_In', 'Beaumont , Texas']
# -----------------------------------------------
# At a briefing at NRC headquarters in nearby Rockville , Md. , Bernero said the volcanic cones in the area of Yucca Mountain have been a cause of concern for NRC experts.
#
# TRUE (SET):  [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.'], ['Bernero', 'Work_For', 'NRC'], ['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.']]
# GENERATED: [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.']]
# FALSE NEGATIVE: ['Bernero', 'Work_For', 'NRC']
# -----------------------------------------------
# ( Text ) Saint-Gall , Switzerland , Feb 2 ( AFP ) -- The wreck of a twin-engine aircraft has been found 160 metres below the surface of Lake Constance , Swiss police said Tuesday ( 1 February ) .
#
# TRUE (SET):  [['Saint-Gall', 'Located_In', 'Switzerland'], ['AFP', 'OrgBased_In', 'Saint-Gall'], ['AFP', 'OrgBased_In', 'Switzerland']]
# GENERATED: [['Stan-Gall', 'Located_In', 'Switzerland']]
# FALSE NEGATIVE: ['Saint-Gall', 'Located_In', 'Switzerland']
# -----------------------------------------------
# ( Text ) Saint-Gall , Switzerland , Feb 2 ( AFP ) -- The wreck of a twin-engine aircraft has been found 160 metres below the surface of Lake Constance , Swiss police said Tuesday ( 1 February ) .
#
# TRUE (SET):  [['Saint-Gall', 'Located_In', 'Switzerland'], ['AFP', 'OrgBased_In', 'Saint-Gall'], ['AFP', 'OrgBased_In', 'Switzerland']]
# GENERATED: [['Stan-Gall', 'Located_In', 'Switzerland']]
# FALSE NEGATIVE: ['AFP', 'OrgBased_In', 'Saint-Gall']
# -----------------------------------------------
# ( Text ) Saint-Gall , Switzerland , Feb 2 ( AFP ) -- The wreck of a twin-engine aircraft has been found 160 metres below the surface of Lake Constance , Swiss police said Tuesday ( 1 February ) .
#
# TRUE (SET):  [['Saint-Gall', 'Located_In', 'Switzerland'], ['AFP', 'OrgBased_In', 'Saint-Gall'], ['AFP', 'OrgBased_In', 'Switzerland']]
# GENERATED: [['Stan-Gall', 'Located_In', 'Switzerland']]
# FALSE NEGATIVE: ['AFP', 'OrgBased_In', 'Switzerland']
# -----------------------------------------------
# In an " electoral communique " signed by CNTP Secretary Luis Cobos R. , the organization said it hopes that with this decision " we will achieve the return of the Torrijist forces to power to stimulate the process of national liberation . "
#
# TRUE (SET):  [['Luis Cobos R.', 'Work_For', 'CNTP']]
# GENERATED: [['CNTP', 'OrgBased_In', 'Luis Cobos R.']]
# FALSE NEGATIVE: ['Luis Cobos R.', 'Work_For', 'CNTP']
# -----------------------------------------------
# In it , actor Edwin Booth tells us his version of his life story , in which he and not his brother John Wilkes shoots Abraham Lincoln at Ford 's Theater .
#
# TRUE (SET):  [['John Wilkes', 'Kill', 'Abraham Lincoln']]
# GENERATED: [['Edwin Booth', 'Kill', 'Abraham Lincoln']]
# FALSE NEGATIVE: ['John Wilkes', 'Kill', 'Abraham Lincoln']
# -----------------------------------------------
# In 1801 , Mormon leader Brigham Young was born in Whitingham , Vt .
#
# TRUE (SET):  [['Brigham Young', 'Live_In', 'Whitingham , Vt']]
# GENERATED: [['Brigham Young', 'Live_In', 'Whitingham, Vt']]
# FALSE NEGATIVE: ['Brigham Young', 'Live_In', 'Whitingham , Vt']
# -----------------------------------------------
# " I was hearing the same story , " says James Hackett , an executive with Titan Systems and one of the leading missile experts in the U.S .
#
# TRUE (SET):  [['James Hackett', 'Work_For', 'Titan Systems'], ['James Hackett', 'Live_In', 'U.S .']]
# GENERATED: [['James Hackett', 'Work_For', 'Titan Systems']]
# FALSE NEGATIVE: ['James Hackett', 'Live_In', 'U.S .']
# -----------------------------------------------
# They will also be cleaning the car Oswald drove on the day Kennedy was shot and the ambulance that took Oswald to hospital after he was shot by Jack Ruby .
#
# TRUE (SET):  [['Jack Ruby', 'Kill', 'Oswald']]
# GENERATED: [['Oswald', 'Kill', 'Kennedy']]
# FALSE NEGATIVE: ['Jack Ruby', 'Kill', 'Oswald']
# -----------------------------------------------
# Widespread street flooding was reported throughout Brazoria , Fort Bend , Galveston and southern Harris Counties in southeast Texas.
#
# TRUE (SET):  [['Brazoria', 'Located_In', 'Texas.'], ['Fort Bend', 'Located_In', 'Texas.'], ['Galveston', 'Located_In', 'Texas.'], ['Harris Counties', 'Located_In', 'Texas.']]
# GENERATED: [['Brazoria', 'Located_In', 'Fort Bend'], ['Fort Bend', 'Located_In', 'Galveston'], ['Harrisburg', 'Located_In', 'Texas'], ['Harrisburg', 'Located_In', 'Texas']]
# FALSE NEGATIVE: ['Brazoria', 'Located_In', 'Texas.']
# -----------------------------------------------
# Widespread street flooding was reported throughout Brazoria , Fort Bend , Galveston and southern Harris Counties in southeast Texas.
#
# TRUE (SET):  [['Brazoria', 'Located_In', 'Texas.'], ['Fort Bend', 'Located_In', 'Texas.'], ['Galveston', 'Located_In', 'Texas.'], ['Harris Counties', 'Located_In', 'Texas.']]
# GENERATED: [['Brazoria', 'Located_In', 'Fort Bend'], ['Fort Bend', 'Located_In', 'Galveston'], ['Harrisburg', 'Located_In', 'Texas'], ['Harrisburg', 'Located_In', 'Texas']]
# FALSE NEGATIVE: ['Fort Bend', 'Located_In', 'Texas.']
# -----------------------------------------------
# Widespread street flooding was reported throughout Brazoria , Fort Bend , Galveston and southern Harris Counties in southeast Texas.
#
# TRUE (SET):  [['Brazoria', 'Located_In', 'Texas.'], ['Fort Bend', 'Located_In', 'Texas.'], ['Galveston', 'Located_In', 'Texas.'], ['Harris Counties', 'Located_In', 'Texas.']]
# GENERATED: [['Brazoria', 'Located_In', 'Fort Bend'], ['Fort Bend', 'Located_In', 'Galveston'], ['Harrisburg', 'Located_In', 'Texas'], ['Harrisburg', 'Located_In', 'Texas']]
# FALSE NEGATIVE: ['Galveston', 'Located_In', 'Texas.']
# -----------------------------------------------
# Widespread street flooding was reported throughout Brazoria , Fort Bend , Galveston and southern Harris Counties in southeast Texas.
#
# TRUE (SET):  [['Brazoria', 'Located_In', 'Texas.'], ['Fort Bend', 'Located_In', 'Texas.'], ['Galveston', 'Located_In', 'Texas.'], ['Harris Counties', 'Located_In', 'Texas.']]
# GENERATED: [['Brazoria', 'Located_In', 'Fort Bend'], ['Fort Bend', 'Located_In', 'Galveston'], ['Harrisburg', 'Located_In', 'Texas'], ['Harrisburg', 'Located_In', 'Texas']]
# FALSE NEGATIVE: ['Harris Counties', 'Located_In', 'Texas.']
# -----------------------------------------------
# Navy sources said the Coral Sea , on duty with the 6th Fleet in the Mediterranean , left ` ` a few hours ' ' ahead of its scheduled departure.
#
# TRUE (SET):  [['6th Fleet', 'OrgBased_In', 'Mediterranean']]
# GENERATED: [['Coral Sea', 'Located_In', 'Mediterranean']]
# FALSE NEGATIVE: ['6th Fleet', 'OrgBased_In', 'Mediterranean']
# -----------------------------------------------

# %%
print ("FN: ", len(fn))
recall = len(tp) / (len(tp) + len(fn))
print ("RECALL: ", recall)
print ("F1 SCORE: ", 2 * (precision * recall) / (precision + recall))
# Out:
# FN:  136
# RECALL:  0.5964391691394659
# F1 SCORE:  0.6081694402420574
