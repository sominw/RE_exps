# %%
import numpy as np
import pandas as pd
import logging
import os
import json
import glob
import regex as re
import torch
import argparse
import random
import itertools
import ast
import sys
import ast
from tqdm import tqdm
import warnings

from sklearn.model_selection import train_test_split
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from transformers import pipeline
from datasets import load_dataset, get_dataset_split_names

warnings.filterwarnings("ignore")

# %%
res = pd.read_csv("conll_flan_fewshot_results.csv")
res.shape
# Out:
# (231, 2)

# %%
res.head()
# Out:
#                                                input  \
# 0  TEXT: John Wilkes Booth , who assassinated Pre...
# 1  TEXT: The opera company performed at the Palac...
# 2  TEXT: In the field of mechanics , Wang Ziqiang...
# 3  TEXT: Sun Hung Kai Properties , a Hong Kong co...
# 4  TEXT: Marie Magdefrau Ferraro , 50 , of Bethan...
#
#                                             response
# 0     [["John Wilkes Booth", "Occupation", "Actor"]]
# 1  [["Kevin O'Brien", "Worked_For", Palace of Fin...
# 2  [["Wang Ziqiang", "Works_at", "Institute of Me...
# 3  [["Sun Hung Kai Properties", "Type", "Construc...
# 4  [["Marie Magdefrau Ferraro", "Death_Place", "B...

# %%
results = res.copy()

error_count = 0

for ix, row in results.iterrows():
    
    try:
        response = ast.literal_eval(row["response"])
        for triplets in response:
            if len(triplets) != 3:
                raise ValueError
    except:
        error_count += 1
        print ("Error on index: ", ix)
        print (row["response"])
        results.drop(ix, inplace=True)
# Out:
# Error on index:  1
# [["Kevin O'Brien", "Worked_For", Palace of Fine Arts]]
# Error on index:  13
# [["Yang Jianbai", "Org", Economic Research]]
# Error on index:  20
# [["La Valette Underground Military Museum", "Owner", Gerald Przenislawski]]
# Error on index:  22
# [["Dueling Over a Gun", "Place", Dallas]]
# Error on index:  25
# [["Mark Moseley", "Sibling", Pamela Moseley]]
# Error on index:  27
# [["Rolling Fork", "is_part_of", Mississippi]]
# Error on index:  34
# [["Phnom Penh", "is_part_of", Cambodia]]
# Error on index:  46
# [["River North", "has_a_name"]]
# Error on index:  48
# [["Kyoto"], "Showcased_in", "Tokyo"]]
# Error on index:  61
# [["Robert C. Corduwener", "Nationality", Netherlands]]
# Error on index:  62
# [["Volcanoes in Nicaragua and Indonesia", "Subject", "deforestation in Brazil and Madagascar", "the Sahara desert in Africa"]]
# Error on index:  72
# [["Grand Rapids, Michigan"], "City", "Grand Rapids, Michigan"]]
# Error on index:  95
# [["Solidarity", "Person", Lech Walesa]]
# Error on index:  135
# [["Brian Mulroney", "Party", Progressive Conservative Party]]
# Error on index:  160
# [["American Express", "product", Weather Phone]]
# Error on index:  161
# [["1968"], "Person", "Martin Luther King Jr."], ["1968"], "Place", "London"]]
# Error on index:  180
# [["Ryan's Hope", "Show_Sponsored_By", ABC Entertainment]]
# Error on index:  182
# [["Moscow"], "Club", "Moskovsky Komsomolets"]]
# Error on index:  187
# [["Karbala", "is_part_of", Iraq]]
# Error on index:  196
# [["The Ballad of Czolgosz", "Singer", Leon Czolgosz]]
# Error on index:  198
# [["We are constantly getting confirmation that the U.S. economy is no longer in a boom phase, and that interest rates are falling,", "We are constantly getting confirmation that the U.S. economy is no longer in a boom phase, and that interest rates are falling,", "We are constantly getting confirmation that the U.S. economy is no longer in a boom phase, and that interest rates are falling,", "We are constantly getting confirmation that the U.S. economy is no longer in a boom phase, and that interest rates are falling,"]]
# Error on index:  200
# [["Jesse Jackson", "Native_Place", South Carolina]]
# Error on index:  202
# [["Jackson", "Wyoming", "temperature"], ["Jackson", "Colorado", "temperature"], ["Jackson", "Texas", "temperature"], ["Jackson", "Colorado", "name"], ["Jackson", "Wyoming", "state"], ["Jackson", "Wyoming", "city"], ["Jackson", "Wyoming", "zipcode"], ["Jackson", "Wyoming", "country"], ["Jackson", "Wyoming", "city"], ["Jackson", "Wyoming", "zipcode"], ["Jackson", "Wyoming", "state"], ["Jackson", "Wyoming
# Error on index:  203
# [["Craig Martin", "Works_For", Boeing Commercial Airplanes]]
# Error on index:  204
# [["Adam Urbanski", "Place", Rochester]]
# Error on index:  207
# [["Los Angeles", "City_State", "California"], ["Los Angeles", "City", "Los Angeles"], ["Los Angeles", "City", "Los Angeles"], ["Los Angeles", "City", "Los Angeles"], ["Los Angeles", "City", "Los Angeles"], ["Los Angeles", "City", "Los Angeles"], ["Los Angeles", "City", "Los Angeles"], ["Los Angeles", "City", "Los Angeles"], ["Los Angeles", "City", "Los Angeles"], ["Los Angeles", "City", "Los Angeles"], ["Los Angeles", "City", "L
# Error on index:  224
# [["Sultan Qabus Bin-Sa'id of Oman", "Title"]]
# Error on index:  227
# [["Widespread street flooding was reported throughout Brazoria , Fort Bend , Galveston and southern Harris Counties in southeast Texas"]]
# Error on index:  230
# [["Saudi Arabia"], "Location", "northern Saudi Arabia"]]

# %%
error_count
# Out:
# 29

# %%
results.shape
# Out:
# (202, 2)

# %%
valid_r_types = ["work_for", "live_in", "located_in", "orgbased_in", "kill"]

# %%
total_count = 0
nc_rel = 0
c_rel = 0
v_rels = 0
r_types = []

for ix, row in results.iterrows():
    for relation in ast.literal_eval(row["response"]):
        total_count += 1
        if len(relation) == 3:
            c_rel += 1
            r_types.append(relation[1])
            if relation[1].lower() in valid_r_types:
                v_rels += 1
                print (relation)
        else:
            nc_rel += 1
#             print (relation)

r_types = set(r_types)

print ("\n\nTOTAL: ", total_count)
print ("NON-CONFORMING: ", nc_rel)
print ("CONFORMING: ", c_rel)
print ("TOTAL VALID R-TYPES: ", v_rels)
print ("TOTAL UNIQUE CONFORMING R-TYPES: ", len(r_types))
# Out:
# ['Savannah River Plant', 'located_in', 'Aiken, S.C.']
# ['Novonezhino', 'located_in', 'Vladivostok']
# ['Parkland Memorial Hospital', 'located_in', 'Dallas']
# ['Parkland Memorial Hospital', 'located_in', 'Texas Theater']
#
#
# TOTAL:  247
# NON-CONFORMING:  0
# CONFORMING:  247
# TOTAL VALID R-TYPES:  4
# TOTAL UNIQUE CONFORMING R-TYPES:  121

# %%
r_types
# Out:
# {'Activity',
#  'Age',
#  'Aircraft',
#  'Appointed_By',
#  'Assassin',
#  'Assassinates',
#  'Assassination',
#  'Attached_to',
#  'Bank',
#  'Birth_Place',
#  'Born',
#  'Born_in',
#  'Brother',
#  'Callers',
#  'Capsule_name',
#  'Cause',
#  'Chairman',
#  'City',
#  'City,',
#  'Client',
#  'Component',
#  'Creditor',
#  'Crime',
#  'Date',
#  'Date_of_Death',
#  'Day',
#  'Death_Penalty',
#  'Death_Place',
#  'Director',
#  'Education',
#  'Employee',
#  'Flight_Status',
#  'Friend',
#  'Governor',
#  'Hometown',
#  'Killed',
#  'Killed_By',
#  'Killing',
#  'Kingdom',
#  'Known_as',
#  'Location',
#  'Mother',
#  'Movie',
#  'Nationality',
#  'Native_Son',
#  'Native_name',
#  'Newspaper',
#  'Nickname',
#  'Number_Of_Passengers',
#  'Occupation',
#  'Office',
#  'Office_Space',
#  'Officer',
#  'Operator',
#  'Order_to_ignore',
#  'Org',
#  'Owner',
#  'Part',
#  'Percentage',
#  'Person',
#  'Piano',
#  'Place',
#  'President',
#  'Purpose',
#  'Rank',
#  'Said',
#  'Sale_to',
#  'Secretary',
#  'Sentence',
#  'Sentenced_To_Death',
#  'Sex',
#  'Shot_By',
#  'Size',
#  'Son',
#  'Source',
#  'Speaker',
#  'Spin-off',
#  'Spouse',
#  'Staff_name',
#  'Statue',
#  'Summer',
#  'Term',
#  'Title',
#  'Top_Leader',
#  'Total_acres',
#  'Type',
#  'Visitor',
#  'WorkedFor',
#  'Worked_For',
#  'Worked_for',
#  'Works_For',
#  'Works_at',
#  'Works_for',
#  'Year',
#  'Years_in_use',
#  'Years_on_the_Supreme_Court',
#  'assassinater',
#  'assassination_date',
#  'capital',
#  'channel',
#  'date',
#  'department',
#  'departure',
#  'former_chief_executive',
#  'former_name',
#  'has_a_leader',
#  'has_a_river_name',
#  'isPartOf',
#  'is_a_member_of',
#  'is_part_of',
#  'island',
#  'killed',
#  'language',
#  'located_in',
#  'location',
#  'on_behalf_of',
#  'on_duty_with',
#  'reminds_someone_of',
#  'structure',
#  'theory',
#  'worked_for'}

# %%
conll_gold = json.load(open('conll04_dev.json'))

# %%
ips = []
gold = []

for i in conll_gold:
    ips.append("TEXT: " +  ' '.join(i["tokens"]))
    triplets = []
    for relation in i["relations"]:
        triplet = []
        # print (i["entities"])
        # print (i["entities"][relation["head"]]["type"])
        triplet.append(str(" ".join(i["tokens"][i["entities"][relation["head"]]["start"]:i["entities"][relation["head"]]["end"]])))
        triplet.append(relation["type"])
        triplet.append(str(" ".join(i["tokens"][i["entities"][relation["tail"]]["start"]:i["entities"][relation["tail"]]["end"]])))
#         print (triplet)
        triplets.append(triplet)
#     print (triplets)
    gold.append(triplets)
#     print ("\n")

df = pd.DataFrame({'input': ips, 'gold': gold}, index=None)

# %%
text = []
gold = []
generated = []

for ix, row in results.iterrows():
    gold_df = df.loc[df['input'] == row["input"]]
    if gold_df.shape[0] > 1:
        continue
    text.append(row["input"])
    for i, r in gold_df.iterrows():
#         print ("TRUE: ", r["gold"])
        gold.append(r["gold"])
#     print ("GENERATED: ", ast.literal_eval(row["response"]))
    generated.append(ast.literal_eval(row["response"]))
#     print ("TRUE: ", gold_df["gold"])
#     print ("\n-------------------------------------------\n")

# %%
df = pd.DataFrame({'text': text, 'generated': generated, 'true': gold}, index=None)
df.head()
# Out:
#                                                 text  \
# 0  TEXT: John Wilkes Booth , who assassinated Pre...
# 1  TEXT: In the field of mechanics , Wang Ziqiang...
# 2  TEXT: Sun Hung Kai Properties , a Hong Kong co...
# 3  TEXT: Marie Magdefrau Ferraro , 50 , of Bethan...
# 4  TEXT: Ten oil workers were missing off Morgan ...
#
#                                            generated  \
# 0           [[John Wilkes Booth, Occupation, Actor]]
# 1  [[Wang Ziqiang, Works_at, Institute of Mechani...
# 2  [[Sun Hung Kai Properties, Type, Construction ...
# 3  [[Marie Magdefrau Ferraro, Death_Place, Bethan...
# 4             [[Morgan City, is_part_of, Louisiana]]
#
#                                                 true
# 0     [[John Wilkes Booth, Kill, President Lincoln]]
# 1  [[Wang Ziqiang, Work_For, Institute of Mechani...
# 2  [[Sun Hung Kai Properties, OrgBased_In, Hong K...
# 3  [[Marie Magdefrau Ferraro, Live_In, Bethany], ...
# 4                   [[Morgan City, Located_In, La.]]

# %%
df.shape
# Out:
# (197, 3)

# %%
for ix, row in df.iterrows():
    
    if (row["text"] == "TEXT: Widespread street flooding was reported throughout Brazoria , Fort Bend , Galveston and southern Harris Counties in southeast Texas."):
#         print (row["true"])
        for triplet in row["generated"]:
            print (len(triplet))

# %%
tp = ()

input = []
relations = []
prefix = []
gold_relations = []

count = 0
for row in df.iterrows():
#     print (row[1]["text"])
    curr_tp = ()
    for t_triplet in row[1]["true"]:
        if t_triplet in row[1]["generated"]:
            tp += (t_triplet,)
            curr_tp += (t_triplet,)
        else:
            for g_triplet in row[1]["generated"]:
                if ((str(t_triplet[0]) in str(g_triplet[0])) or (str(g_triplet[0]) in str(t_triplet[0]) )) and (( str(t_triplet[2]) in str(g_triplet[2])) or (str(g_triplet[2]) in str(t_triplet[2]) )) and ( str(t_triplet[1]) == str(g_triplet[1]) ):
                    tp += (g_triplet,)
                    curr_tp += (g_triplet,)
                    print (row[1]["text"] + "\n")
                    print ("TRUE: " + str(t_triplet))
                    print ("PARTIAL TP GENERATED: " + str(g_triplet))
                    print ("-----------------------------------------------")
#     if len(curr_tp) > 0:
#         count += 1
#         print (row[1]["input"] + "\n")
#         input.append(row[1]["input"])
#         relations.append(list(curr_tp))
#         prefix.append("CONLL04")
#         gold_relations.append(row[1]["true"])
#         print ("TRUE (SET): ", row[1]["true"])
#         print ("TP (SET): ", list(curr_tp))
#         print ("----------------")

print ("TOTAL TRUE RELATIONS: ", count)
# Out:
# TOTAL TRUE RELATIONS:  0

# %%
fp = ()

fp_list = []
text = []

for row in df.iterrows():
    for g_triplet in row[1]["generated"]:
        flag = True
        if g_triplet in row[1]["true"]:
            continue
        else:
            for t_triplet in row[1]["true"]:
                if ((str(t_triplet[0]) in str(g_triplet[0]) ) or (str(g_triplet[0]) in str(t_triplet[0]) )) and ((str(t_triplet[2]) in str(g_triplet[2])) or (str(g_triplet[2]) in str(t_triplet[2]))) and (str(t_triplet[1]) == str(g_triplet[1])):
                    flag = False
            if flag:
                text.append(row[1]["text"])
                fp_list.append(g_triplet)
                fp += (g_triplet,)
                print (row[1]["text"] + "\n")
                print ("TRUE (SET): ", row[1]["true"])
                print ("FALSE POSITIVE GENERATED: " + str(g_triplet))
                print ("-----------------------------------------------")
# Out:
# TEXT: John Wilkes Booth , who assassinated President Lincoln , was an actor .
#
# TRUE (SET):  [['John Wilkes Booth', 'Kill', 'President Lincoln']]
# FALSE POSITIVE GENERATED: ['John Wilkes Booth', 'Occupation', 'Actor']
# -----------------------------------------------
# TEXT: In the field of mechanics , Wang Ziqiang at the Institute of Mechanics has made considerable headway in the area of elastoplastic crack mechanics .
#
# TRUE (SET):  [['Wang Ziqiang', 'Work_For', 'Institute of Mechanics']]
# FALSE POSITIVE GENERATED: ['Wang Ziqiang', 'Works_at', 'Institute of Mechanics']
# -----------------------------------------------
# TEXT: Sun Hung Kai Properties , a Hong Kong construction firm with a 27 percent share ;
#
# TRUE (SET):  [['Sun Hung Kai Properties', 'OrgBased_In', 'Hong Kong']]
# FALSE POSITIVE GENERATED: ['Sun Hung Kai Properties', 'Type', 'Construction company']
# -----------------------------------------------
# TEXT: Marie Magdefrau Ferraro , 50 , of Bethany , Conn. , was shot to death Thursday when two bandits armed with assault rifles emerged from nearby bushes and began firing at a van carrying a Connecticut Audubon Society wildlife wild tour group .
#
# TRUE (SET):  [['Marie Magdefrau Ferraro', 'Live_In', 'Bethany'], ['Marie Magdefrau Ferraro', 'Live_In', 'Conn.'], ['Bethany', 'Located_In', 'Conn.']]
# FALSE POSITIVE GENERATED: ['Marie Magdefrau Ferraro', 'Death_Place', 'Bethany, Connecticut']
# -----------------------------------------------
# TEXT: Ten oil workers were missing off Morgan City , La. , after their rig capsized while heading inland Monday to escape the storm.
#
# TRUE (SET):  [['Morgan City', 'Located_In', 'La.']]
# FALSE POSITIVE GENERATED: ['Morgan City', 'is_part_of', 'Louisiana']
# -----------------------------------------------
# TEXT: Lightning ignited a firestorm that charred 10 , 000 acres in central Idaho , including much of the small resort town of Lowman , about 70 miles northeast of Boise.
#
# TRUE (SET):  [['Lowman', 'Located_In', 'Idaho']]
# FALSE POSITIVE GENERATED: ['Lowman', 'is_part_of', 'Idaho']
# -----------------------------------------------
# TEXT: " It ( Arrow ) is not practical in the short term , " says former Air Force commander Avihu Bin-Nun .
#
# TRUE (SET):  [['Avihu Bin-Nun', 'Work_For', 'Air Force']]
# FALSE POSITIVE GENERATED: ['Avihu Bin-Nun', 'Rank', 'General']
# -----------------------------------------------
# TEXT: The three reactors , all at the Savannah River Plant , in Aiken , S.C. , have been shut down since last April undergoing changes to make them safer .
#
# TRUE (SET):  [['Savannah River Plant', 'Located_In', 'Aiken'], ['Savannah River Plant', 'Located_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# FALSE POSITIVE GENERATED: ['Savannah River Plant', 'located_in', 'Aiken, S.C.']
# -----------------------------------------------
# TEXT: Composer Thomas is a native of Chisholm , Minn .
#
# TRUE (SET):  [['Thomas', 'Live_In', 'Chisholm'], ['Thomas', 'Live_In', 'Minn .'], ['Chisholm', 'Located_In', 'Minn .']]
# FALSE POSITIVE GENERATED: ['Joseph Thomas', 'Born_in', 'Chisholm, Minnesota']
# -----------------------------------------------
# TEXT: Illinois Gov. James Thompson signed legislation last month scrapping Chicago 's central school board next July , to be replaced by parent-run councils empowered to set budgets and hire and fire principals .
#
# TRUE (SET):  [['James Thompson', 'Live_In', 'Illinois']]
# FALSE POSITIVE GENERATED: ['Chicago', 'Governor', 'James Thompson']
# -----------------------------------------------
# TEXT: During the 10-hour rescue , diver Brian Michaud of Millinocket hooked the men to harnesses , and rescuers dragged them to the surface with winches .
#
# TRUE (SET):  [['Brian Michaud', 'Live_In', 'Millinocket']]
# FALSE POSITIVE GENERATED: ['Brian Michaud', 'Occupation', 'Scuba diver']
# -----------------------------------------------
# TEXT: The Warren Commission found Oswald acted alone in killing Kennedy .
#
# TRUE (SET):  [['Oswald', 'Kill', 'Kennedy']]
# FALSE POSITIVE GENERATED: ['Jack Ruby', 'Killing', 'John F. Kennedy']
# -----------------------------------------------
# TEXT: The Warren Commission found Oswald acted alone in killing Kennedy .
#
# TRUE (SET):  [['Oswald', 'Kill', 'Kennedy']]
# FALSE POSITIVE GENERATED: ['John F. Kennedy', 'Assassination', 'John Lee Oswald']
# -----------------------------------------------
# TEXT: The Warren Commission found Oswald acted alone in killing Kennedy .
#
# TRUE (SET):  [['Oswald', 'Kill', 'Kennedy']]
# FALSE POSITIVE GENERATED: ['John F. Kennedy', 'Assassination', 'Lyndon B. Johnson']
# -----------------------------------------------
# TEXT: ` ` He was going pretty fast , wasn 't he ? ' ' said Daniel Urquhart , 8 , of Aumsville , whose slug crept to the championship.
#
# TRUE (SET):  [['Daniel Urquhart', 'Live_In', 'Aumsville']]
# FALSE POSITIVE GENERATED: ['Daniel Urquhart', 'Age', 8]
# -----------------------------------------------
# TEXT: Kovacevic , a Serb , has come under fire from Serbian politicians and the republic 's press since the U.S. Congress last month passed two resolutions claiming there were human rights violations in the strife-torn southern province of Kosovo.
#
# TRUE (SET):  [['Congress', 'OrgBased_In', 'U.S.']]
# FALSE POSITIVE GENERATED: ['Kovacevic', 'Nationality', 'Serbian']
# -----------------------------------------------
# TEXT: Martin Luther King III , a son of the slain civil rights leader , said the execution of King assassin James Earl Ray ` ` would not bring my father back. ' '
#
# TRUE (SET):  [['James Earl Ray', 'Kill', 'Martin Luther King III']]
# FALSE POSITIVE GENERATED: ['Martin Luther King III', 'Son', 'Martin Luther King Jr.']
# -----------------------------------------------
# TEXT: On this date : In 1833 , Benjamin Harrison , the 23rd President of the United States , was born in North Bend , Ohio .
#
# TRUE (SET):  [['Benjamin Harrison', 'Live_In', 'North Bend , Ohio']]
# FALSE POSITIVE GENERATED: ['Benjamin Harrison', 'President', '23rd']
# -----------------------------------------------
# TEXT: On this date : In 1833 , Benjamin Harrison , the 23rd President of the United States , was born in North Bend , Ohio .
#
# TRUE (SET):  [['Benjamin Harrison', 'Live_In', 'North Bend , Ohio']]
# FALSE POSITIVE GENERATED: ['Benjamin Harrison', 'Born', '1833']
# -----------------------------------------------
# TEXT: On this date : In 1833 , Benjamin Harrison , the 23rd President of the United States , was born in North Bend , Ohio .
#
# TRUE (SET):  [['Benjamin Harrison', 'Live_In', 'North Bend , Ohio']]
# FALSE POSITIVE GENERATED: ['Benjamin Harrison', 'Born', 'North Bend, Ohio']
# -----------------------------------------------
# TEXT: The book said Khrushchev 's order to ignore the blockade was disclosed in a largely unknown work by dissident Soviet historian Roy Medvedev .
#
# TRUE (SET):  [['Khrushchev', 'Live_In', 'Soviet'], ['Roy Medvedev', 'Live_In', 'Soviet']]
# FALSE POSITIVE GENERATED: ['Khrushchev', 'Order_to_ignore', 'Blockade']
# -----------------------------------------------
# TEXT: EDITOR 'S NOTE : Walter R. Mears , vice and columnist for The Associated Press , has reported on Washington and national politics for more than 25 years .
#
# TRUE (SET):  [['Walter R. Mears', 'Work_For', 'The Associated Press']]
# FALSE POSITIVE GENERATED: ['Walter R. Mears', 'Works_for', 'The Associated Press']
# -----------------------------------------------
# TEXT: ` ` With South Carolina being Jesse Jackson 's home state , there was a very strong incentive in the black community. ' '
#
# TRUE (SET):  [['Jesse Jackson', 'Live_In', 'South Carolina']]
# FALSE POSITIVE GENERATED: ['Jesse Jackson', 'Hometown', 'South Carolina']
# -----------------------------------------------
# TEXT: In a statement at the airport before his departure , Cetin said that Turkey welcomed this step taken by Bosnians and Croats and hoped that real peace comes to Bosnia-Herzegovina when Serbs join this process too .
#
# TRUE (SET):  [['Cetin', 'Live_In', 'Turkey']]
# FALSE POSITIVE GENERATED: ['Cetin', 'departure', 'at the airport before his departure']
# -----------------------------------------------
# TEXT: On Friday , U.S. Ambassador Vernon A. Walters displayed photographs of one Libyan jet showing shapes resembling missile pods on its wings and fuselage .
#
# TRUE (SET):  [['Vernon A. Walters', 'Live_In', 'U.S.']]
# FALSE POSITIVE GENERATED: ['Vernon A. Walters', 'Worked_For', 'United States']
# -----------------------------------------------
# TEXT: Hernandez Galicia 's allegedly corrupt Mexican Oil Workers Union controls more than half the lucrative drilling contracts issued by the state oil monopoly , Pemex .
#
# TRUE (SET):  [['Hernandez Galicia', 'Work_For', 'Mexican Oil Workers Union']]
# FALSE POSITIVE GENERATED: ['Hernandez Galicia', 'Org', 'Mexican Oil Workers Union']
# -----------------------------------------------
# TEXT: ` ` The Challenger accident marked a major change in the U.S. outlook and policies with respect to the flight of other than NASA astronauts , ' ' the National Aeronautics and Space Administration said in a policy statement .
#
# TRUE (SET):  [['NASA', 'OrgBased_In', 'U.S.'], ['National Aeronautics and Space Administration', 'OrgBased_In', 'U.S.']]
# FALSE POSITIVE GENERATED: ['NASA', 'Owner', 'United States']
# -----------------------------------------------
# TEXT: ` ` It 's not going to make you a whole bunch of money , but that 's not why we 're doing it , ' ' said Phil Fuhrer , vice of Gannett New Media. 1-900-WEATHER offers callers the current weather and a three-day forecast , plus skiing and highway conditions in the winter and coastal reports during the summer.
#
# TRUE (SET):  [['Phil Fuhrer', 'Work_For', 'Gannett New Media.']]
# FALSE POSITIVE GENERATED: ['1-900-Weather', 'Callers', 'the current weather and a three-day forecast']
# -----------------------------------------------
# TEXT: PA2904034294 Guatemala City Teleonce Television in Spanish 0400 GMT 26 Apr 94
#
# TRUE (SET):  [['Teleonce Television', 'OrgBased_In', 'Guatemala City']]
# FALSE POSITIVE GENERATED: ['PA2904034294', 'Title', 'Guatemala City Teleonce Television in Spanish 0400 GMT 26 Apr 94']
# -----------------------------------------------
# TEXT: DAYTON , Ohio ( AP )
#
# TRUE (SET):  [['DAYTON', 'Located_In', 'Ohio'], ['AP', 'OrgBased_In', 'DAYTON'], ['AP', 'OrgBased_In', 'Ohio']]
# FALSE POSITIVE GENERATED: ['Dayton', 'is_part_of', 'Ohio']
# -----------------------------------------------
# TEXT: In 1865 , four people were hanged in Washington , D.C. , after being convicted of conspiring with John Wilkes Booth in the assassination of President Lincoln .
#
# TRUE (SET):  [['John Wilkes Booth', 'Kill', 'President Lincoln']]
# FALSE POSITIVE GENERATED: ['John Wilkes Booth', 'Assassination', 'Abraham Lincoln']
# -----------------------------------------------
# TEXT: San Gabriel River Channel , Azusa , Calif. ;
#
# TRUE (SET):  [['San Gabriel River Channel', 'Located_In', 'Azusa'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azusa', 'Located_In', 'Calif.']]
# FALSE POSITIVE GENERATED: ['San Gabriel River Channel', 'Location', 'Azusa, California']
# -----------------------------------------------
# TEXT: Derwinski , a Republican from Chicago who served 24 years in Congress , publicly denied 1978 allegations that he leaked the information and refused to testify in the matter before a federal grand jury and the House Ethics Committee .
#
# TRUE (SET):  [['Derwinski', 'Live_In', 'Chicago'], ['Derwinski', 'Work_For', 'Congress']]
# FALSE POSITIVE GENERATED: ['Derwinski', 'Office', 'Congressman']
# -----------------------------------------------
# TEXT: ( Text ) Police Major Pramot Pansakun , the commander of the Region 2 Border Patrol Police ( BPP ) , Khon Kaen , and Thai and American narcotics suppression officials accompanied by reporters , spent more than 2 hours climbing a high mountain to destroy a Hmong poppy field located along the border between Dan Sai District in Loei Province , Nakhon Thai District in Phitsanulok Province , and Lomsak District in Phetchabun Province .
#
# TRUE (SET):  [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Dan Sai District', 'Located_In', 'Loei Province'], ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province'], ['Lomsak District', 'Located_In', 'Phetchabun Province']]
# FALSE POSITIVE GENERATED: ['Pamot Pansakun', 'Officer', 'Border Patrol Police (BPP)']
# -----------------------------------------------
# TEXT: Further buying was linked to rumors that the Chilean copper company Codelco was considering shutting down its smelter at Chuquicamata , the world 's largest copper mine , due to persistent mechanical problems , said Fred Demler , metals economist with Drexel Burnham Lambert Inc. in New York .
#
# TRUE (SET):  [['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.'], ['Fred Demler', 'Live_In', 'New York'], ['Drexel Burnham Lambert Inc.', 'OrgBased_In', 'New York']]
# FALSE POSITIVE GENERATED: ['Drexel Burnham Lambert Inc.', 'City', 'New York']
# -----------------------------------------------
# TEXT: An urgent call for international help to avert food shortages in Poland went out both from last month 's Western economic summit in Paris and from Monday 's meeting in Brussels of 24 concerned nations chaired by the European Community Commission.
#
# TRUE (SET):  [['European Community Commission.', 'OrgBased_In', 'Brussels']]
# FALSE POSITIVE GENERATED: ['Paris', 'City', 'Brussels']
# -----------------------------------------------
# TEXT: Cheek , 53 , is a former chief and charge in Addis Ababa , Ethiopia.
#
# TRUE (SET):  [['Addis Ababa', 'Located_In', 'Ethiopia.']]
# FALSE POSITIVE GENERATED: ['Cheek', 'Office', 'Addis Ababa']
# -----------------------------------------------
# TEXT: In 1881 , President James A. Garfield was shot by Charles J. Guiteau , a disappointed office-seeker , at the Washington railroad station .
#
# TRUE (SET):  [['Charles J. Guiteau', 'Kill', 'President James A. Garfield']]
# FALSE POSITIVE GENERATED: ['James A. Garfield', 'Assassination', 'Charles J. Guiteau']
# -----------------------------------------------
# TEXT: Middle-class Argentines , among the most affluent in Latin America at one time , are so strapped now that they are selling off heirlooms that had been in their families since the days when beef and grain made Argentina one of the world 's wealthiest nations.
#
# TRUE (SET):  [['Argentina', 'Located_In', 'Latin America']]
# FALSE POSITIVE GENERATED: ['Argentina', 'is_part_of', 'Latin America']
# -----------------------------------------------
# TEXT: ` ` I don 't think there are any good answers why , ' ' said Virginia Towle of Wallingford , a family friend.
#
# TRUE (SET):  [['Virginia Towle', 'Live_In', 'Wallingford']]
# FALSE POSITIVE GENERATED: ['Virginia Towle', 'Friend', 'Wallingford']
# -----------------------------------------------
# TEXT: The meeting will be held at the request of the Soviet Union , which also plans direct talks with resistance leader Prince Norodom Sihanouk , said Sihanouk 's son and representative in Thailand , Prince Norodom Ranariddh .
#
# TRUE (SET):  [['Prince Norodom Ranariddh', 'Live_In', 'Thailand']]
# FALSE POSITIVE GENERATED: ['Norodom Ranariddh', 'Son', 'Norodom Sihanouk']
# -----------------------------------------------
# TEXT: Hundreds of children and adults sporting cowboy boots and hats turned out Wednesday to watch as Winterset 's busiest street was named for John Wayne , the community 's most famous native son .
#
# TRUE (SET):  [['John Wayne', 'Live_In', 'Winterset']]
# FALSE POSITIVE GENERATED: ['John Wayne', 'Native_Son', 'Winterset, Iowa']
# -----------------------------------------------
# TEXT: Police Find No Signs of Radiation Leak AU0202111694 Paris AFP in English 0107 GMT 2 Feb 94
#
# TRUE (SET):  [['AFP', 'OrgBased_In', 'Paris']]
# FALSE POSITIVE GENERATED: ['Paris AFP', 'language', 'English']
# -----------------------------------------------
# TEXT: The self-propelled rig Avco 5 with 14 people aboard was headed to shore early Monday when it capsized about 20 miles off the Louisiana coast , near Morgan City , Chevron spokesman Jonathan Lifa said.
#
# TRUE (SET):  [['Jonathan Lifa', 'Work_For', 'Chevron']]
# FALSE POSITIVE GENERATED: ['Avco 5', 'Capsule_name', 'Avco 5']
# -----------------------------------------------
# TEXT: Sen. Jake Garn , R-Utah , flew on the shuttle in April 1985 and Rep. Bill Nelson , D-Fla. , was aboard in January 1986 , at the invitation of NASA 's administrator .
#
# TRUE (SET):  [['Jake Garn', 'Work_For', 'NASA'], ['Bill Nelson', 'Work_For', 'NASA']]
# FALSE POSITIVE GENERATED: ['Jake Garn', 'Officer', 'NASA Administrator']
# -----------------------------------------------
# TEXT: Sen. Jake Garn , R-Utah , flew on the shuttle in April 1985 and Rep. Bill Nelson , D-Fla. , was aboard in January 1986 , at the invitation of NASA 's administrator .
#
# TRUE (SET):  [['Jake Garn', 'Work_For', 'NASA'], ['Bill Nelson', 'Work_For', 'NASA']]
# FALSE POSITIVE GENERATED: ['Bill Nelson', 'Officer', 'NASA Administrator']
# -----------------------------------------------
# TEXT: Sen. Jake Garn , R-Utah , flew on the shuttle in April 1985 and Rep. Bill Nelson , D-Fla. , was aboard in January 1986 , at the invitation of NASA 's administrator .
#
# TRUE (SET):  [['Jake Garn', 'Work_For', 'NASA'], ['Bill Nelson', 'Work_For', 'NASA']]
# FALSE POSITIVE GENERATED: ['Jake Garn', 'Officer', 'Congressman']
# -----------------------------------------------
# TEXT: Ten Soviet volunteers and their American counterparts plan to spend August in Washington building homes for the poor as a return favor for help in earthquake-devastated Soviet Armenia.
#
# TRUE (SET):  [['Armenia.', 'Located_In', 'Soviet']]
# FALSE POSITIVE GENERATED: ['Washington', 'has_a_river_name', 'Washington River']
# -----------------------------------------------
# TEXT: Evaluating Juppe 's visit , Cetin said that the French Government was not displaying a disturbing stand toward Turkey and was very careful in not intervening in Turkey 's internal affairs .
#
# TRUE (SET):  [['Juppe', 'Work_For', 'French Government'], ['Cetin', 'Live_In', 'Turkey'], ['Cetin', 'Live_In', 'Turkey']]
# FALSE POSITIVE GENERATED: ['Cetin', 'Visitor', 'Juppe']
# -----------------------------------------------
# TEXT: Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# FALSE POSITIVE GENERATED: ['Jose Vicente Maldonado', 'Office', 'Minister of Industry, Commerce and Integration']
# -----------------------------------------------
# TEXT: Dole 's wife , Elizabeth , is a native of Salisbury , N.C .
#
# TRUE (SET):  [['Elizabeth', 'Live_In', 'Salisbury , N.C']]
# FALSE POSITIVE GENERATED: ['Elizabeth Dole', 'Native_name', 'Salisbury, N.C.']
# -----------------------------------------------
# TEXT: ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# FALSE POSITIVE GENERATED: ['Bulgarian Socialist Party', 'former_name', 'Bulgarian Communist Party']
# -----------------------------------------------
# TEXT: Starr , who served as counselor to Attorney William French Smith from 1981 prior to taking the bench in 1983 , had been mentioned as a possible Supreme Court nominee after his former colleague on the District of Columbia circuit , Robert Bork , failed to win Senate confirmation in 1987 .
#
# TRUE (SET):  [['Supreme Court', 'OrgBased_In', 'District of Columbia'], ['Senate', 'OrgBased_In', 'District of Columbia']]
# FALSE POSITIVE GENERATED: ['Robert Bork', 'Years_on_the_Supreme_Court', '1987']
# -----------------------------------------------
# TEXT: The program , financed with a grant from the United States Agency for International Development , is aimed at reducing infant mortality in Madagascar , an island nation in the Indian Ocean off the eastern coast of Africa.
#
# TRUE (SET):  [['Madagascar', 'Located_In', 'Indian Ocean']]
# FALSE POSITIVE GENERATED: ['Madagascar', 'island', 'Madagascar']
# -----------------------------------------------
# TEXT: JN0704183294 Paris Radio Monte Carlo in Arabic 1700 GMT 7 Apr 94
#
# TRUE (SET):  [['Radio Monte Carlo', 'OrgBased_In', 'Paris']]
# FALSE POSITIVE GENERATED: ['Paris Radio Monte Carlo in Arabic', 'Title', '7 Apr 94']
# -----------------------------------------------
# TEXT: On this date : In 1533 , the last Incan King of Peru , Atahualpa , was murdered on the orders of Spanish conqueror Francisco Pizarro .
#
# TRUE (SET):  [['Francisco Pizarro', 'Kill', 'Atahualpa']]
# FALSE POSITIVE GENERATED: ['Atahualpa', 'Kingdom', 'Peru']
# -----------------------------------------------
# TEXT: ` ` We 'd play hearts for hours at a time , ' ' said Atlanta businessman Neil Estes.
#
# TRUE (SET):  [['Neil Estes.', 'Live_In', 'Atlanta']]
# FALSE POSITIVE GENERATED: ['Neil Estes', 'Occupation', 'Businessman']
# -----------------------------------------------
# TEXT: ` ` This is really hurting Heuchelheim , ' ' the town 's mayor Willi Marx told The Associated Press in an interview at his office earlier this month .
#
# TRUE (SET):  [['Willi Marx', 'Live_In', 'Heuchelheim']]
# FALSE POSITIVE GENERATED: ['Willy Marx', 'Works_For', 'Associated Press']
# -----------------------------------------------
# TEXT: ` ` I think at this moment they fear making a wrong move _ whether they should seek political asylum or use other reasons to remain here , ' ' said Jeff Shia , president of the Kiangsu Chekiang Association , a non-profit group that helps new Chinese immigrants establish themselves in the city.
#
# TRUE (SET):  [['Jeff Shia', 'Work_For', 'Kiangsu Chekiang Association']]
# FALSE POSITIVE GENERATED: ['Jeff Shia', 'Works_for', 'Kiangsu Chekiang Association']
# -----------------------------------------------
# TEXT: The term ` ` 30 Seconds Over Tokyo ' ' was the title of a popular movie about the raid. _Anzio _ The Anzio beachhead , 33 miles south of Rome , saw some of the bloodiest fighting of World War II and accounted for many of the 10 , 000 U.S. battle deaths in Italy the first half of 1944 .
#
# TRUE (SET):  [['Anzio', 'Located_In', 'Italy']]
# FALSE POSITIVE GENERATED: ['30 Seconds Over Tokyo', 'Movie', '30 Seconds Over Tokyo']
# -----------------------------------------------
# TEXT: Anna Sandhu Ray , who 10 years ago Thursday wed the man convicted of killing the Rev. Martin Luther King Jr. , said on her anniversary that she plans to divorce James Earl Ray .
#
# TRUE (SET):  [['James Earl Ray', 'Kill', 'Rev. Martin Luther King Jr.']]
# FALSE POSITIVE GENERATED: ['Anna Sandhu Ray', 'Spouse', 'James Earl Ray']
# -----------------------------------------------
# TEXT: The 23-foot-tall statue was modeled after the 30-foot-tall Goddess of Democracy raised by Chinese pro-democracy demonstrators in Beijing 's Tiananmen Square on May 30.
#
# TRUE (SET):  [['Tiananmen Square', 'Located_In', 'Beijing']]
# FALSE POSITIVE GENERATED: ['Goddess of Democracy', 'Size', '30 ft.']
# -----------------------------------------------
# TEXT: The 23-foot-tall statue was modeled after the 30-foot-tall Goddess of Democracy raised by Chinese pro-democracy demonstrators in Beijing 's Tiananmen Square on May 30.
#
# TRUE (SET):  [['Tiananmen Square', 'Located_In', 'Beijing']]
# FALSE POSITIVE GENERATED: ['Goddess of Democracy', 'Statue', '23 ft.']
# -----------------------------------------------
# TEXT: The 23-foot-tall statue was modeled after the 30-foot-tall Goddess of Democracy raised by Chinese pro-democracy demonstrators in Beijing 's Tiananmen Square on May 30.
#
# TRUE (SET):  [['Tiananmen Square', 'Located_In', 'Beijing']]
# FALSE POSITIVE GENERATED: ['Goddess of Democracy', 'Statue', 'Beijing']
# -----------------------------------------------
# TEXT: ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
#
# TRUE (SET):  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# FALSE POSITIVE GENERATED: ['Li Peng', 'Office', "Premier of the People's Republic of China"]
# -----------------------------------------------
# TEXT: ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
#
# TRUE (SET):  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# FALSE POSITIVE GENERATED: ['P. Jasray', 'Office', 'Prime Minister of Mongolia']
# -----------------------------------------------
# TEXT: ( Text ) The Rwandan Patriotic Front ( RPF ) has rescued 2 , 000 people in Bugesera in the southeastern part of Rwanda .
#
# TRUE (SET):  [['Bugesera', 'Located_In', 'Rwanda']]
# FALSE POSITIVE GENERATED: ['Bugesera', 'Part', 'Southeastern part of Rwanda']
# -----------------------------------------------
# TEXT: One of Warner 's lawyers , Andrew Hall of Miami , Fla. , confirmed Tuesday that Warner is trying to settle the case.
#
# TRUE (SET):  [['Andrew Hall', 'Live_In', 'Miami'], ['Andrew Hall', 'Live_In', 'Fla.'], ['Miami', 'Located_In', 'Fla.']]
# FALSE POSITIVE GENERATED: ['Andrew Hall', 'WorkedFor', 'Warner Bros.']
# -----------------------------------------------
# TEXT: New Jersey Gov. Thomas Kean , who is leaving office after two terms at the end of this year , was greeted with effuse public praise by his colleagues during the conference.
#
# TRUE (SET):  [['Thomas Kean', 'Live_In', 'New Jersey']]
# FALSE POSITIVE GENERATED: ['Thomas Kean', 'Office', 'Governor of New Jersey']
# -----------------------------------------------
# TEXT: ` ` The country was starved of resources , ' ' said Marcos Victorica , director of the Institute of Contemporary Studies.
#
# TRUE (SET):  [['Marcos Victorica', 'Work_For', 'Institute of Contemporary Studies.']]
# FALSE POSITIVE GENERATED: ['Institute of Contemporary Studies', 'Director', 'Marcos Victorica']
# -----------------------------------------------
# TEXT: Excess Lira Reportedly Causes Currency Crisis NC1901223094 London Kanal-6 Television in Turkish 1700 GMT 19 Jan 94
#
# TRUE (SET):  [['Kanal-6 Television', 'OrgBased_In', 'London']]
# FALSE POSITIVE GENERATED: ['Excess Lira Reportedly Causes Currency Crisis', 'date', '19 Jan 94']
# -----------------------------------------------
# TEXT: Excess Lira Reportedly Causes Currency Crisis NC1901223094 London Kanal-6 Television in Turkish 1700 GMT 19 Jan 94
#
# TRUE (SET):  [['Kanal-6 Television', 'OrgBased_In', 'London']]
# FALSE POSITIVE GENERATED: ['Excess Lira Reportedly Causes Currency Crisis', 'channel', 'Kanal-6 Television']
# -----------------------------------------------
# TEXT: " This is the Garrett place where John Wilkes Booth , assassin of Lincoln , was cornered by Union soldiers and killed April 26 , 1865 .
#
# TRUE (SET):  [['John Wilkes Booth', 'Kill', 'Lincoln']]
# FALSE POSITIVE GENERATED: ['John Wilkes Booth', 'Killed', 'Abraham Lincoln']
# -----------------------------------------------
# TEXT: Joseph Cicippio , 58 , was acting comptroller at the American University of Beirut when he was kidnapped from the campus Sept. 12 , 1986.
#
# TRUE (SET):  [['Joseph Cicippio', 'Work_For', 'American University of Beirut']]
# FALSE POSITIVE GENERATED: ['Joseph Cicippio', 'Attached_to', 'American University of Beirut']
# -----------------------------------------------
# TEXT: The Santa Ana winds _ also called ` ` devil winds ' ' _ are spun off by high pressure over the interior of the country , picking up speed as they move from Southern California 's deserts through mountain passes and roar down on adjacent communities .
#
# TRUE (SET):  [['Santa Ana', 'Located_In', 'Southern California']]
# FALSE POSITIVE GENERATED: ['Santa Ana winds', 'Spin-off', 'High pressure over the interior of the country']
# -----------------------------------------------
# TEXT: FL2706231194 Havana Radio Reloj Network in Spanish 1402 GMT 27 Jun 94
#
# TRUE (SET):  [['Radio Reloj Network', 'OrgBased_In', 'Havana']]
# FALSE POSITIVE GENERATED: ['FL2706231194', 'Title', 'Havana Radio Reloj Network in Spanish']
# -----------------------------------------------
# TEXT: ` ` Our white paper , market pulp and packaging businesses turned in particularly impressive results in 1988 , ' ' said John A. Georges , International Paper 's chairman and chief executive officer .
#
# TRUE (SET):  [['John A. Georges', 'Work_For', 'International Paper']]
# FALSE POSITIVE GENERATED: ['International Paper', 'Chairman', 'John A. Georges']
# -----------------------------------------------
# TEXT: The FA-18 Hornet was on a mission to Pinecastle Electronic Warfare Range in the Ocala National Forest when the bomb tumbled free at 1 : 50 p.m .
#
# TRUE (SET):  [['Pinecastle Electronic Warfare Range', 'Located_In', 'Ocala National Forest']]
# FALSE POSITIVE GENERATED: ['FA-18 Hornet', 'Aircraft', 'F/A-18 Hornet']
# -----------------------------------------------
# TEXT: The FA-18 Hornet was on a mission to Pinecastle Electronic Warfare Range in the Ocala National Forest when the bomb tumbled free at 1 : 50 p.m .
#
# TRUE (SET):  [['Pinecastle Electronic Warfare Range', 'Located_In', 'Ocala National Forest']]
# FALSE POSITIVE GENERATED: ['FA-18 Hornet', 'Flight_Status', 'Flight']
# -----------------------------------------------
# TEXT: The FA-18 Hornet was on a mission to Pinecastle Electronic Warfare Range in the Ocala National Forest when the bomb tumbled free at 1 : 50 p.m .
#
# TRUE (SET):  [['Pinecastle Electronic Warfare Range', 'Located_In', 'Ocala National Forest']]
# FALSE POSITIVE GENERATED: ['FA-18 Hornet', 'Location', 'Ocala National Forest']
# -----------------------------------------------
# TEXT: EAST LANSING , Mich.
#
# TRUE (SET):  [['EAST LANSING', 'Located_In', 'Mich.']]
# FALSE POSITIVE GENERATED: ['East Lansing', 'is_part_of', 'Michigan']
# -----------------------------------------------
# TEXT: Born in Athens , Psacharopoulos came to the United States at age 17 to enter Oberlin College , where he studied art history .
#
# TRUE (SET):  [['Oberlin College', 'OrgBased_In', 'United States']]
# FALSE POSITIVE GENERATED: ['George Psacharopoulos', 'Born', 'Athens']
# -----------------------------------------------
# TEXT: Born in Athens , Psacharopoulos came to the United States at age 17 to enter Oberlin College , where he studied art history .
#
# TRUE (SET):  [['Oberlin College', 'OrgBased_In', 'United States']]
# FALSE POSITIVE GENERATED: ['George Psacharopoulos', 'Education', 'Oberlin College']
# -----------------------------------------------
# TEXT: Two days later , Perry operated on Kennedy 's assassin , Lee Harvey Oswald , who had just been shot by Jack Ruby .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy'], ['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# FALSE POSITIVE GENERATED: ['Lee Harvey Oswald', 'Killed', 'John F. Kennedy']
# -----------------------------------------------
# TEXT: Two days later , Perry operated on Kennedy 's assassin , Lee Harvey Oswald , who had just been shot by Jack Ruby .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy'], ['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# FALSE POSITIVE GENERATED: ['John F. Kennedy', 'Assassin', 'Lee Harvey Oswald']
# -----------------------------------------------
# TEXT: Two days later , Perry operated on Kennedy 's assassin , Lee Harvey Oswald , who had just been shot by Jack Ruby .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy'], ['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# FALSE POSITIVE GENERATED: ['Lee Harvey Oswald', 'Shot_By', 'Jack Ruby']
# -----------------------------------------------
# TEXT: The prime was accompanied by his wife , Datuk Sri Datin Paduka Dr. Siti Hasmah and the deputy secretary of the Foreign Ministry , Datuk Abdul Halim Ali , during his brief visit to South Africa .
#
# TRUE (SET):  [['Datuk Abdul Halim Ali', 'Work_For', 'Foreign Ministry']]
# FALSE POSITIVE GENERATED: ['Datuk Abdul Halim Ali', 'Office', 'Foreign Ministry']
# -----------------------------------------------
# TEXT: The federal appeals court previously overturned a key provision of Arizona 's death penalty statute in the case of John Harvey Adamson , convicted of murdering reporter Don Bolles .
#
# TRUE (SET):  [['John Harvey Adamson', 'Kill', 'Don Bolles']]
# FALSE POSITIVE GENERATED: ['Don Bolles', 'Death_Penalty', 'Death']
# -----------------------------------------------
# TEXT: The federal appeals court previously overturned a key provision of Arizona 's death penalty statute in the case of John Harvey Adamson , convicted of murdering reporter Don Bolles .
#
# TRUE (SET):  [['John Harvey Adamson', 'Kill', 'Don Bolles']]
# FALSE POSITIVE GENERATED: ['Don Bolles', 'Crime', 'Murder']
# -----------------------------------------------
# TEXT: The federal appeals court previously overturned a key provision of Arizona 's death penalty statute in the case of John Harvey Adamson , convicted of murdering reporter Don Bolles .
#
# TRUE (SET):  [['John Harvey Adamson', 'Kill', 'Don Bolles']]
# FALSE POSITIVE GENERATED: ['Don Bolles', 'Sex', 'Female']
# -----------------------------------------------
# TEXT: The federal appeals court previously overturned a key provision of Arizona 's death penalty statute in the case of John Harvey Adamson , convicted of murdering reporter Don Bolles .
#
# TRUE (SET):  [['John Harvey Adamson', 'Kill', 'Don Bolles']]
# FALSE POSITIVE GENERATED: ['Don Bolles', 'Born', '1938']
# -----------------------------------------------
# TEXT: The movie 's script remains a secret , but Stone has said Kevin Costner will star as New Orleans prosecutor Jim Garrison , who said that Kennedy was the victim of an FBI and CIA conspiracy and that Lee Harvey Oswald , identified by a presidential commission as the lone assassin , was set up to take the blame. ;
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# FALSE POSITIVE GENERATED: ['Jim Garrison', 'killed', 'John F. Kennedy']
# -----------------------------------------------
# TEXT: Becton Dickinson sells needle containers to doctors and hospitals but may develop a container for home use , said Linda Schmitt , an assistant product manager.
#
# TRUE (SET):  [['Linda Schmitt', 'Work_For', 'Becton Dickinson']]
# FALSE POSITIVE GENERATED: ['Becton Dickinson', 'Sale_to', 'Doctors and hospitals']
# -----------------------------------------------
# TEXT: Becton Dickinson sells needle containers to doctors and hospitals but may develop a container for home use , said Linda Schmitt , an assistant product manager.
#
# TRUE (SET):  [['Linda Schmitt', 'Work_For', 'Becton Dickinson']]
# FALSE POSITIVE GENERATED: ['Becton Dickinson', 'Sale_to', 'Home users']
# -----------------------------------------------
# TEXT: Becton Dickinson sells needle containers to doctors and hospitals but may develop a container for home use , said Linda Schmitt , an assistant product manager.
#
# TRUE (SET):  [['Linda Schmitt', 'Work_For', 'Becton Dickinson']]
# FALSE POSITIVE GENERATED: ['Becton Dickinson', 'Staff_name', 'Linda Schmitt']
# -----------------------------------------------
# TEXT: The police files on Kennedy 's shooting could shed new light on persistent questions about whether Sirhan Bishara Sirhan was the only gunman in the shooting .
#
# TRUE (SET):  [['Sirhan Bishara Sirhan', 'Kill', 'Kennedy']]
# FALSE POSITIVE GENERATED: ['Sirhan Bishara Sirhan', 'Assassination', 'Robert F. Kennedy']
# -----------------------------------------------
# TEXT: NC1404123794 Cairo AL-AHALI in Arabic 6 Apr 94 p 6
#
# TRUE (SET):  [['AL-AHALI', 'OrgBased_In', 'Cairo']]
# FALSE POSITIVE GENERATED: ['NC1404123794', 'language', 'Arabic']
# -----------------------------------------------
# TEXT: NC1404123794 Cairo AL-AHALI in Arabic 6 Apr 94 p 6
#
# TRUE (SET):  [['AL-AHALI', 'OrgBased_In', 'Cairo']]
# FALSE POSITIVE GENERATED: ['NC1404123794', 'date', '6 April 1994']
# -----------------------------------------------
# TEXT: In 1936 , rock legend Buddy Holly was born Charles Hardin Holley in Lubbock , Texas .
#
# TRUE (SET):  [['Buddy Holly', 'Live_In', 'Lubbock , Texas'], ['Charles Hardin Holley', 'Live_In', 'Lubbock , Texas']]
# FALSE POSITIVE GENERATED: ['Buddy Holly', 'Born', 1936]
# -----------------------------------------------
# TEXT: Belli 's clients have included Jack Ruby , who killed John F. Kennedy assassin Lee Harvey Oswald , and Jim and Tammy Bakker .
#
# TRUE (SET):  [['Jack Ruby', 'Kill', 'Lee Harvey Oswald'], ['Lee Harvey Oswald', 'Kill', 'John F. Kennedy']]
# FALSE POSITIVE GENERATED: ['Jack Ruby', 'Client', 'John F. Kennedy']
# -----------------------------------------------
# TEXT: Belli 's clients have included Jack Ruby , who killed John F. Kennedy assassin Lee Harvey Oswald , and Jim and Tammy Bakker .
#
# TRUE (SET):  [['Jack Ruby', 'Kill', 'Lee Harvey Oswald'], ['Lee Harvey Oswald', 'Kill', 'John F. Kennedy']]
# FALSE POSITIVE GENERATED: ['Jack Ruby', 'Client', 'Tammy Bakker']
# -----------------------------------------------
# TEXT: Bosnia 's capital , Sarajevo , is best-known as the site of the assassination in 1914 of Austrian Archduke Franz Ferdinand by young Bosnian nationalist Gavrilo Princip , which was the spark that ignited World War I. No single party appeared likely to win a clear majority in Bosnia 's 240-seat bicameral parliament .
#
# TRUE (SET):  [['Sarajevo', 'Located_In', 'Bosnia'], ['Gavrilo Princip', 'Kill', 'Austrian Archduke Franz Ferdinand']]
# FALSE POSITIVE GENERATED: ['Bosnia', 'capital', 'Sarajevo']
# -----------------------------------------------
# TEXT: In 1817 , naturalist-author Henry David Thoreau was born in Concord , Mass .
#
# TRUE (SET):  [['Henry David Thoreau', 'Live_In', 'Concord , Mass']]
# FALSE POSITIVE GENERATED: ['Henry David Thoreau', 'Born', '1817']
# -----------------------------------------------
# TEXT: The nine sentences noting the spot where Dallas was settled are followed by this : ` ` On Nov. 22 , 1963 , the building gained national notoriety when Lee Harvey Oswald allegedly shot and killed President John F. Kennedy from a sixth floor window as the presidential motorcade passed the site. ' '
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'President John F. Kennedy']]
# FALSE POSITIVE GENERATED: ['John F. Kennedy', 'Assassination', 'Lee Harvey Oswald']
# -----------------------------------------------
# TEXT: It almost makes me want to laugh. ( Minoli ) Why ? ( Fini ) Bossi is a very strange character and his extreme envy has been demonstrated. ( passage omitted ) He tried to get votes from the south , those votes which he now despises so much , but the south sent him back to the valleys. ( Minoli ) You said that Bossi reminded you of Hitler trapped in his Berlin bunker , a man with delusions of grandeur and a tendency towards suicide .
#
# TRUE (SET):  [['Hitler', 'Live_In', 'Berlin']]
# FALSE POSITIVE GENERATED: ['Bossi', 'reminds_someone_of', 'Hitler']
# -----------------------------------------------
# TEXT: ` ` One thing I have learned over the past 17 months is that the truth is hard to find , and it remains so , ' ' said Mrs. Higgins , 37 , who is a major inthe Marine Corps and works at the Pentagon as a public information officer.
#
# TRUE (SET):  [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Pentagon']]
# FALSE POSITIVE GENERATED: ['Mrs. Higgins', 'Rank', 'Major']
# -----------------------------------------------
# TEXT: ` ` One thing I have learned over the past 17 months is that the truth is hard to find , and it remains so , ' ' said Mrs. Higgins , 37 , who is a major inthe Marine Corps and works at the Pentagon as a public information officer.
#
# TRUE (SET):  [['Mrs. Higgins', 'Work_For', 'Marine Corps'], ['Mrs. Higgins', 'Work_For', 'Pentagon']]
# FALSE POSITIVE GENERATED: ['Mrs. Higgins', 'Works_at', 'Pentagon']
# -----------------------------------------------
# TEXT: Sam Kadet of the corporate law firm of Skadden , Arps said Popeyes could give Church 's notice on Thursday that it planned to proceed with the takeover attempt and deliver the information to Church 's after five business days .
#
# TRUE (SET):  [['Sam Kadet', 'Work_For', 'Skadden , Arps']]
# FALSE POSITIVE GENERATED: ['Sam Kadet', 'Worked_For', 'Skadden, Arps']
# -----------------------------------------------
# TEXT: Yisrael Tal , one of the top military strategists in Israel , says the Arabs have reached a strategic balance with Israel through their acquisition of ground-to-ground missiles .
#
# TRUE (SET):  [['Yisrael Tal', 'Live_In', 'Israel'], ['Yisrael Tal', 'Live_In', 'Israel']]
# FALSE POSITIVE GENERATED: ['Yisrael Tal', 'Works_for', 'Israel Defense Forces']
# -----------------------------------------------
# TEXT: Some people in the United States are saying that Clinton " gave away " $12 billion to Russia -- this is the amount it is proposed to pay for uranium destined for U.S. nuclear electric power stations , which will be obtained from our nuclear warheads .
#
# TRUE (SET):  [['Clinton', 'Live_In', 'United States'], ['Clinton', 'Live_In', 'U.S.']]
# FALSE POSITIVE GENERATED: ['Clinton', 'President', 'Clinton']
# -----------------------------------------------
# TEXT: Guy M. Struve , the New York attorney representing Church 's , said he was disappointed and did not know when the chain would decide whether to appeal Thursday 's ruling .
#
# TRUE (SET):  [['Guy M. Struve', 'Live_In', 'New York'], ['Guy M. Struve', 'Work_For', "Church 's"]]
# FALSE POSITIVE GENERATED: ['Guy M. Struve', 'Worked_For', "Church's Chicken"]
# -----------------------------------------------
# TEXT: A golden future seemed assured when , at 25 , Ogdon shared top place with Soviet pianist Vladimir Ashkenazy in the piano section of the 1962 Moscow Tchaikovsky International Competition for young musicians.
#
# TRUE (SET):  [['Vladimir Ashkenazy', 'Live_In', 'Soviet']]
# FALSE POSITIVE GENERATED: ['Moscow Tchaikovsky International Competition for Young Musicians', 'Piano', 'Soviet Union']
# -----------------------------------------------
# TEXT: Illinois born Charlton Heston was a 27-year-old actor from Broadway and television when he arrived in Hollywood for a five-picture contract with Hal Wallis .
#
# TRUE (SET):  [['Charlton Heston', 'Live_In', 'Illinois']]
# FALSE POSITIVE GENERATED: ['Charlton Heston', 'Born', 'Illinois']
# -----------------------------------------------
# TEXT: The justices heard 60 minutes of arguments Wednesday on whether they will allow the execution of Johnny Paul Penry , 32 , a convicted rapist-murderer sentenced to die in Texas .
#
# TRUE (SET):  [['Johnny Paul Penry', 'Live_In', 'Texas']]
# FALSE POSITIVE GENERATED: ['Johnny Paul Penry', 'Sentenced_To_Death', 'Texas']
# -----------------------------------------------
# TEXT: 1911 , playwright Tennessee Williams was born in Columbus , Miss.
#
# TRUE (SET):  [['Tennessee Williams', 'Live_In', 'Columbus , Miss.']]
# FALSE POSITIVE GENERATED: ['Tennessee Williams', 'Born', '1911']
# -----------------------------------------------
# TEXT: BRISBANE , Australia ( AP )
#
# TRUE (SET):  [['BRISBANE', 'Located_In', 'Australia'], ['AP', 'OrgBased_In', 'BRISBANE'], ['AP', 'OrgBased_In', 'Australia']]
# FALSE POSITIVE GENERATED: ['BRISBANE', 'City', 'Brisbane']
# -----------------------------------------------
# TEXT: CNEN Radioprotection Director Laercio Vinhas yesterday reported by fax that the thyroid dysfunctions detected in the employees have no relation whatsoever with their work at the laboratory and that this problem is detected in 3 percent of the overall population .
#
# TRUE (SET):  [['Laercio Vinhas', 'Work_For', 'CNEN']]
# FALSE POSITIVE GENERATED: ['CNEN Radioprotection', 'Director', 'Laercio Vinhas']
# -----------------------------------------------
# TEXT: Photographer , author , filmmaker and composer Gordon Parks , 76 , born in Fort Scott , Kan. , who was on the photographic staff of Life Magazine for 19 years before branching out into other activities.
#
# TRUE (SET):  [['Gordon Parks', 'Live_In', 'Fort Scott , Kan.']]
# FALSE POSITIVE GENERATED: ['Gordon Parks', 'Born', 'Fort Scott, Kansas']
# -----------------------------------------------
# TEXT: In 1830 , poet Emily Dickinson was born in Amherst , Mass.
#
# TRUE (SET):  [['Emily Dickinson', 'Live_In', 'Amherst , Mass.']]
# FALSE POSITIVE GENERATED: ['Emily Dickinson', 'Born', '1830']
# -----------------------------------------------
# TEXT: ` ` This is not a good idea for a lot of environmental reasons , ' ' Stephanie Powell , of the DEM 's division of groundwater and freshwater wetlands , said Tuesday.
#
# TRUE (SET):  [['Stephanie Powell', 'Work_For', 'DEM']]
# FALSE POSITIVE GENERATED: ['Stephanie Powell', 'Works_For', 'Department of Environmental Management']
# -----------------------------------------------
# TEXT: Nihat ( Marka ) , deputy leader of SHP ( Social Democrat Populist Party ) parliamentary group , said : They should have run in the elections for the sake of democracy .
#
# TRUE (SET):  [['Nihat', 'Work_For', 'SHP'], ['Nihat', 'Work_For', 'Social Democrat Populist Party'], ['Marka', 'Work_For', 'SHP'], ['Marka', 'Work_For', 'Social Democrat Populist Party']]
# FALSE POSITIVE GENERATED: ['Nihat (Marka)', 'Worked_For', 'SHP (Social Democrat Populist Party) parliamentary group']
# -----------------------------------------------
# TEXT: A statement from military headquarters said the aircraft crashed during a 260-mile flight to Khartoum from Kassala in eastern Sudan near the Ethiopian border.
#
# TRUE (SET):  [['Kassala', 'Located_In', 'Sudan']]
# FALSE POSITIVE GENERATED: ['Khartoum', 'is_part_of', 'Khartoum Governorate']
# -----------------------------------------------
# TEXT: Harrington , a professor of political science at Queens College of the City University of New York and honorary president of the Socialist International , died Monday night at his home in suburban Larchmont , the university said in a statement Tuesday.
#
# TRUE (SET):  [['Harrington', 'Work_For', 'Queens College'], ['Harrington', 'Work_For', 'City University of New York'], ['Harrington', 'Work_For', 'Socialist International'], ['Harrington', 'Live_In', 'Larchmont']]
# FALSE POSITIVE GENERATED: ['Harrington', 'Worked_For', 'Queens College of the City University of New York']
# -----------------------------------------------
# TEXT: Norton Winfred Simon was born on Feb. 5 , 1907 , in Portland , Ore. , and spent his teen-age years in San Francisco .
#
# TRUE (SET):  [['Norton Winfred Simon', 'Live_In', 'Portland , Ore.']]
# FALSE POSITIVE GENERATED: ['Norton Winfred Simon', 'Born', '1907-02-05']
# -----------------------------------------------
# TEXT: The National Aeronautics and Space Administration announced Thursday that Ulf D. Merbold , 47 , of the European Space Agency and Roger K. Crouch of NASA have been chosen to train to perform materials sciences experiments on the International Microgravity Laboratory-1 mission scheduled for April 1991 .
#
# TRUE (SET):  [['Ulf D. Merbold', 'Work_For', 'European Space Agency'], ['Roger K. Crouch', 'Work_For', 'National Aeronautics and Space Administration'], ['Roger K. Crouch', 'Work_For', 'NASA']]
# FALSE POSITIVE GENERATED: ['International Microgravity Laboratory-1', 'Operator', 'NASA']
# -----------------------------------------------
# TEXT: The National Aeronautics and Space Administration announced Thursday that Ulf D. Merbold , 47 , of the European Space Agency and Roger K. Crouch of NASA have been chosen to train to perform materials sciences experiments on the International Microgravity Laboratory-1 mission scheduled for April 1991 .
#
# ...
#
# TRUE (SET):  [['Wang Guangyan', 'Work_For', 'Institute of Mathematics']]
# FALSE POSITIVE GENERATED: ["Riemann's multi-dimensional space", 'structure', 'Minimal surface']
# -----------------------------------------------
# TEXT: An abstract theory explaining the structure of minimal surface in Riemann 's multi-dimensional space has been developed by Wang Guangyan , with the assistance of his PhD student , at the Institute of Mathematics .
#
# TRUE (SET):  [['Wang Guangyan', 'Work_For', 'Institute of Mathematics']]
# FALSE POSITIVE GENERATED: ['Wang Guangyan', 'worked_for', 'Institute of Mathematics']
# -----------------------------------------------
# TEXT: Owen Le Vallee , president of the Liberation Day Committee , said his mother found a starving German in the outhouse during the year after D-Day , the 1944 Allied invasion of Europe.
#
# TRUE (SET):  [['Owen Le Vallee', 'Work_For', 'Liberation Day Committee']]
# FALSE POSITIVE GENERATED: ['Owen Le Vallee', 'Mother', 'Owen Le Vallee']
# -----------------------------------------------
# TEXT: Another beacon of the better life is Prateep Ungsongtham , known as the ` ` Slum Angel of Bangkok. ' '
#
# TRUE (SET):  [['Prateep Ungsongtham', 'Live_In', 'Bangkok.']]
# FALSE POSITIVE GENERATED: ['Prateep Ungsongtham', 'Known_as', 'Slum Angel of Bangkok']
# -----------------------------------------------
# TEXT: ( Text ) In an interview with Interfax the chief of Belarus 's Security Committee , Eduard Shirkovskiy , has dismissed rumors that the copies of the files relating to Lee Harvey Oswald , who was charged with having assassinated President John Kennedy , will be handed to President Bill Clinton during his visit to Minsk .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'President John Kennedy']]
# FALSE POSITIVE GENERATED: ['Interfax', 'Person', 'Eduard Shirkovskiy']
# -----------------------------------------------
# TEXT: Michael Henley Jr. , 10 , disappeared on a turkey hunt with his father in April 1988 in the mountains near their hometown of Grants , N.M. Ms. Calico , then 19 , disappeared five months later while bicycling on a country road near her hometown of Belen , N.M.
#
# TRUE (SET):  [['Michael Henley Jr.', 'Live_In', 'Grants'], ['Michael Henley Jr.', 'Live_In', 'N.M.'], ['Grants', 'Located_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'Belen'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Belen', 'Located_In', 'N.M.']]
# FALSE POSITIVE GENERATED: ['Michael Henley Jr.', 'Date_of_Death', '1988-04-26']
# -----------------------------------------------
# TEXT: Michael Henley Jr. , 10 , disappeared on a turkey hunt with his father in April 1988 in the mountains near their hometown of Grants , N.M. Ms. Calico , then 19 , disappeared five months later while bicycling on a country road near her hometown of Belen , N.M.
#
# TRUE (SET):  [['Michael Henley Jr.', 'Live_In', 'Grants'], ['Michael Henley Jr.', 'Live_In', 'N.M.'], ['Grants', 'Located_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'Belen'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Belen', 'Located_In', 'N.M.']]
# FALSE POSITIVE GENERATED: ['Michael Henley Jr.', 'Hometown', 'Grants, N.M.']
# -----------------------------------------------
# TEXT: Michael Henley Jr. , 10 , disappeared on a turkey hunt with his father in April 1988 in the mountains near their hometown of Grants , N.M. Ms. Calico , then 19 , disappeared five months later while bicycling on a country road near her hometown of Belen , N.M.
#
# TRUE (SET):  [['Michael Henley Jr.', 'Live_In', 'Grants'], ['Michael Henley Jr.', 'Live_In', 'N.M.'], ['Grants', 'Located_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'Belen'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Belen', 'Located_In', 'N.M.']]
# FALSE POSITIVE GENERATED: ['Michael Henley Jr.', 'Date_of_Death', '1988-04-26']
# -----------------------------------------------
# TEXT: Michael Henley Jr. , 10 , disappeared on a turkey hunt with his father in April 1988 in the mountains near their hometown of Grants , N.M. Ms. Calico , then 19 , disappeared five months later while bicycling on a country road near her hometown of Belen , N.M.
#
# TRUE (SET):  [['Michael Henley Jr.', 'Live_In', 'Grants'], ['Michael Henley Jr.', 'Live_In', 'N.M.'], ['Grants', 'Located_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Ms. Calico', 'Live_In', 'Belen'], ['Ms. Calico', 'Live_In', 'N.M.'], ['Belen', 'Located_In', 'N.M.']]
# FALSE POSITIVE GENERATED: ['Michael Henley Jr.', 'Cause', 'Disappearance']
# -----------------------------------------------
# TEXT: ( Text ) Moscow April 25 TASS -- Preliminary marine pollution measurements taken from the sites of radioactive waste dumping by the former Soviet Union and Japan in the Sea of Japan did not reveal any Caesium-137 radioactive level fluctuations .
#
# TRUE (SET):  [['TASS', 'OrgBased_In', 'Moscow']]
# FALSE POSITIVE GENERATED: ['Moscow', 'is_part_of', 'Russia']
# -----------------------------------------------
# TEXT: Police arrested 10 Spanish Basque militants , including Jose Antonio Urutigoechea , considered by Madrid to be a top leader of the Spanish Basque separatist organization ETA , authorities said today .
#
# TRUE (SET):  [['Jose Antonio Urutigoechea', 'Work_For', 'ETA']]
# FALSE POSITIVE GENERATED: ['ETA', 'Top_Leader', 'Jose Antonio Urutigoechea']
# -----------------------------------------------
# TEXT: The Warren Commission concluded that Oswald , acting alone , fired the shots that killed Kennedy and wounded John Connally , then the Texas governor .
#
# TRUE (SET):  [['Oswald', 'Kill', 'Kennedy']]
# FALSE POSITIVE GENERATED: ['John Connally', 'Killed', 'John F. Kennedy']
# -----------------------------------------------
# TEXT: The advisory committee voted 7-1 to recommend that the drug remain a prescription ingredient , said Susan Cruzan , an FDA spokeswoman.
#
# TRUE (SET):  [['Susan Cruzan', 'Work_For', 'FDA']]
# FALSE POSITIVE GENERATED: ['Susan Cruzan', 'Works_For', 'FDA']
# -----------------------------------------------
# TEXT: ` ` It 's been a nightmare , ' ' said Shelley Yeager , director of the Clara Barton camp at Oxford in central Massachusetts.
#
# TRUE (SET):  [['Oxford', 'Located_In', 'Massachusetts.']]
# FALSE POSITIVE GENERATED: ['Shelly Yeager', 'Works_for', 'Clara Barton Camp']
# -----------------------------------------------
# TEXT: Yeltsin Orders Audit of Ostankino Finances MK1401103094 Moscow MOSKOVSKIY KOMSOMOLETS in Russian 14 Jan 94 p 1
#
# TRUE (SET):  [['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']]
# FALSE POSITIVE GENERATED: ['Moscow Moskovskiy Kommunalete', 'language', 'Russian']
# -----------------------------------------------
# TEXT: Yeltsin Orders Audit of Ostankino Finances MK1401103094 Moscow MOSKOVSKIY KOMSOMOLETS in Russian 14 Jan 94 p 1
#
# TRUE (SET):  [['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']]
# FALSE POSITIVE GENERATED: ['Moscow Moskovskiy Kommunalete', 'date', '1994-01-14']
# -----------------------------------------------
# TEXT: In 1969 , Sirhan Sirhan was convicted of assassinating U.S. Sen. Robert F. Kennedy .
#
# TRUE (SET):  [['Sirhan Sirhan', 'Kill', 'U.S. Sen. Robert F. Kennedy']]
# FALSE POSITIVE GENERATED: ['Robert F. Kennedy', 'Assassination', '1969']
# -----------------------------------------------
# TEXT: MEXICO CITY ( AP )
#
# TRUE (SET):  [['AP', 'OrgBased_In', 'MEXICO CITY']]
# FALSE POSITIVE GENERATED: ['AP', 'Newspaper', 'Mexico City Herald']
# -----------------------------------------------
# TEXT: Tokyo MAINICHI SHIMBUN
#
# TRUE (SET):  [['MAINICHI SHIMBUN', 'OrgBased_In', 'Tokyo']]
# FALSE POSITIVE GENERATED: ['Mainichi Shimbun', 'City', 'Tokyo']
# -----------------------------------------------
# TEXT: If the elections had been held during the last 10 days of May , that is , after the debate , Fernandez de Cevallos would reportedly be the next president of Mexico with 33.2 percent of the vote .
#
# TRUE (SET):  [['Fernandez de Cevallos', 'Live_In', 'Mexico']]
# FALSE POSITIVE GENERATED: ['Fernandez de Cevallos', 'Percentage', '33.2']
# -----------------------------------------------
# TEXT: Meanwhile , the historical society in Beaumont , Texas , Richardson 's hometown , plans to raise two statues on Feb. 3 _ one of Buddy Holly , Richardson and Valens , and a second of the Big Bopper alone .
#
# TRUE (SET):  [['Richardson', 'Live_In', 'Beaumont , Texas']]
# FALSE POSITIVE GENERATED: ['Big Bopper', 'Death_Place', 'Beaumont, Texas']
# -----------------------------------------------
# TEXT: At a briefing at NRC headquarters in nearby Rockville , Md. , Bernero said the volcanic cones in the area of Yucca Mountain have been a cause of concern for NRC experts.
#
# TRUE (SET):  [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.'], ['Bernero', 'Work_For', 'NRC'], ['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.']]
# FALSE POSITIVE GENERATED: ['Rockville', 'is_part_of', 'Maryland']
# -----------------------------------------------
# TEXT: ( Text ) Saint-Gall , Switzerland , Feb 2 ( AFP ) -- The wreck of a twin-engine aircraft has been found 160 metres below the surface of Lake Constance , Swiss police said Tuesday ( 1 February ) .
#
# TRUE (SET):  [['Saint-Gall', 'Located_In', 'Switzerland'], ['AFP', 'OrgBased_In', 'Saint-Gall'], ['AFP', 'OrgBased_In', 'Switzerland']]
# FALSE POSITIVE GENERATED: ['Lake Constance', 'Number_Of_Passengers', '2']
# -----------------------------------------------
# TEXT: According to the communique , clashes are continuing mainly in the Rancho Nuevo area at the military base in the southern Chiapas State .
#
# TRUE (SET):  [['Rancho Nuevo', 'Located_In', 'Chiapas State']]
# FALSE POSITIVE GENERATED: ['Rancho Nuevo', 'Location', 'Mexico']
# -----------------------------------------------
# TEXT: Dallas police arrested Oswald there on Nov. 22 , 1963 , after the assassination of President John F. Kennedy .
#
# TRUE (SET):  [['Oswald', 'Kill', 'President John F. Kennedy']]
# FALSE POSITIVE GENERATED: ['Nov. 22', 'Year', 1963]
# -----------------------------------------------
# TEXT: In Washington state , near the Canadian border , firefighters hoped to contain an 850-acre fire by tonight , said Greg Thayer of the Forest Service.
#
# TRUE (SET):  [['Greg Thayer', 'Work_For', 'Forest Service.']]
# FALSE POSITIVE GENERATED: ['Greg Thayer', 'Worked_For', 'Forest Service']
# -----------------------------------------------
# TEXT: In an " electoral communique " signed by CNTP Secretary Luis Cobos R. , the organization said it hopes that with this decision " we will achieve the return of the Torrijist forces to power to stimulate the process of national liberation . "
#
# TRUE (SET):  [['Luis Cobos R.', 'Work_For', 'CNTP']]
# FALSE POSITIVE GENERATED: ['CNTP', 'Secretary', 'Luis Cobos R.']
# -----------------------------------------------
# TEXT: In it , actor Edwin Booth tells us his version of his life story , in which he and not his brother John Wilkes shoots Abraham Lincoln at Ford 's Theater .
#
# TRUE (SET):  [['John Wilkes', 'Kill', 'Abraham Lincoln']]
# FALSE POSITIVE GENERATED: ['Edwin Booth', 'Brother', 'John Wilkes Booth']
# -----------------------------------------------
# TEXT: In 1801 , Mormon leader Brigham Young was born in Whitingham , Vt .
#
# TRUE (SET):  [['Brigham Young', 'Live_In', 'Whitingham , Vt']]
# FALSE POSITIVE GENERATED: ['Brigham Young', 'Born', '1801']
# -----------------------------------------------
# TEXT: In 1801 , Mormon leader Brigham Young was born in Whitingham , Vt .
#
# TRUE (SET):  [['Brigham Young', 'Live_In', 'Whitingham , Vt']]
# FALSE POSITIVE GENERATED: ['Brigham Young', 'Born', 'Whitingham, Vermont']
# -----------------------------------------------
# TEXT: The Warren Commission concluded that Lee Harvey Oswald , acting alone , fired the shots that killed Kennedy and wounded John Connally , then the Texas governor , on Nov. 22 , 1963 in Dallas .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# FALSE POSITIVE GENERATED: ['John Connally', 'Killed', 'John F. Kennedy']
# -----------------------------------------------
# TEXT: The spilled fuel covered an area two miles long and nearly a half-mile wide , said Whitefish City Attorney Tom Muri.
#
# TRUE (SET):  [['Tom Muri.', 'Live_In', 'Whitefish City']]
# FALSE POSITIVE GENERATED: ['Whitefish City Attorney Tom Muri', 'Said', 'The spilled fuel covered an area two miles long and nearly a half-mile wide']
# -----------------------------------------------
# TEXT: In California 's Sierra Nevada foothills , firefighters today declared they had contained a fire that blackened 11 , 700 acres of brush and grassland and destroyed seven homes.
#
# TRUE (SET):  [['Sierra Nevada', 'Located_In', 'California']]
# FALSE POSITIVE GENERATED: ['11,700 acres', 'Total_acres', '11,700']
# -----------------------------------------------
# TEXT: In California 's Sierra Nevada foothills , firefighters today declared they had contained a fire that blackened 11 , 700 acres of brush and grassland and destroyed seven homes.
#
# TRUE (SET):  [['Sierra Nevada', 'Located_In', 'California']]
# FALSE POSITIVE GENERATED: ['11,700 acres', 'Location', 'Sierra Nevada foothills']
# -----------------------------------------------
# TEXT: " I was hearing the same story , " says James Hackett , an executive with Titan Systems and one of the leading missile experts in the U.S .
#
# TRUE (SET):  [['James Hackett', 'Work_For', 'Titan Systems'], ['James Hackett', 'Live_In', 'U.S .']]
# FALSE POSITIVE GENERATED: ['James Hackett', 'Works_For', 'Titan Systems']
# -----------------------------------------------
# TEXT: The quake leveled much of Leninakan , Armenia 's second-largest city 10 miles east of the Turkish border and left thousands homeless .
#
# TRUE (SET):  [['Leninakan', 'Located_In', 'Armenia']]
# FALSE POSITIVE GENERATED: ['Leninakan', 'is_part_of', 'Armenia']
# -----------------------------------------------
# TEXT: Pittsburgh-Corning Corp. of Pittsburgh ;
#
# TRUE (SET):  [['Pittsburgh-Corning Corp.', 'OrgBased_In', 'Pittsburgh']]
# FALSE POSITIVE GENERATED: ['Pittsburgh-Corning Corp.', 'City,', 'Pittsburgh']
# -----------------------------------------------
# TEXT: Barrett is a member of the Illinois Commerce Commission , and Marshall is a lawyer and former legislative aide to Patrick.
#
# TRUE (SET):  [['Barrett', 'Work_For', 'Illinois Commerce Commission']]
# FALSE POSITIVE GENERATED: ['Barrett Marshall', 'Office', 'Member of the Illinois Commerce Commission']
# -----------------------------------------------
# TEXT: Ten years ago : James Earl Ray , convicted of assassinating Dr. Martin Luther King Jr. in 1968 , repeated his assertion at a Capitol Hill hearing that he did not commit the crime , saying he 'd been set up to take the blame by a mysterious man called Raoul .
#
# TRUE (SET):  [['James Earl Ray', 'Kill', 'Dr. Martin Luther King Jr.']]
# FALSE POSITIVE GENERATED: ['James Earl Ray', 'Assassinates', 'Martin Luther King Jr.']
# -----------------------------------------------
# TEXT: They will also be cleaning the car Oswald drove on the day Kennedy was shot and the ambulance that took Oswald to hospital after he was shot by Jack Ruby .
#
# TRUE (SET):  [['Jack Ruby', 'Kill', 'Oswald']]
# FALSE POSITIVE GENERATED: ['Jack Ruby', 'killed', 'Leonid D. Kennedy']
# -----------------------------------------------
# TEXT: LD2804174994 Moscow INTERFAX in English 1601 GMT 28 Apr 94
#
# TRUE (SET):  [['INTERFAX', 'OrgBased_In', 'Moscow']]
# FALSE POSITIVE GENERATED: ['LD2804174994', 'language', 'English']
# -----------------------------------------------
# TEXT: LD2804174994 Moscow INTERFAX in English 1601 GMT 28 Apr 94
#
# TRUE (SET):  [['INTERFAX', 'OrgBased_In', 'Moscow']]
# FALSE POSITIVE GENERATED: ['LD2804174994', 'date', '1994-04-28']
# -----------------------------------------------
# TEXT: Navy sources said the Coral Sea , on duty with the 6th Fleet in the Mediterranean , left ` ` a few hours ' ' ahead of its scheduled departure.
#
# TRUE (SET):  [['6th Fleet', 'OrgBased_In', 'Mediterranean']]
# FALSE POSITIVE GENERATED: ['USS Coral Sea', 'on_duty_with', '6th Fleet']
# -----------------------------------------------

# %%
temp_df = pd.DataFrame({"text": text, "gen_fp": fp_list}, index=None)
temp_df.to_csv("fp_conll_flan_eval.csv", index=False)

# %%
fn = ()
fn_list = []
text = []
gen_list = []
for row in df.iterrows():
    for t_triplet in row[1]["true"]:
        flag = True
        if t_triplet in row[1]["generated"]:
            continue
        else:
            for g_triplet in row[1]["generated"]:
                if ((str(t_triplet[0]) in str(g_triplet[0])) or (str(g_triplet[0]) in str(t_triplet[0]))) and ((str(t_triplet[2]) in str(g_triplet[2])) or (str(g_triplet[2]) in str(t_triplet[2]))) and (str(t_triplet[1]) == str(g_triplet[1])):
                    flag = False
            if flag:
                text.append(row[1]["text"])
                fn_list.append(t_triplet)
                gen_list.append(str(row[1]["generated"]))
                fn += (t_triplet,)
                print (row[1]["text"] + "\n")
                print ("TRUE (SET): ", row[1]["true"])
                print ("GENERATED: " + str(row[1]["generated"]))
                print ("FALSE NEGATIVE: " + str(t_triplet))
                print ("-----------------------------------------------")
# Out:
# TEXT: John Wilkes Booth , who assassinated President Lincoln , was an actor .
#
# TRUE (SET):  [['John Wilkes Booth', 'Kill', 'President Lincoln']]
# GENERATED: [['John Wilkes Booth', 'Occupation', 'Actor']]
# FALSE NEGATIVE: ['John Wilkes Booth', 'Kill', 'President Lincoln']
# -----------------------------------------------
# TEXT: In the field of mechanics , Wang Ziqiang at the Institute of Mechanics has made considerable headway in the area of elastoplastic crack mechanics .
#
# TRUE (SET):  [['Wang Ziqiang', 'Work_For', 'Institute of Mechanics']]
# GENERATED: [['Wang Ziqiang', 'Works_at', 'Institute of Mechanics']]
# FALSE NEGATIVE: ['Wang Ziqiang', 'Work_For', 'Institute of Mechanics']
# -----------------------------------------------
# TEXT: Sun Hung Kai Properties , a Hong Kong construction firm with a 27 percent share ;
#
# TRUE (SET):  [['Sun Hung Kai Properties', 'OrgBased_In', 'Hong Kong']]
# GENERATED: [['Sun Hung Kai Properties', 'Type', 'Construction company']]
# FALSE NEGATIVE: ['Sun Hung Kai Properties', 'OrgBased_In', 'Hong Kong']
# -----------------------------------------------
# TEXT: Marie Magdefrau Ferraro , 50 , of Bethany , Conn. , was shot to death Thursday when two bandits armed with assault rifles emerged from nearby bushes and began firing at a van carrying a Connecticut Audubon Society wildlife wild tour group .
#
# TRUE (SET):  [['Marie Magdefrau Ferraro', 'Live_In', 'Bethany'], ['Marie Magdefrau Ferraro', 'Live_In', 'Conn.'], ['Bethany', 'Located_In', 'Conn.']]
# GENERATED: [['Marie Magdefrau Ferraro', 'Death_Place', 'Bethany, Connecticut']]
# FALSE NEGATIVE: ['Marie Magdefrau Ferraro', 'Live_In', 'Bethany']
# -----------------------------------------------
# TEXT: Marie Magdefrau Ferraro , 50 , of Bethany , Conn. , was shot to death Thursday when two bandits armed with assault rifles emerged from nearby bushes and began firing at a van carrying a Connecticut Audubon Society wildlife wild tour group .
#
# TRUE (SET):  [['Marie Magdefrau Ferraro', 'Live_In', 'Bethany'], ['Marie Magdefrau Ferraro', 'Live_In', 'Conn.'], ['Bethany', 'Located_In', 'Conn.']]
# GENERATED: [['Marie Magdefrau Ferraro', 'Death_Place', 'Bethany, Connecticut']]
# FALSE NEGATIVE: ['Marie Magdefrau Ferraro', 'Live_In', 'Conn.']
# -----------------------------------------------
# TEXT: Marie Magdefrau Ferraro , 50 , of Bethany , Conn. , was shot to death Thursday when two bandits armed with assault rifles emerged from nearby bushes and began firing at a van carrying a Connecticut Audubon Society wildlife wild tour group .
#
# TRUE (SET):  [['Marie Magdefrau Ferraro', 'Live_In', 'Bethany'], ['Marie Magdefrau Ferraro', 'Live_In', 'Conn.'], ['Bethany', 'Located_In', 'Conn.']]
# GENERATED: [['Marie Magdefrau Ferraro', 'Death_Place', 'Bethany, Connecticut']]
# FALSE NEGATIVE: ['Bethany', 'Located_In', 'Conn.']
# -----------------------------------------------
# TEXT: Ten oil workers were missing off Morgan City , La. , after their rig capsized while heading inland Monday to escape the storm.
#
# TRUE (SET):  [['Morgan City', 'Located_In', 'La.']]
# GENERATED: [['Morgan City', 'is_part_of', 'Louisiana']]
# FALSE NEGATIVE: ['Morgan City', 'Located_In', 'La.']
# -----------------------------------------------
# TEXT: Lightning ignited a firestorm that charred 10 , 000 acres in central Idaho , including much of the small resort town of Lowman , about 70 miles northeast of Boise.
#
# TRUE (SET):  [['Lowman', 'Located_In', 'Idaho']]
# GENERATED: [['Lowman', 'is_part_of', 'Idaho']]
# FALSE NEGATIVE: ['Lowman', 'Located_In', 'Idaho']
# -----------------------------------------------
# TEXT: " It ( Arrow ) is not practical in the short term , " says former Air Force commander Avihu Bin-Nun .
#
# TRUE (SET):  [['Avihu Bin-Nun', 'Work_For', 'Air Force']]
# GENERATED: [['Avihu Bin-Nun', 'Rank', 'General']]
# FALSE NEGATIVE: ['Avihu Bin-Nun', 'Work_For', 'Air Force']
# -----------------------------------------------
# TEXT: The three reactors , all at the Savannah River Plant , in Aiken , S.C. , have been shut down since last April undergoing changes to make them safer .
#
# TRUE (SET):  [['Savannah River Plant', 'Located_In', 'Aiken'], ['Savannah River Plant', 'Located_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# GENERATED: [['Savannah River Plant', 'located_in', 'Aiken, S.C.']]
# FALSE NEGATIVE: ['Savannah River Plant', 'Located_In', 'Aiken']
# -----------------------------------------------
# TEXT: The three reactors , all at the Savannah River Plant , in Aiken , S.C. , have been shut down since last April undergoing changes to make them safer .
#
# TRUE (SET):  [['Savannah River Plant', 'Located_In', 'Aiken'], ['Savannah River Plant', 'Located_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# GENERATED: [['Savannah River Plant', 'located_in', 'Aiken, S.C.']]
# FALSE NEGATIVE: ['Savannah River Plant', 'Located_In', 'S.C.']
# -----------------------------------------------
# TEXT: The three reactors , all at the Savannah River Plant , in Aiken , S.C. , have been shut down since last April undergoing changes to make them safer .
#
# TRUE (SET):  [['Savannah River Plant', 'Located_In', 'Aiken'], ['Savannah River Plant', 'Located_In', 'S.C.'], ['Aiken', 'Located_In', 'S.C.']]
# GENERATED: [['Savannah River Plant', 'located_in', 'Aiken, S.C.']]
# FALSE NEGATIVE: ['Aiken', 'Located_In', 'S.C.']
# -----------------------------------------------
# TEXT: Composer Thomas is a native of Chisholm , Minn .
#
# TRUE (SET):  [['Thomas', 'Live_In', 'Chisholm'], ['Thomas', 'Live_In', 'Minn .'], ['Chisholm', 'Located_In', 'Minn .']]
# GENERATED: [['Joseph Thomas', 'Born_in', 'Chisholm, Minnesota']]
# FALSE NEGATIVE: ['Thomas', 'Live_In', 'Chisholm']
# -----------------------------------------------
# TEXT: Composer Thomas is a native of Chisholm , Minn .
#
# TRUE (SET):  [['Thomas', 'Live_In', 'Chisholm'], ['Thomas', 'Live_In', 'Minn .'], ['Chisholm', 'Located_In', 'Minn .']]
# GENERATED: [['Joseph Thomas', 'Born_in', 'Chisholm, Minnesota']]
# FALSE NEGATIVE: ['Thomas', 'Live_In', 'Minn .']
# -----------------------------------------------
# TEXT: Composer Thomas is a native of Chisholm , Minn .
#
# TRUE (SET):  [['Thomas', 'Live_In', 'Chisholm'], ['Thomas', 'Live_In', 'Minn .'], ['Chisholm', 'Located_In', 'Minn .']]
# GENERATED: [['Joseph Thomas', 'Born_in', 'Chisholm, Minnesota']]
# FALSE NEGATIVE: ['Chisholm', 'Located_In', 'Minn .']
# -----------------------------------------------
# TEXT: Illinois Gov. James Thompson signed legislation last month scrapping Chicago 's central school board next July , to be replaced by parent-run councils empowered to set budgets and hire and fire principals .
#
# TRUE (SET):  [['James Thompson', 'Live_In', 'Illinois']]
# GENERATED: [['Chicago', 'Governor', 'James Thompson']]
# FALSE NEGATIVE: ['James Thompson', 'Live_In', 'Illinois']
# -----------------------------------------------
# TEXT: During the 10-hour rescue , diver Brian Michaud of Millinocket hooked the men to harnesses , and rescuers dragged them to the surface with winches .
#
# TRUE (SET):  [['Brian Michaud', 'Live_In', 'Millinocket']]
# GENERATED: [['Brian Michaud', 'Occupation', 'Scuba diver']]
# FALSE NEGATIVE: ['Brian Michaud', 'Live_In', 'Millinocket']
# -----------------------------------------------
# TEXT: The Warren Commission found Oswald acted alone in killing Kennedy .
#
# TRUE (SET):  [['Oswald', 'Kill', 'Kennedy']]
# GENERATED: [['Jack Ruby', 'Killing', 'John F. Kennedy'], ['John F. Kennedy', 'Assassination', 'John Lee Oswald'], ['John F. Kennedy', 'Assassination', 'Lyndon B. Johnson']]
# FALSE NEGATIVE: ['Oswald', 'Kill', 'Kennedy']
# -----------------------------------------------
# TEXT: ` ` He was going pretty fast , wasn 't he ? ' ' said Daniel Urquhart , 8 , of Aumsville , whose slug crept to the championship.
#
# TRUE (SET):  [['Daniel Urquhart', 'Live_In', 'Aumsville']]
# GENERATED: [['Daniel Urquhart', 'Age', 8]]
# FALSE NEGATIVE: ['Daniel Urquhart', 'Live_In', 'Aumsville']
# -----------------------------------------------
# TEXT: Kovacevic , a Serb , has come under fire from Serbian politicians and the republic 's press since the U.S. Congress last month passed two resolutions claiming there were human rights violations in the strife-torn southern province of Kosovo.
#
# TRUE (SET):  [['Congress', 'OrgBased_In', 'U.S.']]
# GENERATED: [['Kovacevic', 'Nationality', 'Serbian']]
# FALSE NEGATIVE: ['Congress', 'OrgBased_In', 'U.S.']
# -----------------------------------------------
# TEXT: Martin Luther King III , a son of the slain civil rights leader , said the execution of King assassin James Earl Ray ` ` would not bring my father back. ' '
#
# TRUE (SET):  [['James Earl Ray', 'Kill', 'Martin Luther King III']]
# GENERATED: [['Martin Luther King III', 'Son', 'Martin Luther King Jr.']]
# FALSE NEGATIVE: ['James Earl Ray', 'Kill', 'Martin Luther King III']
# -----------------------------------------------
# TEXT: On this date : In 1833 , Benjamin Harrison , the 23rd President of the United States , was born in North Bend , Ohio .
#
# TRUE (SET):  [['Benjamin Harrison', 'Live_In', 'North Bend , Ohio']]
# GENERATED: [['Benjamin Harrison', 'President', '23rd'], ['Benjamin Harrison', 'Born', '1833'], ['Benjamin Harrison', 'Born', 'North Bend, Ohio']]
# FALSE NEGATIVE: ['Benjamin Harrison', 'Live_In', 'North Bend , Ohio']
# -----------------------------------------------
# TEXT: The book said Khrushchev 's order to ignore the blockade was disclosed in a largely unknown work by dissident Soviet historian Roy Medvedev .
#
# TRUE (SET):  [['Khrushchev', 'Live_In', 'Soviet'], ['Roy Medvedev', 'Live_In', 'Soviet']]
# GENERATED: [['Khrushchev', 'Order_to_ignore', 'Blockade']]
# FALSE NEGATIVE: ['Khrushchev', 'Live_In', 'Soviet']
# -----------------------------------------------
# TEXT: The book said Khrushchev 's order to ignore the blockade was disclosed in a largely unknown work by dissident Soviet historian Roy Medvedev .
#
# TRUE (SET):  [['Khrushchev', 'Live_In', 'Soviet'], ['Roy Medvedev', 'Live_In', 'Soviet']]
# GENERATED: [['Khrushchev', 'Order_to_ignore', 'Blockade']]
# FALSE NEGATIVE: ['Roy Medvedev', 'Live_In', 'Soviet']
# -----------------------------------------------
# TEXT: EDITOR 'S NOTE : Walter R. Mears , vice and columnist for The Associated Press , has reported on Washington and national politics for more than 25 years .
#
# TRUE (SET):  [['Walter R. Mears', 'Work_For', 'The Associated Press']]
# GENERATED: [['Walter R. Mears', 'Works_for', 'The Associated Press']]
# FALSE NEGATIVE: ['Walter R. Mears', 'Work_For', 'The Associated Press']
# -----------------------------------------------
# TEXT: ` ` With South Carolina being Jesse Jackson 's home state , there was a very strong incentive in the black community. ' '
#
# TRUE (SET):  [['Jesse Jackson', 'Live_In', 'South Carolina']]
# GENERATED: [['Jesse Jackson', 'Hometown', 'South Carolina']]
# FALSE NEGATIVE: ['Jesse Jackson', 'Live_In', 'South Carolina']
# -----------------------------------------------
# TEXT: In a statement at the airport before his departure , Cetin said that Turkey welcomed this step taken by Bosnians and Croats and hoped that real peace comes to Bosnia-Herzegovina when Serbs join this process too .
#
# TRUE (SET):  [['Cetin', 'Live_In', 'Turkey']]
# GENERATED: [['Cetin', 'departure', 'at the airport before his departure']]
# FALSE NEGATIVE: ['Cetin', 'Live_In', 'Turkey']
# -----------------------------------------------
# TEXT: On Friday , U.S. Ambassador Vernon A. Walters displayed photographs of one Libyan jet showing shapes resembling missile pods on its wings and fuselage .
#
# TRUE (SET):  [['Vernon A. Walters', 'Live_In', 'U.S.']]
# GENERATED: [['Vernon A. Walters', 'Worked_For', 'United States']]
# FALSE NEGATIVE: ['Vernon A. Walters', 'Live_In', 'U.S.']
# -----------------------------------------------
# TEXT: Hernandez Galicia 's allegedly corrupt Mexican Oil Workers Union controls more than half the lucrative drilling contracts issued by the state oil monopoly , Pemex .
#
# TRUE (SET):  [['Hernandez Galicia', 'Work_For', 'Mexican Oil Workers Union']]
# GENERATED: [['Hernandez Galicia', 'Org', 'Mexican Oil Workers Union']]
# FALSE NEGATIVE: ['Hernandez Galicia', 'Work_For', 'Mexican Oil Workers Union']
# -----------------------------------------------
# TEXT: ` ` The Challenger accident marked a major change in the U.S. outlook and policies with respect to the flight of other than NASA astronauts , ' ' the National Aeronautics and Space Administration said in a policy statement .
#
# TRUE (SET):  [['NASA', 'OrgBased_In', 'U.S.'], ['National Aeronautics and Space Administration', 'OrgBased_In', 'U.S.']]
# GENERATED: [['NASA', 'Owner', 'United States']]
# FALSE NEGATIVE: ['NASA', 'OrgBased_In', 'U.S.']
# -----------------------------------------------
# TEXT: ` ` The Challenger accident marked a major change in the U.S. outlook and policies with respect to the flight of other than NASA astronauts , ' ' the National Aeronautics and Space Administration said in a policy statement .
#
# TRUE (SET):  [['NASA', 'OrgBased_In', 'U.S.'], ['National Aeronautics and Space Administration', 'OrgBased_In', 'U.S.']]
# GENERATED: [['NASA', 'Owner', 'United States']]
# FALSE NEGATIVE: ['National Aeronautics and Space Administration', 'OrgBased_In', 'U.S.']
# -----------------------------------------------
# TEXT: ` ` It 's not going to make you a whole bunch of money , but that 's not why we 're doing it , ' ' said Phil Fuhrer , vice of Gannett New Media. 1-900-WEATHER offers callers the current weather and a three-day forecast , plus skiing and highway conditions in the winter and coastal reports during the summer.
#
# TRUE (SET):  [['Phil Fuhrer', 'Work_For', 'Gannett New Media.']]
# GENERATED: [['1-900-Weather', 'Callers', 'the current weather and a three-day forecast']]
# FALSE NEGATIVE: ['Phil Fuhrer', 'Work_For', 'Gannett New Media.']
# -----------------------------------------------
# TEXT: PA2904034294 Guatemala City Teleonce Television in Spanish 0400 GMT 26 Apr 94
#
# TRUE (SET):  [['Teleonce Television', 'OrgBased_In', 'Guatemala City']]
# GENERATED: [['PA2904034294', 'Title', 'Guatemala City Teleonce Television in Spanish 0400 GMT 26 Apr 94']]
# FALSE NEGATIVE: ['Teleonce Television', 'OrgBased_In', 'Guatemala City']
# -----------------------------------------------
# TEXT: DAYTON , Ohio ( AP )
#
# TRUE (SET):  [['DAYTON', 'Located_In', 'Ohio'], ['AP', 'OrgBased_In', 'DAYTON'], ['AP', 'OrgBased_In', 'Ohio']]
# GENERATED: [['Dayton', 'is_part_of', 'Ohio']]
# FALSE NEGATIVE: ['DAYTON', 'Located_In', 'Ohio']
# -----------------------------------------------
# TEXT: DAYTON , Ohio ( AP )
#
# TRUE (SET):  [['DAYTON', 'Located_In', 'Ohio'], ['AP', 'OrgBased_In', 'DAYTON'], ['AP', 'OrgBased_In', 'Ohio']]
# GENERATED: [['Dayton', 'is_part_of', 'Ohio']]
# FALSE NEGATIVE: ['AP', 'OrgBased_In', 'DAYTON']
# -----------------------------------------------
# TEXT: DAYTON , Ohio ( AP )
#
# TRUE (SET):  [['DAYTON', 'Located_In', 'Ohio'], ['AP', 'OrgBased_In', 'DAYTON'], ['AP', 'OrgBased_In', 'Ohio']]
# GENERATED: [['Dayton', 'is_part_of', 'Ohio']]
# FALSE NEGATIVE: ['AP', 'OrgBased_In', 'Ohio']
# -----------------------------------------------
# TEXT: In 1865 , four people were hanged in Washington , D.C. , after being convicted of conspiring with John Wilkes Booth in the assassination of President Lincoln .
#
# TRUE (SET):  [['John Wilkes Booth', 'Kill', 'President Lincoln']]
# GENERATED: [['John Wilkes Booth', 'Assassination', 'Abraham Lincoln']]
# FALSE NEGATIVE: ['John Wilkes Booth', 'Kill', 'President Lincoln']
# -----------------------------------------------
# TEXT: San Gabriel River Channel , Azusa , Calif. ;
#
# TRUE (SET):  [['San Gabriel River Channel', 'Located_In', 'Azusa'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azusa', 'Located_In', 'Calif.']]
# GENERATED: [['San Gabriel River Channel', 'Location', 'Azusa, California']]
# FALSE NEGATIVE: ['San Gabriel River Channel', 'Located_In', 'Azusa']
# -----------------------------------------------
# TEXT: San Gabriel River Channel , Azusa , Calif. ;
#
# TRUE (SET):  [['San Gabriel River Channel', 'Located_In', 'Azusa'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azusa', 'Located_In', 'Calif.']]
# GENERATED: [['San Gabriel River Channel', 'Location', 'Azusa, California']]
# FALSE NEGATIVE: ['San Gabriel River Channel', 'Located_In', 'Calif.']
# -----------------------------------------------
# TEXT: San Gabriel River Channel , Azusa , Calif. ;
#
# TRUE (SET):  [['San Gabriel River Channel', 'Located_In', 'Azusa'], ['San Gabriel River Channel', 'Located_In', 'Calif.'], ['Azusa', 'Located_In', 'Calif.']]
# GENERATED: [['San Gabriel River Channel', 'Location', 'Azusa, California']]
# FALSE NEGATIVE: ['Azusa', 'Located_In', 'Calif.']
# -----------------------------------------------
# TEXT: Derwinski , a Republican from Chicago who served 24 years in Congress , publicly denied 1978 allegations that he leaked the information and refused to testify in the matter before a federal grand jury and the House Ethics Committee .
#
# TRUE (SET):  [['Derwinski', 'Live_In', 'Chicago'], ['Derwinski', 'Work_For', 'Congress']]
# GENERATED: [['Derwinski', 'Office', 'Congressman']]
# FALSE NEGATIVE: ['Derwinski', 'Live_In', 'Chicago']
# -----------------------------------------------
# TEXT: Derwinski , a Republican from Chicago who served 24 years in Congress , publicly denied 1978 allegations that he leaked the information and refused to testify in the matter before a federal grand jury and the House Ethics Committee .
#
# TRUE (SET):  [['Derwinski', 'Live_In', 'Chicago'], ['Derwinski', 'Work_For', 'Congress']]
# GENERATED: [['Derwinski', 'Office', 'Congressman']]
# FALSE NEGATIVE: ['Derwinski', 'Work_For', 'Congress']
# -----------------------------------------------
# TEXT: ( Text ) Police Major Pramot Pansakun , the commander of the Region 2 Border Patrol Police ( BPP ) , Khon Kaen , and Thai and American narcotics suppression officials accompanied by reporters , spent more than 2 hours climbing a high mountain to destroy a Hmong poppy field located along the border between Dan Sai District in Loei Province , Nakhon Thai District in Phitsanulok Province , and Lomsak District in Phetchabun Province .
#
# TRUE (SET):  [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Dan Sai District', 'Located_In', 'Loei Province'], ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province'], ['Lomsak District', 'Located_In', 'Phetchabun Province']]
# GENERATED: [['Pamot Pansakun', 'Officer', 'Border Patrol Police (BPP)']]
# FALSE NEGATIVE: ['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police']
# -----------------------------------------------
# TEXT: ( Text ) Police Major Pramot Pansakun , the commander of the Region 2 Border Patrol Police ( BPP ) , Khon Kaen , and Thai and American narcotics suppression officials accompanied by reporters , spent more than 2 hours climbing a high mountain to destroy a Hmong poppy field located along the border between Dan Sai District in Loei Province , Nakhon Thai District in Phitsanulok Province , and Lomsak District in Phetchabun Province .
#
# TRUE (SET):  [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Dan Sai District', 'Located_In', 'Loei Province'], ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province'], ['Lomsak District', 'Located_In', 'Phetchabun Province']]
# GENERATED: [['Pamot Pansakun', 'Officer', 'Border Patrol Police (BPP)']]
# FALSE NEGATIVE: ['Dan Sai District', 'Located_In', 'Loei Province']
# -----------------------------------------------
# TEXT: ( Text ) Police Major Pramot Pansakun , the commander of the Region 2 Border Patrol Police ( BPP ) , Khon Kaen , and Thai and American narcotics suppression officials accompanied by reporters , spent more than 2 hours climbing a high mountain to destroy a Hmong poppy field located along the border between Dan Sai District in Loei Province , Nakhon Thai District in Phitsanulok Province , and Lomsak District in Phetchabun Province .
#
# TRUE (SET):  [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Dan Sai District', 'Located_In', 'Loei Province'], ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province'], ['Lomsak District', 'Located_In', 'Phetchabun Province']]
# GENERATED: [['Pamot Pansakun', 'Officer', 'Border Patrol Police (BPP)']]
# FALSE NEGATIVE: ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province']
# -----------------------------------------------
# TEXT: ( Text ) Police Major Pramot Pansakun , the commander of the Region 2 Border Patrol Police ( BPP ) , Khon Kaen , and Thai and American narcotics suppression officials accompanied by reporters , spent more than 2 hours climbing a high mountain to destroy a Hmong poppy field located along the border between Dan Sai District in Loei Province , Nakhon Thai District in Phitsanulok Province , and Lomsak District in Phetchabun Province .
#
# TRUE (SET):  [['Pramot Pansakun', 'Work_For', 'Region 2 Border Patrol Police'], ['Dan Sai District', 'Located_In', 'Loei Province'], ['Nakhon Thai District', 'Located_In', 'Phitsanulok Province'], ['Lomsak District', 'Located_In', 'Phetchabun Province']]
# GENERATED: [['Pamot Pansakun', 'Officer', 'Border Patrol Police (BPP)']]
# FALSE NEGATIVE: ['Lomsak District', 'Located_In', 'Phetchabun Province']
# -----------------------------------------------
# TEXT: Further buying was linked to rumors that the Chilean copper company Codelco was considering shutting down its smelter at Chuquicamata , the world 's largest copper mine , due to persistent mechanical problems , said Fred Demler , metals economist with Drexel Burnham Lambert Inc. in New York .
#
# TRUE (SET):  [['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.'], ['Fred Demler', 'Live_In', 'New York'], ['Drexel Burnham Lambert Inc.', 'OrgBased_In', 'New York']]
# GENERATED: [['Drexel Burnham Lambert Inc.', 'City', 'New York']]
# FALSE NEGATIVE: ['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.']
# -----------------------------------------------
# TEXT: Further buying was linked to rumors that the Chilean copper company Codelco was considering shutting down its smelter at Chuquicamata , the world 's largest copper mine , due to persistent mechanical problems , said Fred Demler , metals economist with Drexel Burnham Lambert Inc. in New York .
#
# TRUE (SET):  [['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.'], ['Fred Demler', 'Live_In', 'New York'], ['Drexel Burnham Lambert Inc.', 'OrgBased_In', 'New York']]
# GENERATED: [['Drexel Burnham Lambert Inc.', 'City', 'New York']]
# FALSE NEGATIVE: ['Fred Demler', 'Live_In', 'New York']
# -----------------------------------------------
# TEXT: Further buying was linked to rumors that the Chilean copper company Codelco was considering shutting down its smelter at Chuquicamata , the world 's largest copper mine , due to persistent mechanical problems , said Fred Demler , metals economist with Drexel Burnham Lambert Inc. in New York .
#
# TRUE (SET):  [['Fred Demler', 'Work_For', 'Drexel Burnham Lambert Inc.'], ['Fred Demler', 'Live_In', 'New York'], ['Drexel Burnham Lambert Inc.', 'OrgBased_In', 'New York']]
# GENERATED: [['Drexel Burnham Lambert Inc.', 'City', 'New York']]
# FALSE NEGATIVE: ['Drexel Burnham Lambert Inc.', 'OrgBased_In', 'New York']
# -----------------------------------------------
# TEXT: An urgent call for international help to avert food shortages in Poland went out both from last month 's Western economic summit in Paris and from Monday 's meeting in Brussels of 24 concerned nations chaired by the European Community Commission.
#
# TRUE (SET):  [['European Community Commission.', 'OrgBased_In', 'Brussels']]
# GENERATED: [['Paris', 'City', 'Brussels']]
# FALSE NEGATIVE: ['European Community Commission.', 'OrgBased_In', 'Brussels']
# -----------------------------------------------
# TEXT: Cheek , 53 , is a former chief and charge in Addis Ababa , Ethiopia.
#
# TRUE (SET):  [['Addis Ababa', 'Located_In', 'Ethiopia.']]
# GENERATED: [['Cheek', 'Office', 'Addis Ababa']]
# FALSE NEGATIVE: ['Addis Ababa', 'Located_In', 'Ethiopia.']
# -----------------------------------------------
# TEXT: In 1881 , President James A. Garfield was shot by Charles J. Guiteau , a disappointed office-seeker , at the Washington railroad station .
#
# TRUE (SET):  [['Charles J. Guiteau', 'Kill', 'President James A. Garfield']]
# GENERATED: [['James A. Garfield', 'Assassination', 'Charles J. Guiteau']]
# FALSE NEGATIVE: ['Charles J. Guiteau', 'Kill', 'President James A. Garfield']
# -----------------------------------------------
# TEXT: Middle-class Argentines , among the most affluent in Latin America at one time , are so strapped now that they are selling off heirlooms that had been in their families since the days when beef and grain made Argentina one of the world 's wealthiest nations.
#
# TRUE (SET):  [['Argentina', 'Located_In', 'Latin America']]
# GENERATED: [['Argentina', 'is_part_of', 'Latin America']]
# FALSE NEGATIVE: ['Argentina', 'Located_In', 'Latin America']
# -----------------------------------------------
# TEXT: ` ` I don 't think there are any good answers why , ' ' said Virginia Towle of Wallingford , a family friend.
#
# TRUE (SET):  [['Virginia Towle', 'Live_In', 'Wallingford']]
# GENERATED: [['Virginia Towle', 'Friend', 'Wallingford']]
# FALSE NEGATIVE: ['Virginia Towle', 'Live_In', 'Wallingford']
# -----------------------------------------------
# TEXT: The meeting will be held at the request of the Soviet Union , which also plans direct talks with resistance leader Prince Norodom Sihanouk , said Sihanouk 's son and representative in Thailand , Prince Norodom Ranariddh .
#
# TRUE (SET):  [['Prince Norodom Ranariddh', 'Live_In', 'Thailand']]
# GENERATED: [['Norodom Ranariddh', 'Son', 'Norodom Sihanouk']]
# FALSE NEGATIVE: ['Prince Norodom Ranariddh', 'Live_In', 'Thailand']
# -----------------------------------------------
# TEXT: Hundreds of children and adults sporting cowboy boots and hats turned out Wednesday to watch as Winterset 's busiest street was named for John Wayne , the community 's most famous native son .
#
# TRUE (SET):  [['John Wayne', 'Live_In', 'Winterset']]
# GENERATED: [['John Wayne', 'Native_Son', 'Winterset, Iowa']]
# FALSE NEGATIVE: ['John Wayne', 'Live_In', 'Winterset']
# -----------------------------------------------
# TEXT: Police Find No Signs of Radiation Leak AU0202111694 Paris AFP in English 0107 GMT 2 Feb 94
#
# TRUE (SET):  [['AFP', 'OrgBased_In', 'Paris']]
# GENERATED: [['Paris AFP', 'language', 'English']]
# FALSE NEGATIVE: ['AFP', 'OrgBased_In', 'Paris']
# -----------------------------------------------
# TEXT: The self-propelled rig Avco 5 with 14 people aboard was headed to shore early Monday when it capsized about 20 miles off the Louisiana coast , near Morgan City , Chevron spokesman Jonathan Lifa said.
#
# TRUE (SET):  [['Jonathan Lifa', 'Work_For', 'Chevron']]
# GENERATED: [['Avco 5', 'Capsule_name', 'Avco 5']]
# FALSE NEGATIVE: ['Jonathan Lifa', 'Work_For', 'Chevron']
# -----------------------------------------------
# TEXT: Sen. Jake Garn , R-Utah , flew on the shuttle in April 1985 and Rep. Bill Nelson , D-Fla. , was aboard in January 1986 , at the invitation of NASA 's administrator .
#
# TRUE (SET):  [['Jake Garn', 'Work_For', 'NASA'], ['Bill Nelson', 'Work_For', 'NASA']]
# GENERATED: [['Jake Garn', 'Officer', 'NASA Administrator'], ['Bill Nelson', 'Officer', 'NASA Administrator'], ['Jake Garn', 'Officer', 'Congressman']]
# FALSE NEGATIVE: ['Jake Garn', 'Work_For', 'NASA']
# -----------------------------------------------
# TEXT: Sen. Jake Garn , R-Utah , flew on the shuttle in April 1985 and Rep. Bill Nelson , D-Fla. , was aboard in January 1986 , at the invitation of NASA 's administrator .
#
# TRUE (SET):  [['Jake Garn', 'Work_For', 'NASA'], ['Bill Nelson', 'Work_For', 'NASA']]
# GENERATED: [['Jake Garn', 'Officer', 'NASA Administrator'], ['Bill Nelson', 'Officer', 'NASA Administrator'], ['Jake Garn', 'Officer', 'Congressman']]
# FALSE NEGATIVE: ['Bill Nelson', 'Work_For', 'NASA']
# -----------------------------------------------
# TEXT: Ten Soviet volunteers and their American counterparts plan to spend August in Washington building homes for the poor as a return favor for help in earthquake-devastated Soviet Armenia.
#
# TRUE (SET):  [['Armenia.', 'Located_In', 'Soviet']]
# GENERATED: [['Washington', 'has_a_river_name', 'Washington River']]
# FALSE NEGATIVE: ['Armenia.', 'Located_In', 'Soviet']
# -----------------------------------------------
# TEXT: Evaluating Juppe 's visit , Cetin said that the French Government was not displaying a disturbing stand toward Turkey and was very careful in not intervening in Turkey 's internal affairs .
#
# TRUE (SET):  [['Juppe', 'Work_For', 'French Government'], ['Cetin', 'Live_In', 'Turkey'], ['Cetin', 'Live_In', 'Turkey']]
# GENERATED: [['Cetin', 'Visitor', 'Juppe']]
# FALSE NEGATIVE: ['Juppe', 'Work_For', 'French Government']
# -----------------------------------------------
# TEXT: Evaluating Juppe 's visit , Cetin said that the French Government was not displaying a disturbing stand toward Turkey and was very careful in not intervening in Turkey 's internal affairs .
#
# TRUE (SET):  [['Juppe', 'Work_For', 'French Government'], ['Cetin', 'Live_In', 'Turkey'], ['Cetin', 'Live_In', 'Turkey']]
# GENERATED: [['Cetin', 'Visitor', 'Juppe']]
# FALSE NEGATIVE: ['Cetin', 'Live_In', 'Turkey']
# -----------------------------------------------
# TEXT: Evaluating Juppe 's visit , Cetin said that the French Government was not displaying a disturbing stand toward Turkey and was very careful in not intervening in Turkey 's internal affairs .
#
# TRUE (SET):  [['Juppe', 'Work_For', 'French Government'], ['Cetin', 'Live_In', 'Turkey'], ['Cetin', 'Live_In', 'Turkey']]
# GENERATED: [['Cetin', 'Visitor', 'Juppe']]
# FALSE NEGATIVE: ['Cetin', 'Live_In', 'Turkey']
# -----------------------------------------------
# TEXT: Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# GENERATED: [['Jose Vicente Maldonado', 'Office', 'Minister of Industry, Commerce and Integration']]
# FALSE NEGATIVE: ['Andean Group', 'OrgBased_In', 'Colombia']
# -----------------------------------------------
# TEXT: Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# GENERATED: [['Jose Vicente Maldonado', 'Office', 'Minister of Industry, Commerce and Integration']]
# FALSE NEGATIVE: ['Andean Group', 'OrgBased_In', 'Bolivia']
# -----------------------------------------------
# TEXT: Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# GENERATED: [['Jose Vicente Maldonado', 'Office', 'Minister of Industry, Commerce and Integration']]
# FALSE NEGATIVE: ['Andean Group', 'OrgBased_In', 'Ecuador']
# -----------------------------------------------
# TEXT: Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# GENERATED: [['Jose Vicente Maldonado', 'Office', 'Minister of Industry, Commerce and Integration']]
# FALSE NEGATIVE: ['Andean Group', 'OrgBased_In', 'Peru']
# -----------------------------------------------
# TEXT: Jose Vicente Maldonado , the Ecuadoran minister of industry , commerce , and integration , said that the foreign of the Andean Group ( Colombia , Bolivia , Ecuador , Peru , and Venezuela ) , will study a new date for the summit .
#
# TRUE (SET):  [['Andean Group', 'OrgBased_In', 'Colombia'], ['Andean Group', 'OrgBased_In', 'Bolivia'], ['Andean Group', 'OrgBased_In', 'Ecuador'], ['Andean Group', 'OrgBased_In', 'Peru'], ['Andean Group', 'OrgBased_In', 'Venezuela']]
# GENERATED: [['Jose Vicente Maldonado', 'Office', 'Minister of Industry, Commerce and Integration']]
# FALSE NEGATIVE: ['Andean Group', 'OrgBased_In', 'Venezuela']
# -----------------------------------------------
# TEXT: Dole 's wife , Elizabeth , is a native of Salisbury , N.C .
#
# TRUE (SET):  [['Elizabeth', 'Live_In', 'Salisbury , N.C']]
# GENERATED: [['Elizabeth Dole', 'Native_name', 'Salisbury, N.C.']]
# FALSE NEGATIVE: ['Elizabeth', 'Live_In', 'Salisbury , N.C']
# -----------------------------------------------
# TEXT: ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# GENERATED: [['Bulgarian Socialist Party', 'former_name', 'Bulgarian Communist Party']]
# FALSE NEGATIVE: ['BTA', 'OrgBased_In', 'Sofia']
# -----------------------------------------------
# TEXT: ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# GENERATED: [['Bulgarian Socialist Party', 'former_name', 'Bulgarian Communist Party']]
# FALSE NEGATIVE: ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria']
# -----------------------------------------------
# TEXT: ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# GENERATED: [['Bulgarian Socialist Party', 'former_name', 'Bulgarian Communist Party']]
# FALSE NEGATIVE: ['BSP', 'OrgBased_In', 'Bulgaria']
# -----------------------------------------------
# TEXT: ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# GENERATED: [['Bulgarian Socialist Party', 'former_name', 'Bulgarian Communist Party']]
# FALSE NEGATIVE: ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria']
# -----------------------------------------------
# TEXT: ( Text ) Sofia , February 15 ( BTA ) -- Today the two main political forces in Bulgaria , the Bulgarian Socialist ( formerly Communist ) Party ( BSP ) and the Union of Democratic Forces ( SDS ) announced their stand on the possible airstrikes in Bosnia five days before the expiry of NATO 's ultimatum .
#
# TRUE (SET):  [['BTA', 'OrgBased_In', 'Sofia'], ['Bulgarian Socialist ( formerly Communist ) Party', 'OrgBased_In', 'Bulgaria'], ['BSP', 'OrgBased_In', 'Bulgaria'], ['Union of Democratic Forces', 'OrgBased_In', 'Bulgaria'], ['SDS', 'OrgBased_In', 'Bulgaria']]
# GENERATED: [['Bulgarian Socialist Party', 'former_name', 'Bulgarian Communist Party']]
# FALSE NEGATIVE: ['SDS', 'OrgBased_In', 'Bulgaria']
# -----------------------------------------------
# TEXT: Starr , who served as counselor to Attorney William French Smith from 1981 prior to taking the bench in 1983 , had been mentioned as a possible Supreme Court nominee after his former colleague on the District of Columbia circuit , Robert Bork , failed to win Senate confirmation in 1987 .
#
# TRUE (SET):  [['Supreme Court', 'OrgBased_In', 'District of Columbia'], ['Senate', 'OrgBased_In', 'District of Columbia']]
# GENERATED: [['Robert Bork', 'Years_on_the_Supreme_Court', '1987']]
# FALSE NEGATIVE: ['Supreme Court', 'OrgBased_In', 'District of Columbia']
# -----------------------------------------------
# TEXT: Starr , who served as counselor to Attorney William French Smith from 1981 prior to taking the bench in 1983 , had been mentioned as a possible Supreme Court nominee after his former colleague on the District of Columbia circuit , Robert Bork , failed to win Senate confirmation in 1987 .
#
# TRUE (SET):  [['Supreme Court', 'OrgBased_In', 'District of Columbia'], ['Senate', 'OrgBased_In', 'District of Columbia']]
# GENERATED: [['Robert Bork', 'Years_on_the_Supreme_Court', '1987']]
# FALSE NEGATIVE: ['Senate', 'OrgBased_In', 'District of Columbia']
# -----------------------------------------------
# TEXT: The program , financed with a grant from the United States Agency for International Development , is aimed at reducing infant mortality in Madagascar , an island nation in the Indian Ocean off the eastern coast of Africa.
#
# TRUE (SET):  [['Madagascar', 'Located_In', 'Indian Ocean']]
# GENERATED: [['Madagascar', 'island', 'Madagascar']]
# FALSE NEGATIVE: ['Madagascar', 'Located_In', 'Indian Ocean']
# -----------------------------------------------
# TEXT: JN0704183294 Paris Radio Monte Carlo in Arabic 1700 GMT 7 Apr 94
#
# TRUE (SET):  [['Radio Monte Carlo', 'OrgBased_In', 'Paris']]
# GENERATED: [['Paris Radio Monte Carlo in Arabic', 'Title', '7 Apr 94']]
# FALSE NEGATIVE: ['Radio Monte Carlo', 'OrgBased_In', 'Paris']
# -----------------------------------------------
# TEXT: On this date : In 1533 , the last Incan King of Peru , Atahualpa , was murdered on the orders of Spanish conqueror Francisco Pizarro .
#
# TRUE (SET):  [['Francisco Pizarro', 'Kill', 'Atahualpa']]
# GENERATED: [['Atahualpa', 'Kingdom', 'Peru']]
# FALSE NEGATIVE: ['Francisco Pizarro', 'Kill', 'Atahualpa']
# -----------------------------------------------
# TEXT: ` ` We 'd play hearts for hours at a time , ' ' said Atlanta businessman Neil Estes.
#
# TRUE (SET):  [['Neil Estes.', 'Live_In', 'Atlanta']]
# GENERATED: [['Neil Estes', 'Occupation', 'Businessman']]
# FALSE NEGATIVE: ['Neil Estes.', 'Live_In', 'Atlanta']
# -----------------------------------------------
# TEXT: ` ` This is really hurting Heuchelheim , ' ' the town 's mayor Willi Marx told The Associated Press in an interview at his office earlier this month .
#
# TRUE (SET):  [['Willi Marx', 'Live_In', 'Heuchelheim']]
# GENERATED: [['Willy Marx', 'Works_For', 'Associated Press']]
# FALSE NEGATIVE: ['Willi Marx', 'Live_In', 'Heuchelheim']
# -----------------------------------------------
# TEXT: ` ` I think at this moment they fear making a wrong move _ whether they should seek political asylum or use other reasons to remain here , ' ' said Jeff Shia , president of the Kiangsu Chekiang Association , a non-profit group that helps new Chinese immigrants establish themselves in the city.
#
# TRUE (SET):  [['Jeff Shia', 'Work_For', 'Kiangsu Chekiang Association']]
# GENERATED: [['Jeff Shia', 'Works_for', 'Kiangsu Chekiang Association']]
# FALSE NEGATIVE: ['Jeff Shia', 'Work_For', 'Kiangsu Chekiang Association']
# -----------------------------------------------
# TEXT: The term ` ` 30 Seconds Over Tokyo ' ' was the title of a popular movie about the raid. _Anzio _ The Anzio beachhead , 33 miles south of Rome , saw some of the bloodiest fighting of World War II and accounted for many of the 10 , 000 U.S. battle deaths in Italy the first half of 1944 .
#
# TRUE (SET):  [['Anzio', 'Located_In', 'Italy']]
# GENERATED: [['30 Seconds Over Tokyo', 'Movie', '30 Seconds Over Tokyo']]
# FALSE NEGATIVE: ['Anzio', 'Located_In', 'Italy']
# -----------------------------------------------
# TEXT: Anna Sandhu Ray , who 10 years ago Thursday wed the man convicted of killing the Rev. Martin Luther King Jr. , said on her anniversary that she plans to divorce James Earl Ray .
#
# TRUE (SET):  [['James Earl Ray', 'Kill', 'Rev. Martin Luther King Jr.']]
# GENERATED: [['Anna Sandhu Ray', 'Spouse', 'James Earl Ray']]
# FALSE NEGATIVE: ['James Earl Ray', 'Kill', 'Rev. Martin Luther King Jr.']
# -----------------------------------------------
# TEXT: The 23-foot-tall statue was modeled after the 30-foot-tall Goddess of Democracy raised by Chinese pro-democracy demonstrators in Beijing 's Tiananmen Square on May 30.
#
# TRUE (SET):  [['Tiananmen Square', 'Located_In', 'Beijing']]
# GENERATED: [['Goddess of Democracy', 'Size', '30 ft.'], ['Goddess of Democracy', 'Statue', '23 ft.'], ['Goddess of Democracy', 'Statue', 'Beijing']]
# FALSE NEGATIVE: ['Tiananmen Square', 'Located_In', 'Beijing']
# -----------------------------------------------
# TEXT: ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
#
# TRUE (SET):  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# GENERATED: [['Li Peng', 'Office', "Premier of the People's Republic of China"], ['P. Jasray', 'Office', 'Prime Minister of Mongolia']]
# FALSE NEGATIVE: ['XINHUA', 'OrgBased_In', 'China']
# -----------------------------------------------
# TEXT: ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
#
# TRUE (SET):  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# GENERATED: [['Li Peng', 'Office', "Premier of the People's Republic of China"], ['P. Jasray', 'Office', 'Prime Minister of Mongolia']]
# FALSE NEGATIVE: ['XINHUA', 'OrgBased_In', "People 's Republic of China"]
# -----------------------------------------------
# TEXT: ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
#
# TRUE (SET):  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# GENERATED: [['Li Peng', 'Office', "Premier of the People's Republic of China"], ['P. Jasray', 'Office', 'Prime Minister of Mongolia']]
# FALSE NEGATIVE: ['Li Peng', 'Live_In', 'China']
# -----------------------------------------------
# TEXT: ( Text ) Ulaanbaatar , 29 Apr ( XINHUA ) -- China 's Premier Li Peng and Mongolian Prime P. Jasray signed the " Treaty of Friendly Cooperation Relations Between the People 's Republic of China and Mongolia " at the State Palace in the afternoon of 29 April .
#
# TRUE (SET):  [['XINHUA', 'OrgBased_In', 'China'], ['XINHUA', 'OrgBased_In', "People 's Republic of China"], ['Li Peng', 'Live_In', 'China'], ['Li Peng', 'Live_In', "People 's Republic of China"]]
# GENERATED: [['Li Peng', 'Office', "Premier of the People's Republic of China"], ['P. Jasray', 'Office', 'Prime Minister of Mongolia']]
# FALSE NEGATIVE: ['Li Peng', 'Live_In', "People 's Republic of China"]
# -----------------------------------------------
# TEXT: ( Text ) The Rwandan Patriotic Front ( RPF ) has rescued 2 , 000 people in Bugesera in the southeastern part of Rwanda .
#
# TRUE (SET):  [['Bugesera', 'Located_In', 'Rwanda']]
# GENERATED: [['Bugesera', 'Part', 'Southeastern part of Rwanda']]
# FALSE NEGATIVE: ['Bugesera', 'Located_In', 'Rwanda']
# -----------------------------------------------
# TEXT: One of Warner 's lawyers , Andrew Hall of Miami , Fla. , confirmed Tuesday that Warner is trying to settle the case.
#
# TRUE (SET):  [['Andrew Hall', 'Live_In', 'Miami'], ['Andrew Hall', 'Live_In', 'Fla.'], ['Miami', 'Located_In', 'Fla.']]
# GENERATED: [['Andrew Hall', 'WorkedFor', 'Warner Bros.']]
# FALSE NEGATIVE: ['Andrew Hall', 'Live_In', 'Miami']
# -----------------------------------------------
# TEXT: One of Warner 's lawyers , Andrew Hall of Miami , Fla. , confirmed Tuesday that Warner is trying to settle the case.
#
# TRUE (SET):  [['Andrew Hall', 'Live_In', 'Miami'], ['Andrew Hall', 'Live_In', 'Fla.'], ['Miami', 'Located_In', 'Fla.']]
# GENERATED: [['Andrew Hall', 'WorkedFor', 'Warner Bros.']]
# FALSE NEGATIVE: ['Andrew Hall', 'Live_In', 'Fla.']
# -----------------------------------------------
# TEXT: One of Warner 's lawyers , Andrew Hall of Miami , Fla. , confirmed Tuesday that Warner is trying to settle the case.
#
# TRUE (SET):  [['Andrew Hall', 'Live_In', 'Miami'], ['Andrew Hall', 'Live_In', 'Fla.'], ['Miami', 'Located_In', 'Fla.']]
# GENERATED: [['Andrew Hall', 'WorkedFor', 'Warner Bros.']]
# FALSE NEGATIVE: ['Miami', 'Located_In', 'Fla.']
# -----------------------------------------------
# TEXT: New Jersey Gov. Thomas Kean , who is leaving office after two terms at the end of this year , was greeted with effuse public praise by his colleagues during the conference.
#
# TRUE (SET):  [['Thomas Kean', 'Live_In', 'New Jersey']]
# GENERATED: [['Thomas Kean', 'Office', 'Governor of New Jersey']]
# FALSE NEGATIVE: ['Thomas Kean', 'Live_In', 'New Jersey']
# -----------------------------------------------
# TEXT: ` ` The country was starved of resources , ' ' said Marcos Victorica , director of the Institute of Contemporary Studies.
#
# TRUE (SET):  [['Marcos Victorica', 'Work_For', 'Institute of Contemporary Studies.']]
# GENERATED: [['Institute of Contemporary Studies', 'Director', 'Marcos Victorica']]
# FALSE NEGATIVE: ['Marcos Victorica', 'Work_For', 'Institute of Contemporary Studies.']
# -----------------------------------------------
# TEXT: Excess Lira Reportedly Causes Currency Crisis NC1901223094 London Kanal-6 Television in Turkish 1700 GMT 19 Jan 94
#
# TRUE (SET):  [['Kanal-6 Television', 'OrgBased_In', 'London']]
# GENERATED: [['Excess Lira Reportedly Causes Currency Crisis', 'date', '19 Jan 94'], ['Excess Lira Reportedly Causes Currency Crisis', 'channel', 'Kanal-6 Television']]
# FALSE NEGATIVE: ['Kanal-6 Television', 'OrgBased_In', 'London']
# -----------------------------------------------
# TEXT: " This is the Garrett place where John Wilkes Booth , assassin of Lincoln , was cornered by Union soldiers and killed April 26 , 1865 .
#
# TRUE (SET):  [['John Wilkes Booth', 'Kill', 'Lincoln']]
# GENERATED: [['John Wilkes Booth', 'Killed', 'Abraham Lincoln']]
# ...
# TEXT: ( Text ) Moscow April 25 TASS -- Preliminary marine pollution measurements taken from the sites of radioactive waste dumping by the former Soviet Union and Japan in the Sea of Japan did not reveal any Caesium-137 radioactive level fluctuations .
#
# TRUE (SET):  [['TASS', 'OrgBased_In', 'Moscow']]
# GENERATED: [['Moscow', 'is_part_of', 'Russia']]
# FALSE NEGATIVE: ['TASS', 'OrgBased_In', 'Moscow']
# -----------------------------------------------
# TEXT: Police arrested 10 Spanish Basque militants , including Jose Antonio Urutigoechea , considered by Madrid to be a top leader of the Spanish Basque separatist organization ETA , authorities said today .
#
# TRUE (SET):  [['Jose Antonio Urutigoechea', 'Work_For', 'ETA']]
# GENERATED: [['ETA', 'Top_Leader', 'Jose Antonio Urutigoechea']]
# FALSE NEGATIVE: ['Jose Antonio Urutigoechea', 'Work_For', 'ETA']
# -----------------------------------------------
# TEXT: The Warren Commission concluded that Oswald , acting alone , fired the shots that killed Kennedy and wounded John Connally , then the Texas governor .
#
# TRUE (SET):  [['Oswald', 'Kill', 'Kennedy']]
# GENERATED: [['John Connally', 'Killed', 'John F. Kennedy']]
# FALSE NEGATIVE: ['Oswald', 'Kill', 'Kennedy']
# -----------------------------------------------
# TEXT: The advisory committee voted 7-1 to recommend that the drug remain a prescription ingredient , said Susan Cruzan , an FDA spokeswoman.
#
# TRUE (SET):  [['Susan Cruzan', 'Work_For', 'FDA']]
# GENERATED: [['Susan Cruzan', 'Works_For', 'FDA']]
# FALSE NEGATIVE: ['Susan Cruzan', 'Work_For', 'FDA']
# -----------------------------------------------
# TEXT: ` ` It 's been a nightmare , ' ' said Shelley Yeager , director of the Clara Barton camp at Oxford in central Massachusetts.
#
# TRUE (SET):  [['Oxford', 'Located_In', 'Massachusetts.']]
# GENERATED: [['Shelly Yeager', 'Works_for', 'Clara Barton Camp']]
# FALSE NEGATIVE: ['Oxford', 'Located_In', 'Massachusetts.']
# -----------------------------------------------
# TEXT: Yeltsin Orders Audit of Ostankino Finances MK1401103094 Moscow MOSKOVSKIY KOMSOMOLETS in Russian 14 Jan 94 p 1
#
# TRUE (SET):  [['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']]
# GENERATED: [['Moscow Moskovskiy Kommunalete', 'language', 'Russian'], ['Moscow Moskovskiy Kommunalete', 'date', '1994-01-14']]
# FALSE NEGATIVE: ['MOSKOVSKIY KOMSOMOLETS', 'OrgBased_In', 'Moscow']
# -----------------------------------------------
# TEXT: In 1969 , Sirhan Sirhan was convicted of assassinating U.S. Sen. Robert F. Kennedy .
#
# TRUE (SET):  [['Sirhan Sirhan', 'Kill', 'U.S. Sen. Robert F. Kennedy']]
# GENERATED: [['Robert F. Kennedy', 'Assassination', '1969']]
# FALSE NEGATIVE: ['Sirhan Sirhan', 'Kill', 'U.S. Sen. Robert F. Kennedy']
# -----------------------------------------------
# TEXT: MEXICO CITY ( AP )
#
# TRUE (SET):  [['AP', 'OrgBased_In', 'MEXICO CITY']]
# GENERATED: [['AP', 'Newspaper', 'Mexico City Herald']]
# FALSE NEGATIVE: ['AP', 'OrgBased_In', 'MEXICO CITY']
# -----------------------------------------------
# TEXT: Tokyo MAINICHI SHIMBUN
#
# TRUE (SET):  [['MAINICHI SHIMBUN', 'OrgBased_In', 'Tokyo']]
# GENERATED: [['Mainichi Shimbun', 'City', 'Tokyo']]
# FALSE NEGATIVE: ['MAINICHI SHIMBUN', 'OrgBased_In', 'Tokyo']
# -----------------------------------------------
# TEXT: If the elections had been held during the last 10 days of May , that is , after the debate , Fernandez de Cevallos would reportedly be the next president of Mexico with 33.2 percent of the vote .
#
# TRUE (SET):  [['Fernandez de Cevallos', 'Live_In', 'Mexico']]
# GENERATED: [['Fernandez de Cevallos', 'Percentage', '33.2']]
# FALSE NEGATIVE: ['Fernandez de Cevallos', 'Live_In', 'Mexico']
# -----------------------------------------------
# TEXT: Meanwhile , the historical society in Beaumont , Texas , Richardson 's hometown , plans to raise two statues on Feb. 3 _ one of Buddy Holly , Richardson and Valens , and a second of the Big Bopper alone .
#
# TRUE (SET):  [['Richardson', 'Live_In', 'Beaumont , Texas']]
# GENERATED: [['Big Bopper', 'Death_Place', 'Beaumont, Texas']]
# FALSE NEGATIVE: ['Richardson', 'Live_In', 'Beaumont , Texas']
# -----------------------------------------------
# TEXT: At a briefing at NRC headquarters in nearby Rockville , Md. , Bernero said the volcanic cones in the area of Yucca Mountain have been a cause of concern for NRC experts.
#
# TRUE (SET):  [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.'], ['Bernero', 'Work_For', 'NRC'], ['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.']]
# GENERATED: [['Rockville', 'is_part_of', 'Maryland']]
# FALSE NEGATIVE: ['NRC', 'OrgBased_In', 'Rockville']
# -----------------------------------------------
# TEXT: At a briefing at NRC headquarters in nearby Rockville , Md. , Bernero said the volcanic cones in the area of Yucca Mountain have been a cause of concern for NRC experts.
#
# TRUE (SET):  [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.'], ['Bernero', 'Work_For', 'NRC'], ['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.']]
# GENERATED: [['Rockville', 'is_part_of', 'Maryland']]
# FALSE NEGATIVE: ['NRC', 'OrgBased_In', 'Md.']
# -----------------------------------------------
# TEXT: At a briefing at NRC headquarters in nearby Rockville , Md. , Bernero said the volcanic cones in the area of Yucca Mountain have been a cause of concern for NRC experts.
#
# TRUE (SET):  [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.'], ['Bernero', 'Work_For', 'NRC'], ['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.']]
# GENERATED: [['Rockville', 'is_part_of', 'Maryland']]
# FALSE NEGATIVE: ['Rockville', 'Located_In', 'Md.']
# -----------------------------------------------
# TEXT: At a briefing at NRC headquarters in nearby Rockville , Md. , Bernero said the volcanic cones in the area of Yucca Mountain have been a cause of concern for NRC experts.
#
# TRUE (SET):  [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.'], ['Bernero', 'Work_For', 'NRC'], ['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.']]
# GENERATED: [['Rockville', 'is_part_of', 'Maryland']]
# FALSE NEGATIVE: ['Bernero', 'Work_For', 'NRC']
# -----------------------------------------------
# TEXT: At a briefing at NRC headquarters in nearby Rockville , Md. , Bernero said the volcanic cones in the area of Yucca Mountain have been a cause of concern for NRC experts.
#
# TRUE (SET):  [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.'], ['Bernero', 'Work_For', 'NRC'], ['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.']]
# GENERATED: [['Rockville', 'is_part_of', 'Maryland']]
# FALSE NEGATIVE: ['NRC', 'OrgBased_In', 'Rockville']
# -----------------------------------------------
# TEXT: At a briefing at NRC headquarters in nearby Rockville , Md. , Bernero said the volcanic cones in the area of Yucca Mountain have been a cause of concern for NRC experts.
#
# TRUE (SET):  [['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.'], ['Rockville', 'Located_In', 'Md.'], ['Bernero', 'Work_For', 'NRC'], ['NRC', 'OrgBased_In', 'Rockville'], ['NRC', 'OrgBased_In', 'Md.']]
# GENERATED: [['Rockville', 'is_part_of', 'Maryland']]
# FALSE NEGATIVE: ['NRC', 'OrgBased_In', 'Md.']
# -----------------------------------------------
# TEXT: ( Text ) Saint-Gall , Switzerland , Feb 2 ( AFP ) -- The wreck of a twin-engine aircraft has been found 160 metres below the surface of Lake Constance , Swiss police said Tuesday ( 1 February ) .
#
# TRUE (SET):  [['Saint-Gall', 'Located_In', 'Switzerland'], ['AFP', 'OrgBased_In', 'Saint-Gall'], ['AFP', 'OrgBased_In', 'Switzerland']]
# GENERATED: [['Lake Constance', 'Number_Of_Passengers', '2']]
# FALSE NEGATIVE: ['Saint-Gall', 'Located_In', 'Switzerland']
# -----------------------------------------------
# TEXT: ( Text ) Saint-Gall , Switzerland , Feb 2 ( AFP ) -- The wreck of a twin-engine aircraft has been found 160 metres below the surface of Lake Constance , Swiss police said Tuesday ( 1 February ) .
#
# TRUE (SET):  [['Saint-Gall', 'Located_In', 'Switzerland'], ['AFP', 'OrgBased_In', 'Saint-Gall'], ['AFP', 'OrgBased_In', 'Switzerland']]
# GENERATED: [['Lake Constance', 'Number_Of_Passengers', '2']]
# FALSE NEGATIVE: ['AFP', 'OrgBased_In', 'Saint-Gall']
# -----------------------------------------------
# TEXT: ( Text ) Saint-Gall , Switzerland , Feb 2 ( AFP ) -- The wreck of a twin-engine aircraft has been found 160 metres below the surface of Lake Constance , Swiss police said Tuesday ( 1 February ) .
#
# TRUE (SET):  [['Saint-Gall', 'Located_In', 'Switzerland'], ['AFP', 'OrgBased_In', 'Saint-Gall'], ['AFP', 'OrgBased_In', 'Switzerland']]
# GENERATED: [['Lake Constance', 'Number_Of_Passengers', '2']]
# FALSE NEGATIVE: ['AFP', 'OrgBased_In', 'Switzerland']
# -----------------------------------------------
# TEXT: According to the communique , clashes are continuing mainly in the Rancho Nuevo area at the military base in the southern Chiapas State .
#
# TRUE (SET):  [['Rancho Nuevo', 'Located_In', 'Chiapas State']]
# GENERATED: [['Rancho Nuevo', 'Location', 'Mexico']]
# FALSE NEGATIVE: ['Rancho Nuevo', 'Located_In', 'Chiapas State']
# -----------------------------------------------
# TEXT: Dallas police arrested Oswald there on Nov. 22 , 1963 , after the assassination of President John F. Kennedy .
#
# TRUE (SET):  [['Oswald', 'Kill', 'President John F. Kennedy']]
# GENERATED: [['Nov. 22', 'Year', 1963]]
# FALSE NEGATIVE: ['Oswald', 'Kill', 'President John F. Kennedy']
# -----------------------------------------------
# TEXT: In Washington state , near the Canadian border , firefighters hoped to contain an 850-acre fire by tonight , said Greg Thayer of the Forest Service.
#
# TRUE (SET):  [['Greg Thayer', 'Work_For', 'Forest Service.']]
# GENERATED: [['Greg Thayer', 'Worked_For', 'Forest Service']]
# FALSE NEGATIVE: ['Greg Thayer', 'Work_For', 'Forest Service.']
# -----------------------------------------------
# TEXT: In an " electoral communique " signed by CNTP Secretary Luis Cobos R. , the organization said it hopes that with this decision " we will achieve the return of the Torrijist forces to power to stimulate the process of national liberation . "
#
# TRUE (SET):  [['Luis Cobos R.', 'Work_For', 'CNTP']]
# GENERATED: [['CNTP', 'Secretary', 'Luis Cobos R.']]
# FALSE NEGATIVE: ['Luis Cobos R.', 'Work_For', 'CNTP']
# -----------------------------------------------
# TEXT: In it , actor Edwin Booth tells us his version of his life story , in which he and not his brother John Wilkes shoots Abraham Lincoln at Ford 's Theater .
#
# TRUE (SET):  [['John Wilkes', 'Kill', 'Abraham Lincoln']]
# GENERATED: [['Edwin Booth', 'Brother', 'John Wilkes Booth']]
# FALSE NEGATIVE: ['John Wilkes', 'Kill', 'Abraham Lincoln']
# -----------------------------------------------
# TEXT: In 1801 , Mormon leader Brigham Young was born in Whitingham , Vt .
#
# TRUE (SET):  [['Brigham Young', 'Live_In', 'Whitingham , Vt']]
# GENERATED: [['Brigham Young', 'Born', '1801'], ['Brigham Young', 'Born', 'Whitingham, Vermont']]
# FALSE NEGATIVE: ['Brigham Young', 'Live_In', 'Whitingham , Vt']
# -----------------------------------------------
# TEXT: The Warren Commission concluded that Lee Harvey Oswald , acting alone , fired the shots that killed Kennedy and wounded John Connally , then the Texas governor , on Nov. 22 , 1963 in Dallas .
#
# TRUE (SET):  [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# GENERATED: [['John Connally', 'Killed', 'John F. Kennedy']]
# FALSE NEGATIVE: ['Lee Harvey Oswald', 'Kill', 'Kennedy']
# -----------------------------------------------
# TEXT: The spilled fuel covered an area two miles long and nearly a half-mile wide , said Whitefish City Attorney Tom Muri.
#
# TRUE (SET):  [['Tom Muri.', 'Live_In', 'Whitefish City']]
# GENERATED: [['Whitefish City Attorney Tom Muri', 'Said', 'The spilled fuel covered an area two miles long and nearly a half-mile wide']]
# FALSE NEGATIVE: ['Tom Muri.', 'Live_In', 'Whitefish City']
# -----------------------------------------------
# TEXT: In California 's Sierra Nevada foothills , firefighters today declared they had contained a fire that blackened 11 , 700 acres of brush and grassland and destroyed seven homes.
#
# TRUE (SET):  [['Sierra Nevada', 'Located_In', 'California']]
# GENERATED: [['11,700 acres', 'Total_acres', '11,700'], ['11,700 acres', 'Location', 'Sierra Nevada foothills']]
# FALSE NEGATIVE: ['Sierra Nevada', 'Located_In', 'California']
# -----------------------------------------------
# TEXT: " I was hearing the same story , " says James Hackett , an executive with Titan Systems and one of the leading missile experts in the U.S .
#
# TRUE (SET):  [['James Hackett', 'Work_For', 'Titan Systems'], ['James Hackett', 'Live_In', 'U.S .']]
# GENERATED: [['James Hackett', 'Works_For', 'Titan Systems']]
# FALSE NEGATIVE: ['James Hackett', 'Work_For', 'Titan Systems']
# -----------------------------------------------
# TEXT: " I was hearing the same story , " says James Hackett , an executive with Titan Systems and one of the leading missile experts in the U.S .
#
# TRUE (SET):  [['James Hackett', 'Work_For', 'Titan Systems'], ['James Hackett', 'Live_In', 'U.S .']]
# GENERATED: [['James Hackett', 'Works_For', 'Titan Systems']]
# FALSE NEGATIVE: ['James Hackett', 'Live_In', 'U.S .']
# -----------------------------------------------
# TEXT: The quake leveled much of Leninakan , Armenia 's second-largest city 10 miles east of the Turkish border and left thousands homeless .
#
# TRUE (SET):  [['Leninakan', 'Located_In', 'Armenia']]
# GENERATED: [['Leninakan', 'is_part_of', 'Armenia']]
# FALSE NEGATIVE: ['Leninakan', 'Located_In', 'Armenia']
# -----------------------------------------------
# TEXT: Pittsburgh-Corning Corp. of Pittsburgh ;
#
# TRUE (SET):  [['Pittsburgh-Corning Corp.', 'OrgBased_In', 'Pittsburgh']]
# GENERATED: [['Pittsburgh-Corning Corp.', 'City,', 'Pittsburgh']]
# FALSE NEGATIVE: ['Pittsburgh-Corning Corp.', 'OrgBased_In', 'Pittsburgh']
# -----------------------------------------------
# TEXT: Barrett is a member of the Illinois Commerce Commission , and Marshall is a lawyer and former legislative aide to Patrick.
#
# TRUE (SET):  [['Barrett', 'Work_For', 'Illinois Commerce Commission']]
# GENERATED: [['Barrett Marshall', 'Office', 'Member of the Illinois Commerce Commission']]
# FALSE NEGATIVE: ['Barrett', 'Work_For', 'Illinois Commerce Commission']
# -----------------------------------------------
# TEXT: Ten years ago : James Earl Ray , convicted of assassinating Dr. Martin Luther King Jr. in 1968 , repeated his assertion at a Capitol Hill hearing that he did not commit the crime , saying he 'd been set up to take the blame by a mysterious man called Raoul .
#
# TRUE (SET):  [['James Earl Ray', 'Kill', 'Dr. Martin Luther King Jr.']]
# GENERATED: [['James Earl Ray', 'Assassinates', 'Martin Luther King Jr.']]
# FALSE NEGATIVE: ['James Earl Ray', 'Kill', 'Dr. Martin Luther King Jr.']
# -----------------------------------------------
# TEXT: They will also be cleaning the car Oswald drove on the day Kennedy was shot and the ambulance that took Oswald to hospital after he was shot by Jack Ruby .
#
# TRUE (SET):  [['Jack Ruby', 'Kill', 'Oswald']]
# GENERATED: [['Jack Ruby', 'killed', 'Leonid D. Kennedy']]
# FALSE NEGATIVE: ['Jack Ruby', 'Kill', 'Oswald']
# -----------------------------------------------
# TEXT: LD2804174994 Moscow INTERFAX in English 1601 GMT 28 Apr 94
#
# TRUE (SET):  [['INTERFAX', 'OrgBased_In', 'Moscow']]
# GENERATED: [['LD2804174994', 'language', 'English'], ['LD2804174994', 'date', '1994-04-28']]
# FALSE NEGATIVE: ['INTERFAX', 'OrgBased_In', 'Moscow']
# -----------------------------------------------
# TEXT: Navy sources said the Coral Sea , on duty with the 6th Fleet in the Mediterranean , left ` ` a few hours ' ' ahead of its scheduled departure.
#
# TRUE (SET):  [['6th Fleet', 'OrgBased_In', 'Mediterranean']]
# GENERATED: [['USS Coral Sea', 'on_duty_with', '6th Fleet']]
# FALSE NEGATIVE: ['6th Fleet', 'OrgBased_In', 'Mediterranean']
# -----------------------------------------------

# %%
temp = pd.DataFrame({"text": text, "true_fn": fn_list, "gen":gen_list}, index=None)
temp.to_csv("fn_conll_flan_eval.csv", index=False)
