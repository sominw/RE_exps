# %%
import numpy as np
import pandas as pd
import logging
import os
import glob
import warnings
import regex as re
import torch
import argparse
import random
import itertools
import random
import ast
import sys
import ast

from sklearn.model_selection import train_test_split
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from transformers import T5Tokenizer, T5ForConditionalGeneration, Trainer, TrainingArguments
import simpletransformers
from simpletransformers.t5 import T5Model, T5Args
from datasets import load_dataset, get_dataset_split_names
from transformers import AdamW

os.environ['TORCH_HOME'] = '/scratch/wadhwa.s/cache/'
os.environ['HF_HOME'] = '/scratch/wadhwa.s/cache'
os.environ['TRANSFORMERS_CACHE'] = '/scratch/wadhwa.s/cache'


warnings.filterwarnings("ignore")

# %%
ade = pd.read_csv("ade_gpt3_fewshot_tp.csv")
nyt = pd.read_csv("nyt_gpt3_fewshot_tp.csv")
conll = pd.read_csv("conll_gpt3_fewshot_tp.csv")

# %%
print (ade.shape, nyt.shape, conll.shape)
# Out:
# (614, 4) (3731, 4) (150, 4)

# %%
df = pd.concat([ade, nyt, conll]).sample(frac=1)
df.head(10)
# Out:
#                                                   input  \
# 157   diagnosis of hypothyroidism during treatment c...
# 2951  -LRB- On Wednesday , China urged North Korea t...
# 868   After waiting nearly half a century for Fidel ...
# 2663  In a law enforcement compound in this town in ...
# 404   6 Large Protest in Taiwan Hundreds of thousand...
# 3402  Rose Cinemas , 30 Lafayette Avenue , at Ashlan...
# 257   The committee said that while it found no evid...
# 330   After their post-9 \/ 11 period of quiescence ...
# 2151  Several years later he opened a plant in Long ...
# 2564  It would be a shame to recognize only one as `...
#
#                                               relations prefix  \
# 157            [['alpha interferon', 'hypothyroidism']]    ADE
# 2951  [['Beijing', 'LOC_COUNTRY', 'China'], ['China'...    NYT
# 868   [['Cuba', 'LOC_CONTAINS', 'Havana'], ['Havana'...    NYT
# 2663            [['Chechnya', 'LOC_CONTAINS', 'Argun']]    NYT
# 404                [['Taiwan', 'LOC_COUNTRY', 'China']]    NYT
# 3402      [['Brooklyn', 'LOC_CONTAINS', 'Fort Greene']]    NYT
# 257      [['Kofi Annan', 'PEO_CHILDREN', 'Kojo Annan']]    NYT
# 330    [['Chuck Hagel', 'PEO_PLACE_LIVED', 'Nebraska']]    NYT
# 2151   [['Queens', 'LOC_CONTAINS', 'Long Island City']]    NYT
# 2564  [['California', 'LOC_CONTAINS', 'Sonoma'], ['C...    NYT
#
#                                          gold_relations
# 157            [['alpha interferon', 'hypothyroidism']]
# 2951  [['Beijing', 'LOC_COUNTRY', 'China'], ['China'...
# 868   [['Cuba', 'LOC_ADMIN_DIVISIONS', 'Havana'], ['...
# 2663            [['Chechnya', 'LOC_CONTAINS', 'Argun']]
# 404   [['China', 'LOC_ADMIN_DIVISIONS', 'Beijing'], ...
# 3402  [['Fort Greene', 'LOC_NEIGHBORHOOD', 'Brooklyn...
# 257   [['Kofi Annan', 'PEO_CHILDREN', 'Kojo Annan'],...
# 330    [['Chuck Hagel', 'PEO_PLACE_LIVED', 'Nebraska']]
# 2151  [['Queens', 'LOC_CONTAINS', 'Long Island City'...
# 2564  [['California', 'LOC_CONTAINS', 'Sonoma'], ['C...

# %%
train, test = train_test_split(df, test_size=0.20, stratify=df["prefix"])

# %%
print (train.shape, test.shape)
# Out:
# (3596, 4) (899, 4)

# %%
model_args = {
    "cache_dir" : "/scratch/wadhwa.s/cache/",
#     "device_map" : "auto",
#     "use_multiprocessing": False,
#     "use_multiprocessed_decoding": False,
    "config" : {"cache_dir" : "/scratch/wadhwa.s/cache/"},
    "max_seq_length" : 512,
    "train_batch_size" : 4,
    "eval_batch_size" :4,
    "max_length" : 200,
         "num_train_epochs" : 4,
         "no_save" : True,
#         "preprocess_inputs" : False,
         "overwrite_output_dir" : True,
#         "special_tokens_list" : ["<bos>", "<eos>", "<rel>", "<ent>"],
#         "max_length" : 200,
#         "num_beams" : 5,
#         "learning_rate": lr,

    }

train = train.rename(columns={"input": "input_text", "relations": "target_text"})
test = test.rename(columns={"input": "input_text", "relations": "target_text"})

train_df = train[["prefix", "input_text", "target_text"]]
test_df = test[["prefix", "input_text", "target_text"]]

# %%
print (train_df.shape, test_df.shape)
# Out:
# (3596, 3) (899, 3)

# %%
model = T5Model("t5", "t5-large", args=model_args)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████| 1.20k/1.20k [00:00<00:00, 1.34MB/s]
# loading configuration file config.json from cache at /scratch/wadhwa.s/cache/models--t5-large/snapshots/cb7a9673bcaf9ab8b677ad4a5650c1d74b4a5a8e/config.json
# Model config T5Config {
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 4096,
#   "d_kv": 64,
#   "d_model": 1024,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "relu",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": false,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 24,
#   "num_heads": 16,
#   "num_layers": 24,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# Downloading: 100%|█████████████████████████████████████████████████████| 2.95G/2.95G [01:05<00:00, 45.2MB/s]
# loading weights file pytorch_model.bin from cache at /scratch/wadhwa.s/cache/models--t5-large/snapshots/cb7a9673bcaf9ab8b677ad4a5650c1d74b4a5a8e/pytorch_model.bin
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at t5-large.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# Downloading: 100%|███████████████████████████████████████████████████████| 792k/792k [00:00<00:00, 11.7MB/s]
# loading file spiece.model from cache at /scratch/wadhwa.s/cache/models--t5-large/snapshots/cb7a9673bcaf9ab8b677ad4a5650c1d74b4a5a8e/spiece.model
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at /scratch/wadhwa.s/cache/models--t5-large/snapshots/cb7a9673bcaf9ab8b677ad4a5650c1d74b4a5a8e/config.json
# Model config T5Config {
#   "_name_or_path": "t5-large",
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 4096,
#   "d_kv": 64,
#   "d_model": 1024,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "relu",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": false,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 24,
#   "num_heads": 16,
#   "num_layers": 24,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 32128
# }

# %%
model.train_model(train)
# Out:
# 100%|█████████████████████████████████████████████████████████████████| 3596/3596 [00:02<00:00, 1467.97it/s]
# Epoch 1 of 4:   0%|                                                                   | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|                                                         | 0/899 [00:00<?, ?it/s]
# Epochs 0/4. Running Loss:       nan:   0%|                                          | 0/899 [00:00<?, ?it/s]
# Epochs 0/4. Running Loss:       nan:   0%|                                  | 1/899 [00:01<18:32,  1.24s/it]
# Epochs 0/4. Running Loss:       nan:   0%|                                  | 1/899 [00:01<18:32,  1.24s/it]
# Epochs 0/4. Running Loss:       nan:   0%|                                  | 2/899 [00:01<14:04,  1.06it/s]
# Epochs 0/4. Running Loss:       nan:   0%|                                  | 2/899 [00:02<14:04,  1.06it/s]
# Epochs 0/4. Running Loss:       nan:   0%|                                  | 3/899 [00:02<12:37,  1.18it/s]
# Epochs 0/4. Running Loss:       nan:   0%|                                  | 3/899 [00:03<12:37,  1.18it/s]
# Epochs 0/4. Running Loss:       nan:   0%|▏                                 | 4/899 [00:03<11:56,  1.25it/s]
# Epochs 0/4. Running Loss:       nan:   0%|▏                                 | 4/899 [00:03<11:56,  1.25it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▏                                 | 5/899 [00:04<11:33,  1.29it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▏                                 | 5/899 [00:04<11:33,  1.29it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▏                                 | 6/899 [00:04<11:19,  1.31it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▏                                 | 6/899 [00:05<11:19,  1.31it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▎                                 | 7/899 [00:05<11:13,  1.33it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▎                                 | 7/899 [00:05<11:13,  1.33it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▎                                 | 8/899 [00:06<11:07,  1.34it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▎                                 | 8/899 [00:06<11:07,  1.34it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▎                                 | 9/899 [00:07<11:01,  1.35it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▎                                 | 9/899 [00:07<11:01,  1.35it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▎                                | 10/899 [00:07<11:04,  1.34it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▎                                | 10/899 [00:08<11:04,  1.34it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▍                                | 11/899 [00:08<11:03,  1.34it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▍                                | 11/899 [00:08<11:03,  1.34it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▍                                | 12/899 [00:09<10:58,  1.35it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▍                                | 12/899 [00:09<10:58,  1.35it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▍                                | 13/899 [00:10<10:55,  1.35it/s]
# Epochs 0/4. Running Loss:       nan:   1%|▍                                | 13/899 [00:10<10:55,  1.35it/s]
# Epochs 0/4. Running Loss:       nan:   2%|▌                                | 14/899 [00:10<10:52,  1.36it/s]
# Epochs 0/4. Running Loss:       nan:   2%|▌                                | 14/899 [00:11<10:52,  1.36it/s]
# Epochs 0/4. Running Loss:       nan:   2%|▌                                | 15/899 [00:11<11:27,  1.29it/s]
# Epoch 1 of 4:   0%|                                                                   | 0/4 [00:11<?, ?it/s]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_28316/4159083419.py:1 in <cell line: 1>                                           │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_28316/4159083419.py'                        │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/simpletransformers/t5/t5_model.py:22 │
# │ 9 in train_model                                                                                 │
# │                                                                                                  │
# │    226 │   │                                                                                     │
# │    227 │   │   os.makedirs(output_dir, exist_ok=True)                                            │
# │    228 │   │                                                                                     │
# │ ❱  229 │   │   global_step, training_details = self.train(                                       │
# │    230 │   │   │   train_dataset,                                                                │
# │    231 │   │   │   output_dir,                                                                   │
# │    232 │   │   │   show_running_loss=show_running_loss,                                          │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/simpletransformers/t5/t5_model.py:52 │
# │ 4 in train                                                                                       │
# │                                                                                                  │
# │    521 │   │   │   │   inputs = self._get_inputs_dict(batch)                                     │
# │    522 │   │   │   │   if args.fp16:                                                             │
# │    523 │   │   │   │   │   with amp.autocast():                                                  │
# │ ❱  524 │   │   │   │   │   │   outputs = model(**inputs)                                         │
# │    525 │   │   │   │   │   │   # model outputs are always tuple in pytorch-transformers (see do  │
# │    526 │   │   │   │   │   │   loss = outputs[0]                                                 │
# │    527 │   │   │   │   else:                                                                     │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in   │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/accelerate/hooks.py:148 in           │
# │ new_forward                                                                                      │
# │                                                                                                  │
# │   145 │   │   │   with torch.no_grad():                                                          │
# │   146 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   147 │   │   else:                                                                              │
# │ ❱ 148 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   149 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   150 │                                                                                          │
# │   151 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.p │
# │ y:1648 in forward                                                                                │
# │                                                                                                  │
# │   1645 │   │   │   │   decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_de  │
# │   1646 │   │                                                                                     │
# │   1647 │   │   # Decode                                                                          │
# │ ❱ 1648 │   │   decoder_outputs = self.decoder(                                                   │
# │   1649 │   │   │   input_ids=decoder_input_ids,                                                  │
# │   1650 │   │   │   attention_mask=decoder_attention_mask,                                        │
# │   1651 │   │   │   inputs_embeds=decoder_inputs_embeds,                                          │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in   │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/accelerate/hooks.py:148 in           │
# │ new_forward                                                                                      │
# │                                                                                                  │
# │   145 │   │   │   with torch.no_grad():                                                          │
# │   146 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   147 │   │   else:                                                                              │
# │ ❱ 148 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   149 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   150 │                                                                                          │
# │   151 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.p │
# │ y:1040 in forward                                                                                │
# │                                                                                                  │
# │   1037 │   │   │   │   │   None,  # past_key_value is always None with gradient checkpointing    │
# │   1038 │   │   │   │   )                                                                         │
# │   1039 │   │   │   else:                                                                         │
# │ ❱ 1040 │   │   │   │   layer_outputs = layer_module(                                             │
# │   1041 │   │   │   │   │   hidden_states,                                                        │
# │   1042 │   │   │   │   │   attention_mask=extended_attention_mask,                               │
# │   1043 │   │   │   │   │   position_bias=position_bias,                                          │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in   │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/accelerate/hooks.py:148 in           │
# │ new_forward                                                                                      │
# │                                                                                                  │
# │   145 │   │   │   with torch.no_grad():                                                          │
# │   146 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   147 │   │   else:                                                                              │
# │ ❱ 148 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   149 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   150 │                                                                                          │
# │   151 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.p │
# │ y:673 in forward                                                                                 │
# │                                                                                                  │
# │    670 │   │   else:                                                                             │
# │    671 │   │   │   self_attn_past_key_value, cross_attn_past_key_value = None, None              │
# │    672 │   │                                                                                     │
# │ ❱  673 │   │   self_attention_outputs = self.layer[0](                                           │
# │    674 │   │   │   hidden_states,                                                                │
# │    675 │   │   │   attention_mask=attention_mask,                                                │
# │    676 │   │   │   position_bias=position_bias,                                                  │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in   │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/accelerate/hooks.py:148 in           │
# │ new_forward                                                                                      │
# │                                                                                                  │
# │   145 │   │   │   with torch.no_grad():                                                          │
# │   146 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   147 │   │   else:                                                                              │
# │ ❱ 148 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   149 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   150 │                                                                                          │
# │   151 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.p │
# │ y:579 in forward                                                                                 │
# │                                                                                                  │
# │    576 │   │   output_attentions=False,                                                          │
# │    577 │   ):                                                                                    │
# │    578 │   │   normed_hidden_states = self.layer_norm(hidden_states)                             │
# │ ❱  579 │   │   attention_output = self.SelfAttention(                                            │
# │    580 │   │   │   normed_hidden_states,                                                         │
# │    581 │   │   │   mask=attention_mask,                                                          │
# │    582 │   │   │   position_bias=position_bias,                                                  │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in   │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/accelerate/hooks.py:148 in           │
# │ new_forward                                                                                      │
# │                                                                                                  │
# │   145 │   │   │   with torch.no_grad():                                                          │
# │   146 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   147 │   │   else:                                                                              │
# │ ❱ 148 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   149 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   150 │                                                                                          │
# │   151 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.p │
# │ y:498 in forward                                                                                 │
# │                                                                                                  │
# │    495 │   │   │   return hidden_states                                                          │
# │    496 │   │                                                                                     │
# │    497 │   │   # get query states                                                                │
# │ ❱  498 │   │   query_states = shape(self.q(hidden_states))  # (batch_size, n_heads, seq_length,  │
# │    499 │   │                                                                                     │
# │    500 │   │   # get key/value states                                                            │
# │    501 │   │   key_states = project(                                                             │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in   │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/accelerate/hooks.py:148 in           │
# │ new_forward                                                                                      │
# │                                                                                                  │
# │   145 │   │   │   with torch.no_grad():                                                          │
# │   146 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   147 │   │   else:                                                                              │
# │ ❱ 148 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   149 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   150 │                                                                                          │
# │   151 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/nn/modules/linear.py:114 in    │
# │ forward                                                                                          │
# │                                                                                                  │
# │   111 │   │   │   init.uniform_(self.bias, -bound, bound)                                        │
# │   112 │                                                                                          │
# │   113 │   def forward(self, input: Tensor) -> Tensor:                                            │
# │ ❱ 114 │   │   return F.linear(input, self.weight, self.bias)                                     │
# │   115 │                                                                                          │
# │   116 │   def extra_repr(self) -> str:                                                           │
# │   117 │   │   return 'in_features={}, out_features={}, bias={}'.format(                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
train = train.rename(columns={"input": "input_text", "relations": "target_text"})
train["input_text"] = train.apply(lambda x: x["prefix"] + ": " + x["input_text"], axis=1)

test = test.rename(columns={"input": "input_text", "relations": "target_text"})
test["input_text"] = test.apply(lambda x: x["prefix"] + ": " + x["input_text"], axis=1)

# %%
train = train[["input_text", "target_text"]]
test = test[["input_text", "target_text"]]
print (train.shape, test.shape)
# Out:
# (3596, 2) (899, 2)

# %%
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-large", cache_dir="/scratch/wadhwa.s/cache")
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-large", cache_dir="/scratch/wadhwa.s/cache", device_map="auto")

# %%
optimizer=AdamW(model.parameters(), lr=3e-5, weight_decay=0.01),

args = TrainingArguments(
    learning_rate = 3e-5,
    output_dir='/scratch/wadhwa.s/outputs/',
    num_train_epochs=4,
#    max_input_length = 512,
#    max_output_length = 200,
)

# %%
train_dict = train.to_dict('records')
test_dict = test.to_dict('records')

# %%
print (len(train_dict), len(test_dict))
# Out:
# 3596 899

# %%
trainer = Trainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_dict,
    source_text = "input_text",
    target_text = "target_text",
    args=args,
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_28316/3769855561.py:1 in <cell line: 1>                                           │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_28316/3769855561.py'                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: __init__() got an unexpected keyword argument 'source_text'

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 3596
#   Num Epochs = 4
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1800
#   Number of trainable parameters = 783150080
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: sw7. Use `wandb login --relogin` to force relogin
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/wadhwa.s/gpt3/wandb/run-20221208_143928-1i005y91</code>
# Syncing run <strong><a href="https://wandb.ai/sw7/huggingface/runs/1i005y91" target="_blank">/scratch/wadhwa.s/outputs/</a></strong> to <a href="https://wandb.ai/sw7/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# The following columns in the training set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: target_text, input_text. If target_text, input_text are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_28316/4032920361.py:1 in <cell line: 1>                                           │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_28316/4032920361.py'                        │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/trainer.py:1501 in      │
# │ train                                                                                            │
# │                                                                                                  │
# │   1498 │   │   inner_training_loop = find_executable_batch_size(                                 │
# │   1499 │   │   │   self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size  │
# │   1500 │   │   )                                                                                 │
# │ ❱ 1501 │   │   return inner_training_loop(                                                       │
# │   1502 │   │   │   args=args,                                                                    │
# │   1503 │   │   │   resume_from_checkpoint=resume_from_checkpoint,                                │
# │   1504 │   │   │   trial=trial,                                                                  │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/trainer.py:1723 in      │
# │ _inner_training_loop                                                                             │
# │                                                                                                  │
# │   1720 │   │   │   │   self._load_rng_state(resume_from_checkpoint)                              │
# │   1721 │   │   │                                                                                 │
# │   1722 │   │   │   step = -1                                                                     │
# │ ❱ 1723 │   │   │   for step, inputs in enumerate(epoch_iterator):                                │
# │   1724 │   │   │   │                                                                             │
# │   1725 │   │   │   │   # Skip past any already trained steps if resuming training                │
# │   1726 │   │   │   │   if steps_trained_in_current_epoch > 0:                                    │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/utils/data/dataloader.py:681   │
# │ in __next__                                                                                      │
# │                                                                                                  │
# │    678 │   │   │   if self._sampler_iter is None:                                                │
# │    679 │   │   │   │   # TODO(https://github.com/pytorch/pytorch/issues/76750)                   │
# │    680 │   │   │   │   self._reset()  # type: ignore[call-arg]                                   │
# │ ❱  681 │   │   │   data = self._next_data()                                                      │
# │    682 │   │   │   self._num_yielded += 1                                                        │
# │    683 │   │   │   if self._dataset_kind == _DatasetKind.Iterable and \                          │
# │    684 │   │   │   │   │   self._IterableDataset_len_called is not None and \                    │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/utils/data/dataloader.py:721   │
# │ in _next_data                                                                                    │
# │                                                                                                  │
# │    718 │                                                                                         │
# │    719 │   def _next_data(self):                                                                 │
# │    720 │   │   index = self._next_index()  # may raise StopIteration                             │
# │ ❱  721 │   │   data = self._dataset_fetcher.fetch(index)  # may raise StopIteration              │
# │    722 │   │   if self._pin_memory:                                                              │
# │    723 │   │   │   data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)            │
# │    724 │   │   return data                                                                       │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:52  │
# │ in fetch                                                                                         │
# │                                                                                                  │
# │   49 │   │   │   data = [self.dataset[idx] for idx in possibly_batched_index]                    │
# │   50 │   │   else:                                                                               │
# │   51 │   │   │   data = self.dataset[possibly_batched_index]                                     │
# │ ❱ 52 │   │   return self.collate_fn(data)                                                        │
# │   53                                                                                             │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/trainer_utils.py:696 in │
# │ __call__                                                                                         │
# │                                                                                                  │
# │   693 │                                                                                          │
# │   694 │   def __call__(self, features: List[dict]):                                              │
# │   695 │   │   features = [self._remove_columns(feature) for feature in features]                 │
# │ ❱ 696 │   │   return self.data_collator(features)                                                │
# │   697                                                                                            │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/data/data_collator.py:2 │
# │ 49 in __call__                                                                                   │
# │                                                                                                  │
# │    246 │   return_tensors: str = "pt"                                                            │
# │    247 │                                                                                         │
# │    248 │   def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, Any]:                 │
# │ ❱  249 │   │   batch = self.tokenizer.pad(                                                       │
# │    250 │   │   │   features,                                                                     │
# │    251 │   │   │   padding=self.padding,                                                         │
# │    252 │   │   │   max_length=self.max_length,                                                   │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/tokenization_utils_base │
# │ .py:2904 in pad                                                                                  │
# │                                                                                                  │
# │   2901 │   │                                                                                     │
# │   2902 │   │   # The model's main input name, usually `input_ids`, has be passed for padding     │
# │   2903 │   │   if self.model_input_names[0] not in encoded_inputs:                               │
# │ ❱ 2904 │   │   │   raise ValueError(                                                             │
# │   2905 │   │   │   │   "You should supply an encoding or a list of encodings to this method "    │
# │   2906 │   │   │   │   f"that includes {self.model_input_names[0]}, but you provided {list(enco  │
# │   2907 │   │   │   )                                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: You should supply an encoding or a list of encodings to this method that includes input_ids, but you
# provided []
