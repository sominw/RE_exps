# %%
import pandas as pd
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset
from transformers import DataCollatorForSeq2Seq
import torch
import evaluate
import numpy as np
from tqdm import tqdm

# %%
# !pwd
# Out:
# /home/wadhwa.s/gpt3

# %%
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-large", 
                                              cache_dir="/scratch/wadhwa.s/cache", 
                                              device_map="auto")
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-large", 
                                          cache_dir="/scratch/wadhwa.s/cache")

# %%
rouge = evaluate.load("rouge")

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    result = rouge.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    return {k: round(v, 4) for k, v in result.items()}

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

# %%
df = pd.read_csv("ade_gpt3_explanations_responses.csv")
for ix, row in df.iterrows():
    # print("TEXT: ", row["input"])
    row["explanations"] = "Explanation: " + row["explanations"] + "</s>"
    # print ("Relations: ", row["gold_relations"])
    # print (row["explanations"])
    # print ("\n----------------\n")
df.to_csv("ade_gpt3_explanations_responses.csv", index=False)

# %%
ade_data = load_dataset("csv", data_files="ade_gpt3_explanations_responses.csv")
ade_data = ade_data["train"]
# Out:
# Using custom data configuration default-6f29c012792c1789
# Downloading and preparing dataset csv/default to /home/wadhwa.s/.cache/huggingface/datasets/csv/default-6f29c012792c1789/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317...
# Downloading data files: 100%|██████████| 1/1 [00:00<00:00, 6364.65it/s]
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 516.54it/s]
# Generating train split: 0 examples [00:00, ? examples/s]/home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/datasets/download/streaming_download_manager.py:714: FutureWarning: the 'mangle_dupe_cols' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'mangle_dupe_cols'
#   return pd.read_csv(xopen(filepath_or_buffer, "rb", use_auth_token=use_auth_token), **kwargs)
# Dataset csv downloaded and prepared to /home/wadhwa.s/.cache/huggingface/datasets/csv/default-6f29c012792c1789/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
# 100%|██████████| 1/1 [00:00<00:00, 137.51it/s]

# %%
ade = ade_data.train_test_split(test_size=0.2)

prefix = """List the drugs and their corresponding adverse-effects in the following TEXT using [drug, effect] format:\nTEXT: """

print (prefix)
# Out:
# List the drugs and their corresponding adverse-effects in the following TEXT using [drug, effect] format:
# TEXT:

# %%
target = [prefix + example + "\nRelations: " for example in ade["train"]["input"]]
print (target[0])
# Out:
# List the drugs and their corresponding adverse-effects in the following TEXT using [drug, effect] format:
# TEXT: A case of allopurinol hypersensitivity, possibly the first in a black African, is reported.
# Relations:

# %%
def preprocess_function(examples):
    inputs = [prefix + example + "\nRelations: " for example in examples["input"]]
    model_inputs = tokenizer(inputs, max_length=512, truncation=True)
    targets = [gold_relations + "\n" + explanation for gold_relations, explanation in zip(examples["gold_relations"], examples["explanations"])]
    labels = tokenizer(text_target=targets, max_length=256, truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_ade = ade.map(preprocess_function, batched=True)
# Out:
# 100%|██████████| 4/4 [00:01<00:00,  3.39ba/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.97ba/s]

# %%
tokenized_ade
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'explanations', 'gold_relations', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 3403
#     })
#     test: Dataset({
#         features: ['input', 'explanations', 'gold_relations', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 851
#     })
# })

# %%
torch.cuda.empty_cache()

# %%
torch.cuda.empty_cache()

training_args = Seq2SeqTrainingArguments(
    output_dir="/scratch/wadhwa.s/cache/ade_explanations",
    evaluation_strategy="steps",
    learning_rate=3e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    logging_steps=1000,
    eval_delay=600,
    logging_strategy="epoch",
    save_total_limit=7,
    weight_decay=0.01,
    num_train_epochs=10,
    predict_with_generate=True,
    # gradient_accumulation_steps=4,
    # fp16=True,
    # push_to_hub=True,
)

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_ade["train"],
    eval_dataset=tokenized_ade["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: explanations, gold_relations, input. If explanations, gold_relations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 3403
#   Num Epochs = 10
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 8510
#   Number of trainable parameters = 783150080
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# wandb: Currently logged in as: sw7. Use `wandb login --relogin` to force relogin
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/wadhwa.s/gpt3/wandb/run-20230102_202118-209zu129</code>
# Syncing run <strong><a href="https://wandb.ai/sw7/huggingface/runs/209zu129" target="_blank">/scratch/wadhwa.s/cache/ade_explanations</a></strong> to <a href="https://wandb.ai/sw7/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='5104' max='8510' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5104/8510 52:08 < 34:48, 1.63 it/s, Epoch 6.00/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.245100</td>
#       <td>0.163630</td>
#       <td>0.270400</td>
#       <td>0.182400</td>
#       <td>0.269700</td>
#       <td>0.269800</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.167400</td>
#       <td>0.158184</td>
#       <td>0.269800</td>
#       <td>0.182300</td>
#       <td>0.269000</td>
#       <td>0.269100</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.137200</td>
#       <td>0.158266</td>
#       <td>0.269500</td>
#       <td>0.183400</td>
#       <td>0.268700</td>
#       <td>0.268700</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.115100</td>
#       <td>0.154412</td>
#       <td>0.269900</td>
#       <td>0.183900</td>
#       <td>0.269000</td>
#       <td>0.269200</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.100600</td>
#       <td>0.160567</td>
#       <td>0.272200</td>
#       <td>0.187300</td>
#       <td>0.271600</td>
#       <td>0.271600</td>
#       <td>19.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-500
# Configuration saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/ade_explanations/checkpoint-1000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: explanations, gold_relations, input. If explanations, gold_relations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 851
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-1000
# Configuration saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-1000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-1000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-1000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/ade_explanations/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-1500
# Configuration saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-1500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-1500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-1500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/ade_explanations/checkpoint-2000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: explanations, gold_relations, input. If explanations, gold_relations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 851
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-2000
# Configuration saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-2000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-2000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-2000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/ade_explanations/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-2500
# Configuration saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-2500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-2500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-2500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: explanations, gold_relations, input. If explanations, gold_relations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 851
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000
# Configuration saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/ade_explanations/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3500
# Configuration saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/ade_explanations/checkpoint-4000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: explanations, gold_relations, input. If explanations, gold_relations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 851
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-4000
# Configuration saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-4000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-4000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-4000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/ade_explanations/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-4500
# Configuration saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-4500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-4500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-4500/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/ade_explanations/checkpoint-1000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: explanations, gold_relations, input. If explanations, gold_relations, input are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 851
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-5000
# Configuration saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-5000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/ade_explanations/checkpoint-5000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/ade_explanations/checkpoint-5000/spiece.model
# Deleting older checkpoint [/scratch/wadhwa.s/cache/ade_explanations/checkpoint-1500] due to args.save_total_limit
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_12933/4032920361.py:1 in <cell line: 1>                                           │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_12933/4032920361.py'                        │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/trainer.py:1501 in      │
# │ train                                                                                            │
# │                                                                                                  │
# │   1498 │   │   inner_training_loop = find_executable_batch_size(                                 │
# │   1499 │   │   │   self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size  │
# │   1500 │   │   )                                                                                 │
# │ ❱ 1501 │   │   return inner_training_loop(                                                       │
# │   1502 │   │   │   args=args,                                                                    │
# │   1503 │   │   │   resume_from_checkpoint=resume_from_checkpoint,                                │
# │   1504 │   │   │   trial=trial,                                                                  │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/trainer.py:1749 in      │
# │ _inner_training_loop                                                                             │
# │                                                                                                  │
# │   1746 │   │   │   │   │   with model.no_sync():                                                 │
# │   1747 │   │   │   │   │   │   tr_loss_step = self.training_step(model, inputs)                  │
# │   1748 │   │   │   │   else:                                                                     │
# │ ❱ 1749 │   │   │   │   │   tr_loss_step = self.training_step(model, inputs)                      │
# │   1750 │   │   │   │                                                                             │
# │   1751 │   │   │   │   if (                                                                      │
# │   1752 │   │   │   │   │   args.logging_nan_inf_filter                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/trainer.py:2526 in      │
# │ training_step                                                                                    │
# │                                                                                                  │
# │   2523 │   │   │   # loss gets scaled under gradient_accumulation_steps in deepspeed             │
# │   2524 │   │   │   loss = self.deepspeed.backward(loss)                                          │
# │   2525 │   │   else:                                                                             │
# │ ❱ 2526 │   │   │   loss.backward()                                                               │
# │   2527 │   │                                                                                     │
# │   2528 │   │   return loss.detach()                                                              │
# │   2529                                                                                           │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/_tensor.py:396 in backward     │
# │                                                                                                  │
# │    393 │   │   │   │   retain_graph=retain_graph,                                                │
# │    394 │   │   │   │   create_graph=create_graph,                                                │
# │    395 │   │   │   │   inputs=inputs)                                                            │
# │ ❱  396 │   │   torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=input  │
# │    397 │                                                                                         │
# │    398 │   def register_hook(self, hook):                                                        │
# │    399 │   │   r"""Registers a backward hook.                                                    │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/autograd/__init__.py:173 in    │
# │ backward                                                                                         │
# │                                                                                                  │
# │   170 │   # The reason we repeat same the comment below is that                                  │
# │   171 │   # some Python versions print out the first line of a multi-line function               │
# │   172 │   # calls in the traceback and some print out the last line                              │
# │ ❱ 173 │   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the bac   │
# │   174 │   │   tensors, grad_tensors_, retain_graph, create_graph, inputs,                        │
# │   175 │   │   allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to ru   │
# │   176                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
torch.cuda.empty_cache()

# %%
tuned_model = AutoModelForSeq2SeqLM.from_pretrained("/scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000")
tokenizer = AutoTokenizer.from_pretrained("/scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000")
# Out:
# loading configuration file /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000/config.json
# Model config T5Config {
#   "_name_or_path": "/scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2816,
#   "d_kv": 64,
#   "d_model": 1024,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 24,
#   "num_heads": 16,
#   "num_layers": 24,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading weights file /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000/pytorch_model.bin
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at /scratch/wadhwa.s/cache/ade_explanations/checkpoint-3000.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# loading file spiece.model
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json

# %%
ip = []
gold = []
generated = []
nc_count = 0

for _, i in enumerate(tqdm(ade["test"])):
    text = prefix + i["input"] + "\nRelations: "
    inputs = tokenizer(text, return_tensors="pt").input_ids
    outputs = tuned_model.generate(inputs, max_new_tokens=256, do_sample=False)
    out = tokenizer.decode(outputs[0], skip_special_tokens=True)
    torch.cuda.empty_cache()
    try:
        generated.append(out.split(" Explanation: ")[0])
        ip.append(i["input"])
        gold.append(i["gold_relations"])
    except:
        nc_count += 1
        print ("********* Not able to Decode *********")
        print (i["input"])
        print ("Relations: ", i["gold_relations"])
        print ("Generated: ", out)
        print ("\n----------------\n")
    # break
# Out:
# 100%|██████████| 851/851 [2:26:24<00:00, 10.32s/it]

# %%
df = pd.DataFrame({"text": ip, "gold_labels": gold, "generated": generated})
df.to_csv("ade_flan_explanations_generated.csv", index=False)
print (df.shape)
# Out:
# (851, 3)

# %%
# !pwd
# Out:
# /home/wadhwa.s/gpt3

# %%
for text, gold_relations, generated in zip(ip, gold, generated):
    print ("TEXT: ", text)
    print ("Relations: ", gold_relations)
    print ("Generated: ", generated)
    print ("\n----------------\n")
# Out:
# TEXT:  Severe hepatitis caused by cyproterone acetate.
# Relations:  [['cyproterone acetate', 'Severe hepatitis']]
# Generated:  [['cyproterone acetate', 'Severe hepatitis']]
#
# ----------------
#
# TEXT:  Sustained-release procainamide-induced reversible granulocytopenia after myocardial infarction.
# Relations:  [['procainamide', 'reversible granulocytopenia']]
# Generated:  [['procainamide','reversible granulocytopenia']]
#
# ----------------
#
# TEXT:  CASE REPORT: We hereby report a case of radiation recall dermatitis and myositis occurring on gemcitabine monotherapy, five months after completing chemoradiation for locally advanced pancreatic cancer.
# Relations:  [['gemcitabine', 'myositis'], ['gemcitabine', 'radiation recall dermatitis']]
# Generated:  [['gemcitabine','myositis'], ['gemcitabine', 'radiation recall dermatitis']]
#
# ----------------
#
# TEXT:  Hepatic angiosarcoma occurring after cyclophosphamide therapy: case report and review of the literature.
# Relations:  [['cyclophosphamide', 'Hepatic angiosarcoma']]
# Generated:  [['cyclophosphamide', 'Hepatic angiosarcoma']]
#
# ----------------
#
# TEXT:  Cutaneous sarcoidosis during interferon alfa and ribavirin treatment of hepatitis C virus infection: two cases.
# Relations:  [['interferon alfa', 'Cutaneous sarcoidosis'], ['ribavirin', 'Cutaneous sarcoidosis']]
# Generated:  [['interferon alfa', 'Cutaneous sarcoidosis'], ['ribavirin', 'Cutaneous sarcoidosis']]
#
# ----------------
#
# TEXT:  Allopurinol-associated hand and foot deformities in chronic tophaceous gout.
# Relations:  [['Allopurinol', 'hand and foot deformities']]
# Generated:  [['Allopurinol', 'hand and foot deformities']]
#
# ----------------
#
# TEXT:  Methemoglobinemia: an occupational hazard of phenylpropanolamine production.
# Relations:  [['phenylpropanolamine', 'Methemoglobinemia']]
# Generated:  [['phenylpropanolamine', 'Methemoglobinemia']]
#
# ----------------
#
# TEXT:  Metronidazole neuropathy.
# Relations:  [['Metronidazole', 'neuropathy']]
# Generated:  [['Metronidazole', 'neuropathy']]
#
# ----------------
#
# TEXT:  DISCUSSION: Olanzapine, like other atypical antipsychotic drugs, may cause muscle injury with concomitant elevations of serum CK of muscle origin.
# Relations:  [['Olanzapine', 'muscle injury with concomitant elevations of serum CK']]
# Generated:  [['Olanzapine','muscle injury'], ['Olanzapine', 'elevations of serum CK of muscle origin']]
#
# ----------------
#
# TEXT:  A depressed woman with no history of bipolar illness developed a manic episode during treatment with fluoxetine.
# Relations:  [['fluoxetine', 'manic episode']]
# Generated:  [['fluoxetine','manic episode']]
#
# ----------------
#
# TEXT:  Sudden cardiac death due to hypersensitivity myocarditis during clozapine treatment.
# Relations:  [['clozapine', 'hypersensitivity myocarditis'], ['clozapine', 'Sudden cardiac death']]
# Generated:  [['clozapine', 'hypersensitivity myocarditis'], ['clozapine', 'Sudden cardiac death']]
#
# ----------------
#
# TEXT:  Treatment of amiodarone-induced thyrotoxicosis (AIT) with thionamide, lithium or radioactive iodine is ineffective.
# Relations:  [['amiodarone', 'thyrotoxicosis']]
# Generated:  [['amiodarone', 'thyrotoxicosis']]
#
# ----------------
#
# TEXT:  How low can you go? Use of very low dosage of gold in patients with mucocutaneous reactions.
# Relations:  [['gold', 'mucocutaneous reactions']]
# Generated:  [['gold','mucocutaneous reactions']]
#
# ----------------
#
# TEXT:  Cardiorespiratory toxicity due to miconazole.
# Relations:  [['miconazole', 'Cardiorespiratory toxicity']]
# Generated:  [['miconazole', 'Cardiorespiratory toxicity']]
#
# ----------------
#
# TEXT:  After a second dose of metoclopramide, these symptoms recurred and were associated with confusion, agitation, fever, diaphoresis, tachypnea, tachycardia, and hypertension.
# Relations:  [['metoclopramide', 'agitation'], ['metoclopramide', 'confusion'], ['metoclopramide', 'diaphoresis'], ['metoclopramide', 'fever'], ['metoclopramide', 'hypertension'], ['metoclopramide', 'tachycardia'], ['metoclopramide', 'tachypnea']]
# Generated:  [['metoclopramide', 'agitation'], ['metoclopramide', 'fever'], ['metoclopramide', 'diaphoresis'], ['metoclopramide', 'tachycardia'], ['metoclopramide', 'tachycardia'], ['metoclopramide', 'tachycardia'], ['metoclopramide', 'tachycardia'], ['metoclopramide', 'tachycardia'], ['metoclopramide', 'tachycardia'], ['metoclopramide', 'tachycardia'], ['metoclopramide', 'tachycardia'], ['metoclopramide', 'tachycardia'], ['metoclopramide', 'tachycardia'], ['metoclopramide', '
#
# ----------------
#
# TEXT:  We report a patient who experienced LABD shortly after starting carbamazepine therapy.
# Relations:  [['carbamazepine', 'LABD']]
# Generated:  [['carbamazepine', 'LABD']]
#
# ----------------
#
# TEXT:  Cardiac decompensation following verapamil therapy in infants with supraventricular tachycardia.
# Relations:  [['verapamil', 'Cardiac decompensation']]
# Generated:  [['verapamil', 'Cardiac decompensation']]
#
# ----------------
#
# TEXT:  Thus any case of severe neutropenia occurring in a patient receiving olanzapine is alarming to clinicians.
# Relations:  [['olanzapine', 'severe neutropenia']]
# Generated:  [['olanzapine','severe neutropenia']]
#
# ----------------
#
# TEXT:  The potential development of SJS/TEN, a severe life-threatening illness, emphasizes the need for judicious use of TMP-Sx and close monitoring and follow-up for patients who were given TMP-Sx for SSTIs.
# Relations:  [['TMP-Sx', 'SJS'], ['TMP-Sx', 'TEN']]
# Generated:  [['TMP-Sx', 'SJS/TEN']]
#
# ----------------
#
# TEXT:  Dyspnea possibly associated with controlled-release morphine sulfate tablets.
# Relations:  [['morphine sulfate', 'Dyspnea']]
# Generated:  [['morphine sulfate', 'Dyspnea']]
#
# ----------------
#
# TEXT:  We report 2 cases of maculopapular eruption and fever in patients infected with human immunodeficiency virus (HIV) on the 2nd day of first administration of ritonavir, a protease inhibitor.
# Relations:  [['ritonavir', 'fever'], ['ritonavir', 'maculopapular eruption']]
# Generated:  [['ritonavir', 'fever'], ['ritonavir','maculopapular eruption']]
#
# ----------------
#
# TEXT:  Nitrofurantoin-induced acute liver damage in pregnancy.
# Relations:  [['Nitrofurantoin', 'acute liver damage']]
# Generated:  [['Nitrofurantoin', 'acute liver damage']]
#
# ----------------
#
# TEXT:  A 70-year-old man was admitted to our hospital because of dyspnea after taking an antihistaminic agent (homochlorcyclizine hydrochloride) for itching.
# Relations:  [['homochlorcyclizine hydrochloride', 'dyspnea']]
# Generated:  [['homochlorcyclizine hydrochloride', 'dyspnea']]
#
# ----------------
#
# TEXT:  Epoprostenol may be associated rarely with severe erythroderma.
# Relations:  [['Epoprostenol', 'erythroderma']]
# Generated:  [['Epoprostenol', 'erythroderma']]
#
# ----------------
#
# TEXT:  CONCLUSIONS: Because of its structural similarity to the other vinca alkaloids, vinorelbine is believed to be responsible for SIADH in our patient.
# Relations:  [['vinorelbine', 'SIADH']]
# Generated:  [['vinorelbine', 'SIADH']]
#
# ----------------
#
# TEXT:  We describe a 43-year-old man who developed signs and symptoms of bilateral optic neuropathy during treatment with ethambutol.
# Relations:  [['ethambutol', 'bilateral optic neuropathy']]
# Generated:  [['ethambutol', 'bilateral optic neuropathy']]
#
# ----------------
#
# TEXT:  This is the first report on the histopathological findings of thyroid tissue from a patient with amiodarone-induced hypothyroidism.
# Relations:  [['amiodarone', 'hypothyroidism']]
# Generated:  [['amiodarone', 'hypothyroidism']]
#
# ----------------
#
# TEXT:  MR findings in methotrexate-induced CNS abnormalities.
# Relations:  [['methotrexate', 'CNS abnormalities'], ['methotrexate', 'CNS abnormalities']]
# Generated:  [['methotrexate', 'CNS abnormalities']]
#
# ----------------
#
# TEXT:  In addition to the recognized arrhythmic complications, the authors emphasize myocardial necrosis as a possible further manifestation of amsacrine-related cardiotoxicity.
# Relations:  [['amsacrine', 'cardiotoxicity'], ['amsacrine', 'myocardial necrosis']]
# Generated:  [['amsacrine', 'cardiotoxicity'], ['amsacrine','myocardial necrosis']]
#
# ----------------
#
# TEXT:  Aminophylline hypersensitivity apparently due to ethylenediamine.
# Relations:  [['Aminophylline', 'Aminophylline hypersensitivity'], ['ethylenediamine', 'Aminophylline hypersensitivity']]
# Generated:  [['ethylenediamine', 'hypersensitivity'], ['Aminophylline', 'hypersensitivity']]
#
# ----------------
#
# TEXT:  Toxic epidermal necrolysis resulted after 19 days of treatment with 5-fluorocytosine and amphotericin B.
# Relations:  [['5-fluorocytosine', 'Toxic epidermal necrolysis'], ['amphotericin B', 'Toxic epidermal necrolysis']]
# Generated:  [['5-fluorocytosine', 'Toxic epidermal necrolysis'], ['amphotericin B', 'Toxic epidermal necrolysis']]
#
# ----------------
#
# TEXT:  Development of tics in a thirteen-year-old male following atomoxetine use.
# Relations:  [['atomoxetine', 'tics']]
# Generated:  [['atomoxetine', 'tics']]
#
# ----------------
#
# TEXT:  Provocation of non-convulsive status epilepticus by tiagabine in three adolescent patients.
# Relations:  [['tiagabine', 'non-convulsive status epilepticus']]
# Generated:  [['tiagabine', 'non-convulsive status epilepticus']]
#
# ----------------
#
# TEXT:  We report a case of myoclonus induced by quetiapine.
# Relations:  [['quetiapine', 'myoclonus']]
# Generated:  [['quetiapine','myoclonus']]
#
# ----------------
#
# TEXT:  We report the first case of polymorphic ventricular tachycardia with normal QT interval associated with the oral use of levofloxacin in the absence of other etiologies known to cause these arrhythmias.
# Relations:  [['levofloxacin', 'polymorphic ventricular tachycardia']]
# Generated:  [['levofloxacin', 'polymorphic ventricular tachycardia with normal QT interval']]
#
# ----------------
#
# TEXT:  Cyclosporine-induced pain syndrome in a child undergoing hematopoietic stem cell transplant.
# Relations:  [['Cyclosporine', 'pain syndrome']]
# Generated:  [['Cyclosporine', 'pain syndrome']]
#
# ----------------
#
# TEXT:  BACKGROUND: How to best treat psychotic patients who have had past clozapine-induced agranulocytosis or granulocytopenia remains a problem.
# Relations:  [['clozapine', 'granulocytopenia']]
# Generated:  [['clozapine', 'agranulocytosis'], ['clozapine', 'granulocytopenia']]
#
# ----------------
#
# TEXT:  Metastatic osteomyelitis following BCG vaccination.
# Relations:  [['BCG', 'Metastatic osteomyelitis']]
# Generated:  [['BCG', 'Metastatic osteomyelitis']]
#
# ----------------
#
# TEXT:  Beneficial effect of low-dose mianserin on fluvoxamine-induced akathisia in an obsessive-compulsive patient.
# Relations:  [['fluvoxamine', 'akathisia']]
# Generated:  [['fluvoxamine', 'akathisia']]
#
# ----------------
#
# TEXT:  Two infants developed hyperkalemia shortly after cessation of prolonged ACTH therapy for infantile spasms.
# Relations:  [['ACTH', 'hyperkalemia']]
# Generated:  [['ACTH', 'hyperkalemia']]
#
# ----------------
#
# TEXT:  In all the patients, pellagra symptoms appeared during isoniazid therapy.
# Relations:  [['isoniazid', 'pellagra']]
# Generated:  [['isoniazid', 'pellagra symptoms']]
#
# ----------------
#
# TEXT:  In one instance a systemic hypoglycemic reaction resulting in head trauma and confusion ended in an emegency hospital admission following the substitution of acetohexamide for acetazolamide.
# Relations:  [['acetohexamide', 'confusion'], ['acetohexamide', 'head trauma'], ['acetohexamide', 'systemic hypoglycemic reaction']]
# Generated:  [['acetohexamide', 'confusion'], ['acetazolamide', 'confusion'], ['acetohexamide', 'head trauma'], ['acetazolamide', 'head trauma'], ['acetohexamide','systemic hypoglycemic reaction'], ['acetazolamide','systemic hypoglycemic reaction'], ['acetohexamide', 'head trauma'], ['acetazolamide', 'head trauma']]
#
# ----------------
#
# TEXT:  Intravenous diazepam exacerbated the seizures.
# Relations:  [['diazepam', 'seizures']]
# Generated:  [['diazepam','seizures']]
#
# ----------------
#
# TEXT:  CONCLUSIONS: The value of multihormonal therapy in breast carcinoma is not established, and the addition of progestogens to tamoxifen may not reduce of developing endometrial lesions, including carcinoma.
# Relations:  [['tamoxifen', 'carcinoma'], ['tamoxifen', 'endometrial lesions']]
# Generated:  [['tamoxifen', 'carcinoma']]
#
# ----------------
#
# TEXT:  This case suggests that acyclovir when given intravenously in doses of 10 mg/kg may result in increased serum lithium concentrations.
# Relations:  [['acyclovir', 'increased serum lithium'], ['lithium', 'increased serum lithium']]
# Generated:  [['acyclovir', 'increased serum lithium concentrations']]
#
# ----------------
#
# TEXT:  The patient experienced muscle twitches, tremulousness, and anxiety on day 17 of foscarnet therapy.
# Relations:  [['foscarnet', 'anxiety'], ['foscarnet', 'muscle twitches'], ['foscarnet', 'tremulousness']]
# Generated:  [['foscarnet', 'anxiety'], ['foscarnet','muscle twitches'], ['foscarnet', 'tremulousness']]
#
# ----------------
#
# TEXT:  Anaphylactoid reaction to methylprednisolone pulsed therapy for multiple sclerosis.
# Relations:  [['methylprednisolone', 'Anaphylactoid reaction']]
# Generated:  [['methylprednisolone', 'Anaphylactoid reaction']]
#
# ----------------
#
# TEXT:  RESULTS: Two patients with ocular inflammation of unknown origin developed severe chorioretinitis after IVTA injection.
# Relations:  [['IVTA', 'severe chorioretinitis']]
# Generated:  [['IVTA', 'chorioretinitis']]
#
# ----------------
#
# TEXT:  We report a case of reversible DKA and new-onset DM that developed in a demented patient who was treated with quetiapine for 14 days.
# Relations:  [['quetiapine', 'DKA'], ['quetiapine', 'DM']]
# Generated:  [['quetiapine','reversible DKA'], ['quetiapine', 'new-onset DM']]
#
# ----------------
#
# TEXT:  Lovastatin-induced rhabdomyolysis possibly associated with clarithromycin and azithromycin.
# Relations:  [['azithromycin', 'rhabdomyolysis'], ['clarithromycin', 'rhabdomyolysis'], ['Lovastatin', 'rhabdomyolysis']]
# Generated:  [['Azithromycin', 'rhabdomyolysis'], ['Lovastatin', 'rhabdomyolysis'], ['clarithromycin', 'rhabdomyolysis'], ['Lovastatin', 'rhabdomyolysis']]
#
# ----------------
#
# TEXT:  An encephalopathy and cardiomyopathy developed in a seventeen-year-old girl with chemotherapy-induced renal failure while receiving an intravesical aluminum infusion for hemorrhagic cystitis.
# Relations:  [['aluminum', 'cardiomyopathy'], ['aluminum', 'encephalopathy']]
# Generated:  [['aluminum', 'cardiomyopathy'], ['aluminum', 'encephalopathy'], ['aluminum','renal failure']]
#
# ----------------
#
# TEXT:  Although this type of hyperpigmentation has been previously seen in patients with cancer who are receiving bleomycin, this is, to our knowledge, the first reported case of bleomycin-induced hyperpigmentation in an AIDS patient and should be added to the growing list of cutaneous eruptions seen in these patients.
# Relations:  [['bleomycin', 'hyperpigmentation'], ['bleomycin', 'hyperpigmentation']]
# Generated:  [['bleomycin', 'hyperpigmentation']]
#
# ----------------
#
# TEXT:  Neurological side effects in two patients receiving gold injections for rheumatoid arthritis.
# Relations:  [['gold', 'Neurological side effects']]
# Generated:  [['gold', 'Neurological side effects']]
#
# ----------------
#
# TEXT:  A patient with psoriasis is described who had an abnormal response to the glucose tolerance test without other evidence of diabetes and then developed postprandial hyperglycemia and glycosuria during a period of topical administration of a corticosteroid cream, halcinonide cream 0.1%, under occlusion.
# Relations:  [['halcinonide', 'glycosuria'], ['halcinonide', 'postprandial hyperglycemia']]
# Generated:  [['halcinonide cream 0.1%', 'glycosuria'], ['halcinonide cream 0.1%', 'postprandial hyperglycemia']]
#
# ----------------
#
# TEXT:  Gemcitabine-induced rectus abdominus radiation recall.
# Relations:  [['Gemcitabine', 'rectus abdominus radiation recall']]
# Generated:  [['Gemcitabine','rectus abdominus radiation recall']]
#
# ----------------
#
# TEXT:  Bilateral acoustic (VIII) nerve palsy in this patient was most likely a manifestation of vincristine neurotoxicity.
# Relations:  [['vincristine', 'Bilateral acoustic (VIII) nerve palsy'], ['vincristine', 'neurotoxicity']]
# Generated:  [['vincristine', 'Bilateral acoustic (VIII) nerve palsy'], ['vincristine', 'neurotoxicity']]
#
# ----------------
#
# TEXT:  An objective causality assessment by use of the Naranjo probability scale revealed that NCSE due to ifosfamide was probable.
# Relations:  [['ifosfamide', 'NCSE']]
# Generated:  [['ifosfamide', 'NCSE']]
#
# ----------------
#
# TEXT:  Case report: life-threatening hypoglycaemia associated with sulfadoxine-pyrimethamine, a commonly used antimalarial drug.
# Relations:  [['sulfadoxine-pyrimethamine', 'life-threatening hypoglycaemia']]
# Generated:  [['sulfadoxine-pyrimethamine', 'hypoglycaemia']]
#
# ----------------
#
# TEXT:  A 52 year-old male patient diagnosed of ankylosing spondylitis presented with an iron deficiency anemia after a ten-month treatment of methotrexate.
# Relations:  [['methotrexate', 'iron deficiency anemia']]
# Generated:  [['methotrexate', 'iron deficiency anemia']]
#
# ----------------
#
# TEXT:  We present a case of severe unilateral posterior scleritis associated with zoledronic acid administration that was recognized and treated in a timely manner.
# Relations:  [['zoledronic acid', 'severe unilateral posterior scleritis']]
# Generated:  [['zoledronic acid','severe unilateral posterior scleritis']]
#
# ----------------
#
# TEXT:  It was postulated that the allergic reaction was most likely caused by capecitabine or the intermediate metabolites based on the immediate reappearance of symptoms from the rechallenge, pharmacokinetic data, and well-tolerance of fluorouracil.
# Relations:  [['capecitabine', 'allergic reaction']]
# Generated:  [['capecitabine', 'allergic reaction'], ['fluorouracil', 'allergic reaction']]
#
# ----------------
#
# TEXT:  Sertraline-induced rhabdomyolysis in an elderly patient with dementia and comorbidities.
# Relations:  [['Sertraline', 'rhabdomyolysis']]
# Generated:  [['Sertraline', 'rhabdomyolysis']]
#
# ----------------
#
# TEXT:  This is the first histologically confirmed case of NASH that was aggravated by raloxifene.
# Relations:  [['raloxifene', 'NASH']]
# Generated:  [['raloxifene', 'NASH']]
#
# ----------------
#
# TEXT:  Until additional data are available, if intravenous acyclovir is administered concurrently with lithium, we recommend closely monitoring patients for signs of lithium toxicity and measuring serum lithium levels every second or third day.
# Relations:  [['acyclovir', 'lithium toxicity'], ['lithium', 'lithium toxicity']]
# Generated:  [['lithium', 'lithium toxicity'], ['acyclovir', 'lithium toxicity']]
#
# ----------------
#
# TEXT:  Moreover, these findings suggest that the incidence of BOOP following rituximab therapy may be higher than has been previously appreciated.
# Relations:  [['rituximab', 'BOOP']]
# Generated:  [['rituximab', 'BOOP']]
#
# ----------------
#
# TEXT:  Hyperpigmentation during interferon-alpha therapy for chronic hepatitis C virus infection.
# Relations:  [['interferon-alpha', 'Hyperpigmentation']]
# Generated:  [['interferon-alpha', 'Hyperpigmentation']]
#
# ----------------
#
# TEXT:  Nine azotemic patients who developed a coagulopathy associated with the use of either cephalosporin or moxalactam antibiotics are reported.
# Relations:  [['cephalosporin', 'coagulopathy'], ['moxalactam', 'coagulopathy']]
# Generated:  [['cephalosporin', 'coagulopathy'], ['moxalactam', 'coagulopathy']]
#
# ----------------
#
# TEXT:  His impaired memory was found to be due to the atenolol he was on and he made a complete recovery on withdrawing the beta-blocker.
# Relations:  [['atenolol', 'impaired memory']]
# Generated:  [['atenolol', 'impaired memory']]
#
# ----------------
#
# TEXT:  Fulminant hepatic failure is a rare complication of disulfiram treatment for alcoholism.
# Relations:  [['disulfiram', 'Fulminant hepatic failure']]
# Generated:  [['disulfiram', 'Fulminant hepatic failure']]
#
# ----------------
#
# TEXT:  Thus, we confirm that desensitization may be a safe procedure in patients with cancer who experience methotrexate-induced anaphylaxis.
# Relations:  [['methotrexate', 'anaphylaxis']]
# Generated:  [['methotrexate', 'anaphylaxis']]
#
# ----------------
#
# TEXT:  Warfarin-associated bleeding complication saved life.
# Relations:  [['Warfarin', 'bleeding']]
# Generated:  [['Warfarin', 'bleeding complication']]
#
# ----------------
#
# TEXT:  Eleven days after initiation of therapy with amiodarone, the patient experienced syncope and was noted to have recurrent episodes of polymorphous ventricular tachycardia.
# Relations:  [['amiodarone', 'polymorphous ventricular tachycardia'], ['amiodarone', 'syncope']]
# Generated:  [['amiodarone', 'polymorphous ventricular tachycardia'], ['amiodarone','syncope']]
#
# ----------------
#
# TEXT:  We report the first case of IHA associated with cefuroxime administration.
# Relations:  [['cefuroxime', 'IHA']]
# Generated:  [['cefuroxime', 'IHA']]
#
# ----------------
#
# TEXT:  Multiple pulmonary nodules: an unusual presentation of fludarabine pulmonary toxicity: case report and review of literature.
# Relations:  [['fludarabine', 'Multiple pulmonary nodules'], ['fludarabine', 'pulmonary toxicity']]
# Generated:  [['fludarabine', 'pulmonary toxicity'], ['fludarabine', 'Multiple pulmonary nodules']]
#
# ----------------
#
# TEXT:  Acute reversible ataxo-myoclonic encephalopathy with flecainide therapy.
# Relations:  [['flecainide', 'Acute reversible ataxo-myoclonic encephalopathy']]
# Generated:  [['flecainide', 'Acute reversible ataxo-myoclonic encephalopathy']]
#
# ----------------
#
# TEXT:  Propylthiouracil-induced sensorineural hearing loss associated with antineutrophil cytoplasmic antibodies.
# Relations:  [['Propylthiouracil', 'antineutrophil cytoplasmic antibodies'], ['Propylthiouracil', 'sensorineural hearing loss']]
# Generated:  [['Propylthiouracil','sensorineural hearing loss']]
#
# ----------------
#
# TEXT:  We cared for a patient with progressive renal impairment who presented with blurred vision, QRS broadening and cardiac failure due to chronic cibenzoline intoxication.
# Relations:  [['cibenzoline', 'blurred vision'], ['cibenzoline', 'cardiac failure'], ['cibenzoline', 'cibenzoline intoxication'], ['cibenzoline', 'QRS broadening']]
# Generated:  [['cibenzoline', 'cardiac failure'], ['cibenzoline', 'blurry vision'], ['cibenzoline', 'QRS broadening']]
#
# ----------------
#
# TEXT:  CONCLUSIONS: Symptoms and pathologic changes of colitis are associated with exposure to rofecoxib.
# Relations:  [['rofecoxib', 'colitis']]
# Generated:  [['rofecoxib', 'colitis']]
#
# ----------------
#
# TEXT:  Toxic optic neuropathy associated with ethambutol: implications for current therapy.
# Relations:  [['ethambutol', 'Toxic optic neuropathy']]
# Generated:  [['ethambutol', 'Toxic optic neuropathy']]
#
# ----------------
#
# TEXT:  PET scintigraphy of etoposide-induced pulmonary toxicity.
# Relations:  [['etoposide', 'pulmonary toxicity']]
# Generated:  [['etoposide', 'pulmonary toxicity']]
#
# ----------------
#
# TEXT:  CONCLUSION: All doctors need to be aware of the need to review the indications for gabapentin use during periods of acute illness, especially with regard to renal impairment.
# Relations:  [['gabapentin', 'renal impairment']]
# Generated:  [['gabapentin','renal impairment']]
#
# ----------------
#
# TEXT:  Severe respiratory syncytial virus pulmonary infection in a patient treated with fludarabine for chronic lymphocytic leukemia.
# Relations:  [['fludarabine', 'Severe respiratory syncytial virus pulmonary infection']]
# Generated:  [['fludarabine', 'Severe respiratory syncytial virus pulmonary infection']]
#
# ----------------
#
# TEXT:  We report two cases of cerebrospinal fluid eosinophilia (CSFE) secondary to the intraventricular administration of vancomycin.
# Relations:  [['vancomycin', 'cerebrospinal fluid eosinophilia'], ['vancomycin', 'CSFE']]
# Generated:  [['vancomycin', 'cerebrospinal fluid eosinophilia'], ['vancomycin', 'CSFE']]
#
# ----------------
#
# TEXT:  We report an 82-year-old man who developed ventricular tachycardia and Torsades de Pointes (TdP) after oral administration of garenoxacin, a novel quinolone antibiotic agent that differs from the third-generation quinolones, for pneumonia.
# Relations:  [['garenoxacin', 'TdP'], ['garenoxacin', 'Torsades de Pointes'], ['garenoxacin', 'ventricular tachycardia']]
# Generated:  [['garenoxacin','ventricular tachycardia'], ['garenoxacin', 'TdP'], ['garenoxacin', 'TdP'], ['garenoxacin', 'TdP'], ['garenoxacin', 'TdP']]
#
# ----------------
#
# TEXT:  Fatal digoxin poisoning: an unsuccessful resuscitation with use of digoxin-immune Fab.
# Relations:  [['digoxin', 'Fatal digoxin poisoning']]
# Generated:  [['digoxin', 'Fatal digoxin poisoning']]
#
# ----------------
#
# TEXT:  Can propofol precipitate pancreatitis in patients with Cushing's syndrome?
# Relations:  [['propofol', 'pancreatitis']]
# Generated:  [['propofol', 'pancreatitis']]
#
# ----------------
#
# TEXT:  Acute psychosis associated with levetiracetam.
# Relations:  [['levetiracetam', 'Acute psychosis']]
# Generated:  [['levetiracetam', 'Acute psychosis']]
#
# ----------------
#
# TEXT:  She continued taking verapamil for 6 months, then, on her own, stopped all medications including the sustained-release verapamil, and her asthma symptoms disappeared.
# Relations:  [['verapamil', 'asthma']]
# Generated:  [['verapamil', 'asthma symptoms']]
#
# ----------------
#
# TEXT:  A 52-year-old Black woman on phenytoin therapy for post-traumatic epilepsy developed transient hemiparesis contralateral to the injury.
# Relations:  [['phenytoin', 'transient hemiparesis']]
# Generated:  [['phenytoin', 'transient hemiparesis']]
#
# ----------------
#
# TEXT:  Autopsy evidence of herpesvirus infection was found in visceral organs of four leukemic patients who had received large doses of cytarabine (cytosine arabinoside; Ara-C) shortly before their death.
# Relations:  [['Ara-C', 'herpesvirus infection'], ['cytarabine', 'herpesvirus infection'], ['cytosine arabinoside', 'herpesvirus infection']]
# Generated:  [['cytarabine', 'herpesvirus infection'], ['cytosine arabinoside', 'herpesvirus infection'], ['Ara-C', 'herpesvirus infection'], ['cytarabine', 'herpesvirus infection'], ['cytosine arabinoside', 'herpesvirus infection']]
#
# ----------------
#
# TEXT:  Cytarabine-induced cerebellar syndrome: case report and literature review.
# Relations:  [['Cytarabine', 'cerebellar syndrome']]
# Generated:  [['Cytarabine', 'cerebellar syndrome']]
#
# ----------------
#
# TEXT:  These cases were considered unusual in light of the short delay of their onset after initiation of immunosuppressive therapy and their fulminant course: 3 of these patients died of PCP occurring during the first month of treatment with prednisone.
# Relations:  [['prednisone', 'died']]
# Generated:  [['prednisone', 'PCP']]
#
# ----------------
#
# TEXT:  On the next day, after a total dose of only 600 mg of danazol, gingival bleeding and purpura occurred.
# Relations:  [['danazol', 'gingival bleeding'], ['danazol', 'purpura']]
# Generated:  [['danazol', 'gingival bleeding'], ['danazol', 'purpura']]
#
# ----------------
#
# TEXT:  We describe a 41 yr old leprosy patient treated for 10 yrs with clofazimine who underwent laparotomy for severe abdominal pain.
# Relations:  [['clofazimine', 'abdominal pain']]
# Generated:  [['clofazimine', 'abdominal pain']]
#
# ----------------
#
# TEXT:  A case of metoclopramide-induced oculogyric crisis in a 16-year-old girl with cystic fibrosis.
# Relations:  [['metoclopramide', 'oculogyric crisis']]
# Generated:  [['metoclopramide', 'oculogyric crisis']]
#
# ----------------
#
# TEXT:  Long-term follow-up after neoplastic seeding complicating percutaneous ethanol injection for treatment of hepatocellular carcinoma.
# Relations:  [['ethanol', 'neoplastic seeding']]
# Generated:  [['ethanol injection', 'neoplastic seeding']]
#
# ----------------
#
# TEXT:  Intrahepatic cholestasis and sicca complex after thiabendazole.
# Relations:  [['thiabendazole', 'Intrahepatic cholestasis'], ['thiabendazole', 'sicca complex']]
# Generated:  [['thiabendazole', 'Intrahepatic cholestasis'], ['thiabendazole','sicca complex']]
#
# ----------------
#
# TEXT:  Colonic necrosis is known as a rare complication following the administration of Kayexalate (sodium polystryrene sulfonate) in sorbitol.
# Relations:  [['Kayexalate', 'Colonic necrosis'], ['sodium polystryrene sulfonate', 'Colonic necrosis']]
# Generated:  [['Kayexalate', 'Colonic necrosis'], ['sorbitol', 'Colonic necrosis']]
#
# ----------------
#
# TEXT:  We report the occurrence of spontaneous intracranial bleeding in an human immunodeficiency virus (HIV)-infected adolescent with hemophilia A who was receiving amprenavir (APV).
# Relations:  [['amprenavir', 'intracranial bleeding']]
# Generated:  [['amprenavir', 'intracraneal bleeding'], ['APV', 'intracraneal bleeding']]
#
# ----------------
#
# TEXT:  Primary CNS lymphoma regressed on withdrawal of MM.
# Relations:  [['MM', 'CNS lymphoma']]
# Generated:  [['MM', 'Primary CNS lymphoma']]
#
# ----------------
#
# TEXT:  A 50-year-old woman with a history of migraine without aura, predominantly occurring around her menstrual periods, developed a spinal cord lesion following the use of zolmitriptan.
# Relations:  [['zolmitriptan', 'spinal cord lesion']]
# Generated:  [['zolmitriptan','spinal cord lesion']]
#
# ----------------
#
# TEXT:  Prolonged severe cholestasis induced by oxacillin derivatives.
# Relations:  [['oxacillin', 'severe cholestasis']]
# Generated:  [['oxacillin', 'Prolonged severe cholestasis']]
#
# ----------------
#
# TEXT:  Myotonia associated with sarcoidosis: marked exacerbation with pravastatin.
# Relations:  [['pravastatin', 'Myotonia']]
# Generated:  [['pravastatin', 'Myotonia']]
#
# ----------------
#
# TEXT:  Risperidone-induced obsessive-compulsive symptoms in two children.
# Relations:  [['Risperidone', 'obsessive-compulsive symptoms']]
# Generated:  [['Risperidone', 'obsessive-compulsive symptoms']]
#
# ----------------
#
# TEXT:  We describe in detail the first U.S. case report, of a 4(1/2)-year-old boy who experienced angioedema during treatment with oxcarbazepine.
# Relations:  [['oxcarbazepine', 'angioedema']]
# Generated:  [['oxcarbazepine', 'angioedema']]
#
# ----------------
#
# TEXT:  His fever resolved, but he developed symptoms consistent with those of chloroquine toxicity.
# Relations:  [['chloroquine', 'chloroquine toxicity']]
# Generated:  [['chloroquine', 'chloroquine toxicity']]
#
# ----------------
#
# TEXT:  Nephrotic syndrome associated with lithium therapy.
# Relations:  [['lithium', 'Nephrotic syndrome']]
# Generated:  [['lithium', 'Nephrotic syndrome']]
#
# ----------------
#
# TEXT:  The renal biopsy showed focal segmental glomerulosclerosis, which has only been previously reported in two cases of CML treated with IFNalpha.
# Relations:  [['IFNalpha', 'focal segmental glomerulosclerosis']]
# Generated:  [['IFNalpha', 'focal segmental glomerulosclerosis']]
#
# ----------------
#
# TEXT:  The patient was initially treated with hydration and furosemide but developed congestive heart failure.
# Relations:  [['furosemide', 'congestive heart failure']]
# Generated:  [['furosemide', 'congestive heart failure']]
#
# ----------------
#
# TEXT:  Can magnesium sulfate therapy impact lactogenesis?
# Relations:  [['magnesium sulfate', 'lactogenesis']]
# Generated:  [['magnesium sulfate', 'lactogenesis']]
#
# ----------------
#
# TEXT:  An adverse reaction to IFN was strongly suspected as the cause of CHF.
# Relations:  [['IFN', 'CHF']]
# Generated:  [['IFN', 'CHF']]
#
# ----------------
#
# TEXT:  Theophylline intoxication mimicking diabetic ketoacidosis in a child.
# Relations:  [['Theophylline', 'Theophylline intoxication']]
# Generated:  [['Theophylline', 'diabetic ketoacidosis'], ['Theophylline', 'Theophylline intoxication']]
#
# ----------------
#
# TEXT:  Although heparin-dependent antibodies (HDAs) typically manifest with thrombocytopenia as in heparin-induced thrombocytopenia (HIT), they may also manifest with preserved platelet counts.
# Relations:  [['heparin', 'thrombocytopenia']]
# Generated:  [['heparin', 'preserved platelet counts'], ['heparin', 'thrombocytopenia'], ['heparin', 'HIT'], ['heparin', 'thrombocytopenia']]
#
# ----------------
#
# TEXT:  Vanishing bile duct and Stevens-Johnson syndrome associated with ciprofloxacin treated with tacrolimus.
# Relations:  [['ciprofloxacin', 'Stevens-Johnson syndrome'], ['ciprofloxacin', 'Vanishing bile duct']]
# Generated:  [['ciprofloxacin', 'Vanishing bile duct'], ['tacrolimus', 'Stevens-Johnson syndrome'], ['ciprofloxacin', 'Stevens-Johnson syndrome']]
#
# ----------------
#
# TEXT:  In addition to its known effect on gallbladder stasis, octreotide alters bile acid composition and may thus hasten intrahepatic sludge and stone formation.
# Relations:  [['octreotide', 'alters bile acid composition'], ['octreotide', 'gallbladder stasis'], ['octreotide', 'hasten intrahepatic sludge'], ['octreotide', 'stone formation']]
# Generated:  [['octreotide','stone formation'], ['octreotide', 'adverse effects on gallbladder stasis'], ['octreotide', 'adverse effects on intrahepatic sludge']]
#
# ----------------
#
# TEXT:  We report the case histories of identical twin brothers who developed concordant acute lymphoblastic leukemia at the age of 4 years and who later developed leukoencephalopathy and hydrocephalus related to central nervous system prophylaxis by, in the first case intrathecally administered methotrexate and, in the second by intrathecally administered methotrexate and cranial irradiation.
# Relations:  [['methotrexate', 'hydrocephalus'], ['methotrexate', 'hydrocephalus'], ['methotrexate', 'leukoencephalopathy'], ['methotrexate', 'leukoencephalopathy']]
# Generated:  [['methotrexate', 'leukoencephalopathy'], ['methotrexate', 'hydrocephalus'], ['methotrexate', 'central nervous system prophylaxis'], ['methotrexate', 'hypercephalus']]
#
# ----------------
#
# TEXT:  Alprazolam-induced mania: two clinical cases.
# Relations:  [['Alprazolam', 'mania']]
# Generated:  [['Alprazolam','mania']]
#
# ----------------
#
# TEXT:  Seizures and transient blindness following intravenous pulse methylprednisolone in children with primary glomerulonephritis.
# Relations:  [['methylprednisolone', 'Seizures'], ['methylprednisolone', 'transient blindness']]
# Generated:  [['methylprednisolone', 'Seizures'], ['methylprednisolone', 'transient blindness']]
#
# ----------------
#
# TEXT:  Cardiac arrest associated with sulprostone use during caesarean section.
# Relations:  [['sulprostone', 'Cardiac arrest']]
# Generated:  [['sulprostone', 'Cardiac arrest']]
#
# ----------------
#
# TEXT:  This is, to the best of our knowledge, the first report of a case in which agranulocytosis followed treatment with both propylthiouracil and methimazole in the same patient.
# Relations:  [['methimazole', 'agranulocytosis'], ['propylthiouracil', 'agranulocytosis']]
# Generated:  [['methimazole', 'agranulocytosis'], ['propylthiouracil', 'agranulocytosis']]
#
# ----------------
#
# TEXT:  Fatal acute encephalomyelitis after a single dose of intrathecal methotrexate.
# Relations:  [['methotrexate', 'Fatal acute encephalomyelitis']]
# Generated:  [['methotrexate', 'Fatal acute encephalomyelitis']]
#
# ----------------
#
# TEXT:  The autopsy findings and a detailed medical history supported the conclusion that clozapine-induced hypersensitivity myocarditis was the most likely cause of death.
# Relations:  [['clozapine', 'hypersensitivity myocarditis']]
# Generated:  [['clozapine', 'hypersensitivity myocarditis']]
#
# ----------------
#
# TEXT:  CASE: A malignant mixed mesodermal tumor was diagnosed in a 64-year-old woman with a bicornuate uterus while she was taking raloxifene for osteoporosis prevention.
# Relations:  [['raloxifene', 'malignant mixed mesodermal tumor']]
# Generated:  [['raloxifene','malignant mixed mesodermal tumor']]
#
# ----------------
#
# TEXT:  A 40-year-old man with relapsing-remitting multiple sclerosis (MS) developed primary central nervous system lymphoma (PCNSL) after having received 21 doses of natalizumab monotherapy.
# Relations:  [['natalizumab', 'PCNSL'], ['natalizumab', 'primary central nervous system lymphoma']]
# Generated:  [['natalizumab', 'PCNSL'], ['natalizumab', 'primary central nervous system lymphoma']]
#
# ----------------
#
# TEXT:  Generalized pustular psoriasis precipitated by trazodone in the treatment of depression.
# Relations:  [['trazodone', 'Generalized pustular psoriasis']]
# Generated:  [['trazodone', 'Generalized pustular psoriasis']]
#
# ----------------
#
# TEXT:  Although the existence of an acute pericarditis or an acute myocarditis as possible causes of the ST elevation cannot be fully ruled out, the sudden onset, prominent magnitude, and brief duration of the ST elevation are perhaps more indicative of an acute ischemic event, possibly related to a transient coronary vasoconstriction induced by the dopamine infusion.
# Relations:  [['dopamine', 'coronary vasoconstriction']]
# Generated:  [['dopamine', 'ST elevation'], ['dopamine', 'acute ischemic event'], ['dopamine', 'transient coronary vasoconstriction']]
#
# ----------------
#
# TEXT:  The observations suggest that testicular swelling and pain are side effects of desipramine.
# Relations:  [['desipramine', 'pain'], ['desipramine', 'testicular swelling']]
# Generated:  [['desipramine', 'pain'], ['desipramine', 'testicular swelling']]
#
# ----------------
#
# TEXT:  Clofazimine enteropathy caused by crystal deposition can be life-threatening.
# Relations:  [['Clofazimine', 'enteropathy'], ['Clofazimine', 'life-threatening']]
# Generated:  [['Clofazimine', 'Crystallodeposition'], ['Clofazimine', 'Clofazimine enteropathy']]
#
# ----------------
#
# TEXT:  Agranulocytosis is a rare adverse effect associated with prolonged vancomycin therapy, and is potentially serious, especially in end stage renal disease (ESRD) patients.
# Relations:  [['vancomycin', 'Agranulocytosis']]
# Generated:  [['vancomycin', 'Agranulocytosis']]
#
# ----------------
#
# TEXT:  Intensive high-flux hemodiafiltration is often used in the management of vancomycin toxicity.
# Relations:  [['vancomycin', 'vancomycin toxicity']]
# Generated:  [['vancomycin', 'vancomycin toxicity']]
#
# ----------------
#
# TEXT:  Pulmonary fibrosis is a complication of paclitaxel therapy that may occur despite treatments with corticosteroids.
# Relations:  [['paclitaxel', 'Pulmonary fibrosis']]
# Generated:  [['paclitaxel', 'Pulmonary fibrosis']]
#
# ----------------
#
# TEXT:  Carbamazepine-induced systemic lupus erythematosus-like disease.
# Relations:  [['Carbamazepine', 'systemic lupus erythematosus-like disease']]
# Generated:  [['Carbamazepine','systemic lupus erythematosus-like disease']]
#
# ----------------
#
# TEXT:  We concluded that the colonic ulcer and the sigmoidovesical fistula had been caused by the administration of calcium polystyrene sulfonate and sorbitol.
# Relations:  [['calcium polystyrene sulfonate', 'colonic ulcer'], ['sorbitol', 'colonic ulcer'], ['calcium polystyrene sulfonate', 'sigmoidovesical fistula'], ['sorbitol', 'sigmoidovesical fistula']]
# Generated:  [['calcium polystyrene sulfonate', 'colonic ulcer'], ['sorbitol','sigmoidovesical fistula'], ['calcium polystyrene sulfonate','sigmoidovesical fistula']]
#
# ----------------
#
# TEXT:  Trimethoprim-sulfamethoxazole-induced hepatotoxicity in a pediatric patient.
# Relations:  [['Trimethoprim-sulfamethoxazole', 'hepatotoxicity']]
# Generated:  [['Trimethoprim-sulfamethoxazole', 'hepatotoxicity']]
#
# ----------------
#
# TEXT:  We report the successful treatment of heparin-induced thrombocytopenia and subsequent hemorrhagic complications postoperatively in a 2-year-old child with Danaparoid (orgaran).
# Relations:  [['heparin', 'hemorrhagic complications'], ['heparin', 'thrombocytopenia']]
# Generated:  [['heparin', 'thrombocytopenia'], ['heparin', 'hemorrhagic complications']]
#
# ----------------
#
# TEXT:  RESULTS: Replacing valproate with lamotrigine resulted in a decrease in serum testosterone concentrations in all 3 women.
# Relations:  [['valproate', 'serum testosterone']]
# Generated:  [['valproate', 'decrease in serum testosterone concentrations'], ['lamotrigine', 'decrease in serum testosterone concentrations']]
#
# ----------------
#
# TEXT:  DISCUSSION: The occurrence of priapism in our patient was related to zuclopenthixol.
# Relations:  [['zuclopenthixol', 'priapism']]
# Generated:  [['zuclopenthixol', 'priapism']]
#
# ----------------
#
# TEXT:  Acute dystonia during pegylated interferon alpha therapy in a case with chronic hepatitis B infection.
# Relations:  [['pegylated interferon alpha', 'Acute dystonia']]
# Generated:  [['pegylated interferon alpha', 'Acute dystonia']]
#
# ----------------
#
# TEXT:  This supports the well-reported potential of bleomycin to trigger acral vascular toxicity.
# Relations:  [['bleomycin', 'acral vascular toxicity']]
# Generated:  [['bleomycin', 'acral vascular toxicity']]
#
# ----------------
#
# TEXT:  Interstitial pneumonitis associated with sirolimus: a dilemma for lung transplantation.
# Relations:  [['sirolimus', 'Interstitial pneumonitis']]
# Generated:  [['sirolimus', 'Interstitial pneumonitis']]
#
# ----------------
#
# TEXT:  Ifosfamide is a known nephrotoxic drug with demonstrated tubulopathies.
# Relations:  [['Ifosfamide', 'tubulopathies']]
# Generated:  [['Ifosfamide', 'tubulopathies'], ['Ifosfamide', 'nephrotoxic']]
#
# ----------------
#
# TEXT:  Clinicians should be cognizant of this possibility and consider a diagnosis of HDAs in patients with ongoing thrombosis who are receiving heparin therapy.
# Relations:  [['heparin', 'thrombosis']]
# Generated:  [['heparin', 'HDAs']]
#
# ----------------
#
# TEXT:  Hemorrhage from a falx meningioma after internal use of low-dose aspirin.
# Relations:  [['aspirin', 'Hemorrhage']]
# Generated:  [['aspirin', 'Hemorrhage']]
#
# ----------------
#
# TEXT:  The case of a 29-year-old man suffering from falciparum malaria disease who got a reversible hearing loss from quinine therapy is presented.
# Relations:  [['quinine', 'reversible hearing loss']]
# Generated:  [['quinine','reversible hearing loss']]
#
# ----------------
#
# TEXT:  Allergic contact dermatitis to compound tincture of benzoin.
# Relations:  [['benzoin', 'Allergic contact dermatitis']]
# Generated:  [['benzoin', 'Allergic contact dermatitis']]
#
# ----------------
#
# TEXT:  A case of severe acute hepatitis caused by cyproterone acetate in a 71 year old man with prostatic carcinoma is reported with a review of the literature on hepatic reactions to this drug.
# Relations:  [['cyproterone acetate', 'severe acute hepatitis']]
# Generated:  [['cyproterone acetate','severe acute hepatitis']]
#
# ----------------
#
# TEXT:  PURPOSE: To present a case of respiratory depression following the administration of nebulised morphine.
# Relations:  [['morphine', 'respiratory depression']]
# Generated:  [['morphine','respiratory depression']]
#
# ----------------
#
# TEXT:  A 62-year-old Indian with diabetic nephropathy controlled with metformin, developed miliary tuberculosis for which he was treated with rifampicin, isoniazid and ethambutol.
# Relations:  [['metformin', 'miliary tuberculosis']]
# Generated:  [['metformin','miliary tuberculosis']]
#
# ----------------
#
# TEXT:  Although lung specimens were lacking from these three patients, it is suggested that the pulmonary toxicity of CCNU may be dose-related.
# Relations:  [['CCNU', 'pulmonary toxicity']]
# Generated:  [['CCNU', 'pulmonary toxicity']]
#
# ----------------
#
# TEXT:  Proliferation of abnormal bone marrow histiocytes, an undesired effect of granulocyte macrophage-colony-stimulating factor therapy in a patient with Hurler's syndrome undergoing bone marrow transplantation.
# Relations:  [['granulocyte macrophage-colony-stimulating factor', 'Proliferation of abnormal bone marrow histiocytes']]
# Generated:  [['granulocyte macrophage-colony-stimulating factor', 'Proliferation of abnormal bone marrow histiocytes']]
#
# ----------------
#
# TEXT:  Epstein-Barr virus-associated lymphoproliferative disorder in a patient with rheumatoid arthritis on methotrexate and rofecoxib: idiosyncratic reaction or pharmacogenetics?
# Relations:  [['methotrexate', 'Epstein-Barr virus-associated lymphoproliferative disorder'], ['rofecoxib', 'Epstein-Barr virus-associated lymphoproliferative disorder']]
# Generated:  [['methotrexate', 'Epstein-Barr virus-associated lymphoproliferative disorder'], ['rofecoxib', 'Epstein-Barr virus-associated lymphoproliferative disorder']]
#
# ----------------
#
# TEXT:  The relationship between infliximab treatment and lymphoma in Crohn's disease.
# Relations:  [['infliximab', 'lymphoma']]
# Generated:  [['infliximab', 'lymphoma']]
#
# ----------------
#
# TEXT:  Linezolid-associated acute interstitial nephritis and drug rash with eosinophilia and systemic symptoms (DRESS) syndrome.
# Relations:  [['Linezolid', 'acute interstitial nephritis'], ['Linezolid', 'DRESS'], ['Linezolid', 'drug rash with eosinophilia and systemic symptoms']]
# Generated:  [['Linezolid', 'acute interstitial nephritis'], ['Linezolid', 'drug rash with eosinophilia and systemic symptoms'], ['Linezolid', 'DRESS']]
#
# ----------------
#
# TEXT:  Early ritonavir-induced maculopapular eruption.
# Relations:  [['ritonavir', 'maculopapular eruption']]
# Generated:  [['ritonavir','maculopapular eruption']]
#
# ----------------
#
# TEXT:  A patient that received methadone for cancer-associated pain developed myoclonus as a side effect.
# Relations:  [['methadone', 'myoclonus']]
# Generated:  [['methadone','myoclonus']]
#
# ----------------
#
# TEXT:  After 39 hours on argatroban, the infusion was stopped when minor bleeding was observed with a concurrent activated partial thromboplastin time (aPTT) of 100 seconds.
# Relations:  [['argatroban', 'bleeding']]
# Generated:  [['argatroban','minor bleeding']]
#
# ----------------
#
# TEXT:  Acute renal failure following intravenous immunoglobulin therapy in a HIV-infected patient.
# Relations:  [['immunoglobulin', 'Acute renal failure']]
# Generated:  [['immunoglobulin', 'Acute renal failure']]
#
# ----------------
#
# TEXT:  Captopril-associated "pseudocholangitis'.
# Relations:  [['Captopril', 'pseudocholangitis']]
# Generated:  [['Captopril', 'pseudocholangitis']]
#
# ----------------
#
# TEXT:  A 52-year-old woman developed symmetric sensorimotor polyneuropathy and cerebellar syndrome after 24 months of amiodarone treatment.
# Relations:  [['amiodarone', 'cerebellar syndrome'], ['amiodarone', 'symmetric sensorimotor polyneuropathy']]
# Generated:  [['amiodarone', 'cerebellar syndrome'], ['amiodarone','symmetric sensorimotor polyneuropathy']]
#
# ----------------
#
# TEXT:  Initiation of posaconazole led to clinical improvement until the patient's demise from bacteremic vancomycin-resistant enterococcal peritonitis.
# Relations:  [['posaconazole', 'enterococcal peritonitis']]
# Generated:  [['posaconazole', 'bacteremic vancomycin-resistant enterococcal peritonitis']]
#
# ----------------
#
# TEXT:  Disseminated tuberculous lesions post intravesical BCG therapy are rare but need to be identified and treated quickly.
# Relations:  [['BCG', 'Disseminated tuberculous lesions']]
# Generated:  [['BCG', 'Disseminated tuberculous lesions']]
#
# ----------------
#
# TEXT:  Diabetes Mellitus was observed in a patient given carbamazepine.
# Relations:  [['carbamazepine', 'Diabetes Mellitus']]
# Generated:  [['carbamazepine', 'Diabetes Mellitus']]
#
# ----------------
#
# TEXT:  The patient was positive for antibody against complexes of heparin and platelet factor 4, and was diagnosed as heparin-induced thrombocytopenia with thrombosis syndrome (HITTS).
# Relations:  [['heparin', 'thrombocytopenia'], ['heparin', 'thrombosis syndrome']]
# Generated:  [['heparin', 'thrombocytopenia'], ['heparin', 'thrombosis syndrome'], ['heparin', 'HITTS']]
#
# ----------------
#
# TEXT:  We report a case of severe hypotension associated with intravenous valproate used to treat status epilepticus in an 11-year-old girl.
# Relations:  [['valproate', 'hypotension']]
# Generated:  [['valproate','severe hypotension']]
#
# ----------------
#
# TEXT:  The most likely cause of liver failure in this patient was, therefore, clarithromycin, which undergoes hepatic metabolism and has been reported to cause fulminant hepatic failure.
# Relations:  [['clarithromycin', 'fulminant hepatic failure'], ['clarithromycin', 'liver failure']]
# Generated:  [['clarithromycin', 'fulminant hepatic failure']]
#
# ----------------
#
# TEXT:  Can roxithromycin and betamethasone induce acute pancreatitis? A case report.
# Relations:  [['betamethasone', 'acute pancreatitis'], ['roxithromycin', 'acute pancreatitis']]
# ...
#
# ----------------
#
# TEXT:  A case of propranolol overdose complicated by esophageal spasm preventing extrication of an orogastric lavage tube and relieved by intravenous glucagon is presented.
# Relations:  [['propranolol', 'esophageal spasm']]
# Generated:  [['propranolol', 'esophageal spasm'], ['propranolol', 'propranolol overdose']]
#
# ----------------
#
# TEXT:  Intravenous administration of levodopa ameliorated a refractory akathisia case induced by interferon-alpha.
# Relations:  [['interferon-alpha', 'akathisia']]
# Generated:  [['interferon-alpha', 'akathisia']]
#
# ----------------
#
# TEXT:  We describe a premenopausal woman who, while having tamoxifen due to a diagnosis of in situ ductal carcinoma, developed endometriosis requiring surgery.
# Relations:  [['tamoxifen', 'endometriosis']]
# Generated:  [['tamoxifen', 'endometriosis']]
#
# ----------------
#
# TEXT:  We report the development of scrotal ulcer in a patient with acute promyleocytic leukemia (APL) within 10 days of treatment with ATRA at a dose of 40 mg orally twice daily.
# Relations:  [['ATRA', 'scrotal ulcer']]
# Generated:  [['ATRA','scrotal ulcer']]
#
# ----------------
#
# TEXT:  We present a case of photo-onycholysis in a patient treated with doxycycline for acne vulgaris.
# Relations:  [['doxycycline', 'photo-onycholysis']]
# Generated:  [['doxycycline', 'photo-onycholysis']]
#
# ----------------
#
# TEXT:  Niacin maculopathy.
# Relations:  [['Niacin', 'maculopathy']]
# Generated:  [['Niacin', 'Maculopathy']]
#
# ----------------
#
# TEXT:  Acute leukaemia during tamoxifen therapy.
# Relations:  [['tamoxifen', 'Acute leukaemia']]
# Generated:  [['tamoxifen', 'Acute leukaemia']]
#
# ----------------
#
# TEXT:  From 1996 to 2002 several medications were changed due to their adverse effects: indinavir (renal colic and fever), nelfinavir (cutaneous rash), and efavirenz (nausea and temporary memory loss).
# Relations:  [['nelfinavir', 'cutaneous rash'], ['indinavir', 'fever'], ['efavirenz', 'nausea'], ['indinavir', 'renal colic'], ['efavirenz', 'temporary memory loss']]
# Generated:  [['indinavir', 'fever'], ['nelfinavir', 'cutaneous rash'], ['efavirenz', 'nausea'], ['indinavir','renal colic']]
#
# ----------------
#
# TEXT:  Angio-oedema as an unusual tolerable side effect of voriconazole therapy.
# Relations:  [['voriconazole', 'Angio-oedema']]
# Generated:  [['voriconazole', 'Angio-oedema']]
#
# ----------------
#
# TEXT:  We stress the potential of benzarone to cause hepatotoxicity, which usually resembles severe chronic active hepatitis.
# Relations:  [['benzarone', 'hepatotoxicity'], ['benzarone', 'severe chronic active hepatitis']]
# Generated:  [['benzarone', 'hepatotoxicity']]
#
# ----------------
#
# TEXT:  Methotrexate (MTX) is a commonly used second line agent for RA, and there have been several recent reports of Epstein-Barr virus (EBV)-associated polyclonal B cell lymphoproliferative disorder in MTX-treated RA patients.
# Relations:  [['Methotrexate', 'Epstein-Barr virus (EBV)-associated polyclonal B cell lymphoproliferative disorder'], ['MTX', 'Epstein-Barr virus (EBV)-associated polyclonal B cell lymphoproliferative disorder'], ['MTX', 'Epstein-Barr virus (EBV)-associated polyclonal B cell lymphoproliferative disorder']]
# Generated:  [['Methotrexate', 'polyclonal B cell lymphoproliferative disorder'], ['MTX', 'polyclonal B cell lymphoproliferative disorder'], ['Epstein-Barr virus (EBV)', 'polyclonal B cell lymphoproliferative disorder']]
#
# ----------------
#
# TEXT:  The incidence of angioedema secondary to losartan, an angiotensin II receptor antagonist, is unknown.
# Relations:  [['losartan', 'angioedema']]
# Generated:  [['losartan', 'angioedema']]
#
# ----------------
#
# TEXT:  Nephrogenic diabetes insipidus and renal tubular acidosis secondary to foscarnet therapy.
# Relations:  [['foscarnet', 'Nephrogenic diabetes insipidus'], ['foscarnet', 'renal tubular acidosis']]
# Generated:  [['foscarnet','renal tubular acidosis'], ['foscarnet', 'Nephrogenic diabetes insipidus']]
#
# ----------------
#
# TEXT:  Intranasal desmopressin-induced hyponatremia.
# Relations:  [['desmopressin', 'hyponatremia']]
# Generated:  [['desmopressin', 'hyponatremia']]
#
# ----------------
#
# TEXT:  Systemic capillary leak syndrome after granulocyte colony-stimulating factor (G-CSF).
# Relations:  [['G-CSF', 'Systemic capillary leak syndrome'], ['granulocyte colony-stimulating factor', 'Systemic capillary leak syndrome']]
# Generated:  [['granulocyte colony-stimulating factor', 'Systemic capillary leak syndrome'], ['G-CSF', 'Systemic capillary leak syndrome']]
#
# ----------------
#
# TEXT:  This regimen could prove useful for other patients who develop hypersensitivity reactions to carboplatin and allow therapy to continue.
# Relations:  [['carboplatin', 'hypersensitivity']]
# Generated:  [['carboplatin', 'hypersensitivity reactions']]
#
# ----------------
#
# TEXT:  CONCLUSION: The present findings suggest that fluvoxamine can cause increased libido in some patients.
# Relations:  [['fluvoxamine', 'increased libido']]
# Generated:  [['fluvoxamine', 'increased libido']]
#
# ----------------
#
# TEXT:  For patients who suffer from osteogenic sarcoma and have anaphylactic reactions to MTX, this desensitization protocol will allow these patients to continue with needed therapeutic or palliative chemotherapy.
# Relations:  [['MTX', 'anaphylactic reactions']]
# Generated:  [['MTX', 'anaphylactic reactions']]
#
# ----------------
#
# TEXT:  We report a case of biopsy-proven acute tubulointerstitial nephritis associated with a second course of flurbiprofen, a nonsteroidal anti-inflammatory drug of the propionic acid class.
# Relations:  [['flurbiprofen', 'acute tubulointerstitial nephritis']]
# Generated:  [['flurbiprofen', 'acute tubulointerstitial nephritis']]
#
# ----------------
#
# TEXT:  Acute respiratory distress syndrome after rituximab infusion.
# Relations:  [['rituximab', 'Acute respiratory distress syndrome']]
# Generated:  [['rituximab', 'Acute respiratory distress syndrome']]
#
# ----------------
#
# TEXT:  We report here a rare case of pleuropericarditis due to methotrexate.
# Relations:  [['methotrexate', 'pleuropericarditis']]
# Generated:  [['methotrexate', 'pleuropericarditis']]
#
# ----------------
#
# TEXT:  Skin necrosis is a rare complication of subcutaneous heparin therapy that usually occurs at injection sites.
# Relations:  [['heparin', 'Skin necrosis']]
# Generated:  [['heparin', 'Skin necrosis']]
#
# ----------------
#
# TEXT:  Angioedema, a rare side effect of carbamazepine, involves vascular leakage in dermis and subcutis mediated by immunoglobulin E and/or bradykinins.
# Relations:  [['carbamazepine', 'Angioedema']]
# Generated:  [['carbamazepine', 'Angioedema']]
#
# ----------------
#
# TEXT:  Propoxyphene-induced wide QRS complex dysrhythmia responsive to sodium bicarbonate--a case report.
# Relations:  [['Propoxyphene', 'wide QRS complex dysrhythmia']]
# Generated:  [['Propoxyphene', 'wide QRS complex dysrhythmia']]
#
# ----------------
#
# TEXT:  Administration of lamotrigine, especially in combination with valproic acid, may lead to the development of TEN.
# Relations:  [['lamotrigine', 'TEN'], ['valproic acid', 'TEN']]
# Generated:  [['lamotrigine', 'TEN'], ['valproic acid', 'TEN']]
#
# ----------------
#
# TEXT:  We report the case of a man, treated with mesalazine for Crohn's disease who developed drug-induced pericarditis.
# Relations:  [['mesalazine', 'pericarditis']]
# Generated:  [['mesalazine', 'pericarditis']]
#
# ----------------
#
# TEXT:  Two patients treated with 5-fluorouracil (5-FU) for disseminated adenocarcinoma of the colon developed cerebellar dysfunction typical of 5-FU neurotoxicity.
# Relations:  [['5-fluorouracil', 'cerebellar dysfunction'], ['5-FU', 'cerebellar dysfunction'], ['5-FU', 'cerebellar dysfunction'], ['5-fluorouracil', 'neurotoxicity'], ['5-FU', 'neurotoxicity'], ['5-FU', 'neurotoxicity']]
# Generated:  [['5-fluorouracil', 'cerebellar dysfunction'], ['5-FU', 'cerebellar dysfunction'], ['5-fluorouracil', 'neurotoxicity'], ['5-FU', 'neurotoxicity']]
#
# ----------------
#
# TEXT:  Diarrhea-associated over-anticoagulation in a patient taking warfarin: therapeutic role of cholestyramine.
# Relations:  [['warfarin', 'Diarrhea-associated over-anticoagulation']]
# Generated:  [['warfarin', 'Diarrhea'], ['warfarin', 'over-anticoagulation']]
#
# ----------------
#
# TEXT:  Reduction of methylprednisolone dosage rather than insulin therapy resulted in better control of glycemia.
# Relations:  [['methylprednisolone', 'glycemia']]
# Generated:  [['methylprednisolone', 'glycemia']]
#
# ----------------
#
# TEXT:  A case is reported in which severe hypocalcemia, with a low plasma parathyroid hormone (PTH) concentration, resulted from the therapeutic use of magnesium sulfate for toxemia of pregnancy.
# Relations:  [['magnesium sulfate', 'low plasma parathyroid hormone'], ['magnesium sulfate', 'PTH'], ['magnesium sulfate', 'severe hypocalcemia']]
# Generated:  [['magnesium sulfate','severe hypocalcemia']]
#
# ----------------
#
# TEXT:  This review presents the first case series of DIC associated with acute hemoglobinemia or hemoglobinuria following anti-D IGIV administration for ITP.
# Relations:  [['anti-D IGIV', 'acute hemoglobinemia'], ['anti-D IGIV', 'DIC'], ['anti-D IGIV', 'hemoglobinuria']]
# Generated:  [['anti-D IGIV', 'acute hemoglobinemia'], ['anti-D IGIV', 'hemoglobinuria'], ['anti-D IGIV', 'DIC']]
#
# ----------------
#
# TEXT:  Stroke-like syndrome after gold sodium thiomalate induced vasomotor reaction.
# Relations:  [['gold sodium thiomalate', 'Stroke-like syndrome'], ['gold sodium thiomalate', 'vasomotor reaction']]
# Generated:  [['gold sodium thiomalate', 'Stroke-like syndrome']]
#
# ----------------
#
# TEXT:  Carbamazepine-induced tics.
# Relations:  [['Carbamazepine', 'tics']]
# Generated:  [['Carbamazepine', 'tics']]
#
# ----------------
#
# TEXT:  In this report, we present a case of hypoglycaemic coma associated with SP, an adverse reaction that is likely to be underreported and expected to occur with greater frequency as the use of SP increases.
# Relations:  [['SP', 'hypoglycaemic coma'], ['SP', 'hypoglycaemic coma']]
# Generated:  [['SP', 'hypoglycaemic coma']]
#
# ----------------
#
# TEXT:  The aim of this report is to describe the clinical and electroencephalographic findings seen in an elderly woman without previous history of seizures who developed a nonconvulsive generalized status epilepticus following acute withdrawal of lorazepam.
# Relations:  [['lorazepam', 'nonconvulsive generalized status epilepticus']]
# Generated:  [['lorazepam', 'nonconvulsive generalized status epilepticus']]
#
# ----------------
#
# TEXT:  Acute non-lymphocytic leukemia in patients with ovarian carcinoma following long-term treatment with Treosulfan (= dihydroxybusulfan).
# Relations:  [['dihydroxybusulfan', 'Acute non-lymphocytic leukemia'], ['Treosulfan', 'Acute non-lymphocytic leukemia']]
# Generated:  [['dihydroxybusulfan', 'Acute non-lymphocytic leukemia'], ['Treosulfan', 'Acute non-lymphocytic leukemia']]
#
# ----------------
#
# TEXT:  Acyclovir-induced neurotoxicity: concentration-side effect relationship in acyclovir overdose.
# Relations:  [['Acyclovir', 'neurotoxicity']]
# Generated:  [['Acyclovir', 'neurotoxicity']]
#
# ----------------
#
# TEXT:  Tacrolimus-induced HUS: an unusual cause of acute renal failure in nephrotic syndrome.
# Relations:  [['Tacrolimus', 'acute renal failure'], ['Tacrolimus', 'HUS']]
# Generated:  [['Tacrolimus', 'acute renal failure'], ['Tacrolimus', 'HUS']]
#
# ----------------
#
# TEXT:  Retinal abnormalities, including retinal hemorrhage and "cotton-wool" spots, often occur within the first 8 weeks in the course of interferon therapy in patients with chronic hepatitis C.
# Relations:  [['interferon', '"cotton-wool" spots'], ['interferon', 'Retinal abnormalities'], ['interferon', 'retinal hemorrhage']]
# Generated:  [['interferon', 'cotton-wool' spots'], ['interferon','retinal abnormalities'], ['interferon','retinal hemorrhage']]
#
# ----------------
#
# TEXT:  This patient developed sequential symptoms including alternative hemiparesis, dysarthria and altered consciousness 5 days after the second course of HD-MTX (8 gm/m2 by 6 h continuous infusion) with leucovorin rescue.
# Relations:  [['HD-MTX', 'altered consciousness'], ['HD-MTX', 'dysarthria'], ['HD-MTX', 'hemiparesis']]
# Generated:  [['HD-MTX', 'alternative hemiparesis'], ['HD-MTX', 'dysarthria'], ['HD-MTX', 'altered consciousness'], ['HD-MTX', 'dysarthria'], ['HD-MTX', 'alternative consciousness'], ['HD-MTX', 'dysarthria']]
#
# ----------------
#
# TEXT:  An episode of subacute encephalopathy after the infusion of a moderate dose of methotrexate (1500 mg/m2) (MTX) is reported in a young adult with metastastic gastric cancer.
# Relations:  [['methotrexate', 'encephalopathy']]
# Generated:  [['methotrexate','subacute encephalopathy'], ['MTX','subacute encephalopathy']]
#
# ----------------
#
# TEXT:  Esophageal spasm following propranolol overdose relieved by glucagon.
# Relations:  [['propranolol', 'Esophageal spasm']]
# Generated:  [['propranolol', 'Esophageal spasm']]
#
# ----------------
#
# TEXT:  METHODS: Five cases of contact dermatitis due to budesonide, a nonhalogenated steroid, are described.
# Relations:  [['budesonide', 'contact dermatitis']]
# Generated:  [['budesonide', 'contact dermatitis']]
#
# ----------------
#
# TEXT:  It was restarted 6 weeks later, and 10 weeks after that, the patient presented with fulminant hepatic failure, which resolved rapidly after cessation of nicotinic acid therapy.
# Relations:  [['nicotinic acid', 'fulminant hepatic failure']]
# Generated:  [['nicotinic acid', 'fulminant hepatic failure']]
#
# ----------------
#
# TEXT:  Risperidone-induced psychosis and depression in a child with a mitochondrial disorder.
# Relations:  [['Risperidone', 'depression'], ['Risperidone', 'psychosis']]
# Generated:  [['Risperidone', 'depression'], ['Risperidone', 'psychosis']]
#
# ----------------
#
# TEXT:  Masculinization of a female fetus occurred in 5 of 39 (12.8%) exposed to norethisterone; all were cases of clitoral hypertrophy not requiring surgical treatment.
# Relations:  [['norethisterone', 'clitoral hypertrophy'], ['norethisterone', 'Masculinization of a female fetus']]
# Generated:  [['norethisterone', 'Masculinization of a female fetus']]
#
# ----------------
#
# TEXT:  A 51-yr-old nonsmoking male patient without any history of previous allergies, asthma, hay fever, or urticaria developed attacks of asthma when captopril was added to the nadolol and dyazide treatment for his high blood pressure.
# Relations:  [['captopril', 'attacks of asthma'], ['dyazide', 'attacks of asthma'], ['nadolol', 'attacks of asthma']]
# Generated:  [['nadolol', 'asthma'], ['captopril', 'asthma'], ['dyazide', 'asthma'], ['captopril', 'asthma']]
#
# ----------------
#
# TEXT:  Hypersensitivity to carboplatin has been reported in up to 44% of patients receiving this antineoplastic agent, usually occurring after several courses of treatment.
# Relations:  [['carboplatin', 'Hypersensitivity']]
# Generated:  [['carboplatin', 'Hypersensitivity']]
#
# ----------------
#
# TEXT:  Sustained hypothyroidism induced by recombinant alpha interferon in patients with chronic hepatitis C.
# Relations:  [['recombinant alpha interferon', 'Sustained hypothyroidism']]
# Generated:  [['recombinant alpha interferon', 'Sustained hypothyroidism']]
#
# ----------------
#
# TEXT:  Anaphylaxis after the injection of chymopapain occurs in about 1% of such cases.
# Relations:  [['chymopapain', 'Anaphylaxis']]
# Generated:  [['chymopapain', 'Anaphylaxis']]
#
# ----------------
#
# TEXT:  We believe that this is the first report of secretory carcinoma of the endometrium associated with tamoxifen use.
# Relations:  [['tamoxifen', 'secretory carcinoma of the endometrium']]
# Generated:  [['tamoxifen','secretory carcinoma of the endometrium']]
#
# ----------------
#
# TEXT:  AIM: To report three cases of extensive skin necrosis in cirrhotic patients treated with the vasoconstrictor agent terlipressin (Glypressin).
# Relations:  [['Glypressin', 'skin necrosis'], ['terlipressin', 'skin necrosis']]
# Generated:  [['Glypressin','skin necrosis'], ['terlipressin','skin necrosis']]
#
# ----------------

# %%
text = prefix + "spindle coma in benzodiazepine toxicity: case report." + "\nRelations: "
print (text)
# Out:
# List the drugs and their corresponding adverse-effects in the following TEXT using [drug, effect] format:
# TEXT: spindle coma in benzodiazepine toxicity: case report.
# Relations:

# %%
inputs = tokenizer(text, return_tensors="pt").input_ids

# %%
outputs = tuned_model.generate(inputs, max_new_tokens=100, do_sample=False)

# %%
out = tokenizer.decode(outputs[0], skip_special_tokens=True)
print (out)
# Out:
# [['benzodiazepine','spindle coma']] Explanation: Explanation: Spindle coma was reported in benzodiazepine toxicity.

# %%
import ast

# %%
print (ast.literal_eval(out))
# Out:
# [['Alprazolam', 'headache'], ['Xanax', 'headache']]
