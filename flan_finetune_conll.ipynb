# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset
import json
from tqdm import tqdm
from transformers import DataCollatorForSeq2Seq
import torch
import evaluate
import numpy as np
import ast
import re

# %%
rouge = evaluate.load("rouge")

# %%
torch.cuda.empty_cache()

model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-large", 
                                              cache_dir="/scratch/wadhwa.s/cache", 
                                              device_map="auto")
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-large", 
                                          cache_dir="/scratch/wadhwa.s/cache")

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    result = rouge.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    return {k: round(v, 4) for k, v in result.items()}

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

# %%
valid = ["Work_For", "Live_In", "OrgBased_In", "Kill", "Located_In"]
df = pd.read_csv("conll_gpt3_explanations_responses.csv")
# for ix, row in df.iterrows():
#     row["explanations"] = row["explanations"] + "</s>"

# df.to_csv("conll_gpt3_explanations_responses.csv", index=False)

# %%
for ix, row in df.sample(100).iterrows():
    print(row["input"])
    print ("Relations: " + row["gold_relations"] + "\n" + row["explanations"])
    print ("\n----------------\n")
# Out:
# TEXT: Farley attorney Stephen Greiner contended during Wednesday 's 90-minute hearing that the pill ` ` is a device by which the board of directors of West Point says nobody can buy more than 10 percent. ' '
# Relations: [['Stephen Greiner', 'Work_For', 'Farley']]
# Explanation: Stephen Greiner is an attorney that works for Farley.</s>
#
# ----------------
#
# TEXT: However , I do have feelings. ( Minoli ) Do you think that Berlusconi is the Freedom Alliance 's candidate for the post of prime ? ( Fini ) We must let the electors decide .
# Relations: [['Berlusconi', 'Work_For', 'Freedom Alliance']]
# Explanation: Berlusconi is the candidate for the post of prime for the Freedom Alliance.</s>
#
# ----------------
#
# TEXT: Remodeling Planned To Improve H-2 Rocket Launch OW2202091394 Tokyo MAINICHI SHIMBUN in Japanese 21 Feb 94 Morning Edition p 11 -- FOR OFFICIAL USE ONLY
# Relations: [['MAINICHI SHIMBUN', 'OrgBased_In', 'Tokyo']]
# Explanation: MAINICHI SHIMBUN is an organization based in Tokyo.</s>
#
# ----------------
#
# TEXT: Last week , commissioners approved spending $2.3 million in county funds for constructing an outside elevator , to be used to carry visitors to the sixth floor , where Lee Harvey Oswald was believed to have perched on the day of the Kennedy assassination , Nov. 22 , 1963 .
# Relations: [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# Explanation: Lee Harvey Oswald was believed to have killed President Kennedy on Nov. 22, 1963.</s>
#
# ----------------
#
# TEXT: In 1809 , author Edgar Allan Poe was born in Boston .
# Relations: [['Edgar Allan Poe', 'Live_In', 'Boston']]
# Explanation: Edgar Allan Poe was born in Boston and therefore lived in Boston.</s>
#
# ----------------
#
# TEXT: Hernandez Galicia was arrested when soldiers blew down his door with a bazooka in a raid on his Ciudad Madero home .
# Relations: [['Hernandez Galicia', 'Live_In', 'Ciudad Madero']]
# Explanation: Hernandez Galicia lives in Ciudad Madero, thus it can be inferred that Ciudad Madero is his home.</s>
#
# ----------------
#
# TEXT: In 1752 , flagmaker Betsy Ross was born in Philadelphia .
# Relations: [['Betsy Ross', 'Live_In', 'Philadelphia']]
# Explanation: Betsy Ross was born in Philadelphia and therefore lived in Philadelphia.</s>
#
# ----------------
#
# TEXT: The odds of becoming a murder victim are five times greater for non-white males born now than for the overall population of the United States , the FBI said Thursday .
# Relations: [['FBI', 'OrgBased_In', 'United States']]
# Explanation: The FBI is an organization based in the United States.</s>
#
# ----------------
#
# TEXT: Riga Radio Riga Network
# Relations: [['Radio Riga Network', 'OrgBased_In', 'Riga']]
# Explanation: Radio Riga Network is an organization based in Riga.</s>
#
# ----------------
#
# TEXT: Both high level employees as well as lower-level ones were obliged to clear out , to run away because of threats by 18 January Senator Osny Eugene , the quaestor of the unofficial Senate office who was very angry and took off his jacket so he could drive employees out .
# Relations: [['Osny Eugene', 'Work_For', 'Senate']]
# Explanation: Osny Eugene is a Senator and a quaestor of the unofficial Senate office.</s>
#
# ----------------
#
# TEXT: The Massachusetts Department of Public Health has adopted new regulations on the disposal of infectious waste that take effect next week , but like the federal rules , they don 't apply to household waste , said the department 's Al Comproni.
# Relations: [['Al Comproni.', 'Work_For', 'Massachusetts Department of Public Health']]
# Explanation: Al Comproni is an employee of the Massachusetts Department of Public Health.</s>
#
# ----------------
#
# TEXT: Ray is being held in Tennessee 's Brushy Mountain State Prison on a 99-year sentence for the April 4 , 1968 , slaying of King .
# Relations: [['Ray', 'Kill', 'King']]
# Explanation: Ray is being held in Tennessee's Brushy Mountain State Prison for the killing of King.</s>
#
# ----------------
#
# TEXT: The Former southernmost Yugoslav Republic of Macedonia followed suit so that Yugoslavia now consists of Serbia and Montenegro .
# Relations: [['Serbia', 'Located_In', 'Yugoslavia'], ['Montenegro', 'Located_In', 'Yugoslavia']]
# Explanation: Serbia and Montenegro are located in the former Yugoslavia.</s>
#
# ----------------
#
# TEXT: Andric wrote about the Moslems organising gangs to hunt down Serbs after the young revolutionary Gavrilo Princip assassinated Archduke Ferdinand in Sarajevo in 1914 - one of the events which triggered the first world war .
# Relations: [['Gavrilo Princip', 'Kill', 'Archduke Ferdinand']]
# Explanation: Gavrilo Princip assassinated Archduke Ferdinand in Sarajevo in 1914.</s>
#
# ----------------
#
# TEXT: LD0904140094 Helsinki Suomen Yleisradio Network in Finnish 1300 GMT 9 Apr 94
# Relations: [['Suomen Yleisradio Network', 'OrgBased_In', 'Helsinki']]
# Explanation: Suomen Yleisradio Network is an organization based in Helsinki.</s>
#
# ----------------
#
# TEXT: Lehi , also known as the Stern Gang , assassinated the British colonial minister , Lord Moyne , and the Swedish U.N. mediator , Count Folke Bernadotte. ;
# Relations: [['Lehi', 'Kill', 'Lord Moyne'], ['Lehi', 'Kill', 'Folke Bernadotte.'], ['Stern Gang', 'Kill', 'Lord Moyne'], ['Stern Gang', 'Kill', 'Folke Bernadotte.']]
# Explanation: Lehi, also known as the Stern Gang, assassinated Lord Moyne and Count Folke Bernadotte.</s>
#
# ----------------
#
# TEXT: The seven-day average yield on money market mutual funds fell in the week ended Tuesday to 8.28 percent from 8.39 percent the previous week , according to Donoghue 's Money Fund Report , a trade journal based in Holliston , Mass .
# Relations: [['Holliston', 'Located_In', 'Mass']]
# Explanation: Donoghue's Money Fund Report is a trade journal based in Holliston, Mass., so we can deduce that Holliston is located in Mass.</s>
#
# ----------------
#
# TEXT: Even Lee Harvey Oswald , who shot President Kennedy , seems after manifold investigations to have been a loner .
# Relations: [['Lee Harvey Oswald', 'Kill', 'President Kennedy']]
# Explanation: Lee Harvey Oswald was the gunman who killed President Kennedy.</s>
#
# ----------------
#
# TEXT: But Sen. Strom Thurmond , R-S.C. , sponsor of a proposed constitutional amendment , said , ` ` An overwhelming majority of Americans are looking to the Congress to ... restore the proper civil respect for our American flag. ' '
# Relations: [['Strom Thurmond', 'Work_For', 'Congress']]
# Explanation: Strom Thurmond is a senator that works for the Congress.</s>
#
# ----------------
#
# TEXT: ( Excerpts ) In Djibouti , a demonstration in the Afar district of Arhiba was violently repressed by the police this morning. ( passage omitted ) Djama Elabe , the chairman of the Party for Democratic Renewal , is outraged at what happened .
# Relations: [['Afar district', 'Located_In', 'Djibouti'], ['Afar district', 'Located_In', 'Arhiba'], ['Arhiba', 'Located_In', 'Djibouti'], ['Djama Elabe', 'Work_For', 'Party for Democratic Renewal']]
# Explanation: Afar district is located in Djibouti and Arhiba, Djibouti. Djama Elabe is the chairman of the Party for Democratic Renewal.</s>
#
# ----------------
#
# TEXT: During his six-year tenure as Los Angeles County district attorney , Sirhan was tried and convicted for the 1968 assassination of U.S. Sen. Robert Kennedy .
# Relations: [['Sirhan', 'Kill', 'U.S. Sen. Robert Kennedy']]
# Explanation: Sirhan was tried and convicted for the assassination of U.S. Sen. Robert Kennedy.</s>
#
# ----------------
#
# TEXT: Senate Bob Dole of Kansas on Tuesday threatened a parliamentary maneuver that could help force passage of President Bush 's savings and loan bailout before Congress goes on vacation by attaching it to essential legislation.
# Relations: [['Bob Dole', 'Live_In', 'Kansas']]
# Explanation: Bob Dole is a senator from Kansas, so he lives in Kansas.</s>
#
# ----------------
#
# TEXT: Nevertheless , Indemerc-Louis Harris President Vicente Licona said that most of this support has gone to Labor Party ( PT ) candidate Cecilia Soto , while support for the remaining contenders in this group has shown little or no change .
# Relations: [['Vicente Licona', 'Work_For', 'Indemerc-Louis Harris'], ['Cecilia Soto', 'Work_For', 'Labor Party']]
# Explanation: Vicente Licona is the President of Indemerc-Louis Harris and Cecilia Soto is a candidate for the Labor Party.</s>
#
# ----------------
#
# TEXT: Anthropoligist Dean Falk of State University of New York at Albany supports the Kebara findings in the Science News article.
# Relations: [['Dean Falk', 'Work_For', 'State University of New York'], ['Dean Falk', 'Live_In', 'Albany'], ['State University of New York', 'OrgBased_In', 'Albany']]
# Explanation: Dean Falk is an anthropologist who works for the State University of New York and lives in Albany. The State University of New York is based in Albany.</s>
#
# ----------------
#
# TEXT: A reading of the unpublished " Written in My Dream by William Carlos Williams " led to an impromptu lecture by Ginsberg on his fellow New Jersey native , whose use of vernacular and vivid description were a great influence on Ginsberg and other Beat poets .
# Relations: [['Ginsberg', 'Live_In', 'New Jersey']]
# Explanation: Ginsberg is a fellow New Jersey native and therefore lived in New Jersey.</s>
#
# ----------------
#
# TEXT: Smith said there have been a number of successful civil cases against gun retailers in other states , including a recent judgment against K mart in a similar case in St. Claire Shores , Mich .
# Relations: [['K mart', 'OrgBased_In', 'St. Claire Shores'], ['K mart', 'OrgBased_In', 'Mich .'], ['St. Claire Shores', 'Located_In', 'Mich .']]
# Explanation: K mart is an organization based in St. Claire Shores, Mich., which is a place located in Mich..</s>
#
# ----------------
#
# TEXT: The elder Quayle , publisher of the Huntington Herald-Press , said the family is still upset by media coverage of his son 's selection as President-elect George Bush 's running mate , and of the campaign that led to their election in November .
# Relations: [['Quayle', 'Work_For', 'Huntington Herald-Press']]
# Explanation: The elder Quayle is the publisher of the Huntington Herald-Press, thus we can see that he works for this organization.</s>
#
# ----------------
#
# TEXT: ` ` We 're not anti-growth in the traditional sense , ' ' says Patrick Strosahl , a jeweler and president of Vision Seattle , which supports CAP .
# Relations: [['Patrick Strosahl', 'Work_For', 'Vision Seattle']]
# Explanation: Patrick Strosahl is the president of Vision Seattle, which supports CAP.</s>
#
# ----------------
#
# TEXT: The $40 million , three-hour film centers on the conspiracy theories of former New Orleans District Attorney Jim Garrison , who believed that Lee Harvey Oswald did not act alone in the slaying of President Kennedy and was , in fact , a patsy for the military , the Central Intelligence Agency and corporate defense contractors .
# Relations: [['Lee Harvey Oswald', 'Kill', 'President Kennedy']]
# Explanation: Lee Harvey Oswald was the lone gunman who killed President Kennedy.</s>
#
# ----------------
#
# TEXT: PY1204232594 Buenos Aires CLARIN in Spanish 10 Apr 94 Economic Supplement p 6 , 7
# Relations: [['CLARIN', 'OrgBased_In', 'Buenos Aires']]
# Explanation: CLARIN is an organization based in Buenos Aires.</s>
#
# ----------------
#
# TEXT: Most of the work conducted by the Warren Commission , which concluded that Lee Harvey Oswald acted alone in the Kennedy slaying , has been opened to the public , a move that has helped researchers evaluate _ and in many cases strongly criticize _ that investigation .
# Relations: [['Lee Harvey Oswald', 'Kill', 'Kennedy']]
# Explanation: Lee Harvey Oswald acted alone in killing Kennedy.</s>
#
# ----------------
#
# TEXT: U.S. ( USTR ) Mickey Kantor , who came to Japan amid the political confusion within the Hosokawa administration caused by the economic stimulation plan , stated before he left for home that " If we see no actual results , we might have to consider other options . "
# Relations: [['Mickey Kantor', 'Live_In', 'U.S.'], ['Hosokawa', 'Live_In', 'Japan']]
# Explanation: Mickey Kantor lives in the U.S. and Hosokawa is a political figure in Japan.</s>
#
# ----------------
#
# TEXT: Among the enterprises that consume large amounts of energy , 25 have exceeded quotas -- among them the rope and thread factory ; the Martires leather factory in Caguasu ; the meat complex ; the metal-tooling factory ; and the Cuba Libre , Juan Avila , Reinol Garcia , Mexico , and Jovellanos Farming Complexes .
# Relations: [['Martires leather factory', 'OrgBased_In', 'Caguasu']]
# Explanation: The Martires leather factory is an organization based in Caguasu.</s>
#
# ----------------
#
# TEXT: Beside the dispute over the Gabcikovo hydroelectric project itself which was taken to the International Court of Justice in The Hague last July , Bratislava and Budapest are also in disagreement over the temporary water regime on the Danube to function until a verdict is passed in The Hague .
# Relations: [['International Court of Justice', 'OrgBased_In', 'The Hague'], ['International Court of Justice', 'OrgBased_In', 'The Hague']]
# Explanation: The International Court of Justice is an organization based in The Hague, Netherlands.</s>
#
# ----------------
#
# TEXT: In 1847 , inventor Thomas Alva Edison was born in Milan , Ohio .
# Relations: [['Thomas Alva Edison', 'Live_In', 'Milan , Ohio']]
# Explanation: Thomas Alva Edison was born in Milan, Ohio and thus lived there.</s>
#
# ----------------
#
# TEXT: Brazil : Brazilian Space Program Summarized 94WS0145A Sao Paulo GAZETA MERCANTIL in Portuguese 27-29 Nov 93 p 5
# Relations: [['GAZETA MERCANTIL', 'OrgBased_In', 'Sao Paulo']]
# Explanation: GAZETA MERCANTIL is an organization based in Sao Paulo, Brazil.</s>
#
# ----------------
#
# TEXT: Rainfall , heavy over the lower Mississippi and Tennessee valleys in recent days left streams in Tennessee , Kentucky and northern Alabama flowing near bankful , and flooded some streets in Memphis , Tenn. , during rush hour .
# Relations: [['Memphis', 'Located_In', 'Tenn.']]
# Explanation: It can be seen that Memphis is a place located in Tenn. as it was flooded during rush hour.</s>
#
# ----------------
#
# TEXT: A thunderstorm dumped more than half an inch of rain in 12 minutes in Cedar City , Utah Monday afternoon , flooding basements in about 200 homes and buildings.
# Relations: [['Cedar City', 'Located_In', 'Utah']]
# Explanation: Cedar City is a place located in Utah.</s>
#
# ----------------
#
# TEXT: ` ` It would be helpful if you folks would provide leadership , ' ' shot back Rep. Ted Weiss , D-N.Y. , chairman of the House oversight subcommittee grilling Mason and other administration officials about a broad range of AIDS programs.
# Relations: [['Ted Weiss', 'Work_For', 'House']]
# Explanation: Ted Weiss is a Representative of the House and is chairman of the House oversight subcommittee.</s>
#
# ----------------
#
# TEXT: Also on Thursday , Knight-Ridder announced that it has named Larry Jinks publisher of the San Jose Mercury News , succeeding William A. Ott , who will be the newspaper 's chairman .
# Relations: [['Larry Jinks', 'Work_For', 'Knight-Ridder'], ['Larry Jinks', 'Work_For', 'San Jose Mercury News'], ['William A. Ott', 'Work_For', 'Knight-Ridder'], ['William A. Ott', 'Work_For', 'San Jose Mercury News']]
# Explanation: Larry Jinks is the publisher of the San Jose Mercury News, while William A. Ott is its chairman. Both of them work for Knight-Ridder as well as San Jose Mercury News.</s>
#
# ----------------
#
# TEXT: ( Editorial Report ) Panama City Circuito RPC Television in Spanish at 0200 GMT on 9 March broadcasts its 60-minute " Democracy 94 " program , which features a live or recorded interview with Ruben Blades , presidential candidate of the Papa Egoro Movement , MPE , by Hugo Enrique Famania .
# Relations: [['Ruben Blades', 'Work_For', 'Papa Egoro Movement'], ['Ruben Blades', 'Work_For', 'MPE']]
# Explanation: Ruben Blades is a presidential candidate for the Papa Egoro Movement and the MPE.</s>
#
# ----------------
#
# TEXT: The fire at the Pacific Fleet Air Wing 's ammunition dump , which resulted from today 's explosion , is being localized , according to the fleet 's senior duty officer Vsevolod Fadeyev .
# Relations: [['Vsevolod Fadeyev', 'Work_For', 'Pacific Fleet']]
# Explanation: Vsevolod Fadeyev is a senior duty officer for the Pacific Fleet.</s>
#
# ----------------
#
# TEXT: ( By ITAR-TASS diplomatic correspondent Yuriy Tyssovsky )
# Relations: [['Yuriy Tyssovsky', 'Work_For', 'ITAR-TASS']]
# Explanation: Yuriy Tyssovsky is a diplomatic correspondent for the ITAR-TASS.</s>
#
# ----------------
#
# TEXT: The explosion set fire to about 100 yards of wooded area , said Lt. Jim Bowell of the Butler Township Fire Department .
# Relations: [['Jim Bowell', 'Work_For', 'Butler Township Fire Department']]
# Explanation: Jim Bowell is a Lieutenant of the Butler Township Fire Department.</s>
#
# ----------------
#
# TEXT: In 1964 , a jury in Dallas found Jack Ruby guilty of murdering Lee Harvey Oswald , the accused assassin of President Kennedy.
# Relations: [['Jack Ruby', 'Kill', 'Lee Harvey Oswald']]
# Explanation: Jack Ruby was found guilty of murdering Lee Harvey Oswald.</s>
#
# ----------------
#
# TEXT: Robert Bernero , chief of waste disposal for the NRC , said the shafts would be ` ` the first major holes to be dug into the Yucca Mountain formation. ' '
# Relations: [['Robert Bernero', 'Work_For', 'NRC']]
# Explanation: Robert Bernero is the chief of waste disposal for the NRC.</s>
#
# ----------------
#
# TEXT: ( Text ) Crimean Supreme Soviet Chairman Mykola Bahrov met today with U.S. Ambassador to Ukraine William Miller.
# Relations: [['William Miller.', 'Live_In', 'Ukraine']]
# Explanation: William Miller is the U.S. Ambassador to Ukraine, which means he lives in Ukraine.</s>
#
# ----------------
#
# TEXT: The book , ` ` On the Brink : Americans and Soviets Reexamine the Cuban Missile Crisis , ' ' is based largely on two 1987 conferences sponsored by Harvard _ one that featured top Kennedy advisers and U.S. scholars and a second in which three Soviets joined the Americans .
# Relations: [['Harvard', 'OrgBased_In', 'U.S.'], ['Kennedy', 'Live_In', 'U.S.']]
# Explanation: Harvard is an organization based in the U.S. and Kennedy was an American and lived in the U.S..</s>
#
# ----------------
#
# TEXT: Derwinski 's involvement in the episode and his early lack of candor will be investigated during Senate confirmation hearings on his nomination to head the new Veterans Department , said Sen. Alan Cranston , D-Calif. , chairman of the Senate Committee on Veterans Affairs .
# Relations: [['Alan Cranston', 'Work_For', 'Senate Committee on Veterans Affairs']]
# Explanation: Alan Cranston is the chairman of the Senate Committee on Veterans Affairs.</s>
#
# ----------------
#
# TEXT: On the Republican side , state Sen. Ileana Ros-Lehtinen concentrated on get-out-the-vote efforts Monday in hopes of winning a majority against opponents led by fellow Cuban-American Carlos Perez , a wealthy activist for conservative causes who was endorsed by former National Security Council aide Oliver North.
# Relations: [['Oliver North.', 'Work_For', 'National Security Council']]
# Explanation: Oliver North was an aide for the National Security Council.</s>
#
# ----------------
#
# TEXT: In 1865 , John Wilkes Booth , the assassin of President Abraham Lincoln , was surrounded by federal troops near Bowling Green , Va. , and killed .
# Relations: [['John Wilkes Booth', 'Kill', 'President Abraham Lincoln']]
# Explanation: John Wilkes Booth was the assassin of President Abraham Lincoln.</s>
#
# ----------------
#
# TEXT: Their deaths bring the number of political assassinations to six since former communist party official Ferhat Chibout was killed on January 27 .
# Relations: [['Ferhat Chibout', 'Work_For', 'communist party']]
# Explanation: Ferhat Chibout was a former official of the communist party.</s>
#
# ----------------
#
# TEXT: ( Text ) Prague , March 5 ( TANJUG ) -- The Committee of Senior Officials of the Conference on Security and Cooperation in Europe ( CSCE ) meeting in Prague called for the early return of its missions to Kosovo , Sandzak and Vojvodina in the Yugoslav Republic of Serbia .
# Relations: [['Kosovo', 'Located_In', 'Yugoslav Republic of Serbia'], ['Sandzak', 'Located_In', 'Yugoslav Republic of Serbia'], ['Vojvodina', 'Located_In', 'Yugoslav Republic of Serbia']]
# Explanation: The Committee of Senior Officials of the CSCE called for the early return of its missions to Kosovo, Sandzak and Vojvodina, which are located in the Yugoslav Republic of Serbia.</s>
#
# ----------------
#
# TEXT: Lee 's surrender of the Army of Northern Virginia had virtually ended the war by that time , but Booth thought he could save the South by killing Lincoln , said Tidwell , a retired CIA officer .
# Relations: [['Booth', 'Kill', 'Lincoln']]
# Explanation: Booth thought he could save the South by killing Lincoln.</s>
#
# ----------------
#
# TEXT: Pittsburgh Mayor Sophie Masloff touted the joys of her favorite city on the nationally televised Pat Sajak Show and put an end to rumors that she sometimes arrives at work with a cup of homemade chicken soup .
# Relations: [['Sophie Masloff', 'Live_In', 'Pittsburgh']]
# Explanation: Sophie Masloff is the mayor of Pittsburgh, so it can be inferred that she lives in Pittsburgh.</s>
#
# ----------------
#
# TEXT: This April 14 is the 125th anniversary of the night when Lincoln , the 16th president , was assassinated by John Wilkes Booth in the presidential box at Ford 's Theatre .
# Relations: [['John Wilkes Booth', 'Kill', 'Lincoln']]
# Explanation: John Wilkes Booth killed Lincoln, the 16th president, on the night of April 14th.</s>
#
# ----------------
#
# TEXT: PY2604013394 Rio de Janeiro O GLOBO in Portuguese 23 Apr 94 p 8
# Relations: [['O GLOBO', 'OrgBased_In', 'Rio de Janeiro']]
# Explanation: O GLOBO is an organization based in Rio de Janeiro.</s>
#
# ----------------
#
# TEXT: The Foreign Ministry 's Southeast Asian Department Chief Don Paramatwinai quoted President Kim as saying that the nuclear conflict between South and North Korea posed not only a threat to the Korean Peninsula but the entire world .
# Relations: [['Don Paramatwinai', 'Work_For', 'Foreign Ministry'], ['Don Paramatwinai', 'Work_For', 'Southeast Asian Department']]
# Explanation: Don Paramatwinai is the Chief of the Southeast Asian Department of the Foreign Ministry.</s>
#
# ----------------
#
# TEXT: LD2204095694 Madrid RNE International in Spanish 0800 GMT 22 Apr 94
# Relations: [['RNE International', 'OrgBased_In', 'Madrid']]
# Explanation: RNE International is an organization based in Madrid.</s>
#
# ----------------
#
# TEXT: The investigation centers on a check and drain valve for the F404 engine that powers the Navy 's FA-18 fighter , GE spokesman Richard Kennedy said Wednesday .
# Relations: [['Richard Kennedy', 'Work_For', 'GE']]
# Explanation: Richard Kennedy is a spokesman for GE.</s>
#
# ----------------
#
# TEXT: Genetic material could disclose whether Lincoln was afflicted with an inherited disease called Marfan syndrome , as some experts suspect from indirect evidence , which could have taken his life at any time , even if John Wilkes Booth had not assassinated him at Ford 's Theater on April 14 , 1865. ;
# Relations: [['John Wilkes Booth', 'Kill', 'Lincoln']]
# Explanation: John Wilkes Booth assassinated Lincoln at Ford's Theater on April 14, 1865.</s>
#
# ----------------
#
# TEXT: Palestine Liberation Organization chairman Yasser Arafat addressed a league committee and berated Arab colleagues for reneging on their promise of aid to the people of the Israeli occupied West Bank and Gaza Strip .
# Relations: [['Yasser Arafat', 'Work_For', 'Palestine Liberation Organization']]
# Explanation: Yasser Arafat is the chairman of the Palestine Liberation Organization.</s>
#
# ----------------
#
# TEXT: Diplomatic Correspondents Igor Porshnev , Vitaly Trubetskoi and others ) ( Text ) Russia " resolutely condemns the senseless subversive activity of those , who seek to cast shadow on the elections to the first non-racial parliament in South Africa , " said the Foreign Ministry spokesman , Grigory Karasin , at Thursday 's ( 28 April ) briefing in Moscow .
# Relations: [['Grigory Karasin', 'Work_For', 'Foreign Ministry']]
# Explanation: Grigory Karasin works for the Foreign Ministry.</s>
#
# ----------------
#
# TEXT: From a broader perspective , Mason pointed out that he also bears responsiblity for preparing the entire Public Health Service budget , which includes the National Insitutes of Health , the O and Drug Administration and several lesser known agencies.
# Relations: [['Mason', 'Work_For', 'Public Health Service']]
# Explanation: Mason works for the Public Health Service, which includes the National Institutes of Health, the O and Drug Administration and several lesser known agencies.</s>
#
# ----------------
#
# TEXT: The Warren Commission 's central conclusion , that Mr Kennedy was killed by Lee Harvey Oswald acting alone , has been backed up by most serious inquiries since then , with the exception of a 1979 House of Representatives select committee chaired by Mr Louis Stokes , an Ohio Democrat , which found that a second gunman probably fired at Mr Kennedy and missed .
# Relations: [['Lee Harvey Oswald', 'Kill', 'Mr Kennedy']]
# Explanation: Lee Harvey Oswald was the lone gunman who killed Mr Kennedy.</s>
#
# ----------------
#
# TEXT: Washington : About 110 firefighters cut a containment line most of the way around an 850-acre forest fire in the Pasayten Wilderness near the Canadian border Tuesday.
# Relations: [['Pasayten Wilderness', 'Located_In', 'Washington']]
# Explanation: The Pasayten Wilderness is located in Washington state.</s>
#
# ----------------
#
# TEXT: Agents of the FBI and the Environmental Protection Agency raided the Rocky Flats plutonium processing plant in Colorado and the Fernald uranium processing plant in Ohio this summer.
# Relations: [['Rocky Flats', 'Located_In', 'Colorado'], ['Fernald', 'Located_In', 'Ohio']]
# Explanation: Rocky Flats plutonium processing plant is located in Colorado and the Fernald uranium processing plant is located in Ohio.</s>
#
# ----------------
#
# TEXT: Booth sneaked into the President 's box and shot Lincoln in the back of the head .
# Relations: [['Booth', 'Kill', 'Lincoln']]
# Explanation: Booth sneaked into the President's box and shot Lincoln in the back of the head, thus killing him.</s>
#
# ----------------
#
# TEXT: ( Text ) Diego Fernandez de Cevallos is reportedly ahead of Ernesto Zedillo , candidate of the Institutional Revolutionary Party ( PRI ) by only 5 percent of the vote in the race for the Presidency of the republic , according to two recent polls , one conducted by the Opinion Research Center ( CEO ) and the University of Guadalajara and the other by the Indemerc-Louis Harris Firm .
# Relations: [['Ernesto Zedillo', 'Work_For', 'Institutional Revolutionary Party']]
# Explanation: Ernesto Zedillo is a candidate of the Institutional Revolutionary Party (PRI).</s>
#
# ----------------
#
# TEXT: Sturholm had resigned effective Monday and told friends he intended to pursue interests in writing and video production , said Kathryn Rich , assistant news director for KIRO.
# Relations: [['Sturholm', 'Work_For', 'KIRO.'], ['Kathryn Rich', 'Work_For', 'KIRO.']]
# Explanation: Sturholm had resigned from KIRO and Kathryn Rich is an assistant news director for KIRO.</s>
#
# ----------------
#
# TEXT: In 1854 , George Eastman , inventor of the Kodak camera , was born in Waterville , N. Y.
# Relations: [['George Eastman', 'Live_In', 'Waterville , N. Y.']]
# Explanation: George Eastman was born in Waterville, N. Y., so he lived in Waterville, N. Y.</s>
#
# ----------------
#
# TEXT: Photo , Dueling Over a GunIt is a scene seared into the memories of Americans old enough to have watched it that November day in 1963 : Jack Ruby firing his .38-caliber Colt Cobra , above , at Lee Harvey Oswald , the man who had assassinated President John F. Kennedy two days earlier.
# Relations: [['Jack Ruby', 'Kill', 'Lee Harvey Oswald'], ['Lee Harvey Oswald', 'Kill', 'President John F. Kennedy']]
# Explanation: Jack Ruby killed Lee Harvey Oswald, who had assassinated President John F. Kennedy two days earlier.</s>
#
# ----------------
#
# TEXT: BLYTHE , Calif .
# Relations: [['BLYTHE', 'Located_In', 'Calif .']]
# Explanation: BLYTHE is a place located in Calif..</s>
#
# ----------------
#
# TEXT: Darci Alves Pereira stunned a packed courtroom by admitting he shot Mendes on Dec. 22 , 1988 , shortly after dark outside his home in this remote Amazon town near the Bolivian border , 2 , 650 miles northwest of Rio de Janeiro .
# Relations: [['Darci Alves Pereira', 'Kill', 'Mendes']]
# Explanation: Darci Alves Pereira admitted to shooting Mendes, thus establishing a relation of Kill.</s>
#
# ----------------
#
# TEXT: ADDIS ABABA , Ethiopia ( AP )
# Relations: [['ADDIS ABABA', 'Located_In', 'Ethiopia']]
# Explanation: ADDIS ABABA is a place located in Ethiopia.</s>
#
# ----------------
#
# TEXT: Ten years ago : Former President Gerald R. Ford , a member of the Warren Commission that investigated President John F. Kennedy 's assassination , told a House committee he stood by the commission 's basic finding that assassin Lee Harvey Oswald had acted alone .
# Relations: [['Lee Harvey Oswald', 'Kill', 'President John F. Kennedy']]
# Explanation: Lee Harvey Oswald was the assassin of President John F. Kennedy.</s>
#
# ----------------
#
# TEXT: WASHINGTON ( AP )
# Relations: [['AP', 'OrgBased_In', 'WASHINGTON']]
# Explanation: AP is an organization based in Washington.</s>
#
# ----------------
#
# TEXT: Pereira 's father , rancher Darly Alves da Silva , was convicted of planning the shotgun slaying of Mendes , an internationally known crusader for the preservation of the Amazon forest from destruction by ranchers and loggers .
# Relations: [['Darly Alves da Silva', 'Kill', 'Mendes']]
# Explanation: Darly Alves da Silva was convicted of planning the shotgun slaying of Mendes.</s>
#
# ----------------
#
# TEXT: In 1969 , James Earl Ray pleaded guilty in Memphis , Tenn. , to the assassination of civil rights leader Martin Luther King Junior .
# Relations: [['James Earl Ray', 'Kill', 'Martin Luther King Junior']]
# Explanation: James Earl Ray was responsible for the assassination of Martin Luther King Junior.</s>
#
# ----------------
#
# TEXT: These bodies have been flowing into Lake Victoria causing a health hazard along the Akagera River course through Tanzania and Uganda .
# Relations: [['Akagera River', 'Located_In', 'Tanzania'], ['Akagera River', 'Located_In', 'Uganda']]
# Explanation: The Akagera River flows through Tanzania and Uganda, so it is located in both countries.</s>
#
# ----------------
#
# TEXT: ( Interview with Major Samih al-Sa 'id , Asyut
# Relations: [["Samih al-Sa 'id", 'Live_In', 'Asyut']]
# Explanation: Major Samih al-Sa 'id is from Asyut, meaning he lives in Asyut.</s>
#
# ----------------
#
# TEXT: Attacks on Bosnia " ; as released by The Hague ANP Database ) ( Text ) The Hague , 9 Feb ( ANP ) -- F-16 pilots from the Netherlands Air Force are to begin exercises -- with real bombs -- on Monday ( 7 February ) on the island of Vlieland for two weeks .
# Relations: [['ANP', 'OrgBased_In', 'The Hague'], ['ANP', 'OrgBased_In', 'The Hague']]
# Explanation: ANP is an organization based in The Hague and The Hague ANP Database is an organization also based in The Hague.</s>
#
# ----------------
#
# TEXT: The spy , high-ranking Korean CIA official Sohn Ho Young , wanted to defect because he was about to be transferred home from a post in New York City , the newspaper said .
# Relations: [['Sohn Ho Young', 'Work_For', 'Korean CIA']]
# Explanation: Sohn Ho Young is a high-ranking official of the Korean CIA.</s>
#
# ----------------
#
# TEXT: In 1865 , John Wilkes Booth , the assassin of President Abraham Lincoln , was surrounded by federal troops near Bowling Green , Va. , and killed .
# Relations: [['John Wilkes Booth', 'Kill', 'President Abraham Lincoln']]
# Explanation: John Wilkes Booth was the assassin of President Abraham Lincoln.</s>
#
# ----------------
#
# TEXT: Almost 23 years ago , it was Barry who jumped out of the crowd at the Ambassador Hotel in Los Angeles when Sen. Robert F. Kennedy was shot and tackled Kennedy 's assassin , Sirhan Sirhan .
# Relations: [['Sirhan Sirhan', 'Kill', 'Sen. Robert F. Kennedy'], ['Sirhan Sirhan', 'Kill', 'Kennedy']]
# Explanation: Sirhan Sirhan was the assassin who killed both Sen. Robert F. Kennedy and Kennedy.</s>
#
# ----------------
#
# TEXT: Louis W. Parker , born in Budapest , Hungary , who is credited with developing the television receiver.
# Relations: [['Louis W. Parker', 'Live_In', 'Budapest , Hungary']]
# Explanation: Louis W. Parker was born in Budapest, Hungary and thus lived there.</s>
#
# ----------------
#
# TEXT: Birand asserts that " the lastest situation on arms supplies has been created by the problems in Germany 's domestic politics , " and goes on to point out that the German Government faces elections this year .
# Relations: [['German Government', 'OrgBased_In', 'Germany']]
# Explanation: The German Government is an organization based in Germany.</s>
#
# ----------------
#
# TEXT: It recommended stopping nuclear fuels processing at four sites where problems have been highly publicized : the Rocky Flats Plant near Denver , the Hanford Site near Richland , Wash. , the Feed Materials Production Center at Fernald , Ohio , and the Mound Plant in Ohio .
# Relations: [['Richland', 'Located_In', 'Wash.'], ['Feed Materials Production Center', 'Located_In', 'Fernald'], ['Feed Materials Production Center', 'Located_In', 'Ohio'], ['Feed Materials Production Center', 'Located_In', 'Ohio'], ['Fernald', 'Located_In', 'Ohio'], ['Mound Plant', 'Located_In', 'Ohio']]
# Explanation: Richland is located in Wash., Feed Materials Production Center is located in Fernald and Ohio, and Mound Plant is located in Ohio.</s>
#
# ----------------
#
# TEXT: On Monday , the nation will observe the birthday of Martin Luther King Jr. , who was cut down by assassin James Earl Ray in 1968 .
# Relations: [['James Earl Ray', 'Kill', 'Martin Luther King Jr.']]
# Explanation: James Earl Ray assassinated Martin Luther King Jr. in 1968.</s>
#
# ----------------
#
# TEXT: He said the failure of the talks between the Phnom Penh government and the Khmer Rouge faction in Pyongyang recently was due to the fact that the Khmer Rouge put forward proposals that did not totally lend support to the integrity of Cambodia .
# Relations: [['Phnom Penh government', 'OrgBased_In', 'Cambodia'], ['Khmer Rouge', 'OrgBased_In', 'Cambodia']]
# Explanation: The Phnom Penh government and the Khmer Rouge faction are both based in Cambodia.</s>
#
# ----------------
#
# TEXT: Today 's highlight in history : In 1901 , President William McKinley was shot by anarchist Leon Czolgosz at the Pan-American Exposition in Buffalo , N.Y.
# Relations: [['Leon Czolgosz', 'Kill', 'President William McKinley']]
# Explanation: Leon Czolgosz was the anarchist who shot President William McKinley at the Pan-American Exposition in Buffalo, N.Y.</s>
#
# ----------------
#
# TEXT: CDT Tuesday in the area of Port Arther and Galveston , Texas.
# Relations: [['Port Arther', 'Located_In', 'Texas.'], ['Galveston', 'Located_In', 'Texas.']]
# Explanation: Port Arther and Galveston are places located in Texas.</s>
#
# ----------------
#
# TEXT: Paris AFP
# Relations: [['AFP', 'OrgBased_In', 'Paris']]
# Explanation: AFP is an organization based in Paris.</s>
#
# ----------------
#
# TEXT: In 1977 , James Earl Ray , the convicted assassin of civil rights leader Dr. Martin Luther King Jr. , was recaptured following his escape from a Tennessee prison June 10 .
# Relations: [['James Earl Ray', 'Kill', 'Dr. Martin Luther King Jr.']]
# Explanation: James Earl Ray was the convicted assassin of civil rights leader Dr. Martin Luther King Jr..</s>
#
# ----------------
#
# TEXT: Christophersen Says " ) ( Text ) ( ANSA ) Brussels , May 25 -- Price and exchange rate stability , achieved by reducing the inflation rate by no more than 2-3 percent by 1996 , were among the primary objectives indicated by the European Commission to member states , including Italy , in a program document outlined here today by Commissioner Henning Christophersen .
# Relations: [['ANSA', 'OrgBased_In', 'Brussels']]
# Explanation: ANSA is an organization based in Brussels.</s>
#
# ----------------
#
# TEXT: It launched the careers of many well-known actors , including Corbin Bernsen , who stars on NBC 's ` ` L.A. Law , ' ' and Kate Mulgrew , star of ABC 's ` ` HeartBeat. ' '
# Relations: [['Corbin Bernsen', 'Work_For', 'NBC'], ['Kate Mulgrew', 'Work_For', 'ABC']]
# Explanation: Corbin Bernsen stars on NBC’s “L.A. Law” and Kate Mulgrew stars on ABC’s “HeartBeat”. Therefore, they both work for NBC and ABC respectively.</s>
#
# ----------------
#
# TEXT: In Wednesday 's announcement , locations containing unused or underutilized federally owned buildings deemed suitable for homeless facilities were listed as : Clear Air Force Station , Alaska ;
# Relations: [['Clear Air Force Station', 'Located_In', 'Alaska']]
# Explanation: Clear Air Force Station was listed as a location in Alaska, thus it can be said that it is located in Alaska.</s>
#
# ----------------
#
# TEXT: Portland , Maine 11 fair ;
# Relations: [['Portland', 'Located_In', 'Maine']]
# Explanation: Portland is located in Maine.</s>
#
# ----------------
#
# TEXT: There are , to be sure , WPA accounts of the impact of the Depression on rural America , great photographs by Walker Evans , but North Carolina 's native son Thomas Wolfe , in " You Can 't Go Home Again , " described more lyrically the repercussions that events on Wall Street had on his state , even in little hollows like Monroe :
# Relations: [['Thomas Wolfe', 'Live_In', 'North Carolina']]
# Explanation: Thomas Wolfe is a native of North Carolina and therefore lived in North Carolina.</s>
#
# ----------------
#
# TEXT: " We hope to dispel the different myths about why Weiss allegedly killed Huey Long , when Weiss was on the threshold of beginning a very exciting life , " Johnston said Wednesday from Washington. ;
# Relations: [['Weiss', 'Kill', 'Huey Long']]
# Explanation: Weiss allegedly killed Huey Long.</s>
#
# ----------------

# %%
conll_data = load_dataset("csv", data_files="conll_gpt3_explanations_responses.csv")
conll = conll_data["train"]

conll_reference = load_dataset("csv", data_files="conll_fewshot_reference.csv")
conll_eval = conll_reference["train"]
# Out:
# Using custom data configuration default-7c18d0d9ebe66610
# Found cached dataset csv (/home/wadhwa.s/.cache/huggingface/datasets/csv/default-7c18d0d9ebe66610/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
# 100%|██████████| 1/1 [00:00<00:00, 756.14it/s]
# Using custom data configuration default-01766038312a4186
# Found cached dataset csv (/home/wadhwa.s/.cache/huggingface/datasets/csv/default-01766038312a4186/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
# 100%|██████████| 1/1 [00:00<00:00, 730.21it/s]

# %%
prefix = """List all relations of the following type in the given text and provide reasonable explanations for your answers - \n1. Kill: Entity A killed Entity B.\n2. Work_For: Entity A works for Entity B.\n3. Located_In: Entity A is located in Entity B.\n4. Live_In: Entity A lives in Entity B.\n5. OrgBased_In: Entity A is an organization based in Entity B.\n\n"""

print (prefix)
# Out:
# List all relations of the following type in the given text and provide reasonable explanations for your answers -
# 1. Kill: Entity A killed Entity B.
# 2. Work_For: Entity A works for Entity B.
# 3. Located_In: Entity A is located in Entity B.
# 4. Live_In: Entity A lives in Entity B.
# 5. OrgBased_In: Entity A is an organization based in Entity B.

# %%
targets = [gold_relations + "\n" + explanation for gold_relations, explanation in zip(conll["gold_relations"], conll["explanations"])]
print (targets[10])
# Out:
# [['Betsy Ross', 'Live_In', 'Philadelphia']]
# Explanation: Betsy Ross was born in Philadelphia and therefore lived in Philadelphia.</s>

# %%
def preprocess_function(examples):
    inputs = [prefix + example + "\nRelations: " for example in examples["input"]]
    model_inputs = tokenizer(inputs, max_length=512, truncation=True)
    targets = [gold_relations + "\n" + explanation for gold_relations, explanation in zip(conll["gold_relations"], conll["explanations"])]
    labels = tokenizer(text_target=targets, max_length=256, truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
"""Split into train and validation sets"""
conll = conll.train_test_split(test_size=0.2)
conll
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'explanations', 'gold_relations'],
#         num_rows: 724
#     })
#     test: Dataset({
#         features: ['input', 'explanations', 'gold_relations'],
#         num_rows: 182
#     })
# })

# %%
tokenized_conll = conll.map(preprocess_function, batched=True)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.77ba/s]

# %%
tokenized_conll = tokenized_conll.train_test_split(test_size=0.2)
tokenized_conll["train"]
# Out:
# Dataset({
#     features: ['input', 'explanations', 'gold_relations', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 724
# })

# %%
torch.cuda.empty_cache()

# %%
torch.cuda.empty_cache()

training_args = Seq2SeqTrainingArguments(
    output_dir="/scratch/wadhwa.s/cache/conll_explanations",
    evaluation_strategy="epoch",
    learning_rate=3e-5,
    per_device_train_batch_size=4,
    eval_delay=3,
    per_device_eval_batch_size=4,
    logging_strategy="epoch",
#    logging_steps=30,
    weight_decay=0.01,
    save_total_limit=7,
    num_train_epochs=25,
    predict_with_generate=True,
    # gradient_accumulation_steps=4,
    # fp16=True,
    # push_to_hub=True,
)

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_conll["train"],
    eval_dataset=tokenized_conll["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: input, gold_relations, explanations. If input, gold_relations, explanations are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 724
#   Num Epochs = 25
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 4525
#   Number of trainable parameters = 783150080
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# wandb: Currently logged in as: sw7. Use `wandb login --relogin` to force relogin
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/wadhwa.s/gpt3/wandb/run-20230102_131044-9y93trv7</code>
# Syncing run <strong><a href="https://wandb.ai/sw7/huggingface/runs/9y93trv7" target="_blank">/scratch/wadhwa.s/cache/conll_explanations</a></strong> to <a href="https://wandb.ai/sw7/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='2066' max='4525' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2066/4525 24:24 < 29:04, 1.41 it/s, Epoch 11.41/25]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>0.157600</td>
#       <td>0.170353</td>
#       <td>0.323500</td>
#       <td>0.258200</td>
#       <td>0.322900</td>
#       <td>0.323000</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.131800</td>
#       <td>0.164951</td>
#       <td>0.317700</td>
#       <td>0.253100</td>
#       <td>0.317300</td>
#       <td>0.317600</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.110800</td>
#       <td>0.169526</td>
#       <td>0.322800</td>
#       <td>0.257600</td>
#       <td>0.321700</td>
#       <td>0.321800</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.097000</td>
#       <td>0.163147</td>
#       <td>0.317800</td>
#       <td>0.253300</td>
#       <td>0.317700</td>
#       <td>0.317600</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.083500</td>
#       <td>0.170356</td>
#       <td>0.323100</td>
#       <td>0.258200</td>
#       <td>0.322600</td>
#       <td>0.322800</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.074600</td>
#       <td>0.174032</td>
#       <td>0.320900</td>
#       <td>0.256600</td>
#       <td>0.320500</td>
#       <td>0.320900</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.064700</td>
#       <td>0.193734</td>
#       <td>0.319800</td>
#       <td>0.255500</td>
#       <td>0.319600</td>
#       <td>0.319300</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.058600</td>
#       <td>0.193359</td>
#       <td>0.324000</td>
#       <td>0.259600</td>
#       <td>0.323500</td>
#       <td>0.323200</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.052200</td>
#       <td>0.202077</td>
#       <td>0.322500</td>
#       <td>0.258800</td>
#       <td>0.321600</td>
#       <td>0.321900</td>
#       <td>19.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /scratch/wadhwa.s/cache/conll_explanations/checkpoint-500
# Configuration saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/conll_explanations/checkpoint-500/spiece.model
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: input, gold_relations, explanations. If input, gold_relations, explanations are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 182
#   Batch size = 4
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: input, gold_relations, explanations. If input, gold_relations, explanations are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 182
#   Batch size = 4
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: input, gold_relations, explanations. If input, gold_relations, explanations are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 182
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/conll_explanations/checkpoint-1000
# Configuration saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-1000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-1000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/conll_explanations/checkpoint-1000/spiece.model
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: input, gold_relations, explanations. If input, gold_relations, explanations are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 182
#   Batch size = 4
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: input, gold_relations, explanations. If input, gold_relations, explanations are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 182
#   Batch size = 4
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: input, gold_relations, explanations. If input, gold_relations, explanations are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 182
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/conll_explanations/checkpoint-1500
# Configuration saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-1500/config.json
# Model weights saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-1500/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/conll_explanations/checkpoint-1500/spiece.model
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: input, gold_relations, explanations. If input, gold_relations, explanations are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 182
#   Batch size = 4
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: input, gold_relations, explanations. If input, gold_relations, explanations are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 182
#   Batch size = 4
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: input, gold_relations, explanations. If input, gold_relations, explanations are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 182
#   Batch size = 4
# Saving model checkpoint to /scratch/wadhwa.s/cache/conll_explanations/checkpoint-2000
# Configuration saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-2000/config.json
# Model weights saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /scratch/wadhwa.s/cache/conll_explanations/checkpoint-2000/special_tokens_map.json
# Copy vocab file to /scratch/wadhwa.s/cache/conll_explanations/checkpoint-2000/spiece.model
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_22269/4032920361.py:1 in <cell line: 1>                                           │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_22269/4032920361.py'                        │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/trainer.py:1501 in      │
# │ train                                                                                            │
# │                                                                                                  │
# │   1498 │   │   inner_training_loop = find_executable_batch_size(                                 │
# │   1499 │   │   │   self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size  │
# │   1500 │   │   )                                                                                 │
# │ ❱ 1501 │   │   return inner_training_loop(                                                       │
# │   1502 │   │   │   args=args,                                                                    │
# │   1503 │   │   │   resume_from_checkpoint=resume_from_checkpoint,                                │
# │   1504 │   │   │   trial=trial,                                                                  │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/trainer.py:1816 in      │
# │ _inner_training_loop                                                                             │
# │                                                                                                  │
# │   1813 │   │   │   │   │   │   scale_after = self.scaler.get_scale()                             │
# │   1814 │   │   │   │   │   │   optimizer_was_run = scale_before <= scale_after                   │
# │   1815 │   │   │   │   │   else:                                                                 │
# │ ❱ 1816 │   │   │   │   │   │   self.optimizer.step()                                             │
# │   1817 │   │   │   │   │                                                                         │
# │   1818 │   │   │   │   │   if optimizer_was_run and not self.deepspeed:                          │
# │   1819 │   │   │   │   │   │   self.lr_scheduler.step()                                          │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:65 in    │
# │ wrapper                                                                                          │
# │                                                                                                  │
# │     62 │   │   │   │   instance = instance_ref()                                                 │
# │     63 │   │   │   │   instance._step_count += 1                                                 │
# │     64 │   │   │   │   wrapped = func.__get__(instance, cls)                                     │
# │ ❱   65 │   │   │   │   return wrapped(*args, **kwargs)                                           │
# │     66 │   │   │                                                                                 │
# │     67 │   │   │   # Note that the returned function here is no longer a bound method,           │
# │     68 │   │   │   # so attributes like `__func__` and `__self__` no longer exist.               │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/torch/optim/optimizer.py:113 in      │
# │ wrapper                                                                                          │
# │                                                                                                  │
# │   110 │   │   │   │   obj, *_ = args                                                             │
# │   111 │   │   │   │   profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)     │
# │   112 │   │   │   │   with torch.autograd.profiler.record_function(profile_name):                │
# │ ❱ 113 │   │   │   │   │   return func(*args, **kwargs)                                           │
# │   114 │   │   │   return wrapper                                                                 │
# │   115 │   │                                                                                      │
# │   116 │   │   hooked = getattr(self.__class__.step, "hooked", None)                              │
# │                                                                                                  │
# │ /home/wadhwa.s/.conda/envs/py38/lib/python3.8/site-packages/transformers/optimization.py:362 in  │
# │ step                                                                                             │
# │                                                                                                  │
# │   359 │   │   │   │   # In-place operations to update the averages at the same time              │
# │   360 │   │   │   │   exp_avg.mul_(beta1).add_(grad, alpha=(1.0 - beta1))                        │
# │   361 │   │   │   │   exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1.0 - beta2)             │
# │ ❱ 362 │   │   │   │   denom = exp_avg_sq.sqrt().add_(group["eps"])                               │
# │   363 │   │   │   │                                                                              │
# │   364 │   │   │   │   step_size = group["lr"]                                                    │
# │   365 │   │   │   │   if group["correct_bias"]:  # No bias correction for Bert                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
torch.cuda.empty_cache()

# %%
tuned_model = AutoModelForSeq2SeqLM.from_pretrained("/scratch/wadhwa.s/cache/conll_explanations/checkpoint-2000")
tokenizer = AutoTokenizer.from_pretrained("/scratch/wadhwa.s/cache/conll_explanations/checkpoint-2000")
# Out:
# loading configuration file /scratch/wadhwa.s/cache/conll_explanations/checkpoint-2000/config.json
# Model config T5Config {
#   "_name_or_path": "/scratch/wadhwa.s/cache/conll_explanations/checkpoint-2000",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2816,
#   "d_kv": 64,
#   "d_model": 1024,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 24,
#   "num_heads": 16,
#   "num_layers": 24,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading weights file /scratch/wadhwa.s/cache/conll_explanations/checkpoint-2000/pytorch_model.bin
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at /scratch/wadhwa.s/cache/conll_explanations/checkpoint-2000.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# loading file spiece.model
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json

# %%
df = pd.read_csv("conll_fewshot_reference.csv")
df.shape
# Out:
# (231, 3)

# %%
ip = []
gold = []
generated = []
nc_count = 0

for ix, row in tqdm(df.iterrows(), total=df.shape[0]):
    text = prefix + row["text"]
    inputs = tokenizer(text, return_tensors="pt").input_ids
    outputs = tuned_model.generate(inputs, max_new_tokens=256, do_sample=False)
    out = tokenizer.decode(outputs[0], skip_special_tokens=True)
    torch.cuda.empty_cache()
    try:
        generated.append(out.split(" Explanation: ")[0])
        ip.append(row["text"])
        gold.append(row["gold_labels"])
        # print ("PRED: " + out)
    except:
        nc_count += 1
        print (row["text"])
        print ("GOLD: " + row["gold_labels"])
        print ("PRED ---- NON CONFORMING OUTPUT: " + out)
        print ("\n----------------\n")
# Out:
# 100%|██████████| 231/231 [35:52<00:00,  9.32s/it]

# %%
df = pd.DataFrame({"text": ip, "gold_labels": gold, "generated": generated})
# df.to_csv("conll_flan_explanations_generated_ckpt500.csv", index=False)
print (df.shape)
# Out:
# (231, 3)

# %%
invalid_count = 0
total_count = 0
valid_parsed = 0
for ix, row in df.iterrows():
    # print ("GOLD: " + row["gold_labels"])
    try:
        pred = ast.literal_eval(row["generated"])
        total_count += len(pred)
        valid_parsed += 1
        for relation in pred:
            if relation[1] not in valid:
                print ("TEXT: ", row["text"])
                print ("PRED: " + relation)
                print ("\n*********************\n")
    except:
        invalid_count += 1
        print ("TEXT: ", row["text"])
        print ("NON CONFORMING PRED: ", row["generated"])
        print ("\n----------------\n")
# Out:
# TEXT:  The opera company performed at the Palace of Fine Arts , in San Francisco , on June 30 and July 1-2 , said Kevin O 'Brien , a spokesman for the theater.
# NON CONFORMING PRED:  [['Palace of Fine Arts', 'OrgBased_In', 'San Francisco'], ['Kevin O'Brien', 'Work_For', 'Palace of Fine Arts'], ['Kevin O'Brien', 'Live_In', 'San Francisco']]
#
# ----------------
#
# TEXT:  It was filmed on location in Tokyo and Kyoto and is a co-production of Children 's Television Worship and NHK network in Japan .
# NON CONFORMING PRED:  [['Children's Television Worship', 'OrgBased_In', 'Tokyo'], ['NHK network', 'OrgBased_In', 'Japan']]
#
# ----------------
#
# TEXT:  Guy M. Struve , the New York attorney representing Church 's , said he was disappointed and did not know when the chain would decide whether to appeal Thursday 's ruling .
# NON CONFORMING PRED:  [['Guy M. Struve', 'Work_For', 'Church's']]
#
# ----------------
#
# TEXT:  During my recent tour , I met with Sultan Qabus Bin-Sa 'id of Oman .
# NON CONFORMING PRED:  [['Sultan Qabus Bin-Sa 'id', 'Live_In', 'Oman']]
#
# ----------------

# %%
print (invalid_count, total_count, valid_parsed)
# Out:
# 4 299 227

# %%
text = [prefix + s1, prefix + s2]
print (text[1])
# Out:
# List all relations of the following type in the given text and provide reasonable explanations for your answers -
# 1. Kill: Entity A killed Entity B.
# 2. Work_For: Entity A works for Entity B.
# 3. Located_In: Entity A is located in Entity B.
# 4. Live_In: Entity A lives in Entity B.
# 5. OrgBased_In: Entity A is an organization based in Entity B.
#
# TEXT: Harry Truman then signed the final legislation to create the National Security Council at his residence in Washington .

# %%
torch.cuda.empty_cache()
inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True).input_ids

# %%
len(inputs)
# Out:
# 2

# %%
outputs = model.generate(inputs, max_new_tokens=256, do_sample=False)

# %%
out = tokenizer.decode(outputs[1], skip_special_tokens=True)
print (out)
# Out:
# [['Harry Truman', 'Live_In', 'Washington']] Explanation: Harry Truman lives in Washington, so it can be concluded that Harry Truman Lives In Washington.

# %%
out = out.split(" Explanation")[0]

# %%
import ast

# %%
print (ast.literal_eval(out))
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────╮
# │  <unknown>:1                                                                                     │
# │ [['Sultan Qabus Bin-Sa'id', 'Work_For', 'Oman']]                                                 │
# │                        ▲                                                                         │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# SyntaxError: invalid syntax

# %%
conll = json.load(open('conll04_dev.json'))

# %%
conll[4]
# Out:
# {'tokens': ['Marie',
#   'Magdefrau',
#   'Ferraro',
#   ',',
#   '50',
#   ',',
#   'of',
#   'Bethany',
#   ',',
#   'Conn.',
#   ',',
#   'was',
#   'shot',
#   'to',
#   'death',
#   'Thursday',
#   'when',
#   'two',
#   'bandits',
#   'armed',
#   'with',
#   'assault',
#   'rifles',
#   'emerged',
#   'from',
#   'nearby',
#   'bushes',
#   'and',
#   'began',
#   'firing',
#   'at',
#   'a',
#   'van',
#   'carrying',
#   'a',
#   'Connecticut',
#   'Audubon',
#   'Society',
#   'wildlife',
#   'wild',
#   'tour',
#   'group',
#   '.'],
#  'entities': [{'type': 'Peop', 'start': 0, 'end': 3},
#   {'type': 'Loc', 'start': 7, 'end': 8},
#   {'type': 'Loc', 'start': 9, 'end': 10},
#   {'type': 'Org', 'start': 35, 'end': 39}],
#  'relations': [{'type': 'Live_In', 'head': 0, 'tail': 1},
#   {'type': 'Live_In', 'head': 0, 'tail': 2},
#   {'type': 'Located_In', 'head': 1, 'tail': 2}],
#  'orig_id': 1771}
